# %%
import os
from tqdm.notebook import tqdm
import glob
import numpy as np
import pandas as pd
import random
from collections import defaultdict
from nltk.tokenize import sent_tokenize, word_tokenize

# %% [markdown]
# # Read files and annotations

# %%
#This class is provided by i2b2 challenge. I use its functions to get annotations and text

class RecordTrack2(object):
    """Record for Track 2 class."""

    def __init__(self, file_path):
        """Initialize."""
        self.path = os.path.abspath(file_path)
        self.basename = os.path.basename(self.path)
        self.annotations = self._get_annotations()
        # self.text = self._get_text()

    @property
    def tags(self):
        return self.annotations['tags']

    @property
    def relations(self):
        return self.annotations['relations']

    def _get_annotations(self):
        """Return a dictionary with all the annotations in the .ann file."""
        annotations = defaultdict(dict)
        with open(self.path) as annotation_file:
            lines = annotation_file.readlines()
            for line_num, line in enumerate(lines):
                if line.strip().startswith('T'):
                    try:
                        tag_id, tag_m, tag_text = line.strip().split('\t')
                    except ValueError:
                        print(self.path, line)
                    if len(tag_m.split(' ')) == 3:
                        tag_type, tag_start, tag_end = tag_m.split(' ')
                    elif len(tag_m.split(' ')) == 4:
                        tag_type, tag_start, _, tag_end = tag_m.split(' ')
                    elif len(tag_m.split(' ')) == 5:
                        tag_type, tag_start, _, _, tag_end = tag_m.split(' ')
                    else:
                        print(self.path)
                        print(line)
                    tag_start, tag_end = int(tag_start), int(tag_end)
                    annotations['tags'][tag_id] = (tag_id, tag_start ,tag_end, tag_type, tag_text)
            for line_num, line in enumerate(lines):
                if line.strip().startswith('R'):
                    rel_id, rel_m = line.strip().split('\t')
                    rel_type, rel_arg1, rel_arg2 = rel_m.split(' ')
                    rel_arg1 = rel_arg1.split(':')[1]
                    rel_arg2 = rel_arg2.split(':')[1]
                    arg1 = annotations['tags'][rel_arg1]
                    arg2 = annotations['tags'][rel_arg2]
                    annotations['relations'][rel_id] = (arg1,arg2, rel_type)
        return annotations

    def get_text(self):
        """Return the text in the corresponding txt file."""
        path = self.path.replace('.ann', '.txt')
        with open(path) as text_file:
            text = text_file.read()
        return text

# %%
#reading data and create a list of RecordTrack2 class for each file
folder1 = 'test/'
anno = []
files1 = set([os.path.basename(f) for f in glob.glob(
    os.path.join(folder1, '*.ann'))])
for file in files1:
    anno.append(RecordTrack2(os.path.join(folder1, file)))

# %% [markdown]
# # Generate entities within sentence
#
# Find the offset of each entity within that sentence.
#
# The offset provided by i2b2 is aginst the whole file.
#
# In this section, we will locate the entity, tokenise sentense, and remove extra spaces
#
# The offset I generated in this section is word offset (created by len(text.split()), feel free to change to character offset if needed.

# %%
#function to generate the first entity in a sentence
def first_entity(text, start, end, entity):
        text_before = sent_tokenize(text[:start]) #all the text befere the start of the entity
        sent_num = len(text_before)
        word_before = text_before[-1].split() #words before entity in the current sentence 
        word_start = len(word_before) #start position
        word_end = word_start+len(entity.split()) #end position
        sent_after = sent_tokenize(text[end:])[0] #the left of current sentence
        sent_piece = ' '.join(word_before + entity.split()) #current sentence until the end of first entity, extra spaces removed by .split()
        return word_start, word_end, sent_after, sent_piece

# %%
#function to generate non-first entity in a sentence, same logic sa first_entity function
def entity_within_sent(text, word_end_before, end_before, start, end, entity):
    word_between = text[end_before:start].split()
    word_start = word_end_before + len(word_between)
    word_end = word_start+len(entity.split())
    sent_after = sent_tokenize(text[end:])[0]
    #print(sent_after)
    sent_piece = ' '.join(word_between + entity.split())
    return word_start, word_end, sent_after, sent_piece

# %%
tags_list = []
sents_dict = {}
for i, an in enumerate(tqdm(anno)):
    text = an.get_text()
    tags = pd.DataFrame(an.tags.values()).sort_values(1).values
    #skip used to mark how many entities we have processed within the previous sentence
    skip = 0
    for j, (en_id, start, end, concept, entity) in enumerate(tags):
        #we skip the entities we have processed from last sentence, it will bring us to the first entity in current sentence
        if skip>0:
            skip -= 1
            continue
        #remove entities that across sentences
        if len(sent_tokenize(text[start:end]))>1:
            continue
        word_start, word_end, sent_after, sent_piece = first_entity(text, start, end, entity)
        #'-'.join([str(i),str(j)]) is an unique idenfitier for each sentence in the dataset, 
        #i identify the document and j identify the sentence within the document
        tags_list.append([i, en_id, word_start, word_end, concept, entity, '-'.join([str(i),str(j)])])
        while j+skip+1<len(tags) and end+len(sent_after)>= tags[j+skip+1][1]:
            anno_curr = tags[j+skip+1]
            word_end_before = word_end
            end_before = end
            sent_piece_before = sent_piece
            en_id = anno_curr[0]
            start = anno_curr[1]
            end = anno_curr[2]
            concept = anno_curr[3]
            entity = anno_curr[4]
            word_start, word_end, sent_after, sent_piece = entity_within_sent(text, word_end_before, end_before, start, end, entity)
            sent_piece = ' '. join([sent_piece_before, sent_piece])
            tags_list.append([i, en_id, word_start, word_end, concept, entity, '-'.join([str(i),str(j)])])
            skip += 1
        sents_dict['-'.join([str(i),str(j)])] = sent_piece
# Out:
#   0%|          | 0/202 [00:00<?, ?it/s]

# %%
tags_list
# Out:
# [[0, 'T39', 20, 21, 'Drug', 'coumadin', '0-0'],
#  [0, 'T48', 31, 33, 'Reason', 'atrial fibrillation', '0-0'],
#  [0, 'T81', 11, 12, 'Drug', 'Contrast', '0-2'],
#  [0, 'T83', 6, 7, 'Route', 'intravenous', '0-3'],
#  [0, 'T82', 7, 8, 'Drug', 'contrast', '0-3'],
#  [0, 'T102', 4, 6, 'Reason', '>250 neutrophils', '0-5'],
#  [0, 'T49', 14, 16, 'Duration', 'five day', '0-5'],
#  [0, 'T10', 18, 19, 'Drug', 'ceftriaxone', '0-5'],
#  [0, 'T103', 6, 10, 'Reason', 'neutrophil count of 280', '0-8'],
#  [0, 'T50', 17, 19, 'Duration', 'five days', '0-8'],
#  [0, 'T84', 20, 21, 'Drug', 'antibiotics', '0-8'],
#  [0, 'T2', 22, 23, 'Drug', 'ciprofloxacin', '0-8'],
#  [0, 'T20', 28, 29, 'Drug', 'cefepime', '0-8'],
#  [0, 'T51', 30, 31, 'Drug', 'vanc', '0-8'],
#  [0, 'T104', 4, 8, 'Reason', 'slow accumulation of fluid', '0-14'],
#  [0, 'T14', 12, 13, 'Drug', 'octreotide', '0-14'],
#  [0, 'T86', 8, 9, 'Dosage', '4L', '0-16'],
#  [0, 'T85', 9, 10, 'Drug', 'O2', '0-16'],
#  [0, 'T87', 11, 13, 'Route', 'nasal cannula', '0-16'],
#  [0, 'T106', 27, 30, 'Reason', 'reduce chylous ascites', '0-19'],
#  [0, 'T105', 34, 35, 'Drug', 'octreotide', '0-19'],
#  [0, 'T89', 11, 12, 'Dosage', '4L', '0-21'],
#  [0, 'T88', 13, 14, 'Drug', 'oxygen', '0-21'],
#  [0, 'T90', 15, 17, 'Route', 'nasal cannula', '0-21'],
#  [0, 'T107', 1, 5, 'Reason', 'Health Care Associated Pneumonia', '0-24'],
#  [0, 'T52', 3, 5, 'Duration', '9 days', '0-25'],
#  [0, 'T1', 6, 7, 'Drug', 'cefepime', '0-25'],
#  [0, 'T8', 8, 9, 'Drug', 'vancomycin', '0-25'],
#  [0, 'T53', 1, 3, 'Reason', 'LLE DVT', '0-28'],
#  [0, 'T26', 8, 9, 'Drug', 'heparin', '0-28'],
#  [0, 'T54', 9, 10, 'Route', 'gtt', '0-28'],
#  [0, 'T46', 16, 17, 'Drug', 'coumadin', '0-28'],
#  [0, 'T19', 5, 6, 'Drug', 'heparin', '0-32'],
#  [0, 'T55', 6, 7, 'Route', 'gtt', '0-32'],
#  [0, 'T21', 28, 29, 'Drug', 'warfarin', '0-32'],
#  [0, 'T91', 30, 31, 'Reason', 'Anticoagulation', '0-35'],
#  [0,
#   'T47',
#   35,
#   39,
#   'Drug',
#   'unfractionated heparin (enoxaparin, warfarin)',
#   '0-35'],
#  [0, 'T56', 1, 2, 'Reason', 'Cellulitis', '0-37'],
#  [0, 'T13', 10, 11, 'Drug', 'penicillin', '0-37'],
#  [0, 'T92', 13, 15, 'Duration', 'few days', '0-37'],
#  [0, 'T40', 16, 17, 'Drug', 'cefazolin', '0-37'],
#  [0, 'T93', 22, 24, 'Reason', 'abdominal rash', '0-37'],
#  [0, 'T58', 3, 5, 'Duration', '10 days', '0-42'],
#  [0, 'T11', 6, 7, 'Drug', 'vancomycin', '0-42'],
#  [0, 'T57', 10, 11, 'Drug', 'steroid', '0-42'],
#  [0, 'T12', 11, 12, 'Form', 'cream', '0-42'],
#  [0, 'T94', 16, 18, 'Reason', 'abdominal rash', '0-42'],
#  [0, 'T108', 21, 23, 'Reason', 'contact dermatitis', '0-42'],
#  [0, 'T95', 13, 15, 'ADE', 'morbilliform eruption', '0-48'],
#  [0, 'T45', 26, 28, 'Drug', 'piperacillin -tazobactam', '0-48'],
#  [0, 'T96', 6, 7, 'ADE', 'rash', '0-50'],
#  [0, 'T59', 1, 3, 'Reason', 'Atrial fibrillation', '0-51'],
#  [0, 'T9', 3, 4, 'Drug', 'diltiazem', '0-52'],
#  [0, 'T97', 13, 15, 'Reason', 'rate control', '0-52'],
#  [0, 'T98', 4, 5, 'Drug', 'antibiotics', '0-54'],
#  [0, 'T7', 20, 21, 'Drug', 'morphine', '0-55'],
#  [0, 'T44', 4, 6, 'Drug', 'Pantoprazol e', '0-56'],
#  [0, 'T41', 6, 8, 'Strength', '40 mg', '0-56'],
#  [0, 'T60', 8, 12, 'Form', 'Tablet, Delayed Release (E.C.)', '0-56'],
#  [0, 'T61', 13, 15, 'Dosage', 'One (1)', '0-56'],
#  [0, 'T42', 15, 20, 'Form', 'Tablet , Delayed Release (E.C.)', '0-56'],
#  [0, 'T43', 20, 21, 'Route', 'PO', '0-56'],
#  [0, 'T62', 21, 25, 'Frequency', 'Q24H (every 24 hours)', '0-56'],
#  [0, 'T31', 1, 3, 'Drug', 'Diltiazem HCl', '0-63'],
#  [0, 'T32', 3, 5, 'Strength', '300 mg', '0-63'],
#  [0, 'T63', 5, 8, 'Form', 'Capsule, Sustained Release', '0-63'],
#  [0, 'T64', 9, 11, 'Dosage', 'One (1)', '0-63'],
#  [0, 'T33', 11, 15, 'Form', 'Capsule , Sustained Release', '0-63'],
#  [0, 'T34', 15, 16, 'Route', 'PO', '0-63'],
#  [0, 'T65', 16, 18, 'Frequency', 'DAILY (Daily)', '0-63'],
#  [0, 'T15', 1, 3, 'Drug', 'Metoprolol Tartrate', '0-70'],
#  [0, 'T16', 3, 5, 'Strength', '50 mg', '0-70'],
#  [0, 'T66', 5, 6, 'Form', 'Tablet', '0-70'],
#  [0, 'T67', 7, 9, 'Dosage', 'One (1)', '0-70'],
#  [0, 'T17', 9, 10, 'Form', 'Tablet', '0-70'],
#  [0, 'T18', 10, 11, 'Route', 'PO', '0-70'],
#  [0, 'T68', 11, 16, 'Frequency', 'BID (2 times a day)', '0-70'],
#  [0, 'T25', 1, 3, 'Drug', 'Lisinopri l', '0-77'],
#  [0, 'T22', 3, 5, 'Strength', '20 mg', '0-77'],
#  [0, 'T69', 5, 6, 'Form', 'Tablet', '0-77'],
#  [0, 'T70', 7, 9, 'Dosage', 'Two (2)', '0-77'],
#  [0, 'T23', 9, 10, 'Form', 'Tablet', '0-77'],
#  [0, 'T24', 10, 11, 'Route', 'PO', '0-77'],
#  [0, 'T71', 11, 13, 'Frequency', 'DAILY (Daily)', '0-77'],
#  [0, 'T30', 1, 3, 'Drug', 'Furosemid e', '0-84'],
#  [0, 'T27', 3, 5, 'Strength', '40 mg', '0-84'],
#  [0, 'T72', 5, 6, 'Form', 'Tablet', '0-84'],
#  [0, 'T73', 7, 9, 'Dosage', 'One (1)', '0-84'],
#  [0, 'T28', 9, 10, 'Form', 'Tablet', '0-84'],
#  [0, 'T29', 10, 11, 'Route', 'PO', '0-84'],
#  [0, 'T74', 11, 13, 'Frequency', 'DAILY (Daily)', '0-84'],
#  [0, 'T38', 1, 3, 'Drug', 'Simvastati n', '0-91'],
#  [0, 'T35', 3, 5, 'Strength', '10 mg', '0-91'],
#  [0, 'T75', 5, 6, 'Form', 'Tablet', '0-91'],
#  [0, 'T76', 7, 9, 'Dosage', 'Two (2)', '0-91'],
#  [0, 'T36', 9, 10, 'Form', 'Tablet', '0-91'],
#  [0, 'T37', 10, 11, 'Route', 'PO', '0-91'],
#  [0, 'T77', 11, 13, 'Frequency', 'DAILY (Daily)', '0-91'],
#  [0, 'T3', 1, 3, 'Drug', 'Docusate Sodium', '0-98'],
#  [0, 'T4', 3, 5, 'Strength', '100 mg', '0-98'],
#  [0, 'T78', 5, 6, 'Form', 'Capsule', '0-98'],
#  [0, 'T79', 7, 9, 'Dosage', 'One (1)', '0-98'],
#  [0, 'T5', 9, 10, 'Form', 'Capsule', '0-98'],
#  [0, 'T6', 10, 11, 'Route', 'PO', '0-98'],
#  [0, 'T80', 11, 16, 'Frequency', 'BID (2 times a day)', '0-98'],
#  [1, 'T2', 48, 49, 'Drug', 'epinephrine', '1-0'],
#  [1, 'T3', 49, 50, 'Form', 'injection', '1-0'],
#  [1, 'T50', 6, 7, 'Drug', 'Excedrin', '1-2'],
#  [1, 'T98', 1, 2, 'Reason', 'unresponsive', '1-3'],
#  [1, 'T99', 3, 7, 'Reason', "brady'd down to 30-40s", '1-3'],
#  [1, 'T20', 6, 7, 'Drug', 'epinephrine', '1-5'],
#  [1, 'T54', 8, 9, 'Drug', 'atropine', '1-5'],
#  [1, 'T103', 1, 2, 'Drug', 'Ca', '1-7'],
#  [1, 'T104', 3, 4, 'Drug', 'bicarb', '1-7'],
#  [1, 'T102', 5, 7, 'Dosage', '5 U', '1-7'],
#  [1, 'T101', 7, 8, 'Drug', 'PRBCs', '1-7'],
#  [1, 'T100', 9, 10, 'Dosage', '2L', '1-7'],
#  [1, 'T97', 10, 11, 'Drug', 'IVF', '1-7'],
#  [1, 'T106', 8, 10, 'ADE', 'gastric ulcer', '1-13'],
#  [1, 'T107', 11, 14, 'ADE', 'duodenal bulb ulcers', '1-13'],
#  [1, 'T105', 15, 16, 'Drug', 'NSAID', '1-13'],
#  [1, 'T108', 16, 17, 'ADE', 'toxicity', '1-13'],
#  [1, 'T32', 9, 10, 'Drug', 'Actonel', '1-17'],
#  [1, 'T109', 1, 4, 'ADE', 'Upper GI Bleed', '1-18'],
#  [1, 'T55', 5, 6, 'ADE', 'PUD', '1-18'],
#  [1, 'T56', 8, 9, 'Drug', 'NSAIDs', '1-18'],
#  [1, 'T57', 4, 5, 'Drug', 'PPI', '1-21'],
#  [1, 'T58', 7, 8, 'Route', 'IV', '1-21'],
#  [1, 'T59', 11, 12, 'Route', 'oral', '1-21'],
#  [1, 'T60', 1, 2, 'Drug', 'NSAIDS', '1-24'],
#  [1, 'T37', 3, 4, 'Drug', 'Actonel', '1-24'],
#  [1, 'T110', 17, 21, 'ADE', 'Gastrin level was elevated', '1-26'],
#  [1, 'T61', 26, 27, 'Drug', 'PPI', '1-26'],
#  [1, 'T62', 13, 14, 'Drug', 'NSAIDs', '1-28'],
#  [1, 'T12', 1, 2, 'Drug', 'Lipitor', '1-29'],
#  [1, 'T111', 3, 4, 'ADE', 'transaminitis', '1-29'],
#  [1, 'T16', 35, 36, 'Drug', 'aspirin', '1-31'],
#  [1, 'T31', 5, 6, 'Drug', 'vanco/unasyn', '1-32'],
#  [1, 'T1', 11, 12, 'Drug', 'levofloxacin', '1-32'],
#  [1, 'T63', 17, 18, 'Reason', 'pneumonia', '1-32'],
#  [1, 'T92', 4, 5, 'Form', 'nebulizer', '1-35'],
#  [1, 'T95', 11, 12, 'Drug', 'bronchodilators', '1-35'],
#  [1, 'T113', 2, 3, 'Reason', 'Pyschiatric', '1-37'],
#  [1, 'T49', 6, 7, 'Drug', 'Fluoxetine', '1-37'],
#  [1, 'T52', 8, 9, 'Drug', 'clonazepam', '1-37'],
#  [1, 'T21', 10, 11, 'Drug', 'Anafranil', '1-37'],
#  [1, 'T13', 3, 4, 'Drug', 'Fluoxetine', '1-41'],
#  [1, 'T14', 4, 6, 'Strength', '20 mg', '1-41'],
#  [1, 'T15', 6, 7, 'Route', 'po', '1-41'],
#  [1, 'T64', 7, 8, 'Frequency', 'QD', '1-41'],
#  [1, 'T38', 8, 9, 'Drug', 'Lipitor', '1-41'],
#  [1, 'T39', 9, 11, 'Strength', '20 mg', '1-41'],
#  [1, 'T40', 11, 12, 'Route', 'po', '1-41'],
#  [1, 'T65', 12, 13, 'Frequency', 'QD', '1-41'],
#  [1, 'T66', 13, 14, 'Drug', 'Klonipin', '1-41'],
#  [1, 'T67', 14, 16, 'Strength', '1 mg', '1-41'],
#  [1, 'T114', 16, 20, 'Frequency', 'up to tid prn', '1-41'],
#  [1, 'T17', 20, 21, 'Drug', 'Anafranil', '1-41'],
#  [1, 'T18', 21, 23, 'Strength', '250 mg', '1-41'],
#  [1, 'T19', 23, 24, 'Route', 'po', '1-41'],
#  [1, 'T68', 24, 25, 'Frequency', 'QD', '1-41'],
#  [1, 'T43', 25, 26, 'Drug', 'Actonel', '1-41'],
#  [1, 'T44', 26, 28, 'Strength', '5 mg', '1-41'],
#  [1, 'T45', 28, 29, 'Route', 'po', '1-41'],
#  [1, 'T69', 29, 30, 'Frequency', 'QD', '1-41'],
#  [1, 'T23', 33, 35, 'Drug', 'Fluoxetine HCl', '1-60'],
#  [1, 'T24', 35, 37, 'Strength', '20 mg', '1-60'],
#  [1, 'T70', 37, 38, 'Form', 'Capsule', '1-60'],
#  [1, 'T71', 39, 41, 'Dosage', 'One (1)', '1-60'],
#  [1, 'T25', 41, 42, 'Form', 'Capsule', '1-60'],
#  [1, 'T26', 42, 43, 'Route', 'PO', '1-60'],
#  [1, 'T72', 43, 45, 'Frequency', 'DAILY (Daily)', '1-60'],
#  [1, 'T27', 1, 2, 'Drug', 'Sucralfate', '1-67'],
#  [1, 'T28', 2, 4, 'Strength', '1 g', '1-67'],
#  [1, 'T73', 4, 5, 'Form', 'Tablet', '1-67'],
#  [1, 'T74', 6, 8, 'Dosage', 'One (1)', '1-67'],
#  [1, 'T29', 8, 9, 'Form', 'Tablet', '1-67'],
#  [1, 'T30', 9, 10, 'Route', 'PO', '1-67'],
#  [1, 'T75', 10, 15, 'Frequency', 'QID (4 times a day)', '1-67'],
#  [1, 'T8', 4, 5, 'Drug', 'Clonazepam', '1-74'],
#  [1, 'T9', 5, 7, 'Strength', '1 mg', '1-74'],
#  [1, 'T76', 7, 8, 'Form', 'Tablet', '1-74'],
#  [1, 'T77', 9, 11, 'Dosage', 'One (1)', '1-74'],
#  [1, 'T10', 11, 12, 'Form', 'Tablet', '1-74'],
#  [1, 'T11', 12, 13, 'Route', 'PO', '1-74'],
#  [1, 'T78', 13, 20, 'Frequency', 'TID (3 times a day) as needed', '1-74'],
#  [1, 'T53', 21, 22, 'Reason', 'anxiety', '1-74'],
#  [1, 'T33', 1, 3, 'Drug', 'Clomipramine HCl', '1-82'],
#  [1, 'T34', 3, 5, 'Strength', '50 mg', '1-82'],
#  [1, 'T79', 5, 6, 'Form', 'Capsule', '1-82'],
#  [1, 'T80', 7, 9, 'Dosage', 'Five (5)', '1-82'],
#  [1, 'T35', 9, 10, 'Form', 'Capsule', '1-82'],
#  [1, 'T36', 10, 11, 'Route', 'PO', '1-82'],
#  [1, 'T81', 11, 13, 'Frequency', 'DAILY (Daily)', '1-82'],
#  [1, 'T46', 1, 3, 'Drug', 'Pantoprazole Sodium', '1-89'],
#  [1, 'T47', 3, 5, 'Strength', '40 mg', '1-89'],
#  [1, 'T48', 5, 10, 'Form', 'Tablet , Delayed Release (E.C.)', '1-89'],
#  [1, 'T82', 11, 13, 'Dosage', 'One (1)', '1-89'],
#  [1, 'T83', 13, 17, 'Form', 'Tablet, Delayed Release (E.C.)', '1-89'],
#  [1, 'T84', 17, 18, 'Route', 'PO', '1-89'],
#  [1, 'T85', 18, 22, 'Frequency', 'Q12H (every 12 hours)', '1-89'],
#  [1, 'T41', 3, 5, 'Drug', 'Salmeterol Xinafoate', '1-96'],
#  [1, 'T42', 5, 8, 'Strength', '50 mcg /Dose', '1-96'],
#  [1, 'T86', 8, 11, 'Form', 'Disk with Device', '1-96'],
#  [1, 'T87', 12, 14, 'Dosage', 'One (1)', '1-96'],
#  [1, 'T88', 14, 16, 'Route', 'inhalation Inhalation', '1-96'],
#  [1, 'T51', 16, 20, 'Frequency', 'Q12H (every 12 hours)', '1-96'],
#  [1, 'T4', 4, 6, 'Drug', 'Albuterol- Ipratropium', '1-102'],
#  [1, 'T89', 6, 8, 'Strength', '103-18 mcg/Actuation', '1-102'],
#  [1, 'T5', 8, 9, 'Form', 'Aerosol', '1-102'],
#  [1, 'T115', 11, 12, 'Form', 'puffs', '1-102'],
#  [1, 'T90', 12, 13, 'Route', 'Inhalation', '1-102'],
#  [1, 'T6', 13, 17, 'Frequency', 'four times a day', '1-102'],
#  [1, 'T91', 3, 4, 'Drug', 'NSAIDs', '1-108'],
#  [1, 'T7', 5, 6, 'Drug', 'aspirin', '1-108'],
#  [1, 'T22', 7, 8, 'Drug', 'Excedrin', '1-108'],
#  [2, 'T23', 15, 16, 'Drug', 'Trileptal', '2-0'],
#  [2, 'T26', 17, 18, 'Drug', 'Hydrochlorothiazide', '2-0'],
#  [2, 'T36', 3, 4, 'Reason', 'seizures', '2-2'],
#  [2, 'T14', 10, 11, 'Drug', 'Trileptal', '2-2'],
#  [2, 'T1', 1, 2, 'Drug', 'trileptal', '2-4'],
#  [2, 'T20', 16, 17, 'Drug', 'keppra', '2-4'],
#  [2, 'T38', 1, 2, 'Reason', 'hypertension', '2-6'],
#  [2, 'T37', 6, 7, 'Drug', 'HCTz', '2-6'],
#  [2, 'T39', 3, 4, 'Reason', 'seizures', '2-8'],
#  [2, 'T21', 10, 11, 'Drug', 'Trileptal', '2-8'],
#  [2, 'T24', 1, 2, 'Drug', 'trileptal', '2-10'],
#  [2, 'T5', 16, 17, 'Drug', 'keppra', '2-10'],
#  [2, 'T40', 1, 2, 'Reason', 'hypertension', '2-12'],
#  [2, 'T41', 6, 7, 'Drug', 'HCTz', '2-12'],
#  [2, 'T71', 9, 10, 'Drug', 'Today', '2-14'],
#  [2, 'T65', 4, 5, 'Strength', '80cc/hr', '2-15'],
#  [2, 'T66', 6, 7, 'Drug', 'NS', '2-15'],
#  [2, 'T67', 11, 13, 'Dosage', '500 cc', '2-15'],
#  [2, 'T68', 5, 7, 'Drug', 'hypertonic saline', '2-18'],
#  [2, 'T69', 11, 14, 'Reason', 'increasing her Na', '2-18'],
#  [2, 'T42', 3, 4, 'Drug', 'NS', '2-20'],
#  [2, 'T43', 5, 7, 'Reason', 'volume repletion', '2-20'],
#  [2, 'T25', 1, 2, 'Drug', 'trileptal', '2-22'],
#  [2, 'T34', 13, 14, 'Drug', 'keppra', '2-22'],
#  [2, 'T35', 15, 17, 'Reason', 'antiseizure prophylaxis', '2-22'],
#  [2, 'T72', 2, 3, 'Drug', 'HCTZ', '2-25'],
#  [2, 'T6', 3, 4, 'Drug', 'keppra', '2-26'],
#  [2, 'T44', 4, 5, 'Drug', 'HCTZ', '2-26'],
#  [2, 'T45', 5, 6, 'Strength', '25mg', '2-26'],
#  [2, 'T46', 6, 7, 'Frequency', 'daily', '2-26'],
#  [2, 'T12', 7, 8, 'Drug', 'Atenolol', '2-26'],
#  [2, 'T13', 8, 10, 'Strength', '50 mg', '2-26'],
#  [2, 'T32', 12, 13, 'Drug', 'Zetia', '2-26'],
#  [2, 'T33', 13, 15, 'Strength', '10 mg', '2-26'],
#  [2, 'T47', 15, 16, 'Frequency', 'qd', '2-26'],
#  [2, 'T3', 16, 17, 'Drug', 'Nexium', '2-26'],
#  [2, 'T4', 17, 19, 'Strength', '40 mg', '2-26'],
#  [2, 'T48', 19, 20, 'Frequency', 'qd', '2-26'],
#  [2, 'T8', 20, 21, 'Drug', 'Aspirin', '2-26'],
#  [2, 'T9', 21, 22, 'Strength', '325mg', '2-26'],
#  [2, 'T49', 22, 23, 'Frequency', 'qd', '2-26'],
#  [2, 'T50', 26, 27, 'Drug', 'Aspirin', '2-41'],
#  [2, 'T22', 27, 29, 'Strength', '325 mg', '2-41'],
#  [2, 'T73', 29, 32, 'Form', 'Tablet, Delayed Release', '2-41'],
#  [2, 'T51', 1, 3, 'Dosage', 'One (1)', '2-44'],
#  [2, 'T52', 3, 7, 'Form', 'Tablet, Delayed Release (E.C.)', '2-44'],
#  [2, 'T53', 7, 8, 'Route', 'PO', '2-44'],
#  [2, 'T54', 8, 10, 'Frequency', 'DAILY (Daily)', '2-44'],
#  [2, 'T27', 1, 2, 'Drug', 'Levetiracetam', '2-48'],
#  [2, 'T28', 2, 4, 'Strength', '500 mg', '2-48'],
#  [2, 'T74', 4, 5, 'Form', 'Tablet', '2-48'],
#  [2, 'T55', 6, 8, 'Dosage', 'Two (2)', '2-48'],
#  [2, 'T29', 8, 9, 'Form', 'Tablet', '2-48'],
#  [2, 'T31', 9, 10, 'Route', 'PO', '2-48'],
#  [2, 'T30', 10, 15, 'Frequency', 'BID (2 times a day)', '2-48'],
#  [2, 'T15', 4, 5, 'Drug', 'Zetia', '2-55'],
#  [2, 'T16', 5, 7, 'Strength', '10 mg', '2-55'],
#  [2, 'T75', 7, 8, 'Form', 'Tablet', '2-55'],
#  [2, 'T56', 9, 11, 'Dosage', 'One (1)', '2-55'],
#  [2, 'T17', 11, 12, 'Form', 'Tablet', '2-55'],
#  [2, 'T19', 12, 13, 'Route', 'PO', '2-55'],
#  [2, 'T18', 13, 16, 'Frequency', 'once a day', '2-55'],
#  [2, 'T10', 1, 2, 'Drug', 'Nexium', '2-62'],
#  [2, 'T11', 2, 4, 'Strength', '40 mg', '2-62'],
#  [2, 'T57', 4, 8, 'Form', 'Capsule , Delayed Release(E.C.)', '2-62'],
#  [2, 'T58', 9, 11, 'Dosage', 'One (1)', '2-62'],
#  [2, 'T76', 11, 14, 'Form', 'Capsule, Delayed Release', '2-62'],
#  [2, 'T59', 6, 7, 'Route', 'PO', '2-67'],
#  [2, 'T60', 7, 10, 'Frequency', 'once a day', '2-67'],
#  [2, 'T62', 5, 6, 'ADE', 'Hyponatremia', '2-69'],
#  [2, 'T2', 8, 9, 'Drug', 'trileptal', '2-69'],
#  [2, 'T61', 10, 11, 'Drug', 'HCTZ', '2-69'],
#  [2, 'T70', 10, 14, 'ADE', 'Sodium level was low', '2-72'],
#  [2, 'T7', 7, 8, 'Drug', 'Trileptal', '2-73'],
#  [2, 'T63', 9, 10, 'Drug', 'Hydrochlorthiazide', '2-73'],
#  [3, 'T11', 2, 3, 'Drug', 'propranolol', '3-0'],
#  [3, 'T3', 4, 5, 'Drug', 'spironolactone', '3-0'],
#  [3, 'T9', 6, 7, 'Drug', 'Lasix', '3-0'],
#  [3, 'T1', 8, 9, 'Drug', 'Levoxyl', '3-0'],
#  [3, 'T17', 4, 5, 'ADE', 'HIT', '3-4'],
#  [3, 'T6', 1, 2, 'Drug', 'heparin', '3-5'],
#  [3, 'T7', 16, 17, 'Drug', 'Levophed', '3-6'],
#  [3, 'T14', 18, 21, 'Reason', 'blood pressure control', '3-6'],
#  [3, 'T25', 5, 6, 'Drug', 'fluid', '3-8'],
#  [3, 'T26', 6, 7, 'Reason', 'resuscitation', '3-8'],
#  [3, 'T27', 4, 5, 'Drug', 'TPN', '3-10'],
#  [3, 'T24', 6, 8, 'Reason', 'nutritional support', '3-10'],
#  [3, 'T29', 7, 8, 'Drug', 'albumin', '3-12'],
#  [3, 'T15', 14, 15, 'Route', 'V', '3-12'],
#  [3, 'T18', 15, 16, 'Drug', 'fluid', '3-12'],
#  [3, 'T20', 9, 10, 'Reason', 'Pseudomonas', '3-15'],
#  [3, 'T8', 19, 20, 'Drug', 'Zosyn', '3-15'],
#  [3, 'T4', 21, 22, 'Drug', 'meropenem', '3-15'],
#  [3, 'T21', 9, 10, 'Reason', 'anticoagulation', '3-18'],
#  [3, 'T5', 11, 12, 'Drug', 'argatroban', '3-18'],
#  [3, 'T10', 13, 14, 'Drug', 'lepirudin', '3-18'],
#  [3, 'T28', 14, 15, 'Drug', 'anticoagulation', '3-21'],
#  [3,
#   'T22',
#   9,
#   15,
#   'Reason',
#   'ventilator acquired pneumonia with the Pseudomonas',
#   '3-22'],
#  [3, 'T13', 23, 24, 'Drug', 'meropenem', '3-22'],
#  [3, 'T2', 5, 6, 'Drug', 'ciprofloxacin', '3-24'],
#  [3,
#   'T23',
#   6,
#   12,
#   'Reason',
#   'blood cultures which had gram-positive cocci',
#   '3-25'],
#  [3, 'T12', 5, 6, 'Drug', 'vancomycin', '3-26'],
#  [4, 'T27', 15, 18, 'Reason', 'metastatic breast cancer', '4-0'],
#  [4, 'T18', 29, 31, 'Drug', 'lapatinib monotherapy', '4-0'],
#  [4, 'T19', 31, 33, 'Strength', '1500 mg', '4-0'],
#  [4, 'T15', 11, 12, 'Drug', 'tamoxifen', '4-3'],
#  [4, 'T39', 2, 3, 'Reason', 'HER-2/neu', '4-4'],
#  [4, 'T20', 4, 5, 'Drug', 'Arimidex', '4-5'],
#  [4, 'T28', 5, 8, 'Duration', 'for six months', '4-5'],
#  [4, 'T9', 13, 14, 'Drug', 'Taxol', '4-5'],
#  [4, 'T17', 15, 16, 'Drug', 'Herceptin', '4-5'],
#  [4, 'T41', 5, 6, 'Dosage', 'high-dose', '4-9'],
#  [4, 'T40', 6, 7, 'Drug', 'chemo', '4-9'],
#  [4, 'T10', 8, 9, 'Drug', 'Herceptin', '4-9'],
#  [4, 'T29', 1, 2, 'Drug', 'chemo', '4-12'],
#  [4, 'T24', 3, 4, 'Drug', 'thiotepa', '4-12'],
#  [4, 'T7', 10, 11, 'Drug', 'Taxol', '4-12'],
#  [4, 'T4', 6, 7, 'Drug', 'letrozole', '4-15'],
#  [4, 'T23', 8, 9, 'Drug', 'Herceptin', '4-15'],
#  [4, 'T2', 14, 15, 'Drug', 'Aromasin', '4-15'],
#  [4, 'T3', 16, 17, 'Drug', 'Herceptin', '4-15'],
#  [4, 'T16', 11, 12, 'Drug', 'lapatinib', '4-19'],
#  [4, 'T5', 18, 19, 'Drug', 'herceptin', '4-19'],
#  [4, 'T44', 3, 5, 'Duration', '8 cycles', '4-21'],
#  [4, 'T6', 6, 7, 'Drug', 'lapatinib', '4-21'],
#  [4, 'T1', 5, 6, 'Drug', 'Lidocaine', '4-23'],
#  [4, 'T42', 5, 6, 'Drug', 'Contrast', '4-24'],
#  [4, 'T32', 18, 19, 'Reason', 'Anesthesia', '4-24'],
#  [4, 'T30', 20, 21, 'Strength', '1%', '4-24'],
#  [4, 'T8', 21, 22, 'Drug', 'Lidocaine', '4-24'],
#  [4, 'T31', 22, 23, 'Route', 'subq', '4-24'],
#  [4, 'T33', 1, 3, 'Reason', 'Breast cancer', '4-29'],
#  [4, 'T25', 6, 7, 'Drug', 'lapatinib', '4-30'],
#  [4, 'T21', 3, 4, 'Drug', 'Simvastatin', '4-31'],
#  [4, 'T22', 4, 6, 'Strength', '20 mg', '4-31'],
#  [4, 'T34', 6, 7, 'Frequency', 'QD', '4-31'],
#  [4, 'T11', 10, 11, 'Drug', 'Simvastatin', '4-34'],
#  [4, 'T12', 11, 13, 'Strength', '10 mg', '4-34'],
#  [4, 'T35', 13, 14, 'Form', 'Tablet', '4-34'],
#  [4, 'T37', 15, 17, 'Dosage', 'Two (2)', '4-34'],
#  [4, 'T13', 17, 18, 'Form', 'Tablet', '4-34'],
#  [4, 'T14', 18, 19, 'Route', 'PO', '4-34'],
#  [4, 'T36', 19, 21, 'Frequency', 'DAILY (Daily)', '4-34'],
#  [5, 'T129', 40, 41, 'Route', 'IV', '5-0'],
#  [5, 'T135', 42, 43, 'Drug', 'tPA', '5-0'],
#  [5, 'T133', 27, 28, 'Drug', 'tPA', '5-2'],
#  [5, 'T136', 8, 11, 'Reason', 'acute embolic stroke', '5-3'],
#  [5, 'T134', 27, 28, 'Route', 'IV', '5-4'],
#  [5, 'T138', 28, 29, 'Drug', 'tPA', '5-4'],
#  [5, 'T137', 8, 9, 'Route', 'IV', '5-6'],
#  [5, 'T140', 9, 10, 'Drug', 'tPA', '5-6'],
#  [5, 'T141', 9, 10, 'Drug', 'tPA', '5-8'],
#  [5, 'T142', 10, 11, 'Form', 'infusion', '5-8'],
#  [5, 'T143', 29, 30, 'Drug', 'tPA', '5-8'],
#  [5, 'T144', 5, 6, 'Drug', 'tPA', '5-11'],
#  [5,
#   'T145',
#   10,
#   21,
#   'ADE',
#   'hematomas of the right knee, left scalp, and left clavicular area',
#   '5-11'],
#  [5, 'T139', 23, 24, 'Route', 'IV', '5-11'],
#  [5, 'T147', 24, 25, 'Drug', 'TPA', '5-11'],
#  [5, 'T148', 4, 5, 'Drug', 'Aspirin', '5-15'],
#  [5, 'T149', 5, 6, 'Strength', '81mg', '5-15'],
#  [5, 'T150', 7, 8, 'Drug', 'Lovenox', '5-15'],
#  [5, 'T151', 8, 9, 'Strength', '40mg', '5-15'],
#  [5, 'T152', 9, 10, 'Frequency', 'daily', '5-15'],
#  [5, 'T153', 12, 13, 'Reason', 'MDS', '5-15'],
#  [5, 'T168', 14, 15, 'Reason', 'malignancy', '5-15'],
#  [5, 'T154', 1, 3, 'Reason', 'Blood pressure', '5-22'],
#  [5, 'T155', 5, 6, 'Drug', 'metoprolol', '5-22'],
#  [5, 'T156', 6, 7, 'Strength', '25mg', '5-22'],
#  [5, 'T157', 7, 8, 'Frequency', 'TID', '5-22'],
#  [5, 'T158', 9, 11, 'Frequency', 'as needed', '5-22'],
#  [5, 'T159', 11, 12, 'Drug', 'hydralazine', '5-22'],
#  [5, 'T160', 1, 2, 'Drug', 'metoprolol', '5-28'],
#  [5, 'T161', 5, 6, 'Strength', '50mg', '5-28'],
#  [5, 'T162', 6, 7, 'Frequency', 'TID', '5-28'],
#  [5, 'T163', 11, 12, 'ADE', 'methemoglobinemia', '5-31'],
#  [5, 'T1640', 12, 13, 'Reason', 'methemoglobinemia', '5-31'],
#  [5, 'T164', 17, 18, 'Drug', 'benzocaine', '5-31'],
#  [5, 'T165', 18, 19, 'Form', 'spray', '5-31'],
#  [5, 'T166', 2, 4, 'Drug', 'Methylene blue', '5-35'],
#  [5, 'T167', 4, 5, 'Strength', '140mg', '5-35'],
#  [5, 'T146', 5, 6, 'Route', 'IV', '5-35'],
#  [5, 'T169', 7, 8, 'ADE', 'bleeding', '5-38'],
#  [5, 'T170', 9, 10, 'Drug', 'tPA', '5-38'],
#  [5, 'T171', 13, 14, 'Drug', 'epo', '5-40'],
#  [5, 'T172', 15, 16, 'Drug', 'aranesp', '5-40'],
#  [5, 'T1', 2, 3, 'Drug', 'Famotidine', '5-42'],
#  [5, 'T2', 4, 6, 'Reason', 'GI prophylaxis', '5-42'],
#  [5, 'T3', 8, 10, 'Reason', 'alcohol withdrawal', '5-44'],
#  [5, 'T4', 11, 12, 'Drug', 'Ativan', '5-45'],
#  [5, 'T5', 15, 16, 'Drug', 'Valium', '5-45'],
#  [5, 'T6', 16, 17, 'Frequency', 'q12', '5-45'],
#  [5, 'T7', 3, 4, 'Drug', 'thiamine', '5-48'],
#  [5, 'T8', 5, 6, 'Drug', 'folate', '5-48'],
#  [5, 'T9', 2, 3, 'Drug', 'Trazadone', '5-50'],
#  [5, 'T10', 4, 5, 'Reason', 'sleep', '5-50'],
#  [5, 'T11', 17, 18, 'Reason', 'Pain', '5-52'],
#  [5, 'T12', 21, 22, 'Drug', 'tylenol', '5-52'],
#  [5, 'T13', 23, 24, 'Drug', 'oxycodone', '5-52'],
#  [5, 'T14', 4, 5, 'Drug', 'amlodipine', '5-55'],
#  [5, 'T15', 5, 6, 'Strength', '5mg', '5-55'],
#  [5, 'T16', 6, 7, 'Frequency', 'daily', '5-55'],
#  [5, 'T17', 8, 9, 'Drug', 'omeprazole', '5-55'],
#  [5, 'T18', 9, 10, 'Strength', '20mg', '5-55'],
#  [5, 'T19', 10, 11, 'Frequency', 'daily', '5-55'],
#  [5, 'T20', 12, 13, 'Drug', 'atenolol', '5-55'],
#  [5, 'T21', 13, 14, 'Strength', '50mg', '5-55'],
#  [5, 'T22', 14, 15, 'Frequency', 'daily', '5-55'],
#  [5, 'T23', 16, 17, 'Drug', 'levothyroxine', '5-55'],
#  [5, 'T24', 17, 18, 'Strength', '50mcg', '5-55'],
#  [5, 'T25', 18, 19, 'Frequency', 'daily', '5-55'],
#  [5, 'T26', 20, 22, 'Drug', 'vit B-12', '5-55'],
#  [5, 'T27', 22, 23, 'Strength', '1000mcg', '5-55'],
#  [5, 'T28', 23, 24, 'Frequency', 'daily', '5-55'],
#  [5, 'T29', 25, 27, 'Drug', 'vit B1', '5-55'],
#  [5, 'T30', 27, 28, 'Strength', '100mg', '5-55'],
#  [5, 'T31', 31, 33, 'Drug', 'folic acid', '5-55'],
#  [5, 'T32', 33, 34, 'Strength', '1mg', '5-55'],
#  [5, 'T33', 34, 35, 'Frequency', 'daily', '5-55'],
#  [5, 'T34', 38, 39, 'Drug', 'enoxaparin', '5-55'],
#  [5, 'T35', 39, 42, 'Strength', '40 mg/0.4 mL', '5-55'],
#  [5, 'T36', 42, 43, 'Form', 'Syringe', '5-55'],
#  [5, 'T37', 44, 47, 'Dosage', 'Forty (40) MG', '5-55'],
#  [5, 'T38', 47, 48, 'Route', 'Subcutaneous', '5-55'],
#  [5, 'T39', 48, 50, 'Frequency', 'DAILY (Daily)', '5-55'],
#  [5, 'T40', 1, 2, 'Drug', 'senna', '5-81'],
#  [5, 'T41', 2, 5, 'Strength', '8.8 mg/5 mL', '5-81'],
#  [5, 'T42', 5, 6, 'Form', 'Syrup', '5-81'],
#  [5, 'T43', 7, 10, 'Dosage', 'Five (5) ML', '5-81'],
#  [5, 'T44', 10, 11, 'Route', 'PO', '5-81'],
#  [5, 'T45', 11, 18, 'Frequency', 'BID (2 times a day) as needed', '5-81'],
#  [5, 'T46', 19, 20, 'Reason', 'constipation', '5-81'],
#  [5, 'T47', 1, 3, 'Drug', 'docusate sodium', '5-88'],
#  [5, 'T48', 3, 6, 'Strength', '50 mg/5 mL', '5-88'],
#  [5, 'T49', 6, 7, 'Form', 'Liquid', '5-88'],
#  [5, 'T50', 8, 11, 'Dosage', 'Ten (10) ML', '5-88'],
#  [5, 'T51', 11, 12, 'Route', 'PO', '5-88'],
#  [5, 'T52', 12, 17, 'Frequency', 'BID (2 times a day)', '5-88'],
#  [5, 'T53', 1, 2, 'Drug', 'bisacodyl', '5-94'],
#  [5, 'T54', 2, 4, 'Strength', '5 mg', '5-94'],
#  [5, 'T55', 4, 8, 'Form', 'Tablet, Delayed Release (E.C.)', '5-94'],
#  [5, 'T56', 9, 11, 'Dosage', 'Two (2)', '5-94'],
#  [5, 'T57', 11, 15, 'Form', 'Tablet, Delayed Release (E.C.)', '5-94'],
#  [5, 'T58', 15, 16, 'Route', 'PO', '5-94'],
#  [5, 'T59', 16, 20, 'Frequency', 'DAILY (Daily) as needed', '5-94'],
#  [5, 'T60', 21, 22, 'Reason', 'constipation', '5-94'],
#  [5, 'T61', 1, 2, 'Drug', 'aspirin', '5-102'],
#  [5, 'T62', 2, 4, 'Strength', '325 mg', '5-102'],
#  [5, 'T63', 4, 5, 'Form', 'Tablet', '5-102'],
#  [5, 'T64', 6, 8, 'Dosage', 'One (1)', '5-102'],
#  [5, 'T65', 8, 9, 'Form', 'Tablet', '5-102'],
#  [5, 'T66', 9, 10, 'Route', 'PO', '5-102'],
#  [5, 'T67', 10, 12, 'Frequency', 'DAILY (Daily)', '5-102'],
#  [5, 'T68', 1, 2, 'Drug', 'acetaminophen', '5-109'],
#  [5, 'T69', 2, 4, 'Strength', '325 mg', '5-109'],
#  [5, 'T70', 4, 5, 'Form', 'Tablet', '5-109'],
#  [5, 'T71', 6, 8, 'Dosage', 'Two (2)', '5-109'],
#  [5, 'T72', 8, 9, 'Form', 'Tablet', '5-109'],
#  [5, 'T73', 9, 10, 'Route', 'PO', '5-109'],
#  [5, 'T74', 10, 16, 'Frequency', 'Q4H (every 4 hours) as needed', '5-109'],
#  [5, 'T75', 17, 18, 'Reason', 'pain', '5-109'],
#  [5, 'T76', 1, 2, 'Drug', 'trazodone', '5-117'],
#  [5, 'T77', 2, 4, 'Strength', '50 mg', '5-117'],
#  [5, 'T78', 4, 5, 'Form', 'Tablet', '5-117'],
#  [5, 'T79', 6, 8, 'Dosage', 'One (1)', '5-117'],
#  [5, 'T80', 8, 9, 'Form', 'Tablet', '5-117'],
#  [5, 'T81', 9, 10, 'Route', 'PO', '5-117'],
#  [5, 'T82', 10, 15, 'Frequency', 'HS (at bedtime) as needed', '5-117'],
#  [5, 'T83', 16, 17, 'Reason', 'insomnia', '5-117'],
#  [5, 'T84', 1, 3, 'Drug', 'thiamine HCl', '5-125'],
#  [5, 'T85', 3, 5, 'Strength', '100 mg', '5-125'],
#  [5, 'T86', 5, 6, 'Form', 'Tablet', '5-125'],
#  [5, 'T87', 7, 9, 'Dosage', 'One (1)', '5-125'],
#  [5, 'T88', 9, 10, 'Form', 'Tablet', '5-125'],
#  [5, 'T89', 10, 11, 'Route', 'PO', '5-125'],
#  [5, 'T90', 11, 13, 'Frequency', 'DAILY (Daily)', '5-125'],
#  [5, 'T91', 1, 3, 'Drug', 'folic acid', '5-132'],
#  [5, 'T92', 3, 5, 'Strength', '1 mg', '5-132'],
#  [5, 'T93', 5, 6, 'Form', 'Tablet', '5-132'],
#  [5, 'T94', 7, 9, 'Dosage', 'One (1)', '5-132'],
#  [5, 'T95', 9, 10, 'Form', 'Tablet', '5-132'],
#  [5, 'T96', 10, 11, 'Route', 'PO', '5-132'],
#  [5, 'T97', 11, 13, 'Frequency', 'DAILY (Daily)', '5-132'],
#  [5, 'T98', 1, 2, 'Drug', 'multivitamin', '5-139'],
#  [5, 'T99', 2, 3, 'Form', 'Tablet', '5-139'],
#  [5, 'T100', 4, 6, 'Dosage', 'One (1)', '5-139'],
#  [5, 'T101', 6, 7, 'Form', 'Tablet', '5-139'],
#  [5, 'T102', 7, 8, 'Route', 'PO', '5-139'],
#  [5, 'T103', 8, 10, 'Frequency', 'DAILY (Daily)', '5-139'],
#  [5, 'T104', 1, 2, 'Drug', 'famotidine', '5-145'],
#  [5, 'T105', 2, 4, 'Strength', '20 mg', '5-145'],
#  [5, 'T106', 4, 5, 'Form', 'Tablet', '5-145'],
#  [5, 'T107', 6, 8, 'Dosage', 'One (1)', '5-145'],
#  [5, 'T108', 8, 9, 'Form', 'Tablet', '5-145'],
#  [5, 'T109', 9, 10, 'Route', 'PO', '5-145'],
#  [5, 'T110', 10, 15, 'Frequency', 'BID (2 times a day)', '5-145'],
#  [5, 'T111', 1, 3, 'Drug', 'metoprolol tartrate', '5-152'],
#  [5, 'T112', 3, 5, 'Strength', '50 mg', '5-152'],
#  [5, 'T113', 5, 6, 'Form', 'Tablet', '5-152'],
#  [5, 'T114', 7, 9, 'Dosage', 'One (1)', '5-152'],
#  [5, 'T115', 9, 10, 'Form', 'Tablet', '5-152'],
#  [5, 'T116', 10, 11, 'Route', 'PO', '5-152'],
#  [5, 'T117', 11, 16, 'Frequency', 'TID (3 times a day)', '5-152'],
#  [5, 'T118', 35, 36, 'ADE', 'methemoglobinemia', '5-159'],
#  [5, 'T119', 38, 39, 'Drug', 'benzocaine', '5-159'],
#  [5, 'T120', 39, 40, 'Form', 'spray', '5-159'],
#  [5, 'T121', 13, 14, 'Reason', 'stroke', '5-162'],
#  [5, 'T122', 3, 4, 'Drug', 'TPA', '5-163'],
#  [5, 'T123', 7, 14, 'Reason', 'break up the clot in your brain', '5-163'],
#  [5, 'T124', 25, 26, 'ADE', 'bruising', '5-163'],
#  [5, 'T125', 5, 6, 'Drug', 'Lovenox', '5-166'],
#  [5, 'T126', 8, 9, 'Drug', 'Aspirin', '5-166'],
#  [5, 'T127', 11, 16, 'Reason', 'prevent further clots and strokes', '5-166'],
#  [5, 'T128', 6, 9, 'Drug', 'blood pressure medication', '5-169'],
#  [5, 'T130', 6, 7, 'Drug', 'benzocaine', '5-170'],
#  [5, 'T131', 7, 8, 'Form', 'spray', '5-170'],
#  [5, 'T132', 10, 11, 'ADE', 'methemoglobinemia', '5-170'],
#  [6, 'T48', 15, 16, 'Drug', 'Hydromorphone', '6-0'],
#  [6, 'T14', 13, 14, 'Drug', 'Decadron', '6-1'],
#  [6, 'T37', 3, 4, 'Strength', '4mg', '6-2'],
#  [6, 'T39', 5, 6, 'Drug', 'Decadron', '6-2'],
#  [6, 'T40', 9, 11, 'Duration', 'few days', '6-2'],
#  [6, 'T49', 17, 19, 'Dosage', '6 cycles', '6-5'],
#  [6, 'T50', 24, 25, 'Drug', 'taxol', '6-5'],
#  [6, 'T51', 3, 4, 'Strength', '10mg', '6-7'],
#  [6, 'T52', 4, 5, 'Drug', 'decadron', '6-7'],
#  [6, 'T53', 6, 7, 'Route', 'IV', '6-7'],
#  [6, 'T54', 7, 8, 'Drug', 'hydration', '6-7'],
#  [6, 'T55', 9, 10, 'Drug', 'Decadron', '6-7'],
#  [6, 'T56', 10, 11, 'Strength', '4mg', '6-7'],
#  [6, 'T57', 11, 12, 'Frequency', 'Q6h', '6-7'],
#  [6, 'T58', 4, 5, 'Drug', 'Reglan', '6-14'],
#  [6, 'T59', 5, 6, 'Frequency', 'PRN', '6-14'],
#  [6, 'T60', 7, 8, 'Drug', 'Compazine', '6-14'],
#  [6, 'T61', 8, 9, 'Frequency', 'PRN', '6-14'],
#  [6, 'T62', 10, 11, 'Drug', 'Zofran', '6-14'],
#  [6, 'T63', 11, 12, 'Frequency', 'PRN', '6-14'],
#  [6, 'T64', 13, 14, 'Reason', 'nausea', '6-14'],
#  [6, 'T65', 2, 3, 'Drug', 'Dexamethasone', '6-21'],
#  [6, 'T66', 5, 6, 'Drug', 'Bactrim', '6-22'],
#  [6, 'T67', 7, 8, 'Reason', 'PCP', '6-22'],
#  [6, 'T68', 9, 11, 'Reason', 'pain control', '6-24'],
#  [6, 'T69', 13, 14, 'Drug', 'Motrin', '6-24'],
#  [6, 'T70', 15, 16, 'Drug', 'Oxycodone', '6-24'],
#  [6, 'T71', 16, 17, 'Frequency', 'PRN', '6-24'],
#  [6, 'T72', 1, 2, 'Reason', 'Depression', '6-28'],
#  [6, 'T73', 3, 4, 'Reason', 'Insomnia', '6-28'],
#  [6, 'T74', 10, 11, 'Drug', 'Citalopram', '6-28'],
#  [6, 'T75', 12, 13, 'Drug', 'Ativan', '6-28'],
#  [6, 'T76', 13, 15, 'Frequency', 'qhs PRN', '6-28'],
#  [6, 'T77', 1, 2, 'Reason', 'HTN/HL', '6-33'],
#  [6, 'T78', 8, 9, 'Drug', 'HCTZ', '6-33'],
#  [6, 'T79', 10, 11, 'Drug', 'Lisinopril', '6-33'],
#  [6, 'T80', 12, 13, 'Drug', 'Verapamil', '6-33'],
#  [6, 'T81', 8, 9, 'Drug', 'HCTZ', '6-37'],
#  [6, 'T82', 13, 14, 'ADE', 'hyponatremia', '6-37'],
#  [6, 'T83', 5, 6, 'Drug', 'Simvastatin', '6-39'],
#  [6, 'T84', 10, 12, 'Reason', 'Pain control', '6-40'],
#  [6, 'T85', 14, 15, 'Drug', 'Motrin', '6-40'],
#  [6, 'T86', 16, 17, 'Drug', 'Oxycodone', '6-40'],
#  [6, 'T87', 17, 18, 'Frequency', 'PRN', '6-40'],
#  [6, 'T88', 8, 9, 'Drug', 'PPI', '6-44'],
#  [6, 'T89', 3, 5, 'Reason', 'DVT PPx', '6-45'],
#  [6, 'T90', 6, 7, 'Route', 'SC', '6-45'],
#  [6, 'T91', 7, 8, 'Drug', 'Heparin', '6-45'],
#  [6, 'T92', 3, 4, 'Drug', 'DEXAMETHASONE', '6-48'],
#  [6, 'T93', 12, 14, 'Strength', '1 mg', '6-48'],
#  [6, 'T94', 14, 15, 'Form', 'Tablet', '6-48'],
#  [6, 'T95', 16, 17, 'Dosage', '2', '6-48'],
#  [6, 'T96', 17, 18, 'Form', 'Tablet', '6-48'],
#  [6, 'T97', 19, 21, 'Route', 'by mouth', '6-48'],
#  [6, 'T98', 21, 24, 'Frequency', 'twice a day', '6-48'],
#  [6, 'T99', 28, 30, 'Strength', '2 mg', '6-48'],
#  [6, 'T100', 35, 37, 'Strength', '2 mg', '6-48'],
#  [6, 'T101', 37, 38, 'Frequency', 'QAM', '6-48'],
#  [6, 'T102', 39, 41, 'Strength', '1 mg', '6-48'],
#  [6, 'T103', 41, 42, 'Frequency', 'QPM', '6-48'],
#  [6, 'T105', 47, 49, 'Frequency', 'once daily', '6-48'],
#  [6, 'T104', 52, 54, 'Strength', '1 mg', '6-48'],
#  [6, 'T157', 55, 56, 'Frequency', 'daily', '6-48'],
#  [6, 'T106', 2, 3, 'Drug', 'Decadron', '6-63'],
#  [6, 'T107', 8, 9, 'Drug', 'HYDROCHLOROTHIAZIDE', '6-64'],
#  [6, 'T108', 15, 17, 'Strength', '12.5 mg', '6-64'],
#  [6, 'T109', 17, 18, 'Form', 'Capsule', '6-64'],
#  [6, 'T110', 19, 20, 'Dosage', '2', '6-64'],
#  [6, 'T111', 20, 21, 'Form', 'Capsule(s)', '6-64'],
#  [6, 'T112', 21, 23, 'Route', 'by mouth', '6-64'],
#  [6, 'T113', 23, 24, 'Frequency', 'DAILY', '6-64'],
#  [6, 'T114', 25, 26, 'Drug', 'IBUPROFEN', '6-64'],
#  [6, 'T115', 34, 36, 'Strength', '600 mg', '6-64'],
#  [6, 'T116', 36, 37, 'Form', 'Tablet', '6-64'],
#  [6, 'T117', 38, 39, 'Dosage', '1', '6-64'],
#  [6, 'T118', 39, 40, 'Form', 'Tablet(s)', '6-64'],
#  [6, 'T119', 40, 42, 'Route', 'by mouth', '6-64'],
#  [6, 'T120', 42, 48, 'Frequency', 'three times a day as needed', '6-64'],
#  [6, 'T121', 49, 50, 'Reason', 'pain', '6-64'],
#  [6, 'T122', 50, 51, 'Drug', 'LISINOPRIL', '6-64'],
#  [6, 'T123', 57, 59, 'Strength', '5 mg', '6-64'],
#  [6, 'T124', 59, 60, 'Form', 'Tablet', '6-64'],
#  [6, 'T125', 61, 62, 'Dosage', '1', '6-64'],
#  [6, 'T126', 62, 63, 'Form', 'Tablet(s)', '6-64'],
#  [6, 'T127', 63, 65, 'Route', 'by mouth', '6-64'],
#  [6, 'T128', 65, 66, 'Frequency', 'DAILY', '6-64'],
#  [6, 'T129', 67, 68, 'Drug', 'LORAZEPAM', '6-64'],
#  [6, 'T130', 69, 71, 'Strength', '0.5 mg', '6-64'],
#  [6, 'T131', 71, 72, 'Form', 'Tablet', '6-64'],
#  [6, 'T132', 73, 74, 'Dosage', '1', '6-64'],
#  [6, 'T133', 74, 75, 'Form', 'Tablet', '6-64'],
#  [6, 'T134', 76, 78, 'Route', 'by mouth', '6-64'],
#  [6, 'T135', 78, 83, 'Frequency', 'at bedtime and as needed', '6-64'],
#  [6, 'T136', 83, 84, 'Drug', 'METOCLOPRAMIDE', '6-64'],
#  [6, 'T137', 85, 87, 'Strength', '10 mg', '6-64'],
#  [6, 'T138', 87, 88, 'Form', 'Tablet', '6-64'],
#  [6, 'T139', 89, 90, 'Dosage', '1', '6-64'],
#  [6, 'T140', 90, 91, 'Form', 'Tablet', '6-64'],
#  [6, 'T141', 92, 94, 'Route', 'by mouth', '6-64'],
#  [6, 'T142', 94, 99, 'Frequency', 'every 6 hours as needed', '6-64'],
#  [6, 'T143', 100, 101, 'Reason', 'nausea', '6-64'],
#  [6, 'T144', 102, 104, 'Reason', 'abdominal bloating', '6-64'],
#  [6, 'T145', 105, 108, 'Frequency', '30min before meals', '6-64'],
#  [6, 'T146', 108, 109, 'Drug', 'OMEPRAZOLE', '6-64'],
#  [6, 'T147', 110, 112, 'Strength', '40 mg', '6-64'],
#  [6, 'T148', 112, 115, 'Form', 'Capsule, Delayed Release', '6-64'],
#  [6, 'T149', 1, 2, 'Dosage', '1', '6-106'],
#  [6, 'T150', 2, 3, 'Form', 'Capsule', '6-106'],
#  [6, 'T151', 4, 6, 'Route', 'by mouth', '6-106'],
#  [6, 'T152', 6, 8, 'Frequency', 'DAILY (Daily)', '6-106'],
#  [6, 'T153', 8, 10, 'Drug', 'ONDANSETRON HCL', '6-106'],
#  [6, 'T154', 11, 13, 'Strength', '8 mg', '6-106'],
#  [6, 'T155', 13, 14, 'Form', 'Tablet', '6-106'],
#  [6, 'T156', 15, 16, 'Dosage', '1', '6-106'],
#  [6, 'T158', 16, 17, 'Form', 'Tablet(s)', '6-106'],
#  [6, 'T159', 17, 19, 'Route', 'by mouth', '6-106'],
#  [6, 'T160', 19, 22, 'Frequency', 'q8hr as needed', '6-106'],
#  [6, 'T161', 23, 24, 'Reason', 'nausea', '6-106'],
#  [6, 'T162', 25, 26, 'Reason', 'vomiting', '6-106'],
#  [6, 'T163', 26, 27, 'Drug', 'OXYCODONE', '6-106'],
#  [6, 'T164', 28, 30, 'Strength', '5 mg', '6-106'],
#  [6, 'T165', 30, 31, 'Form', 'Tablet', '6-106'],
#  [6, 'T166', 33, 34, 'Form', 'Tablet', '6-106'],
#  [6, 'T167', 35, 37, 'Route', 'by mouth', '6-106'],
#  [6, 'T168', 37, 40, 'Frequency', 'q4hr as needed', '6-106'],
#  [6, 'T169', 41, 42, 'Reason', 'pain', '6-106'],
#  [6, 'T170', 42, 44, 'Drug', 'PROCHLORPERAZINE MALEATE', '6-106'],
#  [6, 'T171', 45, 47, 'Strength', '10 mg', '6-106'],
#  [6, 'T172', 47, 48, 'Form', 'Tablet', '6-106'],
#  [6, 'T173', 49, 50, 'Dosage', '1/2-1', '6-106'],
#  [6, 'T174', 50, 51, 'Form', 'Tablet', '6-106'],
#  [6, 'T175', 52, 54, 'Route', 'by mouth', '6-106'],
#  [6, 'T176', 54, 57, 'Frequency', 'q6hr as needed', '6-106'],
#  [6, 'T177', 58, 59, 'Reason', 'nausea', '6-106'],
#  [6, 'T178', 60, 61, 'Reason', 'vomiting', '6-106'],
#  [6, 'T179', 68, 69, 'Drug', 'SIMVASTATIN', '6-106'],
#  [6, 'T180', 75, 77, 'Strength', '10 mg', '6-106'],
#  [6, 'T181', 77, 78, 'Form', 'Tablet', '6-106'],
#  [6, 'T182', 79, 80, 'Dosage', '2', '6-106'],
#  [6, 'T183', 80, 81, 'Form', 'Tablet(s)', '6-106'],
#  [6, 'T184', 81, 83, 'Route', 'by mouth', '6-106'],
#  [6, 'T185', 83, 84, 'Frequency', 'DAILY', '6-106'],
#  [6, 'T186', 85, 86, 'Drug', 'VERAPAMIL', '6-106'],
#  [6, 'T187', 92, 94, 'Strength', '240 mg', '6-106'],
#  [6, 'T188', 94, 97, 'Form', 'Tablet Sustained Release', '6-106'],
#  [6, 'T189', 98, 99, 'Dosage', '1', '6-106'],
#  [6, 'T190', 99, 100, 'Form', 'Tablet', '6-106'],
#  [6, 'T191', 101, 103, 'Route', 'by mouth', '6-106'],
#  [6, 'T192', 103, 106, 'Frequency', 'every twenty-four(24) hours', '6-106'],
#  [6, 'T193', 109, 110, 'Drug', 'citalopram', '6-106'],
#  [6, 'T194', 110, 112, 'Strength', '40 mg', '6-106'],
#  [6, 'T195', 112, 113, 'Form', 'Tablet', '6-106'],
#  [6, 'T196', 114, 116, 'Dosage', 'One (1)', '6-106'],
#  [6, 'T197', 116, 117, 'Form', 'Tablet', '6-106'],
#  [6, 'T198', 117, 118, 'Route', 'PO', '6-106'],
#  [6, 'T199', 118, 121, 'Frequency', 'once a day', '6-106'],
#  [6, 'T200', 1, 2, 'Drug', 'lisinopril', '6-156'],
#  [6, 'T201', 2, 4, 'Strength', '5 mg', '6-156'],
#  [6, 'T202', 4, 5, 'Form', 'Tablet', '6-156'],
#  [6, 'T203', 6, 8, 'Dosage', 'One (1)', '6-156'],
#  [6, 'T204', 8, 9, 'Form', 'Tablet', '6-156'],
#  [6, 'T205', 9, 10, 'Route', 'PO', '6-156'],
#  [6, 'T206', 10, 12, 'Frequency', 'DAILY (Daily)', '6-156'],
#  [6, 'T207', 1, 2, 'Drug', 'verapamil', '6-163'],
#  [6, 'T208', 2, 4, 'Strength', '120 mg', '6-163'],
#  [6, 'T209', 4, 7, 'Form', 'Tablet Sustained Release', '6-163'],
#  [6, 'T210', 8, 10, 'Dosage', 'Two (2)', '6-163'],
#  [6, 'T211', 10, 13, 'Form', 'Tablet Sustained Release', '6-163'],
#  [6, 'T212', 13, 14, 'Route', 'PO', '6-163'],
#  [6, 'T213', 14, 18, 'Frequency', 'Q24H (every 24 hours)', '6-163'],
#  [6, 'T214', 1, 2, 'Drug', 'oxycodone', '6-170'],
#  [6, 'T215', 2, 4, 'Strength', '5 mg', '6-170'],
#  [6, 'T216', 4, 5, 'Form', 'Tablet', '6-170'],
#  [6, 'T217', 6, 8, 'Dosage', 'One (1)', '6-170'],
#  [6, 'T218', 8, 9, 'Form', 'Tablet', '6-170'],
#  [6, 'T219', 9, 10, 'Route', 'PO', '6-170'],
#  [6, 'T220', 10, 16, 'Frequency', 'Q4H (every 4 hours) as needed', '6-170'],
#  [6, 'T221', 17, 18, 'Reason', 'pain', '6-170'],
#  [6, 'T222', 1, 2, 'Drug', 'docusate', '6-178'],
#  [6, 'T223', 5, 7, 'Strength', '100 mg', '6-178'],
#  [6, 'T224', 7, 8, 'Form', 'Capsule', '6-178'],
#  [6, 'T225', 9, 11, 'Dosage', 'One (1)', '6-178'],
#  [6, 'T226', 11, 12, 'Form', 'Capsule', '6-178'],
#  [6, 'T227', 12, 13, 'Route', 'PO', '6-178'],
#  [6, 'T228', 13, 14, 'Frequency', 'BID', '6-178'],
#  [6, 'T229', 4, 5, 'Drug', 'senna', '6-185'],
#  [6, 'T230', 5, 7, 'Strength', '8.6 mg', '6-185'],
#  [6, 'T231', 7, 8, 'Form', 'Tablet', '6-185'],
#  [6, 'T232', 9, 11, 'Dosage', 'One (1)', '6-185'],
#  [6, 'T233', 11, 12, 'Form', 'Tablet', '6-185'],
#  [6, 'T234', 12, 13, 'Route', 'PO', '6-185'],
#  [6, 'T235', 13, 20, 'Frequency', 'BID (2 times a day) as needed', '6-185'],
#  [6, 'T236', 21, 22, 'Reason', 'constipation', '6-185'],
#  [6, 'T237', 4, 6, 'Drug', 'ondansetron HCl', '6-193'],
#  [6, 'T238', 6, 8, 'Strength', '8 mg', '6-193'],
#  [6, 'T239', 8, 9, 'Form', 'Tablet', '6-193'],
#  [6, 'T240', 10, 12, 'Dosage', 'One (1)', '6-193'],
#  [6, 'T241', 12, 13, 'Form', 'Tablet', '6-193'],
#  [6, 'T242', 13, 14, 'Route', 'PO', '6-193'],
#  [6, 'T243', 14, 20, 'Frequency', 'three times a day as needed', '6-193'],
#  [6, 'T244', 21, 22, 'Reason', 'nausea', '6-193'],
#  [6, 'T245', 1, 2, 'Drug', 'prochlorperazine', '6-201'],
#  [6, 'T246', 3, 5, 'Strength', '5 mg', '6-201'],
#  [6, 'T247', 5, 6, 'Form', 'Tablet', '6-201'],
#  [6, 'T248', 7, 8, 'Dosage', '1-2', '6-201'],
#  [6, 'T249', 8, 9, 'Form', 'Tablets', '6-201'],
#  [6, 'T250', 9, 10, 'Route', 'PO', '6-201'],
#  [6, 'T251', 10, 16, 'Frequency', 'four times a day as needed', '6-201'],
#  [6, 'T252', 17, 18, 'Reason', 'nausea', '6-201'],
#  [6, 'T253', 1, 2, 'Drug', 'simvastatin', '6-209'],
#  [6, 'T254', 2, 4, 'Strength', '20 mg', '6-209'],
#  [6, 'T255', 4, 5, 'Form', 'Tablet', '6-209'],
#  [6, 'T256', 6, 8, 'Dosage', 'One (1)', '6-209'],
#  [6, 'T257', 8, 9, 'Form', 'Tablet', '6-209'],
#  [6, 'T258', 9, 10, 'Route', 'PO', '6-209'],
#  [6, 'T259', 10, 13, 'Frequency', 'once a day', '6-209'],
#  [6, 'T260', 1, 2, 'Drug', 'lorazepam', '6-216'],
#  [6, 'T261', 2, 4, 'Strength', '0.5 mg', '6-216'],
#  [6, 'T262', 4, 5, 'Form', 'Tablet', '6-216'],
#  [6, 'T263', 6, 8, 'Dosage', 'One (1)', '6-216'],
#  [6, 'T264', 8, 9, 'Form', 'Tablet', '6-216'],
#  [6, 'T265', 9, 10, 'Route', 'PO', '6-216'],
#  [6, 'T266', 10, 14, 'Frequency', 'at bedtime as needed', '6-216'],
#  [6, 'T267', 15, 16, 'Reason', 'insomnia', '6-216'],
#  [6, 'T268', 1, 2, 'Drug', 'metoclopramide', '6-224'],
#  [6, 'T269', 2, 4, 'Strength', '10 mg', '6-224'],
#  [6, 'T270', 4, 5, 'Form', 'Tablet', '6-224'],
#  [6, 'T271', 6, 8, 'Dosage', 'One (1)', '6-224'],
#  [6, 'T272', 8, 9, 'Form', 'Tablet', '6-224'],
#  [6, 'T273', 9, 10, 'Route', 'PO', '6-224'],
#  [6, 'T274', 10, 16, 'Frequency', 'every six (6) hours as needed', '6-224'],
#  [6, 'T275', 17, 18, 'Reason', 'nausea', '6-224'],
#  [6, 'T276', 1, 2, 'Drug', 'omeprazole', '6-232'],
#  [6, 'T277', 2, 4, 'Strength', '40 mg', '6-232'],
#  [6, 'T278', 4, 7, 'Form', 'Capsule, Delayed Release', '6-232'],
#  [6, 'T279', 1, 3, 'Dosage', 'One (1)', '6-235'],
#  [6, 'T280', 3, 6, 'Form', 'Capsule, Delayed Release', '6-235'],
#  [6, 'T281', 6, 7, 'Route', 'PO', '6-237'],
#  [6, 'T282', 7, 10, 'Frequency', 'once a day', '6-237'],
#  [6, 'T283', 1, 2, 'Drug', 'hydrochlorothiazide', '6-239'],
#  [6, 'T284', 2, 4, 'Strength', '12.5 mg', '6-239'],
#  [6, 'T285', 4, 5, 'Form', 'Capsule', '6-239'],
#  [6, 'T286', 6, 8, 'Dosage', 'One (1)', '6-239'],
#  [6, 'T287', 8, 9, 'Form', 'Capsule', '6-239'],
#  [6, 'T288', 9, 10, 'Route', 'PO', '6-239'],
#  [6, 'T289', 10, 11, 'Frequency', 'DAILY', '6-239'],
#  [6, 'T290', 3, 4, 'Drug', 'chloride', '6-246'],
#  [6, 'T291', 4, 6, 'Strength', '1 gram', '6-246'],
#  [6, 'T292', 6, 7, 'Form', 'Tablet', '6-246'],
#  [6, 'T293', 8, 10, 'Dosage', 'Two (2)', '6-246'],
#  [6, 'T294', 10, 11, 'Form', 'Tablet', '6-246'],
#  [6, 'T295', 11, 12, 'Route', 'PO', '6-246'],
#  [6, 'T296', 12, 13, 'Frequency', 'TID', '6-246'],
#  [6, 'T297', 4, 5, 'Drug', 'dexamethasone', '6-253'],
#  [6, 'T298', 5, 7, 'Strength', '2 mg', '6-253'],
#  [6, 'T299', 7, 8, 'Form', 'Tablet', '6-253'],
#  [6, 'T300', 9, 11, 'Dosage', 'Three (3)', '6-253'],
#  [6, 'T301', 11, 12, 'Form', 'Tablet', '6-253'],
#  [6, 'T302', 12, 13, 'Route', 'PO', '6-253'],
#  [6, 'T303', 13, 14, 'Frequency', 'Q12H', '6-253'],
#  [6, 'T304', 17, 20, 'Duration', 'for 3 days', '6-253'],
#  [6, 'T305', 4, 5, 'Drug', 'dexamethasone', '6-261'],
#  [6, 'T306', 5, 7, 'Strength', '2 mg', '6-261'],
#  [6, 'T307', 7, 8, 'Form', 'Tablet', '6-261'],
#  [6, 'T308', 9, 11, 'Dosage', 'Two (2)', '6-261'],
#  [6, 'T309', 11, 12, 'Form', 'Tablet', '6-261'],
#  [6, 'T310', 12, 13, 'Route', 'PO', '6-261'],
#  [6, 'T311', 13, 16, 'Frequency', 'twice a day', '6-261'],
#  [6, 'T312', 16, 19, 'Duration', 'for 3 days', '6-261'],
#  [6, 'T313', 4, 5, 'Drug', 'dexamethasone', '6-269'],
#  [6, 'T314', 5, 7, 'Strength', '2 mg', '6-269'],
#  [6, 'T315', 7, 8, 'Form', 'Tablet', '6-269'],
#  [6, 'T316', 9, 11, 'Dosage', 'Three (3)', '6-269'],
#  [6, 'T317', 11, 12, 'Form', 'Tablet', '6-269'],
#  [6, 'T318', 12, 13, 'Route', 'PO', '6-269'],
#  [6, 'T319', 13, 14, 'Frequency', 'QAM', '6-269'],
#  [6, 'T320', 4, 5, 'Drug', 'oxycodone', '6-276'],
#  [6, 'T321', 5, 7, 'Strength', '5 mg', '6-276'],
#  [6, 'T322', 7, 8, 'Form', 'Tablet', '6-276'],
#  [6, 'T323', 9, 10, 'Dosage', '1-2', '6-276'],
#  [6, 'T324', 10, 11, 'Form', 'Tablets', '6-276'],
#  [6, 'T325', 11, 12, 'Route', 'PO', '6-276'],
#  [6, 'T326', 12, 17, 'Frequency', 'every 4-6 hours as needed', '6-276'],
#  [6, 'T327', 18, 19, 'Reason', 'pain', '6-276'],
#  [6, 'T328', 4, 6, 'Drug', 'Bactrim DS', '6-284'],
#  [6, 'T329', 6, 8, 'Strength', '800-160 mg', '6-284'],
#  [6, 'T330', 8, 9, 'Form', 'Tablet', '6-284'],
#  [6, 'T331', 10, 12, 'Dosage', 'One (1)', '6-284'],
#  [6, 'T332', 12, 13, 'Form', 'Tablet', '6-284'],
#  [6, 'T333', 13, 14, 'Route', 'PO', '6-284'],
#  [6, 'T334', 14, 15, 'Frequency', 'MWF', '6-284'],
#  [6, 'T1', 12, 13, 'Drug', 'chloride', '6-291'],
#  [6, 'T2', 13, 14, 'Strength', '1mg', '6-291'],
#  [6, 'T3', 15, 16, 'Dosage', '2', '6-291'],
#  [6, 'T4', 16, 17, 'Form', 'tablets', '6-291'],
#  [6, 'T5', 18, 21, 'Frequency', 'three times daily', '6-291'],
#  [6, 'T6', 35, 36, 'Drug', 'Oxycodone', '6-291'],
#  [6, 'T7', 36, 37, 'Strength', '5mg', '6-291'],
#  [6, 'T8', 37, 38, 'Dosage', '1-2', '6-291'],
#  [6, 'T9', 38, 39, 'Form', 'tablets', '6-291'],
#  [6, 'T10', 39, 44, 'Frequency', 'every four hours as needed', '6-291'],
#  [6, 'T11', 45, 46, 'Reason', 'pain', '6-291'],
#  [6, 'T12', 50, 51, 'ADE', 'sedation', '6-291'],
#  [6, 'T13', 1, 3, 'Drug', 'Bactrim DS', '6-303'],
#  [6, 'T15', 4, 5, 'Route', 'Oral', '6-303'],
#  [6, 'T16', 6, 8, 'Strength', '800-160 mg', '6-303'],
#  [6, 'T17', 8, 9, 'Form', 'Tablet', '6-303'],
#  [6, 'T18', 10, 11, 'Dosage', '1', '6-303'],
#  [6, 'T19', 11, 12, 'Form', 'tablet', '6-303'],
#  [6, 'T20', 13, 17, 'Frequency', 'Monday, Wednesday and Friday', '6-303'],
#  [6, 'T21', 39, 40, 'Drug', 'steroids', '6-303'],
#  [6, 'T22', 50, 51, 'Drug', 'Dexamethasone', '6-303'],
#  [6, 'T23', 59, 60, 'Drug', 'Dexamethasone', '6-303'],
#  [6, 'T24', 60, 61, 'Strength', '6mg', '6-303'],
#  [6, 'T25', 61, 63, 'Route', 'by mouth', '6-303'],
#  [6, 'T26', 63, 65, 'Frequency', 'twice daily', '6-303'],
#  [6, 'T27', 65, 68, 'Duration', 'for 3 days', '6-303'],
#  [6, 'T28', 71, 72, 'Strength', '4mg', '6-303'],
#  [6, 'T29', 72, 74, 'Frequency', 'twice daily', '6-303'],
#  [6, 'T30', 74, 77, 'Duration', 'for 3 days', '6-303'],
#  [6, 'T31', 80, 81, 'Strength', '6mg', '6-303'],
#  [6, 'T32', 81, 85, 'Frequency', 'daily in the morning', '6-303'],
#  [6, 'T33', 18, 19, 'Drug', 'dexamethasone', '6-322'],
#  [6, 'T34', 9, 10, 'Drug', 'hydrochlorathiazide', '6-323'],
#  [6, 'T35', 10, 11, 'Strength', '25mg', '6-323'],
#  [6, 'T36', 11, 12, 'Frequency', 'daily', '6-323'],
#  [6, 'T38', 1, 2, 'Drug', 'HCTZ', '6-326'],
#  [6, 'T41', 6, 7, 'Drug', 'fiber', '6-327'],
#  [6, 'T42', 9, 12, 'Drug', 'narcotic pain medicine', '6-327'],
#  [6, 'T43', 14, 15, 'ADE', 'constipation', '6-327'],
#  [6, 'T44', 8, 10, 'Drug', 'stool softener', '6-330'],
#  [6, 'T45', 13, 14, 'Drug', 'Docusate', '6-330'],
#  [6, 'T46', 15, 16, 'Drug', 'Colace', '6-330'],
#  [6, 'T47', 19, 22, 'Drug', 'narcotic pain medication', '6-330'],
#  [7, 'T36', 15, 16, 'Drug', 'Vicodin', '7-0'],
#  [7, 'T52', 17, 18, 'Drug', 'Roxicet', '7-0'],
#  [7, 'T62', 19, 20, 'Drug', 'Sirolimus', '7-0'],
#  [7, 'T141', 13, 15, 'Reason', 'clonic seizure', '7-3'],
#  [7, 'T26', 20, 21, 'Drug', 'Ativan', '7-4'],
#  [7, 'T27', 21, 22, 'Strength', '2mg', '7-4'],
#  [7, 'T28', 22, 23, 'Route', 'IV', '7-4'],
#  [7, 'T142', 37, 38, 'ADE', 'DM', '7-7'],
#  [7, 'T143', 38, 39, 'Reason', 'DM', '7-7'],
#  [7, 'T113', 40, 41, 'Drug', 'insulin', '7-7'],
#  [7, 'T282', 45, 46, 'Drug', 'steroid', '7-7'],
#  [7, 'T284', 21, 22, 'ADE', 'myopathy', '7-11'],
#  [7, 'T283', 23, 24, 'Drug', 'steroid', '7-12'],
#  [7, 'T144', 8, 9, 'Drug', 'benzodiazepines', '7-13'],
#  [7, 'T145', 4, 5, 'Drug', 'phenytoin', '7-14'],
#  [7, 'T94', 6, 7, 'Drug', 'oxcarbazepine', '7-14'],
#  [7, 'T63', 8, 9, 'Drug', 'Trileptal', '7-14'],
#  [7, 'T29', 17, 18, 'Drug', 'phenytoin', '7-14'],
#  [7, 'T105', 28, 29, 'Drug', 'keppra', '7-14'],
#  [7, 'T66', 4, 5, 'Drug', 'fentanyl', '7-19'],
#  [7, 'T124', 6, 7, 'Drug', 'midazolam', '7-19'],
#  [7, 'T185', 8, 11, 'Reason', 'monitored conscious sedation', '7-19'],
#  [7, 'T147', 3, 4, 'Reason', 'NSTEMI', '7-22'],
#  [7, 'T138', 4, 5, 'Drug', 'aspirin', '7-23'],
#  [7, 'T146', 6, 8, 'Drug', 'beta blocker', '7-23'],
#  [7, 'T21', 9, 10, 'Drug', 'atorvastatin', '7-23'],
#  [7, 'T149', 3, 6, 'Reason', 'Acute Renal Failure', '7-26'],
#  [7, 'T65', 3, 4, 'Route', 'IV', '7-27'],
#  [7, 'T148', 4, 5, 'Drug', 'hydration', '7-27'],
#  [7, 'T85', 4, 5, 'Drug', 'Thiamine', '7-29'],
#  [7, 'T18', 6, 7, 'Drug', 'Folate', '7-29'],
#  [7, 'T150', 8, 9, 'Drug', 'MVI', '7-29'],
#  [7, 'T281', 1, 3, 'Reason', 'Liver transplantation', '7-32'],
#  [7, 'T280', 12, 14, 'Drug', 'immunosuppressive agents', '7-33'],
#  [7, 'T140', 6, 7, 'Reason', 'prophylaxis', '7-34'],
#  [7, 'T64', 12, 13, 'Drug', 'Heparin', '7-34'],
#  [7, 'T50', 3, 4, 'Drug', 'Prograf', '7-36'],
#  [7, 'T51', 4, 5, 'Strength', '1mg', '7-36'],
#  [7, 'T83', 7, 8, 'Drug', 'Imuran', '7-36'],
#  [7, 'T84', 8, 9, 'Strength', '50mg', '7-36'],
#  [7, 'T122', 11, 12, 'Drug', 'Cellcept', '7-36'],
#  [7, 'T286', 13, 15, 'Drug', 'mycophenidate mofetil', '7-36'],
#  [7, 'T123', 16, 17, 'Strength', '1000mg', '7-36'],
#  [7, 'T88', 19, 20, 'Drug', 'bactrim', '7-36'],
#  [7, 'T42', 20, 21, 'Drug', 'metoprolol', '7-36'],
#  [7, 'T43', 21, 22, 'Strength', '50mg', '7-36'],
#  [7, 'T82', 24, 25, 'Drug', 'Clindagel', '7-36'],
#  [7, 'T151', 25, 26, 'Drug', 'asa', '7-36'],
#  [7, 'T152', 26, 27, 'Strength', '81mg', '7-36'],
#  [7, 'T153', 27, 28, 'Frequency', 'daily', '7-36'],
#  [7, 'T7', 28, 29, 'Drug', 'fosamax', '7-36'],
#  [7, 'T8', 29, 30, 'Strength', '35mg', '7-36'],
#  [7, 'T154', 30, 32, 'Frequency', 'q fri', '7-36'],
#  [7, 'T135', 32, 33, 'Drug', 'marinol', '7-36'],
#  [7, 'T136', 33, 34, 'Strength', '5mg', '7-36'],
#  [7, 'T155', 34, 37, 'Frequency', 'qpm and qhs', '7-36'],
#  [7, 'T12', 37, 38, 'Drug', 'simethicone', '7-36'],
#  [7, 'T13', 38, 39, 'Strength', '80mg', '7-36'],
#  [7, 'T156', 41, 45, 'Drug', 'calcum 500mg + D', '7-36'],
#  [7, 'T89', 47, 48, 'Drug', 'Ambien', '7-36'],
#  [7, 'T97', 49, 50, 'Drug', 'zolpidem', '7-36'],
#  [7, 'T98', 51, 52, 'Strength', '5mg', '7-36'],
#  [7, 'T157', 52, 53, 'Frequency', 'qhs', '7-36'],
#  [7, 'T19', 53, 54, 'Drug', 'doxazosin', '7-36'],
#  [7, 'T20', 54, 55, 'Strength', '1.5mg', '7-36'],
#  [7, 'T158', 55, 56, 'Frequency', 'qhs', '7-36'],
#  [7, 'T1', 56, 58, 'Drug', 'hydroxyzine hcl', '7-36'],
#  [7, 'T2', 58, 59, 'Strength', '50mg', '7-36'],
#  [7, 'T129', 61, 62, 'Drug', 'ritalin', '7-36'],
#  [7, 'T130', 62, 63, 'Strength', '15mg', '7-36'],
#  [7, 'T159', 63, 64, 'Frequency', 'qam', '7-36'],
#  [7, 'T55', 64, 65, 'Drug', 'remeron', '7-36'],
#  [7, 'T160', 65, 66, 'Strength', '7.5', '7-36'],
#  [7, 'T161', 66, 67, 'Frequency', 'qhs', '7-36'],
#  [7, 'T71', 67, 68, 'Drug', 'prilosec', '7-36'],
#  [7, 'T72', 68, 69, 'Strength', '20mg', '7-36'],
#  [7, 'T162', 69, 70, 'Frequency', 'daily', '7-36'],
#  [7, 'T99', 70, 71, 'Drug', 'Effexor', '7-36'],
#  [7, 'T100', 71, 72, 'Strength', '37.5mg', '7-36'],
#  [7, 'T163', 72, 73, 'Frequency', 'daily', '7-36'],
#  [7, 'T131', 73, 74, 'Drug', 'Florinef', '7-36'],
#  [7, 'T132', 74, 75, 'Strength', '0.1mg', '7-36'],
#  [7, 'T164', 75, 76, 'Frequency', 'daily', '7-36'],
#  [7, 'T10', 76, 77, 'Drug', 'Lasix', '7-36'],
#  [7, 'T11', 77, 78, 'Strength', '20mg', '7-36'],
#  [7, 'T165', 78, 79, 'Frequency', 'daily', '7-36'],
#  [7, 'T167', 79, 80, 'Drug', 'Kayexylate', '7-36'],
#  [7, 'T34', 80, 81, 'Drug', 'Lipitor', '7-36'],
#  [7, 'T35', 81, 82, 'Strength', '10mg', '7-36'],
#  [7, 'T166', 82, 83, 'Frequency', 'daily', '7-36'],
#  [7, 'T53', 83, 84, 'Drug', 'Lisinopril', '7-36'],
#  [7, 'T54', 84, 85, 'Strength', '5mg', '7-36'],
#  [7, 'T168', 85, 86, 'Frequency', 'daily', '7-36'],
#  [7, 'T78', 86, 87, 'Drug', 'Percocet', '7-36'],
#  [7, 'T80', 87, 88, 'Dosage', 'one', '7-36'],
#  [7, 'T79', 88, 89, 'Form', 'tab', '7-36'],
#  [7, 'T81', 89, 91, 'Frequency', 'qid prn', '7-36'],
#  [7, 'T106', 91, 92, 'Drug', 'Cosopt', '7-36'],
#  [7, 'T108', 92, 93, 'Dosage', 'one', '7-36'],
#  [7, 'T107', 93, 94, 'Form', 'drop', '7-36'],
#  [7, 'T169', 95, 97, 'Route', 'left eye', '7-36'],
#  [7, 'T170', 99, 100, 'Drug', 'Alphagan', '7-36'],
#  [7, 'T175', 100, 101, 'Strength', '0.15%', '7-36'],
#  [7, 'T176', 102, 104, 'Route', 'left eye', '7-36'],
#  [7, 'T171', 106, 107, 'Drug', 'Ofloxacin', '7-36'],
#  [7, 'T174', 107, 108, 'Strength', '0.3%', '7-36'],
#  [7, 'T287', 108, 109, 'Route', 'eye', '7-36'],
#  [7, 'T139', 109, 110, 'Form', 'drop', '7-36'],
#  [7, 'T178', 111, 113, 'Route', 'left eye', '7-36'],
#  [7, 'T179', 113, 114, 'Frequency', 'qid', '7-36'],
#  [7, 'T172', 114, 115, 'Drug', 'Prednisolone', '7-36'],
#  [7, 'T180', 115, 116, 'Strength', '1%', '7-36'],
#  [7, 'T288', 116, 117, 'Route', 'eye', '7-36'],
#  [7, 'T177', 117, 118, 'Form', 'drop', '7-36'],
#  [7, 'T182', 119, 121, 'Route', 'left eye', '7-36'],
#  [7, 'T183', 121, 122, 'Frequency', 'qid', '7-36'],
#  [7, 'T173', 122, 123, 'Drug', 'Homatropine', '7-36'],
#  [7, 'T184', 123, 124, 'Strength', '5%', '7-36'],
#  [7, 'T289', 124, 125, 'Route', 'eye', '7-36'],
#  [7, 'T181', 125, 126, 'Form', 'drop', '7-36'],
#  [7, 'T186', 127, 129, 'Route', 'left eye', '7-36'],
#  [7, 'T58', 130, 131, 'Drug', 'Aspirin', '7-121'],
#  [7, 'T59', 131, 133, 'Strength', '325 mg', '7-121'],
#  [7, 'T187', 133, 134, 'Form', 'Tablet', '7-121'],
#  [7, 'T189', 135, 137, 'Dosage', 'One (1)', '7-121'],
#  [7, 'T60', 137, 138, 'Form', 'Tablet', '7-121'],
#  [7, 'T61', 138, 139, 'Route', 'PO', '7-121'],
#  [7, 'T188', 139, 141, 'Frequency', 'DAILY (Daily)', '7-121'],
#  [7, 'T30', 1, 2, 'Drug', 'Bisacodyl', '7-128'],
#  [7, 'T31', 2, 4, 'Strength', '5 mg', '7-128'],
#  [7, 'T32', 4, 9, 'Form', 'Tablet , Delayed Release (E.C.)', '7-128'],
#  [7, 'T190', 10, 12, 'Dosage', 'Two (2)', '7-128'],
#  [7, 'T191', 12, 16, 'Form', 'Tablet, Delayed Release (E.C.)', '7-128'],
#  [7, 'T192', 16, 17, 'Route', 'PO', '7-128'],
#  ...]

# %%
(sents_dict)
# Out:
# {'0-0': 'The patient has long been awaiting repair of a large inguinal hernia and ventral hernia and had stopped taking his coumadin 10 days prior to presentation (he is on this for atrial fibrillation',
#  '0-2': 'Otherwise, tracing is within normal limits CT Abdomen and Pelvis W/O Contrast',
#  '0-3': 'These findings are incompletely characterized without intravenous contrast',
#  '0-5': 'This paracentesis also revealed >250 neutrophils so the patient was empirically started on a five day course of ceftriaxone',
#  '0-8': 'The second of these revealed a neutrophil count of 280 so led to a second course of five days of antibiotics with ciprofloxacin (as the patient was on cefepime / vanc',
#  '0-14': 'Attempts were made to slow accumulation of fluid with medical therapies including octreotide',
#  '0-16': "He was desatting to the low 90's on 4L O2 by nasal cannula",
#  '0-19': 'Over the ensuing days the patient continued to put out greater than one liter of chylous fluid per 24 hour period despite the various interventions meant to reduce chylous ascites mentioned (low fat diets, octreotide',
#  '0-21': 'After the second thoracentesis the patient remained dependent on at least 4L of oxygen by nasal cannula',
#  '0-24': '4) Health Care Associated Pneumonia',
#  '0-25': 'Therefore, he received 9 days of cefepime / vancomycin',
#  '0-28': '5) LLE DVT : He was initially on heparin gtt then transitioned to be therapeutic on coumadin',
#  '0-32': 'He was transferred back to heparin gtt once on the medical service and continued on this throughout his course there to make procedures feasible without needing a long warfarin',
#  '0-35': 'He was transferred back to heparin gtt once on the medical service and continued on this throughout his course there to make procedures feasible without needing a long warfarin wash-out. Anticoagulation with medications other than unfractionated heparin (enoxaparin, warfarin)',
#  '0-37': '6) Cellulitis : The patient initially received a dose of penicillin then a few days of cefazolin with minimal improvement in his abdominal rash',
#  '0-42': 'He then received 10 days of vancomycin as well as steroid cream after dermatology thought the abdominal rash could be a contact dermatitis',
#  '0-48': '7) Likely drug rash: Later in his hospitalization (around [**11-19**]-15th) he developed a morbilliform eruption on his trunk in the context of receiving a dose of piperacillin -tazobactam',
#  '0-50': 'This medication was stopped an his rash',
#  '0-51': '10) Atrial fibrillation',
#  '0-52': 'This broke with diltiazem and he was restarted on this medication with good rate control',
#  '0-54': 'Reasonably benign interventions (i.e. antibiotics',
#  '0-55': 'When his respiratory status deteriorated on [**11-30**] (as above), further diagnostics and interventions were not pursued, and he was given morphine',
#  '0-56': 'Medications on Admission: 1. Pantoprazol e 40 mg Tablet, Delayed Release (E.C.) Sig: One (1) Tablet , Delayed Release (E.C.) PO Q24H (every 24 hours)',
#  '0-63': '2. Diltiazem HCl 300 mg Capsule, Sustained Release Sig: One (1) Capsule , Sustained Release PO DAILY (Daily)',
#  '0-70': '3. Metoprolol Tartrate 50 mg Tablet Sig: One (1) Tablet PO BID (2 times a day)',
#  '0-77': '4. Lisinopri l 20 mg Tablet Sig: Two (2) Tablet PO DAILY (Daily)',
#  '0-84': '5. Furosemid e 40 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '0-91': '6. Simvastati n 10 mg Tablet Sig: Two (2) Tablet PO DAILY (Daily)',
#  '0-98': '7. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)',
#  '1-0': 'Admission Date: [**2114-2-3**] Discharge Date: [**2114-2-10**] Date of Birth: [**2059-9-16**] Sex: F Service: MEDICINE Allergies: Patient recorded as having No Known Allergies to Drugs Attending:[**First Name3 (LF) 898**] Chief Complaint: Admitted to MICU for GIB, originally c/o dizziness and dark stool Major Surgical or Invasive Procedure: EGD with epinephrine injection',
#  '1-2': 'She reports taking "a lot" of Excedrin',
#  '1-3': "became unresponsive and brady'd down to 30-40s",
#  '1-5': 'The patient was then intubated, given epinephrine and atropine',
#  '1-7': 'Given Ca , bicarb , 5 U PRBCs and 2L IVF',
#  '1-13': 'GI came to do emergent EGD and found gastric ulcer and duodenal bulb ulcers c/w NSAID toxicity',
#  '1-17': 'Past Medical History: Anemia OCD Depression GERD (but thought Actonel',
#  '1-18': '1. Upper GI Bleed : PUD likely [**3-7**] NSAIDs',
#  '1-21': 'Pt was continued on PPI , initially IV and transitioned to oral',
#  '1-24': 'All NSAIDS and Actonel',
#  '1-26': 'All NSAIDS and Actonel were held, with a recommendation to continue to avoid these medications after discharge. Gastrin level was elevated , but believed secondary to PPI',
#  '1-28': "Finally, concern regarding the level of insight underlying the patient's large doses of NSAIDs",
#  '1-29': 'Held Lipitor given transaminitis',
#  '1-31': '4) Bradycardia: possibly due to massive GI Bleed, or elev K and acidosis, resolved in ICU 5) Metabolic acidosis: -likely lactic acidosis from hypotention and hypovolemic shock, although lactate mildly elevated (but checked after resucitation), aspirin',
#  '1-32': '[**Name10 (NameIs) **] was on vanco/unasyn in the ICU, narrowed to levofloxacin as she had suggestion of pneumonia',
#  '1-35': 'The patient improved with nebulizer treatments, and will be discharged on bronchodilators',
#  '1-37': '8) Neuro/ Pyschiatric : Patient on Fluoxetine , clonazepam and Anafranil',
#  '1-41': 'Medications on Admission: Fluoxetine 20 mg po QD Lipitor 20 mg po QD Klonipin 1 mg up to tid prn Anafranil 250 mg po QD Actonel 5 mg po QD',
#  '1-60': 'Medications on Admission: Fluoxetine 20 mg po QD Lipitor 20 mg po QD Klonipin 1 mg up to tid prn Anafranil 250 mg po QD Actonel 5 mg po QD Discharge Medications: 1. Fluoxetine HCl 20 mg Capsule Sig: One (1) Capsule PO DAILY (Daily)',
#  '1-67': '2. Sucralfate 1 g Tablet Sig: One (1) Tablet PO QID (4 times a day)',
#  '1-74': 'Disp:*120 Tablet(s)* Refills:*2* 3. Clonazepam 1 mg Tablet Sig: One (1) Tablet PO TID (3 times a day) as needed for anxiety',
#  '1-82': '4. Clomipramine HCl 50 mg Capsule Sig: Five (5) Capsule PO DAILY (Daily)',
#  '1-89': '5. Pantoprazole Sodium 40 mg Tablet , Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q12H (every 12 hours)',
#  '1-96': ')(s)* Refills:*2* 6. Salmeterol Xinafoate 50 mcg /Dose Disk with Device Sig: One (1) inhalation Inhalation Q12H (every 12 hours)',
#  '1-102': 'Disp:*60 inhalation* Refills:*2* 7. Albuterol- Ipratropium 103-18 mcg/Actuation Aerosol Sig: [**2-4**] puffs Inhalation four times a day',
#  '1-108': '* Avoid all NSAIDs , aspirin , Excedrin',
#  '2-0': 'Admission Date: [**2141-10-24**] Discharge Date: [**2141-10-26**] Date of Birth: [**2070-7-11**] Sex: F Service: MEDICINE Allergies: Trileptal / Hydrochlorothiazide',
#  '2-2': 'Because of her seizures , she was recently started on Trileptal',
#  '2-4': 'Her trileptal was tapered and she received her last dose on [**2141-10-23**] and she was started keppra',
#  '2-6': 'For hypertension , she was started HCTz',
#  '2-8': 'Because of her seizures , she was recently started on Trileptal',
#  '2-10': 'Her trileptal was tapered and she received her last dose on [**2141-10-23**] and she was started keppra',
#  '2-12': 'For hypertension , she was started HCTz',
#  '2-14': 'For hypertension, she was started HCTz 5 days ago. Today',
#  '2-15': 'In the ED: - 80cc/hr of NS for a total of 500 cc',
#  '2-18': 'Hence she was treated with hypertonic saline with a goal of increasing her Na',
#  '2-20': 'She also received NS for volume repletion',
#  '2-22': 'Her trileptal was tapered off by the Neurology sevice and transitioned over to keppra for antiseizure prophylaxis',
#  '2-25': 'Also, her HCTZ',
#  '2-26': 'Medications on Admission: keppra HCTZ 25mg daily Atenolol 50 mg [**Hospital1 **] Zetia 10 mg qd Nexium 40 mg qd Aspirin 325mg qd',
#  '2-41': 'Medications on Admission: keppra HCTZ 25mg daily Atenolol 50 mg [**Hospital1 **] Zetia 10 mg qd Nexium 40 mg qd Aspirin 325mg qd Discharge Medications: 1. Aspirin 325 mg Tablet, Delayed Release',
#  '2-44': 'Sig: One (1) Tablet, Delayed Release (E.C.) PO DAILY (Daily)',
#  '2-48': '2. Levetiracetam 500 mg Tablet Sig: Two (2) Tablet PO BID (2 times a day)',
#  '2-55': 'Disp:*60 Tablet(s)* Refills:*2* 3. Zetia 10 mg Tablet Sig: One (1) Tablet PO once a day',
#  '2-62': '4. Nexium 40 mg Capsule , Delayed Release(E.C.) Sig: One (1) Capsule, Delayed Release',
#  '2-67': 'Sig: One (1) Capsule, Delayed Release(E.C.) PO once a day',
#  '2-69': 'Discharge Disposition: Home Discharge Diagnosis: Hyponatremia due to trileptal / HCTZ',
#  '2-72': 'Discharge Instructions: You were admitted to the hospital because your Sodium level was low',
#  '2-73': 'This was most likely related to taking Trileptal and Hydrochlorthiazide',
#  '3-0': 'MEDICATIONS: Included propranolol , spironolactone , Lasix and Levoxyl',
#  '3-4': 'Because of this, a HIT',
#  '3-5': 'Her heparin',
#  '3-6': 'Postoperatively, from the second washout she was continued on ventilatory management, and she was kept on Levophed for blood pressure control',
#  '3-8': 'She continued to require significant fluid resuscitation',
#  '3-10': 'She was started on TPN for nutritional support',
#  '3-12': 'She was continued to be replaced with albumin , as well as with I V fluid',
#  '3-15': 'Pancultures were done, and she was found to have Pseudomonas in her lungs and; therefore, she was changed from Zosyn to meropenem',
#  '3-18': 'She was attempted on multiple occasions to be given anticoagulation using argatroban and lepirudin',
#  '3-21': 'However, her creatinine clearance and primary liver function abnormalities did not allow for adequate anticoagulation',
#  '3-22': 'Again, she began having high fevers, and she had ventilator acquired pneumonia with the Pseudomonas , and this had now become resistant to meropenem',
#  '3-24': 'Therefore, she was changed to ciprofloxacin',
#  '3-25': 'At the same time, she had blood cultures which had gram-positive cocci',
#  '3-26': 'She was started empirically on vancomycin',
#  '4-0': 'History of Present Illness: The patient is a 52-year old female with a history of metastatic breast cancer , s/p lt. mastectomy now enrolled in clinical trial "05-395" ( lapatinib monotherapy 1500 mg',
#  '4-3': 'She is status post left mastectomy with reconstruction, CAF followed by tamoxifen',
#  '4-4': 'Biopsy documented HER-2/neu',
#  '4-5': 'She was treated with Arimidex for six months , which was followed by Taxol and Herceptin',
#  '4-9': 'She was then treated with high-dose chemo and Herceptin',
#  '4-12': 'This chemo included thiotepa , [**Doctor Last Name **], and Taxol',
#  '4-15': 'In [**9-/2173**], she was treated with letrozole and Herceptin and was then switched to Aromasin and Herceptin',
#  '4-19': 'Upon progression [**Male First Name (un) **] was switched to the lapatinib phase II trial in [**7-28**], and herceptin',
#  '4-21': 'She has received 8 cycles of lapatinib',
#  '4-23': 'TECHNICAL FACTORS: Total time ( Lidocaine',
#  '4-24': 'Fluoro time = 2.3 minutes. Contrast injected: Non-ionic low osmolar (isovue, optiray...), vol 20 ml, Indications - Renal Anesthesia : 1% Lidocaine subq',
#  '4-29': '3. Breast cancer',
#  '4-30': 'The patient is now off the lapatinib',
#  '4-31': 'Medications on Admission: Simvastatin 20 mg QD',
#  '4-34': 'Medications on Admission: Simvastatin 20 mg QD Discharge Medications: 1. Simvastatin 10 mg Tablet Sig: Two (2) Tablet PO DAILY (Daily)',
#  '5-0': 'Admission Date: [**2135-1-21**] Discharge Date: [**2135-1-31**] Date of Birth: [**2085-2-3**] Sex: F Service: NEUROLOGY Allergies: Hurricaine Attending:[**Last Name (NamePattern1) 1838**] Chief Complaint: Called by Emergency Department as a Code Stroke for Left-sided weakness and aphasia Major Surgical or Invasive Procedure: IV - tPA',
#  '5-2': 'She was initially taken to OSH, where she had a CT head that was negative for hemorrhage; it was there determined that she was "out of the tPA',
#  '5-3': 'Her history, exam and imaging are consistent with acute embolic stroke',
#  '5-4': 'The time of onset was taken to be 0130; the time of her thrashing, and so when she was seen here, she remained within the window for IV tPA',
#  '5-6': 'The decision was made to proceed with the IV tPA',
#  '5-8': 'The plan at this time is to proceed with tPA infusion and if clinical exam remains unchanged in 30 minutes, then plan is to proceed with angio for IA tPA',
#  '5-11': 'There was no improvement with tPA , and she developed hematomas of the right knee, left scalp, and left clavicular area , so IV TPA',
#  '5-15': 'She was started on Aspirin 81mg and Lovenox 40mg daily (given possible MDS / malignancy',
#  '5-22': 'CVR: Blood pressure was controlled metoprolol 25mg TID and as needed hydralazine',
#  '5-28': 'Her metoprolol was increased to 50mg TID',
#  '5-31': 'A transesophageal echocardiogram was attempted, however Ms. [**Known lastname 104742**] developed methemoglobinemia methemoglobinemia (level 29) after receiving benzocaine spray',
#  '5-35': 'She received Methylene blue 140mg IV',
#  '5-38': 'Heme: Due to her myelodysplastic syndrome and bleeding with tPA',
#  '5-40': 'Additionally, the team spoke with her outpatient hematologist who confirmed no need for epo or aranesp',
#  '5-42': 'She received Famotidine for GI prophylaxis',
#  '5-44': 'Psych/ETOH: Initially Ms. [**Known lastname 104742**] had significant alcohol withdrawal',
#  '5-45': 'She was on a CIWA scale and received multiple doses of Ativan in addition to Valium q12',
#  '5-48': 'She also received thiamine and folate',
#  '5-50': 'She received Trazadone for sleep',
#  '5-52': 'She had an XR which showed no evidence of cortical disruptions suggestive of fracture or AC separation. Pain was treated with tylenol and oxycodone',
#  '5-55': 'Medications on Admission: - amlodipine 5mg daily - omeprazole 20mg daily - atenolol 50mg daily - levothyroxine 50mcg daily - vit B-12 1000mcg daily - vit B1 100mg [**Hospital1 **] - folic acid 1mg daily Discharge Medications: 1. enoxaparin 40 mg/0.4 mL Syringe Sig: Forty (40) MG Subcutaneous DAILY (Daily)',
#  '5-81': '2. senna 8.8 mg/5 mL Syrup Sig: Five (5) ML PO BID (2 times a day) as needed for constipation',
#  '5-88': '3. docusate sodium 50 mg/5 mL Liquid Sig: Ten (10) ML PO BID (2 times a day)',
#  '5-94': '4. bisacodyl 5 mg Tablet, Delayed Release (E.C.) Sig: Two (2) Tablet, Delayed Release (E.C.) PO DAILY (Daily) as needed for constipation',
#  '5-102': '5. aspirin 325 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '5-109': '6. acetaminophen 325 mg Tablet Sig: Two (2) Tablet PO Q4H (every 4 hours) as needed for pain',
#  '5-117': '7. trazodone 50 mg Tablet Sig: One (1) Tablet PO HS (at bedtime) as needed for insomnia',
#  '5-125': '8. thiamine HCl 100 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '5-132': '9. folic acid 1 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '5-139': '10. multivitamin Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '5-145': '11. famotidine 20 mg Tablet Sig: One (1) Tablet PO BID (2 times a day)',
#  '5-152': '12. metoprolol tartrate 50 mg Tablet Sig: One (1) Tablet PO TID (3 times a day)',
#  '5-159': 'Discharge Disposition: Extended Care Facility: [**Hospital6 85**] - [**Location (un) 86**] Discharge Diagnosis: Primary diagnosis: -Stroke (Right PCA+MCA-territory infarction) Secondary diagnoses: - EtOHism / withdrawal - chronic LBP - chronic mild anemia, possible MDS - methemoglobinemia secondary to benzocaine spray',
#  '5-162': 'Discharge Instructions: You were admitted to [**Hospital1 18**] after you had a large stroke',
#  '5-163': 'You initially received TPA in attempt to break up the clot in your brain , however this did not improve your symptoms and you developed bruising',
#  '5-166': 'You were started on medication, Lovenox , and Aspirin , to prevent further clots and strokes',
#  '5-169': 'You were also started on a blood pressure medication',
#  '5-170': 'You also developed a reaction to benzocaine spray , called methemoglobinemia',
#  '6-0': 'Admission Date: [**2120-12-23**] Discharge Date: [**2120-12-27**] Date of Birth: [**2053-8-26**] Sex: F Service: NEUROLOGY Allergies: Hydromorphone',
#  '6-1': 'She Called her oncologist who advised her to take an extra dose of Decadron',
#  '6-2': 'She has taken 4mg of Decadron for the past few days',
#  '6-5': 'Brief Hospital Course: This is a 67 yo female with h/o stage IV ovarian ca s/p surgery, 6 cycles of [**Doctor Last Name **]/ taxol',
#  '6-7': 'She was given 10mg decadron , IV hydration , Decadron 4mg Q6h',
#  '6-14': 'Pt was continued on Reglan PRN , Compazine PRN and Zofran PRN for nausea',
#  '6-21': 'At discharge, Dexamethasone',
#  '6-22': 'Pt was also initiated on Bactrim for PCP',
#  '6-24': '# Stage IV ovarian cancer: Pt was continued on pain control with home Motrin , Oxycodone PRN',
#  '6-28': '# Depression / Insomnia : Pt was continued on home Citalopram and Ativan qhs PRN',
#  '6-33': '# HTN/HL : Pt was continued on home HCTZ , Lisinopril , Verapamil',
#  '6-37': "It can be considered as outpt to discontinue HCTZ , given pt's persistent hyponatremia",
#  '6-39': 'Pt was continued on home Simvastatin',
#  '6-40': '# Pt was on a regular diet, oncology repletion scales. Pain control was with Motrin , Oxycodone PRN',
#  '6-44': 'Pt was on a bowel regimen and a PPI',
#  '6-45': 'Pt was on DVT PPx with SC Heparin',
#  '6-48': 'Medications on Admission: DEXAMETHASONE - (Dose adjustment - no new Rx) - 1 mg Tablet - 2 Tablet (s) by mouth twice a day Taper as follows: take 2 mg [**Hospital1 **] on [**11-12**], take 2 mg QAM and 1 mg QPM on [**2122-12-24**], take 2 mg once daily on [**11-20**], take 1 mg once daily',
#  '6-63': 'Stop taking Decadron',
#  '6-64': 'Stop taking Decadron after your dose on [**2121-1-3**]. HYDROCHLOROTHIAZIDE - (Prescribed by Other Provider) - 12.5 mg Capsule - 2 Capsule(s) by mouth DAILY (Daily) IBUPROFEN - (Dose adjustment - no new Rx) - 600 mg Tablet - 1 Tablet(s) by mouth three times a day as needed for pain LISINOPRIL - (Prescribed by Other Provider) - 5 mg Tablet - 1 Tablet(s) by mouth DAILY (Daily) LORAZEPAM - 0.5 mg Tablet - 1 Tablet (s) by mouth at bedtime and as needed METOCLOPRAMIDE - 10 mg Tablet - 1 Tablet (s) by mouth every 6 hours as needed for nausea , abdominal bloating take 30min before meals OMEPRAZOLE - 40 mg Capsule, Delayed Release',
#  '6-106': '- 1 Capsule (s) by mouth DAILY (Daily) ONDANSETRON HCL - 8 mg Tablet - 1 Tablet(s) by mouth q8hr as needed for nausea , vomiting OXYCODONE - 5 mg Tablet - [**1-6**] Tablet (s) by mouth q4hr as needed for pain PROCHLORPERAZINE MALEATE - 10 mg Tablet - 1/2-1 Tablet (s) by mouth q6hr as needed for nausea , vomiting SCALP PROSTHESIS - - apply to head SIMVASTATIN - (Prescribed by Other Provider) - 10 mg Tablet - 2 Tablet(s) by mouth DAILY (Daily) VERAPAMIL - (Prescribed by Other Provider) - 240 mg Tablet Sustained Release - 1 Tablet (s) by mouth every twenty-four(24) hours Discharge Medications: 1. citalopram 40 mg Tablet Sig: One (1) Tablet PO once a day',
#  '6-156': '2. lisinopril 5 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '6-163': '3. verapamil 120 mg Tablet Sustained Release Sig: Two (2) Tablet Sustained Release PO Q24H (every 24 hours)',
#  '6-170': '4. oxycodone 5 mg Tablet Sig: One (1) Tablet PO Q4H (every 4 hours) as needed for pain',
#  '6-178': '5. docusate [**Month/Day (2) **] 100 mg Capsule Sig: One (1) Capsule PO BID',
#  '6-185': 'Disp:*60 Capsule(s)* Refills:*2* 6. senna 8.6 mg Tablet Sig: One (1) Tablet PO BID (2 times a day) as needed for constipation',
#  '6-193': 'Disp:*30 Tablet(s)* Refills:*0* 7. ondansetron HCl 8 mg Tablet Sig: One (1) Tablet PO three times a day as needed for nausea',
#  '6-201': '8. prochlorperazine maleate 5 mg Tablet Sig: 1-2 Tablets PO four times a day as needed for nausea',
#  '6-209': '9. simvastatin 20 mg Tablet Sig: One (1) Tablet PO once a day',
#  '6-216': '10. lorazepam 0.5 mg Tablet Sig: One (1) Tablet PO at bedtime as needed for insomnia',
#  '6-224': '11. metoclopramide 10 mg Tablet Sig: One (1) Tablet PO every six (6) hours as needed for nausea',
#  '6-232': '12. omeprazole 40 mg Capsule, Delayed Release',
#  '6-235': 'Sig: One (1) Capsule, Delayed Release',
#  '6-237': 'Sig: One (1) Capsule, Delayed Release(E.C.) PO once a day',
#  '6-239': '13. hydrochlorothiazide 12.5 mg Capsule Sig: One (1) Capsule PO DAILY',
#  '6-246': '[**Month/Day (2) **] chloride 1 gram Tablet Sig: Two (2) Tablet PO TID',
#  '6-253': 'Disp:*180 Tablet(s)* Refills:*0* 15. dexamethasone 2 mg Tablet Sig: Three (3) Tablet PO Q12H (every 12 hours) for 3 days',
#  '6-261': 'Disp:*18 Tablet(s)* Refills:*0* 16. dexamethasone 2 mg Tablet Sig: Two (2) Tablet PO twice a day for 3 days',
#  '6-269': 'Disp:*12 Tablet(s)* Refills:*0* 17. dexamethasone 2 mg Tablet Sig: Three (3) Tablet PO QAM',
#  '6-276': 'Disp:*36 Tablet(s)* Refills:*2* 18. oxycodone 5 mg Tablet Sig: 1-2 Tablets PO every 4-6 hours as needed for pain',
#  '6-284': 'Disp:*20 Tablet(s)* Refills:*0* 19. Bactrim DS 800-160 mg Tablet Sig: One (1) Tablet PO MWF',
#  '6-291': 'The following medications were changed during this admission: START [**Known lastname **] chloride 1mg , 2 tablets , three times daily (this is to maintain your [**Known lastname **] levels at a normal level) START Oxycodone 5mg 1-2 tablets every four hours as needed for pain **This medication can cause sedation',
#  '6-303': 'START Bactrim DS ( Oral ) 800-160 mg Tablet , 1 tablet on Monday, Wednesday and Friday (this is an antibiotic that prevents an infection called PCP in the lungs; this is important to take since you are on steroids and may be more susceptible to infection) The dose of Dexamethasone was changed; Please follow the schedule below: START Dexamethasone 6mg by mouth twice daily for 3 days , then take 4mg twice daily for 3 days , then take 6mg daily in the morning',
#  '6-322': 'You should see your doctor in the interim to determine how long you need to be on the dexamethasone',
#  '6-323': '**You have been continued on your home dose of hydrochlorathiazide 25mg daily',
#  '6-326': 'However, HCTZ',
#  '6-327': 'Increase your intake of fluids and fiber , as narcotic pain medicine can cause constipation',
#  '6-330': 'We generally recommend taking an over the counter stool softener , such as Docusate ( Colace ) while taking narcotic pain medication',
#  '7-0': 'Admission Date: [**2202-10-17**] Discharge Date: [**2202-10-22**] Date of Birth: [**2143-12-3**] Sex: M Service: NEUROLOGY Allergies: Vicodin / Roxicet / Sirolimus',
#  '7-3': 'He responded with moan when his name was called, then developed left arm clonic seizure',
#  '7-4': 'He responded with moan when his name was called, then developed left arm clonic seizure (secondary generalization) and became unresponsive. Ativan 2mg IV',
#  '7-7': 'Course c/b recurrent hep C viremia, CRI, LFT abnl, acute rejection and hepatic artery thrombosis ([**2196**]) - Polymyositis - diagnosed in [**2196**] after hepatic artery thrombosis, Bx showed inflammatory myositis - HTN - CRI (baseline 2.0) - DM DM on insulin - post-transplant, related to steroid',
#  '7-11': 'Brief Hospital Course: Mr. [**Known lastname 2809**] is a 58 year old gentleman s/p liver transplant related to chronic HCV infection, myopathy',
#  '7-12': 'Brief Hospital Course: Mr. [**Known lastname 2809**] is a 58 year old gentleman s/p liver transplant related to chronic HCV infection, myopathy (? steroid',
#  '7-13': 'Initial labs notable for presence of only serum benzodiazepines',
#  '7-14': 'He was changed from phenytoin to oxcarbazepine ( Trileptal ) given multiple long term side effects of phenytoin , and with normal hepatic function, but renal impairment and keppra',
#  '7-19': 'It was re-attempted with fentanyl and midazolam for monitored conscious sedation',
#  '7-22': '2) Cardio: * NSTEMI',
#  '7-23': 'He was started on aspirin , beta blocker , atorvastatin',
#  '7-26': '3) FEN * Acute Renal Failure',
#  '7-27': 'He received vigorous IV hydration',
#  '7-29': 'He was started on Thiamine , Folate and MVI',
#  '7-32': '4) Liver transplantation',
#  '7-33': 'Hepatology consultation was obtained and recommended continuing with his prior regimen of immunosuppressive agents',
#  '7-34': '6) PPx, reactivation and reconditioning For prophylaxis , he was put on Heparin',
#  '7-36': 'Medications on Admission: Prograf 1mg [**Hospital1 **] Imuran 50mg [**Hospital1 **] Cellcept ( mycophenidate mofetil ) 1000mg [**Hospital1 **] bactrim metoprolol 50mg [**Hospital1 **] Clindagel asa 81mg daily fosamax 35mg q fri marinol 5mg qpm and qhs simethicone 80mg [**Hospital1 **] calcum 500mg + D [**Hospital1 **] Ambien ( zolpidem ) 5mg qhs doxazosin 1.5mg qhs hydroxyzine hcl 50mg [**Hospital1 **] ritalin 15mg qam remeron 7.5 qhs prilosec 20mg daily Effexor 37.5mg daily Florinef 0.1mg daily Lasix 20mg daily Kayexylate Lipitor 10mg daily Lisinopril 5mg daily Percocet one tab qid prn Cosopt one drop to left eye [**Hospital1 **] Alphagan 0.15% to left eye [**Hospital1 **] Ofloxacin 0.3% eye drop to left eye qid Prednisolone 1% eye drop to left eye qid Homatropine 5% eye drop to left eye',
#  '7-121': 'Medications on Admission: Prograf 1mg [**Hospital1 **] Imuran 50mg [**Hospital1 **] Cellcept (mycophenidate mofetil) 1000mg [**Hospital1 **] bactrim metoprolol 50mg [**Hospital1 **] Clindagel asa 81mg daily fosamax 35mg q fri marinol 5mg qpm and qhs simethicone 80mg [**Hospital1 **] calcum 500mg + D [**Hospital1 **] Ambien (zolpidem) 5mg qhs doxazosin 1.5mg qhs hydroxyzine hcl 50mg [**Hospital1 **] ritalin 15mg qam remeron 7.5 qhs prilosec 20mg daily Effexor 37.5mg daily Florinef 0.1mg daily Lasix 20mg daily Kayexylate Lipitor 10mg daily Lisinopril 5mg daily Percocet one tab qid prn Cosopt one drop to left eye [**Hospital1 **] Alphagan 0.15% to left eye [**Hospital1 **] Ofloxacin 0.3% eye drop to left eye qid Prednisolone 1% eye drop to left eye qid Homatropine 5% eye drop to left eye [**Hospital1 **] Discharge Medications: 1. Aspirin 325 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '7-128': '2. Bisacodyl 5 mg Tablet , Delayed Release (E.C.) Sig: Two (2) Tablet, Delayed Release (E.C.) PO DAILY (Daily) as needed',
#  '7-135': '3. Tacrolimus 1 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)',
#  '7-142': '4. Mycophenolate Mofetil 500 mg Tablet Sig: Two (2) Tablet PO twice a day',
#  '7-149': '5. Colace 100 mg Capsule Sig: One (1) Capsule PO twice a day',
#  '7-156': '6. Alendronate 35 mg Tablet Sig: One (1) Tablet PO QFRI (every Friday)',
#  '7-163': '7. Doxazosin 1 mg Tablet Sig: 1.5 Tablets PO HS (at bedtime)',
#  '7-170': '8. Hydroxyzine HCl 25 mg Tablet Sig: Two (2) Tablet PO BID (2 times a day)',
#  '7-177': '9. Venlafaxine 37.5 mg Capsule, Sust. Release 24 hr Sig: One (1) Capsule, Sust. Release 24 hr PO DAILY (Daily)',
#  '7-184': '10. Fludrocortison e 0.1 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '7-191': '11. Heparin (Porcine) 5,000 unit /mL Solution Sig: One (1) Injection [**Hospital1 **] ( 2 times a day',
#  '7-197': '12. Trimethoprim- Sulfamethoxazole 160-800 mg Tablet Sig: One (1) Tablet PO MWF (Monday-Wednesday-Friday) as needed for ppx',
#  '7-205': '13. Oxcarbazepin e 300 mg Tablet Sig: One (1) Tablet PO BID (2 times a day)',
#  '7-212': '14. Dorzolamide- Timolol 2-0.5 % Drops Sig: One (1) Drop Ophthalmic [**Hospital1 **] ( 2 times a day',
#  '7-219': '15. Brimonidine 0.15 % Drops Sig: One (1) Drop Ophthalmic Q 12H (Every 12 Hours)',
#  '7-226': '16. Ofloxacin 0.3 % Drops Sig: One (1) Ophthalmic four times daily',
#  '7-232': '17. Prednisolone Acetate 1 % Drops, Suspension Sig: One (1) Drop Ophthalmic QID (4 times a day)',
#  '7-239': '18. Homatropine HBr 5 % Drops Sig: One (1) Ophthalmic twice daily',
#  '7-245': '19. Famotidin e 20 mg Tablet Sig: One (1) Tablet PO Q24H (every 24 hours)',
#  '7-252': '20. Metoprolol Tartrate 25 mg Tablet Sig: Three (3) Tablet PO BID (2 times a day)',
#  '7-259': '21. Atorvastatin 10 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '7-266': '22. Hexavitamin Tablet Sig: One (1) Cap PO DAILY (Daily)',
#  '7-272': '23. Thiamine HCl 100 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '7-279': '24. Folic Acid 1 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '7-286': 'Your medications such as Remeron and Methylphenidate',
#  '8-0': 'Admission Date: [**2119-4-6**] Discharge Date: [**2119-4-15**] Service: MEDICINE Allergies: Bactrim Ds / Zyprexa / Lisinopril',
#  '8-4': 'The patient was seen by her ophthalmologist on [**2119-4-4**] with impression that there was moderate lid edema present suggestive of hypersensitivity but no discharge to suggest infection. Polysporin was discontinued (with concern for hypersensitivty per discussion with daughter) and other meds ( Pred 1 % TID OS , Timolol 0.5 % [**Hospital1 **] OU , Xalatan QHS OS , Tobradex',
#  '8-17': 'Not signed out, but per nursing report and discussion a central line was attempted given poor PIV access for which the patient received Haldol',
#  '8-18': 'No documentation of dose is available, [**Name8 (MD) **] RN to RN signout this was 5mg IV',
#  '8-20': 'The patient was given Azithromycin , Vancomycin , and Ceftriaxone',
#  '8-23': 'A CT of the Head and Neck with IV contrast',
#  '8-26': 'Swelling around false cords, tonsillar edema',
#  '8-27': 'The team thought the swelling',
#  '8-28': 'She was started on solumedrol 60 IV and famotidine 20mg',
#  '8-32': 'She was given one dose of zosyn and then switched to unasyn to cover for possible soft tissue infection',
#  '8-36': 'She was monitored and continued on Decadron for three',
#  '8-38': 'Unclear etiology: possible allergic reaction vs infectious process vs both given tonsils appear possibly infectious and lower airway appears more edematous and less infectious. Lisinopril',
#  '8-39': '-Pt was treated for 10 days for ? soft tissue infection and switched to Augmentin for additional 5 days',
#  '8-42': 'Ophtho felt the eye was improving and recommended decreasing doses of eye drops',
#  '8-43': '#. Altered Mental Status : On admission, she was lethargic , possibly from the Haldol',
#  '8-46': 'Shortely thereafter, however, she became agitated and combative and received 1.5mg Haldol and later the same day 5mg of Zyprexa',
#  '8-52': 'EEG showed some focal acitivity concerning for sublinical seizures',
#  '8-53': 'Pt was started on keppra',
#  '8-54': '-Pt curently is on Keppra 1000mg [**Hospital1 **] for one week and to be increased to 1500mg',
#  '8-58': '#. UTI : grew Enterococcus',
#  '8-60': 'She was continued on Unasyn for 10 days',
#  '8-62': 'This was likely a contaminant so vancomycin',
#  '8-63': "#. Parkinson's Disease : continued Sinemet",
#  '8-65': '#. Hypertension, benign : Lisinopril was stopped due to concern of angioedema',
#  '8-68': 'Hypertension, benign: Lisinopril was stopped due to concern of angioedema. Atenolol',
#  '8-69': '#. Hyperlipidemia : continued statin',
#  '8-71': '#. Hypothyroidism',
#  '8-72': 'Continued levothyroxine',
#  '8-73': '#. Diabetes II , diet controlled without complication: - insulin sliding scale',
#  '8-76': 'Pt can have [**Hospital1 **] finger checks to Rehab but since not needing insulin , does not have to be on sliding scale # Deconditioning: per PT eval, pt was 2 person assist and will need significant PT therapy to get back to baseline where she was walking with a walker Medications on Admission: Tylenol 1000mg PO twice daliy Aspirin 81mg daily Atenolol 25mg daily Carbidopa/Levodopa 25/100mg three times daily Enablex 7.5mg SR daily Fish Oil 1000mg daily Levothyroxin 125mcg daily Lisinopril 20mg daily Simvastatin 10mg daily Cyanocobalamin 1000mcg daily Docusate 100mg daily Pred 1 % TID OS Timolol 0.5 % [**Hospital1 **] OU Xalatan QHS OS Tobradex OS QHS',
#  '8-125': 'Pt can have [**Hospital1 **] finger checks to Rehab but since not needing insulin, does not have to be on sliding scale # Deconditioning: per PT eval, pt was 2 person assist and will need significant PT therapy to get back to baseline where she was walking with a walker Medications on Admission: Tylenol 1000mg PO twice daliy Aspirin 81mg daily Atenolol 25mg daily Carbidopa/Levodopa 25/100mg three times daily Enablex 7.5mg SR daily Fish Oil 1000mg daily Levothyroxin 125mcg daily Lisinopril 20mg daily Simvastatin 10mg daily Cyanocobalamin 1000mcg daily Docusate 100mg daily Pred 1% TID OS Timolol 0.5% [**Hospital1 **] OU Xalatan QHS OS Tobradex OS QHS Discharge Medications: 1. Latanoprost 0.005 % Drops Sig: One (1) Drop Ophthalmic HS (at bedtime)',
#  '8-132': '2. Tobramycin-Dexamethasone 0.3-0.1 % Ointment Sig: One (1) Appl Ophthalmic QHS (once a day (at bedtime))',
#  '8-139': '3. Timolol Maleate 0.5 % Drops Sig: One (1) Drop Ophthalmic [**Hospital1 **] ( 2 times a day',
#  '8-146': '4. Prednisolone Acetate 1 % Drops, Suspension Sig: One (1) Drop Ophthalmic DAILY (Daily)',
#  '8-152': '5. Atenolol 25 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '8-159': '6. Carbidopa-Levodopa 25-100 mg Tablet Sig: One (1) Tablet PO TID (3 times a day)',
#  '8-166': '7. Levothyroxine 125 mcg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '8-173': '8. Simvastatin 10 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '8-180': '9. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)',
#  '8-187': '10. Senna 8.6 mg Tablet Sig: One (1) Tablet PO BID (2 times a day)',
#  '8-194': '11. Bisacodyl 10 mg Suppository Sig: One (1) Suppository Rectal DAILY (Daily)',
#  '8-201': '12. Aspirin 325 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '8-208': '13. Levetiracetam 500 mg Tablet Sig: Two (2) Tablet PO BID (2 times a day) : for one week , then increase to 1500mg',
#  '8-217': '14. Augmentin 875-125 mg Tablet Sig: One (1) Tablet PO twice a day for 5 days',
#  '8-225': "Disp:*10 Tablet(s)* Refills:*0* Discharge Disposition: Extended Care Facility: [**Hospital6 459**] for the Aged - [**Location (un) 550**] Discharge Diagnosis: Primary: oropharyngeal swelling, delirium, urinary tract infection Secondary: Parkinson's disease, diabetes type 2, hypertension, hyperlipidemia Discharge Condition: Good Discharge Instructions: You were evaluated for confusion and found to have swelling of your tongue and throat as well as a urinary tract infection",
#  '8-226': 'You improved with antibiotics',
#  '9-0': 'Admission Date: [**2153-1-20**] Discharge Date: [**2153-2-19**] Date of Birth: [**2084-11-24**] Sex: M Service: NEUROSURGERY Allergies: Heparin Agents / Motrin Attending:[**First Name3 (LF) 1835**] Chief Complaint: shoulder pain Major Surgical or Invasive Procedure: S/P ACD S/P POSTERIOR CERVICAL RECONSTRUCTION History of Present Illness: 68 M PMH thyroid ca with mets to bone and liver, history of intrathecal narcotics',
#  '9-4': 'He was attempting to increase his decadron',
#  '9-5': 'In the ED, given dilaudid 4mg IV x 2 , with pain',
#  '9-10': 'Past Medical History: Thyroid ca s/p thyroidectomy [**2147**], with mets to bone and liver -s/p implanted epidural narcotics on prior admission; hx of infected Port-A-Cath system S/p carboplatin',
#  '9-13': '# pneumonia',
#  '9-14': 'Started on levo / flagyl',
#  '9-16': 'No fevers since starting levo / flagyl',
#  '9-18': '# L shoulder/humerus pain',
#  '9-19': 'His pain was initially difficult to control, but was ultimately dramatically improved when he was changed to a dilaudid PCA --he did not have relief from fentanyl patch',
#  '9-23': '# thyroid ca , metastatic disease',
#  '9-25': '#thyroid ca, metastatic disease: progressive in spine and likely contributing to current complaints. Levothyroxine',
#  '9-26': 'consider neupogen',
#  '9-27': '# thrush : The patient was admitted with thrush which was succesfully treated with nystatin S&S',
#  '9-30': "The total EBL was 7.5 liters with the pt being given 22 units of PRBC's",
#  '9-32': 'Postoperatively he was started on Fondiparinox on [**2-13**] as he is HIT positive',
#  '9-34': "His course complicated by intermittent low HCT's for which he was transfused. Temps as high as 102 .+ for which he was started on Zosyn",
#  '9-36': 'Medications on Admission: gabapentin 300/300/900 , hydromorphone 4-8 mg Q8H PRN , tizanidine 2mg t.i.d ., fentanyl patch 75 mcg per hour every three days , lidoderm patch 50 , 3 patches a day lorazepam 0.5mg Q4-6H PRN levothyroxine 0.125 qd protonix 40 qd folic acid decadron 2mg [**Hospital1 **] (incr to 4mg',
#  '10-0': 'Admission Date: [**2123-1-12**] Discharge Date: [**2123-1-19**] Date of Birth: [**2047-9-27**] Sex: F Service: MEDICINE Allergies: Tape [**12-14**]"X10YD / Morphine',
#  '10-1': 'On Monday, she was started on azithromycin yesterday as well as home oxygen with a plan to increase her prednisone',
#  '10-4': 'There was iniital concern for a COPD exacerbation ; she was given 250 mg azithro , 1 gm cftx , albuterol/ipratropium nebs , IV solumedrol 125 mg IV',
#  '10-15': 'Pt ruled in for NSTEMI',
#  '10-16': 'She was given 325 mg ASA , plavix 75 mg , & she was started on heparin gtt',
#  '10-22': 'She was also given 40 mg IV lasix',
#  '10-25': 'ACUTE DIAGNOSES: # NSTEMI',
#  '10-26': 'Transferred on heparin gtt',
#  '10-28': 'Pt was continued on metoprolol , statin , ASA',
#  '10-31': 'Loaded with plavix',
#  '10-32': 'Patient hypotensive during case, requiring dopamine gtt',
#  '10-34': 'She was given protamine',
#  '10-35': 'Patient also dyspnea , requiring O2 4L per NC',
#  '10-38': 'In the CCU, patient was continued on ASA 325mg PO , Atorvastatin 80mg PO daily , Metoprolol tartrate 50mg PO BID , plavix',
#  '10-50': 'In the CCU, patient was continued on ASA 325mg PO, Atorvastatin 80mg PO daily, Metoprolol tartrate 50mg PO BID, plavix. Amlodipine was discontinued and lisinopril was held due to hypotension / low urine output',
#  '10-54': 'On the floor, patient started on diovan 40 mg',
#  '10-56': 'Discharged on full ASA , plavix , metoprolol succinate 100 mg QD',
#  '10-61': '# LEFT GROIN HEMATOMA : Developed apparent right groin hematoma which was treated with protamine',
#  '10-63': 'Patient was maintained on pneumoboots instead of heparin sq prophylaxis',
#  '10-66': 'Pt was given IV lasix',
#  '10-68': 'During catheterization, pt was hypotensive & required dopamine gtt',
#  '10-71': 'She was transferred to the CCU for transient hypotension requiring dopamine',
#  '10-73': 'Ms. [**Known lastname 13143**] was normotensive on the floor. Diovan',
#  '10-74': 'Diovan was started on the floor as above. Lasix',
#  '10-75': 'CHRONIC DIAGNOSES: # COPD / Emphysema : Pt was continued on her course of azithromycin',
#  '10-78': '# PVD : continued on aspirin & plavix',
#  '10-81': '# Seizure disorder',
#  '10-82': 'He was continued on home keppra 1500mg',
#  '10-84': 'The recommended dose (based on creatinine clearance) is 750 mg',
#  '10-85': '# Rheumatoid arthritis : He was continued on prednisone 5mg PO daily',
#  '10-90': 'Her celebrex',
#  '10-91': '# Osteopenia : He was continued on calcium , vitamin D',
#  '10-94': 'Daughter is HCP: [**Name (NI) **] [**Name (NI) **] [**Telephone/Fax (1) 28220**] Medications on Admission: Aspirin 81mg daily Celebrex 100mg daily Simvastatin 20mg nightly Prednisone 5 mg daily Metoprolol 25mg daily Omeprazole 20mg daily Amlodipine 5mg daily Vitamin D 400 units daily Calcium carbonate - 6 tabs daily Keppra 1500mg [**Hospital1 **] B12 injection once per month Timolol 0.5 % one drop to each eye daily in AM (not recently taking) Brimodidine 0.15 % one drop left eye [**Hospital1 **] (not recently taking) Optive dry eye solution , both eyes TID (not recently taking) Discharge Medications: 1. prednisone 5 mg Tablet Sig: One (1) Tablet PO DAILY',
#  '10-149': '2. clopidogrel 75 mg Tablet Sig: One (1) Tablet PO DAILY',
#  '10-156': '3. atorvastatin 80 mg Tablet Sig: One (1) Tablet PO DAILY',
#  '10-163': '4. sodium chloride 0.65 % Aerosol, Spray Sig: [**12-14**] Sprays Nasal QID (4 times a day) as needed for dry nose',
#  '10-170': '5. aspirin 325 mg Tablet Sig: One (1) Tablet PO DAILY',
#  '10-177': '6. metoprolol tartrate 50 mg Tablet Sig: One (1) Tablet PO BID',
#  '10-184': '7. citalopram 20 mg Tablet Sig: 0.5 Tablet PO DAILY',
#  '10-191': '8. valsartan 40 mg Tablet Sig: One (1) Tablet PO DAILY',
#  '10-198': '9. omeprazole 20 mg Capsule, Delayed Release(E.C.) Sig: One (1) Capsule, Delayed Release(E.C.) PO once a day',
#  '10-205': '10. cholecalciferol (vitamin D3) 400 unit Tablet Sig: One (1) Tablet PO DAILY',
#  '10-212': '11. benzonatate 100 mg Capsule Sig: One (1) Capsule PO TID (3 times a day) as needed for cough for 2 weeks',
#  '10-221': '12. Cepacol Sore Throat 15-2.6 mg Lozenge Sig: One (1) Mucous membrane five times a day as needed for sore throat for 1 weeks',
#  '10-229': '13. Tylenol 325 mg Tablet Sig: 1-2 Tablets PO every six (6) hours as needed for pain',
#  '10-237': '14. omeprazole 20 mg Capsule, Delayed Release(E.C.) Sig: One (1) Capsule, Delayed Release(E.C.) PO once a day',
#  '10-244': '15. calcium citrate 200 mg (950 mg) Tablet Sig: One (1) Tablet PO three times a day',
#  '10-251': 'Medication B12 injections one per month 17. timolol maleate (PF) 0.5 % Dropperette Sig: One (1) drop Ophthalmic QAM',
#  '10-260': '18. levetiracetam 250 mg Tablet Sig: Three (3) Tablet PO BID',
#  '10-267': '19. guaifenesin 100 mg/5 mL Syrup Sig: 5-10 MLs PO Q6H (every 6 hours) as needed for cough',
#  '10-274': '20. codeine-guaifenesin 10-100 mg/5 mL Syrup Sig: 5-10 MLs PO HS (at bedtime) as needed for cough for 1 weeks',
#  '10-282': '21. oxymetazoline 0.05 % Aerosol, Spray Sig: One (1) Spray Nasal [**Hospital1 **] ( 2 times a day ) as needed for congestion for 2 days',
#  '10-291': '22. fluticasone-salmeterol 250-50 mcg/dose Disk with Device Sig: One (1) Inhalation Inhalation [**Hospital1 **] ( 2 times a day',
#  '10-298': 'While you were there, you were treated with some intravenous diuretics',
#  '10-300': 'MEDICATION INSTRUCTIONS: - Medications STARTED: ---> Please start taking celexa 10 mg daily ---> Please start taking diovan 40 mg daily ---> Please start taking atorvastatin 80 mg daily ---> Please start taking plavix 75 mg daily ---> Please start taking nasal saline spray as needed for dry nose ---> Please start taking calcium citrate (instead of calcium carbonate ) ---> Please start taking your inhaler as indicated - Medications STOPPED: ---> Please stop taking lisinopril ---> Please stop taking amlodipine ---> Please stop taking simvastatin ---> Please stop taking calcium carbonate - Medications CHANGED: ---> Please decrease your dose of Keppra from 1500 mg twice a day to 750 mg twice a day (this medication is now dosed safely according to your kidney function) ---> Please increase your dose of aspirin from 81 mg to 325 mg daily ---> Please increase your dose of metoprolol from 25 mg daily to 100 mg daily',
#  '11-0': 'Admission Date: [**2124-3-15**] Discharge Date: [**2124-3-21**] Date of Birth: [**2055-1-24**] Sex: F Service: MEDICINE Allergies: Penicillins / Aspirin / lisinopril / Wellbutrin / Seroquel',
#  '11-5': 'She continues to breakthrough despite pharmacologic therapy with metoprolol , and failed amiodarone',
#  '11-7': 'Received 500cc NS',
#  '11-9': 'Past Medical History: -Paroxysmal SVT/AT -CAD; NSTEMI ([**9-26**]) BMS to LAD, RCA 100% occluded -chronic systolic HF, LVEF 35% -DM2 -Hypertension -Hyperlipidemia -CVA (residual R weakness and intermittent R facial droop) -PAD -ESRD on HD 3x/week: anuric, on HD for >5y -Sleep apnea (not using CPAP) - Seizure disorder since [**3-/2123**] on Keppra',
#  '11-11': 'Attempts to increase beta-blockade beyond Toprol 75mg PO QD',
#  '11-16': 'We note that on [**3-16**], post-procedure recovery was initially complicated by anaesthesia -induced hypotension',
#  '11-18': 'She was euvolemic during admission; volume/BP control primarily via BB',
#  '11-20': 'She was euvolemic during admission; volume/BP control primarily via BB and dialysis. Imdur was stopped due to relative hypotension',
#  '11-22': 'Imdur was stopped due to relative hypotension (SBP 90s-110s). Metoprolol dose increased to Toprol 75 mg QD',
#  '11-26': 'We note hx lisinopril',
#  '11-27': 'Family confirmed that she suffers from lightheadedness when she first rises to stand, especially after watching television (she like Westerns). Imdur had already been stopped prior to this PT eval; BB was subsequently lowered from Toprol 100 QD to 75 QD',
#  '11-34': '# DM2 Patient has known DM2 , not on either oral hypoglycemics or insulin',
#  '11-38': '# DM2 Patient has known DM2, not on either oral hypoglycemics or insulin. Insulin needs here ranged from 8-12U / day',
#  '11-41': 'Discussed initiating insulin',
#  '11-42': '# CAD',
#  '11-43': 'Continued Plavix and ASA 81mg',
#  '11-46': '# Hx Hypothyroidism',
#  '11-47': 'Continued home dose of synthroid',
#  '11-48': '# Hx HLD Continued home statin',
#  '11-50': '# Hx Seizure disorder',
#  '11-51': 'Continued home Keppra',
#  '11-52': 'EP to reassess for possible future repeat ablation attempt 2. DM2 - Pt refused discussion of insulin , had 8-12U / day insulin',
#  '11-57': 'Follow-up HR, BP, orthostatic VS. Toprol dose increased to 75mg po DAILY , imdur',
#  '11-62': 'Medications on Admission: 1. atorvastatin 80 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '11-69': 'Medications on Admission: 1. atorvastatin 80 mg Tablet Sig: One (1) Tablet PO DAILY (Daily). Tablet (s) 2. clopidogre l 75 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '11-77': '3. isosorbide mononitrate 60 mg Tablet Extended Release 24 hr Sig: One (1) Tablet Extended Release 24 hr PO DAILY (Daily)',
#  '11-84': '4. aripiprazole 10 mg Tablet Sig: Three (3) Tablet PO DAILY (Daily)',
#  '11-91': '5. B complex-vitamin C- folic acid 1 mg Capsule Sig: One (1) Cap PO DAILY (Daily)',
#  '11-98': '6. calcium acetate 667 mg Capsule Sig: One (1) Capsule PO TID W/MEALS (3 TIMES A DAY WITH MEALS)',
#  '11-105': '7. citalopra m 20 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '11-112': '8. levetiracetam 500 mg Tablet Sig: One (1) Tablet PO ONCE (Once) for 1 doses',
#  '11-120': '9. levothyroxine 100 mcg Tablet Sig: Three (3) Tablet PO DAILY (Daily)',
#  '11-127': '10. mirtazapin e 15 mg Tablet Sig: One (1) Tablet PO HS (at bedtime) as needed for insomnia',
#  '11-135': '11. pantoprazol e 40 mg Tablet, Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q24H (every 24 hours)',
#  '11-142': '12. aspiri n 81 mg Tablet, Chewable Sig: One (1) Tablet, Chewable PO DAILY (Daily)',
#  '11-149': '13. docusate sodium 100 mg Capsule Sig: One (1) Capsule PO DAILY (Daily)',
#  '11-156': '14. senna 8.6 mg Tablet Sig: 1-2 Tablets PO DAILY (Daily)',
#  '11-163': '15. hydromorphone 2 mg Tablet Sig: One (1) Tablet PO Q6H (every 6 hours) as needed for pain',
#  '11-171': '16. metoprolol succinate 50mg po qday Discharge Medications: 1. atorvastati n 80 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '11-182': '2. clopidogrel 75 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '11-189': '3. aripiprazole 10 mg Tablet Sig: Three (3) Tablet PO DAILY (Daily)',
#  '11-196': '4. B complex-vitamin C- folic acid 1 mg Capsule Sig: One (1) Cap PO DAILY (Daily)',
#  '11-203': '5. calcium acetate 667 mg Capsule Sig: One (1) Capsule PO TID W/MEALS (3 TIMES A DAY WITH MEALS)',
#  '11-210': '6. citalopram 20 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '11-217': '7. levetiracetam 500 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '11-224': '8. levothyroxine 100 mcg Tablet Sig: Three (3) Tablet PO DAILY (Daily)',
#  '11-231': '9. mirtazapin e 15 mg Tablet Sig: One (1) Tablet PO HS (at bedtime) as needed for insomnia',
#  '11-239': '10. pantoprazol e 40 mg Tablet, Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q24H (every 24 hours)',
#  '11-246': '11. aspiri n 81 mg Tablet, Chewable Sig: One (1) Tablet, Chewable PO DAILY (Daily)',
#  '11-253': '12. docusate sodium 100 mg Capsule Sig: One (1) Capsule PO DAILY (Daily)',
#  '11-260': '13. senna 8.6 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '11-267': '14. hydromorphone 2 mg Tablet Sig: One (1) Tablet PO Q6H (every 6 hours) as needed for pain',
#  '11-275': '15. Toprol XL 25 mg Tablet Extended Release 24 hr Sig: Three (3) Tablet Extended Release 24 hr PO once a day',
#  '11-282': 'Disp:*90 Tablet Extended Release 24 hr(s)',
#  '11-283': 'You had elevated blood sugars',
#  '11-284': 'On average, you received 12 units of insulin /day',
#  '11-287': 'The following changes were made to your medications: CHANGED METOPROLOL FORMULATION: START TAKING TOPROL XL 75 MG PER DAY',
#  '11-291': "DON'T TAKE YOUR OLD METOPROLOL/ LOPRESSOR PILLS",
#  '11-293': 'STOP TAKING IMDUR',
# ...
#  '24-125': 'Medications on Admission: MEDICATIONS (from NWH D/C summary on [**9-11**]) acetaminophen 1 g q8hr ASA 325 Daily Erythropoietin 4000 units SC weekly Ferrous sulfate 325 mg Daily Furosemide 40 mg daily Lovenox 30 mg SC daily until ambulatory NPH (8 units before breakfast and dinner Regular insulin (5 units before breakfast and dinner Metoprolol 12.5 mg [**Hospital1 **] MVT daily Miralax 17 g Daily Nystain triamcinolone cream topically twice daily omeprazole 29 mg daily Sarna lotion to affected area [**Hospital1 **] senokot qHs Sertraline 50 mg daily simvastatin 20 mg daily flomax 0.4 mg daily Discharge Medications: 1. Sertraline 50 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '24-132': '2. Camphor-Menthol 0.5-0.5 % Lotion Sig: One (1) Appl Topical QID (4 times a day) as needed for itching',
#  '24-140': '3. Acetaminophen 325 mg Tablet Sig: 1-2 Tablets PO Q6H (every 6 hours) as needed for fever , pain',
#  '24-149': '4. Quetiapine 25 mg Tablet Sig: One (1) Tablet PO QHS (once a day (at bedtime))',
#  '24-156': '5. Trazodone 50 mg Tablet Sig: One (1) Tablet PO HS (at bedtime) as needed for insomnia',
#  '24-164': '6. Senna 8.6 mg Tablet Sig: One (1) Tablet PO BID (2 times a day) as needed for constipation',
#  '24-172': '7. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day) as needed for constipation',
#  '24-180': '8. Morphine 10 mg/5 mL Solution Sig: [**4-29**] mL PO Q4H (every 4 hours) as needed for pain , respiratory distress',
#  '24-187': '9. Hydrocortisone 2.5 % Cream Sig: One (1) Appl Rectal TID (3 times a day) as needed for itching',
#  '24-195': '10. Doxepin 25 mg Capsule Sig: One (1) Capsule PO BID',
#  '24-202': '11. Quetiapine 25 mg Tablet Sig: One (1) Tablet PO Q6H (every 6 hours) as needed for anxiety',
#  '24-210': '12. Zofran 2 mg/mL Solution Sig: Four (4) mg Intravenous every six (6) hours as needed for nausea',
#  '25-0': 'Admission Date: [**2188-2-4**] Discharge Date: [**2188-2-11**] Service: MEDICINE Allergies: Patient recorded as having No Known Allergies to Drugs Attending:[**First Name3 (LF) 12**] Chief Complaint: Hematemesis Major Surgical or Invasive Procedure: Endoscopy with clips, epinephrine injection',
#  '25-2': 'History of Present Illness: 84M with lymphoma s/p CHOP last week, h/o GIB, dilated CMP, who originally presented from home with hematemesis x2 , after taking high dose prednisone during chemotherapy as well as Bufrin for arthritis',
#  '25-10': 'Patient has had UGIB in past with NSAID',
#  '25-12': 'He was given PPI , received NGT lavage , which did not clear after 1L , and patient was fluid resuscitated',
#  '25-18': 'In the MICU, patient had endoscopy showing multiple gastric ulcers , which were clipped, injected with epinephrine',
#  '25-21': 'Patient was also found to have an evolving STEMI',
#  '25-22': 'Cardiology was consulted, and patient was medically managed with a beta blocker , ACE inhibitor',
#  '25-24': 'Patient was taken off his home digoxin and amlodipine',
#  '25-26': 'Past Medical History: 1. Lymphoma',
#  '25-27': 'Tx c XRT [**8-26**]-on CHOP-R - last chemo',
#  '25-29': 'Chronic afib , has refused coumadin',
#  '25-31': 'Arthritis 7. question OSA 8. GI bleed - [**2184**] c hgb 7.7 [**1-24**] NSAID / aspirin',
#  '25-34': 'Two resolution clips were applied to the vessel with persistent oozing. 9cc of 1:10,000 epinephrine was injected',
#  '25-38': "Mucosa suggestive of Barrett's esophagus Brief Hospital Course: 84 yo male with PMHx sx for lymphoma, upper GIB, cardiomyopathy, who presented with an upper GI bleed with multiple gastric ulcers seen on endoscopy, likely secondary to NSAID use and recent high dose prednisone with CHOP therapy for lymphoma",
#  '25-45': ". Upper GI bleed : Patient's UGI bleed was likely [**1-24**] NSAID use combined with recent prednisone for CHOP",
#  '25-49': 'Patient had an NG lavage performed, which did not clear after 1000cc NS',
#  '25-53': "Patient's ulcers were clipped, injected with epinephrine",
#  '25-56': 'On transfer to OMED, patient was hemodynamically stable, but then began to have drop in hematocrit',
#  '25-57': 'He received three units of blood',
#  '25-59': 'He remained guaiac positive, had two large bore pIVs for access, and continued on [**Hospital1 **] pantoprazole',
#  '25-60': 'Patient was advised to avoid all NSAIDs',
#  '25-61': '. STEMI',
#  '25-62': "A cardiology consult was obtained, and recommended stopping patient's amlodipine and digoxin , and starting atorvastatin , lisinopril and metoprolol",
#  '25-67': 'Patient was not placed on heparin',
#  '25-68': 'He was not anticoagulated for his atrial fibrillation',
#  '25-70': '. Lymphoma',
#  '25-71': 'He received one dose of neupogen as an inpatient, but had a leukocytosis',
#  '25-74': 'He will be seen in [**Hospital 20722**] clinic for consideration of further chemotherapy',
#  '25-75': 'His electrolytes',
#  '25-76': 'Medications on Admission: Amlodipine Digoxin Bufferin',
#  '25-79': 'Medications on Admission: Amlodipine Digoxin Bufferin Discharge Medications: 1. Pantoprazol e 40 mg Tablet , Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q12H (every 12 hours)',
#  '25-86': ')(s)* Refills:*2* 2. Atorvastatin 40 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '25-93': 'Disp:*28 Tablet(s)* Refills:*2* 3. Metoprolol Tartrate 25 mg Tablet Sig: 0.5 Tablet PO BID (2 times a day)',
#  '25-100': 'ST elevation MI 4. Lymphoma s/p R-CHOP',
#  '26-0': 'Admission Date: [**2174-6-6**] Discharge Date: [**2174-6-16**] Date of Birth: [**2121-12-16**] Sex: F Service: MEDICINE Allergies: Compazine / Reglan / Opioids - Morphine',
#  '26-4': 'On [**5-23**], patient awoke with 10/10 pleuritic pain',
#  '26-5': 'She went to PCP who ordered [**Name Initial (PRE) **] CTA which was negative for PE and diagnosed her with pleurisy',
#  '26-6': 'She was prescribed motrin 800mg TID',
#  '26-9': 'Her pain was mildy improved with the motrin',
#  '26-11': 'Triggered in the ED for hypoxia to 89% RA, placed on O2 by N/C + abx ( CTX and lev',
#  '26-17': 'Past Medical History: SHOULDER PAIN, LEFT-S/P LABRAL TEAR REPAIR AND AC REPAIR FRACTURE, FINGER OSTEOPENIA MENOPAUSAL STATE LYME DISEASE meningitis [**2170**] s/p 3 years of abx (seasonal plaquinel plus doxycycline alternating with clarithromycin',
#  '26-23': 'Brief Hospital Course: 52 year old female with a history of lone atrial fibrillation and Lyme meningitis presenting with progressive shortness of breath and DOE over past 2 weeks admitted to the MICU with pleural effusions and a pericardial effusion in the setting of presumed viral pleurisy and pericarditis that developed into an effusion after chronic NSAID use possible aspiration/CAP PNA who developed AFIB with RVR secondary to pain and pericardial effusion, transaminitis with cholestasis and acute renal failure in the setting of anemia and NSAID',
#  '26-27': 'Due to her effusions, it was thought she may have an underlying PNA and she was started on levaquin for CAP',
#  '26-29': '# Afib with RVR',
#  '26-30': 'On day of admission patient went to Afib',
#  '26-31': 'She received metroprolol IV and dilt drip',
#  '26-35': '- She will need to discuss with her outpatient physician [**Name9 (PRE) **] with aspirin',
#  '26-36': 'ID was consulted who recommended empiric coverage for CAP with a prolonged course of Levofloxacin ( 14 days',
#  '26-39': 'Cytology negative, cultures negative. Morphine and fentanyl pleuritic CP',
#  '26-42': 'Of note her effusions persisted despite antibiotic therapy and NSAID',
#  '26-44': 'She was given diuretics with lasix which did not reduced the size of her effusion',
#  '26-47': 'Patient was given IVF to maintain preload',
#  '26-49': 'She was restarted on NSAID therapy for viral pericarditis',
#  '26-51': '# CAP',
#  '26-52': 'She was given a two week course of levofloxacin',
#  '26-54': '# Diarrhea : She had transient episode of diarrhea while on antibiotics',
#  '26-56': 'Thought potentially from NSAIDs',
#  '26-57': 'She had low UOP , which improved with IVF',
#  '26-59': 'Medications on Admission: - ASPIRIN TAB 81MG EC ( ASPIRIN ) 1 QD Discharge Medications: 1. polyethylene glycol 3350 17 gram/dose Powder Sig: One (1) pack PO DAILY (Daily) as needed for constipation',
#  '26-74': 'Disp:*30 packets* Refills:*0* 2. levofloxacin 750 mg Tablet Sig: One (1) Tablet PO DAILY (Daily) for 4 days',
#  '26-82': 'Disp:*4 Tablet(s)* Refills:*0* 3. lidocaine 5 %(700 mg/patch) Adhesive Patch, Medicated Sig: One (1) Adhesive Patch, Medicated Topical DAILY (Daily)',
#  '26-89': 'Disp:*5 Adhesive Patch, Medicated(s)* Refills:*0* 4. ibuprofen 600 mg Tablet Sig: One (1) Tablet PO Q8H (every 8 hours)',
#  '26-96': '5. Colace 100 mg Capsule Sig: One (1) Capsule PO twice a day',
#  '26-103': '6. Benadryl 25 mg Capsule Sig: One (1) Capsule PO every six (6) hours as needed for Prior to Morphine : Please take before Morphine as needed for itching itching',
#  '26-114': 'Disp:*20 Capsule(s)* Refills:*0* 7. morphine 10 mg Capsule, Ext Release Pellets Sig: One (1) Capsule, Ext Release Pellets PO every six (6) hours as needed for pain',
#  '26-122': 'Your breathing has markedly improved and you are presently able to breathe without use of supplemental oxygen',
#  '26-123': '[**Name10 (NameIs) **] were started on an antibiotics and ibuprofen',
#  '26-125': 'The following medicaiton changes were made: ADDED: levaquin , ibuprofen , miralax , morphine , lidocaine patch , benadryl , morphine , colace STOPPED: aspirin Followup Instructions: Please visit your primary care physician for [**Name9 (PRE) 702**] bloodwork and to determine whether you will need to take more Lasix',
#  '27-0': 'ALLERGIES: Penicillin , which produces a rash',
#  '27-2': 'MEDICATIONS; 1. Toprol 100',
#  '27-4': '2. Lipitor 10 q.d',
#  '27-7': '3. Cardura 2 q.d',
#  '27-10': 'Subsequently the patient was transferred to the Intensive Care Unit and intubated for hypercapnic respiratory failure and was continually treated with Levofloxacin , steroids and nebulized Albuterol and Atrovent for this chronic obstructive pulmonary disease exacerbation',
#  '27-16': 'The patient completed a course of Levofloxacin',
#  '27-17': 'The patient also developed rapid atrial fibrillation during his Emergency Department course that was initially treated with Diltiazem',
#  '27-19': 'The patient was placed on Diltiazem drip and required intermittent boluses of Diltiazem',
#  '27-23': 'After extubation the patient was switched to po Metoprolol of which he was maintained as an outpatient for his known history of paroxysmal atrial fibrillation and supraventricular tachycardia',
#  '27-27': 'At the time of discharge the patient had been without pressers for several days and had his heart rate well controlled on b.i.d',
#  '27-29': 'At the time of discharge the patient had been without pressers for several days and had his heart rate well controlled on b.i.d. Metoprolol',
#  '27-30': 'The Gastroenterology Service was consulted and performed an endoscopy and discovered events of trauma from the nasogastric tube that was thought to be the cause of this self limited upper gastrointestinal bleed while on anticoagulation for the paroxysmal atrial fibrillation',
#  '27-32': "This hematuria was associated with a brief drop in the patient's hematocrit, which required 2 units of packed red blood cells",
#  '27-34': 'DISCHARGE MEDICATIONS: 1. Metoprolol',
#  '27-35': '2. Colace',
#  '27-36': '3. Bisacodyl',
#  '27-37': '4. Nicotine patch',
#  '27-39': '5. Doxazosin',
#  '27-40': '6. Albuterol',
#  '27-41': '7. Atrovent',
#  '27-42': 'Atrovent 8. Fluticasone',
#  '28-0': 'Name: [**Known lastname 447**],[**Known firstname **] [**Last Name (NamePattern1) 940**] Unit No: [**Numeric Identifier 941**] Admission Date: [**2193-10-15**] Discharge Date: [**2193-10-20**] Date of Birth: [**2110-4-2**] Sex: F Service: ORTHOPAEDICS Allergies: Percocet Attending:[**First Name3 (LF) 942**] Addendum: Please note that patient was discharged on metoprolol 50mg QID and not her home dose of propanolol',
#  '28-5': 'Patient also given 1 unit pRBCs on [**10-19**] for hct of 27',
#  '28-8': 'Discharge Medications: 1. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)',
#  '28-15': '2. Bisacody l 5 mg Tablet, Delayed Release (E.C.) Sig: Two (2) Tablet, Delayed Release (E.C.) PO DAILY (Daily) as needed for Constipation',
#  '28-23': '3. Senna 8.6 mg Tablet Sig: One (1) Tablet PO BID (2 times a day) as needed for Constipation',
#  '28-31': '4. Multivitamin Tablet Sig: One (1) Cap PO DAILY (Daily)',
#  '28-37': '5. Ferrous Sulfate 325 mg ( 65 mg Iron ) Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '28-46': '6. Calcium Carbonate 500 mg Tablet, Chewable Sig: One (1) Tablet , Chewable PO TID (3 times a day)',
#  '28-53': '7. Cholecalciferol (Vitamin D3) 400 unit Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '28-60': '8. Levothyroxine 75 mcg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '28-67': '9. Acetaminophen 325 mg Tablet Sig: Two (2) Tablet PO Q6H (every 6 hours) as needed for Pain',
#  '28-75': '10. Warfarin 2 mg Tablet Sig: One (1) Tablet PO Once Daily at 4 PM',
#  '28-82': '11. Lidocaine 5 %(700 mg/patch) Adhesive Patch, Medicated Sig: One (1) Adhesive Patch, Medicated Topical DAILY (Daily) as needed for pain',
#  '28-90': '12. Oxycodone 5 mg Tablet Sig: 0.5 Tablet PO Q4H (every 4 hours) as needed for pain',
#  '28-98': '13. Quetiapin e 25 mg Tablet Sig: 0.5 Tablet PO BID (2 times a day) as needed for distress',
#  '28-106': '14. Lorazepam 0.25 mg IV BID :PRN distress',
#  '28-111': 'Lorazepam 0.25 mg IV BID:PRN distress 15. Metoprolol Tartrate 50 mg Tablet Sig: One (1) Tablet PO QID (4 times a day)',
#  '28-118': 'As your pain improves, please decrease the amount of pain medication',
#  '28-119': 'This medication can cause constipation constipation , so you should drink plenty of water daily and take a stool softener (e.g., colace)',
#  '28-122': 'Please DO NOT take any NSAIDs',
#  '28-123': 'Please DO NOT take any NSAIDs (i.e. celebrex , ibuprofen , advil , motrin',
#  '28-127': '9. ANTICOAGULATION : Please continue coumadin',
#  '28-129': 'Staples out by Dr. [**Last Name (STitle) **] at 2 week post op visit. Coumadin daily',
#  '29-0': 'Admission Date: [**2122-9-22**] Discharge Date: [**2122-9-29**] Date of Birth: [**2059-1-8**] Sex: F Service: MEDICINE Allergies: Percocet / Motrin / Nsaids / Aspirin / Dilantin / Ativan',
#  '29-6': 'Her HR did increase to the 140s in the ED, responded to IV labetolol , but pressure dropped pressure dropped',
#  '29-11': 'This responded to IVF',
#  '29-12': 'She was given 250mg of levetiracetam',
#  '29-14': 'Thrombosis of bilateral IVJ (catheter placement)-- DVT associated with HD catheter RUE on anticoagulation (Coumadin)',
#  '29-16': '[**2122-9-29**] 01:30PM BLOOD WBC-6.4 RBC-3.28* Hgb-10.9* Hct-33.7* MCV-103* MCH-33.3* MCHC-32.4 RDW-16.6* Plt Ct-470* [**2122-9-29**] 01:30PM BLOOD Plt Ct-470* [**2122-9-29**] 01:30PM BLOOD PT-27.6* PTT-131.8* INR(PT)-2.8* [**2122-9-29**] 01:30PM BLOOD Glucose-134* UreaN-36* Creat-9.5*# Na-136 K-3.7 Cl-97 HCO3-26 AnGap-17 [**2122-9-29**] 01:30PM BLOOD Calcium-8.6 Phos-5.8* Mg-2.2 Brief Hospital Course: 1. Altered mental status',
#  '29-17': 'It is possible the Tylenol with codeine she was taking for post operative pain control',
#  '29-19': 'She was evaluated by neurology and was given Ativan and Depakote for complex partial seizure',
#  '29-22': 'Angioedema/respiratory failure: Her tongue was noted to be swollen prior to the administration of Depakote',
#  '29-23': 'The angioedema seemed to correlate with the Ativan',
#  '29-25': 'There is a report of angioedema angioedema in the past, attributed to Dilantin --but she received Ativan',
#  '29-29': 'She was treated for 24 hours with steroids',
#  '29-31': 'Her lisinopril',
#  ...}

# %%
import json
with open("test_sents_dict.txt", "w") as fp:
    json.dump(sents_dict, fp)  # encode dict into JSON

# %%
entity_df = pd.DataFrame(tags_list, columns=['text_id','entity_id','start','end','concept','entity','sent_num']).set_index('entity_id')

# %%
entity_df['concept'].unique()
# Out:
# array(['Drug', 'Reason', 'Route', 'Duration', 'Dosage', 'Form', 'ADE',
#        'Strength', 'Frequency'], dtype=object)

# %%
entity_df.to_csv('test_entity.csv', sep=',', encoding='utf-8')

# %%
'''
This is to generate relations to a specific format for one of my model, a relation triplet is formated as 
"start_position_1st_entity, end_position_1st_entity, start_position_2nd_entity, end_position_2nd_entity,
relation_type, 1st_entity_type, 2nd_entity_type" Each relation is concatenated by all the relation triplets
within the sentence, seperated by '|'
'''

relations = []
sents = []
for i, an in enumerate(tqdm(anno)):
    text = an.get_text()
    relation = ''
    entity_curr = entity_df[entity_df['text_id']==i]#['sent_num']
    curr_sent = 0
    relation_df = pd.DataFrame.from_dict(an.relations,orient='index')#.values()
    if relation_df.empty == True:
        continue
    relation_df['head_entity'] = relation_df[1].apply(lambda x: int(x[1]))
    relation_df = relation_df.sort_values(['head_entity']).drop('head_entity',axis = 1)
    for k in relation_df.values:
        if k[0][0] not in entity_curr.index or k[1][0] not in entity_curr.index:
            continue
        e1, e2, rel = entity_curr.loc[k[0][0]], entity_curr.loc[k[1][0]], k[2]

 

        if e1['sent_num'] != e2['sent_num']:
            continue
        if curr_sent == 0:
            relation = ' '.join([str(e1['start']), str(e1['end']), str(e2['start']), str(e2['end']),
                                   '/'+rel+'/'+k[0][3]+'/'+k[1][3], '|'])
            curr_sent = e1['sent_num']
        elif e1['sent_num'] == curr_sent:           
            relation = ' '.join([relation, str(e1['start']), str(e1['end']), str(e2['start']), str(e2['end']),
                                   '/'+rel+'/'+k[0][3]+'/'+k[1][3], '|'])
        else:
            #print(curr_sent)
            relations.append(relation[:-2])  
            sents.append(sents_dict[curr_sent])
            curr_sent = e1['sent_num']
            relation = ' '.join([str(e1['start']), str(e1['end']), str(e2['start']), str(e2['end']),
                                   '/'+rel+'/'+k[0][3]+'/'+k[1][3],'|'])
    if curr_sent == 0:
        continue
    relations.append(relation[:-2])  
    sents.append(sents_dict[curr_sent])
# Out:
#   0%|          | 0/202 [00:00<?, ?it/s]

# %%
relations[0]
# Out:
# '31 33 20 21 /Reason-Drug/Reason/Drug'

# %%
import re
print(re.findall('\d+', relations[3]))
# Out:
# ['17', '19', '20', '21', '6', '10', '20', '21', '17', '19', '22', '23', '6', '10', '22', '23']

# %%
i_relation = relations[0].split("| ")
sample = []
for i in i_relation:
    relation_sample = []
    relation_sample.append((int(i.split(" ")[0]),int(i.split(" ")[1])))
    relation_sample.append((int(i.split(" ")[2]),int(i.split(" ")[3])))
    relation_sample.append(i.split(" ")[4].split("/")[1])
    sample.append(relation_sample)
print(sample)
# Out:
# [[(31, 33), (20, 21), 'Reason-Drug']]

# %%
sents[0].split()
# Out:
# ['The',
#  'patient',
#  'has',
#  'long',
#  'been',
#  'awaiting',
#  'repair',
#  'of',
#  'a',
#  'large',
#  'inguinal',
#  'hernia',
#  'and',
#  'ventral',
#  'hernia',
#  'and',
#  'had',
#  'stopped',
#  'taking',
#  'his',
#  'coumadin',
#  '10',
#  'days',
#  'prior',
#  'to',
#  'presentation',
#  '(he',
#  'is',
#  'on',
#  'this',
#  'for',
#  'atrial',
#  'fibrillation']

# %%
relation_data = []
for i in range(len(sents)):
    sample = []
    sample.append(sents[i].split())
    i_relation = relations[i].split("| ")
    i_sample = []
    for i in i_relation:
        relation_sample = []
        relation_sample.append((int(i.split(" ")[0]),int(i.split(" ")[1])))
        relation_sample.append((int(i.split(" ")[2]),int(i.split(" ")[3])))
        relation_sample.append(i.split(" ")[4].split("/")[1])
        i_sample.append(relation_sample)
    sample.append(i_sample)
    relation_data.append(sample)

# %%
relation_data[4]
# Out:
# [['Attempts',
#   'were',
#   'made',
#   'to',
#   'slow',
#   'accumulation',
#   'of',
#   'fluid',
#   'with',
#   'medical',
#   'therapies',
#   'including',
#   'octreotide'],
#  [[(4, 8), (12, 13), 'Reason-Drug']]]

# %%
import json
with open("test_relation.txt", "w") as fp:
    json.dump(relation_data, fp)
