# %%
import os
from tqdm.notebook import tqdm
import glob
import numpy as np
import pandas as pd
import random
from collections import defaultdict
from nltk.tokenize import sent_tokenize, word_tokenize

# %% [markdown]
# # Read files and annotations

# %%
#This class is provided by i2b2 challenge. I use its functions to get annotations and text

class RecordTrack2(object):
    """Record for Track 2 class."""

    def __init__(self, file_path):
        """Initialize."""
        self.path = os.path.abspath(file_path)
        self.basename = os.path.basename(self.path)
        self.annotations = self._get_annotations()
        # self.text = self._get_text()

    @property
    def tags(self):
        return self.annotations['tags']

    @property
    def relations(self):
        return self.annotations['relations']

    def _get_annotations(self):
        """Return a dictionary with all the annotations in the .ann file."""
        annotations = defaultdict(dict)
        with open(self.path) as annotation_file:
            lines = annotation_file.readlines()
            for line_num, line in enumerate(lines):
                if line.strip().startswith('T'):
                    try:
                        tag_id, tag_m, tag_text = line.strip().split('\t')
                    except ValueError:
                        print(self.path, line)
                    if len(tag_m.split(' ')) == 3:
                        tag_type, tag_start, tag_end = tag_m.split(' ')
                    elif len(tag_m.split(' ')) == 4:
                        tag_type, tag_start, _, tag_end = tag_m.split(' ')
                    elif len(tag_m.split(' ')) == 5:
                        tag_type, tag_start, _, _, tag_end = tag_m.split(' ')
                    else:
                        print(self.path)
                        print(line)
                    tag_start, tag_end = int(tag_start), int(tag_end)
                    annotations['tags'][tag_id] = (tag_id, tag_start ,tag_end, tag_type, tag_text)
            for line_num, line in enumerate(lines):
                if line.strip().startswith('R'):
                    rel_id, rel_m = line.strip().split('\t')
                    rel_type, rel_arg1, rel_arg2 = rel_m.split(' ')
                    rel_arg1 = rel_arg1.split(':')[1]
                    rel_arg2 = rel_arg2.split(':')[1]
                    arg1 = annotations['tags'][rel_arg1]
                    arg2 = annotations['tags'][rel_arg2]
                    annotations['relations'][rel_id] = (arg1,arg2, rel_type)
        return annotations

    def get_text(self):
        """Return the text in the corresponding txt file."""
        path = self.path.replace('.ann', '.txt')
        with open(path) as text_file:
            text = text_file.read()
        return text

# %%
#reading data and create a list of RecordTrack2 class for each file
folder1 = 'training_20180910/'
anno = []
files1 = set([os.path.basename(f) for f in glob.glob(
    os.path.join(folder1, '*.ann'))])
for file in files1:
    anno.append(RecordTrack2(os.path.join(folder1, file)))

# %% [markdown]
# # Generate entities within sentence
#
# Find the offset of each entity within that sentence.
#
# The offset provided by i2b2 is aginst the whole file.
#
# In this section, we will locate the entity, tokenise sentense, and remove extra spaces
#
# The offset I generated in this section is word offset (created by len(text.split()), feel free to change to character offset if needed.

# %%
#function to generate the first entity in a sentence
def first_entity(text, start, end, entity):
        text_before = sent_tokenize(text[:start]) #all the text befere the start of the entity
        sent_num = len(text_before)
        word_before = text_before[-1].split() #words before entity in the current sentence 
        word_start = len(word_before) #start position
        word_end = word_start+len(entity.split()) #end position
        sent_after = sent_tokenize(text[end:])[0] #the left of current sentence
        sent_piece = ' '.join(word_before + entity.split()) #current sentence until the end of first entity, extra spaces removed by .split()
        return word_start, word_end, sent_after, sent_piece

# %%
#function to generate non-first entity in a sentence, same logic sa first_entity function
def entity_within_sent(text, word_end_before, end_before, start, end, entity):
    word_between = text[end_before:start].split()
    word_start = word_end_before + len(word_between)
    word_end = word_start+len(entity.split())
    sent_after = sent_tokenize(text[end:])[0]
    #print(sent_after)
    sent_piece = ' '.join(word_between + entity.split())
    return word_start, word_end, sent_after, sent_piece

# %%
tags_list = []
sents_dict = {}
for i, an in enumerate(tqdm(anno)):
    text = an.get_text()
    tags = pd.DataFrame(an.tags.values()).sort_values(1).values
    #skip used to mark how many entities we have processed within the previous sentence
    skip = 0
    for j, (en_id, start, end, concept, entity) in enumerate(tags):
        #we skip the entities we have processed from last sentence, it will bring us to the first entity in current sentence
        if skip>0:
            skip -= 1
            continue
        #remove entities that across sentences
        if len(sent_tokenize(text[start:end]))>1:
            continue
        word_start, word_end, sent_after, sent_piece = first_entity(text, start, end, entity)
        #'-'.join([str(i),str(j)]) is an unique idenfitier for each sentence in the dataset, 
        #i identify the document and j identify the sentence within the document
        tags_list.append([i, en_id, word_start, word_end, concept, entity, '-'.join([str(i),str(j)])])
        while j+skip+1<len(tags) and end+len(sent_after)>= tags[j+skip+1][1]:
            anno_curr = tags[j+skip+1]
            word_end_before = word_end
            end_before = end
            sent_piece_before = sent_piece
            en_id = anno_curr[0]
            start = anno_curr[1]
            end = anno_curr[2]
            concept = anno_curr[3]
            entity = anno_curr[4]
            word_start, word_end, sent_after, sent_piece = entity_within_sent(text, word_end_before, end_before, start, end, entity)
            sent_piece = ' '. join([sent_piece_before, sent_piece])
            tags_list.append([i, en_id, word_start, word_end, concept, entity, '-'.join([str(i),str(j)])])
            skip += 1
        sents_dict['-'.join([str(i),str(j)])] = sent_piece
# Out:
#   0%|          | 0/303 [00:00<?, ?it/s]

# %%
tags_list
# Out:
# [[0, 'T29', 12, 13, 'Reason', 'headache', '0-0'],
#  [0, 'T12', 18, 19, 'Drug', 'ibuprofen', '0-0'],
#  [0, 'T31', 3, 4, 'Reason', 'HIV', '0-2'],
#  [0, 'T30', 5, 6, 'Drug', 'HAART', '0-3'],
#  [0, 'T7', 15, 16, 'Drug', 'Bactrim', '0-4'],
#  [0, 'T32', 17, 20, 'Reason', 'Pneumocystis carinii prophylaxis', '0-4'],
#  [0, 'T3', 4, 5, 'Drug', 'Bactrim', '0-6'],
#  [0, 'T6', 6, 7, 'Drug', 'acyclovir', '0-6'],
#  [0, 'T46', 5, 6, 'Drug', 'potassium', '0-8'],
#  [0, 'T47', 13, 14, 'Drug', 'creatinine', '0-8'],
#  [0, 'T45', 15, 16, 'Drug', 'glucose', '0-8'],
#  [0, 'T33', 10, 11, 'Route', 'intravenous', '0-11'],
#  [0, 'T22', 11, 12, 'Drug', 'Bactrim', '0-11'],
#  [0, 'T15', 13, 14, 'Drug', 'prednisone', '0-11'],
#  [0, 'T34', 16, 19, 'Reason', 'possible PCP infection', '0-11'],
#  [0, 'T19', 20, 21, 'Drug', 'levofloxacin', '0-11'],
#  [0, 'T35', 23, 25, 'Reason', 'community-acquired pneumonia', '0-11'],
#  [0, 'T36', 10, 11, 'Drug', 'morphine', '0-17'],
#  [0, 'T25', 12, 13, 'Drug', 'pantoprazole', '0-17'],
#  [0, 'T5', 14, 15, 'Drug', 'zolpidem', '0-17'],
#  [0, 'T13', 17, 18, 'Drug', 'heparin', '0-17'],
#  [0, 'T37', 3, 4, 'Reason', 'sedated', '0-21'],
#  [0, 'T23', 5, 6, 'Drug', 'Fentanyl', '0-21'],
#  [0, 'T2', 7, 8, 'Drug', 'lorazepam', '0-21'],
#  [0, 'T14', 11, 12, 'Drug', 'nicotine', '0-21'],
#  [0, 'T20', 1, 2, 'Drug', 'Bactrim', '0-25'],
#  [0, 'T38', 9, 13, 'ADE', 'adult respiratory distress syndrome', '0-25'],
#  [0, 'T17', 14, 15, 'Drug', 'Bactrim', '0-25'],
#  [0, 'T48', 17, 19, 'Dosage', 'four liters', '0-28'],
#  [0, 'T50', 20, 21, 'Drug', 'oxygen', '0-28'],
#  [0, 'T49', 22, 24, 'Route', 'nasal cannula', '0-28'],
#  [0, 'T39', 14, 15, 'ADE', 'agitation', '0-31'],
#  [0, 'T40', 16, 17, 'ADE', 'hallucinations', '0-31'],
#  [0, 'T41', 18, 19, 'ADE', 'tachypnea', '0-31'],
#  [0, 'T18', 29, 30, 'Drug', 'Fentanyl', '0-31'],
#  [0, 'T42', 7, 9, 'Reason', 'oral thrush', '0-35'],
#  [0, 'T9', 15, 16, 'Drug', 'Nystatin', '0-35'],
#  [0, 'T16', 12, 13, 'Drug', 'Dapsone', '0-37'],
#  [0, 'T43', 14, 16, 'Reason', 'PCP prophylaxis', '0-37'],
#  [0, 'T44', 22, 29, 'ADE', 'rash on both arms and the back', '0-37'],
#  [0, 'T4', 1, 2, 'Drug', 'Dapsone', '0-40'],
#  [0, 'T24', 10, 11, 'Drug', 'Bactrim', '0-40'],
#  [0, 'T8', 13, 14, 'Drug', 'Dapsone', '0-40'],
#  [0, 'T1', 10, 11, 'Drug', 'prednisone', '0-43'],
#  [0, 'T10', 13, 14, 'Drug', 'nicotine', '0-43'],
#  [0, 'T11', 14, 15, 'Form', 'patch', '0-43'],
#  [0, 'T51', 31, 32, 'Drug', 'HAART', '0-46'],
#  [0, 'T21', 5, 6, 'Drug', 'Nystatin', '0-47'],
#  [0, 'T26', 7, 8, 'Drug', 'nicotine', '0-47'],
#  [0, 'T27', 8, 9, 'Form', 'patches', '0-47'],
#  [1, 'T9', 15, 16, 'Drug', 'Propoxyphene', '1-0'],
#  [1, 'T22', 17, 18, 'Drug', 'Pyridium', '1-0'],
#  [1, 'T27', 19, 20, 'Drug', 'Bupropion', '1-0'],
#  [1, 'T68', 21, 22, 'Drug', 'Darvon', '1-0'],
#  [1, 'T120', 23, 24, 'Drug', 'Penicillins', '1-0'],
#  [1, 'T209', 25, 26, 'Drug', 'Claritin', '1-0'],
#  [1, 'T227', 27, 28, 'Drug', 'Codeine', '1-0'],
#  [1, 'T229', 29, 30, 'Drug', 'Moexipril', '1-0'],
#  [1, 'T24', 3, 4, 'Drug', 'toradol', '1-8'],
#  [1, 'T25', 4, 5, 'Strength', '15mg', '1-8'],
#  [1, 'T13', 5, 6, 'Route', 'IV', '1-8'],
#  [1, 'T28', 7, 8, 'Reason', 'pain', '1-8'],
#  [1, 'T179', 3, 4, 'Reason', 'wheeze', '1-12'],
#  [1, 'T199', 9, 10, 'Drug', 'solumedrol', '1-12'],
#  [1, 'T228', 19, 21, 'Drug', 'racemic epi', '1-14'],
#  [1, 'T230', 5, 6, 'Reason', 'HTN', '1-15'],
#  [1, 'T231', 11, 12, 'Drug', 'HCTZ', '1-15'],
#  [1, 'T1', 6, 7, 'Drug', 'vancomycin', '1-17'],
#  [1, 'T2', 8, 9, 'Drug', 'flagyl', '1-17'],
#  [1, 'T3', 10, 11, 'Drug', 'levofloxacin', '1-17'],
#  [1, 'T4', 5, 6, 'Drug', 'solumedrol', '1-20'],
#  [1, 'T5', 7, 8, 'Drug', "MDI's", '1-20'],
#  [1, 'T6', 16, 17, 'Reason', 'stridor', '1-22'],
#  [1, 'T7', 18, 19, 'Reason', 'wheezing', '1-22'],
#  [1, 'T8', 26, 28, 'Drug', 'racemic epi', '1-22'],
#  [1, 'T10', 10, 11, 'Reason', 'pain', '1-25'],
#  [1, 'T11', 4, 5, 'Drug', 'morphine', '1-26'],
#  [1, 'T14', 9, 10, 'Drug', 'morphine', '1-27'],
#  [1, 'T15', 11, 13, 'Reason', 'pain control', '1-27'],
#  [1, 'T16', 2, 3, 'Reason', 'PNEUMONIA', '1-29'],
#  [1, 'T17', 9, 10, 'Reason', 'pneumonia', '1-30'],
#  [1, 'T18', 11, 12, 'Drug', 'levo', '1-30'],
#  [1, 'T19', 13, 14, 'Drug', 'flagyl', '1-30'],
#  [1, 'T20', 15, 16, 'Drug', 'vancomycin', '1-30'],
#  [1, 'T21', 1, 2, 'Drug', 'antibiotic', '1-34'],
#  [1, 'T23', 1, 2, 'Route', 'IV', '1-35'],
#  [1, 'T12', 2, 3, 'Drug', 'hydration', '1-35'],
#  [1, 'T29', 9, 12, 'Reason', 'peptic ulcer disease', '1-37'],
#  [1, 'T30', 5, 6, 'Drug', 'PPI', '1-38'],
#  [1, 'T31', 1, 2, 'ADE', 'diarrhea', '1-39'],
#  [1, 'T32', 9, 10, 'Drug', 'antibiotics', '1-39'],
#  [1, 'T33', 6, 7, 'Route', 'SC', '1-41'],
#  [1, 'T34', 7, 8, 'Drug', 'heparin', '1-41'],
#  [1, 'T35', 12, 13, 'Drug', 'PPI', '1-41'],
#  [1, 'T36', 3, 4, 'Drug', 'HCTZ', '1-44'],
#  [1, 'T37', 4, 5, 'Strength', '25', '1-44'],
#  [1, 'T38', 5, 6, 'Frequency', 'qd', '1-44'],
#  [1, 'T39', 6, 7, 'Drug', 'Pantoprazole', '1-44'],
#  [1, 'T40', 7, 8, 'Strength', '40', '1-44'],
#  [1, 'T41', 8, 9, 'Frequency', 'qd', '1-44'],
#  [1, 'T42', 9, 10, 'Drug', 'Paxil', '1-44'],
#  [1, 'T43', 10, 11, 'Strength', '12.5', '1-44'],
#  [1, 'T44', 11, 12, 'Frequency', 'qd', '1-44'],
#  [1, 'T45', 12, 13, 'Drug', 'Senna', '1-44'],
#  [1, 'T46', 13, 14, 'Frequency', 'PRN', '1-44'],
#  [1, 'T47', 14, 15, 'Drug', 'ASA', '1-44'],
#  [1, 'T48', 15, 16, 'Strength', '81', '1-44'],
#  [1, 'T49', 16, 17, 'Frequency', 'QD', '1-44'],
#  [1, 'T50', 23, 27, 'Drug', 'Ca + Vit D', '1-44'],
#  [1, 'T51', 27, 28, 'Drug', 'MVI', '1-44'],
#  [1, 'T52', 33, 35, 'Drug', 'Paroxetine HCl', '1-60'],
#  [1, 'T53', 35, 37, 'Strength', '10 mg', '1-60'],
#  [1, 'T54', 37, 38, 'Form', 'Tablet', '1-60'],
#  [1, 'T55', 39, 41, 'Dosage', 'One (1)', '1-60'],
#  [1, 'T56', 41, 42, 'Form', 'Tablet', '1-60'],
#  [1, 'T57', 42, 43, 'Route', 'PO', '1-60'],
#  [1, 'T58', 43, 44, 'Frequency', 'QD', '1-60'],
#  [1, 'T59', 4, 6, 'Drug', 'Zolpidem Tartrate', '1-67'],
#  [1, 'T60', 6, 8, 'Strength', '5 mg', '1-67'],
#  [1, 'T61', 8, 9, 'Form', 'Tablet', '1-67'],
#  [1, 'T62', 10, 12, 'Dosage', 'One (1)', '1-67'],
#  [1, 'T63', 12, 13, 'Form', 'Tablet', '1-67'],
#  [1, 'T64', 13, 14, 'Route', 'PO', '1-67'],
#  [1, 'T65', 14, 15, 'Frequency', 'HS', '1-67'],
#  [1, 'T66', 4, 5, 'Drug', 'Camphor-Menthol', '1-74'],
#  [1, 'T67', 5, 6, 'Strength', '0.5-0.5', '1-74'],
#  [1, 'T69', 7, 8, 'Form', 'Lotion', '1-74'],
#  [1, 'T70', 9, 11, 'Dosage', 'One (1)', '1-74'],
#  [1, 'T71', 11, 12, 'Form', 'Appl', '1-74'],
#  [1, 'T72', 12, 13, 'Route', 'Topical', '1-74'],
#  [1, 'T73', 13, 14, 'Frequency', 'QID', '1-74'],
#  [1, 'T74', 4, 6, 'Drug', 'Salmeterol Xinafoate', '1-81'],
#  [1, 'T75', 6, 8, 'Strength', '50 mcg/Dose', '1-81'],
#  [1, 'T76', 8, 11, 'Form', 'Disk with Device', '1-81'],
#  [1, 'T77', 12, 14, 'Dosage', 'One (1)', '1-81'],
#  [1, 'T78', 14, 15, 'Form', 'INH', '1-81'],
#  [1, 'T79', 15, 16, 'Route', 'Inhalation', '1-81'],
#  [1, 'T80', 16, 17, 'Frequency', 'Q12H', '1-81'],
#  [1, 'T81', 4, 6, 'Drug', 'Ipratropium Bromide', '1-88'],
#  [1, 'T82', 6, 7, 'Strength', '0.02', '1-88'],
#  [1, 'T83', 8, 9, 'Form', 'Solution', '1-88'],
#  [1, 'T84', 10, 12, 'Dosage', 'One (1)', '1-88'],
#  [1, 'T85', 12, 13, 'Form', 'INH', '1-88'],
#  [1, 'T86', 13, 14, 'Route', 'Inhalation', '1-88'],
#  [1, 'T87', 14, 15, 'Frequency', 'Q4H', '1-88'],
#  [1, 'T88', 19, 20, 'Drug', 'albuterol', '1-88'],
#  [1, 'T89', 20, 21, 'Form', 'nebs', '1-88'],
#  [1, 'T90', 4, 6, 'Drug', 'Sodium Chloride', '1-97'],
#  [1, 'T91', 6, 7, 'Strength', '0.65', '1-97'],
#  [1, 'T92', 8, 10, 'Form', 'Aerosol, Spray', '1-97'],
#  [1, 'T93', 12, 13, 'Form', 'Sprays', '1-97'],
#  [1, 'T94', 13, 14, 'Route', 'Nasal', '1-97'],
#  [1, 'T95', 14, 15, 'Frequency', 'TID', '1-97'],
#  [1, 'T96', 4, 6, 'Drug', 'Metoprolol Tartrate', '1-103'],
#  [1, 'T97', 6, 8, 'Strength', '25 mg', '1-103'],
#  [1, 'T98', 8, 9, 'Form', 'Tablet', '1-103'],
#  [1, 'T99', 10, 11, 'Dosage', '0.5', '1-103'],
#  [1, 'T100', 11, 12, 'Form', 'Tablet', '1-103'],
#  [1, 'T101', 12, 13, 'Route', 'PO', '1-103'],
#  [1, 'T102', 13, 14, 'Frequency', 'TID', '1-103'],
#  [1, 'T103', 1, 2, 'Dosage', '45', '1-110'],
#  [1, 'T104', 2, 3, 'Form', 'Tablet', '1-110'],
#  [1, 'T105', 4, 6, 'Drug', 'Isosorbide Dinitrate', '1-112'],
#  [1, 'T106', 6, 8, 'Strength', '20 mg', '1-112'],
#  [1, 'T107', 8, 9, 'Form', 'Tablet', '1-112'],
#  [1, 'T108', 10, 12, 'Dosage', 'Two (2)', '1-112'],
#  [1, 'T109', 12, 13, 'Form', 'Tablet', '1-112'],
#  [1, 'T110', 13, 14, 'Route', 'PO', '1-112'],
#  [1, 'T111', 14, 15, 'Frequency', 'TID', '1-112'],
#  [1, 'T112', 4, 6, 'Drug', 'Albuterol Sulfate', '1-119'],
#  [1, 'T113', 6, 7, 'Strength', '0.083', '1-119'],
#  [1, 'T114', 8, 9, 'Form', 'Solution', '1-119'],
#  [1, 'T115', 10, 12, 'Dosage', 'One (1)', '1-119'],
#  [1, 'T116', 12, 13, 'Form', 'INH', '1-119'],
#  [1, 'T117', 13, 14, 'Route', 'Inhalation', '1-119'],
#  [1, 'T118', 14, 15, 'Frequency', 'Q3H', '1-119'],
#  [1, 'T119', 4, 5, 'Drug', 'Multivitamin', '1-126'],
#  [1, 'T121', 5, 6, 'Form', 'Capsule', '1-126'],
#  [1, 'T122', 7, 9, 'Dosage', 'One (1)', '1-126'],
#  [1, 'T123', 9, 10, 'Form', 'Cap', '1-126'],
#  [1, 'T124', 10, 11, 'Route', 'PO', '1-126'],
#  [1, 'T125', 11, 12, 'Frequency', 'QD', '1-126'],
#  [1, 'T126', 4, 5, 'Drug', 'Bisacodyl', '1-132'],
#  [1, 'T127', 5, 7, 'Strength', '5 mg', '1-132'],
#  [1, 'T128', 7, 11, 'Form', 'Tablet, Delayed Release (E.C.)', '1-132'],
#  [1, 'T129', 12, 14, 'Dosage', 'Two (2)', '1-132'],
#  [1, 'T130', 14, 18, 'Form', 'Tablet, Delayed Release (E.C.)', '1-132'],
#  [1, 'T131', 18, 19, 'Route', 'PO', '1-132'],
#  [1, 'T132', 19, 20, 'Frequency', 'DAILY', '1-132'],
#  [1, 'T133', 24, 25, 'Reason', 'constipation', '1-132'],
#  [1, 'T134', 3, 5, 'Drug', 'Bismuth Subsalicylate', '1-140'],
#  [1, 'T135', 5, 8, 'Strength', '262 mg/15 mL', '1-140'],
#  [1, 'T136', 8, 9, 'Form', 'Suspension', '1-140'],
#  [1, 'T137', 10, 12, 'Dosage', 'Fifteen (15)', '1-140'],
#  [1, 'T138', 12, 13, 'Form', 'ML', '1-140'],
#  [1, 'T139', 13, 14, 'Route', 'PO', '1-140'],
#  [1, 'T140', 14, 15, 'Frequency', 'TID', '1-140'],
#  [1, 'T141', 22, 23, 'Reason', 'diarrhea', '1-140'],
#  [1, 'T142', 4, 5, 'Drug', 'Ibuprofen', '1-148'],
#  [1, 'T143', 5, 7, 'Strength', '400 mg', '1-148'],
#  [1, 'T144', 7, 8, 'Form', 'Tablet', '1-148'],
#  [1, 'T145', 9, 11, 'Dosage', 'One (1)', '1-148'],
#  [1, 'T146', 11, 12, 'Form', 'Tablet', '1-148'],
#  [1, 'T147', 12, 13, 'Route', 'PO', '1-148'],
#  [1, 'T148', 13, 14, 'Frequency', 'Q8H', '1-148'],
#  [1, 'T149', 4, 6, 'Drug', 'Pantoprazole Sodium', '1-155'],
#  [1, 'T150', 6, 8, 'Strength', '40 mg', '1-155'],
#  [1, 'T151', 8, 12, 'Form', 'Tablet, Delayed Release (E.C.)', '1-155'],
#  [1, 'T152', 13, 15, 'Dosage', 'One (1)', '1-155'],
#  [1, 'T153', 15, 19, 'Form', 'Tablet, Delayed Release (E.C.)', '1-155'],
#  [1, 'T154', 19, 20, 'Route', 'PO', '1-155'],
#  [1, 'T155', 20, 21, 'Frequency', 'Q12H', '1-155'],
#  [1, 'T156', 3, 4, 'Drug', 'Guaifenesin', '1-162'],
#  [1, 'T157', 4, 7, 'Strength', '100 mg/5 mL', '1-162'],
#  [1, 'T158', 7, 8, 'Form', 'Syrup', '1-162'],
#  [1, 'T159', 9, 10, 'Dosage', '5-10', '1-162'],
#  [1, 'T160', 10, 11, 'Form', 'MLs', '1-162'],
#  [1, 'T161', 11, 12, 'Route', 'PO', '1-162'],
#  [1, 'T162', 12, 13, 'Frequency', 'Q6H', '1-162'],
#  [1, 'T163', 4, 5, 'Drug', 'Phenergan', '1-169'],
#  [1, 'T164', 5, 7, 'Strength', '25 mg/mL', '1-169'],
#  [1, 'T165', 7, 8, 'Form', 'Solution', '1-169'],
#  [1, 'T166', 9, 12, 'Dosage', 'Twenty Five (25)', '1-169'],
#  [1, 'T167', 12, 13, 'Form', 'MG', '1-169'],
#  [1, 'T168', 13, 14, 'Route', 'Injection', '1-169'],
#  [1, 'T169', 14, 17, 'Frequency', 'Q4-6H:PRN as needed', '1-169'],
#  [1, 'T170', 18, 19, 'Reason', 'nausea', '1-169'],
#  [1, 'T171', 4, 6, 'Drug', 'Morphine Sulfate', '1-177'],
#  [1, 'T172', 6, 8, 'Strength', '2 mg/mL', '1-177'],
#  [1, 'T173', 8, 9, 'Form', 'Syringe', '1-177'],
#  [1, 'T174', 10, 11, 'Dosage', '1-2', '1-177'],
#  [1, 'T175', 11, 12, 'Form', 'MG', '1-177'],
#  [1, 'T176', 12, 13, 'Route', 'Injection', '1-177'],
#  [1, 'T177', 13, 16, 'Frequency', 'Q2H:PRN as needed', '1-177'],
#  [1, 'T178', 17, 18, 'Reason', 'pain', '1-177'],
#  [1, 'T180', 4, 6, 'Drug', 'Roxanol Concentrate', '1-185'],
#  [1, 'T181', 6, 8, 'Strength', '20 mg/mL', '1-185'],
#  [1, 'T182', 8, 9, 'Form', 'Solution', '1-185'],
#  [1, 'T183', 10, 11, 'Dosage', '10-30', '1-185'],
#  [1, 'T184', 11, 12, 'Form', 'MG', '1-185'],
#  [1, 'T185', 12, 13, 'Route', 'PO', '1-185'],
#  [1, 'T186', 13, 16, 'Frequency', 'Q4H:PRN as needed', '1-185'],
#  [1, 'T187', 17, 18, 'Reason', 'pain', '1-185'],
#  [1, 'T188', 4, 5, 'Drug', 'Ativan', '1-193'],
#  [1, 'T189', 5, 7, 'Strength', '2 mg/mL', '1-193'],
#  [1, 'T190', 7, 8, 'Form', 'Syringe', '1-193'],
#  [1, 'T191', 9, 10, 'Dosage', '0.5-1', '1-193'],
#  [1, 'T192', 10, 11, 'Form', 'MG', '1-193'],
#  [1, 'T193', 11, 12, 'Route', 'Injection', '1-193'],
#  [1, 'T194', 12, 13, 'Frequency', 'Q4-6H:PRN', '1-193'],
#  [1, 'T195', 4, 5, 'Drug', 'Ativan', '1-200'],
#  [1, 'T196', 5, 7, 'Strength', '0.5 mg', '1-200'],
#  [1, 'T197', 7, 8, 'Form', 'Tablet', '1-200'],
#  [1, 'T198', 9, 10, 'Dosage', '0.5-1', '1-200'],
#  [1, 'T200', 10, 11, 'Form', 'MG', '1-200'],
#  [1, 'T201', 11, 12, 'Route', 'PO', '1-200'],
#  [1, 'T202', 12, 13, 'Frequency', 'Q4-6H:PRN', '1-200'],
#  [1, 'T203', 4, 5, 'Drug', 'Colace', '1-207'],
#  [1, 'T204', 5, 7, 'Strength', '100 mg', '1-207'],
#  [1, 'T205', 7, 8, 'Form', 'Capsule', '1-207'],
#  [1, 'T206', 9, 11, 'Dosage', 'One (1)', '1-207'],
#  [1, 'T207', 11, 12, 'Form', 'Capsule', '1-207'],
#  [1, 'T208', 12, 13, 'Route', 'PO', '1-207'],
#  [1, 'T210', 13, 16, 'Frequency', 'once a day', '1-207'],
#  [1, 'T211', 4, 5, 'Drug', 'Senna', '1-214'],
#  [1, 'T212', 5, 7, 'Strength', '8.6 mg', '1-214'],
#  [1, 'T213', 7, 8, 'Form', 'Capsule', '1-214'],
#  [1, 'T214', 9, 11, 'Dosage', 'Two (2)', '1-214'],
#  [1, 'T215', 11, 12, 'Form', 'Capsule', '1-214'],
#  [1, 'T216', 12, 13, 'Route', 'PO', '1-214'],
#  [1, 'T217', 13, 16, 'Frequency', 'BID:PRN as needed', '1-214'],
#  [1, 'T218', 17, 18, 'Reason', 'constipation', '1-214'],
#  [1, 'T219', 4, 5, 'Drug', 'Dulcolax', '1-222'],
#  [1, 'T220', 5, 7, 'Strength', '10 mg', '1-222'],
#  [1, 'T221', 7, 8, 'Form', 'Suppository', '1-222'],
#  [1, 'T222', 9, 11, 'Dosage', 'Ten (10)', '1-222'],
#  [1, 'T223', 11, 12, 'Form', 'mg', '1-222'],
#  [1, 'T224', 12, 13, 'Route', 'Rectal', '1-222'],
#  [1, 'T225', 13, 16, 'Frequency', 'QD:PRN as needed', '1-222'],
#  [1, 'T226', 17, 18, 'Reason', 'constipation', '1-222'],
#  [2, 'T23', 15, 16, 'Drug', 'Cefepime', '2-0'],
#  [2, 'T46', 3, 4, 'Route', 'IV', '2-1'],
#  [2, 'T4', 4, 5, 'Drug', 'hydration', '2-1'],
#  [2, 'T180', 12, 14, 'Dosage', '1 unit', '2-3'],
#  [2, 'T181', 14, 15, 'Drug', 'pRBC', '2-3'],
#  [2, 'T182', 7, 10, 'Reason', 'pulmonary vascular congestion', '2-5'],
#  [2, 'T33', 6, 7, 'Drug', 'Lasix', '2-6'],
#  [2, 'T183', 2, 3, 'Reason', 'empirically', '2-7'],
#  [2, 'T87', 5, 6, 'Drug', 'vanc', '2-7'],
#  [2, 'T15', 7, 8, 'Drug', 'zosyn', '2-7'],
#  [2, 'T185', 5, 6, 'Drug', 'antibiotics', '2-10'],
#  [2, 'T184', 9, 10, 'Drug', 'vanc', '2-10'],
#  [2, 'T59', 11, 12, 'Drug', 'Cipro', '2-10'],
#  [2, 'T70', 13, 14, 'Drug', 'cefepime', '2-10'],
#  [2, 'T186', 16, 19, 'Reason', 'hospital acquired pneumonia', '2-10'],
#  [2, 'T88', 3, 5, 'Dosage', '2 units', '2-15'],
#  [2, 'T89', 6, 7, 'Drug', "pRBC's", '2-15'],
#  [2, 'T22', 5, 6, 'Drug', 'Lasix', '2-17'],
#  [2, 'T187', 6, 7, 'Dosage', 'boluses', '2-17'],
#  [2, 'T188', 12, 13, 'Reason', 'diuresis', '2-17'],
#  [2, 'T45', 6, 7, 'Strength', '20mg', '2-20'],
#  [2, 'T90', 7, 8, 'Route', 'PO', '2-20'],
#  [2, 'T44', 8, 9, 'Drug', 'Lasix', '2-20'],
#  [2, 'T91', 9, 10, 'Frequency', 'daily', '2-20'],
#  [2, 'T92', 13, 14, 'Strength', '40mg', '2-20'],
#  [2, 'T173', 14, 15, 'Route', 'IV', '2-20'],
#  [2, 'T58', 15, 16, 'Drug', 'Lasix', '2-20'],
#  [2, 'T75', 22, 23, 'Drug', 'Diamox', '2-20'],
#  [2, 'T189', 10, 11, 'Reason', 'hypotensive', '2-28'],
#  [2, 'T190', 13, 14, 'Dosage', '2.5L', '2-28'],
#  [2, 'T191', 15, 16, 'Drug', 'fluid', '2-28'],
#  [2, 'T192', 16, 17, 'Dosage', 'boluses', '2-28'],
#  [2, 'T193', 11, 13, 'Dosage', 'one unit', '2-32'],
#  [2, 'T194', 13, 14, 'Drug', "pRBC's", '2-32'],
#  [2, 'T195', 5, 7, 'ADE', 'urticarial rash', '2-34'],
#  [2, 'T196', 17, 18, 'Drug', 'Cipro', '2-34'],
#  [2, 'T174', 19, 20, 'Route', 'IV', '2-34'],
#  [2, 'T198', 21, 22, 'Route', 'PO', '2-34'],
#  [2, 'T32', 1, 2, 'Drug', 'Cipro', '2-38'],
#  [2, 'T72', 10, 11, 'Drug', 'Levofloxacin', '2-38'],
#  [2, 'T47', 4, 5, 'Drug', 'Vancomycin', '2-40'],
#  [2, 'T55', 6, 7, 'Drug', 'Levofloxacin', '2-40'],
#  [2, 'T93', 8, 10, 'Reason', 'the pneumonia', '2-40'],
#  [2, 'T178', 10, 17, 'Duration', 'for a total of 7 day course', '2-40'],
#  [2, 'T43', 4, 5, 'Drug', 'Flagyl', '2-44'],
#  [2, 'T94', 6, 11, 'Reason', 'a presumed C. difficile colitis', '2-44'],
#  [2, 'T71', 3, 4, 'Drug', 'Flagyl', '2-46'],
#  [2, 'T179', 6, 13, 'Duration', 'for a total of 7 day course', '2-46'],
#  [2, 'T177', 7, 9, 'Reason', 'his anxiety', '2-48'],
#  [2, 'T199', 10, 11, 'Reason', 'depression', '2-48'],
#  [2, 'T20', 18, 19, 'Drug', 'Celexa', '2-48'],
#  [2, 'T21', 20, 22, 'Strength', '40 mg', '2-48'],
#  [2, 'T95', 22, 23, 'Frequency', 'daily', '2-48'],
#  [2, 'T202', 24, 26, 'Strength', '30 mg', '2-48'],
#  [2, 'T96', 29, 30, 'Drug', 'benzodiazepines', '2-48'],
#  [2, 'T83', 38, 39, 'ADE', 'delirium', '2-48'],
#  [2, 'T5', 3, 4, 'Drug', 'Lisinopril', '2-56'],
#  [2, 'T6', 4, 5, 'Strength', '10mg', '2-56'],
#  [2, 'T7', 5, 6, 'Route', 'PO', '2-56'],
#  [2, 'T97', 6, 7, 'Frequency', 'daily', '2-56'],
#  [2, 'T100', 7, 8, 'Drug', 'Levothyroxine', '2-56'],
#  [2, 'T101', 8, 10, 'Strength', '137 mcg', '2-56'],
#  [2, 'T102', 10, 11, 'Route', 'PO', '2-56'],
#  [2, 'T103', 11, 12, 'Frequency', 'daily', '2-56'],
#  [2, 'T36', 12, 13, 'Drug', 'Lasix', '2-56'],
#  [2, 'T37', 13, 15, 'Strength', '20 mg', '2-56'],
#  [2, 'T38', 15, 16, 'Route', 'PO', '2-56'],
#  [2, 'T98', 16, 17, 'Frequency', 'daily', '2-56'],
#  [2, 'T52', 17, 18, 'Drug', 'Celexa', '2-56'],
#  [2, 'T53', 18, 20, 'Strength', '30 mg', '2-56'],
#  [2, 'T54', 20, 21, 'Route', 'PO', '2-56'],
#  [2, 'T99', 21, 22, 'Frequency', 'daily', '2-56'],
#  [2, 'T8', 25, 26, 'Drug', 'lisinopril', '2-56'],
#  [2, 'T9', 26, 28, 'Strength', '10 mg', '2-56'],
#  [2, 'T104', 28, 29, 'Form', 'Tablet', '2-56'],
#  [2, 'T105', 30, 32, 'Dosage', 'One (1)', '2-56'],
#  [2, 'T10', 32, 33, 'Form', 'Tablet', '2-56'],
#  [2, 'T11', 33, 34, 'Route', 'PO', '2-56'],
#  [2, 'T203', 34, 36, 'Frequency', 'DAILY (Daily)', '2-56'],
#  [2, 'T106', 1, 2, 'Drug', 'levothyroxine', '2-79'],
#  [2, 'T107', 2, 4, 'Strength', '137 mcg', '2-79'],
#  [2, 'T108', 4, 5, 'Form', 'Tablet', '2-79'],
#  [2, 'T109', 6, 8, 'Dosage', 'One (1)', '2-79'],
#  [2, 'T110', 8, 9, 'Form', 'Tablet', '2-79'],
#  [2, 'T111', 9, 10, 'Route', 'PO', '2-79'],
#  [2, 'T112', 10, 12, 'Frequency', 'DAILY (Daily)', '2-79'],
#  [2, 'T48', 1, 2, 'Drug', 'furosemide', '2-86'],
#  [2, 'T49', 2, 4, 'Strength', '20 mg', '2-86'],
#  [2, 'T113', 4, 5, 'Form', 'Tablet', '2-86'],
#  [2, 'T114', 6, 8, 'Dosage', 'One (1)', '2-86'],
#  [2, 'T50', 8, 9, 'Form', 'Tablet', '2-86'],
#  [2, 'T51', 9, 10, 'Route', 'PO', '2-86'],
#  [2, 'T115', 10, 12, 'Frequency', 'DAILY (Daily)', '2-86'],
#  [2, 'T65', 1, 2, 'Drug', 'citalopram', '2-93'],
#  [2, 'T66', 2, 4, 'Strength', '20 mg', '2-93'],
#  [2, 'T116', 4, 5, 'Form', 'Tablet', '2-93'],
#  [2, 'T68', 6, 7, 'Dosage', '1.5', '2-93'],
#  [2, 'T67', 7, 8, 'Form', 'Tablets', '2-93'],
#  [2, 'T69', 8, 9, 'Route', 'PO', '2-93'],
#  [2, 'T117', 9, 11, 'Frequency', 'DAILY (Daily)', '2-93'],
#  [2, 'T118', 1, 3, 'Drug', 'albuterol sulfate', '2-100'],
#  [2, 'T119', 3, 9, 'Strength', '2.5 mg /3 mL (0.083 %)', '2-100'],
#  [2, 'T120', 9, 12, 'Form', 'Solution for Nebulization', '2-100'],
#  [2, 'T121', 13, 15, 'Dosage', 'One (1)', '2-100'],
#  [2, 'T122', 15, 17, 'Route', 'Neb Inhalation', '2-100'],
#  [2, 'T123', 17, 23, 'Frequency', 'Q4H (every 4 hours) as needed', '2-100'],
#  [2, 'T84', 24, 27, 'Reason', 'shortness of breath', '2-100'],
#  [2, 'T176', 28, 29, 'Reason', 'wheezing', '2-100'],
#  [2, 'T124', 1, 3, 'Drug', 'ipratropium bromide', '2-108'],
#  [2, 'T125', 3, 5, 'Strength', '0.02 %', '2-108'],
#  [2, 'T126', 5, 6, 'Form', 'Solution', '2-108'],
#  [2, 'T127', 7, 9, 'Dosage', 'One (1)', '2-108'],
#  [2, 'T128', 9, 11, 'Route', 'Neb Inhalation', '2-108'],
#  [2, 'T129', 11, 15, 'Frequency', 'every six (6) hours.', '2-108'],
#  [2, 'T12', 16, 17, 'Drug', 'pantoprazole', '2-108'],
#  [2, 'T13', 17, 19, 'Strength', '40 mg', '2-108'],
#  [2, 'T14', 19, 24, 'Form', 'Tablet , Delayed Release (E.C.)', '2-108'],
#  [2, 'T130', 25, 27, 'Dosage', 'One (1)', '2-108'],
#  [2, 'T131', 27, 31, 'Form', 'Tablet, Delayed Release (E.C.)', '2-108'],
#  [2, 'T132', 31, 32, 'Route', 'PO', '2-108'],
#  [2, 'T133', 32, 36, 'Frequency', 'Q12H (every 12 hours)', '2-108'],
#  [2, 'T34', 1, 3, 'Drug', 'heparin (porcine)', '2-121'],
#  [2, 'T35', 3, 6, 'Strength', '5,000 unit /mL', '2-121'],
#  [2, 'T134', 6, 7, 'Form', 'Solution', '2-121'],
#  [2, 'T135', 8, 11, 'Dosage', 'One (1) ML', '2-121'],
#  [2, 'T136', 11, 12, 'Form', 'Injection', '2-121'],
#  [2, 'T137', 12, 17, 'Frequency', 'TID (3 times a day)', '2-121'],
#  [2, 'T206', 1, 2, 'Drug', 'levothyroxine', '2-127'],
#  [2, 'T207', 2, 4, 'Strength', '75 mcg', '2-127'],
#  [2, 'T208', 4, 5, 'Form', 'Tablet', '2-127'],
#  [2, 'T209', 6, 8, 'Dosage', 'Two (2)', '2-127'],
#  [2, 'T210', 8, 9, 'Form', 'Tablet', '2-127'],
#  [2, 'T211', 10, 12, 'Frequency', 'DAILY (Daily)', '2-127'],
#  [2, 'T24', 1, 3, 'Drug', 'diphenhydramine HCl', '2-133'],
#  [2, 'T25', 3, 5, 'Strength', '25 mg', '2-133'],
#  [2, 'T138', 5, 6, 'Form', 'Capsule', '2-133'],
#  [2, 'T139', 7, 9, 'Dosage', 'One (1)', '2-133'],
#  [2, 'T26', 9, 10, 'Form', 'Capsule', '2-133'],
#  [2, 'T27', 10, 11, 'Route', 'PO', '2-133'],
#  [2, 'T140', 11, 17, 'Frequency', 'Q6H (every 6 hours) as needed', '2-133'],
#  [2, 'T141', 18, 19, 'Reason', 'pruritis', '2-133'],
#  [2, 'T16', 1, 2, 'Drug', 'furosemide', '2-141'],
#  [2, 'T17', 2, 4, 'Strength', '20 mg', '2-141'],
#  [2, 'T142', 4, 5, 'Form', 'Tablet', '2-141'],
#  [2, 'T143', 6, 8, 'Dosage', 'One (1)', '2-141'],
#  [2, 'T18', 8, 9, 'Form', 'Tablet', '2-141'],
#  [2, 'T19', 9, 10, 'Route', 'PO', '2-141'],
#  [2, 'T144', 10, 15, 'Frequency', 'BID (2 times a day)', '2-141'],
#  [2, 'T60', 1, 2, 'Drug', 'trazodone', '2-148'],
#  [2, 'T61', 2, 4, 'Strength', '50 mg', '2-148'],
#  [2, 'T145', 4, 5, 'Form', 'Tablet', '2-148'],
#  [2, 'T63', 6, 7, 'Dosage', '0.5', '2-148'],
#  [2, 'T62', 7, 8, 'Form', 'Tablet', '2-148'],
#  [2, 'T64', 8, 9, 'Route', 'PO', '2-148'],
#  [2, 'T146', 9, 14, 'Frequency', 'HS (at bedtime) as needed', '2-148'],
#  [2, 'T85', 15, 16, 'Reason', 'insomnia', '2-148'],
#  [2, 'T28', 1, 2, 'Drug', 'citalopram', '2-156'],
#  [2, 'T29', 2, 4, 'Strength', '20 mg', '2-156'],
#  [2, 'T147', 4, 5, 'Form', 'Tablet', '2-156'],
#  [2, 'T148', 6, 8, 'Dosage', 'Two (2)', '2-156'],
#  [2, 'T30', 8, 9, 'Form', 'Tablet', '2-156'],
#  [2, 'T31', 9, 10, 'Route', 'PO', '2-156'],
#  [2, 'T149', 10, 12, 'Frequency', 'DAILY (Daily)', '2-156'],
#  [2, 'T150', 1, 3, 'Drug', 'miconazole nitrate', '2-163'],
#  [2, 'T151', 3, 5, 'Strength', '2 %', '2-163'],
#  [2, 'T152', 5, 6, 'Form', 'Powder', '2-163'],
#  [2, 'T153', 7, 9, 'Dosage', 'One (1)', '2-163'],
#  [2, 'T212', 9, 10, 'Form', 'Appl', '2-163'],
#  [2, 'T154', 10, 11, 'Route', 'Topical', '2-163'],
#  [2, 'T155', 11, 15, 'Frequency', 'three times a day', '2-163'],
#  [2, 'T76', 1, 2, 'Drug', 'hydromorphone', '2-170'],
#  [2, 'T77', 2, 4, 'Strength', '2 mg', '2-170'],
#  [2, 'T156', 4, 5, 'Form', 'Tablet', '2-170'],
#  [2, 'T79', 6, 7, 'Dosage', '1-2', '2-170'],
#  [2, 'T78', 7, 8, 'Form', 'Tablets', '2-170'],
#  [2, 'T80', 8, 9, 'Route', 'PO', '2-170'],
#  [2, 'T157', 9, 15, 'Frequency', 'Q4H (every 4 hours) as needed', '2-170'],
#  [2, 'T86', 16, 17, 'Reason', 'pain', '2-170'],
#  [2, 'T39', 1, 3, 'Drug', 'cholestyramine- sucrose', '2-178'],
#  [2, 'T40', 3, 5, 'Strength', '4 gram', '2-178'],
#  [2, 'T158', 5, 6, 'Form', 'Packet', '2-178'],
#  [2, 'T159', 7, 9, 'Dosage', 'Two (2)', '2-178'],
#  [2, 'T41', 9, 10, 'Form', 'Packet', '2-178'],
#  [2, 'T42', 10, 11, 'Route', 'PO', '2-178'],
#  [2, 'T160', 11, 16, 'Frequency', 'BID (2 times a day)', '2-178'],
#  [2, 'T1', 1, 2, 'Drug', 'Vancomycin', '2-185'],
#  [2, 'T2', 2, 4, 'Strength', '1500 mg', '2-185'],
#  [2, 'T175', 4, 5, 'Route', 'IV', '2-185'],
#  [2, 'T3', 5, 7, 'Frequency', 'Q 12H', '2-185'],
#  [2, 'T56', 13, 16, 'Drug', 'levofloxacin in D5W', '2-185'],
#  [2, 'T57', 16, 20, 'Strength', '750 mg /150 mL', '2-185'],
#  [2, 'T161', 20, 21, 'Form', 'Piggyback', '2-185'],
#  [2,
#   'T162',
#   22,
#   29,
#   'Dosage',
#   'Seven [**Age over 90 1230**]y (750) MG',
#   '2-185'],
#  [2, 'T163', 29, 30, 'Route', 'Intravenous', '2-185'],
#  [2, 'T164', 30, 34, 'Frequency', 'Q24H (every 24 hours)', '2-185'],
#  [2, 'T73', 1, 5, 'Drug', 'metronidazole in NaCl (iso-os)', '2-195'],
#  [2, 'T74', 5, 9, 'Strength', '500 mg /100 mL', '2-195'],
#  [2, 'T166', 9, 10, 'Form', 'Piggyback', '2-195'],
#  [2, 'T165', 11, 15, 'Dosage', 'Five Hundred (500) MG', '2-195'],
#  [2, 'T167', 15, 16, 'Route', 'Intravenous', '2-195'],
#  [2, 'T168', 16, 20, 'Frequency', 'Q8H (every 8 hours)', '2-195'],
#  [2, 'T81', 1, 4, 'Drug', 'insulin regular human', '2-201'],
#  [2, 'T82', 4, 7, 'Strength', '100 unit /mL', '2-201'],
#  [2, 'T169', 7, 8, 'Form', 'Solution', '2-201'],
#  [2, 'T170', 9, 11, 'Dosage', 'One (1)', '2-201'],
#  [2, 'T172', 12, 13, 'Form', 'Injection', '2-201'],
#  [2, 'T171', 13, 19, 'Frequency', 'four times a day as needed', '2-201'],
#  [2, 'T213', 21, 23, 'Dosage', 'sliding scale', '2-201'],
#  [3, 'T45', 9, 10, 'Drug', 'Lisinopril', '3-0'],
#  [3, 'T89', 2, 3, 'Drug', 'imdur', '3-1'],
#  [3, 'T90', 4, 5, 'Drug', 'diovan', '3-1'],
#  [3, 'T92', 6, 7, 'Reason', 'pain', '3-1'],
#  [3, 'T66', 1, 2, 'Strength', '5mg', '3-4'],
#  [3, 'T67', 2, 3, 'Route', 'IV', '3-4'],
#  [3, 'T68', 3, 4, 'Drug', 'lopressor', '3-4'],
#  [3, 'T69', 5, 6, 'Drug', 'aspirin', '3-4'],
#  [3, 'T70', 7, 8, 'Drug', 'plavix', '3-4'],
#  [3, 'T71', 9, 10, 'Drug', 'heparin', '3-4'],
#  [3, 'T72', 10, 11, 'Route', 'drip', '3-4'],
#  [3, 'T73', 2, 4, 'Reason', 'chest pain', '3-11'],
#  [3, 'T74', 6, 7, 'Route', 'SL', '3-11'],
#  [3, 'T75', 7, 8, 'Drug', 'nitro', '3-11'],
#  [3, 'T76', 4, 5, 'Drug', 'heparin', '3-14'],
#  [3, 'T77', 6, 7, 'Drug', 'integrelin', '3-14'],
#  [3, 'T78', 7, 8, 'Form', 'gtt', '3-14'],
#  [3, 'T79', 4, 5, 'Drug', 'ASA', '3-17'],
#  [3, 'T80', 5, 6, 'Strength', '325', '3-17'],
#  [3, 'T81', 7, 8, 'Drug', 'plavix', '3-17'],
#  [3, 'T82', 10, 11, 'Strength', '600mg', '3-17'],
#  [3, 'T83', 14, 15, 'Strength', '75mg', '3-17'],
#  [3, 'T84', 15, 16, 'Frequency', 'daily', '3-17'],
#  [3, 'T85', 20, 21, 'Drug', 'BB', '3-17'],
#  [3, 'T86', 4, 5, 'Duration', 'long-term', '3-24'],
#  [3, 'T87', 5, 6, 'Drug', 'Plavix', '3-24'],
#  [3, 'T88', 5, 6, 'Drug', 'BB', '3-26'],
#  [3, 'T91', 1, 2, 'Drug', 'valsartan', '3-27'],
#  [3, 'T93', 1, 2, 'Reason', 'BP', '3-28'],
#  [3, 'T94', 4, 5, 'Drug', 'Diltiazem', '3-29'],
#  [3, 'T95', 6, 7, 'Drug', 'Isosorbide', '3-29'],
#  [3, 'T96', 8, 9, 'Drug', 'Metoprolol', '3-29'],
#  [3, 'T97', 11, 12, 'Drug', 'valsartan', '3-29'],
#  [3, 'T99', 1, 2, 'Reason', 'PROPHYLAXIS', '3-33'],
#  [3, 'T100', 3, 4, 'Drug', 'Heparin', '3-33'],
#  [3, 'T101', 4, 5, 'Route', 'drip', '3-33'],
#  [3, 'T102', 19, 20, 'Drug', 'Atenolol', '3-36'],
#  [3, 'T103', 20, 22, 'Strength', '25 mg', '3-36'],
#  [3, 'T104', 22, 23, 'Form', 'Tablet', '3-36'],
#  [3, 'T105', 24, 26, 'Dosage', 'One (1)', '3-36'],
#  [3, 'T106', 26, 27, 'Form', 'Tablet', '3-36'],
#  [3, 'T107', 27, 28, 'Route', 'PO', '3-36'],
#  [3, 'T108', 28, 29, 'Frequency', 'DAILY', '3-36'],
#  [3, 'T109', 1, 3, 'Drug', 'Diltiazem HCl', '3-43'],
#  [3, 'T110', 3, 5, 'Strength', '300 mg', '3-43'],
#  [3, 'T111', 5, 8, 'Form', 'Capsule, Sustained Release', '3-43'],
#  [3, 'T112', 9, 11, 'Dosage', 'One (1)', '3-43'],
#  [3, 'T113', 11, 14, 'Form', 'Capsule, Sustained Release', '3-43'],
#  [3, 'T114', 14, 15, 'Route', 'PO', '3-43'],
#  [3, 'T115', 15, 16, 'Frequency', 'DAILY', '3-43'],
#  [3, 'T116', 1, 2, 'Drug', 'Valsartan', '3-50'],
#  [3, 'T117', 2, 4, 'Strength', '160 mg', '3-50'],
#  [3, 'T118', 4, 5, 'Form', 'Tablet', '3-50'],
#  [3, 'T119', 6, 8, 'Dosage', 'One (1)', '3-50'],
#  [3, 'T120', 8, 9, 'Form', 'Tablet', '3-50'],
#  [3, 'T121', 9, 10, 'Route', 'PO', '3-50'],
#  [3, 'T122', 10, 11, 'Frequency', 'BID', '3-50'],
#  [3, 'T123', 1, 2, 'Drug', 'Aspirin', '3-57'],
#  [3, 'T124', 2, 4, 'Strength', '81 mg', '3-57'],
#  [3, 'T125', 4, 6, 'Form', 'Tablet, Chewable', '3-57'],
#  [3, 'T126', 7, 9, 'Dosage', 'One (1)', '3-57'],
#  [3, 'T127', 9, 11, 'Form', 'Tablet, Chewable', '3-57'],
#  [3, 'T128', 11, 12, 'Route', 'PO', '3-57'],
#  [3, 'T129', 12, 13, 'Frequency', 'DAILY', '3-57'],
#  [3, 'T130', 1, 2, 'Drug', 'Rosuvastatin', '3-64'],
#  [3, 'T131', 2, 4, 'Strength', '20 mg', '3-64'],
#  [3, 'T132', 4, 5, 'Form', 'Tablet', '3-64'],
#  [3, 'T133', 6, 8, 'Dosage', 'One (1)', '3-64'],
#  [3, 'T134', 8, 9, 'Form', 'Tablet', '3-64'],
#  [3, 'T135', 9, 10, 'Route', 'PO', '3-64'],
#  [3, 'T136', 10, 11, 'Frequency', 'HS', '3-64'],
#  [3, 'T137', 1, 3, 'Drug', 'Isosorbide Mononitrate', '3-71'],
#  [3, 'T138', 3, 5, 'Strength', '30 mg', '3-71'],
#  [3, 'T139', 5, 10, 'Form', 'Tablet Sustained Release 24 hr', '3-71'],
#  [3, 'T140', 11, 12, 'Dosage', '0.5', '3-71'],
#  [3, 'T141', 12, 17, 'Form', 'Tablet Sustained Release 24 hr', '3-71'],
#  [3, 'T142', 17, 18, 'Route', 'PO', '3-71'],
#  [3, 'T143', 18, 19, 'Frequency', 'DAILY', '3-71'],
#  [3, 'T144', 1, 2, 'Drug', 'Latanoprost', '3-78'],
#  [3, 'T145', 2, 3, 'Strength', '0.005', '3-78'],
#  [3, 'T146', 4, 5, 'Form', 'Drops', '3-78'],
#  [3, 'T147', 6, 8, 'Dosage', 'One (1)', '3-78'],
#  [3, 'T148', 8, 9, 'Form', 'Drop', '3-78'],
#  [3, 'T149', 9, 10, 'Route', 'Ophthalmic', '3-78'],
#  [3, 'T150', 10, 11, 'Frequency', 'HS', '3-78'],
#  [3, 'T151', 1, 3, 'Drug', 'Polyvinyl Alcohol', '3-85'],
#  [3, 'T152', 3, 4, 'Strength', '1.4', '3-85'],
#  [3, 'T153', 5, 6, 'Form', 'Drops', '3-85'],
#  [3, 'T154', 7, 8, 'Dosage', '1-2', '3-85'],
#  [3, 'T155', 8, 9, 'Form', 'Drops', '3-85'],
#  [3, 'T156', 9, 10, 'Route', 'Ophthalmic', '3-85'],
#  [3, 'T157', 10, 11, 'Frequency', 'PRN', '3-85'],
#  [3, 'T158', 1, 2, 'Drug', 'Betimol', '3-92'],
#  [3, 'T159', 2, 3, 'Strength', '0.5', '3-92'],
#  [3, 'T160', 4, 5, 'Form', 'Drops', '3-92'],
#  [3, 'T161', 6, 8, 'Dosage', 'One (1)', '3-92'],
#  [3, 'T162', 8, 9, 'Route', 'Ophthalmic', '3-92'],
#  [3, 'T163', 9, 12, 'Frequency', 'once a day', '3-92'],
#  [3, 'T164', 14, 15, 'Drug', 'Valsartan', '3-98'],
#  [3, 'T165', 15, 17, 'Strength', '160 mg', '3-98'],
#  [3, 'T166', 17, 18, 'Form', 'Tablet', '3-98'],
#  [3, 'T167', 19, 21, 'Dosage', 'One (1)', '3-98'],
#  [3, 'T168', 21, 22, 'Form', 'Tablet', '3-98'],
#  [3, 'T169', 22, 23, 'Route', 'PO', '3-98'],
#  [3, 'T170', 23, 26, 'Frequency', 'twice a day', '3-98'],
#  [3, 'T171', 1, 3, 'Drug', 'Isosorbide Mononitrate', '3-105'],
#  [3, 'T172', 3, 5, 'Strength', '30 mg', '3-105'],
#  [3, 'T173', 5, 10, 'Form', 'Tablet Sustained Release 24 hr', '3-105'],
#  [3, 'T174', 11, 12, 'Dosage', '0.5', '3-105'],
#  [3, 'T175', 12, 17, 'Form', 'Tablet Sustained Release 24 hr', '3-105'],
#  [3, 'T176', 17, 18, 'Route', 'PO', '3-105'],
#  [3, 'T177', 18, 21, 'Frequency', 'once a day', '3-105'],
#  [3, 'T178', 1, 2, 'Drug', 'Latanoprost', '3-112'],
#  [3, 'T179', 2, 3, 'Strength', '0.005', '3-112'],
#  [3, 'T180', 4, 5, 'Form', 'Drops', '3-112'],
#  [3, 'T181', 6, 8, 'Dosage', 'One (1)', '3-112'],
#  [3, 'T182', 8, 9, 'Form', 'Drop', '3-112'],
#  [3, 'T183', 9, 10, 'Route', 'Ophthalmic', '3-112'],
#  [3, 'T184', 10, 11, 'Frequency', 'HS', '3-112'],
#  [3, 'T185', 1, 3, 'Drug', 'Timolol Maleate', '3-119'],
#  [3, 'T186', 3, 4, 'Strength', '0.5', '3-119'],
#  [3, 'T187', 5, 6, 'Form', 'Drops', '3-119'],
#  [3, 'T188', 7, 9, 'Dosage', 'One (1)', '3-119'],
#  [3, 'T189', 9, 10, 'Route', 'Ophthalmic', '3-119'],
#  [3, 'T190', 10, 11, 'Frequency', 'Daily', '3-119'],
#  [3, 'T191', 1, 3, 'Drug', 'Polyvinyl Alcohol', '3-125'],
#  [3, 'T192', 3, 4, 'Strength', '1.4', '3-125'],
#  [3, 'T193', 5, 6, 'Form', 'Drops', '3-125'],
#  [3, 'T194', 8, 9, 'Route', 'Ophthalmic', '3-125'],
#  [3, 'T195', 9, 10, 'Frequency', 'prn', '3-125'],
#  [3, 'T196', 1, 3, 'Drug', 'Diltiazem HCl', '3-130'],
#  [3, 'T1', 3, 5, 'Strength', '180 mg', '3-130'],
#  [3, 'T2', 5, 8, 'Form', 'Capsule, Sustained Release', '3-130'],
#  [3, 'T3', 9, 11, 'Dosage', 'One (1)', '3-130'],
#  [3, 'T4', 11, 14, 'Form', 'Capsule, Sustained Release', '3-130'],
#  [3, 'T5', 14, 15, 'Route', 'PO', '3-130'],
#  [3, 'T6', 15, 16, 'Frequency', 'DAILY', '3-130'],
#  [3, 'T7', 1, 2, 'Form', 'Capsule', '3-137'],
#  [3, 'T8', 6, 8, 'Drug', 'Toprol XL', '3-138'],
#  [3, 'T9', 8, 10, 'Strength', '50 mg', '3-138'],
#  [3, 'T10', 10, 15, 'Form', 'Tablet Sustained Release 24 hr', '3-138'],
#  [3, 'T11', 16, 18, 'Dosage', 'Three (3)', '3-138'],
#  [3, 'T12', 18, 23, 'Form', 'Tablet Sustained Release 24 hr', '3-138'],
#  [3, 'T13', 23, 24, 'Route', 'PO', '3-138'],
#  [3, 'T14', 24, 27, 'Frequency', 'once a day', '3-138'],
#  [3, 'T15', 1, 2, 'Form', 'Tablet', '3-145'],
#  [3, 'T16', 8, 9, 'Drug', 'Aspirin', '3-146'],
#  [3, 'T17', 9, 11, 'Strength', '325 mg', '3-146'],
#  [3, 'T18', 11, 12, 'Form', 'Tablet', '3-146'],
#  [3, 'T19', 13, 15, 'Dosage', 'One (1)', '3-146'],
#  [3, 'T20', 15, 16, 'Form', 'Tablet', '3-146'],
#  [3, 'T21', 16, 17, 'Route', 'PO', '3-146'],
#  [3, 'T22', 17, 18, 'Frequency', 'DAILY', '3-146'],
#  [3, 'T23', 4, 5, 'Drug', 'Atorvastatin', '3-153'],
#  [3, 'T24', 5, 7, 'Strength', '80 mg', '3-153'],
#  [3, 'T25', 7, 8, 'Form', 'Tablet', '3-153'],
#  [3, 'T26', 9, 11, 'Dosage', 'One (1)', '3-153'],
#  [3, 'T27', 11, 12, 'Form', 'Tablet', '3-153'],
#  [3, 'T28', 12, 13, 'Route', 'PO', '3-153'],
#  [3, 'T29', 13, 14, 'Frequency', 'DAILY', '3-153'],
#  [3, 'T30', 1, 2, 'Form', 'Tablet', '3-160'],
#  [3, 'T31', 4, 5, 'Drug', 'Clopidogrel', '3-161'],
#  [3, 'T32', 5, 7, 'Strength', '75 mg', '3-161'],
#  [3, 'T33', 7, 8, 'Form', 'Tablet', '3-161'],
#  [3, 'T34', 9, 11, 'Dosage', 'One (1)', '3-161'],
#  [3, 'T35', 11, 12, 'Form', 'Tablet', '3-161'],
#  [3, 'T36', 12, 13, 'Route', 'PO', '3-161'],
#  [3, 'T37', 13, 14, 'Frequency', 'DAILY', '3-161'],
#  [3, 'T38', 4, 5, 'Drug', 'Omeprazole', '3-168'],
#  [3, 'T39', 5, 7, 'Strength', '20 mg', '3-168'],
#  [3, 'T40', 7, 10, 'Form', 'Capsule, Delayed Release(E.C.)', '3-168'],
#  [3, 'T41', 11, 13, 'Dosage', 'Two (2)', '3-168'],
#  [3, 'T42', 13, 16, 'Form', 'Capsule, Delayed Release(E.C.)', '3-168'],
#  [3, 'T43', 16, 17, 'Route', 'PO', '3-168'],
#  [3, 'T44', 17, 18, 'Frequency', 'DAILY', '3-168'],
#  [3, 'T46', 2, 3, 'Drug', 'aspirin', '3-175'],
#  [3, 'T47', 3, 5, 'Strength', '325 mg', '3-175'],
#  [3, 'T48', 5, 6, 'Frequency', 'daily', '3-175'],
#  [3, 'T49', 8, 10, 'Strength', '81 mg', '3-175'],
#  [3, 'T50', 10, 11, 'Frequency', 'daily', '3-175'],
#  [3, 'T51', 2, 3, 'Drug', 'plavix', '3-180'],
#  [3, 'T52', 3, 5, 'Strength', '75 mg', '3-180'],
#  [3, 'T53', 5, 6, 'Frequency', 'daily', '3-180'],
#  [3, 'T54', 4, 6, 'Drug', 'Toprol XL', '3-183'],
#  [3, 'T55', 6, 7, 'Strength', '150mg', '3-183'],
#  [3, 'T56', 7, 8, 'Frequency', 'daily', '3-183'],
#  [3, 'T57', 1, 2, 'Drug', 'Diltiazem', '3-186'],
#  [3, 'T58', 5, 6, 'Strength', '180mg', '3-186'],
#  [3, 'T59', 6, 7, 'Frequency', 'daily', '3-186'],
#  [3, 'T60', 4, 5, 'Drug', 'omeprazole', '3-189'],
#  [3, 'T61', 5, 6, 'Strength', '40mg', '3-189'],
#  [3, 'T62', 6, 7, 'Frequency', 'daily', '3-189'],
#  [3, 'T63', 3, 4, 'Drug', 'Lipitor', '3-192'],
#  [3, 'T64', 4, 5, 'Strength', '80mg', '3-192'],
#  [3, 'T65', 5, 6, 'Frequency', 'daily', '3-192'],
#  [4, 'T128', 15, 16, 'Drug', 'aspirin', '4-0'],
#  [4, 'T129', 17, 18, 'Drug', 'Codeine', '4-0'],
#  [4, 'T130', 19, 20, 'Drug', 'Penicillins', '4-0'],
#  [4, 'T131', 21, 22, 'Drug', 'Iodine', '4-0'],
#  [4, 'T135', 76, 77, 'Drug', 'insulin', '4-0'],
#  [4, 'T136', 78, 79, 'Reason', 'DM', '4-0'],
#  [4, 'T137', 86, 87, 'Drug', 'aspirin', '4-0'],
#  [4, 'T132', 4, 6, 'Reason', 'AV paced', '4-7'],
#  [4, 'T133', 9, 10, 'Drug', 'phenylephrine', '4-7'],
#  [4, 'T134', 10, 11, 'Form', 'infusion', '4-7'],
#  [4, 'T138', 12, 15, 'Reason', 'coronary artery disease', '4-10'],
#  [4, 'T1', 8, 9, 'Drug', 'beta-blockers', '4-11'],
#  [4, 'T2', 10, 11, 'Drug', 'statin', '4-11'],
#  [4, 'T3', 12, 13, 'Drug', 'aspirin', '4-11'],
#  [4, 'T4', 14, 15, 'Drug', 'diuretics', '4-11'],
#  [4, 'T5', 1, 2, 'Drug', 'Lasix', '4-15'],
#  [4, 'T6', 4, 5, 'Drug', 'IVF', '4-15'],
#  [4, 'T7', 4, 5, 'Drug', 'Metformin', '4-17'],
#  [4, 'T8', 5, 7, 'Strength', '1000 mg', '4-17'],
#  [4, 'T9', 7, 8, 'Frequency', 'qam', '4-17'],
#  [4, 'T10', 9, 10, 'Drug', 'Humalin-N', '4-17'],
#  [4, 'T11', 10, 12, 'Dosage', '30 units', '4-17'],
#  [4, 'T12', 12, 13, 'Frequency', 'daily', '4-17'],
#  [4, 'T13', 14, 15, 'Drug', 'Humalin-R', '4-17'],
#  [4, 'T14', 15, 17, 'Dosage', '30 units', '4-17'],
#  [4, 'T15', 17, 18, 'Frequency', 'daily', '4-17'],
#  [4, 'T16', 19, 20, 'Drug', 'Lisinopril', '4-17'],
#  [4, 'T17', 20, 21, 'Dosage', '20', '4-17'],
#  [4, 'T18', 21, 22, 'Frequency', 'daily', '4-17'],
#  [4, 'T19', 23, 24, 'Drug', 'paroxetine', '4-17'],
#  [4, 'T20', 24, 25, 'Dosage', '20', '4-17'],
#  [4, 'T21', 25, 26, 'Frequency', 'daily', '4-17'],
#  [4, 'T22', 29, 30, 'Drug', 'atorvastatin', '4-17'],
#  [4, 'T23', 30, 32, 'Strength', '40 mg', '4-17'],
#  [4, 'T24', 32, 33, 'Form', 'Tablet', '4-17'],
#  [4, 'T25', 34, 36, 'Dosage', 'One (1)', '4-17'],
#  [4, 'T26', 36, 37, 'Form', 'Tablet', '4-17'],
#  [4, 'T27', 37, 38, 'Route', 'PO', '4-17'],
#  [4, 'T28', 38, 40, 'Frequency', 'DAILY (Daily)', '4-17'],
#  [4, 'T139', 1, 2, 'Form', 'Tablet(s)', '4-39'],
#  [4, 'T29', 5, 7, 'Drug', 'paroxetine HCl', '4-39'],
#  [4, 'T30', 7, 9, 'Strength', '20 mg', '4-39'],
#  [4, 'T31', 9, 10, 'Form', 'Tablet', '4-39'],
#  [4, 'T32', 11, 13, 'Dosage', 'One (1)', '4-39'],
#  [4, 'T33', 13, 14, 'Form', 'Tablet', '4-39'],
#  [4, 'T34', 14, 15, 'Route', 'PO', '4-39'],
#  [4, 'T35', 15, 17, 'Frequency', 'DAILY (Daily)', '4-39'],
#  [4, 'T140', 1, 2, 'Form', 'Tablet(s)', '4-47'],
#  [4, 'T36', 5, 7, 'Drug', 'docusate sodium', '4-47'],
#  [4, 'T37', 7, 9, 'Strength', '100 mg', '4-47'],
#  [4, 'T38', 9, 10, 'Form', 'Capsule', '4-47'],
#  [4, 'T39', 11, 13, 'Dosage', 'One (1)', '4-47'],
#  [4, 'T40', 13, 14, 'Form', 'Capsule', '4-47'],
#  [4, 'T41', 14, 15, 'Route', 'PO', '4-47'],
#  [4, 'T42', 15, 20, 'Frequency', 'BID (2 times a day)', '4-47'],
#  [4, 'T141', 1, 2, 'Form', 'Capsule(s)', '4-55'],
#  [4, 'T43', 5, 6, 'Drug', 'aspirin', '4-55'],
#  [4, 'T44', 6, 8, 'Strength', '81 mg', '4-55'],
#  [4, 'T45', 8, 12, 'Form', 'Tablet, Delayed Release (E.C.)', '4-55'],
#  [4, 'T46', 13, 15, 'Dosage', 'One (1)', '4-55'],
#  [4, 'T47', 15, 19, 'Form', 'Tablet, Delayed Release (E.C.)', '4-55'],
#  [4, 'T48', 19, 20, 'Route', 'PO', '4-55'],
#  [4, 'T49', 20, 22, 'Frequency', 'DAILY (Daily)', '4-55'],
#  [4, 'T50', 3, 4, 'Drug', 'omeprazole', '4-64'],
#  [4, 'T51', 4, 6, 'Strength', '20 mg', '4-64'],
#  [4, 'T52', 6, 9, 'Form', 'Capsule, Delayed Release(E.C.)', '4-64'],
#  [4, 'T53', 10, 12, 'Dosage', 'Two (2)', '4-64'],
#  [4, 'T54', 12, 15, 'Form', 'Capsule, Delayed Release(E.C.)', '4-64'],
#  [4, 'T55', 15, 16, 'Route', 'PO', '4-64'],
#  [4, 'T56', 16, 18, 'Frequency', 'DAILY (Daily)', '4-64'],
#  [4, 'T57', 3, 4, 'Drug', 'metformin', '4-72'],
#  [4, 'T58', 4, 6, 'Strength', '500 mg', '4-72'],
#  [4, 'T59', 6, 7, 'Form', 'Tablet', '4-72'],
#  [4, 'T60', 8, 10, 'Dosage', 'One (1)', '4-72'],
#  [4, 'T61', 10, 11, 'Form', 'Tablet', '4-72'],
#  [4, 'T62', 11, 12, 'Route', 'PO', '4-72'],
#  [4, 'T63', 12, 17, 'Frequency', 'BID (2 times a day)', '4-72'],
#  [4, 'T144', 1, 2, 'Form', 'Tablet(s)', '4-79'],
#  [4, 'T64', 5, 6, 'Drug', 'acetaminophen', '4-79'],
#  [4, 'T65', 6, 8, 'Strength', '325 mg', '4-79'],
#  [4, 'T66', 8, 9, 'Form', 'Tablet', '4-79'],
#  [4, 'T67', 10, 12, 'Dosage', 'Two (2)', '4-79'],
#  [4, 'T68', 12, 13, 'Form', 'Tablet', '4-79'],
#  [4, 'T69', 13, 14, 'Route', 'PO', '4-79'],
#  [4, 'T70', 14, 20, 'Frequency', 'Q4H (every 4 hours) as needed', '4-79'],
#  [4, 'T71', 21, 22, 'Reason', 'pain', '4-79'],
#  [4, 'T72', 23, 24, 'Reason', 'fever', '4-79'],
#  [4, 'T73', 1, 3, 'Drug', 'metoprolol tartrate', '4-89'],
#  [4, 'T74', 3, 5, 'Strength', '25 mg', '4-89'],
#  [4, 'T75', 5, 6, 'Form', 'Tablet', '4-89'],
#  [4, 'T76', 7, 8, 'Dosage', '0.5', '4-89'],
#  [4, 'T77', 8, 9, 'Form', 'Tablet', '4-89'],
#  [4, 'T78', 9, 10, 'Route', 'PO', '4-89'],
#  [4, 'T79', 10, 15, 'Frequency', 'BID (2 times a day)', '4-89'],
#  [4, 'T145', 1, 2, 'Form', 'Tablet(s)', '4-96'],
#  [4, 'T80', 5, 6, 'Drug', 'senna', '4-96'],
#  [4, 'T81', 6, 8, 'Strength', '8.6 mg', '4-96'],
#  [4, 'T82', 8, 9, 'Form', 'Capsule', '4-96'],
#  [4, 'T83', 10, 12, 'Dosage', 'One (1)', '4-96'],
#  [4, 'T84', 12, 13, 'Form', 'Capsule', '4-96'],
#  [4, 'T85', 13, 14, 'Route', 'PO', '4-96'],
#  [4, 'T86', 14, 17, 'Frequency', 'twice a day', '4-96'],
#  [4, 'T93', 4, 7, 'Drug', 'insulin regular human', '4-104'],
#  [4, 'T94', 7, 9, 'Strength', '100 unit/mL', '4-104'],
#  [4, 'T95', 9, 10, 'Form', 'Solution', '4-104'],
#  [4, 'T96', 11, 14, 'Dosage', 'Fifteen (15) units', '4-104'],
#  [4, 'T97', 14, 15, 'Route', 'Injection', '4-104'],
#  [4, 'T98', 15, 17, 'Frequency', 'every morning', '4-104'],
#  [4, 'T99', 25, 27, 'Dosage', '30 units', '4-104'],
#  [4, 'T101', 1, 3, 'Drug', 'Humulin N', '4-111'],
#  [4, 'T102', 3, 5, 'Strength', '100 unit/mL', '4-111'],
#  [4, 'T103', 5, 6, 'Form', 'Suspension', '4-111'],
#  [4, 'T104', 7, 10, 'Dosage', 'Fifteen (15) units', '4-111'],
#  [4, 'T105', 10, 11, 'Route', 'Subcutaneous', '4-111'],
#  [4, 'T106', 11, 13, 'Frequency', 'every  morning', '4-111'],
#  [4, 'T107', 21, 23, 'Dosage', '30 units', '4-111'],
#  [4, 'T109', 1, 2, 'Drug', 'furosemide', '4-118'],
#  [4, 'T110', 2, 4, 'Strength', '20 mg', '4-118'],
#  [4, 'T111', 4, 5, 'Form', 'Tablet', '4-118'],
#  [4, 'T112', 6, 8, 'Dosage', 'One (1)', '4-118'],
#  [4, 'T113', 8, 9, 'Form', 'Tablet', '4-118'],
#  [4, 'T114', 9, 10, 'Route', 'PO', '4-118'],
#  [4, 'T115', 10, 13, 'Frequency', 'once a day', '4-118'],
#  [4, 'T116', 13, 16, 'Duration', 'for 5 days', '4-118'],
#  [4, 'T87', 1, 2, 'Form', 'Tablet(s)', '4-126'],
#  [4, 'T117', 5, 7, 'Drug', 'potassium chloride', '4-126'],
#  [4, 'T118', 7, 9, 'Strength', '10 mEq', '4-126'],
#  [4, 'T119', 9, 12, 'Form', 'Tablet Extended Release', '4-126'],
#  [4, 'T120', 13, 15, 'Dosage', 'One (1)', '4-126'],
#  [4, 'T121', 15, 18, 'Form', 'Tablet Extended Release', '4-126'],
#  [4, 'T122', 18, 19, 'Route', 'PO', '4-126'],
#  [4, 'T123', 19, 22, 'Frequency', 'once a day', '4-126'],
#  [4, 'T124', 22, 25, 'Duration', 'for 5 days', '4-126'],
#  [4, 'T88', 1, 4, 'Form', 'Tablet Extended Release(s)', '4-135'],
#  [4, 'T125', 67, 69, 'Reason', 'Incisional pain', '4-135'],
#  [4, 'T126', 71, 72, 'Route', 'oral', '4-135'],
#  [4, 'T127', 72, 73, 'Drug', 'analgesia', '4-135'],
#  [5, 'T18', 15, 16, 'Drug', 'Compazine', '5-0'],
#  [5, 'T194', 3, 4, 'Dosage', 'liter', '5-1'],
#  [5, 'T43', 5, 7, 'Drug', 'normal saline', '5-1'],
#  [5, 'T100', 10, 11, 'Drug', 'bisphosphonate', '5-1'],
#  [5, 'T28', 1, 2, 'Route', 'IV', '5-4'],
#  [5, 'T101', 2, 3, 'Drug', 'hydration', '5-4'],
#  [5, 'T53', 4, 5, 'Drug', 'zometa', '5-4'],
#  [5, 'T197', 2, 3, 'Drug', 'chemo', '5-7'],
#  [5, 'T103', 3, 5, 'Reason', 'LLL pnuemonia', '5-8'],
#  [5, 'T102', 16, 18, 'Duration', '10 day', '5-8'],
#  [5, 'T89', 20, 21, 'Drug', 'levaquin', '5-8'],
#  [5, 'T104', 6, 8, 'Reason', 'LLL pneumonia', '5-11'],
#  [5, 'T42', 13, 14, 'Drug', 'levaquin', '5-11'],
#  [5, 'T105', 4, 5, 'Reason', 'C.dif', '5-13'],
#  [5, 'T195', 7, 9, 'Reason', 'CMV viremia', '5-13'],
#  [5, 'T36', 15, 16, 'Route', 'PO', '5-13'],
#  [5, 'T35', 16, 17, 'Drug', 'flagyl', '5-13'],
#  [5, 'T198', 17, 19, 'Duration', 'x 14d', '5-13'],
#  [5, 'T46', 20, 21, 'Drug', 'valganciclovir', '5-13'],
#  [5, 'T107', 6, 9, 'Reason', 'pruritic, papular rash', '5-19'],
#  [5, 'T170', 17, 18, 'Drug', 'antibiotics', '5-20'],
#  [5, 'T56', 19, 20, 'Drug', 'triamcinolone', '5-20'],
#  [5, 'T27', 21, 22, 'Drug', 'clobetasol', '5-20'],
#  [5, 'T54', 24, 25, 'Route', 'IV', '5-20'],
#  [5, 'T106', 25, 26, 'Drug', 'triamcinolone', '5-20'],
#  [5, 'T171', 2, 4, 'Drug', 'Interferon alpha', '5-25'],
#  [5, 'T172', 5, 7, 'Dosage', '3M units', '5-25'],
#  [5, 'T173', 7, 8, 'Frequency', '3x/wk', '5-25'],
#  [5, 'T174', 2, 4, 'Drug', 'Interferon alpha', '5-28'],
#  [5, 'T175', 6, 7, 'Dosage', '6Munits', '5-28'],
#  [5, 'T176', 7, 8, 'Frequency', '3x/wk', '5-28'],
#  [5, 'T177', 2, 4, 'Drug', 'Interferon alpha', '5-31'],
#  [5, 'T178', 6, 7, 'Dosage', '4.5Munits', '5-31'],
#  [5, 'T179', 7, 8, 'Frequency', '3x/wk', '5-31'],
#  [5, 'T108', 15, 17, 'Drug', 'Interferon alpha', '5-34'],
#  [5, 'T109', 20, 22, 'Dosage', '6M units', '5-34'],
#  [5, 'T110', 22, 25, 'Frequency', 'three times weekly', '5-34'],
#  [5, 'T33', 26, 27, 'Drug', 'bexarotene', '5-34'],
#  [5, 'T34', 30, 31, 'Strength', '150mg', '5-34'],
#  [5, 'T111', 31, 32, 'Frequency', 'daily', '5-34'],
#  [5, 'T112', 35, 36, 'Strength', '75mg', '5-34'],
#  [5, 'T113', 36, 37, 'Frequency', 'daily', '5-34'],
#  [5, 'T199', 2, 3, 'Drug', 'Mtx', '5-42'],
#  [5, 'T114', 5, 7, 'Drug', 'interferon alpha', '5-42'],
#  [5, 'T45', 8, 9, 'Drug', 'bexarotene', '5-42'],
#  [5, 'T115', 15, 16, 'Strength', '45mg', '5-42'],
#  [5, 'T116', 16, 17, 'Frequency', 'weekly', '5-42'],
#  [5, 'T57', 4, 5, 'Drug', 'vorinostat', '5-47'],
#  [5, 'T58', 5, 6, 'Strength', '400mg', '5-47'],
#  [5, 'T117', 6, 7, 'Frequency', 'daily', '5-47'],
#  [5, 'T121', 12, 14, 'Drug', 'interferon alpha', '5-47'],
#  [5, 'T122', 14, 16, 'Dosage', '6M units', '5-47'],
#  [5, 'T180', 16, 17, 'Frequency', 'TIW', '5-47'],
#  [5, 'T119', 2, 3, 'ADE', 'thrombocytopenia', '5-53'],
#  [5, 'T118', 4, 6, 'Drug', 'interferon alpha', '5-53'],
#  [5, 'T120', 9, 11, 'Dosage', '3M units', '5-53'],
#  [5, 'T181', 11, 12, 'Frequency', '3x/wk', '5-53'],
#  [5, 'T88', 7, 8, 'Drug', 'doxorubicin', '5-57'],
#  [5, 'T97', 9, 10, 'Drug', 'gemcitabine', '5-57'],
#  [5, 'T3', 10, 11, 'Drug', 'Vorinostat', '5-59'],
#  [5, 'T123', 12, 14, 'Drug', 'interferon alpha', '5-59'],
#  [5, 'T2', 8, 9, 'Drug', 'doxorubicin', '5-61'],
#  [5, 'T41', 6, 7, 'Drug', 'bortezomib', '5-62'],
#  [5, 'T52', 8, 9, 'Drug', 'gemcitabine', '5-62'],
#  [5, 'T182', 16, 17, 'ADE', 'neutropenia', '5-62'],
#  [5, 'T183', 2, 4, 'Dosage', '3M units', '5-65'],
#  [5, 'T184', 4, 5, 'Frequency', 'TIW', '5-65'],
#  [5, 'T185', 5, 7, 'Drug', 'Interferon alpha', '5-65'],
#  [5, 'T79', 11, 12, 'Drug', 'pentostatin', '5-68'],
#  [5, 'T80', 12, 14, 'Strength', '4mg /m2', '5-68'],
#  [5, 'T124', 14, 15, 'Frequency', 'weekly', '5-68'],
#  [5, 'T186', 16, 17, 'Dosage', '4', '5-68'],
#  [5, 'T187', 21, 23, 'Drug', 'interferon alpha', '5-68'],
#  [5, 'T125', 24, 25, 'Dosage', '3Munits', '5-68'],
#  [5, 'T126', 25, 26, 'Frequency', '3x/wkly', '5-68'],
#  [5, 'T127', 29, 31, 'Dosage', '3M units', '5-68'],
#  [5, 'T128', 31, 32, 'Frequency', '5x/wkly', '5-68'],
#  [5, 'T131', 4, 5, 'Drug', 'ONTAK', '5-77'],
#  [5, 'T129', 2, 3, 'Reason', 'Hypercalcemia', '5-78'],
#  [5, 'T130', 4, 5, 'Drug', 'IVF', '5-78'],
#  [5, 'T1', 6, 7, 'Drug', 'Zometa', '5-78'],
#  [5, 'T17', 3, 4, 'Drug', 'ONTAK', '5-81'],
#  [5, 'T188', 1, 2, 'Drug', 'gadolinium', '5-82'],
#  [5, 'T190', 10, 11, 'Route', 'IV', '5-83'],
#  [5, 'T189', 11, 12, 'Drug', 'gadolinium', '5-83'],
#  [5, 'T55', 4, 6, 'Drug', 'Piperacillin /tazobactam', '5-85'],
#  [5, 'T65', 9, 10, 'Drug', 'AMPICILLIN', '5-86'],
#  [5, 'T95', 13, 15, 'Drug', 'AMPICILLIN /SULBACTAM', '5-86'],
#  [5, 'T11', 18, 19, 'Drug', 'CEFAZOLIN', '5-86'],
#  [5, 'T44', 22, 23, 'Drug', 'CEFEPIME', '5-86'],
#  [5, 'T64', 26, 27, 'Drug', 'CEFTAZIDIME', '5-86'],
#  [5, 'T96', 30, 31, 'Drug', 'CEFTRIAXONE', '5-86'],
#  [5, 'T5', 34, 35, 'Drug', 'CIPROFLOXACIN', '5-86'],
#  [5, 'T132', 38, 39, 'Drug', 'GENTAMICIN', '5-86'],
#  [5, 'T63', 42, 43, 'Drug', 'MEROPENEM', '5-86'],
#  [5, 'T4', 45, 46, 'Drug', 'NITROFURANTOIN', '5-86'],
#  [5, 'T40', 49, 50, 'Drug', 'TOBRAMYCIN', '5-86'],
#  [5, 'T39', 53, 55, 'Drug', 'TRIMETHOPRIM /SULFA', '5-86'],
#  [5, 'T66', 4, 6, 'Drug', 'Folic Acid', '5-98'],
#  [5, 'T67', 6, 8, 'Strength', '1 mg', '5-98'],
#  [5, 'T133', 8, 9, 'Form', 'Tablet', '5-98'],
#  [5, 'T134', 10, 12, 'Dosage', 'One (1)', '5-98'],
#  [5, 'T68', 12, 13, 'Form', 'Tablet', '5-98'],
#  [5, 'T69', 13, 14, 'Route', 'PO', '5-98'],
#  [5, 'T135', 14, 16, 'Frequency', 'DAILY (Daily)', '5-98'],
#  [5, 'T136', 1, 2, 'Drug', 'Levothyroxine', '5-105'],
#  [5, 'T137', 2, 4, 'Strength', '100 mcg', '5-105'],
#  [5, 'T138', 4, 5, 'Form', 'Tablet', '5-105'],
#  [5, 'T139', 6, 8, 'Dosage', 'One (1)', '5-105'],
#  [5, 'T140', 8, 9, 'Form', 'Tablet', '5-105'],
#  [5, 'T141', 9, 10, 'Route', 'PO', '5-105'],
#  [5, 'T142', 10, 12, 'Frequency', 'DAILY (Daily)', '5-105'],
#  [5, 'T78', 1, 3, 'Drug', 'Valganciclovi r', '5-112'],
#  [5, 'T75', 3, 5, 'Strength', '450 mg', '5-112'],
#  [5, 'T143', 5, 6, 'Form', 'Tablet', '5-112'],
#  [5, 'T145', 7, 9, 'Dosage', 'Two (2)', '5-112'],
#  [5, 'T76', 9, 10, 'Form', 'Tablet', '5-112'],
#  [5, 'T77', 10, 11, 'Route', 'PO', '5-112'],
#  [5, 'T144', 11, 16, 'Frequency', 'BID (2 times a day)', '5-112'],
#  [5, 'T62', 4, 6, 'Drug', 'Metronidazol e', '5-119'],
#  [5, 'T59', 6, 8, 'Strength', '500 mg', '5-119'],
#  [5, 'T146', 8, 9, 'Form', 'Tablet', '5-119'],
#  [5, 'T147', 10, 12, 'Dosage', 'One (1)', '5-119'],
#  [5, 'T60', 12, 13, 'Form', 'Tablet', '5-119'],
#  [5, 'T61', 13, 14, 'Route', 'PO', '5-119'],
#  [5, 'T148', 14, 18, 'Frequency', 'Q8H (every 8 hours)', '5-119'],
#  [5, 'T70', 4, 5, 'Drug', 'Lorazepam', '5-126'],
#  [5, 'T71', 5, 7, 'Strength', '0.5 mg', '5-126'],
#  [5, 'T149', 7, 8, 'Form', 'Tablet', '5-126'],
#  [5, 'T73', 9, 10, 'Dosage', '1-2', '5-126'],
#  [5, 'T72', 10, 11, 'Form', 'Tablets', '5-126'],
#  [5, 'T74', 11, 12, 'Route', 'PO', '5-126'],
#  [5, 'T150', 12, 18, 'Frequency', 'Q4H (every 4 hours) as needed', '5-126'],
#  [5, 'T98', 19, 20, 'Reason', 'nausea', '5-126'],
#  [5, 'T196', 21, 22, 'Reason', 'anxiety', '5-126'],
#  [5, 'T12', 1, 2, 'Drug', 'Metoclopramide', '5-135'],
#  [5, 'T13', 2, 4, 'Strength', '10 mg', '5-135'],
#  [5, 'T151', 4, 5, 'Form', 'Tablet', '5-135'],
#  [5, 'T15', 6, 7, 'Dosage', '0.5', '5-135'],
#  [5, 'T14', 7, 8, 'Form', 'Tablet', '5-135'],
#  [5, 'T16', 8, 9, 'Route', 'PO', '5-135'],
#  [5, 'T152', 9, 14, 'Frequency', 'TID (3 times a day)', '5-135'],
#  [5, 'T6', 1, 2, 'Drug', 'Doxepin', '5-142'],
#  [5, 'T7', 2, 4, 'Strength', '25 mg', '5-142'],
#  [5, 'T153', 4, 5, 'Form', 'Capsule', '5-142'],
#  [5, 'T8', 7, 8, 'Form', 'Capsules', '5-142'],
#  [5, 'T10', 8, 9, 'Route', 'PO', '5-142'],
#  [5, 'T9', 9, 12, 'Frequency', 'once a day', '5-142'],
#  [5, 'T19', 1, 2, 'Drug', 'Spironolactone', '5-148'],
#  [5, 'T20', 2, 4, 'Strength', '25 mg', '5-148'],
#  [5, 'T154', 4, 5, 'Form', 'Tablet', '5-148'],
#  [5, 'T155', 6, 8, 'Dosage', 'Two (2)', '5-148'],
#  [5, 'T21', 8, 9, 'Form', 'Tablet', '5-148'],
#  [5, 'T22', 9, 10, 'Route', 'PO', '5-148'],
#  [5, 'T156', 10, 13, 'Frequency', 'twice a day.', '5-148'],
#  [5, 'T83', 1, 2, 'Drug', 'Pyridoxine', '5-155'],
#  [5, 'T84', 2, 4, 'Strength', '100 mg', '5-155'],
#  [5, 'T157', 4, 5, 'Form', 'Tablet', '5-155'],
#  [5, 'T158', 6, 8, 'Dosage', 'Four (4)', '5-155'],
#  [5, 'T85', 8, 9, 'Form', 'Tablet', '5-155'],
#  [5, 'T87', 9, 10, 'Route', 'PO', '5-155'],
#  [5, 'T86', 10, 13, 'Frequency', 'once a day', '5-155'],
#  [5, 'T29', 1, 2, 'Drug', 'Fexofenadine', '5-162'],
#  [5, 'T30', 2, 4, 'Strength', '60 mg', '5-162'],
#  [5, 'T159', 4, 5, 'Form', 'Tablet', '5-162'],
#  [5, 'T160', 6, 8, 'Dosage', 'One (1)', '5-162'],
#  [5, 'T31', 8, 9, 'Form', 'Tablet', '5-162'],
#  [5, 'T32', 9, 10, 'Route', 'PO', '5-162'],
#  [5, 'T161', 10, 13, 'Frequency', 'twice a day', '5-162'],
#  [5, 'T94', 1, 3, 'Drug', 'Allopurino l', '5-169'],
#  [5, 'T90', 3, 5, 'Strength', '300 mg', '5-169'],
#  [5, 'T162', 5, 6, 'Form', 'Tablet', '5-169'],
#  [5, 'T163', 7, 9, 'Dosage', 'One (1)', '5-169'],
#  [5, 'T91', 9, 10, 'Form', 'Tablet', '5-169'],
#  [5, 'T93', 10, 11, 'Route', 'PO', '5-169'],
#  [5, 'T92', 11, 14, 'Frequency', 'once a day', '5-169'],
#  [5, 'T37', 1, 2, 'Drug', 'Benadryl', '5-176'],
#  [5, 'T38', 2, 3, 'Route', 'Oral', '5-176'],
#  [5, 'T47', 3, 4, 'Drug', 'Levaquin', '5-178'],
#  [5, 'T48', 4, 6, 'Strength', '750 mg', '5-178'],
#  ...]

# %%
sents_dict
# Out:
# {'0-0': 'He developed throbbing frontal occipital headache eyes and dry mouth and the headache was alleviated only slightly with ibuprofen',
#  '0-2': 'PAST MEDICAL HISTORY: HIV',
#  '0-3': 'He was in no previous HAART',
#  '0-4': 'Two weeks ago, CD4 count was 171, his viral load 200,000 and was started on Bactrim for Pneumocystis carinii prophylaxis',
#  '0-6': 'MEDICATIONS PRIOR TO ADMISSION: Bactrim , acyclovir',
#  '0-8': 'MCV is 85, sodium 136, potassium 3.4, chloride 102, HCO3 25, BUN 9, creatinine 0.9, glucose',
#  '0-11': 'Induced sputums were performed and the patient was started on intravenous Bactrim and prednisone for a possible PCP infection and levofloxacin for any community-acquired pneumonia',
#  '0-17': 'The patient was also feeling increasingly anxious and was given morphine , pantoprazole , zolpidem , and heparin',
#  '0-21': 'The patient was sedated through Fentanyl , lorazepam and also received nicotine',
#  '0-25': 'As Bactrim has been described to be associated with adult respiratory distress syndrome , Bactrim',
#  '0-28': 'The skin signs markedly improved and his 02 saturation on hospital day nine was now 98% on four liters of oxygen / nasal cannula',
#  '0-31': 'On day ten of his hospital stay, the patient developed withdrawal symptoms consisting of agitation , hallucinations and tachypnea , which could be attributed to the high doses of Fentanyl',
#  '0-35': 'He also still had hallucinations and an oral thrush could be observed and treated with Nystatin',
#  '0-37': 'On day 12 of his hospital stay, the patient was started on Dapsone for PCP prophylaxis , but the patient developed a rash on both arms and the back',
#  '0-40': 'As Dapsone is known to show a cross reactivity to Bactrim in [**10-20**]%, Dapsone',
#  '0-43': 'On day 14 of his hospital stay, all medications except prednisone and the nicotine patch',
#  '0-46': 'Blood cultures will have to be followed up with Dr. [**Last Name (STitle) **], with whom he has an appointment within two weeks and a Infectious Disease Consult for starting of HAART',
#  '0-47': 'His medications on discharge are Nystatin and nicotine patches',
#  '1-0': 'Admission Date: [**2197-10-24**] Discharge Date: [**2197-11-17**] Date of Birth: [**2121-3-31**] Sex: F Service: MEDICINE Allergies: Propoxyphene / Pyridium / Bupropion / Darvon / Penicillins / Claritin / Codeine / Moexipril',
#  '1-8': 'The patient recieved toradol 15mg IV for pain',
#  '1-12': 'Given this new wheeze , she was started on solumedrol',
#  '1-14': 'Pt developed hypercarbic respiratory failure, initially responded to nebs but then began to have decreased air movement despite receiving racemic epi',
#  '1-15': 'Past Medical History: PMH: 1.) HTN -- has been controlled on HCTZ',
#  '1-17': 'On [**10-28**], she was started on vancomycin / flagyl / levofloxacin',
#  '1-20': "She was also started on solumedrol and MDI's",
#  '1-22': 'On [**10-30**], Mrs. [**Known lastname **] then developed hypercarbic respiratory failure and was found to have stridor / wheezing on exam which did not improve with racemic epi',
#  '1-25': 'Mrs. [**Known lastname **] did well post-op with only minor pain',
#  '1-26': 'This was controlled with morphine',
#  '1-27': 'She was maintained on nebulizers for respiratory comfort and morphine for pain control',
#  '1-29': '* 2. PNEUMONIA',
#  '1-30': 'Given her fragile respiratory status, this was treated as pneumonia with levo / flagyl / vancomycin',
#  '1-34': 'The antibiotic',
#  '1-35': 'With IV hydration',
#  '1-37': 'Her abdominal pain was thought to be due to peptic ulcer disease',
#  '1-38': 'She was maintained on her PPI',
#  '1-39': 'Her diarrhea was likely a side effect of her antibiotics',
#  '1-41': 'PROPHYLAXIS: She was maintained on pneumoboots, SC heparin , bowel regimen, and PPI',
#  '1-44': 'Medications on Admission: HCTZ 25 qd Pantoprazole 40 qd Paxil 12.5 qd Senna PRN ASA 81 QD [**Doctor First Name **] 60 PRN Ca + Vit D MVI',
#  '1-60': 'Medications on Admission: HCTZ 25 qd Pantoprazole 40 qd Paxil 12.5 qd Senna PRN ASA 81 QD [**Doctor First Name **] 60 PRN Ca + Vit D MVI ALL: Shellfish Discharge Medications: 1. Paroxetine HCl 10 mg Tablet Sig: One (1) Tablet PO QD',
#  '1-67': 'Disp:*30 Tablet(s)* Refills:*2* 2. Zolpidem Tartrate 5 mg Tablet Sig: One (1) Tablet PO HS',
#  '1-74': 'Disp:*30 Tablet(s)* Refills:*0* 3. Camphor-Menthol 0.5-0.5 % Lotion Sig: One (1) Appl Topical QID',
#  '1-81': 'Disp:*1 bottle* Refills:*0* 4. Salmeterol Xinafoate 50 mcg/Dose Disk with Device Sig: One (1) INH Inhalation Q12H',
#  '1-88': 'Disp:*60 INH* Refills:*0* 5. Ipratropium Bromide 0.02 % Solution Sig: One (1) INH Inhalation Q4H (every 4 hours): with albuterol nebs',
#  '1-97': 'Disp:*180 INH* Refills:*0* 6. Sodium Chloride 0.65 % Aerosol, Spray Sig: [**1-13**] Sprays Nasal TID',
#  '1-103': 'Disp:*1 bottle* Refills:*0* 7. Metoprolol Tartrate 25 mg Tablet Sig: 0.5 Tablet PO TID',
#  '1-110': 'Disp:* 45 Tablet',
#  '1-112': 'Disp:*45 Tablet(s)* Refills:*0* 8. Isosorbide Dinitrate 20 mg Tablet Sig: Two (2) Tablet PO TID',
#  '1-119': 'Disp:*180 Tablet(s)* Refills:*0* 9. Albuterol Sulfate 0.083 % Solution Sig: One (1) INH Inhalation Q3H',
#  '1-126': 'Disp:*240 INH* Refills:*0* 10. Multivitamin Capsule Sig: One (1) Cap PO QD',
#  '1-132': 'Disp:*30 Cap(s)* Refills:*0* 11. Bisacodyl 5 mg Tablet, Delayed Release (E.C.) Sig: Two (2) Tablet, Delayed Release (E.C.) PO DAILY (Daily) as needed for constipation',
#  '1-140': ')(s)* Refills:*0* 12. Bismuth Subsalicylate 262 mg/15 mL Suspension Sig: Fifteen (15) ML PO TID (3 times a day) as needed for diarrhea',
#  '1-148': 'Disp:*1 bottle* Refills:*0* 13. Ibuprofen 400 mg Tablet Sig: One (1) Tablet PO Q8H',
#  '1-155': 'Disp:*90 Tablet(s)* Refills:*0* 14. Pantoprazole Sodium 40 mg Tablet, Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q12H',
#  '1-162': ')(s)* Refills:*0* 15. Guaifenesin 100 mg/5 mL Syrup Sig: 5-10 MLs PO Q6H',
#  '1-169': 'Disp:*1 bottle* Refills:*0* 16. Phenergan 25 mg/mL Solution Sig: Twenty Five (25) MG Injection Q4-6H:PRN as needed for nausea',
#  '1-177': 'Disp:*1 box* Refills:*0* 17. Morphine Sulfate 2 mg/mL Syringe Sig: 1-2 MG Injection Q2H:PRN as needed for pain',
#  '1-185': 'Disp:*40 MG* Refills:*0* 18. Roxanol Concentrate 20 mg/mL Solution Sig: 10-30 MG PO Q4H:PRN as needed for pain',
#  '1-193': 'Disp:*600 mg* Refills:*0* 19. Ativan 2 mg/mL Syringe Sig: 0.5-1 MG Injection Q4-6H:PRN',
#  '1-200': 'Disp:*20 ML* Refills:*0* 20. Ativan 0.5 mg Tablet Sig: 0.5-1 MG PO Q4-6H:PRN',
#  '1-207': 'Disp:*30 tablets* Refills:*0* 21. Colace 100 mg Capsule Sig: One (1) Capsule PO once a day',
#  '1-214': 'Disp:*30 Capsule(s)* Refills:*0* 22. Senna 8.6 mg Capsule Sig: Two (2) Capsule PO BID:PRN as needed for constipation',
#  '1-222': 'Disp:*60 Capsule(s)* Refills:*0* 23. Dulcolax 10 mg Suppository Sig: Ten (10) mg Rectal QD:PRN as needed for constipation',
#  '2-0': 'Admission Date: [**2196-1-25**] Discharge Date: [**2196-2-8**] Date of Birth: [**2149-10-8**] Sex: M Service: SURGERY Allergies: Cefepime',
#  '2-1': 'He was given IV hydration',
#  '2-3': 'POD #1 his urinary output dropped and he received fluid along with 1 unit pRBC',
#  '2-5': 'A CXR was performed which showed mild pulmonary vascular congestion',
#  '2-6': 'He was given a dose of Lasix',
#  '2-7': 'He was empirically started on vanc / zosyn',
#  '2-10': 'The next day ([**2196-2-1**]), his antibiotics were changed to vanc / Cipro / cefepime to cover hospital acquired pneumonia',
#  '2-15': "He was transfused 2 units of pRBC's",
#  '2-17': 'He was started on intermittent Lasix boluses [**2196-2-1**] which resulted in large diuresis',
#  '2-20': 'On [**2196-2-2**], he was started on 20mg PO Lasix daily and was given 40mg IV Lasix as well as a dose of Diamox',
#  '2-28': 'He again responded with a brisk diuresis but then became hypotensive overnight requiring 2.5L of fluid boluses',
#  '2-32': "His HCT in the AM was 21 and he was transfused one unit pRBC's",
#  '2-34': 'The patient also developed an urticarial rash on [**2196-2-2**] and this was attributed to having switched his Cipro from IV to PO',
#  '2-38': 'The Cipro was therefore discontinued and he was started on Levofloxacin',
#  '2-40': 'He remained on the Vancomycin and Levofloxacin for the pneumonia for a total of 7 day course',
#  '2-44': 'He is also receiving Flagyl for a presumed C. difficile colitis',
#  '2-46': 'His treatment with Flagyl will continue for a total of 7 day course',
#  '2-48': 'He was also seen by Psychiatry for his anxiety and depression and it was recommended to increase his Celexa to 40 mg daily from 30 mg and to avoid benzodiazepines as this would put him at risk for delirium',
#  '2-56': 'Medications on Admission: Lisinopril 10mg PO daily Levothyroxine 137 mcg PO daily Lasix 20 mg PO daily Celexa 30 mg PO daily Discharge Medications: 1. lisinopril 10 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '2-79': '2. levothyroxine 137 mcg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '2-86': '3. furosemide 20 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '2-93': '4. citalopram 20 mg Tablet Sig: 1.5 Tablets PO DAILY (Daily)',
#  '2-100': '5. albuterol sulfate 2.5 mg /3 mL (0.083 %) Solution for Nebulization Sig: One (1) Neb Inhalation Q4H (every 4 hours) as needed for shortness of breath or wheezing',
#  '2-108': '6. ipratropium bromide 0.02 % Solution Sig: One (1) Neb Inhalation every six (6) hours. 7. pantoprazole 40 mg Tablet , Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q12H (every 12 hours)',
#  '2-121': '8. heparin (porcine) 5,000 unit /mL Solution Sig: One (1) ML Injection TID (3 times a day)',
#  '2-127': '9. levothyroxine 75 mcg Tablet Sig: Two (2) Tablet PO DAILY (Daily)',
#  '2-133': '10. diphenhydramine HCl 25 mg Capsule Sig: One (1) Capsule PO Q6H (every 6 hours) as needed for pruritis',
#  '2-141': '11. furosemide 20 mg Tablet Sig: One (1) Tablet PO BID (2 times a day)',
#  '2-148': '12. trazodone 50 mg Tablet Sig: 0.5 Tablet PO HS (at bedtime) as needed for insomnia',
#  '2-156': '13. citalopram 20 mg Tablet Sig: Two (2) Tablet PO DAILY (Daily)',
#  '2-163': '14. miconazole nitrate 2 % Powder Sig: One (1) Appl Topical three times a day',
#  '2-170': '15. hydromorphone 2 mg Tablet Sig: 1-2 Tablets PO Q4H (every 4 hours) as needed for pain',
#  '2-178': '16. cholestyramine- sucrose 4 gram Packet Sig: Two (2) Packet PO BID (2 times a day)',
#  '2-185': '17. Vancomycin 1500 mg IV Q 12H Start: [**2196-2-3**] stop date [**2196-2-10**] 18. levofloxacin in D5W 750 mg /150 mL Piggyback Sig: Seven [**Age over 90 1230**]y (750) MG Intravenous Q24H (every 24 hours)',
#  '2-195': '19. metronidazole in NaCl (iso-os) 500 mg /100 mL Piggyback Sig: Five Hundred (500) MG Intravenous Q8H (every 8 hours)',
#  '2-201': '20. insulin regular human 100 unit /mL Solution Sig: One (1) Dose Injection four times a day as needed for per sliding scale',
#  '3-0': 'Admission Date: [**2137-12-28**] Discharge Date: [**2138-1-3**] Service: MEDICINE Allergies: Lisinopril',
#  '3-1': 'Patient took imdur and diovan and pain',
#  '3-4': 'Given 5mg IV lopressor , aspirin , plavix and heparin drip',
#  '3-11': 'She was chest pain free after SL nitro',
#  '3-14': 'She was started on heparin and integrelin gtt',
#  '3-17': 'She was also given ASA 325 , plavix loaded with 600mg and continued on 75mg daily , and continued her BB',
#  '3-24': 'She will plan on long-term Plavix',
#  '3-26': 'She was continued on her BB',
#  '3-27': 'Her valsartan',
#  '3-28': 'Her BP',
#  '3-29': 'She was continued on Diltiazem , Isosorbide , Metoprolol , and valsartan',
#  '3-33': '# PROPHYLAXIS : Heparin drip',
#  '3-36': '# CONTACT: [**Name (NI) **]-daughter [**Name (NI) 15139**] ([**Telephone/Fax (1) 80043**] / ([**Telephone/Fax (1) 80044**] Medications on Admission: -- Atenolol 25 mg Tablet Sig: One (1) Tablet PO DAILY',
#  '3-43': '-- Diltiazem HCl 300 mg Capsule, Sustained Release Sig: One (1) Capsule, Sustained Release PO DAILY',
#  '3-50': '-- Valsartan 160 mg Tablet Sig: One (1) Tablet PO BID',
#  '3-57': '-- Aspirin 81 mg Tablet, Chewable Sig: One (1) Tablet, Chewable PO DAILY',
#  '3-64': '-- Rosuvastatin 20 mg Tablet Sig: One (1) Tablet PO HS',
#  '3-71': '6. Isosorbide Mononitrate 30 mg Tablet Sustained Release 24 hr Sig: 0.5 Tablet Sustained Release 24 hr PO DAILY',
#  '3-78': '7. Latanoprost 0.005 % Drops Sig: One (1) Drop Ophthalmic HS',
#  '3-85': '8. Polyvinyl Alcohol 1.4 % Drops Sig: 1-2 Drops Ophthalmic PRN',
#  '3-92': '9. Betimol 0.5 % Drops Sig: One (1) Ophthalmic once a day',
#  '3-98': 'Betimol 0.5 % Drops Sig: One (1) Ophthalmic once a day Discharge Medications: 1. Valsartan 160 mg Tablet Sig: One (1) Tablet PO twice a day',
#  '3-105': '2. Isosorbide Mononitrate 30 mg Tablet Sustained Release 24 hr Sig: 0.5 Tablet Sustained Release 24 hr PO once a day',
#  '3-112': '3. Latanoprost 0.005 % Drops Sig: One (1) Drop Ophthalmic HS',
#  '3-119': '4. Timolol Maleate 0.5 % Drops Sig: One (1) Ophthalmic Daily',
#  '3-125': '5. Polyvinyl Alcohol 1.4 % Drops Sig: [**12-13**] Ophthalmic prn',
#  '3-130': '6. Diltiazem HCl 180 mg Capsule, Sustained Release Sig: One (1) Capsule, Sustained Release PO DAILY',
#  '3-137': 'Disp:*30 Capsule',
#  '3-138': 'Disp:*30 Capsule, Sustained Release(s)* Refills:*2* 7. Toprol XL 50 mg Tablet Sustained Release 24 hr Sig: Three (3) Tablet Sustained Release 24 hr PO once a day',
#  '3-145': 'Disp:*90 Tablet',
#  '3-146': 'Disp:*90 Tablet Sustained Release 24 hr(s)* Refills:*2* 8. Aspirin 325 mg Tablet Sig: One (1) Tablet PO DAILY',
#  '3-153': 'Disp:*30 Tablet(s)* Refills:*2* 9. Atorvastatin 80 mg Tablet Sig: One (1) Tablet PO DAILY',
#  '3-160': 'Disp:*30 Tablet',
#  '3-161': 'Disp:*30 Tablet(s)* Refills:*2* 10. Clopidogrel 75 mg Tablet Sig: One (1) Tablet PO DAILY',
#  '3-168': 'Disp:*30 Tablet(s)* Refills:*2* 11. Omeprazole 20 mg Capsule, Delayed Release(E.C.) Sig: Two (2) Capsule, Delayed Release(E.C.) PO DAILY',
#  '3-175': 'Please take aspirin 325 mg daily instead of 81 mg daily',
#  '3-180': 'Please take plavix 75 mg daily',
#  '3-183': 'You will start taking Toprol XL 150mg daily',
#  '3-186': 'Your Diltiazem was decreased to 180mg daily',
#  '3-189': 'You were started on omeprazole 40mg daily',
#  '3-192': 'You will start Lipitor 80mg daily',
#  '4-0': 'Admission Date: [**2120-8-30**] Discharge Date: [**2120-9-15**] Date of Birth: [**2051-9-25**] Sex: M Service: CARDIOTHORACIC Allergies: aspirin / Codeine / Penicillins / Iodine Attending:[**First Name3 (LF) 165**] Chief Complaint: Chest Pain Major Surgical or Invasive Procedure: [**2120-9-2**] Cardiac Cath [**2120-9-5**] Urgent coronary artery bypass graft x5: Left internal mammary artery to left anterior descending artery and saphenous vein grafts to diagonal ramus obtuse marginal and posterior descending arteries History of Present Illness: 68 year old male with insulin dependent DM , HTN, obesity admitted to CCU for aspirin',
#  '4-7': 'POSTBYPASS: The patient is AV paced on low dose phenylephrine infusion',
#  '4-10': 'He underwent a cardiac cath on [**9-2**] which revealed severe three vessel coronary artery disease',
#  '4-11': 'On post-op day one he was started on beta-blockers / statin / aspirin / diuretics',
#  '4-15': 'His Lasix was stopped, IVF',
#  '4-17': 'Medications on Admission: - Metformin 1000 mg qam - Humalin-N 30 units daily - Humalin-R 30 units daily - Lisinopril 20 daily - paroxetine 20 daily Discharge Medications: 1. atorvastatin 40 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '4-39': 'Disp:*60 Tablet(s) * Refills:*2* 2. paroxetine HCl 20 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '4-47': 'Disp:*60 Tablet(s) * Refills:*2* 3. docusate sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)',
#  '4-55': 'Disp:*60 Capsule(s) * Refills:*2* 4. aspirin 81 mg Tablet, Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO DAILY (Daily)',
#  '4-64': ')(s)* Refills:*2* 5. omeprazole 20 mg Capsule, Delayed Release(E.C.) Sig: Two (2) Capsule, Delayed Release(E.C.) PO DAILY (Daily)',
#  '4-72': ')(s)* Refills:*2* 6. metformin 500 mg Tablet Sig: One (1) Tablet PO BID (2 times a day)',
#  '4-79': 'Disp:*60 Tablet(s) * Refills:*2* 7. acetaminophen 325 mg Tablet Sig: Two (2) Tablet PO Q4H (every 4 hours) as needed for pain , fever',
#  '4-89': '8. metoprolol tartrate 25 mg Tablet Sig: 0.5 Tablet PO BID (2 times a day)',
#  '4-96': 'Disp:*60 Tablet(s) * Refills:*2* 9. senna 8.6 mg Capsule Sig: One (1) Capsule PO twice a day',
#  '4-104': 'Disp:*1 box* Refills:*2* 12. insulin regular human 100 unit/mL Solution Sig: Fifteen (15) units Injection every morning : [**Month (only) 116**] need to increase to 30 units',
#  '4-111': '13. Humulin N 100 unit/mL Suspension Sig: Fifteen (15) units Subcutaneous every morning : [**Month (only) 116**] need to increase to 30 units',
#  '4-118': '14. furosemide 20 mg Tablet Sig: One (1) Tablet PO once a day for 5 days',
#  '4-126': 'Disp:*5 Tablet(s) * Refills:*0* 15. potassium chloride 10 mEq Tablet Extended Release Sig: One (1) Tablet Extended Release PO once a day for 5 days',
#  '4-135': 'Disp:*5 Tablet Extended Release(s) * Refills:*0* Discharge Disposition: Home With Service Facility: Community Nurse [**First Name (Titles) **] [**Last Name (Titles) **] Care,Inc Discharge Diagnosis: Coronary artery disease s/p coronary artery bypass graft x 5 Past medical history: Diabetes Hypertension Arthritis Kidney Stones Bullet wound to right leg s/p Back surgery s/p Right rotator cuff repair Discharge Condition: Alert and oriented x3 nonfocal Ambulating with steady gait Incisional pain managed with oral analgesia',
#  '5-0': 'Admission Date: [**2103-8-7**] Discharge Date: [**2103-9-23**] Date of Birth: [**2056-3-4**] Sex: F Service: MEDICINE Allergies: Compazine',
#  '5-1': 'She received a liter of normal saline , but no bisphosphonate',
#  '5-4': 'Following IV hydration and zometa',
#  '5-7': 'Her post- chemo',
#  '5-8': 'She developed a LLL pnuemonia towards the end of her hospitalization and was discharged on a 10 day course of levaquin',
#  '5-11': 'She also had CXR evidence of LLL pneumonia and had been discharged on levaquin',
#  '5-13': 'She had also developed C.dif , and CMV viremia , which had been maintained on PO flagyl x 14d and valganciclovir',
#  '5-19': '- [**10-29**]: The patient developed a pruritic, papular rash',
#  '5-20': 'She was seen in the internal medicine and dermatology clinics on several occasions and was treated with antibiotics , triamcinolone , clobetasol , and IV triamcinolone',
#  '5-25': '- [**2101-1-10**]: Interferon alpha at 3M units 3x/wk',
#  '5-28': '- [**2101-1-26**]: Interferon alpha increased to 6Munits 3x/wk',
#  '5-31': '- [**2101-2-23**]: Interferon alpha decreased to 4.5Munits 3x/wk',
#  '5-34': '- [**2101-8-4**]: The patient presented for a follow-up evaluation with clear evidence of disease progression. Interferon alpha was increased to 6M units three times weekly and bexarotene was started at 150mg daily , decreased to 75mg daily',
#  '5-42': '- [**2101-8-25**]: Mtx added to interferon alpha and bexarotene and the dose was up-titrated to 45mg weekly',
#  '5-47': 'The patient was prescribed vorinostat 400mg daily (started [**2101-10-27**]) with continuation of interferon alpha 6M units TIW',
#  '5-53': 'Due to thrombocytopenia , interferon alpha was decreased to 3M units 3x/wk',
#  '5-57': '- [**2101-12-22**]: Cycle 1 Day 1 liposomal doxorubicin plus gemcitabine',
#  '5-59': '- [**2101-12-22**]: Cycle 1 Day 1 liposomal doxorubicin plus gemcitabine. Vorinostat and interferon alpha',
#  '5-61': 'Side Effect: severe palmar-plantar erythrodysesthesia [**12-26**] to liposomal doxorubicin',
#  '5-62': '- [**2102-1-17**]: Cycle 1 Day 1 bortezomib plus gemcitabine , dose-reduced during Cycle 2 due to neutropenia',
#  '5-65': '- [**2102-2-9**] 3M units TIW Interferon alpha',
#  '5-68': '- [**2102-5-26**]: Following a treatment break, the patient was started on pentostatin 4mg /m2 weekly x 4 doses with reinitiation of interferon alpha at 3Munits 3x/wkly , increased to 3M units 5x/wkly',
#  '5-77': '- [**2102-12-25**] Initiation of ONTAK',
#  '5-78': '- [**2103-5-29**]: Hypercalcemia : IVF and Zometa',
#  '5-81': 'Decision to resume ONTAK',
#  '5-82': 'Following gadolinium',
#  '5-83': 'However, for evaluation of subtle process, MRI before and after IV gadolinium',
#  '5-85': '>100,000 ORGANISMS/ML.. PRESUMPTIVE IDENTIFICATION. Piperacillin /tazobactam',
#  '5-86': 'SENSITIVITIES: MIC expressed in MCG/ML _________________________________________________________ ESCHERICHIA COLI | AMPICILLIN ------------ 4 S AMPICILLIN /SULBACTAM -- 4 S CEFAZOLIN ------------- <=4 S CEFEPIME -------------- <=1 S CEFTAZIDIME ----------- <=1 S CEFTRIAXONE ----------- <=1 S CIPROFLOXACIN --------- =>4 R GENTAMICIN ------------ <=1 S MEROPENEM -------------<=0.25 S NITROFURANTOIN -------- <=16 S TOBRAMYCIN ------------ <=1 S TRIMETHOPRIM /SULFA',
#  '5-98': 'Medications on Admission: 1. Folic Acid 1 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '5-105': '2. Levothyroxine 100 mcg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '5-112': '3. Valganciclovi r 450 mg Tablet Sig: Two (2) Tablet PO BID (2 times a day)',
#  '5-119': 'Disp:*60 Tablet(s)* Refills:*2* 4. Metronidazol e 500 mg Tablet Sig: One (1) Tablet PO Q8H (every 8 hours)',
#  '5-126': 'Disp:*28 Tablet(s)* Refills:*0* 5. Lorazepam 0.5 mg Tablet Sig: 1-2 Tablets PO Q4H (every 4 hours) as needed for nausea , anxiety',
#  '5-135': '6. Metoclopramide 10 mg Tablet Sig: 0.5 Tablet PO TID (3 times a day)',
#  '5-142': '7. Doxepin 25 mg Capsule Sig: [**11-25**] Capsules PO once a day',
#  '5-148': '8. Spironolactone 25 mg Tablet Sig: Two (2) Tablet PO twice a day.',
#  '5-155': '9. Pyridoxine 100 mg Tablet Sig: Four (4) Tablet PO once a day',
#  '5-162': '10. Fexofenadine 60 mg Tablet Sig: One (1) Tablet PO twice a day',
#  '5-169': '11. Allopurino l 300 mg Tablet Sig: One (1) Tablet PO once a day',
#  '5-176': '12. Benadryl Oral',
#  '5-178': 'Benadryl Oral 13. Levaquin 750 mg Tablet Sig: One (1) Tablet PO once a day for 9 days',
#  '5-186': 'Line flush order Sodium chloride 5-10ml pre- and post infusion Heparin 10units /ml',
#  '5-191': 'Line flush order Sodium chloride 5-10ml pre- and post infusion Heparin 10units/ml [**12-29**] ml infused as a final flush 15. Metoclopramid e 5 mg Tablet Sig: One (1) Tablet PO three times a day as needed for nausea',
#  '6-0': 'Admission Date: [**2146-3-22**] Discharge Date: [**2146-3-24**] Date of Birth: [**2106-12-1**] Sex: M Service: MEDICINE Allergies: Penicillins / Keflex / Ciprofloxacin / Sulfa (Sulfonamides) / Clarithromycin / Demerol / Red Dye / Haldol',
#  '6-7': 'Also of note, he recently completed a course of azithromycin for a skin boil',
#  '6-9': 'He was given a total of 3L IVFs in the ED with improvement of his tachycardia',
#  '6-12': 'He was also given morphine and zofran',
#  '6-14': 'Subsequently, his SBP dropped to the 80s and high 70s , and was not improving with IVFs',
#  '6-16': 'He was started on peripheral dopamine',
#  '6-18': 'He was given vancomycin , flagyl , and gentamicin',
#  '6-21': 'He has multiple abx',
#  '6-22': '[**3-21**] CT ABD/PELVIS: CT PELVIS WITH IV CONTRAST',
#  '6-24': 'Plan: # Hypotension',
#  '6-25': 'Family deferred CVL; team discussed risks of dopamine peripherally',
#  '6-27': 'Family deferred CVL; team discussed risks of dopamine peripherally. Dopamine was initially given for ~10 hours to maintian MAPs>60',
#  '6-30': 'Pt was initially treated for possible aspiration pna and cdiff with vanco , gentamicin , and flagyl',
#  '6-35': 'On hospital day #2, gentamicin and vancomycin were discontinued and flaygl',
#  '6-38': 'The patient clinically improved and was discharged home on loperamide',
#  '6-39': '# Hypotension',
#  '6-40': 'Pt was treated with IVF and initially with dopamine',
#  '6-42': '# Abd pain / gerd',
#  '6-44': 'Pt remained on his at-home PPI and H2 blocker',
#  '6-46': '# Seizure d/o : continued home phenobarb and diazepam',
#  '6-49': 'Medications on Admission: 1. Mesalamine DR 1200 mg PO BID',
#  '6-53': 'Mesalamine DR 1200 mg PO BID 2. Citalopram Hydrobromide 40 mg PO DAILY',
#  '6-57': 'Citalopram Hydrobromide 40 mg PO DAILY 3. PHENObarbital 32.4 mg tabs 3 tabs PO HS',
#  '6-64': 'PHENObarbital 32.4 mg tabs 3 tabs PO HS 4. Diazepam 6 mg PO HS',
#  '6-68': 'Diazepam 6 mg PO HS 5. Pantoprazole 40 mg PO Q12H',
#  '6-72': 'Pantoprazole 40 mg PO Q12H 6. Famotidine 20 mg PO HS',
#  '6-76': 'Famotidine 20 mg PO HS 7. Nasonex 1 SPRY NU DAILY',
#  '6-81': 'Nasonex 1 SPRY NU DAILY Discharge Medications: 1. Diazepa m 2 mg Tablet [**Month/Year (2) **]: Three (3) Tablet PO HS (at bedtime)',
#  '6-88': '2. Phenobarbital 30 mg Tablet [**Month/Year (2) **]: Three (3) Tablet PO HS (at bedtime)',
#  '6-95': '3. Famotidine 20 mg Tablet [**Month/Year (2) **]: One (1) Tablet PO BID (2 times a day)',
#  '6-102': '4. Citalopram 20 mg Tablet [**Month/Year (2) **]: Two (2) Tablet PO DAILY (Daily)',
#  '6-109': '5. Pantoprazole 40 mg Tablet , Delayed Release (E.C.) [**Month/Year (2) **]: One (1) Tablet, Delayed Release (E.C.) PO every twenty-four(24) hours',
#  '6-116': '6. Loperamide 2 mg Capsule [**Month/Year (2) **]: One (1) Capsule PO QID (4 times a day) as needed for diarrhea',
#  '6-124': 'Disp:*30 Capsule(s)',
#  '6-125': 'Disp:*30 Capsule(s)* Refills:*1* 7. Fluticasone 50 mcg /Actuation Spray , Suspension [**Month/Year (2) **]: One (1) Spray Nasal DAILY (Daily)',
#  '7-0': 'Two weeks ago, he was diagnosed with sinusitis / sinus infection and given antibiotics',
#  '7-3': 'Notably, he had been taking ibuprofe n 800 mg q3h for headache associated with sinusitis',
#  '7-7': 'Took insulin',
#  '7-8': 'His insulin',
#  '7-9': 'He admits to taking insulin about 5 times per week',
#  '7-11': 'Further, when he does take it, he taked a standing dose of 10U Reg and 30U of 70/30',
#  '7-15': 'He does feel episodes of hypoglycemia if he does not eat following insulin : sweating , palpitations , and anxiety',
#  '7-20': 'In the MICU, he was placed on insulin drip , IVF , and electrolytes (most notably K)',
#  '7-24': 'He was receiving standing NPH [**Hospital1 **] and Regular ISS with meals',
#  '7-27': 'His anion gap closed. Potassium and Phos',
#  '7-29': 'Discharge Medications: 1. Pantoprazol e 40 mg Tablet , Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q24H (every 24 hours)',
#  '7-36': ')(s)* Refills:*2* 2. Insulin Lispro 100 unit /mL Insulin Insulin Pen Sig: As per sliding scale Units Subcutaneous four times a day : Use number of units indicated on sliding scale for your measured blood glucose level before breakfast, lunch, dinner, and at bedtime',
#  '7-45': 'Disp:*2 Pens* Refills:*5* 3. Insulin Glargine 300 unit /3 mL Insulin Pen Insulin Pen Sig: Forty (40) Units Subcutaneous at bedtime',
#  '7-52': 'Disp:*2 Pens* Refills:*2* 4. Lancets Misc Sig: One (1) lancet Miscellaneous qachs',
#  '7-56': 'Test strips One test strip qachs dispense 120 Discharge Disposition: Home Discharge Diagnosis: Primary: Diabetic ketoacidosis, IDDM with features of insulin',
#  '7-57': 'This episode of DKA happened becuase you were not regularly taking insulin',
#  '7-58': 'In order to control your sugars , you need to follow the Insulin',
#  '7-60': 'You will have to take 2 types of insulin',
#  '7-61': 'You will take a dose of long acting insulin (Lantus) every night',
#  '7-63': 'You will take a dose of Humalog insulin before every meal based on the sliding scale',
#  '7-66': 'If you find that you are unable to follow the above insulin',
#  '7-67': 'Due to your high use of Motrin before admission, you irritated the lining of your stomach',
#  '7-69': 'Thus, we treated this problem with a medicine to decrease the acid in your stomach called pantoprazole',
#  '7-71': 'You need to schedule an appointment with you primary care doctor within the next few weeks to followup your stomach pain after taking Motrin',
#  '8-0': 'Name: [**Known lastname **],[**Known firstname 8328**] Unit No: [**Numeric Identifier 8329**] Admission Date: [**2122-1-10**] Discharge Date: [**2122-2-5**] Date of Birth: [**2059-1-8**] Sex: F Service: MEDICINE Allergies: Percocet / Motrin / Nsaids / Aspirin / Dilantin Attending:[**First Name3 (LF) 417**] Addendum: Captopril dose on discharge adjusted to 6.25mg TID from 12.5mg TID',
#  '9-0': 'Admission Date: [**2185-11-15**] Discharge Date: [**2185-11-24**] Date of Birth: [**2126-1-11**] Sex: F Service: MEDICINE Allergies: Keflex / Ciprofloxacin / Ertapenem',
#  '9-3': 'They admit that she often fights against taking lactulose',
#  '9-4': 'She may have spit out her lactulose',
#  '9-5': 'ROS: unable to obtain Past Medical History: Hepatitis C, Genotype 1: Diagnosed in [**2185-1-8**] with last VL 263,000 in [**8-/2185**] Cirrhosis ( Methotrexate and Hepatitis C Induced) Portal Hypertension Chronic Kidney Disease with baseline Cr 1.8-2.0 Diastolic CHF: Grade I diastolic dysfunction [**7-17**], EF 75% Ascites Diuretic-Resistant Esophageal Varices per report; however, EGD [**7-/2185**] reports normal esophagus Psoriasis with Arthropathy - s/p Methotrexate x 15 years ( MTX d/c in 12.07 when patient developed ascites and now uses halobetasol cream',
#  '9-14': '# Altered Mental Status: Given her hx of hep C cirrhosis and recent TIPs procedure, her AMS was thought to be most likely due to hepatic encephalopathyy',
#  '9-15': 'She was reported to have a hx of poor compliance with lactulose',
#  '9-16': 'Upon arrival in the MICU she was started on lactulose and rifaximine',
#  '9-18': 'Given her AMS, she was considered high risk for aspiration, and she was started on empiric treatment with vanc / aztreonam / azithromycin ( allergic to cipro and keflex ) for nosocomial or aspiration PNA',
#  '9-25': 'While there was no known hx of EtOH abuse, thiamine IV',
#  '9-27': 'She is being discharged on Rifaximin and furosemide',
#  '9-29': 'It is unclear if she received IVF',
#  '9-30': 'The diffuse maculopapular rash appeared to be new, and looks more like a hypersensitivity reaction , likely to ertapenem',
#  '9-33': 'Pt has known allergies to Keflex ad Cipro , and had received ertapenem',
#  '9-37': 'She was treated with topical clobetasol cream to the rash on abdomen and lower extremities (avoiding folds), and hydrocortisone 2.5% cream to rash',
#  '9-45': '# Cirrhosis [**3-12**] Hep C: Pt was treated as described above with lactulose and rifaximine as well as a PPI',
#  '9-49': '# VRE : Pt had blood culture [**11-16**] which grew VRE sensitive to daptomycin and linezolid',
#  '9-52': '# VRE: Pt had blood culture [**11-16**] which grew VRE sensitive to daptomycin and linezolid in [**2-11**] bottles. Daptomycin',
#  '9-53': 'The pt should be continued on IV daptomycin to complete a 14 day',
#  '9-56': 'She received albumin 25g in 500cc NS x 2',
#  '9-59': '# Hypercalcemia : Pt had transient hypercalcemia to 10.8 this admission thought to be [**3-12**] Calcium and vitamin D',
#  '9-62': 'Medications on Admission: Metoclopramide 5mg TID Pantoprazole 40 mg daily Clobetasol 0.05 % Cream [**Hospital1 **] Ergocalciferol (Vitamin D2) 50,000 unit QWednesday Calcium -Cholecalciferol (D3) 500 (1,250)-400 mg-unit [**Hospital1 **] Nystatin 100,000 unit /mL 5ml QID Lactulose 30ml [**Hospital1 **] Furosemid e 40 mg daily Spironolactone 25 mg daily',
#  '9-88': 'Discharge Medications: 1. Heparin Flush ( 10 units /ml ) 2 mL IV PRN line flush PICC, heparin dependent: Flush with 10mL Normal Saline followed by Heparin as above daily and PRN',
#  '9-101': '2. Daptomycin 500 mg Recon Soln Sig: Four Hundred (400) mg Intravenous Q48H (every 48 hours) : Please continue for 9 days',
#  '9-108': '3. Clobetasol 0.05 % Cream Sig: One (1) Appl Topical [**Hospital1 **] (2 times a day) as needed for psoriasis',
#  '9-115': '4. Furosemide 40 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '9-122': '5. Spironolacton e 25 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '9-129': '6. Lactulose 10 gram /15 mL Syrup Sig: Thirty (30) ML PO twice a day',
#  '9-135': '7. Metoclopramid e 10 mg Tablet Sig: One (1) Tablet PO TID (3 times a day)',
#  '9-142': '8. Nystatin 100,000 unit /mL Suspension Sig: Five (5) ML PO QID (4 times a day)',
#  '9-148': '9. Rifaximi n 200 mg Tablet Sig: Two (2) Tablet PO TID (3 times a day)',
#  '9-155': '10. Hydrocortisone 2.5 % Cream Sig: One (1) Appl Rectal',
#  '9-160': '11. Thiamine HCl 100 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '9-167': '12. Pantoprazole 40 mg Tablet , Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q24H (every 24 hours)',
#  '9-174': '13. Acetaminophen 325 mg Tablet Sig: One (1) Tablet PO Q6H (every 6 hours) as needed for pain',
#  '9-182': 'Discharge Disposition: Extended Care Discharge Diagnosis: Primary: Vancomycin Resistant Enterococcus Bacteremia',
#  '9-184': 'This was likely due to encephalopathy which cleared with lactulose',
#  '9-186': 'You will continue on an antibiotic, Daptomycin , intravenously for a total of 14 days',
#  '9-189': 'Of note, the patient was hypercalcemic',
#  '9-190': 'She had been taking ergocalciferol and cholecalciferol',
#  '10-0': 'Toxicology was consulted and the patient was given 90mg of Methylene blue',
#  '10-2': 'The patient also received Racemic epi & heliox prior to intubation for stridor',
#  '10-5': 'Transfer VS 135 148/95 CMV Peep 10 Fi02100 on Propofol',
#  '10-6': 'Brief Hospital Course: # Respiratory failure / Methemeglobinemia : The patient was intubated with sats in the high 90s after methylene blue',
#  '10-9': 'Cardiac enzymes were trended and were stable. Reglan',
#  '10-10': 'Toxicology followed during stay in MICU and methylene blue',
#  '10-11': 'A number of medication changes were also made, including starting Mirtazapine for appetite stimulation per palliative care, and Acetylcysteine and Codeine/Guiafenesin to promote productive coughing',
#  '10-16': '# Transient hypotension : The patient developed transient hypotension in the setting of propofol boluses',
#  '10-19': 'Blood pressure normalized with fluid boluses and in the absence of fever or leukocytosis, sepsis was deemed unlikely and empiric Vanc / Zosyn',
#  '10-21': 'Medications on Admission: Fibersource HN Liquid Sig: 1560 (1560) cc PO once a day',
#  '10-27': 'Medications on Admission: Fibersource HN Liquid Sig: 1560 (1560) cc PO once a day: goal rate of 65 cc/hr. Ipratropium Bromide 0.02 % Q6 PRN Fentanyl 25 mcg/hr Patch 72 hr Docusate Sodium 50 mg/5 mL PO BID Albuterol Sulfate 2.5 mg /3 mL Q4 PRN Acetylcysteine 20 % (200 mg/mL) Solution Sig: 6-10 MLs Q6h Enoxaparin 60 mg SC BID Ferrous Sulfate 300 mg PO Daily Metoclopramide 10 mg PO Q6H Metoprolol Tartrate 12.5 PO BID Morphine 10 mg/5 mL Solution Sig: [**6-16**] mL PO Q2H (every 2 hours) as needed for pain',
#  '10-70': 'Ipratropium Bromide 0.02 % Q6 PRN Fentanyl 25 mcg/hr Patch 72 hr Docusate Sodium 50 mg/5 mL PO BID Albuterol Sulfate 2.5 mg /3 mL Q4 PRN Acetylcysteine 20 % (200 mg/mL) Solution Sig: 6-10 MLs Q6h Enoxaparin 60 mg SC BID Ferrous Sulfate 300 mg PO Daily Metoclopramide 10 mg PO Q6H Metoprolol Tartrate 12.5 PO BID Morphine 10 mg/5 mL Solution Sig: [**6-16**] mL PO Q2H (every 2 hours) as needed for pain. Ipratropium-Albuterol Q6H PRN Senna 8.8 mg/5 mL PRN Guaifenesin 50 mg/5 mL PO Q6PRN Lidocaine-Diphenhyd -[**Doctor Last Name **]-Mag-[**Doctor Last Name **] 200-25-400-40 mg/30 mL Q6 PRN',
#  '10-82': 'Ipratropium-Albuterol Q6H PRN Senna 8.8 mg/5 mL PRN Guaifenesin 50 mg/5 mL PO Q6PRN Lidocaine-Diphenhyd-[**Doctor Last Name **]-Mag-[**Doctor Last Name **] 200-25-400-40 mg/30 mL Q6 PRN Discharge Medications: 1. Docusate Sodium 50 mg/5 mL Liquid Sig: Ten (10) mL PO BID',
#  '10-89': '2. Ipratropium Bromide 0.02 % Solution Sig: One (1) inhalation Inhalation every six (6) hours',
#  '10-95': '3. Fentanyl 25 mcg/hr Patch 72 hr Sig: One (1) patch Transdermal every seventy-two (72) hours',
#  '10-102': '4. Albuterol Sulfate 2.5 mg/0.5 mL Solution for Nebulization Sig: [**2-8**] pulvules Inhalation every four (4) hours as needed for shortness of breath or wheezing',
#  '10-110': '5. Acetylcysteine 20 % (200 mg/mL) Solution Sig: [**7-17**] mL Miscellaneous [**Hospital1 **] ( 2 times a day',
#  '10-114': '6. Enoxaparin 60 mg/0.6 mL Syringe Sig: One (1) syringe Subcutaneous Q12H',
#  '10-121': '7. Ferrous Sulfate 300 mg (60 mg Iron) Tablet Sig: One (1) Tablet PO once a day',
#  '10-128': '8. Metoclopramide 10 mg Tablet Sig: One (1) Tablet PO QIDACHS',
#  '10-135': '9. Metoprolol Tartrate 25 mg Tablet Sig: 0.5 Tablet PO twice a day',
#  '10-142': '10. Morphine 10 mg/5 mL Solution Sig: [**6-16**] mL PO Q2hrs as needed for pain',
#  '10-149': '11. Senna 8.8 mg/5 mL Syrup Sig: [**6-16**] mL PO twice a day as needed for constipation',
#  '10-156': '12. Lidocaine-Diphenhyd -[**Doctor Last Name **]-Mag-[**Doctor Last Name **] 200-25-400-40 mg/30 mL Mouthwash Sig: 15-30 mL Mucous membrane every six (6) hours as needed for Throat pain',
#  '10-164': '13. Codeine-Guaifenesin 10-100 mg/5 mL Syrup Sig: 5-10 MLs PO BID',
#  '10-171': 'Disp:*600 1* Refills:*2* 14. Mirtazapine 15 mg Tablet Sig: One (1) Tablet PO HS',
#  '10-178': 'Disp:*30 Tablet(s)* Refills:*0* 15. Sodium Chloride 3 % Solution for Nebulization Sig: One (1) neb Inhalation every eight (8) hours',
#  '10-184': 'Tube Feeds Fibersource HN Liquid 1560 cc once a day',
#  '11-0': 'He was found to have a HCT of 19 , and was given 3 units prbc',
#  '11-3': '1) GI bleed',
#  '11-4': 'He also received a PPI',
#  '11-5': 'He was transfused 3 units PRBCs',
#  '11-7': '3) Smoking - Given nicotine patch',
#  '11-10': 'Medications on Admission: ibuprofen 2 tabs 3-4 times weekly for " cold prevention',
#  '11-15': 'Medications on Admission: ibuprofen 2 tabs 3-4 times weekly for "cold prevention" Discharge Medications: 1. Prilosec 20 mg Capsule, Delayed Release(E.C.) Sig: One (1) Capsule, Delayed Release(E.C.) PO twice a day for 14 days',
#  '11-23': ')(s)* Refills:*0* 2. Tetracycline 250 mg Capsule Sig: Two (2) Capsule PO Q6H (every 6 hours)',
#  '11-30': 'Disp:*240 Capsule(s)* Refills:*2* 3. Bismuth Subsalicylate 262 mg Tablet, Chewable Sig: Two (2) Tablet PO QID (4 times a day) for 14 days',
#  '11-38': 'Disp:*112 Tablet(s)* Refills:*0* 4. Metronidazole 500 mg Tablet Sig: One (1) Tablet PO TID (3 times a day) for 14 days',
#  '12-0': 'Admission Date: [**2194-12-7**] Discharge Date: [**2194-12-23**] Date of Birth: [**2118-3-21**] Sex: M Service: CARDIOTHORACIC Allergies: Amiodarone',
#  '12-1': 'Past Medical History: idiopathic thrombocytopenic purpura hepatitis C x8-10years coronary artery disease aortic stenosis hypertension hyperlipidemia atrial fibrillation pulmonary fibrosis secondary to amiodarone',
#  '12-3': 'An abdominal ultrasound showed no signs of splenomegaly and his heparin',
#  '12-4': 'His chronic thrombocytopenia',
#  '12-5': 'He received platelet transfusions',
#  '12-7': 'His Coumadin was restarted on [**12-20**] for his atrial fibrillation',
#  '12-9': "Medications on Admission: Coumadin 2.5mg PO daily Atacand 32mg PO daily Lopressor 100mg PO BID Insulin NPH 22 [**Hospital1 **] Glucotrol 5 ' Digoxin 0.125 ' Lipitor 20 ' Celexa 20 ' Protonix 40",
#  '12-33': "Medications on Admission: Coumadin 2.5mg PO daily Atacand 32mg PO daily Lopressor 100mg PO BID Insulin NPH 22 [**Hospital1 **] Glucotrol 5' Digoxin 0.125' Lipitor 20' Celexa 20' Protonix 40' Discharge Medications: 1. Acetaminophen 325 mg Tablet Sig: Two (2) Tablet PO Q4H (every 4 hours) as needed",
#  '12-40': '2. Aspiri n 81 mg Tablet, Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO DAILY (Daily)',
#  '12-47': '3. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)',
#  '12-54': '4. Oxycodone- Acetaminophen 5-325 mg Tablet Sig: 1-2 Tablets PO Q4H (every 4 hours) as needed for pain',
#  '12-62': '5. Ranitidine HCl 150 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '12-69': '6. Warfarin 5 mg Tablet Sig: One (1) Tablet PO once a day',
#  '12-76': '7. Metoprolol Tartrate 25 mg Tablet Sig: Three (3) Tablet PO BID (2 times a day)',
#  '12-83': '8. Magnesium Hydroxide 400 mg /5 mL Suspension Sig: Thirty (30) ML PO Q6H (every 6 hours) as needed',
#  '12-89': '9. Bisacody l 10 mg Suppository Sig: One (1) Suppository Rectal HS (at bedtime) as needed',
#  '12-96': '10. Lasix 20 mg Tablet Sig: One (1) Tablet PO twice a day for 7 days',
#  '12-104': '11. Lasix 20 mg Tablet Sig: One (1) Tablet PO once a day for 7 days',
#  '12-112': '12. Citalopra m 20 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '12-119': '13. Atorvastati n 20 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '12-126': '14. Humulin N 100 unit/mL Suspension Sig: Eleven (11) units Subcutaneous twice a day',
#  '12-132': '15. Humalog 100 unit/mL Cartridge Sig: One (1) Units Subcutaneous four times a day as needed for hyperglycemia : insulin sliding scale',
#  '13-0': 'He had diarrhea, and was found to be positive for C.dif (presumably [**1-1**] recent Abx treatment for SBP), and was placed on flagyl',
#  '13-2': 'He was treated with octreotide , midodrine , and albumin for likely HRS',
#  '13-6': 'He was initially treated with levofloxacin',
#  '13-7': 'Past Medical History: cirrhosis ([**1-1**] EtOH) h/o hepatic encephalopathy h/o SBP h/o esophageal varices (EGD [**2148**]) C.diff positive (currently on Flagyl',
#  '13-9': '>100,000 ORGANISMS/ML.. COAG NEG STAPH does NOT require contact precautions, regardless of resistance Oxacillin RESISTANT Staphylococci MUST be reported as also RESISTANT to other penicillins , cephalosporins , carbacephems , carbapenems , and beta-lactamase inhibitor combinations',
#  '13-15': '>100,000 ORGANISMS/ML.. COAG NEG STAPH does NOT require contact precautions, regardless of resistance Oxacillin RESISTANT Staphylococci MUST be reported as also RESISTANT to other penicillins, cephalosporins, carbacephems, carbapenems, and beta-lactamase inhibitor combinations. Rifampin',
#  '13-16': 'He was continued on cipro for SBP prophylaxis',
#  '13-18': "Pt's initial U/S was unremarkable for portal vein thrombus, subsequent Abd U/S with doppler as well as CT and MRI, notable for Portal vein thrombus. Anticoagulation",
#  '13-19': "Patient's renal function decreased rapidly during this episode of hepatic decompensation, suggesting hepatorenal syndrome",
#  '13-20': 'Patient was started on octreotide , midodrine , and albumin',
#  '13-23': 'The patient was maintained on midodrine and octreotide for possible hepatorenal syndrome and was additionally treated with IV albumin',
#  '13-28': 'The patient was maintained on midodrine and octreotide for possible hepatorenal syndrome and was additionally treated with IV albumin, which was discontinued on [**2150-7-11**]. Midodrine was increased to 12.5mg',
#  '13-30': 'He received FFP / Cryo',
#  '13-32': 'He recieved several units of PRBC for low HCT',
#  '13-34': 'Had some bleeding',
#  '13-35': 'Was given conjugated estrogen and Vitamin K x 3',
#  '13-38': '# HEPATIC ENCEPHALOPATHY',
#  '13-39': "Patient's mental status much improved with lactulose",
#  '13-40': 'The patient was maintained on lactulose for encephalopathy',
#  '13-42': 'Medications on Admission: MEDS (at OSH): Lactulose 30 ml PO TID Maalox [**9-28**] ml PO Q6H PRN Metronidazole 500 mg PO Albumin 5 % 50 gm IV DAILY Midodrine HCl 7.5 mg PO TID Calcium Carbonate 500 mg PO QID PRN Multivitamins 1 CAP PO DAILY Octreotide Acetate 200 mcg SC Q8H',
#  '13-74': 'Medications on Admission: MEDS (at OSH): Lactulose 30 ml PO TID Maalox [**9-28**] ml PO Q6H PRN Metronidazole 500 mg PO Albumin 5% 50 gm IV DAILY Midodrine HCl 7.5 mg PO TID Calcium Carbonate 500 mg PO QID PRN Multivitamins 1 CAP PO DAILY Octreotide Acetate 200 mcg SC Q8H Discharge Medications: 1. Insulin Regular Human 100 unit/mL Solution Sig: One (1) injection Injection ASDIR (AS DIRECTED): according to sliding scale',
#  '13-80': '2. Oxycodone 5 mg Tablet Sig: 1-2 Tablets PO Q4-6H (every 4 to 6 hours) as needed for pain',
#  '13-88': 'Disp:*100 Tablet(s)* Refills:*0* 3. Lactulose 10 g/15 mL Syrup Sig: Thirty (30) ML PO TID',
#  '13-94': 'Disp:*qs for 1 month ml* Refills:*2* 4. Hydrocortisone 2.5 % Cream Sig: One (1) Appl Rectal [**Hospital1 **] (2 times a day) as needed for hemorrhoids',
#  '13-101': 'Disp:*1 tube* Refills:*0* 5. Polyvinyl Alcohol-Povidone 1.4-0.6 % Dropperette Sig: [**12-1**] Drops Ophthalmic PRN',
#  '13-107': '6. B Complex-Vitamin C-Folic Acid 1 mg Capsule Sig: One (1) Cap PO DAILY',
#  '13-114': 'Disp:*90 Cap(s)* Refills:*2* 7. Camphor-Menthol 0.5-0.5 % Lotion Sig: One (1) Appl Topical [**Hospital1 **] ( 2 times a day ) as needed for itching',
#  '13-122': 'Disp:*1 bottle* Refills:*0* 8. Pantoprazole 40 mg Tablet, Delayed Release',
#  '13-125': 'Sig: One (1) Tablet, Delayed Release',
#  '13-127': 'Sig: One (1) Tablet, Delayed Release (E.C.) PO Q24H',
#  '14-0': 'Admission Date: [**2106-2-10**] Discharge Date: [**2106-2-23**] Date of Birth: [**2044-3-28**] Sex: M Service: SURGERY Allergies: Demerol / Ativan',
#  '14-2': 'History of Present Illness: The patient is a 60M with history of right sided stage III laryngeal cancer diagnosed in [**2099**] and treated with chemotherapy (adjuvant taxol and cisplatin followed by taxol , cisplatin and etoposide for three total cycles',
#  '14-10': 'Unchanged right and left upper lobe pneumonia versus aspiration. CT CHEST W/ CONTRAST [**2106-2-15**] 4:20 PM CHEST CT WITH INTRAVENOUS CONTRAST',
#  '14-15': '[**2106-2-13**] 3:20 PM CTA ABD W&W/O C & RECONS; CT ABDOMEN W/ CONTRAST CT ABDOMEN WITHOUT AND WITH IV CONTRAST',
#  '14-20': 'The appendix contains contrast',
#  '14-21': 'There is no persistent staining on the delayed images, nor is there contrast within the kidneys on the pre- contrast CT',
#  '14-24': 'No lymphadenopathy or ascites. CT PELVIS WITHOUT AND WITH IV CONTRAST',
#  '14-27': 'Subsequent administration of rectal contrast shows no leakage of contrast',
#  '14-29': 'No lymphadenopathy. CT ARTERIOGRAM WITH IV CONTRAST',
#  '14-32': 'Just distal to the insertion site of the femoral-femoral bypass graft on the left is a round fluid collection that on pre- contrast images is heterogeneous in density and post- contrast',
#  '14-34': 'Brief Hospital Course: Patient was admitted and started on anti-coagulation secondary to LE graft coagulopathy',
#  '14-36': 'Patient was started on a heparin gtt',
#  '14-38': 'Patients Coumadin',
#  '14-39': "Patient's anticoags",
#  '14-40': 'Heme was consulted for this and suggested HIT',
#  '14-41': 'Patient most-likely was sub-therapeutic on lovenox',
#  '14-42': 'Typical dosing for Lovenox is 1mg /kg [**Hospital1 **] and he was only on 30mg / day',
#  '14-46': 'Patient was continued on broad spctrum antibiotics ( Vanco / Clinda / Ceftaz / Flagyl',
#  '14-51': 'Patient was screened for HIT and started on Argatroban',
#  '14-52': 'Patients Argatroban',
#  '14-53': "Patients epidural and NG-tube were DC's post-op day 4 and Clinda",
#  '14-55': 'Patient transferred to VICU and Argatroban and Coumadin',
#  '14-57': "Through-out the patients entire hospital stay the goal was to acquire a therapeutic state between (2.0-3.0) Patient was started on Lovenox sq on final hospital day and it was explained to patient that when he get's discharged from hospital he won't be able to check his lovenox",
#  '14-60': 'It was suggested to patient that he stay in the hospital until his PT becomes therapeutic but the patient requested he leave and go home on Lovenox sub-q',
#  '14-62': "Patient wwas also Dc'd on Coumadin 3mg hs , ASA 81mg qd",
#  '14-68': 'Patient was also given Abx - ( Levo / Flagyl',
#  '14-71': 'Medications on Admission: Coumadin , asa , percocet',
#  '14-74': 'Medications on Admission: Coumadin, asa, percocet Discharge Medications: 1. Fluticasone -Salmeterol 250-50 mcg/Dose Disk with Device Sig: One (1) Disk with Device Inhalation [**Hospital1 **] ( 2 times a day',
#  '14-81': 'Disp:*60 Disk with Device(s)* Refills:*2* 2. Tiotropium Bromide 18 mcg Capsule , w/Inhalation Device Sig: One (1) Cap Inhalation DAILY (Daily)',
#  '14-88': 'Disp:*30 Cap(s)* Refills:*2* 3. Albuterol Sulfate 0.083 % Solution Sig: One (1) Inhalation Q6H (every 6 hours)',
#  '14-94': 'Disp:*4 inhalers* Refills:*2* 4. Ipratropium Bromide 0.02 % Solution Sig: One (1) Inhalation Q6H (every 6 hours)',
#  '14-100': 'Disp:*4 inhalers* Refills:*2* 5. Oxycodone- Acetaminophen 5-325 mg/5 mL Solution Sig: 5-10 MLs PO Q4-6H (every 4 to 6 hours) as needed',
#  '14-106': 'Disp:*100 ML(s)* Refills:*0* 6. Aspiri n 81 mg Tablet Sig: One (1) Tablet PO once a day',
#  '14-113': 'Disp:*30 Tablet(s)* Refills:*2* 7. Metoprolol Tartrate 25 mg Tablet Sig: 1.5 Tablets PO BID (2 times a day)',
# ...
#  '25-5': 'Patient had a dental visit today and took antibiotic prophylaxis ( amoxicillin',
#  '25-7': 'Shortly after, he developed symptoms of nausea , vomiting , diarrhea , fever , chills',
#  '25-12': 'Patient received ceftriaxone 2 gm , vancomycin and flagyl',
#  '25-16': 'After 4 liters of normal saline',
#  '25-18': 'He was started on the sepsis protocol and received a total of 6L of NS',
#  '25-20': 'Patient was started on levophed and it was titrated to 0.05 mcg/kg/min',
#  '25-22': 'In the ICU, he initially required pressors to maintain his blood pressure but his hemodynamics quickly stabilized so that he did not require pressors or IV fluids',
#  '25-27': 'On [**10-19**] he was afebrile with stable vitals on po levofloxacin',
#  '25-29': 'He initially required pressors and IV fluids to support his blood pressure',
#  '25-33': 'The etiology of his SIRS was unclear as his infectious workup was largely negative with the exception of a potential LLL pneumonia',
#  '25-34': 'It was thought that this was most likely due to an anaphylactic reaction to amoxicillin as on further questioning he endorsed pruritis , facial erythema/edema , and that these symptoms felt quite similar to an anaphylactic exposure to bactrim',
#  '25-40': 'He was continued on levofloxacin and given a prescription to complete a seven day',
#  '25-42': 'He still complained of slight nausea at discharge and was given a prescription for compazine',
#  '25-44': '4) CAD / HTN',
#  '25-46': 'At discharge he was restarted on atenolol at 25 mg daily',
#  '25-49': 'He has a follow-up appointment in [**Company 191**] on [**2104-9-22**] and at this time he should have his blood pressure checked and medications adjusted if needed (he was previously taking metoprolol 50 mg and lisinopril 5 mg',
#  '25-53': 'He was continued on his aspirin',
#  '25-54': '5) Hyperlipidemia : He was restarted on his pravastatin',
#  '25-56': 'Medications on Admission: ANDROGEL 1%(50MG) -- Apply to shoulders every day as instructed ASPIRIN 325 mg -- one tablet (s) by mouth daily FOLIC ACID 1MG --One mg every day FOSAMPRENAVIR 700MG --Take two pills twice a day with food KALETRA 33.3-133.3 -- 4 capsules twice a day with food LISINOPRIL 5MG --5 mg every day LORATADINE 10 mg -- 1 tablet (s) by mouth once a day LORAZEPAM 1MG --Take [**12-9**] pill as needed for insomnia METOPROLOL TARTRATE 50MG --50 mg every day PATANOL 0.1 %-- 1-2 drops to each eye twice a day PRAVASTATIN SODIUM 20MG --Take one pill at night RHINOCORT AQUA 32 --[**12-9**] sprays to each nostril once a day TENOFOVIR 300 MG --Take one pill a day with food TRICOR 145MG -- One tablet by mouth every day ZANTAC 300MG -- One tablet at bedtime',
#  '25-127': 'Medications on Admission: ANDROGEL 1%(50MG)--Apply to shoulders every day as instructed ASPIRIN 325 mg--one tablet(s) by mouth daily FOLIC ACID 1MG--One mg every day FOSAMPRENAVIR 700MG--Take two pills twice a day with food KALETRA 33.3-133.3--4 capsules twice a day with food LISINOPRIL 5MG--5 mg every day LORATADINE 10 mg--1 tablet(s) by mouth once a day LORAZEPAM 1MG--Take [**12-9**] pill as needed for insomnia METOPROLOL TARTRATE 50MG--50 mg every day PATANOL 0.1 %--1-2 drops to each eye twice a day PRAVASTATIN SODIUM 20MG--Take one pill at night RHINOCORT AQUA 32 --[**12-9**] sprays to each nostril once a day TENOFOVIR 300 MG--Take one pill a day with food TRICOR 145MG--One tablet by mouth every day ZANTAC 300MG--One tablet at bedtime Discharge Medications: 1. Aspirin 325 mg Tablet Sig: One (1) Tablet PO DAILY',
#  '25-134': 'Disp:*30 Tablet(s)* Refills:*2* 2. Fosamprenavir 700 mg Tablet Sig: Two (2) Tablet PO Q12H',
#  '25-141': 'Disp:*120 Tablet(s)* Refills:*2* 3. Lopinavir-Ritonavir 133.3-33.3 mg Capsule Sig: Four (4) Cap PO BID',
#  '25-148': 'Disp:*240 Cap(s)* Refills:*2* 4. Tenofovir Disoproxil Fumarate 300 mg Tablet Sig: One (1) Tablet PO DAILY',
#  '25-155': 'Disp:*30 Tablet(s)* Refills:*2* 5. Levofloxacin 500 mg Tablet Sig: One (1) Tablet PO Q24H (every 24 hours) for 3 days',
#  '25-163': 'Disp:*3 Tablet(s)* Refills:*0* 6. Oxycodone-Acetaminophen 5-325 mg Tablet Sig: 1-2 Tablets PO Q4-6H (every 4 to 6 hours) as needed for headache for 3 days',
#  '25-172': 'Disp:*15 Tablet(s)* Refills:*0* 7. Pravastatin 20 mg Tablet Sig: One (1) Tablet PO once a day',
#  '25-179': 'Disp:*30 Tablet(s)* Refills:*2* 8. Patanol 0.1 % Drops Sig: 1-2 drops Ophthalmic twice a day',
#  '25-186': 'Disp:*1 bottle* Refills:*2* 9. Atenolol 25 mg Tablet Sig: One (1) Tablet PO once a day',
#  '25-193': 'Disp:*30 Tablet(s)* Refills:*0* 10. AndroGel 1 % (50 mg) Gel in Packet Sig: One (1) packet Transdermal once a day',
#  '25-200': 'Disp:*30 packets* Refills:*2* 11. Folic Acid 1 mg Tablet Sig: One (1) Tablet PO once a day',
#  '25-207': 'Disp:*30 Tablet(s)* Refills:*2* 12. Loratadine 10 mg Tablet Sig: One (1) Tablet PO once a day',
#  '25-214': 'Disp:*30 Tablet(s)* Refills:*2* 13. Tricor 145 mg Tablet Sig: One (1) Tablet PO once a day',
#  '25-221': 'Disp:*30 Tablet(s)* Refills:*2* 14. Compazine 10 mg Tablet Sig: One (1) Tablet PO every eight (8) hours as needed for nausea for 1 weeks',
#  '25-230': 'SIRS 2. ? amoxicillin anaphylaxis',
#  '25-232': 'Please refrain from using amoxicillin',
#  '25-233': 'Until this visit please only take atenolol for your blood pressure',
#  '26-0': 'Brief Hospital Course: 56 year old man with a history of chronic L>R painful lymphedema was admitted to the hospital on [**2207-8-16**] with severe cellulitis which we treated with aggressive ACE wrap and elevation, IV antibiotics and IV diuresis',
#  '26-4': 'Despite antibiotics ( vanco , cipro , flagyl and zosyn',
#  '26-9': 'He also developed a new erythema over trunk',
#  '26-10': 'His antibiotics were discontinued and he was started on ceftaroline',
#  '26-12': 'At this point, his antibiotic was then changed to Linezolid',
#  '26-13': 'In terms of his medications: - We weaned his oxycontin from 40mg / day to 30mg / day',
#  '26-18': '- He was restarted on coumadin on [**2207-9-1**] secondary to his atrial fibrillation',
#  '26-20': '- We did not restart Moexipril 30 mg twice daily',
#  '26-23': '- He will continue on the linezolid',
#  '26-24': "Medications on Admission: ASA 325 , Amlodipine 10 , Carvedilol 25 [**Hospital1 **], Clobestasol qAM , Furosemide 40 '', Glipizide 5 , Moexipril 30 '', Rosuvastatin 5 , oxycontin 20",
#  '26-42': 'Discharge Medications: 1. Rosuvastatin Calcium 5 mg PO DAILY',
#  '26-46': 'Rosuvastatin Calcium 5 mg PO DAILY 2. Warfarin 5 mg PO ONCE Duration: 1',
#  '26-51': 'Warfarin 5 mg PO ONCE Duration: 1 Doses 3. GlipiZIDE 5 mg PO DAILY',
#  '26-55': 'GlipiZIDE 5 mg PO DAILY 4. Clobetasol Propionate 0.05 % Cream 1 Appl TP',
#  '26-61': 'Clobetasol Propionate 0.05% Cream 1 Appl TP [**Hospital1 **] 5. Carvedilol 25 mg PO BID',
#  '26-65': 'Carvedilol 25 mg PO BID 6. Amlodipine 10 mg PO DAILY',
#  '26-69': 'Amlodipine 10 mg PO DAILY 7. Aspirin 325 mg PO DAILY',
#  '26-73': 'Aspirin 325 mg PO DAILY 8. Furosemide 40 mg PO BID',
#  '26-77': 'MEDICATIONS: We started you on a new medication called coumadin to prevent blood clots from your atrial fibrillation',
#  '26-80': 'Dr. [**Last Name (STitle) 36516**], your PCP, [**Name10 (NameIs) **] monitor your INRs and adjust your coumadin',
#  '26-81': 'You will be given a new prescription for pain medication',
#  '26-82': 'We restarted your coumadin',
#  '26-83': 'Your PCP will manage your coumadin',
#  '26-84': 'We have also decreased your pain medications',
#  '26-85': 'You were taking 20mg twice daily of oxycontin',
#  '26-88': 'On [**2207-9-1**], we decreased you oxycontin to 20mg in the AM and 10mg at night',
#  '26-93': 'MEDICATIONS: We started you on a new medication called coumadin to prevent blood clots from your atrial fibrillation',
#  '26-96': 'Dr. [**Last Name (STitle) 36516**], your PCP, [**Name10 (NameIs) **] monitor your INRs and adjust your coumadin',
#  '26-97': 'You will be given a new prescription for pain medication',
#  '26-98': 'We restarted your coumadin',
#  '26-99': 'Your PCP will manage your coumadin',
#  '26-100': 'We have also decreased your pain medications',
#  '26-101': 'You were taking 20mg twice daily of oxycontin',
#  '26-104': 'On [**2207-9-1**], we decreased you oxycontin to 20mg in the AM and 10mg at night',
#  '27-0': 'Admission Date: [**2188-10-21**] Discharge Date: [**2188-11-3**] Date of Birth: [**2112-12-21**] Sex: F Service: MEDICINE Allergies: Fish Product Derivatives Attending:[**First Name3 (LF) 759**] Chief Complaint: GI bleed Major Surgical or Invasive Procedure: Colonoscopy EGD History of Present Illness: History of Present Illness: 75 year old woman on Coumadin and Plavix , s/p mechanical MVR',
#  '27-3': 'In PCP office she noted t hree black tarry stools',
#  '27-4': 'She usually takes MiraLax',
#  '27-5': 'The patient has a history of peptic ulcer disease',
#  '27-6': 'She has been maintained on ranitidine 150 mg b.i.d',
#  '27-9': 'Patient was given protonix 40 IV x 1',
#  '27-13': "Past Medical History: CAD: s/p 1 vessel CABG [**2177**] Valvular dz: s/p mechanical MV replacement [**2177**] H/o supraventricular tachycardia TIA's (on plavix",
#  '27-15': 'Serial hematocrits Brief Hospital Course: Assessment and Plan: 75 year old woman on Coumadin and Plavix , s/p mechanical MVR , h/o GI bleed (ten years ago), now presenting with GI bleeding in the setting of a supratherapeutic INR',
#  '27-19': 'She was monitored with serial hematocrits, which trended downward precipitating transfusion with 1 unit of blood',
#  '27-21': 'Her anti-coagulation with Plavix and Coumadin',
#  '27-24': 'After, she was re-started on coumadin with a heparin bridge to therapeutic INR, and her plavix',
#  '27-27': '# Mechanical MV replacement',
#  '27-28': 'The patient is on a higher dose of Coumadin ( 5.5mg',
#  '27-30': 'Per discussion with cardiology, her anti-coagulation',
#  '27-31': 'All anticoagulation was held pending her EGD, and she was started on a heparin drip',
#  '27-34': 'After her colonoscopy, she was restarted on Coumadin and a heparin drip',
#  '27-37': "# CAD s/p 1 vessel CABG [**2177**]: The patient's beta blocker",
#  '27-39': "# TIA's (on plavix ): Plavix",
#  '27-42': 'Medications on Admission: Lipitor 80 Plavix 75 Maxalt ML T 10 prn migraine Amoxicillin prn dental Atenolol 12.5 Alendronate 70 EpiPen prn fish Ambien 10 qhs Coumadin 5.5 everyday except Sat , on Sat pt takes 4mg Skelaxin 800 qhs Zantac 150mg [**Hospital1 **] meds at hospital: Maxalt-MLT *NF* 10 mg Oral daily prn migraine Oxymetazoline 1 SPRY NU [**Hospital1 **] Lorazepam 0.25 mg IV ONCE MR1 Pantoprazole 8 mg/hr IV INFUSION',
#  '27-89': 'Medications on Admission: Lipitor 80 Plavix 75 Maxalt ML T 10 prn migraine Amoxicillin prn dental Atenolol 12.5 Alendronate 70 EpiPen prn fish Ambien 10 qhs Coumadin 5.5 everyday except Sat, on Sat pt takes 4mg Skelaxin 800 qhs Zantac 150mg [**Hospital1 **] meds at hospital: Maxalt-MLT *NF* 10 mg Oral daily prn migraine Oxymetazoline 1 SPRY NU [**Hospital1 **] Lorazepam 0.25 mg IV ONCE MR1 Pantoprazole 8 mg/hr IV INFUSION Discharge Medications: 1. Rizatriptan 10 mg Tablet Sig: One (1) Tablet PO daily prn () as needed for migraine',
#  '27-97': '2. Atorvastatin 40 mg Tablet Sig: Two (2) Tablet PO DAILY (Daily)',
#  '27-104': '3. Zolpidem 5 mg Tablet Sig: Two (2) Tablet PO HS (at bedtime)',
#  '27-111': '4. Warfarin 5 mg Tablet Sig: 5.5 mg every day but Saturday , 4mg on Saturday',
#  '27-118': 'Warfarin 5 mg Tablet Sig: 5.5 mg every day but Saturday, 4mg on Saturday. Tablets PO Once Daily at 4 PM : 5.5mg every day but Saturday',
#  '27-123': 'On saturday take 4mg',
#  '27-125': '5. Plavix 75 mg Tablet Sig: One (1) Tablet PO once a day',
#  '27-132': '6. Atenolol 25 mg Tablet Sig: 0.5 Tablet PO DAILY (Daily)',
#  '27-139': '7. Alendronate 70 mg Tablet Sig: One (1) Tablet PO once a week',
#  '27-146': '8. EpiPen 0.3 mg/0.3 mL Pen Injector Sig: One (1) Intramuscular once a day as needed for anaphylaxis',
#  '27-153': '9. Skelaxin 800 mg Tablet Sig: One (1) Tablet PO at bedtime',
#  '27-160': '10. Clopidogrel 75 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '27-167': '11. Ranitidine HCl 150 mg Capsule Sig: One (1) Capsule PO twice a day',
#  '27-174': 'Valvular disease: status post mechanical Mechanical valve replacement [**2177**] (on coumadin',
#  '27-176': 'History of supraventricular tachycardia 4. Transient ischemic attacks (on plavix',
#  '27-178': '* We restarted your Coumadin',
#  '27-179': 'You should take your Coumadin as per your prior regimen ( 5.5mg every day but Saturday , on Saturday take 4mg',
#  '28-0': 'Admission Date: [**2109-1-25**] Discharge Date: [**2109-1-31**] Date of Birth: [**2032-11-24**] Sex: F Service: MEDICINE Allergies: Aspirin / Lipitor',
#  '28-2': 'History of Present Illness: Ms. [**Known lastname 1968**] is a 76F with CAD s/p CABG on plavix',
#  '28-4': 'Has had CP',
#  '28-5': 'Denies recent NSAID',
#  '28-6': 'She was given 2 SL nitroglycerin , 4 IV morphine , and zofran',
#  '28-13': "Her CP resolved after morphine and nitro x 2 , however she became hypotensive to 80's 30 minutes following nitroglycerin",
#  '28-19': 'Her BP subsequently responded to IVF',
#  '28-20': 'Ordered for 2 units pRBCs',
#  '28-22': 'Past Medical History: Prior GIB while on aspirin',
#  '28-24': '1. Gastrointestinal bleed',
#  '28-25': 'She had small amounts of bright red blood in her stool',
#  '28-26': 'A central line was placed and she was transfused a total of 9 units PRBCs during her six-day',
#  '28-30': 'She was started on IV proton-pump inhibitor',
#  '28-32': 'Her Plavix has been held, and her antihypertensives',
#  '28-34': 'She has chronic chest pain , and is on 2 anti-anginal medications',
#  '28-36': 'During this admission, she reported intermittent episodes of angina',
#  '28-37': 'Her ranolazine was continued but her Imdur and SL nitros held for concern of precipitating hypotension',
#  '28-42': 'She was transfused a total of 9 units PRBCs to keep her hct above 25',
#  '28-45': 'As above, we have held her Plavix and cardiovascular medicines at time of discharge given the recent GI bleed',
#  '28-47': 'She will follow-up with her primary care where decision can be made regarding resumption of her Plavix',
#  '28-48': '3. Diabetes mellitus II',
#  '28-49': 'We held her oral hypoglycemics and kept her on sliding scale humalog insulin',
#  '28-53': 'She will resume her oral hypoglycemics',
#  '28-55': '4. Hypertension',
#  '28-56': 'As above, her metoprolol , Cozaar , Imdur and triamterene /HCTZ',
#  '28-60': '5. Hyperlipidemia',
#  '28-61': 'We continued her outpatient simvastatin',
#  '28-62': 'Medications on Admission: Razolazine 500 [**Hospital1 **] Plavix 75 daily Omeprazole 20 daily Simvastatin 20 daily Triamterene /HCTZ 37.5/25 daily Diltiazem ER 90mg [**Hospital1 **] Metoprolol succinate 25 daily Isosorbide mononitrate 120 daily Losartan 100 daily Glipizide 10 daily Actos 30 daily Insulin',
#  '28-94': 'Medications on Admission: Razolazine 500 [**Hospital1 **] Plavix 75 daily Omeprazole 20 daily Simvastatin 20 daily Triamterene/HCTZ 37.5/25 daily Diltiazem ER 90mg [**Hospital1 **] Metoprolol succinate 25 daily Isosorbide mononitrate 120 daily Losartan 100 daily Glipizide 10 daily Actos 30 daily Insulin Discharge Medications: 1. Simvastati n 10 mg Tablet Sig: Two (2) Tablet PO DAILY (Daily)',
#  '28-101': '2. Ranolazin e 500 mg Tablet Sustained Release 12 hr Sig: One (1) Tablet Sustained Release 12 hr PO BID (2 times a day)',
#  '28-108': '3. Omeprazol e 20 mg Capsule , Delayed Release(E.C.) Sig: One (1) Capsule, Delayed Release(E.C.) PO once a day',
#  '28-115': ')(s)* Refills:*2* 4. Glipizid e 10 mg Tab ,Sust Rel Osmotic Push 24hr Sig: One (1) Tab,Sust Rel Osmotic Push 24hr PO once a day',
#  '28-122': '5. Pioglitazone 30 mg Tablet Sig: One (1) Tablet PO once a day',
#  '28-129': '6. Insulin Glargine 100 unit/mL Cartridge Subcutaneous',
#  '28-133': 'Discharge Instructions: You were hospitalized for treatment of gastrointestinal bleed',
#  '28-134': 'You received nine transfusions of red blood cells',
#  '28-136': 'We have held the Plavix',
#  '28-137': 'We have held the triamterene /hydrochlorthiazide',
#  '28-138': 'We have held the diltiazem',
#  '28-139': 'We have held the metoprolol',
#  ...}

# %%
entity_df = pd.DataFrame(tags_list, columns=['text_id','entity_id','start','end','concept','entity','sent_num']).set_index('entity_id')

# %%
entity_df
# Out:
#            text_id  start  end    concept      entity sent_num
# entity_id
# T29              0     12   13     Reason    headache      0-0
# T12              0     18   19       Drug   ibuprofen      0-0
# T31              0      3    4     Reason         HIV      0-2
# T30              0      5    6       Drug       HAART      0-3
# T7               0     15   16       Drug     Bactrim      0-4
# ...            ...    ...  ...        ...         ...      ...
# T133           302      9   11     Dosage     One (1)  302-129
# T49            302     11   12       Form      Tablet  302-129
# T51            302     12   13      Route          PO  302-129
# T50            302     13   16  Frequency  once a day  302-129
# T134           302     16   19   Duration  for 5 days  302-129
#
# [50946 rows x 6 columns]

# %%
'''
This is to generate relations to a specific format for one of my model, a relation triplet is formated as 
"start_position_1st_entity, end_position_1st_entity, start_position_2nd_entity, end_position_2nd_entity,
relation_type, 1st_entity_type, 2nd_entity_type" Each relation is concatenated by all the relation triplets
within the sentence, seperated by '|'
'''

relations = []
sents = []
for i, an in enumerate(tqdm(anno)):
    text = an.get_text()
    relation = ''
    entity_curr = entity_df[entity_df['text_id']==i]#['sent_num']
    curr_sent = 0
    for k in an.relations.values():
        if k[0][0] not in entity_curr.index or k[1][0] not in entity_curr.index:
            continue
        e1, e2, rel = entity_curr.loc[k[0][0]], entity_curr.loc[k[1][0]], k[2]

        if e1['sent_num'] != e2['sent_num']:
            continue
        if curr_sent == 0:
            relation = ' '.join([str(e1['start']), str(e1['end']-1), str(e2['start']), str(e2['end']-1),
                                   '/'+rel+'/'+k[0][3]+'/'+k[1][3], '|'])
            curr_sent = e1['sent_num']
        elif e1['sent_num'] == curr_sent:           
            relation = ' '.join([relation, str(e1['start']), str(e1['end']-1), str(e2['start']), str(e2['end']-1),
                                   '/'+rel+'/'+k[0][3]+'/'+k[1][3], '|'])
        else:
            relations.append(relation[:-2])  
            sents.append(sents_dict[curr_sent])
            relation = ' '.join([str(e1['start']), str(e1['end']-1), str(e2['start']), str(e2['end']-1),
                                   '/'+rel+'/'+k[0][3]+'/'+k[1][3],'|'])
            curr_sent = e1['sent_num']
        if k[0][3] == 'Reason' and k[1][3]=='Drug' and rel == 'ADE-Drug':
            print(k)
# Out:
#   0%|          | 0/303 [00:00<?, ?it/s]
# (('T243', 34234, 34247, 'Reason', 'Hyperglycemia'), ('T241', 34321, 34329, 'Drug', 'steroids'), 'ADE-Drug')
# (('T111', 1378, 1385, 'Reason', 'itching'), ('T108', 1367, 1370, 'Drug', 'FFP'), 'ADE-Drug')
# (('T119', 5163, 5171, 'Reason', 'GI bleed'), ('T7', 5257, 5265, 'Drug', 'coumadin'), 'ADE-Drug')
# (('T119', 5163, 5171, 'Reason', 'GI bleed'), ('T26', 5287, 5294, 'Drug', 'aspirin'), 'ADE-Drug')
# (('T179', 13587, 13603, 'Reason', 'low blood counts'), ('T177', 13552, 13562, 'Drug', 'vancomycin'), 'ADE-Drug')
# (('T179', 13587, 13603, 'Reason', 'low blood counts'), ('T121', 13566, 13574, 'Drug', 'cefepime'), 'ADE-Drug')
# (('T87', 8275, 8288, 'Reason', 'Hyperglycemia'), ('T85', 8314, 8322, 'Drug', 'steroids'), 'ADE-Drug')
# (('T113', 6733, 6749, 'Reason', 'supratherapeutic'), ('T40', 6686, 6694, 'Drug', 'coumadin'), 'ADE-Drug')
# (('T113', 9636, 9650, 'Reason', 'gastric ulcers'), ('T111', 9674, 9679, 'Drug', 'NSAID'), 'ADE-Drug')
# (('T183', 17789, 17811, 'Reason', 'Junctional Bradycardia'), ('T184', 17833, 17846, 'Drug', 'beta-blockers'), 'ADE-Drug')
# (('T118', 13358, 13383, 'Reason', 'red rash on arms and face'), ('T47', 13387, 13397, 'Drug', 'vancomycin'), 'ADE-Drug')
# (('T59', 3454, 3467, 'Reason', 'hyperglycemia'), ('T61', 3481, 3489, 'Drug', 'steroids'), 'ADE-Drug')
# (('T59', 5277, 5283, 'Reason', 'rigors'), ('T57', 5263, 5267, 'Drug', 'IL-2'), 'ADE-Drug')
# (('T62', 5320, 5331, 'Reason', 'hypotension'), ('T57', 5263, 5267, 'Drug', 'IL-2'), 'ADE-Drug')

# %%
relations[154]
# Out:
# '7 8 5 6 /Strength-Drug/Strength/Drug | 9 11 5 6 /Form-Drug/Form/Drug | 13 14 5 6 /Dosage-Drug/Dosage/Drug | 15 17 5 6 /Form-Drug/Form/Drug | 18 18 5 6 /Route-Drug/Route/Drug | 19 21 5 6 /Frequency-Drug/Frequency/Drug | 22 24 5 6 /Duration-Drug/Duration/Drug'

# %%
sents[154]
# Out:
# 'Disp:*5 Tablet(s) * Refills:*0* 15. potassium chloride 10 mEq Tablet Extended Release Sig: One (1) Tablet Extended Release PO once a day for 5 days'
