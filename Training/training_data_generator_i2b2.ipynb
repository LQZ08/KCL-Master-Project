# %%
import os
from tqdm.notebook import tqdm
import glob
import numpy as np
import pandas as pd
import random
from collections import defaultdict
from nltk.tokenize import sent_tokenize, word_tokenize

# %% [markdown]
# # Read files and annotations

# %%
#This class is provided by i2b2 challenge. I use its functions to get annotations and text

class RecordTrack2(object):
    """Record for Track 2 class."""

    def __init__(self, file_path):
        """Initialize."""
        self.path = os.path.abspath(file_path)
        self.basename = os.path.basename(self.path)
        self.annotations = self._get_annotations()
        # self.text = self._get_text()

    @property
    def tags(self):
        return self.annotations['tags']

    @property
    def relations(self):
        return self.annotations['relations']

    def _get_annotations(self):
        """Return a dictionary with all the annotations in the .ann file."""
        annotations = defaultdict(dict)
        with open(self.path) as annotation_file:
            lines = annotation_file.readlines()
            for line_num, line in enumerate(lines):
                if line.strip().startswith('T'):
                    try:
                        tag_id, tag_m, tag_text = line.strip().split('\t')
                    except ValueError:
                        print(self.path, line)
                    if len(tag_m.split(' ')) == 3:
                        tag_type, tag_start, tag_end = tag_m.split(' ')
                    elif len(tag_m.split(' ')) == 4:
                        tag_type, tag_start, _, tag_end = tag_m.split(' ')
                    elif len(tag_m.split(' ')) == 5:
                        tag_type, tag_start, _, _, tag_end = tag_m.split(' ')
                    else:
                        print(self.path)
                        print(line)
                    tag_start, tag_end = int(tag_start), int(tag_end)
                    annotations['tags'][tag_id] = (tag_id, tag_start ,tag_end, tag_type, tag_text)
            for line_num, line in enumerate(lines):
                if line.strip().startswith('R'):
                    rel_id, rel_m = line.strip().split('\t')
                    rel_type, rel_arg1, rel_arg2 = rel_m.split(' ')
                    rel_arg1 = rel_arg1.split(':')[1]
                    rel_arg2 = rel_arg2.split(':')[1]
                    arg1 = annotations['tags'][rel_arg1]
                    arg2 = annotations['tags'][rel_arg2]
                    annotations['relations'][rel_id] = (arg1,arg2, rel_type)
        return annotations

    def get_text(self):
        """Return the text in the corresponding txt file."""
        path = self.path.replace('.ann', '.txt')
        with open(path) as text_file:
            text = text_file.read()
        return text

# %%
#reading data and create a list of RecordTrack2 class for each file
folder1 = 'training_20180910/'
anno = []
files1 = set([os.path.basename(f) for f in glob.glob(
    os.path.join(folder1, '*.ann'))])
for file in files1:
    anno.append(RecordTrack2(os.path.join(folder1, file)))

# %% [markdown]
# # Generate entities within sentence
#
# Find the offset of each entity within that sentence.
#
# The offset provided by i2b2 is aginst the whole file.
#
# In this section, we will locate the entity, tokenise sentense, and remove extra spaces
#
# The offset I generated in this section is word offset (created by len(text.split()), feel free to change to character offset if needed.

# %%
#function to generate the first entity in a sentence
def first_entity(text, start, end, entity):
        text_before = sent_tokenize(text[:start]) #all the text befere the start of the entity
        sent_num = len(text_before)
        word_before = text_before[-1].split() #words before entity in the current sentence 
        word_start = len(word_before) #start position
        word_end = word_start+len(entity.split()) #end position
        sent_after = sent_tokenize(text[end:])[0] #the left of current sentence
        sent_piece = ' '.join(word_before + entity.split()) #current sentence until the end of first entity, extra spaces removed by .split()
        return word_start, word_end, sent_after, sent_piece

# %%
#function to generate non-first entity in a sentence, same logic sa first_entity function
def entity_within_sent(text, word_end_before, end_before, start, end, entity):
    word_between = text[end_before:start].split()
    word_start = word_end_before + len(word_between)
    word_end = word_start+len(entity.split())
    sent_after = sent_tokenize(text[end:])[0]
    #print(sent_after)
    sent_piece = ' '.join(word_between + entity.split())
    return word_start, word_end, sent_after, sent_piece

# %%
tags_list = []
sents_dict = {}
for i, an in enumerate(tqdm(anno)):
    text = an.get_text()
    tags = pd.DataFrame(an.tags.values()).sort_values(1).values
    #skip used to mark how many entities we have processed within the previous sentence
    skip = 0
    for j, (en_id, start, end, concept, entity) in enumerate(tags):
        #we skip the entities we have processed from last sentence, it will bring us to the first entity in current sentence
        if skip>0:
            skip -= 1
            continue
        #remove entities that across sentences
        if len(sent_tokenize(text[start:end]))>1:
            continue
        word_start, word_end, sent_after, sent_piece = first_entity(text, start, end, entity)
        #'-'.join([str(i),str(j)]) is an unique idenfitier for each sentence in the dataset, 
        #i identify the document and j identify the sentence within the document
        tags_list.append([i, en_id, word_start, word_end, concept, entity, '-'.join([str(i),str(j)])])
        while j+skip+1<len(tags) and end+len(sent_after)>= tags[j+skip+1][1]:
            anno_curr = tags[j+skip+1]
            word_end_before = word_end
            end_before = end
            sent_piece_before = sent_piece
            en_id = anno_curr[0]
            start = anno_curr[1]
            end = anno_curr[2]
            concept = anno_curr[3]
            entity = anno_curr[4]
            word_start, word_end, sent_after, sent_piece = entity_within_sent(text, word_end_before, end_before, start, end, entity)
            sent_piece = ' '. join([sent_piece_before, sent_piece])
            tags_list.append([i, en_id, word_start, word_end, concept, entity, '-'.join([str(i),str(j)])])
            skip += 1
        sents_dict['-'.join([str(i),str(j)])] = sent_piece
# Out:
#   0%|          | 0/303 [00:00<?, ?it/s]

# %%
tags_list
# Out:
# [[0, 'T107', 4, 5, 'Drug', 'Ca-gluconate', '0-0'],
#  [0, 'T108', 6, 8, 'Strength', '10 units', '0-0'],
#  [0, 'T110', 9, 10, 'Drug', 'insulin', '0-0'],
#  [0, 'T111', 15, 17, 'Strength', '15 mg', '0-0'],
#  [0, 'T112', 17, 18, 'Route', 'PO', '0-0'],
#  [0, 'T113', 7, 8, 'Drug', 'Potassium', '0-5'],
#  [0, 'T114', 10, 11, 'Drug', 'acetaminophen', '0-6'],
#  [0, 'T115', 17, 20, 'Drug', 'ibuprofen-containing sleep aid', '0-6'],
#  [0, 'T116', 21, 22, 'Reason', 'insomnia', '0-6'],
#  [0, 'T129', 14, 15, 'Drug', 'lisinopril', '0-9'],
#  [0, 'T40', 16, 17, 'Drug', 'NSAIDs', '0-9'],
#  [0, 'T130', 19, 20, 'Drug', 'potassium', '0-9'],
#  [0, 'T131', 20, 21, 'Drug', 'citrate', '0-9'],
#  [0, 'T132', 5, 6, 'Drug', 'Tamsulosin', '0-13'],
#  [0, 'T133', 7, 9, 'Reason', 'his BPH', '0-13'],
#  [0, 'T134', 15, 16, 'Drug', 'Potassium', '0-15'],
#  [0, 'T135', 21, 22, 'Drug', 'kayexalate', '0-15'],
#  [0, 'T136', 23, 24, 'Drug', 'insulin', '0-15'],
#  [0, 'T1', 8, 9, 'Drug', 'insulin', '0-18'],
#  [0, 'T2', 3, 4, 'Drug', 'Humalog', '0-19'],
#  [0, 'T3', 5, 6, 'Form', 'units', '0-19'],
#  [0, 'T4', 18, 19, 'Drug', 'Lantus', '0-19'],
#  [0, 'T5', 19, 20, 'Strength', '2units', '0-19'],
#  [0, 'T6', 11, 12, 'Drug', 'insulin', '0-23'],
#  [0, 'T7', 1, 2, 'Route', 'oral', '0-24'],
#  [0, 'T8', 3, 4, 'Drug', 'Tamsulosin', '0-25'],
#  [0, 'T9', 10, 11, 'Drug', 'Amlodipine', '0-26'],
#  [0, 'T10', 11, 12, 'Strength', '5mg', '0-26'],
#  [0, 'T11', 13, 15, 'Drug', 'Metoprolol succinate', '0-26'],
#  [0, 'T12', 17, 18, 'Drug', 'Quinapril', '0-29'],
#  [0, 'T13', 3, 4, 'Drug', 'Tamsulosin', '0-30'],
#  [0, 'T14', 15, 16, 'Drug', 'quinapril', '0-31'],
#  [0, 'T15', 17, 18, 'Drug', 'metformin', '0-31'],
#  [0, 'T16', 19, 20, 'Drug', 'glipizide', '0-31'],
#  [0, 'T17', 31, 32, 'Drug', 'glucose', '0-31'],
#  [0, 'T18', 36, 37, 'Drug', 'insulin', '0-31'],
#  [0, 'T19', 47, 48, 'Drug', 'Tamsulosin', '0-31'],
#  [0, 'T20', 11, 12, 'Drug', 'metformin', '0-37'],
#  [0, 'T21', 13, 14, 'Drug', 'glipizide', '0-37'],
#  [0, 'T22', 1, 2, 'Drug', 'Aspirin', '0-39'],
#  [0, 'T23', 2, 4, 'Strength', '162 mg', '0-39'],
#  [0, 'T24', 4, 5, 'Route', 'PO', '0-39'],
#  [0, 'T25', 6, 7, 'Drug', 'Metoprolol', '0-42'],
#  [0, 'T26', 9, 11, 'Strength', '100 mg', '0-42'],
#  [0, 'T27', 11, 12, 'Route', 'PO', '0-42'],
#  [0, 'T28', 8, 9, 'Drug', 'Ezetimibe', '0-45'],
#  [0, 'T29', 9, 11, 'Strength', '10 mg', '0-45'],
#  [0, 'T30', 11, 12, 'Route', 'PO', '0-45'],
#  [0, 'T31', 6, 7, 'Drug', 'Quinapril', '0-48'],
#  [0, 'T32', 7, 9, 'Strength', '20 mg', '0-48'],
#  [0, 'T33', 9, 10, 'Route', 'PO', '0-48'],
#  [0, 'T34', 6, 7, 'Drug', 'MetFORMIN', '0-51'],
#  [0, 'T35', 8, 9, 'Drug', 'Glucophage', '0-51'],
#  [0, 'T36', 10, 12, 'Strength', '1000 mg', '0-51'],
#  [0, 'T37', 12, 13, 'Route', 'PO', '0-51'],
#  [0, 'T38', 13, 14, 'Frequency', 'BID', '0-51'],
#  [0, 'T39', 15, 17, 'Drug', 'potassium citrate', '0-51'],
#  [0, 'T41', 18, 19, 'Dosage', '2', '0-51'],
#  [0, 'T42', 19, 20, 'Form', 'tablets', '0-51'],
#  [0, 'T43', 20, 21, 'Route', 'Oral', '0-51'],
#  [0, 'T44', 21, 22, 'Frequency', 'Daily', '0-51'],
#  [0, 'T45', 15, 17, 'Drug', 'Rosuvastatin Calcium', '0-61'],
#  [0, 'T46', 17, 19, 'Strength', '20 mg', '0-61'],
#  [0, 'T47', 19, 20, 'Route', 'PO', '0-61'],
#  [0, 'T58', 20, 21, 'Frequency', 'DAILY', '0-61'],
#  [0, 'T48', 7, 8, 'Drug', 'GlipiZIDE', '0-65'],
#  [0, 'T49', 9, 11, 'Strength', '10 mg', '0-65'],
#  [0, 'T50', 11, 12, 'Route', 'PO', '0-65'],
#  [0, 'T51', 12, 13, 'Frequency', 'BID', '0-65'],
#  [0, 'T52', 7, 8, 'Drug', 'Amlodipine', '0-69'],
#  [0, 'T53', 8, 10, 'Strength', '5 mg', '0-69'],
#  [0, 'T54', 10, 11, 'Route', 'PO', '0-69'],
#  [0, 'T105', 11, 12, 'Frequency', 'DAILY', '0-69'],
#  [0, 'T55', 8, 9, 'Drug', 'Amlodipine', '0-73'],
#  [0, 'T56', 9, 11, 'Strength', '5 mg', '0-73'],
#  [0, 'T57', 11, 12, 'Route', 'PO', '0-73'],
#  [0, 'T109', 12, 13, 'Frequency', 'DAILY', '0-73'],
#  [0, 'T59', 6, 8, 'Drug', 'Rosuvastatin Calcium', '0-77'],
#  [0, 'T60', 8, 10, 'Strength', '20 mg', '0-77'],
#  [0, 'T61', 10, 11, 'Route', 'PO', '0-77'],
#  [0, 'T117', 11, 12, 'Frequency', 'DAILY', '0-77'],
#  [0, 'T62', 7, 8, 'Drug', 'Aspirin', '0-81'],
#  [0, 'T63', 8, 10, 'Strength', '162 mg', '0-81'],
#  [0, 'T64', 10, 11, 'Route', 'PO', '0-81'],
#  [0, 'T118', 11, 12, 'Frequency', 'DAILY', '0-81'],
#  [0, 'T65', 6, 7, 'Drug', 'Metoprolol', '0-85'],
#  [0, 'T66', 9, 11, 'Strength', '100 mg', '0-85'],
#  [0, 'T67', 11, 12, 'Route', 'PO', '0-85'],
#  [0, 'T119', 12, 13, 'Frequency', 'DAILY', '0-85'],
#  [0, 'T68', 8, 9, 'Drug', 'Tamsulosin', '0-89'],
#  [0, 'T69', 9, 11, 'Strength', '0.4 mg', '0-89'],
#  [0, 'T70', 11, 12, 'Route', 'PO', '0-89'],
#  [0, 'T120', 12, 13, 'Frequency', 'HS', '0-89'],
#  [0, 'T71', 15, 16, 'Drug', 'tamsulosin', '0-89'],
#  [0, 'T72', 16, 18, 'Strength', '0.4 mg', '0-89'],
#  [0, 'T73', 18, 19, 'Dosage', '1', '0-89'],
#  [0, 'T74', 19, 20, 'Form', 'capsule', '0-89'],
#  [0, 'T75', 21, 23, 'Route', 'by mouth', '0-89'],
#  [0, 'T121', 24, 25, 'Frequency', 'bedtime', '0-89'],
#  [0, 'T76', 20, 21, 'Drug', 'Acetaminophen', '0-99'],
#  [0, 'T77', 23, 24, 'Route', 'PO', '0-99'],
#  [0, 'T78', 24, 25, 'Frequency', 'Q6H:PRN', '0-99'],
#  [0, 'T122', 25, 26, 'Reason', 'pain', '0-99'],
#  [0, 'T79', 28, 29, 'Drug', 'acetaminophen', '0-99'],
#  [0, 'T80', 29, 31, 'Strength', '500 mg', '0-99'],
#  [0, 'T81', 31, 32, 'Dosage', '1', '0-99'],
#  [0, 'T82', 32, 33, 'Form', 'tablet', '0-99'],
#  [0, 'T83', 34, 36, 'Route', 'by mouth', '0-99'],
#  [0, 'T84', 36, 38, 'Frequency', 'q6 hour', '0-99'],
#  [0, 'T85', 21, 22, 'Drug', 'Docusate', '0-109'],
#  [0, 'T86', 23, 25, 'Strength', '100 mg', '0-109'],
#  [0, 'T87', 25, 26, 'Route', 'PO', '0-109'],
#  [0, 'T88', 26, 27, 'Frequency', 'BID', '0-109'],
#  [0, 'T89', 29, 30, 'Drug', 'docusate', '0-109'],
#  [0, 'T90', 31, 33, 'Strength', '100 mg', '0-109'],
#  [0, 'T91', 33, 34, 'Dosage', '1', '0-109'],
#  [0, 'T92', 34, 35, 'Form', 'capsule', '0-109'],
#  [0, 'T93', 36, 38, 'Route', 'by mouth', '0-109'],
#  [0, 'T94', 38, 41, 'Frequency', 'twice a day', '0-109'],
#  [0, 'T95', 23, 24, 'Drug', 'Ezetimibe', '0-119'],
#  [0, 'T96', 24, 26, 'Strength', '10 mg', '0-119'],
#  [0, 'T97', 26, 27, 'Route', 'PO', '0-119'],
#  [0, 'T98', 6, 7, 'Drug', 'HumaLOG', '0-122'],
#  [0, 'T99', 10, 11, 'Drug', 'insulin', '0-122'],
#  [0, 'T100', 12, 14, 'Strength', '100 unit', '0-122'],
#  [0, 'T101', 15, 16, 'Form', 'mL', '0-122'],
#  [0, 'T102', 23, 24, 'Drug', 'Humalog', '0-122'],
#  [0, 'T103', 25, 27, 'Strength', '100 unit', '0-122'],
#  [0, 'T104', 28, 29, 'Form', 'mL', '0-122'],
#  [0, 'T106', 5, 6, 'Drug', 'Tamsulosin', '0-129'],
#  [1, 'T87', 4, 5, 'Reason', 'cough', '1-0'],
#  [1, 'T19', 14, 15, 'Drug', 'Azithromycin', '1-0'],
#  [1, 'T105', 4, 5, 'Reason', 'diarrhea', '1-2'],
#  [1, 'T41', 9, 10, 'Drug', 'Azithro', '1-2'],
#  [1, 'T43', 18, 19, 'Reason', 'bradycardia', '1-4'],
#  [1, 'T42', 25, 26, 'Strength', '0.5mg', '1-4'],
#  [1, 'T20', 27, 28, 'Drug', 'Atropine', '1-4'],
#  [1, 'T44', 6, 9, 'Reason', 'grand mal seizure', '1-7'],
#  [1, 'T4', 16, 17, 'Drug', 'Ativan', '1-7'],
#  [1, 'T5', 17, 18, 'Strength', '1mg', '1-7'],
#  [1, 'T15', 16, 17, 'Drug', 'Ceftriaxone', '1-10'],
#  [1, 'T45', 18, 19, 'Drug', 'Levoquin', '1-10'],
#  [1, 'T46', 21, 22, 'Reason', 'PNA', '1-10'],
#  [1, 'T47', 23, 24, 'Reason', 'sepsis', '1-10'],
#  [1, 'T88', 10, 14, 'Reason', 'rhythmic right shoulder jerks', '1-14'],
#  [1, 'T24', 16, 20, 'Reason', 'rolled back right eye', '1-14'],
#  [1, 'T26', 22, 23, 'Drug', 'Ativan', '1-14'],
#  [1, 'T49', 23, 24, 'Strength', '1mg', '1-14'],
#  [1, 'T50', 36, 40, 'Reason', 'contact dermatitis in groin', '1-18'],
#  [1, 'T38', 42, 43, 'Drug', 'hydrocortisone', '1-18'],
#  [1, 'T90', 7, 8, 'Reason', 'CT', '1-20'],
#  [1, 'T89', 10, 11, 'Drug', 'CONTRAST', '1-20'],
#  [1, 'T91', 4, 5, 'Drug', 'CONTRAST', '1-22'],
#  [1, 'T25', 5, 6, 'Drug', 'dilantin', '1-23'],
#  [1, 'T51', 10, 11, 'Drug', 'Carbamazepin', '1-23'],
#  [1, 'T106', 1, 4, 'ADE', 'increased seizure frequency', '1-25'],
#  [1, 'T94', 10, 11, 'ADE', 'toxic', '1-25'],
#  [1, 'T9', 11, 12, 'Drug', 'dilantin', '1-25'],
#  [1, 'T18', 7, 8, 'Drug', 'vancomycin', '1-28'],
#  [1, 'T52', 8, 9, 'Reason', 'emperically', '1-28'],
#  [1, 'T27', 6, 9, 'Drug', 'CARBAMAZEPINE [TEGRETOL XR]', '1-30'],
#  [1, 'T1', 10, 12, 'Strength', '200 mg', '1-30'],
#  [1, 'T54', 12, 16, 'Form', 'Tablet Sustained Release 12hr', '1-30'],
#  [1, 'T2', 17, 18, 'Dosage', '1', '1-30'],
#  [1, 'T28', 18, 20, 'Form', 'Tablet (s)', '1-30'],
#  [1, 'T3', 20, 22, 'Route', 'by mouth', '1-30'],
#  [1, 'T53', 22, 23, 'Frequency', '2/day', '1-30'],
#  [1, 'T29', 29, 30, 'Drug', 'FEXOFENADINE', '1-30'],
#  [1, 'T30', 31, 33, 'Strength', '60 mg', '1-30'],
#  [1, 'T55', 33, 34, 'Form', 'Tablet', '1-30'],
#  [1, 'T32', 35, 36, 'Dosage', '1', '1-30'],
#  [1, 'T31', 36, 38, 'Form', 'Tablet (s)', '1-30'],
#  [1, 'T34', 38, 40, 'Route', 'by mouth', '1-30'],
#  [1, 'T33', 40, 45, 'Frequency', 'twice a day as needed', '1-30'],
#  [1, 'T95', 46, 47, 'Reason', 'rhinitis', '1-30'],
#  [1, 'T96', 48, 49, 'Reason', 'sneezing', '1-30'],
#  [1, 'T56', 67, 68, 'Drug', 'HYDROCORTISONE', '1-30'],
#  [1, 'T57', 69, 71, 'Strength', '2.5 %', '1-30'],
#  [1, 'T58', 71, 72, 'Form', 'Cream', '1-30'],
#  [1, 'T97', 75, 78, 'Route', 'areas of redness', '1-30'],
#  [1, 'T59', 78, 83, 'Frequency', 'twice a day as needed', '1-30'],
#  [1, 'T107', 89, 90, 'Reason', 'rash', '1-30'],
#  [1, 'T10', 99, 101, 'Drug', 'LEVETIRACETAM [KEPPRA]', '1-30'],
#  [1, 'T11', 102, 104, 'Strength', '500 mg', '1-30'],
#  [1, 'T60', 104, 105, 'Form', 'Tablet', '1-30'],
#  [1, 'T13', 106, 107, 'Dosage', '1', '1-30'],
#  [1, 'T12', 107, 109, 'Form', 'Tablet (s)', '1-30'],
#  [1, 'T14', 109, 111, 'Route', 'by mouth', '1-30'],
#  [1, 'T61', 111, 112, 'Frequency', '6/day', '1-30'],
#  [1,
#   'T23',
#   115,
#   120,
#   'Drug',
#   'PHENYTOIN SODIUM EXTENDED [DILANTIN KAPSEAL]',
#   '1-30'],
#  [1, 'T6', 121, 123, 'Strength', '100 mg', '1-30'],
#  [1, 'T7', 123, 124, 'Form', 'Capsule', '1-30'],
#  [1, 'T8', 127, 129, 'Route', 'by mouth', '1-30'],
#  [1, 'T62', 129, 130, 'Frequency', '2/day', '1-30'],
#  [1, 'T63', 7, 10, 'Drug', 'TIMOLOL MALEATE [TIMOPTIC-XE]', '1-64'],
#  [1, 'T64', 11, 13, 'Strength', '0.5 %', '1-64'],
#  [1, 'T65', 13, 16, 'Form', 'Gel Forming Solution', '1-64'],
#  [1, 'T66', 17, 18, 'Dosage', '1', '1-64'],
#  [1, 'T67', 18, 19, 'Form', 'drop', '1-64'],
#  [1, 'T68', 19, 21, 'Route', 'right eye', '1-64'],
#  [1, 'T69', 21, 23, 'Frequency', 'q AM', '1-64'],
#  [1, 'T70', 26, 27, 'Drug', 'BACITRACIN', '1-64'],
#  [1, 'T71', 28, 30, 'Strength', '500 unit/gram', '1-64'],
#  [1, 'T72', 30, 31, 'Form', 'Ointment', '1-64'],
#  [1, 'T73', 33, 35, 'Frequency', 'once daily', '1-64'],
#  [1, 'T74', 37, 39, 'Drug', 'CARBAMIDE PEROXIDE', '1-64'],
#  [1, 'T75', 40, 42, 'Strength', '6.5 %', '1-64'],
#  [1, 'T76', 42, 43, 'Form', 'Drops', '1-64'],
#  [1, 'T77', 44, 47, 'Dosage', 'one dropper full', '1-64'],
#  [1, 'T78', 48, 50, 'Route', 'each ear', '1-64'],
#  [1, 'T79', 50, 53, 'Frequency', 'daily as needed', '1-64'],
#  [1, 'T80', 54, 56, 'Reason', 'ear wax', '1-64'],
#  [1, 'T98', 5, 6, 'Drug', 'antibiotics', '1-82'],
#  [1, 'T37', 4, 5, 'Drug', 'vancomycin', '1-83'],
#  [1, 'T99', 18, 19, 'Reason', 'infection', '1-83'],
#  [1, 'T101', 7, 8, 'Reason', 'seizure', '1-85'],
#  [1, 'T100', 4, 6, 'Drug', 'anti-seizure medications', '1-86'],
#  [1, 'T16', 9, 10, 'Drug', 'Carbamazepine', '1-87'],
#  [1, 'T17', 10, 12, 'Strength', '400mg /600mg', '1-87'],
#  [1, 'T81', 12, 13, 'Frequency', 'am/pm', '1-87'],
#  [1, 'T21', 13, 14, 'Drug', 'Keppra', '1-87'],
#  [1, 'T22', 14, 16, 'Strength', '1500mg /2000mg', '1-87'],
#  [1, 'T82', 16, 17, 'Frequency', 'am/pm', '1-87'],
#  [1, 'T39', 17, 18, 'Drug', 'Phenytoin', '1-87'],
#  [1, 'T40', 18, 20, 'Strength', '150mg /100mg', '1-87'],
#  [1, 'T83', 20, 21, 'Frequency', 'am/pm', '1-87'],
#  [1, 'T35', 26, 27, 'Drug', 'Lamictal', '1-87'],
#  [1, 'T36', 27, 28, 'Strength', '25mg', '1-87'],
#  [1, 'T84', 35, 36, 'Strength', '25mg', '1-87'],
#  [1, 'T85', 36, 38, 'Frequency', 'every week', '1-87'],
#  [1, 'T86', 45, 46, 'Strength', '150mg', '1-87'],
#  [2, 'T1', 9, 10, 'Drug', 'Amoxicillin', '2-0'],
#  [2, 'T12', 43, 44, 'Drug', 'coumadin', '2-0'],
#  [2, 'T13', 45, 47, 'Reason', 'atrial fibrillation', '2-0'],
#  [2, 'T14', 49, 50, 'Reason', 'TIA', '2-0'],
#  [2, 'T73', 3, 5, 'Dosage', '1 U', '2-4'],
#  [2, 'T74', 5, 6, 'Drug', 'PRBC', '2-4'],
#  [2, 'T75', 7, 9, 'Dosage', '2 U', '2-4'],
#  [2, 'T76', 9, 10, 'Drug', 'FFP', '2-4'],
#  [2, 'T77', 12, 14, 'Strength', '5 mg', '2-4'],
#  [2, 'T78', 14, 15, 'Route', 'SC', '2-4'],
#  [2, 'T79', 15, 17, 'Drug', 'vit K', '2-4'],
#  [2, 'T2', 4, 6, 'Reason', 'Atrial fibrillation', '2-11'],
#  [2, 'T15', 10, 11, 'Reason', 'TIA', '2-11'],
#  [2, 'T3', 15, 17, 'Reason', 'chronic anticoagulation', '2-11'],
#  [2, 'T4', 18, 19, 'Drug', 'Coumadin', '2-11'],
#  [2, 'T5', 1, 3, 'Reason', 'Polymyalgia rheumatica', '2-15'],
#  [2, 'T6', 7, 8, 'Drug', 'steroids', '2-15'],
#  [2, 'T7', 10, 11, 'Reason', 'Afib', '2-17'],
#  [2, 'T84', 13, 14, 'Reason', "TIA's", '2-17'],
#  [2, 'T8', 15, 16, 'Drug', 'coumadin', '2-17'],
#  [2, 'T9', 1, 2, 'Reason', 'GIB', '2-20'],
#  [2, 'T10', 8, 9, 'Drug', 'PRBCs', '2-21'],
#  [2, 'T11', 10, 11, 'Drug', 'FFP', '2-21'],
#  [2, 'T16', 8, 9, 'Route', 'PO', '2-23'],
#  [2, 'T17', 9, 10, 'Drug', 'levofloxacin', '2-23'],
#  [2, 'T18', 11, 12, 'Reason', 'neutropenia', '2-23'],
#  [2, 'T19', 1, 3, 'Reason', 'A fib', '2-26'],
#  [2, 'T20', 6, 7, 'Drug', 'digoxin', '2-26'],
#  [2, 'T21', 1, 2, 'Reason', 'Dementia', '2-28'],
#  [2, 'T22', 1, 2, 'Drug', 'Aricept', '2-29'],
#  [2, 'T23', 3, 4, 'Drug', 'Namenda', '2-29'],
#  [2, 'T24', 4, 5, 'Drug', 'Aricept', '2-31'],
#  [2, 'T25', 5, 7, 'Strength', '5 mg', '2-31'],
#  [2, 'T26', 6, 7, 'Drug', 'Coumadin', '2-33'],
#  [2, 'T27', 7, 9, 'Strength', '4 mg', '2-33'],
#  [2, 'T28', 9, 10, 'Frequency', 'M/W/F', '2-33'],
#  [2, 'T29', 11, 13, 'Strength', '5 mg', '2-33'],
#  [2, 'T80', 13, 17, 'Frequency', 'S/[**Doctor First Name **]/Tues', '2-33'],
#  [2, 'T30', 11, 12, 'Drug', 'Detrol', '2-38'],
#  [2, 'T31', 12, 14, 'Strength', '1 mg', '2-38'],
#  [2, 'T32', 6, 7, 'Drug', 'Digoxin', '2-40'],
#  [2, 'T33', 7, 9, 'Strength', '250 mcg', '2-40'],
#  [2, 'T34', 9, 10, 'Frequency', 'qd', '2-40'],
#  [2, 'T35', 5, 6, 'Drug', 'Fosamax', '2-43'],
#  [2, 'T36', 6, 8, 'Strength', '70 mg', '2-43'],
#  [2, 'T37', 8, 9, 'Frequency', 'qweek', '2-43'],
#  [2, 'T38', 5, 6, 'Drug', 'Namenda', '2-46'],
#  [2, 'T39', 6, 8, 'Strength', '10 mg', '2-46'],
#  [2, 'T40', 6, 7, 'Drug', 'MVI', '2-48'],
#  [2, 'T41', 7, 8, 'Frequency', 'qd', '2-48'],
#  [2, 'T42', 3, 5, 'Drug', 'Ca/Vit D', '2-50'],
#  [2, 'T43', 5, 6, 'Frequency', 'qd', '2-50'],
#  [2, 'T44', 6, 7, 'Drug', 'Digoxin', '2-52'],
#  [2, 'T45', 7, 9, 'Strength', '125 mcg', '2-52'],
#  [2, 'T46', 9, 10, 'Form', 'Tablet', '2-52'],
#  [2, 'T47', 11, 13, 'Dosage', 'One (1)', '2-52'],
#  [2, 'T48', 13, 14, 'Form', 'Tablet', '2-52'],
#  [2, 'T49', 14, 15, 'Route', 'PO', '2-52'],
#  [2, 'T50', 15, 17, 'Frequency', 'DAILY (Daily)', '2-52'],
#  [2, 'T81', 1, 2, 'Form', 'Tablet(s', '2-59'],
#  [2, 'T51', 4, 5, 'Drug', 'Memantine', '2-60'],
#  [2, 'T52', 5, 7, 'Strength', '5 mg', '2-60'],
#  [2, 'T53', 7, 8, 'Form', 'Tablet', '2-60'],
#  [2, 'T54', 9, 11, 'Dosage', 'Two (2)', '2-60'],
#  [2, 'T55', 11, 12, 'Form', 'Tablet', '2-60'],
#  [2, 'T56', 12, 13, 'Route', 'PO', '2-60'],
#  [2, 'T57', 13, 14, 'Frequency', 'bid', '2-60'],
#  [2, 'T82', 1, 2, 'Form', 'Tablet(s)', '2-67'],
#  [2, 'T58', 4, 5, 'Drug', 'Donepezil', '2-68'],
#  [2, 'T59', 5, 7, 'Strength', '5 mg', '2-68'],
#  [2, 'T60', 7, 8, 'Form', 'Tablet', '2-68'],
#  [2, 'T61', 9, 11, 'Dosage', 'Two (2)', '2-68'],
#  [2, 'T62', 11, 12, 'Form', 'Tablet', '2-68'],
#  [2, 'T63', 12, 13, 'Route', 'PO', '2-68'],
#  [2, 'T64', 13, 16, 'Frequency', 'HS (at bedtime)', '2-68'],
#  [2, 'T65', 1, 2, 'Drug', 'Levofloxacin', '2-75'],
#  [2, 'T66', 2, 4, 'Strength', '250 mg', '2-75'],
#  [2, 'T67', 4, 5, 'Form', 'Tablet', '2-75'],
#  [2, 'T68', 6, 8, 'Dosage', 'One (1)', '2-75'],
#  [2, 'T69', 8, 9, 'Form', 'Tablet', '2-75'],
#  [2, 'T70', 9, 10, 'Route', 'PO', '2-75'],
#  [2, 'T71', 10, 11, 'Frequency', 'QDAY', '2-75'],
#  [2, 'T72', 12, 15, 'Duration', 'for 7 days', '2-75'],
#  [2, 'T83', 1, 2, 'Form', 'Tablet(s)', '2-83'],
#  [3,
#   'T85',
#   14,
#   25,
#   'Reason',
#   'bilateral DVTs of common femoral, superficial femoral, politeal, and calf veins',
#   '3-0'],
#  [3, 'T8', 6, 8, 'Drug', 'Dalteparin (Fragmin)', '3-1'],
#  [3, 'T86', 8, 9, 'Frequency', 'daily', '3-1'],
#  [3, 'T175', 11, 15, 'Reason', 'O2sat 77% on RA', '3-3'],
#  [3, 'T222', 3, 4, 'Reason', 'hypoxic', '3-4'],
#  [3, 'T87', 11, 12, 'Drug', 'oxygen', '3-4'],
#  [3,
#   'T88',
#   5,
#   17,
#   'Reason',
#   'clot in right main pulmonary artery and branch arteries in the LLL',
#   '3-6'],
#  [3, 'T55', 4, 5, 'Drug', 'heparin', '3-7'],
#  [3, 'T176', 3, 4, 'Reason', 'hypoxemic', '3-8'],
#  [3, 'T177', 7, 8, 'Dosage', '6l', '3-9'],
#  [3, 'T178', 8, 9, 'Route', 'NC', '3-9'],
#  [3, 'T179', 13, 14, 'ADE', 'tachpyneic', '3-9'],
#  [3, 'T89', 1, 2, 'Reason', 'CAD', '3-12'],
#  [3, 'T10', 7, 8, 'Drug', 'plavix', '3-12'],
#  [3, 'T181', 4, 5, 'Reason', 'hypoxic', '3-14'],
#  [3, 'T180', 12, 13, 'Drug', 'oxygen', '3-14'],
#  [3,
#   'T90',
#   5,
#   17,
#   'Reason',
#   'clot in right main pulmonary artery and branch arteries in the LLL.',
#   '3-16'],
#  [3, 'T34', 21, 22, 'Drug', 'heparin', '3-16'],
#  [3, 'T182', 7, 9, 'Dosage', '6 L', '3-18'],
#  [3, 'T183', 9, 10, 'Route', 'NC', '3-18'],
#  [3, 'T184', 14, 15, 'ADE', 'tachpyneic', '3-18'],
#  [3, 'T186', 3, 4, 'Route', 'PSV/CPAP', '3-21'],
#  [3, 'T185', 6, 7, 'Drug', 'Fio2', '3-21'],
#  [3, 'T187', 8, 10, 'Reason', 'sinus tachycardic', '3-21'],
#  [3, 'T161', 5, 6, 'Reason', 'agitation', '3-24'],
#  [3, 'T91', 7, 8, 'Reason', 'delirium', '3-24'],
#  [3, 'T83', 11, 12, 'Drug', 'Zyprexa', '3-24'],
#  [3, 'T93', 11, 13, 'Reason', 'Still agitated', '3-27'],
#  [3, 'T76', 15, 16, 'Drug', 'Versed', '3-27'],
#  [3, 'T92', 17, 18, 'Reason', 'sedation', '3-27'],
#  [3,
#   'T95',
#   11,
#   18,
#   'Reason',
#   'Pressures began to drop to 80-90s systolic',
#   '3-30'],
#  [3, 'T94', 2, 3, 'Drug', 'Neo', '3-31'],
#  [3, 'T27', 3, 4, 'Drug', 'propofol', '3-32'],
#  [3, 'T31', 5, 6, 'Drug', 'fentanyl', '3-32'],
#  [3, 'T188', 8, 9, 'Drug', 'antifungal', '3-34'],
#  [3, 'T189', 8, 9, 'Drug', 'pressor', '3-35'],
#  [3, 'T96', 10, 11, 'Drug', 'vancomycin', '3-36'],
#  [3, 'T7', 12, 13, 'Drug', 'ciprofloxacin', '3-36'],
#  [3, 'T29', 15, 16, 'Drug', 'cefepime', '3-36'],
#  [3, 'T78', 25, 26, 'Drug', 'heparin', '3-36'],
#  [3, 'T97', 26, 27, 'Route', 'gtt', '3-36'],
#  [3, 'T98', 48, 49, 'Drug', 'BB', '3-36'],
#  [3, 'T99', 50, 51, 'Strength', '25', '3-36'],
#  [3, 'T100', 51, 52, 'Frequency', 'TID', '3-36'],
#  [3, 'T190', 62, 63, 'Drug', 'sedation', '3-36'],
#  [3, 'T101', 70, 72, 'Drug', 'beta blocker', '3-36'],
#  [3, 'T125', 91, 92, 'Route', 'IV', '3-36'],
#  [3, 'T16', 92, 93, 'Drug', 'lasix', '3-36'],
#  [3, 'T17', 93, 94, 'Strength', '40mg', '3-36'],
#  [3, 'T77', 112, 113, 'Drug', 'valium', '3-36'],
#  [3, 'T103', 114, 119, 'ADE', 'SBP dropped to 80s systolic', '3-36'],
#  [3, 'T191', 131, 132, 'Drug', 'sedation', '3-36'],
#  [3, 'T49', 162, 163, 'Drug', 'coumadin', '3-36'],
#  [3, 'T192', 163, 164, 'Frequency', 'tmrw', '3-36'],
#  [3, 'T104', 177, 181, 'Reason', 'needed to increase sedation', '3-36'],
#  [3, 'T52', 182, 183, 'Drug', 'fentanyl', '3-36'],
#  [3, 'T38', 185, 186, 'Route', 'IV', '3-36'],
#  [3, 'T69', 186, 187, 'Drug', 'heparin', '3-36'],
#  [3, 'T30', 196, 197, 'Drug', 'heparin', '3-36'],
#  [3, 'T59', 223, 224, 'Drug', 'Heparin', '3-59'],
#  [3, 'T28', 40, 41, 'Drug', 'dilantin', '3-60'],
#  [3, 'T193', 41, 42, 'Strength', '6.6', '3-60'],
#  [3, 'T194', 45, 46, 'Strength', '13.8', '3-60'],
#  [3, 'T227', 5, 6, 'Drug', 'U', '3-63'],
#  [3, 'T229', 7, 9, 'ADE', 'guiac stools', '3-63'],
#  [3, 'T45', 8, 9, 'Drug', 'heparin', '3-65'],
#  [3, 'T4', 6, 7, 'Drug', 'bactrim', '3-66'],
#  [3, 'T70', 10, 11, 'Drug', 'atovaquone', '3-66'],
#  [3, 'T24', 12, 13, 'Drug', 'mucomyst', '3-66'],
#  [3, 'T106', 15, 16, 'Reason', 'secretions', '3-66'],
#  [3, 'T195', 54, 55, 'Reason', 'BMT', '3-66'],
#  [3, 'T50', 57, 58, 'Drug', 'bactrim', '3-66'],
#  [3, 'T56', 59, 60, 'Drug', 'atovaquone', '3-66'],
#  [3, 'T14', 62, 63, 'Drug', 'bactrim', '3-66'],
#  [3, 'T230', 63, 64, 'ADE', 'allergy', '3-66'],
#  [3, 'T107', 64, 69, 'ADE', 'may be causing increased eos', '3-66'],
#  [3, 'T109', 58, 59, 'Drug', 'CVP', '3-76'],
#  [3, 'T110', 59, 60, 'Strength', '10', '3-76'],
#  [3, 'T84', 63, 64, 'Drug', 'lasix', '3-76'],
#  [3, 'T108', 64, 65, 'Strength', '20', '3-76'],
#  [3, 'T12', 1, 2, 'Drug', 'bactrim', '3-80'],
#  [3, 'T196', 40, 44, 'Reason', 'Spiked fever to 103', '3-80'],
#  [3, 'T197', 47, 48, 'Drug', 'tyylenol', '3-80'],
#  [3, 'T111', 55, 56, 'Dosage', '2', '3-80'],
#  [3, 'T112', 57, 58, 'Strength', '40', '3-80'],
#  [3, 'T44', 58, 59, 'Drug', 'Lasix', '3-80'],
#  [3, 'T113', 59, 60, 'Dosage', 'boluses', '3-80'],
#  [3, 'T114', 92, 93, 'Dosage', 'bolus', '3-80'],
#  [3, 'T74', 94, 95, 'Drug', 'Lasix', '3-80'],
#  [3, 'T198', 137, 139, 'Reason', 'A. Fib', '3-80'],
#  [3, 'T115', 140, 145, 'Reason', 'A. flutter (atrial ectopy hybrid)', '3-80'],
#  [3, 'T11', 149, 150, 'Drug', 'digoxin', '3-80'],
#  [3, 'T15', 149, 150, 'Drug', 'Norepinephrine', '3-92'],
#  [3,
#   'T116',
#   152,
#   159,
#   'Drug',
#   'phenylepinephrine (alpha agonist only, no beta agonist',
#   '3-92'],
#  [3, 'T117', 163, 165, 'Dosage', '500 cc', '3-92'],
#  [3, 'T118', 165, 166, 'Drug', 'fluid', '3-92'],
#  [3, 'T119', 166, 167, 'Dosage', 'bolus', '3-92'],
#  [3, 'T120', 170, 171, 'Reason', 'hypotension', '3-92'],
#  [3, 'T199', 22, 24, 'Reason', 'Phos repleted', '3-98'],
#  [3, 'T121', 25, 27, 'Drug', 'pot phos', '3-98'],
#  [3, 'T144', 27, 28, 'Route', 'iv', '3-98'],
#  [3, 'T200', 28, 32, 'Dosage', '15 ml/ 250 cc', '3-98'],
#  [3, 'T202', 32, 33, 'Drug', 'NS', '3-98'],
#  [3, 'T201', 34, 36, 'Reason', 'B-lucan positive', '3-98'],
#  [3, 'T18', 3, 4, 'Drug', 'bactrim', '3-104'],
#  [3, 'T123', 2, 3, 'Drug', 'steroids', '3-105'],
#  [3, 'T124', 1, 2, 'Strength', '20', '3-106'],
#  [3, 'T102', 2, 3, 'Route', 'IV', '3-106'],
#  [3, 'T75', 3, 4, 'Drug', 'lasix', '3-106'],
#  [3, 'T126', 4, 5, 'Dosage', 'x2', '3-106'],
#  [3, 'T39', 6, 7, 'Drug', 'metoprolol', '3-110'],
#  [3, 'T127', 9, 10, 'Drug', 'solumedrol', '3-110'],
#  [3, 'T128', 12, 13, 'Strength', '50', '3-110'],
#  [3, 'T129', 14, 15, 'Strength', '40', '3-110'],
#  [3, 'T60', 33, 34, 'Drug', 'metoprolol', '3-110'],
#  [3, 'T61', 36, 38, 'Strength', '12.5 mg', '3-110'],
#  [3, 'T62', 38, 39, 'Frequency', 'q6h', '3-110'],
#  [3, 'T130', 40, 41, 'Reason', 'HTN', '3-110'],
#  [3, 'T131', 42, 43, 'Reason', 'tachycardia', '3-110'],
#  [3, 'T132', 45, 47, 'Strength', '200 mg', '3-110'],
#  [3, 'T133', 47, 48, 'Route', 'po', '3-110'],
#  [3, 'T134', 48, 49, 'Frequency', 'qD', '3-110'],
#  [3, 'T136', 79, 80, 'Drug', 'hdyrocortisone', '3-110'],
#  [3, 'T137', 80, 81, 'Strength', '50', '3-110'],
#  [3, 'T138', 81, 82, 'Frequency', 'q12', '3-110'],
#  [3, 'T135', 83, 84, 'Drug', 'vanco', '3-110'],
#  [3, 'T139', 85, 86, 'Drug', 'levo', '3-110'],
#  [3, 'T140', 87, 88, 'Drug', 'cefepine', '3-110'],
#  [3, 'T33', 1, 2, 'Drug', 'propofol', '3-128'],
#  [3, 'T57', 8, 9, 'Drug', 'benefiber', '3-128'],
#  [3, 'T58', 25, 26, 'Route', 'po', '3-128'],
#  [3, 'T47', 26, 27, 'Drug', 'flagyl', '3-128'],
#  [3, 'T206', 28, 33, 'Reason', 'until c. diff ruled out', '3-128'],
#  [3, 'T220', 34, 35, 'Drug', 'bleomycin', '3-128'],
#  [3, 'T232', 35, 36, 'ADE', 'toxicity', '3-128'],
#  [3, 'T68', 59, 60, 'Drug', 'sucralfate', '3-128'],
#  [3, 'T141', 62, 66, 'Reason', 'blood in OG tube', '3-128'],
#  [3, 'T207', 69, 70, 'Drug', 'Sedation', '3-128'],
#  [3, 'T208', 71, 72, 'Drug', 'pressors', '3-128'],
#  [3, 'T145', 98, 99, 'Reason', 'hypotensive', '3-128'],
#  [3, 'T143', 103, 105, 'Dosage', '2 L', '3-128'],
#  [3, 'T142', 105, 106, 'Drug', 'NS', '3-128'],
#  [3, 'T210', 109, 111, 'Reason', 'low K', '3-128'],
#  [3, 'T209', 112, 113, 'Drug', 'K', '3-128'],
#  [3, 'T233', 117, 118, 'Drug', 'fluid', '3-128'],
#  [3, 'T51', 120, 121, 'Drug', 'Propofol', '3-128'],
#  [3, 'T211', 1, 2, 'Drug', 'diuresis', '3-146'],
#  [3, 'T212', 3, 5, 'Reason', 'improve ventilation', '3-146'],
#  [3, 'T146', 2, 3, 'Drug', 'Fent', '3-148'],
#  [3, 'T5', 4, 5, 'Drug', 'Versed', '3-148'],
#  [3, 'T9', 6, 7, 'Drug', 'Propofol', '3-148'],
#  [3, 'T147', 7, 8, 'Strength', '20', '3-148'],
#  [3, 'T149', 9, 10, 'Strength', '1.3', '3-148'],
#  [3, 'T148', 10, 11, 'Drug', 'Neo', '3-148'],
#  [3, 'T48', 3, 4, 'Drug', 'propofol', '3-154'],
#  [3, 'T213', 9, 10, 'Drug', 'PSV', '3-154'],
#  [3, 'T32', 28, 29, 'Drug', 'dilantin', '3-156'],
#  [3, 'T63', 5, 6, 'Drug', 'phenytoin', '3-157'],
#  [3, 'T150', 7, 9, 'Strength', '500 mg', '3-157'],
#  [3, 'T105', 9, 10, 'Route', 'iv', '3-157'],
#  [3, 'T36', 18, 20, 'Strength', '200 mg', '3-157'],
#  [3, 'T37', 20, 21, 'Frequency', 'Q8', '3-157'],
#  [3, 'T151', 22, 24, 'Strength', '250 mg', '3-157'],
#  [3, 'T152', 24, 25, 'Frequency', 'Q8', '3-157'],
#  [3, 'T35', 1, 2, 'Drug', 'dilantin', '3-164'],
#  [3, 'T174', 2, 3, 'Drug', 'level', '3-164'],
#  [3, 'T153', 8, 9, 'Drug', 'vanco', '3-164'],
#  [3, 'T154', 11, 13, 'Strength', '1000 mg', '3-164'],
#  [3, 'T155', 13, 14, 'Frequency', 'q12', '3-164'],
#  [3, 'T156', 15, 16, 'Strength', '100o', '3-164'],
#  [3, 'T157', 16, 18, 'Frequency', 'q8 h.', '3-164'],
#  [3, 'T158', 18, 19, 'Drug', 'vanc', '3-164'],
#  [3, 'T46', 36, 37, 'Drug', 'Propofol', '3-164'],
#  [3, 'T235', 48, 50, 'Dosage', '10 L', '3-164'],
#  [3, 'T234', 51, 52, 'Drug', 'fluids', '3-164'],
#  [3, 'T236', 54, 56, 'Duration', '24 hrs', '3-164'],
#  [3, 'T216', 17, 18, 'Drug', 'FiO2', '3-176'],
#  [3, 'T214', 20, 21, 'Drug', 'oxygenation', '3-176'],
#  [3, 'T215', 6, 7, 'Drug', 'FiO2', '3-178'],
#  [3, 'T217', 10, 11, 'Route', 'CPAP', '3-178'],
#  [3, 'T159', 25, 26, 'Drug', 'vanco', '3-178'],
#  [3, 'T160', 27, 28, 'Drug', 'zosyn', '3-178'],
#  [3, 'T13', 29, 30, 'Drug', 'bactrim', '3-178'],
#  [3, 'T237', 31, 37, 'Reason', 'ground glass findings on chest CT', '3-178'],
#  [3, 'T219', 41, 43, 'Reason', 'possible PCP', '3-178'],
#  [3, 'T6', 47, 48, 'Drug', 'phenytoin', '3-178'],
#  [3, 'T122', 51, 52, 'Route', 'iv', '3-178'],
#  [3, 'T79', 67, 68, 'Drug', 'Prednisone', '3-178'],
#  [3, 'T162', 68, 69, 'Dosage', 'one', '3-178'],
#  [3, 'T163', 69, 70, 'Form', 'pill', '3-178'],
#  [3, 'T164', 70, 72, 'Frequency', 'in AM', '3-178'],
#  [3, 'T82', 73, 74, 'Dosage', '2', '3-178'],
#  [3, 'T81', 74, 75, 'Form', 'pills', '3-178'],
#  [3, 'T165', 75, 77, 'Frequency', 'at night', '3-178'],
#  [3, 'T80', 78, 79, 'Strength', '10mg', '3-178'],
#  [3, 'T166', 80, 81, 'Strength', '20mg', '3-178'],
#  [3, 'T53', 86, 88, 'Drug', 'Vitamin D', '3-178'],
#  [3, 'T54', 88, 89, 'Strength', '800mg', '3-178'],
#  [3, 'T167', 89, 90, 'Frequency', 'daily', '3-178'],
#  [3, 'T71', 90, 91, 'Drug', 'Iron', '3-178'],
#  [3, 'T72', 91, 92, 'Strength', '325mg', '3-178'],
#  [3, 'T73', 92, 95, 'Frequency', 'three times daily', '3-178'],
#  [3, 'T25', 95, 97, 'Drug', 'folic acid', '3-178'],
#  [3, 'T26', 97, 99, 'Strength', '1 g', '3-178'],
#  [3, 'T168', 99, 100, 'Frequency', 'daily', '3-178'],
#  [3, 'T19', 100, 101, 'Drug', 'dalteparin', '3-178'],
#  [3, 'T20', 101, 103, 'Dosage', '15,000 units', '3-178'],
#  [3, 'T169', 103, 105, 'Route', 'sub Q', '3-178'],
#  [3, 'T170', 105, 106, 'Frequency', 'daily', '3-178'],
#  [3, 'T40', 106, 107, 'Drug', 'Mesalamine', '3-178'],
#  [3, 'T42', 107, 108, 'Dosage', '4', '3-178'],
#  [3, 'T41', 108, 109, 'Form', 'pills', '3-178'],
#  [3, 'T43', 109, 111, 'Frequency', 'twice daily', '3-178'],
#  [3, 'T64', 111, 112, 'Drug', 'Phenytoin', '3-178'],
#  [3, 'T65', 112, 114, 'Strength', '100 mg', '3-178'],
#  [3, 'T67', 115, 116, 'Dosage', '6', '3-178'],
#  [3, 'T66', 116, 117, 'Form', 'pills', '3-178'],
#  [3, 'T171', 117, 119, 'Frequency', 'at night', '3-178'],
#  [3, 'T1', 119, 120, 'Drug', 'Metoprolol', '3-178'],
#  [3, 'T2', 120, 122, 'Strength', '200 mg', '3-178'],
#  [3, 'T3', 122, 123, 'Route', 'po', '3-178'],
#  [3, 'T172', 123, 124, 'Frequency', 'daily', '3-178'],
#  [3, 'T21', 124, 125, 'Drug', 'Isosorbide', '3-178'],
#  [3, 'T22', 125, 127, 'Strength', '60 mg', '3-178'],
#  [3, 'T23', 127, 128, 'Route', 'po', '3-178'],
#  [3, 'T173', 128, 130, 'Frequency', 'every morning', '3-178'],
#  [4, 'T11', 29, 30, 'Drug', 'Heparin', '4-0'],
#  [4, 'T12', 30, 32, 'Dosage', '5,000 units', '4-0'],
#  [4, 'T31', 32, 33, 'Route', 'subq', '4-0'],
#  [4, 'T32', 33, 34, 'Frequency', 'q.8.', '4-0'],
#  [4, 'T13', 1, 2, 'Drug', 'Acetaminophen', '4-4'],
#  [4, 'T14', 2, 4, 'Strength', '325 mg', '4-4'],
#  [4, 'T16', 4, 5, 'Dosage', '1-2', '4-4'],
#  [4, 'T15', 5, 6, 'Form', 'tablets', '4-4'],
#  [4, 'T17', 6, 7, 'Route', 'p.o.', '4-4'],
#  [4, 'T33', 7, 9, 'Frequency', 'q.4-6h. prn.', '4-4'],
#  [4, 'T30', 1, 3, 'Drug', 'Olanzapin e', '4-10'],
#  [4, 'T27', 3, 5, 'Strength', '2.5 mg', '4-10'],
#  [4, 'T29', 5, 6, 'Route', 'p.o.', '4-10'],
#  [4, 'T28', 6, 8, 'Frequency', 'q.i.d. prn.', '4-10'],
#  [4, 'T6', 1, 2, 'Drug', 'Docusate', '4-14'],
#  [4, 'T7', 2, 4, 'Strength', '100 mg', '4-14'],
#  [4, 'T9', 4, 5, 'Route', 'p.o.', '4-14'],
#  [4, 'T8', 5, 7, 'Frequency', 'b.i.d. prn.', '4-14'],
#  [4, 'T34', 1, 2, 'Drug', 'Senna', '4-18'],
#  [4, 'T18', 2, 4, 'Strength', '8.6 mg', '4-18'],
#  [4, 'T20', 4, 5, 'Route', 'p.o.', '4-18'],
#  [4, 'T19', 5, 7, 'Frequency', 'b.i.d. prn.', '4-18'],
#  [4, 'T1', 1, 3, 'Drug', 'Carbidopa/ levodopa', '4-22'],
#  [4, 'T35', 3, 5, 'Strength', '25/100 mg', '4-22'],
#  [4, 'T3', 5, 6, 'Dosage', 'one', '4-22'],
#  [4, 'T2', 6, 7, 'Form', 'tablet', '4-22'],
#  [4, 'T5', 7, 8, 'Route', 'p.o.', '4-22'],
#  [4, 'T4', 8, 9, 'Frequency', 't.i.d.', '4-22'],
#  [4, 'T36', 1, 2, 'Drug', 'Levothyroxine', '4-28'],
#  [4, 'T21', 2, 4, 'Strength', '100 mcg', '4-28'],
#  [4, 'T22', 4, 5, 'Route', 'p.o.', '4-28'],
#  [4, 'T37', 5, 6, 'Frequency', 'q.d.', '4-28'],
#  [4, 'T23', 1, 3, 'Drug', 'Valsartan/ hydrochlorothiazide', '4-32'],
#  [4, 'T38', 3, 5, 'Strength', '80/12.5 mg', '4-32'],
#  [4, 'T25', 5, 6, 'Dosage', 'one', '4-32'],
#  [4, 'T24', 6, 7, 'Form', 'tablet', '4-32'],
#  [4, 'T26', 7, 8, 'Route', 'p.o.', '4-32'],
#  [4, 'T39', 8, 9, 'Frequency', 'q.d.', '4-32'],
#  [4, 'T40', 10, 13, 'Drug', 'thyroid replacement medication', '4-38'],
#  [4, 'T10', 35, 36, 'Drug', 'Lithium', '4-38'],
#  [5, 'T94', 5, 6, 'Drug', 'NSAID', '5-0'],
#  [5, 'T107', 2, 5, 'Reason', 'guiaic positive rectally', '5-1'],
#  [5, 'T111', 3, 4, 'Dosage', '1L', '5-2'],
#  [5, 'T112', 4, 5, 'Drug', 'IVF', '5-2'],
#  [5, 'T113', 8, 9, 'Drug', 'protonix', '5-2'],
#  [5, 'T1', 4, 5, 'Drug', 'heparin', '5-5'],
#  [5, 'T2', 5, 6, 'Route', 'gtt', '5-5'],
#  [5, 'T3', 17, 19, 'Reason', 'atrial fibrillation', '5-7'],
#  [5, 'T4', 20, 21, 'Drug', 'coumadin', '5-7'],
#  [5, 'T5', 13, 14, 'Reason', 'GIB', '5-9'],
#  [5, 'T6', 10, 11, 'Drug', 'PPI', '5-10'],
#  [5, 'T7', 11, 14, 'Duration', 'for one month', '5-10'],
#  [5, 'T8', 16, 17, 'Frequency', 'daily', '5-10'],
#  [5, 'T9', 17, 18, 'Drug', 'PPI', '5-10'],
#  [5, 'T10', 5, 6, 'Drug', 'coumadin', '5-14'],
#  [5, 'T11', 8, 9, 'Drug', 'heparin', '5-14'],
#  [5, 'T12', 9, 10, 'Route', 'drip', '5-14'],
#  [5, 'T13', 1, 2, 'Reason', 'HTN', '5-17'],
#  [5, 'T14', 4, 5, 'Drug', 'ACE', '5-17'],
#  [5, 'T15', 6, 7, 'Drug', 'BB', '5-17'],
#  [5, 'T16', 16, 17, 'ADE', 'hypotension', '5-17'],
#  [5, 'T17', 1, 4, 'Reason', 'Mechanical heart valve', '5-21'],
#  [5, 'T18', 7, 8, 'Drug', 'heparin', '5-21'],
#  [5, 'T19', 11, 12, 'Drug', 'coumadin', '5-21'],
#  [5, 'T20', 2, 3, 'Drug', 'heparin', '5-24'],
#  [5, 'T21', 4, 5, 'Drug', 'coumadin', '5-24'],
#  [5, 'T22', 1, 2, 'Reason', 'PPx', '5-26'],
#  [5, 'T23', 3, 4, 'Drug', 'Heparin', '5-26'],
#  [5, 'T24', 5, 6, 'Drug', 'coumadin', '5-26'],
#  [5, 'T25', 9, 10, 'Drug', 'PPI', '5-26'],
#  [5, 'T26', 3, 5, 'Drug', 'toprol xl', '5-30'],
#  [5, 'T27', 5, 7, 'Strength', '50 mg', '5-30'],
#  [5, 'T28', 7, 8, 'Route', 'po', '5-30'],
#  [5, 'T29', 8, 9, 'Frequency', 'qdaily', '5-30'],
#  [5, 'T30', 9, 10, 'Drug', 'quinipril', '5-30'],
#  [5, 'T31', 10, 12, 'Strength', '20 mg', '5-30'],
#  [5, 'T32', 12, 13, 'Route', 'po', '5-30'],
#  [5, 'T33', 13, 14, 'Frequency', 'qdaily', '5-30'],
#  [5, 'T34', 14, 15, 'Drug', 'lipitor', '5-30'],
#  [5, 'T35', 15, 16, 'Strength', '10mg', '5-30'],
#  [5, 'T36', 16, 17, 'Route', 'po', '5-30'],
#  [5, 'T37', 17, 18, 'Frequency', 'qdaily', '5-30'],
#  [5, 'T38', 18, 19, 'Drug', 'protonix', '5-30'],
#  [5, 'T39', 19, 21, 'Strength', '40 mg', '5-30'],
#  [5, 'T40', 21, 22, 'Route', 'po', '5-30'],
#  [5, 'T41', 22, 23, 'Frequency', 'qdaily', '5-30'],
#  [5, 'T42', 23, 24, 'Drug', 'lasix', '5-30'],
#  [5, 'T43', 24, 26, 'Strength', '20 mg', '5-30'],
#  [5, 'T44', 26, 27, 'Route', 'po', '5-30'],
#  [5, 'T45', 27, 28, 'Frequency', 'qdaily', '5-30'],
#  [5, 'T46', 28, 29, 'Drug', 'colace', '5-30'],
#  [5, 'T47', 29, 30, 'Strength', '100mg', '5-30'],
#  [5, 'T48', 30, 31, 'Route', 'po', '5-30'],
#  [5, 'T49', 31, 32, 'Frequency', 'qdaily', '5-30'],
#  [5, 'T50', 32, 33, 'Drug', 'ativan', '5-30'],
#  [5, 'T51', 33, 34, 'Strength', '1.5mg', '5-30'],
#  [5, 'T52', 34, 35, 'Route', 'po', '5-30'],
#  [5, 'T53', 35, 36, 'Frequency', 'qhs', '5-30'],
#  [5, 'T54', 39, 40, 'Drug', 'Atorvastatin', '5-58'],
#  [5, 'T55', 40, 42, 'Strength', '10 mg', '5-58'],
#  [5, 'T56', 42, 43, 'Form', 'Tablet', '5-58'],
#  [5, 'T57', 44, 46, 'Dosage', 'One (1)', '5-58'],
#  [5, 'T58', 46, 47, 'Form', 'Tablet', '5-58'],
#  [5, 'T59', 47, 48, 'Route', 'PO', '5-58'],
#  [5, 'T60', 48, 50, 'Frequency', 'DAILY (Daily)', '5-58'],
#  [5, 'T61', 4, 6, 'Drug', 'Methyl Salicylate-Menthol', '5-65'],
#  [5, 'T62', 6, 7, 'Strength', '15-15', '5-65'],
#  [5, 'T63', 8, 9, 'Form', 'Ointment', '5-65'],
#  [5, 'T64', 10, 12, 'Dosage', 'One (1)', '5-65'],
#  [5, 'T65', 12, 13, 'Form', 'Appl', '5-65'],
#  [5, 'T66', 13, 14, 'Form', 'Topical', '5-65'],
#  [5, 'T67', 17, 23, 'Frequency', '2 times a day) as needed', '5-65'],
#  [5, 'T68', 24, 26, 'Reason', 'back pain', '5-65'],
#  [5, 'T69', 4, 5, 'Drug', 'Acetaminophen', '5-73'],
#  [5, 'T70', 5, 7, 'Strength', '325 mg', '5-73'],
#  [5, 'T71', 7, 8, 'Form', 'Tablet', '5-73'],
#  [5, 'T72', 9, 10, 'Dosage', '1-2', '5-73'],
#  [5, 'T73', 10, 11, 'Form', 'Tablets', '5-73'],
#  [5, 'T74', 11, 12, 'Route', 'PO', '5-73'],
#  [5, 'T75', 12, 18, 'Frequency', 'Q6H (every 6 hours) as needed', '5-73'],
#  [5, 'T76', 19, 20, 'Reason', 'pain', '5-73'],
#  [5, 'T77', 1, 2, 'Drug', 'Pantoprazole', '5-81'],
#  [5, 'T78', 2, 4, 'Strength', '40 mg', '5-81'],
#  [5, 'T79', 4, 8, 'Form', 'Tablet, Delayed Release (E.C.)', '5-81'],
#  [5, 'T80', 9, 11, 'Dosage', 'One (1)', '5-81'],
#  [5, 'T81', 11, 15, 'Form', 'Tablet, Delayed Release (E.C.)', '5-81'],
#  [5, 'T82', 15, 16, 'Route', 'PO', '5-81'],
#  [5, 'T83', 16, 22, 'Frequency', 'Q12H (every 12 hours) as needed', '5-81'],
#  [5, 'T84', 23, 25, 'Reason', 'antral erosions', '5-81'],
#  [5, 'T85', 25, 28, 'Duration', 'for 1 months', '5-81'],
#  [5, 'T86', 3, 4, 'Drug', 'Warfarin', '5-90'],
#  [5, 'T87', 4, 6, 'Strength', '2.5 mg', '5-90'],
#  [5, 'T88', 6, 7, 'Form', 'Tablet', '5-90'],
#  [5, 'T89', 8, 10, 'Dosage', 'Two (2)', '5-90'],
#  [5, 'T90', 10, 11, 'Form', 'Tablet', '5-90'],
#  [5, 'T91', 11, 12, 'Route', 'PO', '5-90'],
#  [5, 'T92', 12, 14, 'Frequency', 'at bedtime', '5-90'],
#  [5, 'T93', 27, 28, 'Drug', 'warfarin', '5-90'],
#  [5, 'T95', 4, 5, 'Drug', 'coumadin', '5-98'],
#  [5, 'T96', 7, 8, 'Drug', 'warfarin', '5-98'],
#  [5, 'T97', 20, 23, 'Reason', 'mechanical heart valves', '5-98'],
#  [5, 'T98', 22, 23, 'Drug', 'Coumadin', '5-101'],
#  [5, 'T99', 25, 27, 'Reason', 'prevent strokes', '5-101'],
#  [5, 'T100', 1, 2, 'Drug', 'coumadin', '5-103'],
#  [5, 'T101', 4, 9, 'ADE', 'make it easier to bleed', '5-103'],
#  [5, 'T102', 8, 9, 'Drug', 'coumadin', '5-105'],
#  [5, 'T103', 11, 16, 'ADE', 'erosions in your stomach bled', '5-105'],
#  [5, 'T104', 6, 7, 'Drug', 'coumadin', '5-107'],
#  [5, 'T105', 16, 17, 'Drug', 'coumadin', '5-108'],
#  [5, 'T106', 7, 8, 'Drug', 'coumadin', '5-109'],
#  [5, 'T108', 29, 30, 'Drug', 'coumadin', '5-110'],
#  [5, 'T109', 23, 24, 'Drug', 'Coumadin', '5-111'],
#  [5, 'T110', 26, 28, 'Reason', 'blood thinner', '5-111'],
#  [6, 'T81', 15, 18, 'Drug', 'Sulfa (Sulfonamide Antibiotics)', '6-0'],
#  [6, 'T7', 19, 20, 'Drug', 'Prochlorperazine', '6-0'],
#  [6, 'T82', 22, 23, 'Drug', 'Dye', '6-0'],
#  [6, 'T52', 24, 25, 'Drug', 'Iodine', '6-0'],
#  [6, 'T156', 9, 10, 'Drug', 'anesthesia', '6-4'],
#  [6, 'T83', 10, 12, 'Reason', 'diffused rash', '6-5'],
#  [6, 'T19', 16, 17, 'Drug', 'Benadryl', '6-5'],
#  [6, 'T157', 1, 2, 'Reason', 'rash', '6-7'],
#  [6, 'T165', 7, 8, 'Reason', 'hypotensive', '6-7'],
#  [6, 'T84', 4, 5, 'Drug', 'Neo', '6-9'],
#  [6, 'T63', 1, 2, 'Drug', 'Heparin', '6-10'],
#  [6, 'T85', 2, 3, 'Route', 'gtt', '6-10'],
#  [6, 'T86', 4, 5, 'Drug', 'ASA', '6-12'],
#  [6, 'T6', 6, 7, 'Drug', 'Plavix', '6-12'],
#  [6, 'T67', 4, 5, 'Drug', 'Decadron', '6-14'],
#  [6, 'T68', 5, 6, 'Strength', '4mg', '6-14'],
#  [6, 'T69', 6, 8, 'Frequency', 'Q6 hrs', '6-14'],
#  [6, 'T87', 8, 11, 'Duration', 'for 48 hrs', '6-14'],
#  [6, 'T88', 13, 15, 'Drug', 'H2 blocker', '6-14'],
#  [6, 'T1', 17, 18, 'Drug', 'Benadryl', '6-14'],
#  [6, 'T167', 8, 10, 'Reason', 'allergic reaction', '6-20'],
#  [6, 'T89', 4, 5, 'Drug', 'decardon', '6-21'],
#  [6, 'T90', 5, 6, 'Strength', '4mg', '6-21'],
#  [6, 'T91', 6, 7, 'Frequency', 'q8', '6-21'],
#  [6, 'T8', 7, 8, 'Route', 'IV', '6-21'],
#  [6, 'T158', 8, 10, 'Duration', 'until tomorrow', '6-21'],
#  [6, 'T93', 7, 8, 'Drug', 'ASA', '6-26'],
#  [6, 'T53', 9, 10, 'Drug', 'Plavix', '6-26'],
#  [6, 'T94', 10, 13, 'Duration', 'x 1 month', '6-26'],
#  [6, 'T30', 3, 4, 'Drug', 'Pepcid', '6-29'],
#  [6, 'T59', 5, 6, 'Drug', 'Decadron', '6-29'],
#  [6, 'T31', 7, 8, 'Drug', 'Benadryl', '6-29'],
#  [6, 'T95', 8, 12, 'Duration', 'for one more day', '6-29'],
#  [6, 'T96', 13, 14, 'Route', 'PO', '6-29'],
#  [6, 'T37', 3, 5, 'Drug', 'Metoprolol Tartrate', '6-34'],
#  [6, 'T38', 5, 7, 'Strength', '25 mg', '6-34'],
#  [6, 'T40', 7, 8, 'Route', 'PO', '6-34'],
#  [6, 'T39', 8, 9, 'Frequency', 'BID', '6-34'],
#  [6, 'T2', 9, 11, 'Drug', 'Calcium Carbonate', '6-34'],
#  [6, 'T3', 11, 13, 'Strength', '500 mg', '6-34'],
#  [6, 'T5', 13, 14, 'Route', 'PO', '6-34'],
#  [6, 'T4', 14, 15, 'Frequency', 'BID', '6-34'],
#  [6, 'T41', 15, 17, 'Drug', 'Vitamin D', '6-34'],
#  [6, 'T42', 17, 19, 'Strength', '400 UNIT', '6-34'],
#  [6, 'T43', 19, 20, 'Route', 'PO', '6-34'],
#  [6, 'T97', 20, 21, 'Frequency', 'DAILY', '6-34'],
#  [6, 'T74', 21, 22, 'Drug', 'Plavix', '6-34'],
#  [6, 'T75', 22, 24, 'Strength', '75 mg', '6-34'],
#  [6, 'T76', 24, 25, 'Route', 'PO', '6-34'],
#  [6, 'T98', 25, 26, 'Frequency', 'DAILY', '6-34'],
#  [6, 'T62', 29, 31, 'Drug', 'acetaminophe n', '6-34'],
#  [6, 'T60', 31, 33, 'Strength', '325 mg', '6-34'],
#  [6, 'T61', 33, 34, 'Form', 'Tablet', '6-34'],
#  [6, 'T99', 37, 39, 'Dosage', 'Two (2)', '6-34'],
#  [6, 'T100', 39, 40, 'Form', 'Tablet', '6-34'],
#  [6, 'T101', 40, 41, 'Route', 'PO', '6-34'],
#  [6, 'T102', 41, 47, 'Frequency', 'Q6H (every 6 hours) as needed', '6-34'],
#  [6, 'T77', 48, 49, 'Reason', 'pain', '6-34'],
#  [6, 'T92', 49, 50, 'Reason', 'fever', '6-34'],
#  [6, 'T48', 1, 3, 'Drug', 'docusate sodium', '6-59'],
#  [6, 'T49', 3, 5, 'Strength', '100 mg', '6-59'],
#  [6, 'T103', 5, 6, 'Form', 'Capsule', '6-59'],
#  [6, 'T104', 9, 11, 'Dosage', 'One (1)', '6-59'],
#  [6, 'T50', 11, 12, 'Form', 'Capsule', '6-59'],
#  [6, 'T51', 12, 13, 'Route', 'PO', '6-59'],
#  [6, 'T105', 13, 18, 'Frequency', 'BID (2 times a day)', '6-59'],
#  [6, 'T32', 1, 3, 'Drug', 'oxycodone- acetaminophen', '6-66'],
#  [6, 'T106', 3, 5, 'Strength', '5-325 mg', '6-66'],
#  [6, 'T107', 5, 6, 'Form', 'Tablet', '6-66'],
#  [6, 'T108', 9, 11, 'Dosage', 'One (1)', '6-66'],
#  [6, 'T33', 11, 12, 'Form', 'Tablet', '6-66'],
#  [6, 'T109', 12, 13, 'Route', 'PO', '6-66'],
#  [6, 'T110', 13, 19, 'Frequency', 'Q4H (every 4 hours) as needed', '6-66'],
#  [6, 'T78', 20, 21, 'Reason', 'pain', '6-66'],
#  [6, 'T44', 4, 5, 'Drug', 'clopidogrel', '6-74'],
#  [6, 'T45', 5, 7, 'Strength', '75 mg', '6-74'],
#  [6, 'T112', 7, 8, 'Form', 'Tablet', '6-74'],
#  [6, 'T111', 11, 13, 'Dosage', 'One (1)', '6-74'],
#  [6, 'T46', 13, 14, 'Form', 'Tablet', '6-74'],
#  [6, 'T47', 14, 15, 'Route', 'PO', '6-74'],
#  [6, 'T113', 15, 17, 'Frequency', 'DAILY (Daily)', '6-74'],
#  [6, 'T24', 4, 6, 'Drug', 'metoprolol tartrate', '6-81'],
#  [6, 'T25', 6, 8, 'Strength', '25 mg', '6-81'],
#  [6, 'T114', 8, 9, 'Form', 'Tablet', '6-81'],
#  [6, 'T115', 12, 14, 'Dosage', 'One (1)', '6-81'],
#  [6, 'T26', 14, 15, 'Form', 'Tablet', '6-81'],
#  [6, 'T27', 15, 16, 'Route', 'PO', '6-81'],
#  [6, 'T116', 16, 21, 'Frequency', 'BID (2 times a day)', '6-81'],
#  [6, 'T70', 1, 2, 'Drug', 'aspirin', '6-88'],
#  [6, 'T71', 2, 4, 'Strength', '325 mg', '6-88'],
#  [6, 'T117', 4, 5, 'Form', 'Tablet', '6-88'],
#  [6, 'T118', 8, 10, 'Dosage', 'One (1)', '6-88'],
#  [6, 'T72', 10, 11, 'Form', 'Tablet', '6-88'],
#  [6, 'T73', 11, 12, 'Route', 'PO', '6-88'],
#  [6, 'T119', 12, 14, 'Frequency', 'DAILY (Daily)', '6-88'],
#  [6, 'T55', 4, 6, 'Drug', 'diphenhydramine HCl', '6-95'],
#  [6, 'T56', 6, 8, 'Strength', '25 mg', '6-95'],
#  [6, 'T120', 8, 9, 'Form', 'Capsule', '6-95'],
#  [6, 'T121', 12, 14, 'Dosage', 'Two (2)', '6-95'],
#  [6, 'T57', 14, 15, 'Form', 'Capsule', '6-95'],
#  [6, 'T58', 15, 16, 'Route', 'PO', '6-95'],
#  [6, 'T122', 16, 22, 'Frequency', 'Q6H (every 6 hours) as needed', '6-95'],
#  [6, 'T123', 23, 24, 'Reason', 'pruritis', '6-95'],
#  [6, 'T124', 24, 27, 'Duration', 'for 1 days', '6-95'],
#  [6, 'T18', 4, 6, 'Drug', 'famotidin e', '6-104'],
#  [6, 'T15', 6, 8, 'Strength', '20 mg', '6-104'],
#  [6, 'T125', 8, 9, 'Form', 'Tablet', '6-104'],
#  [6, 'T126', 12, 14, 'Dosage', 'One (1)', '6-104'],
#  [6, 'T16', 14, 15, 'Form', 'Tablet', '6-104'],
#  [6, 'T17', 15, 16, 'Route', 'PO', '6-104'],
#  [6, 'T127', 16, 21, 'Frequency', 'BID (2 times a day)', '6-104'],
#  [6, 'T128', 21, 24, 'Duration', 'for 1 days', '6-104'],
#  [6, 'T23', 4, 6, 'Drug', 'dexamethason e', '6-112'],
#  [6, 'T20', 6, 8, 'Strength', '4 mg', '6-112'],
#  [6, 'T129', 8, 9, 'Form', 'Tablet', '6-112'],
#  [6, 'T130', 12, 14, 'Dosage', 'One (1)', '6-112'],
#  [6, 'T21', 14, 15, 'Form', 'Tablet', '6-112'],
#  [6, 'T22', 15, 16, 'Route', 'PO', '6-112'],
#  [6, 'T131', 16, 20, 'Frequency', 'every eight (8) hours', '6-112'],
#  [6, 'T36', 20, 23, 'Duration', 'for 1 days', '6-112'],
#  [6, 'T34', 4, 6, 'Drug', 'calcium carbonate', '6-120'],
#  [6, 'T35', 6, 8, 'Strength', '200 mg', '6-120'],
#  [6, 'T64', 8, 9, 'Drug', 'calcium', '6-120'],
#  [6, 'T65', 10, 12, 'Strength', '500 mg', '6-120'],
#  [6, 'T66', 13, 16, 'Form', 'Tablet , Chewable', '6-120'],
#  [6, 'T132', 19, 21, 'Dosage', 'One (1)', '6-120'],
#  [6, 'T133', 21, 23, 'Form', 'Tablet, Chewable', '6-120'],
#  [6, 'T134', 23, 24, 'Route', 'PO', '6-120'],
#  [6, 'T135', 24, 29, 'Frequency', 'BID (2 times a day)', '6-120'],
#  [6, 'T28', 1, 4, 'Drug', 'cholecalciferol (vitamin D3)', '6-129'],
#  [6, 'T29', 4, 6, 'Strength', '400 unit', '6-129'],
#  [6, 'T136', 6, 7, 'Form', 'Tablet', '6-129'],
#  [6, 'T137', 10, 12, 'Dosage', 'One (1)', '6-129'],
#  [6, 'T138', 12, 13, 'Form', 'Tablet', '6-129'],
#  [6, 'T139', 13, 14, 'Route', 'PO', '6-129'],
#  [6, 'T140', 14, 16, 'Frequency', 'DAILY (Daily)', '6-129'],
#  [6, 'T141', 1, 2, 'Drug', 'hydrocortisone', '6-136'],
#  [6, 'T142', 2, 4, 'Strength', '2.5 %', '6-136'],
#  [6, 'T143', 4, 5, 'Form', 'Cream', '6-136'],
#  [6, 'T144', 8, 10, 'Dosage', 'One (1)', '6-136'],
#  [6, 'T145', 10, 11, 'Form', 'APPL', '6-136'],
#  [6, 'T146', 11, 12, 'Route', 'Topical', '6-136'],
#  [6, 'T147', 12, 16, 'Frequency', 'QID PRN as needed', '6-136'],
#  [6, 'T79', 17, 18, 'Reason', 'itching', '6-136'],
#  [6, 'T148', 4, 5, 'Drug', 'hydrocortisone', '6-144'],
#  [6, 'T149', 5, 7, 'Strength', '1 %', '6-144'],
#  [6, 'T150', 7, 8, 'Form', 'Lotion', '6-144'],
#  [6, 'T151', 11, 13, 'Dosage', 'One (1)', '6-144'],
#  [6, 'T152', 13, 14, 'Form', 'APPL', '6-144'],
#  [6, 'T153', 14, 15, 'Route', 'Topical', '6-144'],
#  [6, 'T154', 15, 21, 'Frequency', 'four times a day as needed', '6-144'],
#  [6, 'T80', 22, 23, 'Reason', 'itching', '6-144'],
#  [6, 'T12', 1, 2, 'Drug', 'Aspirin', '6-152'],
#  [6, 'T13', 2, 3, 'Strength', '325mg', '6-152'],
#  [6, 'T155', 4, 6, 'Form', 'enteric coated', '6-152'],
#  [6, 'T14', 7, 9, 'Frequency', 'once daily', '6-152'],
#  [6, 'T9', 1, 3, 'Drug', 'Plavix (Clopidogrel)', '6-156'],
#  [6, 'T10', 3, 4, 'Strength', '75mg', '6-156'],
#  [6, 'T11', 4, 6, 'Frequency', 'once daily', '6-156'],
#  [6, 'T54', 3, 4, 'Drug', 'Tylenol', '6-159'],
#  [6, 'T159', 6, 8, 'Drug', 'pain medications', '6-159'],
#  [6, 'T160', 12, 13, 'Reason', 'pain', '6-159'],
#  [6, 'T161', 14, 15, 'Reason', 'discomfort', '6-159'],
#  [6, 'T162', 5, 7, 'Drug', 'CONTRAST DYE', '6-163'],
#  [6, 'T163', 20, 21, 'Drug', 'DYE', '6-163'],
#  [7, 'T226', 1, 2, 'Drug', 'labetalol', '7-0'],
#  [7, 'T227', 2, 4, 'Strength', '10 mg', '7-0'],
#  [7, 'T63', 4, 5, 'Route', 'IV', '7-0'],
#  [7, 'T31', 6, 7, 'Drug', 'morphine', '7-0'],
#  [7, 'T60', 9, 11, 'Strength', '8 mg', '7-0'],
#  [7, 'T221', 11, 12, 'Route', 'IV', '7-0'],
#  [7, 'T59', 13, 14, 'Drug', 'percocet', '7-0'],
#  [7, 'T62', 14, 15, 'Dosage', '2', '7-0'],
#  [7, 'T61', 15, 16, 'Form', 'tab', '7-0'],
#  [7, 'T229', 18, 19, 'Drug', 'benadryl', '7-0'],
#  [7, 'T230', 19, 21, 'Strength', '25 mg', '7-0'],
#  [7, 'T231', 21, 22, 'Route', 'PO', '7-0'],
#  [7, 'T232', 24, 25, 'ADE', 'itching', '7-0'],
#  [7, 'T233', 25, 28, 'Reason', 'itching from morphine', '7-0'],
#  [7, 'T422', 28, 29, 'Drug', 'morphine', '7-0'],
#  [7, 'T150', 17, 18, 'Drug', 'Fioricet', '7-15'],
#  [7, 'T219', 23, 24, 'Reason', 'headache', '7-15'],
#  [7, 'T423', 1, 2, 'Reason', 'headache', '7-17'],
#  [7, 'T152', 6, 7, 'Drug', 'nifedipine', '7-18'],
#  [7, 'T166', 9, 10, 'Drug', 'verapamil', '7-18'],
#  [7, 'T10', 12, 13, 'Drug', 'verapamil', '7-18'],
#  [7,
#   'T444',
#   20,
#   25,
#   'Reason',
#   'vasospasm, migraine, and HTN etiology',
#   '7-18'],
#  [7, 'T124', 6, 7, 'Drug', 'dilaudid', '7-22'],
#  [7, 'T421', 16, 17, 'Reason', 'headaches', '7-23'],
#  [7, 'T8', 17, 18, 'Drug', 'Fioricet', '7-24'],
#  [7, 'T74', 6, 7, 'Drug', 'verapamil', '7-25'],
#  [7, 'T191', 8, 9, 'Drug', 'dilaudid', '7-25'],
#  [7, 'T445', 9, 10, 'Frequency', 'prn', '7-25'],
#  [7, 'T424', 1, 3, 'Drug', 'HTN medication', '7-28'],
#  [7, 'T425', 14, 15, 'Reason', 'headaches', '7-28'],
#  [7, 'T235', 3, 5, 'Reason', 'severe nausea', '7-30'],
#  [7, 'T257', 6, 7, 'Reason', 'vomiting', '7-30'],
#  [7, 'T66', 11, 12, 'Drug', 'reglan', '7-30'],
#  [7, 'T73', 13, 14, 'Drug', 'compazine', '7-30'],
#  [7, 'T93', 16, 17, 'Drug', 'zofran', '7-30'],
#  [7, 'T441', 25, 26, 'Reason', 'headaches', '7-30'],
#  [7, 'T236', 8, 9, 'Drug', 'oxygen', '7-36'],
#  [7, 'T446', 16, 18, 'Reason', 'cluster headache', '7-36'],
#  [7, 'T165', 11, 12, 'Drug', 'opiates', '7-38'],
#  [7, 'T237', 13, 14, 'Drug', 'benzos', '7-38'],
#  [7, 'T238', 10, 12, 'Strength', '1 mg', '7-40'],
#  [7, 'T228', 13, 14, 'Route', 'IV', '7-40'],
#  [7, 'T174', 14, 15, 'Drug', 'Ativan', '7-40'],
#  [7, 'T240', 17, 20, 'ADE', 'decreased his RR', '7-40'],
#  [7, 'T241', 26, 27, 'ADE', 'sleepy', '7-40'],
#  [7, 'T242', 3, 5, 'Strength', '4 mg', '7-45'],
#  [7, 'T234', 5, 6, 'Route', 'IV', '7-45'],
#  [7, 'T196', 6, 7, 'Drug', 'morphine', '7-45'],
#  [7, 'T244', 11, 12, 'Reason', 'HA', '7-45'],
#  [7, 'T245', 17, 19, 'ADE', 'decreased RR', '7-45'],
#  [7, 'T246', 24, 25, 'ADE', 'sleepiness', '7-45'],
#  [7, 'T447', 5, 6, 'Reason', 'headache', '7-51'],
#  [7, 'T239', 32, 33, 'Route', 'IV', '7-51'],
#  [7, 'T133', 33, 34, 'Drug', 'dilaudid', '7-51'],
#  [7, 'T145', 6, 7, 'Drug', 'MS-contin', '7-54'],
#  [7, 'T146', 10, 12, 'Strength', '25 mg', '7-54'],
#  [7, 'T248', 12, 13, 'Drug', 'topomax', '7-54'],
#  [7, 'T249', 11, 13, 'ADE', 'completely somnolent', '7-57'],
#  [7, 'T448', 14, 19, 'Reason', 'responsive to sternal rub only', '7-57'],
#  [7, 'T44', 3, 4, 'Drug', 'Narcan', '7-59'],
#  [7, 'T45', 4, 6, 'Strength', '0.4 mg', '7-59'],
#  [7, 'T250', 7, 9, 'Dosage', 'three times', '7-59'],
#  [7, 'T251', 14, 15, 'Reason', 'somnolence', '7-59'],
#  [7, 'T426', 9, 11, 'Drug', 'sedating medication', '7-63'],
#  [7, 'T28', 1, 2, 'Drug', 'opiates', '7-64'],
#  [7, 'T252', 3, 4, 'Drug', 'topomax', '7-64'],
#  [7, 'T149', 6, 7, 'Drug', 'gabapentin', '7-64'],
#  [7, 'T427', 6, 8, 'Drug', 'sedating medication', '7-67'],
#  [7, 'T157', 12, 13, 'Drug', 'tylenol', '7-67'],
#  [7, 'T253', 14, 16, 'Strength', '1000 mg', '7-67'],
#  [7, 'T254', 16, 18, 'Frequency', 'q 8H', '7-67'],
#  [7, 'T34', 1, 2, 'Drug', 'tylenol', '7-71'],
#  [7, 'T220', 8, 9, 'Reason', 'headaches', '7-71'],
#  [7, 'T255', 1, 2, 'Reason', 'Hypertension', '7-73'],
#  [7, 'T428', 7, 8, 'Drug', 'anti-hypertensives', '7-74'],
#  [7, 'T167', 1, 2, 'Drug', 'clonidine', '7-75'],
#  [7, 'T169', 2, 3, 'Form', 'patch', '7-75'],
#  [7, 'T168', 6, 8, 'Strength', '0.1 mg', '7-75'],
#  [7, 'T449', 7, 9, 'Reason', 'blood pressure', '7-78'],
#  [7, 'T243', 11, 12, 'Route', 'IV', '7-78'],
#  [7, 'T199', 12, 13, 'Drug', 'hydralazine', '7-78'],
#  [7, 'T258', 14, 15, 'Dosage', '1', '7-78'],
#  [7, 'T200', 16, 17, 'Route', 'po', '7-78'],
#  [7, 'T9', 17, 18, 'Drug', 'labetalol', '7-78'],
#  [7, 'T256', 23, 25, 'Drug', 'BP medications', '7-78'],
#  [7, 'T247', 5, 6, 'Route', 'IV', '7-85'],
#  [7, 'T112', 5, 7, 'Drug', 'Minoxidi l', '7-86'],
#  [7, 'T109', 7, 9, 'Strength', '10 mg', '7-86'],
#  [7, 'T111', 9, 10, 'Route', 'po', '7-86'],
#  [7, 'T110', 10, 11, 'Frequency', 'BID', '7-86'],
#  [7, 'T7', 19, 20, 'Drug', 'Minoxidil', '7-90'],
#  [7, 'T259', 23, 25, 'Strength', '5 mg', '7-90'],
#  [7, 'T76', 10, 11, 'Drug', 'clonidine', '7-92'],
#  [7, 'T77', 11, 12, 'Form', 'patch', '7-92'],
#  [7, 'T11', 16, 17, 'Drug', 'Lisinopril', '7-94'],
#  [7, 'T12', 17, 19, 'Strength', '80 mg', '7-94'],
#  [7, 'T13', 19, 20, 'Route', 'po', '7-94'],
#  [7, 'T260', 20, 21, 'Frequency', 'daily', '7-94'],
#  [7, 'T64', 30, 31, 'Drug', 'Valsartan', '7-94'],
#  [7, 'T65', 31, 33, 'Strength', '320 mg', '7-94'],
#  [7, 'T261', 33, 34, 'Frequency', 'qhs', '7-94'],
#  [7, 'T134', 35, 36, 'Drug', 'Carvedilol', '7-94'],
#  [7, 'T135', 36, 38, 'Strength', '25 mg', '7-94'],
#  [7, 'T137', 38, 39, 'Route', 'po', '7-94'],
#  [7, 'T136', 39, 40, 'Frequency', 'BID', '7-94'],
#  [7, 'T118', 41, 43, 'Drug', 'Minoxidi l', '7-94'],
#  [7, 'T115', 43, 45, 'Strength', '5 mg', '7-94'],
#  [7, 'T117', 45, 46, 'Route', 'po', '7-94'],
#  [7, 'T116', 46, 47, 'Frequency', 'BID', '7-94'],
#  [7, 'T450', 1, 2, 'Reason', 'N', '7-109'],
#  [7, 'T429', 3, 4, 'Reason', 'V', '7-109'],
#  [7, 'T158', 1, 2, 'Drug', 'metoclopramide', '7-111'],
#  [7, 'T184', 6, 7, 'Drug', 'compazine', '7-111'],
#  [7, 'T195', 8, 9, 'Drug', 'zofran', '7-111'],
#  [7, 'T451', 12, 13, 'Reason', 'nausea', '7-114'],
#  [7, 'T442', 14, 15, 'Reason', 'vomiting', '7-114'],
#  [7, 'T180', 4, 5, 'Drug', 'metoclopramide', '7-116'],
#  [7, 'T181', 5, 7, 'Strength', '5 mg', '7-116'],
#  [7, 'T183', 7, 8, 'Route', 'PO', '7-116'],
#  [7, 'T182', 8, 9, 'Frequency', 'TID', '7-116'],
#  [7, 'T262', 1, 2, 'Reason', 'DM1', '7-120'],
#  [7, 'T263', 7, 8, 'Drug', 'HISS', '7-120'],
#  [7, 'T452', 1, 2, 'Reason', 'CKD', '7-122'],
#  [7, 'T71', 3, 4, 'Drug', 'sevelamer', '7-123'],
#  [7, 'T87', 6, 7, 'Drug', 'phoslo', '7-123'],
#  [7, 'T264', 1, 2, 'Reason', 'Neuropathy', '7-125'],
#  [7, 'T125', 3, 4, 'Drug', 'gabapentin', '7-125'],
#  [7, 'T126', 7, 8, 'Frequency', 'TID', '7-125'],
#  [7, 'T453', 13, 14, 'ADE', 'somnolent', '7-125'],
#  [7, 'T265', 13, 15, 'Strength', '300 mg', '7-129'],
#  [7, 'T266', 15, 16, 'Frequency', 'TID', '7-129'],
#  [7, 'T197', 5, 6, 'Drug', 'lidocaine', '7-131'],
#  [7, 'T198', 6, 7, 'Form', 'patch', '7-131'],
#  [7, 'T267', 8, 12, 'Reason', 'chronic left flank pain', '7-131'],
#  [7, 'T268', 1, 2, 'Reason', 'Depression', '7-134'],
#  [7, 'T35', 4, 5, 'Drug', 'citalopram', '7-135'],
#  [7, 'T24', 16, 17, 'Drug', 'Citalopram', '7-136'],
#  [7, 'T25', 17, 19, 'Strength', '20 mg', '7-136'],
#  [7, 'T269', 19, 20, 'Form', 'Tablet', '7-136'],
#  [7, 'T270', 21, 23, 'Dosage', 'Two (2)', '7-136'],
#  [7, 'T26', 23, 24, 'Form', 'Tablet', '7-136'],
#  ...]

# %%
sents_dict
# Out:
# {'0-0': 'He received 2 grams Ca-gluconate , 10 units of insulin and D50, sodium bicarbonate, and 15 mg PO',
#  '0-5': 'He proceeded to have brisk urine output. Potassium',
#  '0-6': 'He has had chronic knee pain for which he takes acetaminophen ; he also takes a nightly ibuprofen-containing sleep aid for insomnia',
#  '0-9': 'Additionally, he was also on a number of potentially nephrotoxigenic medications causing ATN, including lisinopril , NSAIDs , and potassium citrate',
#  '0-13': 'Furthermore, he was started on Tamsulosin for his BPH',
#  '0-15': '#Hyperkalemia: He was found to have an elevated K 8 with associated peaked T waves. Potassium levels dropped with administration of kayexalate , insulin',
#  '0-18': 'His blood sugars were managed on sliding scale insulin',
#  '0-19': 'Since he required Humalog 5-7 units for the last 3 days of hospitalization, he was sent home on Lantus 2units',
#  '0-23': 'He was also provided with an educational counseling session regarding home insulin',
#  '0-24': 'His oral',
#  '0-25': 'Was started on Tamsulosin',
#  '0-26': 'After transfer to the floor, he was continued on his Amlodipine 5mg and Metoprolol succinate',
#  '0-29': 'After transfer to the floor, he was continued on his Amlodipine 5mg and Metoprolol succinate 100 daily. Quinapril',
#  '0-30': 'Quinapril discontinued indefinitely. Tamsulosin',
#  '0-31': '-Renal outpatient follow up to readdress kidney function and possibility of restoring prior home meds: quinapril , metformin , glipizide -PCP follow up in the next couple days to follow up glucose control on newly started insulin regimen and antihypertensive regimen, and side effects to newly started Tamsulosin',
#  '0-37': '-Following meds should not be restarted until clearance from renal: quinipril, metformin , glipizide',
#  '0-39': '1. Aspirin 162 mg PO',
#  '0-42': 'Aspirin 162 mg PO DAILY 2. Metoprolol Succinate XL 100 mg PO',
#  '0-45': 'Metoprolol Succinate XL 100 mg PO DAILY 3. Ezetimibe 10 mg PO',
#  '0-48': 'Ezetimibe 10 mg PO DAILY 4. Quinapril 20 mg PO',
#  '0-51': 'Quinapril 20 mg PO DAILY 5. MetFORMIN ( Glucophage ) 1000 mg PO BID 6. potassium citrate *NF* 2 tablets Oral Daily',
#  '0-61': 'MetFORMIN (Glucophage) 1000 mg PO BID 6. potassium citrate *NF* 2 tablets Oral Daily 7. Rosuvastatin Calcium 20 mg PO DAILY',
#  '0-65': 'Rosuvastatin Calcium 20 mg PO DAILY 8. GlipiZIDE XL 10 mg PO BID',
#  '0-69': 'GlipiZIDE XL 10 mg PO BID 9. Amlodipine 5 mg PO DAILY',
#  '0-73': 'Amlodipine 5 mg PO DAILY Discharge Medications: 1. Amlodipine 5 mg PO DAILY',
#  '0-77': 'Amlodipine 5 mg PO DAILY 2. Rosuvastatin Calcium 20 mg PO DAILY',
#  '0-81': 'Rosuvastatin Calcium 20 mg PO DAILY 3. Aspirin 162 mg PO DAILY',
#  '0-85': 'Aspirin 162 mg PO DAILY 4. Metoprolol Succinate XL 100 mg PO DAILY',
#  '0-89': 'Metoprolol Succinate XL 100 mg PO DAILY 5. Tamsulosin 0.4 mg PO HS RX * tamsulosin 0.4 mg 1 capsule (s) by mouth at bedtime',
#  '0-99': 'Tamsulosin 0.4 mg PO HS RX *tamsulosin 0.4 mg 1 capsule(s) by mouth at bedtime Disp #*30 Capsule Refills:*1 6. Acetaminophen 325-650 mg PO Q6H:PRN pain RX * acetaminophen 500 mg 1 tablet (s) by mouth q6 hour',
#  '0-109': 'Acetaminophen 325-650 mg PO Q6H:PRN pain RX *acetaminophen 500 mg 1 tablet(s) by mouth q6 hour Disp #*40 Tablet Refills:*0 7. Docusate Sodium 100 mg PO BID RX * docusate sodium 100 mg 1 capsule (s) by mouth twice a day',
#  '0-119': 'Docusate Sodium 100 mg PO BID RX *docusate sodium 100 mg 1 capsule(s) by mouth twice a day Disp #*60 Capsule Refills:*0 8. Ezetimibe 10 mg PO',
#  '0-122': 'Ezetimibe 10 mg PO DAILY 9. HumaLOG KwikPen *NF* ( insulin lispro) 100 unit / mL Subcutaneous qam ac RX *insulin lispro [ Humalog KwikPen] 100 unit / mL',
#  '0-129': 'You were also started on Tamsulosin',
#  '1-0': 'In [**1-/2196**], developed a cough and drowsiness unaccompanied by fevers, chills, or SOB, recieved Azithromycin',
#  '1-2': 'Apart from a transient diarrhea which resolved after empiric Azithro',
#  '1-4': 'EMS was called for dyspnea and on the way to the [**Hospital1 18**], he had an episode of bradycardia to 39 for which he received 0.5mg of Atropine',
#  '1-7': 'In the ED, he had a grand mal seizure with extremities shaking x4 x1.5min and recieved Ativan 1mg',
#  '1-10': 'He also had an episode of hypothermia T=89 and was placed under a "bair hugger", received Ceftriaxone and Levoquin for ? PNA or sepsis',
#  '1-14': 'He was admitted to the MICU, he was found with rhythmic right shoulder jerks and a rolled back right eye and received Ativan 1mg',
#  '1-18': 'Neurology was consulted for AED mgmt, sz mgmt and altered mental status Review of Systems: As above Past Medical History: Cerebral palsy, mental retardation, seizures, LE edema (thought to be secondary to veinous insufficiency), seasonal allergies, contact dermatitis in groin treated with hydrocortisone',
#  '1-20': 'Gait: Deferred Pertinent Results: Recent STUDIES: [**2196-3-5**] CT NECK W/ CONTRAST',
#  '1-22': '[**2196-3-4**] CT HEAD W/O CONTRAST',
#  '1-23': 'NEURO: The patient had a dilantin level of 28 and Carbamazepin',
#  '1-25': 'His increased seizure frequency was felt to be realted to toxic dilantin',
#  '1-28': 'He was treated with a course of vancomycin emperically',
#  '1-30': 'Medications on Admission: Medications - Prescription CARBAMAZEPINE [TEGRETOL XR] - 200 mg Tablet Sustained Release 12hr - 1 Tablet (s) by mouth 2/day CHUX - - case/9 as needed FEXOFENADINE - 60 mg Tablet - 1 Tablet (s) by mouth twice a day as needed for rhinitis , sneezing HELMET - - HARD SHELL HELMET WITH A FACE BAR dx: Seizures use as directed to prevent injury HYDROCORTISONE - 2.5 % Cream - Apply to areas of redness twice a day as needed for (not open areas) It the rash worsens please stop using cream and call the office LEVETIRACETAM [KEPPRA] - 500 mg Tablet - 1 Tablet (s) by mouth 6/day - No Substitution PHENYTOIN SODIUM EXTENDED [DILANTIN KAPSEAL] - 100 mg Capsule - 1 Capsule(s) by mouth 2/day',
#  '1-64': 'Brand name medically necessary - No Substitution TIMOLOL MALEATE [TIMOPTIC-XE] - 0.5 % Gel Forming Solution - 1 drop right eye q AM Medications - OTC BACITRACIN - 500 unit/gram Ointment - apply once daily to area CARBAMIDE PEROXIDE - 6.5 % Drops - one dropper full in each ear daily as needed for ear wax',
#  '1-82': 'You were treated with broadspectrum antibiotics',
#  '1-83': 'Regardless, you received sufficient vancomycin to cover this organism in the unlikely event that it represented a true infection',
#  '1-85': 'During this period of suspected sepsis your seizure',
#  '1-86': 'We have adjusted your anti-seizure medications',
#  '1-87': 'You are currently stable on the medications as follows: Carbamazepine 400mg /600mg am/pm Keppra 1500mg /2000mg am/pm Phenytoin 150mg /100mg am/pm and you were started on Lamictal 25mg [**Hospital1 **] which will be increased by 25mg every week until you are on a dose of 150mg',
#  '2-0': 'Admission Date: [**2170-10-4**] Discharge Date: [**2170-10-10**] Service: MEDICINE Allergies: Amoxicillin Attending:[**First Name3 (LF) 99**] Chief Complaint: GI Bleed Major Surgical or Invasive Procedure: None History of Present Illness: This is an 84 y/o female recently dx with AML on supportive treatment only, on coumadin for atrial fibrillation and h/o TIA',
#  '2-4': 'She was given 1 U PRBC , 2 U FFP , and 5 mg SC vit K',
#  '2-11': 'Past Medical History: 1. Atrial fibrillation with a history of TIA 10 years ago on chronic anticoagulation with Coumadin',
#  '2-15': '3. Polymyalgia rheumatica , previously treated with steroids',
#  '2-17': "Brief Hospital Course: 84 y/o female with AML, Alzheimer's dementia, Afib and h/o TIA's on coumadin",
#  '2-20': '# GIB',
#  '2-21': 'Spoke with IR, who recommended medical management with PRBCs and FFP',
#  '2-23': 'She will be discharged on 7 days of PO levofloxacin for neutropenia',
#  '2-26': '# A fib - rate-controlled on digoxin',
#  '2-28': '# Dementia',
#  '2-29': 'Continued Aricept and Namenda',
#  '2-31': 'Medications on Admission: 1. Aricept 5 mg',
#  '2-33': 'Aricept 5 mg [**Hospital1 **] 2. Coumadin 4 mg M/W/F , 5 mg S/[**Doctor First Name **]/Tues',
#  '2-38': 'Coumadin 4 mg M/W/F, 5 mg S/[**Doctor First Name **]/Tues 3. Detrol 1 mg',
#  '2-40': 'Detrol 1 mg [**Hospital1 **] 4. Digoxin 250 mcg qd',
#  '2-43': 'Digoxin 250 mcg qd 5. Fosamax 70 mg qweek',
#  '2-46': 'Fosamax 70 mg qweek 6. Namenda 10 mg',
#  '2-48': 'Namenda 10 mg [**Hospital1 **] 7. MVI qd',
#  '2-50': 'MVI qd 8. Ca/Vit D qd',
#  '2-52': 'Ca/Vit D qd Discharge Medications: 1. Digoxin 125 mcg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '2-59': 'Disp:*30 Tablet(s',
#  '2-60': 'Disp:*30 Tablet(s)* Refills:*2* 2. Memantine 5 mg Tablet Sig: Two (2) Tablet PO bid',
#  '2-67': 'Disp:*30 Tablet(s)',
#  '2-68': 'Disp:*30 Tablet(s)* Refills:*1* 3. Donepezil 5 mg Tablet Sig: Two (2) Tablet PO HS (at bedtime)',
#  '2-75': '4. Levofloxacin 250 mg Tablet Sig: One (1) Tablet PO QDAY () for 7 days',
#  '2-83': 'Disp:*7 Tablet(s)',
#  '3-0': 'Of note, this patient was admitted to oncology from [**Date range (1) **] for bilateral DVTs of common femoral, superficial femoral, politeal, and calf veins',
#  '3-1': 'At that time, he was started Dalteparin (Fragmin) daily',
#  '3-3': 'In the ER, intial vitals were 103/43, HR 96, RR 22, O2sat 77% on RA',
#  '3-4': 'Reportedly altered when hypoxic , but mental status improved once on oxygen',
#  '3-6': 'A CTA was done showing clot in right main pulmonary artery and branch arteries in the LLL',
#  '3-7': 'He was started on heparin',
#  '3-8': 'He also remains hypoxemic',
#  '3-9': 'Attempt was made to put him in 6l NC , but he became tachpyneic',
#  '3-12': '- CAD s/p stent [**2-18**] (was on plavix',
#  '3-14': 'He was altered when hypoxic , but mental status improved once on oxygen',
#  '3-16': 'A CTA was done showing clot in right main pulmonary artery and branch arteries in the LLL. He was started on heparin',
#  '3-18': 'Attempt was made to put him in 6 L NC , but he became tachpyneic',
#  '3-21': 'desaturated on [**11-17**] PSV/CPAP with 50% Fio2 and sinus tachycardic',
#  '3-24': 'Initially thought it was [**3-12**] agitation / delirium - was given Zyprexa',
#  '3-27': 'Thought trach looked fine and was more concerned with clinical picture. Still agitated , given Versed for sedation',
#  '3-30': 'Placed on CMV (TV 500, RR 14, FIO2 100%, PEEP 10). Pressures began to drop to 80-90s systolic',
#  '3-31': 'Started on Neo',
#  '3-32': 'Deeply sedated with propofol and fentanyl',
#  '3-34': '- Other considerations: changing NGT to OGT; starting antifungal',
#  '3-35': 'However MAPs not ideal so went up on pressor',
#  '3-36': "[**2148-8-23**]: -pt spiked fever in the afternoon -pt started on vancomycin , ciprofloxacin , and cefepime empirically -nurses suctioning bright red blood from trach- stopped heparin gtt for now -t-[**Doctor First Name **] aware, asked to check Hct, recommend BAL tmrw; call them if bleeding worsens [**2148-8-22**]: -increased BB to 25 TID -got ct abd pelv [**2148-8-21**]: - rec'd PICC today - sedation weaned, much more interactive - up titrated beta blocker although HR remains in 100s - attempted Trach mask trials - increased secretions, likely [**3-12**] fluid overload - given IV lasix 40mg - met goal of 1-2L negative - GI consulted for PEG placement - no recs yet - rec'd valium - SBP dropped to 80s systolic responded with 250cc bolus - did not sleep all night [**2148-8-20**]: -weaning sedation -discussion ongoing for PEG vs. Dobhoff between oncologist Dr. [**First Name (STitle) 2405**] and T-[**Doctor First Name **] Dr. [**First Name (STitle) **]; -plans for Dobhoff tomorrow in IR -start coumadin tmrw [**2148-8-19**]: -HR still 100-130s -got trach placed , no immediate complications -agitated overnight, needed to increase sedation w/ fentanyl -back on IV heparin [**2148-8-18**]: -NPO after MN for peg/ trach placement and heparin",
#  '3-59': "[**2148-8-23**]: -pt spiked fever in the afternoon -pt started on vancomycin, ciprofloxacin, and cefepime empirically -nurses suctioning bright red blood from trach- stopped heparin gtt for now -t-[**Doctor First Name **] aware, asked to check Hct, recommend BAL tmrw; call them if bleeding worsens [**2148-8-22**]: -increased BB to 25 TID -got ct abd pelv [**2148-8-21**]: - rec'd PICC today - sedation weaned, much more interactive - up titrated beta blocker although HR remains in 100s - attempted Trach mask trials - increased secretions, likely [**3-12**] fluid overload - given IV lasix 40mg - met goal of 1-2L negative - GI consulted for PEG placement - no recs yet - rec'd valium - SBP dropped to 80s systolic responded with 250cc bolus - did not sleep all night [**2148-8-20**]: -weaning sedation -discussion ongoing for PEG vs. Dobhoff between oncologist Dr. [**First Name (STitle) 2405**] and T-[**Doctor First Name **] Dr. [**First Name (STitle) **]; -plans for Dobhoff tomorrow in IR -start coumadin tmrw [**2148-8-19**]: -HR still 100-130s -got trach placed , no immediate complications -agitated overnight, needed to increase sedation w/ fentanyl -back on IV heparin [**2148-8-18**]: -NPO after MN for peg/ trach placement and heparin held at 4 am [**8-17**]: - Settings on PS [**11-15**], doing well [**2148-8-16**]: -plan is to have trach/ peg placed on monday [**8-19**] between 8 am -12 pm. Heparin",
#  '3-60': 'please contact anesthesia attending to make them aware of possible emergency airway -wife must sign consetns for trach and peg - anesthesia booked for monday [**8-19**] between 8-10am, case # [**Numeric Identifier 85087**] (booking called at [**Numeric Identifier 85088**]) - dilantin 6.6 , corrected to 13.8',
#  '3-63': 'Check tomorrow, if low, give U PRBC, guiac stools',
#  '3-65': 'we will need to stop tube feeds and heparin',
#  '3-66': "-Onc: hodkins stable, nodes smaller -d/c bactrim , now on atovaquone - mucomyst given for secretions -ABD CT: thickening of fundus and ascending colon- questionable worsening Hodgkin's -discharge summary updated [**8-14**] - CT chest CT/ abd/ pelvis ordered to eval for progression of Hodgkin's -CT [**Doctor First Name **] consulted re trach placement - BMT recs: switch bactrim to atovaquone (worry that bactrim allergy may be causing increased eos",
#  '3-76': '- stool send for ova/ parasites (as source of eos) - Family [**Doctor First Name 85089**] scheduled for 2 PM with entire family tommorrow - Probably should get onc and BMT on board - Onc will be present at [**Last Name (LF) 85089**], [**First Name3 (LF) **] review scan with radiology prior [**8-13**]: -go down on PEEP - CVP 10 , give gently lasix 20',
#  '3-80': '-stopped bactrim because negative bAL PCP x2 [**8-12**] -nutrition consulted for recs to decrease fluid intake [**8-11**]: Resp took off ARDS net protocol, put patient on PS, RR went down into 20s, good sats, PCO2 41 at 3 PM - Spiked fever to 103 at 2 PM, tyylenol given and blood cultures sent - Given 2 x 40 Lasix boluses by 3 PM; peeing well over 2 L but still overall positive due to tube feeds; by 10 PM, MAPs in 70s, still slightly tach to 110s, will hold off on another bolus of Lasix for now - Was becoming tachycardic and tachypneic, went up to PS of 15 at midnight - Talked to son about possibility of a trach and that he may not come off the vent -BCx, UCx, sputum cx sent [**8-10**] -run of A. Fib / A. flutter (atrial ectopy hybrid) around 2200, started on digoxin',
#  '3-92': '-stopped bactrim because negative bAL PCP x2 [**8-12**] -nutrition consulted for recs to decrease fluid intake [**8-11**]: Resp took off ARDS net protocol, put patient on PS, RR went down into 20s, good sats, PCO2 41 at 3 PM - Spiked fever to 103 at 2 PM, tyylenol given and blood cultures sent - Given 2 x 40 Lasix boluses by 3 PM; peeing well over 2 L but still overall positive due to tube feeds; by 10 PM, MAPs in 70s, still slightly tach to 110s, will hold off on another bolus of Lasix for now - Was becoming tachycardic and tachypneic, went up to PS of 15 at midnight - Talked to son about possibility of a trach and that he may not come off the vent -BCx, UCx, sputum cx sent [**8-10**] -run of A. Fib/ A. flutter (atrial ectopy hybrid) around 2200, started on digoxin. Norepinephrine changed to phenylepinephrine (alpha agonist only, no beta agonist ) - pt given 500 cc fluid bolus at 22:30 for hypotension',
#  '3-98': 'worse ground glass opacities, traction bronchiectasis suggestive of underlying interstitial fibrotic lung disease, New left pleural effusion with associated atelectasis - K, Phos repleted with pot phos iv 15 ml/ 250 cc NS - B-lucan positive',
#  '3-104': 'Started him on bactrim',
#  '3-105': 'Already getting steroids',
#  '3-106': '- 20 IV lasix x2',
#  '3-110': "-tube feeds restarted after CTA - metoprolol d/c'ed - solumedrol decreased from 50 to 40 [**8-8**] -diet advanced to full thin liquids -tube feeds restarted at 20 ml/hr, advance to 50 ml/hr - metoprolol started at 12.5 mg q6h for HTN , tachycardia (home dose 200 mg po qD ) -f/u ECG, enzymes, lytes in PM - 3rd c diff negative - NGT placed [**8-7**] -extubated, coughing, satting high 80-low 90 -c. diff neg x2, check last c.diff - hdyrocortisone 50 q12 -continue vanco , levo , cefepine",
#  '3-128': "(Once propofol d/c'ed- increase to 50/hr and stop benefiber ) - Family meeting wiht pt's wife and daughter in afternoon for update on status - po flagyl started until c. diff ruled out -possible bleomycin toxicity , keep on room air unless PaO2< 88 - tube feeds restarted - 500 cc bolus given for CVP of 5 [**8-5**]: - sucralfate added for blood in OG tube on [**8-4**] - Sedation decreased, pressors decreased - Tachypnea during SBT, and increased secretions, will attempt to extubate tomorrow AM - Copious Diarrhea, C. diff sent - 5 am, patient turned, became hypotensive to SBP to 70s, 2 L NS hung, PAC bigemeny, low K , K repleted, pressure stabilized with fluid and decreased Propofol",
#  '3-146': '-gentle diuresis to improve ventilation',
#  '3-148': 'Now on Fent , Versed , Propofol 20 , 1.3 Neo',
#  '3-154': '-goal to stop propofol tomorrow morning and switch to PSV',
#  '3-156': '-tried A-line but unsuccessful at several attempts [**2148-8-3**] 73 y/o w/ ivc filter, start on pcp [**Name9 (PRE) **] [**Name9 (PRE) 85090**] to floor at 3:30 pm - dilantin',
#  '3-157': 'Pt given loading dose of phenytoin of 500 mg iv at 7 pm and standing dose increased from 200 mg Q8 to 250 mg Q8',
#  '3-164': '-check dilantin level in pm of [**8-4**] - vanco changed from 1000 mg q12 to 100o q8 h. vanc trough ordered for [**8-4**] [**8-2**] - Will get IVC filter placed at 8 AM - Weaned off Propofol [**2148-8-1**] -new A-line placed -central line placed -worsening respiratory failure: received 10 L of fluids in last 24 hrs',
#  '3-176': 'femoral, superficial femoral, popliteal involvement bilaterally -metabolic acidosis -->met acidosis + resp acidosis after increasing PEEP and FiO2 which improved oxygenation',
#  '3-178': "[**7-31**] overnight - pt was requiring FiO2 of 100% on CPAP and was sating in mid-80's -intubated and placed on volume support - placed on vanco , zosyn and bactrim for ground glass findings on chest CT concerning for pneumonia and possible PCP [**Name Initial (PRE) **] phenytoin was changed to iv as pt unable to take po at this time Medications on Admission: Medications: Per wife: Prednisone one pill in AM and 2 pills at night (likely 10mg and 20mg , will check with PCP) Vitamin D 800mg daily Iron 325mg three times daily folic acid 1 g daily dalteparin 15,000 units sub Q daily Mesalamine 4 pills twice daily Phenytoin 100 mg - 6 pills at night Metoprolol 200 mg po daily Isosorbide 60 mg po every morning",
#  '4-0': 'Name: [**Known lastname **], [**Known firstname 9188**] Unit No: [**Numeric Identifier 15402**] Admission Date: [**2107-3-4**] Discharge Date: [**2107-3-10**] Date of Birth: [**2029-12-14**] Sex: F Service: FINAL DISCHARGE MEDICATIONS: 1. Heparin 5,000 units subq q.8.',
#  '4-4': '2. Acetaminophen 325 mg 1-2 tablets p.o. q.4-6h. prn.',
#  '4-10': '3. Olanzapin e 2.5 mg p.o. q.i.d. prn.',
#  '4-14': '4. Docusate 100 mg p.o. b.i.d. prn.',
#  '4-18': '5. Senna 8.6 mg p.o. b.i.d. prn.',
#  '4-22': '6. Carbidopa/ levodopa 25/100 mg one tablet p.o. t.i.d.',
#  '4-28': '7. Levothyroxine 100 mcg p.o. q.d.',
#  '4-32': '8. Valsartan/ hydrochlorothiazide 80/12.5 mg one tablet p.o. q.d.',
#  '4-38': '[**Name10 (NameIs) 15403**] patient will likely need close followup of thyroid replacement medication as she will likely require a lower dose of exogenous thyroid in the future as she is unlikely to be reinstated on Lithium',
#  '5-0': 'Pt denied diarrhaea, constipation, recent NSAID',
#  '5-1': 'She was guiaic positive rectally',
#  '5-2': 'She was given 1L IVF and started on protonix',
#  '5-5': 'She is on a heparin gtt',
#  '5-7': 'Past Medical History: aortic valve replacement, mitral valve replacement in [**1-27**] secondary to rheumatic heart disease hypertension atrial fibrillation on coumadin',
#  '5-9': 'Anticoag risk: bigger cardiac/CVA risk of not anticoagulating, compared to anticoagulation risk for GIB',
#  '5-10': 'She was put on a planned course of [**Hospital1 **] PPI for one month , and daily PPI',
#  '5-14': 'She was bridged back to coumadin with a heparin drip',
#  '5-17': '# HTN : held ACE and BB for concern for possible new bleeding and risk for hypotension',
#  '5-21': '## Mechanical heart valve : Was on heparin bridge while off coumadin',
#  '5-24': 'This latter heparin to coumadin',
#  '5-26': '# PPx : Heparin / coumadin , as above; PPI',
#  '5-30': 'Medications on Admission: toprol xl 50 mg po qdaily quinipril 20 mg po qdaily lipitor 10mg po qdaily protonix 40 mg po qdaily lasix 20 mg po qdaily colace 100mg po qdaily ativan 1.5mg po qhs',
#  '5-58': 'Medications on Admission: toprol xl 50 mg po qdaily quinipril 20 mg po qdaily lipitor 10mg po qdaily protonix 40 mg po qdaily lasix 20 mg po qdaily colace 100mg po qdaily ativan 1.5mg po qhs Discharge Medications: 1. Atorvastatin 10 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '5-65': 'Disp:*30 Tablet(s)* Refills:*2* 2. Methyl Salicylate-Menthol 15-15 % Ointment Sig: One (1) Appl Topical [**Hospital1 **] ( 2 times a day) as needed for back pain',
#  '5-73': 'Disp:*1 tube* Refills:*2* 3. Acetaminophen 325 mg Tablet Sig: 1-2 Tablets PO Q6H (every 6 hours) as needed for pain',
#  '5-81': '4. Pantoprazole 40 mg Tablet, Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q12H (every 12 hours) as needed for antral erosions for 1 months',
#  '5-90': ')(s)* Refills:*0* 5. Warfarin 2.5 mg Tablet Sig: Two (2) Tablet PO at bedtime : Talk to your doctor about whether you should change your dose of warfarin',
#  '5-98': 'You have been taking coumadin (also called warfarin ), a blood-thinning medicine that is important for you because you have mechanical heart valves',
#  '5-101': 'You have been taking coumadin (also called warfarin), a blood-thinning medicine that is important for you because you have mechanical heart valves. Coumadin helps to prevent strokes',
#  '5-103': 'But coumadin can also make it easier to bleed',
#  '5-105': 'It is likely that with too high a coumadin level, the erosions in your stomach bled',
#  '5-107': 'You should continue to take the coumadin',
#  '5-108': 'Your doctor or nurse may need to change the dosage in order to make sure the coumadin',
#  '5-109': 'Sometimes leafy green vegetables can lower your coumadin',
#  '5-110': 'If eating leafy green vegetables is important in your diet, talk to your doctor about trying to find ways that you can eat your vegetables and have a stable coumadin',
#  '5-111': 'Followup Instructions: Make an appointment with Dr [**Last Name (STitle) **] as soon as possible-- they need to check your blood levels of Coumadin , the blood thinner',
#  '6-0': 'Admission Date: [**2120-5-7**] Discharge Date: [**2120-5-10**] Date of Birth: [**2057-11-21**] Sex: F Service: NEUROSURGERY Allergies: Sulfa (Sulfonamide Antibiotics) / Prochlorperazine / IV Dye , Iodine',
#  '6-4': 'Pt underwent the procedure without difficulty and awoke from anesthesia',
#  '6-5': 'She was recovered in the NICU overnight, patient developed a diffused rash , she was given Benadryl',
#  '6-7': 'The rash worsened overnight and she became hypotensive',
#  '6-9': 'She was started on Neo',
#  '6-10': 'Her Heparin gtt',
#  '6-12': 'She was started on ASA and Plavix',
#  '6-14': 'Allergy initially asked for Decadron 4mg Q6 hrs for 48 hrs , a H2 blocker , and Benadryl',
#  '6-20': "On [**5-9**], there was significant improvement in patient's allergic reaction",
#  '6-21': 'She is to continue decardon 4mg q8 IV until tomorrow',
#  '6-26': 'On [**5-10**], she was discharged home with ASA and Plavix x 1 month',
#  '6-29': 'She will continue Pepcid / Decadron / Benadryl for one more day with PO',
#  '6-34': 'Medications on Admission: Metoprolol Tartrate 25 mg PO BID Calcium Carbonate 500 mg PO BID Vitamin D 400 UNIT PO DAILY Plavix 75 mg PO DAILY Discharge Medications: 1. acetaminophe n 325 mg Tablet [**Month/Year (2) **]: Two (2) Tablet PO Q6H (every 6 hours) as needed for pain fever',
#  '6-59': '2. docusate sodium 100 mg Capsule [**Month/Year (2) **]: One (1) Capsule PO BID (2 times a day)',
#  '6-66': '3. oxycodone- acetaminophen 5-325 mg Tablet [**Month/Year (2) **]: One (1) Tablet PO Q4H (every 4 hours) as needed for pain',
#  '6-74': 'Disp:*20 Tablet(s)* Refills:*0* 4. clopidogrel 75 mg Tablet [**Month/Year (2) **]: One (1) Tablet PO DAILY (Daily)',
#  '6-81': 'Disp:*30 Tablet(s)* Refills:*0* 5. metoprolol tartrate 25 mg Tablet [**Month/Year (2) **]: One (1) Tablet PO BID (2 times a day)',
#  '6-88': '6. aspirin 325 mg Tablet [**Month/Year (2) **]: One (1) Tablet PO DAILY (Daily)',
#  '6-95': 'Disp:*30 Tablet(s)* Refills:*0* 7. diphenhydramine HCl 25 mg Capsule [**Month/Year (2) **]: Two (2) Capsule PO Q6H (every 6 hours) as needed for pruritis for 1 days',
#  '6-104': 'Disp:*10 Capsule(s)* Refills:*0* 8. famotidin e 20 mg Tablet [**Month/Year (2) **]: One (1) Tablet PO BID (2 times a day) for 1 days',
#  '6-112': 'Disp:*2 Tablet(s)* Refills:*0* 9. dexamethason e 4 mg Tablet [**Month/Year (2) **]: One (1) Tablet PO every eight (8) hours for 1 days',
#  '6-120': 'Disp:*3 Tablet(s)* Refills:*0* 10. calcium carbonate 200 mg calcium ( 500 mg ) Tablet , Chewable [**Month/Year (2) **]: One (1) Tablet, Chewable PO BID (2 times a day)',
#  '6-129': '11. cholecalciferol (vitamin D3) 400 unit Tablet [**Month/Year (2) **]: One (1) Tablet PO DAILY (Daily)',
#  '6-136': '12. hydrocortisone 2.5 % Cream [**Month/Year (2) **]: One (1) APPL Topical QID PRN as needed for itching',
#  '6-144': 'Disp:*1 TUBE* Refills:*3* 13. hydrocortisone 1 % Lotion [**Month/Year (2) **]: One (1) APPL Topical four times a day as needed for itching',
#  '6-152': 'Take Aspirin 325mg ( enteric coated ) once daily',
#  '6-156': 'Take Plavix (Clopidogrel) 75mg once daily',
#  '6-159': 'You make take Tylenol or prescribed pain medications for any post procedure pain or discomfort',
#  '6-163': '******* YOU ARE ALLERGIC TO CONTRAST DYE , AND WILL REQUIRE PRE-MEDICATION FOR ALL FUTURE IMAGING OR PROCEDURES THAT REQUIRE DYE',
#  '7-0': 'Given labetalol 10 mg IV , morphine (total of 8 mg IV ), percocet 2 tab , and benadryl 25 mg PO (due to itching itching from morphine morphine',
#  '7-15': 'They recommended an LP to rule out [**Doctor Last Name **] or infection given his vague symptoms. Fioricet was started to treat his headache',
#  '7-17': 'The headache',
#  '7-18': 'It was decided to discontinue his nifedipine and start verapamil , as verapamil is more vasoactive; this medication would help vasospasm, migraine, and HTN etiology',
#  '7-22': 'Pain was consulted and felt that dilaudid',
#  '7-23': 'It was felt that an injection would not be helpful, given the diffuse nature of his headaches',
#  '7-24': 'It was felt that an injection would not be helpful, given the diffuse nature of his headaches. Fioricet',
#  '7-25': 'He was continued on full dose verapamil and dilaudid prn',
#  '7-28': 'His HTN medication was aggressively uptitrated with the thought this this would help his headaches',
#  '7-30': 'He also had severe nausea and vomiting that was controlled with reglan , compazine , and zofran , which was also thought to help his headaches',
#  '7-36': 'He was given a trial of high flow oxygen as well in case the etiology was cluster headache',
#  '7-38': 'Of note, the patient was felt to be quite sensitive to opiates and benzos',
#  '7-40': 'On the day of his IR guided LP, he received 1 mg of IV Ativan , which decreased his RR to 8 and he appeared very sleepy',
#  '7-45': 'He also received 4 mg IV morphine to help control his HA , but he also developed decreased RR to 8 and the same sleepiness',
#  '7-51': 'Since the etiology of his headache was unclear, it was felt that placing the patient on a regimen that he could take at home would be the best for him, rather than IV dilaudid',
#  '7-54': 'He was started on low dose MS-contin [**Hospital1 **] and 25 mg topomax',
#  '7-57': 'Approximately 36 hours after these medications were started the patient was completely somnolent and responsive to sternal rub only',
#  '7-59': 'He was given Narcan 0.4 mg approximately three times over the course of his somnolence',
#  '7-63': 'It was felt the patient was on too much sedating medication',
#  '7-64': 'All opiates , topomax , and gabapentin',
#  '7-67': 'He was not given any more sedating medication and only given standing tylenol , 1000 mg q 8H',
#  '7-71': 'Surprisingly, tylenol by itself appeared to control his headaches',
#  '7-73': '# Hypertension',
#  '7-74': 'He began to take all of his anti-hypertensives',
#  '7-75': 'A clonidine patch was added at 0.1 mg',
#  '7-78': 'His MICU course was uneventful as his blood pressure decreased with IV hydralazine x 1 and po labetalol , along with taking his BP medications',
#  '7-85': 'He did not need an IV',
#  '7-86': 'He was then started on Minoxidi l 10 mg po BID',
#  '7-90': 'Near the end of his hospitalization, his blood pressure was lower than expected with levels in the low 100s. Minoxidil was decreased to 5 mg',
#  '7-92': 'It was also noted that he was not wearing his clonidine patch',
#  '7-94': 'After consultation with renal on the day of discharge, his current regimen is as follows: -- Lisinopril 80 mg po daily (To be held the mornings prior to HD) -- Valsartan 320 mg qhs -- Carvedilol 25 mg po BID -- Minoxidi l 5 mg po BID',
#  '7-109': 'His N / V',
#  '7-111': 'His metoclopramide was continued, as was compazine and zofran',
#  '7-114': 'Once this was controlled, his blood pressure and headaches, and eventually his nausea and vomiting',
#  '7-116': 'He was discharged on metoclopramide 5 mg PO TID',
#  '7-120': '# DM1 : continued home 75/25 plus HISS',
#  '7-122': '# CKD',
#  '7-123': 'Pt continued on sevelamer alone ( phoslo',
#  '7-125': '# Neuropathy : gabapentin was increased to TID initially, but when patient became somnolent',
#  '7-129': 'Of note, he was on a very high dose for HD patients ( 300 mg TID',
#  '7-131': 'He was continued on a lidocaine patch for chronic left flank pain',
#  '7-134': '# Depression',
#  '7-135': 'He was continued on citalopram',
#  '7-136': '# Code: Full Medications on Admission: Medications (per d/c summary [**2125-1-2**], pt could not confirm) 1. Citalopram 20 mg Tablet Sig: Two (2) Tablet PO DAILY (Daily)',
#  '7-143': '2. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO BID',
#  '7-150': '3. Glycopyrrolate 1 mg Tablet Sig: Two (2) Tablet PO BID (2 times a day)',
#  '7-157': '4. Lidocaine 5 %(700 mg/patch) Adhesive Patch, Medicated Sig: One (1) Adhesive Patch, Medicated Topical DAILY (Daily)',
#  '7-164': '5. Zolpidem 5 mg Tablet Sig: One (1) Tablet PO HS (at bedtime)',
#  '7-171': '6. Calcium Acetate 667 mg Capsule Sig: One (1) Capsule PO TID W/MEALS (3 TIMES A DAY WITH MEALS)',
#  '7-178': '7. Sevelamer Carbonate 800 mg Tablet Sig: One (1) Tablet PO TID W/MEALS (3 TIMES A DAY WITH MEALS)',
#  '7-185': '8. Oxycodone- Acetaminophen 5-325 mg Tablet Sig: One (1) Tablet PO Q6H (every 6 hours) as needed for pain',
#  '7-193': '9. Aspirin 81 mg Tablet, Chewable Sig: One (1) Tablet , Chewable PO DAILY (Daily)',
#  '7-200': '10. Pantoprazole 40 mg Tablet , Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q24H (every 24 hours)',
#  '7-207': '11. Sucralfate 1 gram Tablet Sig: One (1) Tablet PO QID (4 times a day)',
#  '7-214': '12. Metoclopramide 10 mg Tablet Sig: 0.5 Tablet PO QIDACHS (4 times a day (before meals and at bedtime))',
#  '7-221': '13. Ferrous Sulfate 325 mg ( 65 mg Iron ) Tablet Sig: One (1) Tablet PO TID (3 times a day)',
#  '7-230': '14. Nifedipine 60 mg Tablet Sustained Release Sig: Two (2) Tablet Sustained Release PO at bedtime',
#  '7-237': '15. Valsartan 160 mg Tablet Sig: Two (2) Tablet PO DAILY (Daily)',
#  '7-244': '16. Carvedilo l 12.5 mg Tablet Sig: One (1) Tablet PO BID (2 times a day)',
#  '7-251': '17. Lisinopril 20 mg Tablet Sig: Two (2) Tablet PO once a day',
#  '7-258': '18. Gabapentin 300 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)',
#  '7-265': '19. Humalog Mix 75-25 100 unit/mL (75-25) Suspension Sig: Six (6) units Subcutaneous with breakfast daily',
#  '7-271': '20. Humalog Mix 75-25 100 unit/mL (75-25) Suspension Sig: Five (5) units Subcutaneous with dinner daily',
#  '7-277': '21. Insulin sliding scale',
#  '7-279': 'Insulin sliding scale Discharge Medications: 1. Docusate Sodium 100 mg Capsule Sig: Two (2) Capsule PO BID (2 times a day)',
#  '7-286': '2. Lidocaine 5 %(700 mg/patch) Adhesive Patch, Medicated Sig: One (1) Adhesive Patch, Medicated Topical DAILY (Daily)',
#  '7-293': '3. Pantoprazol e 40 mg Tablet , Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q24H (every 24 hours)',
#  '7-300': '4. Aspirin 81 mg Tablet, Chewable Sig: One (1) Tablet , Chewable PO DAILY (Daily)',
#  '7-307': '5. Sevelamer Carbonate 800 mg Tablet Sig: One (1) Tablet PO TID W/MEALS (3 TIMES A DAY WITH MEALS)',
#  '7-314': '6. Senna 8.6 mg Tablet Sig: Two (2) Tablet PO BID (2 times a day)',
#  '7-321': '7. Insulin Humalog Mix 75-25 suspension',
#  '7-324': 'Insulin Humalog Mix 75-25 suspension. 6 units subcutaneously with breakfast daily and 5 units subcutaneously with dinner daily',
#  '7-330': '8. Insulin Humalog sliding scale with breakfast lunch and dinner daily',
#  '7-333': 'Insulin Humalog sliding scale with breakfast lunch and dinner daily 9. Reglan 5 mg Tablet Sig: One (1) Tablet PO three times a day',
#  '7-340': '10. Carvedilo l 25 mg Tablet Sig: One (1) Tablet PO twice a day',
#  '7-347': '11. Verapamil 240 mg Tablet Sustained Release Sig: One (1) Tablet Sustained Release PO twice a day',
#  '7-354': '12. Citalopra m 20 mg Tablet Sig: Two (2) Tablet PO DAILY (Daily)',
#  '7-361': '13. Valsartan 160 mg Tablet Sig: Two (2) Tablet PO QHS (once a day (at bedtime))',
#  '7-368': '14. Ammonium Lactate 12 % Lotion Sig: One (1) Appl Topical [**Hospital1 **] ( 2 times a day',
#  '7-375': '15. Clonidine 0.1 mg /24 hr Patch Weekly Sig: One (1) Patch Weekly Transdermal QSAT (every Saturday)',
#  '7-382': '16. Acetaminophe n 500 mg Tablet Sig: Two (2) Tablet PO Q8H (every 8 hours)',
#  '7-389': '17. Minoxidil 2.5 mg Tablet Sig: Two (2) Tablet PO BID (2 times a day)',
#  '7-396': '18. Lisinopri l 40 mg Tablet Sig: Two (2) Tablet PO once a day',
#  '7-403': 'Your headaches eventually resolved after addition of fioricet',
#  '7-405': 'Your nifedipine was also discontinued and switched to verapimil to help your headache',
#  '7-408': 'The pain service was consulted and a very strong medication, Dilaudid',
#  '7-409': 'We stopped your fiorcet as this did not appear to help your pain anymore, and gave you dilaudid for your pain',
#  '7-412': 'We tried to change your pain medication to different drugs ( ms contin and low dose topomax ), but this made you very sleepy for several days',
#  '7-416': 'We stopped all of these medications plus all strong sedating medications , such as dilaudid , gabapentin , and ambien',
#  '7-420': 'You were continued on tylenol alone for pain control',
#  '7-422': 'You are advised to not take these sedating medications',
#  '7-423': 'You will be discharged on a home dose of an anti-nausea medication , reglan',
#  '7-425': 'When you go back to rehab, your new medications are as follows: YOUR NEW BLOOD PRESSURE REGIMEN: Verapamil 240 mg every 12 hours Valsarta n 320 mg every night Lisinopril 80 mg daily Minoxidil 5 mg twice a day Clonidine patch 0.1 mg to be applied every saturday (keep on all week) PAIN CONTROL: Lidocaine 5% patch , apply 12 hours on and 12 hours off as needed for flank pain Tylenol 1000 mg every eight hours for headache',
#  '7-450': 'Do not take more than 4 grams of tylenol in 24 hours STOP: Gabapentin (this may make you sleepy ) Phoslo Glycopyrrolate',
#  '8-0': 'Admission Date: [**2163-4-16**] Discharge Date: [**2163-4-25**] Date of Birth: [**2131-9-11**] Sex: M Service: NEUROSURGERY Allergies: Azithromycin / Rocephin',
#  '8-2': 'REASON FOR THIS EXAMINATION: ?aneurysmal bleed CONTRAINDICATIONS FOR IV CONTRAST',
#  '8-4': '[**Known lastname 81043**],[**Known firstname **] [**Medical Record Number 81044**] M [**2070-9-25**] Radiology Report MRA NECK W&W/O CONTRAST Study Date of [**2163-4-17**] 12:39 PM [**Last Name (LF) **],[**First Name3 (LF) 742**] NSURG SICU-A [**2163-4-17**] 12:39 PM MR HEAD W & W/O CONTRAST; MRA BRAIN W/O CONTRAST; MRA NECK W&W/O CONTRAST Clip # [**Clip Number (Radiology) 81046**] Reason: eval for bleed Contrast : MAGNEVIST Amt: 20',
#  '8-7': 'Loaded dilantin and given nimodpine',
#  '8-9': 'Angio neg for aneurysm REASON FOR THIS EXAMINATION: eval for bleed CONTRAINDICATIONS FOR IV CONTRAST',
#  '8-11': 'Dynamic coronal VIBE imaging of the neck obtained during intravenous gadolinium',
#  '8-13': 'Following intravenous gadolinium',
#  '8-15': 'Pt was placed on dilantin and nimodipine',
#  '8-17': 'The findings were suggestive of pneumonia vs. aspiration however the pt is afebrile without elevated WBC, so no antibiotics',
#  '8-18': 'Bronchoscopy for sputum culture and or mucous plugging was performed. Lasix gtt was started for ARDS treatment',
#  '8-21': 'He was sent with a prescription of Levaquin to finish his treatment of his pneumonia',
#  '8-23': 'Medications on Admission: lantus , novuloge',
#  '8-25': 'Medications on Admission: lantus, novuloge, body building proteins and supplements Discharge Medications: 1. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)',
#  '8-32': 'Disp:*60 Capsule(s)* Refills:*2* 2. Butalbital -Acetaminophen-Caff 50-325-40 mg Tablet Sig: [**1-28**] Tablets PO Q6H (every 6 hours) as needed for headache',
#  '8-39': 'Disp:*60 Tablet(s)* Refills:*0* 3. Phenytoin 50 mg Tablet, Chewable Sig: Four (4) Tablet, Chewable PO TID (3 times a day) : YOU WERE PRESCRIBED THIS MEDICATION TO PREVENT SEIZURE',
#  '8-47': 'Outpatient Lab Work DILANTIN',
#  '8-48': '5. Nimodipin e 30 mg Capsule Sig: Two (2) Capsule PO Q4H (every 4 hours) for 12 days',
#  '8-56': 'Disp:*144 Capsule(s)* Refills:*0* 6. Levofloxaci n 250 mg Tablet Sig: Three (3) Tablet PO Q24H (every 24 hours) for 3 days',
#  '8-64': 'Disp:*9 Tablet(s)* Refills:*0* Discharge Disposition: Home Discharge Diagnosis: Perimesencaphalic hemorrhage Respiratory failure/hypoxia requiring mechanical ventilation Pneumonia = Community aquired Hyperglycemia = DM I MEDICATION REACTION / NEW ALLERGY TO AZITHROMYCIN AND ROCEPHIN Discharge Condition: NEUROLOGICALLY STABLE Discharge Instructions: Angiogram YOU HAVE BEEN PRESCRIBED DILANTIN FOR SEIZURE CONTROL',
#  '8-68': 'You make take Tylenol or prescribed pain medications for any post procedure pain',
#  '9-0': 'Admission Date: [**2180-9-9**] Discharge Date: [**2180-10-13**] Date of Birth: [**2148-11-12**] Sex: F Service: SURGERY Allergies: Nafcillin / Peanut Attending:[**First Name3 (LF) 5569**] Chief Complaint: Abdominal pain and fever Major Surgical or Invasive Procedure: Colonoscopy ([**2180-9-11**]) History of Present Illness: 31yoF with h/o IVDA, cirrhosis [**1-19**] autoimmune hepatitis c/b portal HTN w/ ascites, variceal bleed s/p TIPS on [**2180-7-17**], and hepatic encephalopathy, as well as hyperglycemia [**1-19**] TIPs and steroids',
#  '9-2': 'During that admission, she had a CT scan which showed no cause for her pain. Gastroenteritis was presumed and she was discharged home after her symptoms improved with zofran and dilaudid',
#  '9-5': 'At OSH ED, she received zofran 4 mg , dilaudid 1 mg x 3 , and 1L NS',
#  '9-12': 'She was given 2L NS , 0.5 mg IV dilaudid x 2 , and 4 mg IV zofran',
#  '9-21': 'Course was complicated by high-grade MRSA bacteremia requiring 6 weeks of IV vancomycin',
#  '9-25': 'Past Medical History: # Autoimmune hepatitis: [**Doctor First Name **]+, AMA-, [**Last Name (un) 15412**]+ # Cirrhosis, complicated by varices, hepatic encephalopathy, and ascites s/p TIPS [**2180-7-17**] # Hep C: Genotype 3. most recent viral load undetectable # high grade S aureus bacteremia on vancomycin',
#  '9-27': 'F with h/o IDDM, IVDA, cirrhosis [**1-19**] autoimmune hepatitis c/b portal HTN w/ ascites, variceal bleed s/p TIPS on [**2180-7-17**], and hepatic encephalopathy, presented with abd pain and occult anemia',
#  '9-28': 'Hct drop from 24 to 21. PRBC transfusion',
#  '9-30': 'Postop course was complicated by high ascites drain output requiring IV fluid replacements and albumin',
#  '9-34': 'Diet was slowly advanced. Lactulose and Rifaximin were started to prevent encephalopathy',
#  '9-37': 'She had high pain med requirements for persistent abdominal pain',
#  '9-39': 'Culture of fluid isolated 2 species of Acinetobacter Baumanii pan-sensitive except Bactrim',
#  '9-41': 'She was started on Cetriaxone',
#  '9-42': 'On postop day 13, she was re-started on Lasix and Aldactone',
#  '9-44': 'Creatinine continued to rise to 3.2 then decrease. Lasix was given for generalized edema',
#  '9-46': 'Diet was advanced and tolerated. Insulin gtt was initially started then switched to sliding scale',
#  '9-49': '[**Last Name (un) **] was consulted and Lantus with sliding scale',
#  '9-51': 'She was assisted out of bed to ambulate. Pain medication was switched to po Dilaudid',
#  '9-54': 'Dose was increased for c/o abdominal pain',
#  '9-55': 'She was also hypertensive',
#  '9-56': 'This was treated with IV Lopressor and IV Morphine',
#  '9-60': 'Head CT was normal. Norvasc was stopped for potential etiology of headache',
#  '9-62': 'Headache and abdominal pain resolved. Immunosuppression consisted of Cellcept which was well tolerated, steroids were tapered',
#  '9-66': 'Immunosuppression consisted of Cellcept which was well tolerated, steroids were tapered per protocol. Prograf',
#  '9-67': 'The plan was for Prednisone to continue permanently after taper for Autoimmune hepatitis',
#  '9-70': 'The plan was for Prednisone to continue permanently after taper for Autoimmune hepatitis. Lasix was continued for 2+ leg edema',
#  '9-72': 'She demonstrated good knowledge of medications and insulin',
#  '9-73': 'Of note, she experienced developed diffuse itching and burning of the skin and sensation of shortness of breath after eating a peanut butter',
#  '9-75': 'She was given Benadryl',
#  '9-76': 'Serum specific IgE to peanuts and other common food allergens were sent, and she was given an EpiPen',
#  '9-78': 'Medications on Admission: MEDICATIONS: (from prior discharge summary) # lactulose 10 gram /15 mL Syrup Sig: Thirty (30) ML PO Q2H (every 2 hours) as needed',
#  '9-84': '# azathioprine 50 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '9-91': '# magnesium oxide 400 mg Tablet Sig: One (1) Tablet PO twice a day',
#  '9-98': '# sulfamethoxazole- trimethoprim 800-160 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '9-105': '# spironolacton e 25 mg Tablet Sig: Two (2) Tablet PO DAILY (Daily ): Please give with furosemide',
#  '9-113': '# furosemide 40 mg Tablet Sig: One (1) Tablet PO DAILY (Daily) : Please give with spironolactone',
#  '9-121': '# metoprolol tartrate 25 mg Tablet Sig: One (1) Tablet PO BID (2 times a day)',
#  '9-128': '# pantoprazole 40 mg Tablet , Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q12H (every 12 hours)',
#  '9-135': '# rifaximi n 550 mg Tablet Sig: One (1) Tablet PO BID (2 times a day)',
#  '9-142': '# prednisone 10 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '9-149': '# insulin glargine 100 unit/mL Cartridge Sig: Thirty (30) units Subcutaneous qam : Please take 30 units of glargine insulin in the morning',
#  '9-158': '# ondansetro n 4 mg Tablet, Rapid Dissolve Sig: One (1) Tablet, Rapid Dissolve PO every eight (8) hours as needed for nausea for 5 doses',
#  '9-167': '# clotrimazole 10 mg Troche Sig: One (1) Troche Mucous membrane 5X/DAY (5 Times a Day)',
#  '9-174': '# fluconazol e 150 mg Tablet Sig: One (1) Tablet PO EVERY 3 DAYS (Every 3 Days)',
#  '9-181': '# insulin lispro 100 unit /mL Solution Sig: sliding scale Subcutaneous per sliding scale : Please take insulin lispro as directed by your home sliding scale three times a day before meals and before bedtime',
#  '9-190': 'Discharge Medications: 1. fluconazole 200 mg Tablet Sig: Two (2) Tablet PO Q24H (every 24 hours)',
#  '9-197': '2. prednisone 20 mg Tablet Sig: One (1) Tablet PO DAILY (Daily) : follow sliding scale taper',
#  '9-205': '3. docusate sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)',
#  '9-212': '4. mycophenolate mofetil 500 mg Tablet Sig: Two (2) Tablet PO BID (2 times a day)',
#  '9-219': '5. sulfamethoxazole-trimethoprim 400-80 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '9-226': '6. pantoprazol e 40 mg Tablet , Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO twice a day',
#  '9-233': '7. valganciclovi r 450 mg Tablet Sig: Two (2) Tablet PO once a day',
#  '9-240': '8. tacrolimus 1 mg Capsule Sig: Five (5) Capsule PO Q12H (every 12 hours)',
#  '9-247': '9. insulin lispro 100 unit /mL Solution Sig: follow sliding scale Subcutaneous four times a day',
#  '9-253': 'Disp:*1 bottle* Refills:*2* 10. tacrolimu s 1 mg Capsule Sig: Three (3) Capsule PO Q12H (every 12 hours)',
#  '9-260': '11. metoprolol tartrate 25 mg Tablet Sig: One (1) Tablet PO BID (2 times a day)',
#  '9-267': 'Disp:*60 Tablet(s) * Refills:*2* 12. pregabali n 25 mg Capsule Sig: Two (2) Capsule PO QHS (once a day (at bedtime))',
#  '9-275': 'Disp:*60 Capsule(s) * Refills:*2* 13. morphine 15 mg Tablet Extended Release Sig: One (1) Tablet Extended Release PO Q12H (every 12 hours)',
#  '9-283': 'Disp:*28 Tablet Extended Release(s) * Refills:*0* 14. oxycodone 5 mg Tablet Sig: Two (2) Tablet PO Q4H (every 4 hours) as needed for pain',
#  '9-292': 'Disp:*70 Tablet(s) * Refills:*0* 15. furosemide 40 mg Tablet Sig: One (1) Tablet PO BID (2 times a day)',
#  '9-300': 'Disp:*20 Tablet(s)',
#  '9-301': 'Disp:*20 Tablet(s)* Refills:*1* 16. NPH insulin human recomb 100 unit /mL Suspension Sig: Twenty (20) units Subcutaneous once a day',
#  '9-307': 'Disp:*1 bottle* Refills:*2* 17. Insulin Syringes Low dose U-100 syringes 25-26 gauge [**12-19**] inch needle for [**Hospital1 **] NPH and sliding scale qid humalog',
#  '10-0': 'Admission Date: [**2197-10-24**] Discharge Date: [**2197-11-17**] Date of Birth: [**2121-3-31**] Sex: F Service: MEDICINE Allergies: Propoxyphene / Pyridium / Bupropion / Darvon / Penicillins / Claritin / Codeine / Moexipril',
#  '10-8': 'The patient recieved toradol 15mg IV for pain',
#  '10-12': 'Given this new wheeze , she was started on solumedrol',
#  '10-14': 'Pt developed hypercarbic respiratory failure, initially responded to nebs but then began to have decreased air movement despite receiving racemic epi',
#  '10-15': 'Past Medical History: PMH: 1.) HTN -- has been controlled on HCTZ',
#  '10-17': 'On [**10-28**], she was started on vancomycin / flagyl / levofloxacin',
#  '10-20': "She was also started on solumedrol and MDI's",
#  '10-22': 'On [**10-30**], Mrs. [**Known lastname **] then developed hypercarbic respiratory failure and was found to have stridor / wheezing on exam which did not improve with racemic epi',
#  '10-25': 'Mrs. [**Known lastname **] did well post-op with only minor pain',
#  '10-26': 'This was controlled with morphine',
#  '10-27': 'She was maintained on nebulizers for respiratory comfort and morphine for pain control',
#  '10-29': '* 2. PNEUMONIA',
#  '10-30': 'Given her fragile respiratory status, this was treated as pneumonia with levo / flagyl / vancomycin',
#  '10-34': 'The antibiotic',
#  '10-35': 'With IV hydration',
#  '10-37': 'Her abdominal pain was thought to be due to peptic ulcer disease',
# ...
#  '25-3': 'The patient was given fluids and was transfused 2U of FFP and 2U of PRBC',
#  '25-8': 'The pt had an IVC filter placed and was on Heparin sc TID for DVT prophylaxis',
#  '25-12': 'PSH: S/p b/l TKR in [**2193**] s/p R total hip replacement in [**9-/2198**] complicated by a DVT for which an IVC filter was placed Addendum/clarification based on discussion with the PCP ([**First Name5 (NamePattern1) 4468**] [**Last Name (NamePattern1) 70012**]): She underwent R THR at [**Hospital3 934**] in [**5-15**] without complications, discharged on coumadin for DVT prophylaxis',
#  '25-14': 'Readmitted in [**6-14**] with thigh pain and a DVT',
#  '25-15': 'On lovenox , plavix and aspirin , she developed a thigh hematoma',
#  '25-19': 'Placed on steroids',
#  '25-20': 'Readmitted [**11-11**] from rehab because she was placed on heparin SQ despite the IVCF and developed BRBPR and hypotension',
#  '25-24': 'Targeted colonoscopy of this area or single-contrast barium',
#  '25-25': '1) LGIB',
#  '25-26': "She received 2 units of FFP and 2 units of PRBC's",
#  '25-30': 'She was admitted to the MICU at [**Hospital1 18**] and GoLytely was administered in preparation for a colonoscopy',
#  '25-32': "On admission to this institution, she had a large drop in her hct from 33.8 to 26.6 and was transfused an additional 2 units of PRBC's and started on IV PPI",
#  '25-36': '3) Rheumatoid Arthritis - Patient has a long history of RA for 30 years and is on a slow prednisone taper',
#  '25-39': 'Current dose of 20 mg was continued to prevent adrenal insufficiency',
#  '25-41': '4) Leukocytosis : Most likely due to chronic prednisone',
#  '25-43': '5) Afib : Sotalol',
#  '25-45': '6) FEN : Received gentle IVFs',
#  '25-47': 'Patient has IVC filter in place given h/o DVT. PPI for GI prophylaxis',
#  '25-49': '9) Code status: DNR/DNI Medications on Admission: Medications on admission to outside hospital: Lipitor 10mg QD Enteric coated Aspirin 81 mg Nexium 40mg QD Sotalol 40mg QD Prednisone 20mg QD',
#  '25-64': 'Home Meds: included sq heparin',
#  '25-66': 'Medications on transfer to outside hospital: Pantoprazol e 40 mg PO Q12H Prednison e 20 mg PO DAILY Acetaminophen 325-650 mg PO Q4 -6H:PRN Sotalol HCl 40 mg PO DAILY Atorvastati n 10 mg PO DAILY',
#  '25-86': 'Medications on transfer to outside hospital: Pantoprazole 40 mg PO Q12H Prednisone 20 mg PO DAILY Acetaminophen 325-650 mg PO Q4-6H:PRN Sotalol HCl 40 mg PO DAILY Atorvastatin 10 mg PO DAILY Discharge Medications: 1. Atorvastati n 10 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '25-93': '2. Acetaminophen 325 mg Tablet Sig: Two (2) Tablet PO every [**3-15**] hours as needed for pain',
#  '25-100': '3. Pantoprazole 40 mg Tablet , Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q12H (every 12 hours)',
#  '25-107': '4. Prednisone 20 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '25-114': '5. Sotalol 80 mg Tablet Sig: 0.5 Tablet PO DAILY (Daily)',
#  '26-0': 'Admission Date: [**2172-4-19**] Discharge Date: [**2172-4-24**] Date of Birth: [**2105-9-27**] Sex: M Service: NEUROLOGY Allergies: Patient recorded as having No Known Allergies to Drugs',
#  '26-1': 'He was on high dose steroid therapy to reduce the cerebral edema and developed a myopathy which prompted the gradual tapering of his steroids',
#  '26-7': 'He was recently enrolled in the Xerecept clinical trial and his decadron dose was reduced from 12mg qd down to 6 mg qd',
#  '26-13': 'His daughter notes that since the reduction of the steroids',
#  '26-14': 'He was recently diagnosed with a right lower extremity DVT for which he was started on lovenox',
#  '26-16': 'Pt discussed with Dr [**Last Name (STitle) 724**] and given dose of Dexadron ( 10 mg IV',
#  '26-19': 'Past Medical History: 1. Astrocytoma, grade III : Now, status-post: - Open Brain Biopsy on [**2171-7-11**] by Dr. [**Last Name (STitle) **] - Cyberknife SRS [**2171-10-2**] to left temporal area to 1800 cGy - [**Doctor Last Name **] + Navelbine started [**2171-10-3**] for 3 cycles - Involved-field radiation (3.5 wks) + Temodar',
#  '26-23': "Astrocytoma: The CT of his demonstrated increasing midline shift along with increasing edema likely accounting for the majority of his symptoms. Steroid dose had been tapered recently given the patient's steroid myopathy",
#  '26-27': 'Given this, he was given 10 mg IV decadrom in the emergency room with continuation of IV steroids',
#  '26-32': 'The patient was taken to the trauma ICU overnight for close monitoring of his neuro status and blood pressure. PRN hydralazine was used to keep SBP<140',
#  '26-35': 'At the time of discharge, the plan was for: - Continued dexamethasone , with taper - Follow-up with Dr. [**Last Name (STitle) 4253**] on [**5-5**] for chemotherapy - Monitoring of mental status - Metoprolol was started for blood pressure control',
#  '26-40': 'At the time of discharge, the plan was for: - Continued dexamethasone, with taper - Follow-up with Dr. [**Last Name (STitle) 4253**] on [**5-5**] for chemotherapy - Monitoring of mental status - Metoprolol was started for blood pressure control 2. Steroid Myopathy : Patient had a history of steroid induced myopathy and had presented with an ongoing steroid taper',
#  '26-46': 'Given the amount of edema seen and the symptoms secondary to this, steroids were increased at the time of admission and were continued; upon discharge, plan was for a steroid taper',
#  '26-50': '3. DVT',
#  '26-51': 'Presented on daily lovenox',
#  '26-53': 'Post-operatively, the lovenox',
#  '26-54': 'Medications on Admission: Zoloft 100 mg HS Keppra 1000 mg [**Hospital1 **] Aggrenox 200/25 mg [**Hospital1 **] Zocor 20 mg HS Senna-C [**Hospital1 **] Colace [**Hospital1 **] Protonix 40 mg daily Lovenox 100mg qd Decadron 4 mg TID',
#  '26-75': 'Medications on Admission: Zoloft 100 mg HS Keppra 1000 mg [**Hospital1 **] Aggrenox 200/25 mg [**Hospital1 **] Zocor 20 mg HS Senna-C [**Hospital1 **] Colace [**Hospital1 **] Protonix 40 mg daily Lovenox 100mg qd Decadron 4 mg TID (?) Decadron 4mg qam and 2 mg qpm',
#  '26-80': 'Decadron 4mg qam and 2 mg qpm (?) Ativan PRN',
#  '26-82': 'Ativan PRN Discharge Medications: 1. Sertraline 100 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '26-89': '2. Levetiracetam 500 mg Tablet Sig: Two (2) Tablet PO BID (2 times a day)',
#  '26-96': '3. Simvastati n 10 mg Tablet Sig: Two (2) Tablet PO DAILY (Daily)',
#  '26-103': '4. Senna 8.6 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '26-110': '5. Pantoprazol e 40 mg Tablet, Delayed Release (E.C.) Sig: One (1) Tablet , Delayed Release (E.C.) PO Q24H (every 24 hours)',
#  '26-117': '6. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)',
#  '26-124': '7. Trimethoprim- Sulfamethoxazole 160-800 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '26-131': '8. Insulin Lispro (Human) 100 unit /mL Solution Sig: One (1) Subcutaneous ASDIR (AS DIRECTED): Please see attached sliding scale',
#  '26-137': 'To be used while on steroids',
#  '26-138': '9. Dexamethasone 4 mg Tablet Sig: Two (2) Tablet PO TID (3 times a day) : Taper as follows: 8mg TID ([**Date range (1) 42062**]) 6mg TID ([**Date range (1) 42063**]) 4mg TID',
#  '26-151': '10. Oxycodone- Acetaminophen 5-325 mg Tablet Sig: One (1) Tablet PO Q4 -6H (every 4 to 6 hours) as needed for pain',
#  '26-159': '11. Metoprolol Tartrate 25 mg Tablet Sig: One (1) Tablet PO BID (2 times a day)',
#  '26-166': '12. Lovenox 80 mg /0.8 mL Syringe Sig: One (1) Subcutaneous twice a day',
#  '27-0': 'He developed throbbing frontal occipital headache eyes and dry mouth and the headache was alleviated only slightly with ibuprofen',
#  '27-2': 'PAST MEDICAL HISTORY: HIV',
#  '27-3': 'He was in no previous HAART',
#  '27-4': 'Two weeks ago, CD4 count was 171, his viral load 200,000 and was started on Bactrim for Pneumocystis carinii prophylaxis',
#  '27-6': 'MEDICATIONS PRIOR TO ADMISSION: Bactrim , acyclovir',
#  '27-8': 'MCV is 85, sodium 136, potassium 3.4, chloride 102, HCO3 25, BUN 9, creatinine 0.9, glucose',
#  '27-11': 'Induced sputums were performed and the patient was started on intravenous Bactrim and prednisone for a possible PCP infection and levofloxacin for any community-acquired pneumonia',
#  '27-17': 'The patient was also feeling increasingly anxious and was given morphine , pantoprazole , zolpidem , and heparin',
#  '27-21': 'The patient was sedated through Fentanyl , lorazepam and also received nicotine',
#  '27-25': 'As Bactrim has been described to be associated with adult respiratory distress syndrome , Bactrim',
#  '27-28': 'The skin signs markedly improved and his 02 saturation on hospital day nine was now 98% on four liters of oxygen / nasal cannula',
#  '27-31': 'On day ten of his hospital stay, the patient developed withdrawal symptoms consisting of agitation , hallucinations and tachypnea , which could be attributed to the high doses of Fentanyl',
#  '27-35': 'He also still had hallucinations and an oral thrush could be observed and treated with Nystatin',
#  '27-37': 'On day 12 of his hospital stay, the patient was started on Dapsone for PCP prophylaxis , but the patient developed a rash on both arms and the back',
#  '27-40': 'As Dapsone is known to show a cross reactivity to Bactrim in [**10-20**]%, Dapsone',
#  '27-43': 'On day 14 of his hospital stay, all medications except prednisone and the nicotine patch',
#  '27-46': 'Blood cultures will have to be followed up with Dr. [**Last Name (STitle) **], with whom he has an appointment within two weeks and a Infectious Disease Consult for starting of HAART',
#  '27-47': 'His medications on discharge are Nystatin and nicotine patches',
#  '28-0': 'The patient is status post a bicycle accident in the summer of [**2166**] and has been taking ibuprofe n 400 mg q. 4-6 hours for approximately one month',
#  '28-4': 'MEDICATIONS ON ADMISSION: 1. Neurontin (patient self-discontinued secondary to sedative',
#  '28-6': '2. Ibuprofen 400 mg q. 4-6 hours p.r.n.',
#  '28-9': '3. Prozac 20 mg p.o. q.d. 4. Flonase',
#  '28-14': '5. Omega oils',
#  '28-15': 'ALLERGIES: Sulfa',
#  '28-16': "The patient's hematocrit reached a nadir of 13.9 on [**2168-4-18**] and required six units of packed red blood cells for resuscitation",
#  '28-19': 'Gastroenterology followed the patient during the course of admission and made several recommendations to decrease future risks of GI bleeding , including Protonix b.i.d. for at least two weeks and then continued q.d. thereafter, avoidance of non-steroidal anti-inflammatory drugs and Omega oils',
#  '28-26': 'He had a normal EKG. Pain resolved with treatment of upper GI bleed and with Ultram',
#  '28-28': '3. Back pain : The patient was initiated on a treatment plan with Ultram as an alternative to ibuprofen',
#  '28-31': 'He will be discharged with a prescription for Ultram',
#  '28-32': 'He will be discharged with a prescription for Ultram. Tylenol',
#  '28-33': 'Anemia secondary to blood loss status post six units of packed red blood cells',
#  '28-35': 'DISCHARGE MEDICATIONS: 1. Protonix 40 mg p.o. b.i.d.',
#  '28-39': '2. Tramadol 50 mg p.o. q. 4-6 hours p.r.n',
#  '28-43': '3. Prozac 20 mg p.o. q.d.',
#  '29-0': 'Admission Date: [**2107-11-12**] Discharge Date: [**2107-12-21**] Date of Birth: [**2045-12-2**] Sex: M Service: MEDICINE Allergies: Vancomycin',
#  '29-1': 'During hospital course on the floor, renal function continued to worsen and urine output was low even with furosemide',
#  '29-2': 'CPR initiated and initial rhythm asystole/very slow PEA, subsequently faster PEA',
#  '29-3': 'Received total 2 mg epinephrine , 2 amps bicarb , 1 mg atropine , insulin/D50 , IVFs',
#  '29-12': 'Mild pulmonary hypertension - Diabetes, type 2 , on insulin',
#  '29-14': 'Now s/p 7-day course of vanc / zosyn for aspiration',
#  '29-18': '# Stenotrophomonas PNA',
#  '29-19': 'On Bactrim x 14 day',
#  '29-21': 'Note that Bactrim',
#  '29-22': 'Intially diagnosed [**12-2**], but was inadquately treated as Bactrim',
#  '29-23': '# Pseudomonas UTI : Had a long course of Cefepime',
#  '29-25': '# Line infection : S/p Cefepime initially for UTI',
#  '29-28': 'Then Linezolid',
#  '29-29': 'According to ID, the Cefepime',
#  '29-30': 'He received a 14d course of Cefepime and 9d course of Linezolid',
#  '29-34': '# Labile blood pressures',
#  '29-35': 'He was given stress dose steroids',
#  '29-37': 'He was on pressors for hypotension',
#  '29-39': 'Ultimately this resolved and he became persistently hypertensive',
#  '29-40': 'He was started on a labetalol drip as well as PRN hydralazine',
#  '29-44': 'He has been transitioned from Labetalol drip to PO Labetalol on [**12-9**], then switched to Labetalol PRN',
#  '29-50': 'On [**12-14**], Labetalol',
#  '29-51': 'Continue atenolol at 50mg daily',
#  '29-54': 'Continue lisinopril 10mg daily',
#  '29-57': 'Receiveing pulse steroids with Prednisone 40mg daily x 5 days',
#  '29-62': 'Will resume chronic Prednisone 5mg PO daily for maintenance of transplanted kidney',
#  '29-67': '[**Month (only) 116**] need suppressive allopurinol in the future for his gout',
#  '29-69': '# DVT',
#  '29-70': 'He was on a heparin drip , being bridged with coumadin',
#  '29-73': 'However, all anticoagulation stopped when liver hematoma',
#  '29-74': 'Hematology was consulted regarding whether it is appropriate to resume anticoagulation given the risk of bleed, and recommended SC Heparin tid',
#  '29-77': 'The patient should not be anti-coagulated with agents other than SC Heparin',
#  '29-79': '?s syndrome from infection/sepsis, intra-abdominal bleed, narcotic',
#  '29-80': 'Continue Reglan 2.5mg TID standing for treatment of presumed diabetic gastroparesis',
#  '29-84': '# Liver Hematoma : As above, CT showed hematoma of liver while on heparin drip for IVC thombus',
#  '29-88': 'Received total of 3 unit pRBC after reversal of PTT with FFP',
#  '29-91': 'Ultimately was transitioned from fentanyl to methadone and then weaned on seroquel',
#  '29-94': 'Neuro recommended starting Keppra , with Keppra 500mg qday and an extra 250mg after HD',
#  '29-100': 'Continue prednisone 5mg PO daily for rejection as well as Renagel 800 tid , Sevelemer 800 tid',
#  '29-111': 'Follow up speech therapy in rehab s/p d/c Medications on Admission: - Amlodipine 10 mg [**Hospital1 **] - Calcitriol 0.25mcg QD - Cinacalcet 90 mg QD - Clonidine 0.1 mg [**Hospital1 **] - Lasix 120mg PO BID - Labetalol 600mg [**Hospital1 **] Lisinopril 10mg QHS - Minoxidil 10mg [**Hospital1 **] - Mycophenolate Mofetil 500mg [**Hospital1 **] - Prednisone 5mg QD Vardenafil 10mg PRN - Aspirin 81mg QD Insulin NPH & Regular Human Ten (10) units Subcutaneous qPM',
#  '29-147': 'Follow up speech therapy in rehab s/p d/c Medications on Admission: -Amlodipine 10 mg [**Hospital1 **] -Calcitriol 0.25mcg QD -Cinacalcet 90 mg QD -Clonidine 0.1 mg [**Hospital1 **] -Lasix 120mg PO BID -Labetalol 600mg [**Hospital1 **] Lisinopril 10mg QHS -Minoxidil 10mg [**Hospital1 **] -Mycophenolate Mofetil 500mg [**Hospital1 **] -Prednisone 5mg QD Vardenafil 10mg PRN -Aspirin 81mg QD Insulin NPH & Regular Human Ten (10) units Subcutaneous qPM. Insulin NPH & Regular Human Twenty (20) Units Subcutaneous qAM',
#  '29-151': 'Discharge Medications: 1. Heparin (Porcine) 5,000 unit/mL Solution Sig: 4000-[**Numeric Identifier 2249**] units Injection PRN (as needed) as needed for line flush',
#  '29-158': '2. Senna 8.6 mg Tablet Sig: One (1) Tablet PO BID (2 times a day) as needed for constipation',
#  '29-166': '3. Sucralfate 1 gram Tablet Sig: One (1) Tablet PO QID (4 times a day)',
#  '29-173': '4. Acetaminophen 160 mg/5 mL Solution Sig: 325-650 mg PO Q6H (every 6 hours) as needed for fever , pain',
#  '29-181': '5. Bisacodyl 5 mg Tablet, Delayed Release (E.C.) Sig: Two (2) Tablet, Delayed Release (E.C.) PO BID (2 times a day) as needed for constipation',
#  '29-189': '6. Cinacalcet 30 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '29-196': '7. Polyvinyl Alcohol-Povidone 1.4-0.6 % Dropperette Sig: [**1-7**] Drops Ophthalmic PRN (as needed) as needed for irritation',
#  ...}

# %%
entity_df = pd.DataFrame(tags_list, columns=['text_id','entity_id','start','end','concept','entity','sent_num']).set_index('entity_id')

# %%
entity_df
# Out:
#            text_id  start  end    concept                entity sent_num
# entity_id
# T107             0      4    5       Drug          Ca-gluconate      0-0
# T108             0      6    8   Strength              10 units      0-0
# T110             0      9   10       Drug               insulin      0-0
# T111             0     15   17   Strength                 15 mg      0-0
# T112             0     17   18      Route                    PO      0-0
# ...            ...    ...  ...        ...                   ...      ...
# T28            302     26   28   Strength                325 mg   302-14
# T29            302     28   30  Frequency            once daily   302-14
# T30            302     30   31       Drug              Darvocet   302-14
# T31            302     31   32  Frequency                 p.r.n   302-14
# T32            302      1    3     Reason  abdominal discomfort   302-28
#
# [50946 rows x 6 columns]

# %%
'''
This is to generate relations to a specific format for one of my model, a relation triplet is formated as 
"start_position_1st_entity, end_position_1st_entity, start_position_2nd_entity, end_position_2nd_entity,
relation_type, 1st_entity_type, 2nd_entity_type" Each relation is concatenated by all the relation triplets
within the sentence, seperated by '|'
'''

relations = []
sents = []
for i, an in enumerate(tqdm(anno)):
    text = an.get_text()
    relation = ''
    entity_curr = entity_df[entity_df['text_id']==i]#['sent_num']
    curr_sent = 0
    for k in an.relations.values():
        if k[0][0] not in entity_curr.index or k[1][0] not in entity_curr.index:
            continue
        e1, e2, rel = entity_curr.loc[k[0][0]], entity_curr.loc[k[1][0]], k[2]

        if e1['sent_num'] != e2['sent_num']:
            continue
        if curr_sent == 0:
            relation = ' '.join([str(e1['start']), str(e1['end']-1), str(e2['start']), str(e2['end']-1),
                                   '/'+rel+'/'+k[0][3]+'/'+k[1][3], '|'])
            curr_sent = e1['sent_num']
        elif e1['sent_num'] == curr_sent:           
            relation = ' '.join([relation, str(e1['start']), str(e1['end']-1), str(e2['start']), str(e2['end']-1),
                                   '/'+rel+'/'+k[0][3]+'/'+k[1][3], '|'])
        else:
            relations.append(relation[:-2])  
            sents.append(sents_dict[curr_sent])
            relation = ' '.join([str(e1['start']), str(e1['end']-1), str(e2['start']), str(e2['end']-1),
                                   '/'+rel+'/'+k[0][3]+'/'+k[1][3],'|'])
            curr_sent = e1['sent_num']
        if k[0][3] == 'Reason' and k[1][3]=='Drug' and rel == 'ADE-Drug':
            print(k)
# Out:
#   0%|          | 0/303 [00:00<?, ?it/s]
# (('T113', 9636, 9650, 'Reason', 'gastric ulcers'), ('T111', 9674, 9679, 'Drug', 'NSAID'), 'ADE-Drug')
# (('T179', 13587, 13603, 'Reason', 'low blood counts'), ('T177', 13552, 13562, 'Drug', 'vancomycin'), 'ADE-Drug')
# (('T179', 13587, 13603, 'Reason', 'low blood counts'), ('T121', 13566, 13574, 'Drug', 'cefepime'), 'ADE-Drug')
# (('T243', 34234, 34247, 'Reason', 'Hyperglycemia'), ('T241', 34321, 34329, 'Drug', 'steroids'), 'ADE-Drug')
# (('T118', 13358, 13383, 'Reason', 'red rash on arms and face'), ('T47', 13387, 13397, 'Drug', 'vancomycin'), 'ADE-Drug')
# (('T113', 6733, 6749, 'Reason', 'supratherapeutic'), ('T40', 6686, 6694, 'Drug', 'coumadin'), 'ADE-Drug')
# (('T59', 5277, 5283, 'Reason', 'rigors'), ('T57', 5263, 5267, 'Drug', 'IL-2'), 'ADE-Drug')
# (('T62', 5320, 5331, 'Reason', 'hypotension'), ('T57', 5263, 5267, 'Drug', 'IL-2'), 'ADE-Drug')
# (('T87', 8275, 8288, 'Reason', 'Hyperglycemia'), ('T85', 8314, 8322, 'Drug', 'steroids'), 'ADE-Drug')
# (('T111', 1378, 1385, 'Reason', 'itching'), ('T108', 1367, 1370, 'Drug', 'FFP'), 'ADE-Drug')
# (('T119', 5163, 5171, 'Reason', 'GI bleed'), ('T7', 5257, 5265, 'Drug', 'coumadin'), 'ADE-Drug')
# (('T119', 5163, 5171, 'Reason', 'GI bleed'), ('T26', 5287, 5294, 'Drug', 'aspirin'), 'ADE-Drug')
# (('T183', 17789, 17811, 'Reason', 'Junctional Bradycardia'), ('T184', 17833, 17846, 'Drug', 'beta-blockers'), 'ADE-Drug')
# (('T59', 3454, 3467, 'Reason', 'hyperglycemia'), ('T61', 3481, 3489, 'Drug', 'steroids'), 'ADE-Drug')

# %%
relations[154]
# Out:
# '6 7 4 5 /Strength-Drug/Strength/Drug | 14 14 4 5 /Form-Drug/Form/Drug | 15 15 4 5 /Route-Drug/Route/Drug'

# %%
sents[154]
# Out:
# 'Disp:*10 Capsule(s)* Refills:*0* 8. famotidin e 20 mg Tablet [**Month/Year (2) **]: One (1) Tablet PO BID (2 times a day) for 1 days'
