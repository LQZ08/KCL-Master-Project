# %%
import os
from tqdm.notebook import tqdm
import glob
import numpy as np
import pandas as pd
import random
from collections import defaultdict
from nltk.tokenize import sent_tokenize, word_tokenize

# %% [markdown]
# # Read files and annotations

# %%
#This class is provided by i2b2 challenge. I use its functions to get annotations and text

class RecordTrack2(object):
    """Record for Track 2 class."""

    def __init__(self, file_path):
        """Initialize."""
        self.path = os.path.abspath(file_path)
        self.basename = os.path.basename(self.path)
        self.annotations = self._get_annotations()
        # self.text = self._get_text()

    @property
    def tags(self):
        return self.annotations['tags']

    @property
    def relations(self):
        return self.annotations['relations']

    def _get_annotations(self):
        """Return a dictionary with all the annotations in the .ann file."""
        annotations = defaultdict(dict)
        with open(self.path) as annotation_file:
            lines = annotation_file.readlines()
            for line_num, line in enumerate(lines):
                if line.strip().startswith('T'):
                    try:
                        tag_id, tag_m, tag_text = line.strip().split('\t')
                    except ValueError:
                        print(self.path, line)
                    if len(tag_m.split(' ')) == 3:
                        tag_type, tag_start, tag_end = tag_m.split(' ')
                    elif len(tag_m.split(' ')) == 4:
                        tag_type, tag_start, _, tag_end = tag_m.split(' ')
                    elif len(tag_m.split(' ')) == 5:
                        tag_type, tag_start, _, _, tag_end = tag_m.split(' ')
                    else:
                        print(self.path)
                        print(line)
                    tag_start, tag_end = int(tag_start), int(tag_end)
                    annotations['tags'][tag_id] = (tag_id, tag_start ,tag_end, tag_type, tag_text)
            for line_num, line in enumerate(lines):
                if line.strip().startswith('R'):
                    rel_id, rel_m = line.strip().split('\t')
                    rel_type, rel_arg1, rel_arg2 = rel_m.split(' ')
                    rel_arg1 = rel_arg1.split(':')[1]
                    rel_arg2 = rel_arg2.split(':')[1]
                    arg1 = annotations['tags'][rel_arg1]
                    arg2 = annotations['tags'][rel_arg2]
                    annotations['relations'][rel_id] = (arg1,arg2, rel_type)
        return annotations

    def get_text(self):
        """Return the text in the corresponding txt file."""
        path = self.path.replace('.ann', '.txt')
        with open(path) as text_file:
            text = text_file.read()
        return text

# %%
#reading data and create a list of RecordTrack2 class for each file
folder1 = 'training_20180910/'
anno = []
files1 = set([os.path.basename(f) for f in glob.glob(
    os.path.join(folder1, '*.ann'))])
for file in files1:
    anno.append(RecordTrack2(os.path.join(folder1, file)))

# %% [markdown]
# # Generate entities within sentence
#
# Find the offset of each entity within that sentence.
#
# The offset provided by i2b2 is aginst the whole file.
#
# In this section, we will locate the entity, tokenise sentense, and remove extra spaces
#
# The offset I generated in this section is word offset (created by len(text.split()), feel free to change to character offset if needed.

# %%
#function to generate the first entity in a sentence
def first_entity(text, start, end, entity):
        text_before = sent_tokenize(text[:start]) #all the text befere the start of the entity
        sent_num = len(text_before)
        word_before = text_before[-1].split() #words before entity in the current sentence 
        word_start = len(word_before) #start position
        word_end = word_start+len(entity.split()) #end position
        sent_after = sent_tokenize(text[end:])[0] #the left of current sentence
        sent_piece = ' '.join(word_before + entity.split()) #current sentence until the end of first entity, extra spaces removed by .split()
        return word_start, word_end, sent_after, sent_piece

# %%
#function to generate non-first entity in a sentence, same logic sa first_entity function
def entity_within_sent(text, word_end_before, end_before, start, end, entity):
    word_between = text[end_before:start].split()
    word_start = word_end_before + len(word_between)
    word_end = word_start+len(entity.split())
    sent_after = sent_tokenize(text[end:])[0]
    #print(sent_after)
    sent_piece = ' '.join(word_between + entity.split())
    return word_start, word_end, sent_after, sent_piece

# %%
tags_list = []
sents_dict = {}
for i, an in enumerate(tqdm(anno)):
    text = an.get_text()
    tags = pd.DataFrame(an.tags.values()).sort_values(1).values
    #skip used to mark how many entities we have processed within the previous sentence
    skip = 0
    for j, (en_id, start, end, concept, entity) in enumerate(tags):
        #we skip the entities we have processed from last sentence, it will bring us to the first entity in current sentence
        if skip>0:
            skip -= 1
            continue
        #remove entities that across sentences
        if len(sent_tokenize(text[start:end]))>1:
            continue
        word_start, word_end, sent_after, sent_piece = first_entity(text, start, end, entity)
        #'-'.join([str(i),str(j)]) is an unique idenfitier for each sentence in the dataset, 
        #i identify the document and j identify the sentence within the document
        tags_list.append([i, en_id, word_start, word_end, concept, entity, '-'.join([str(i),str(j)])])
        while j+skip+1<len(tags) and end+len(sent_after)>= tags[j+skip+1][1]:
            anno_curr = tags[j+skip+1]
            word_end_before = word_end
            end_before = end
            sent_piece_before = sent_piece
            en_id = anno_curr[0]
            start = anno_curr[1]
            end = anno_curr[2]
            concept = anno_curr[3]
            entity = anno_curr[4]
            word_start, word_end, sent_after, sent_piece = entity_within_sent(text, word_end_before, end_before, start, end, entity)
            sent_piece = ' '. join([sent_piece_before, sent_piece])
            tags_list.append([i, en_id, word_start, word_end, concept, entity, '-'.join([str(i),str(j)])])
            skip += 1
        sents_dict['-'.join([str(i),str(j)])] = sent_piece
# Out:
#   0%|          | 0/303 [00:00<?, ?it/s]

# %%
tags_list
# Out:
# [[0, 'T1', 15, 16, 'Drug', 'Zosyn', '0-0'],
#  [0, 'T5', 17, 18, 'Drug', 'Quinolones', '0-0'],
#  [0, 'T6', 19, 20, 'Drug', 'Ceftriaxone', '0-0'],
#  [0, 'T16', 21, 22, 'Drug', 'Flagyl', '0-0'],
#  [0, 'T19', 23, 24, 'Drug', 'Keppra', '0-0'],
#  [0, 'T20', 25, 26, 'Drug', 'Lisinopril', '0-0'],
#  [0, 'T23', 27, 28, 'Drug', 'Naprosyn', '0-0'],
#  [0, 'T24', 52, 53, 'Reason', 'HTN', '0-0'],
#  [0, 'T25', 54, 55, 'Drug', 'ACEI', '0-0'],
#  [0, 'T213', 14, 15, 'Drug', 'Lisinopril', '0-9'],
#  [0, 'T214', 15, 17, 'Strength', '20 mg', '0-9'],
#  [0, 'T271', 18, 19, 'Reason', 'anxiety', '0-11'],
#  [0, 'T2', 20, 21, 'Reason', 'dyscomfort', '0-11'],
#  [0, 'T3', 3, 5, 'Strength', '5 mg', '0-13'],
#  [0, 'T4', 6, 7, 'Drug', 'midazolam', '0-13'],
#  [0, 'T7', 2, 4, 'Strength', '125 mg', '0-15'],
#  [0, 'T11', 5, 6, 'Route', 'IV', '0-15'],
#  [0, 'T9', 6, 7, 'Drug', 'solumedrol', '0-15'],
#  [0, 'T10', 8, 10, 'Strength', '20 mg', '0-15'],
#  [0, 'T8', 11, 12, 'Route', 'IV', '0-15'],
#  [0, 'T12', 12, 13, 'Drug', 'famotidine', '0-15'],
#  [0, 'T13', 14, 16, 'Strength', '25 mg', '0-15'],
#  [0, 'T14', 17, 18, 'Route', 'IV', '0-15'],
#  [0, 'T15', 18, 19, 'Drug', 'diphenydramine', '0-15'],
#  [0, 'T17', 20, 21, 'Drug', 'epipen', '0-15'],
#  [0, 'T18', 22, 23, 'Dosage', '2', '0-15'],
#  [0, 'T21', 22, 23, 'Drug', 'epineprhine', '0-26'],
#  [0, 'T22', 23, 24, 'Route', 'IM', '0-26'],
#  [0, 'T26', 5, 6, 'Drug', 'ACEI', '0-28'],
#  [0, 'T27', 15, 16, 'Drug', 'Naprosyn', '0-29'],
#  [0, 'T28', 8, 9, 'Drug', 'naproxen', '0-30'],
#  [0, 'T29', 10, 11, 'ADE', 'angioedema', '0-30'],
#  [0, 'T30', 4, 5, 'Drug', 'steroids', '0-32'],
#  [0, 'T31', 6, 7, 'Drug', 'antihistamines', '0-32'],
#  [0, 'T32', 1, 2, 'Drug', 'ACE-i', '0-34'],
#  [0, 'T33', 7, 8, 'Drug', 'Naproxen', '0-34'],
#  [0, 'T34', 9, 10, 'Drug', 'NSAIDs', '0-34'],
#  [0, 'T35', 1, 2, 'Reason', 'Asthma', '0-37'],
#  [0, 'T36', 4, 5, 'Drug', 'Albuterol', '0-38'],
#  [0, 'T37', 10, 11, 'Drug', 'Montelukast', '0-38'],
#  [0, 'T38', 1, 2, 'Reason', 'HTN', '0-40'],
#  [0, 'T39', 5, 6, 'Drug', 'ACEI', '0-40'],
#  [0, 'T40', 7, 8, 'Drug', 'beta-blocker', '0-40'],
#  [0, 'T41', 1, 2, 'Drug', 'ace-inhibitor', '0-43'],
#  [0, 'T42', 6, 7, 'Drug', 'beta-blocker', '0-43'],
#  [0, 'T43', 1, 2, 'Reason', 'seizure', '0-45'],
#  [0, 'T44', 7, 8, 'Drug', 'Phenytoin', '0-45'],
#  [0, 'T45', 8, 9, 'Route', 'IV', '0-45'],
#  [0, 'T46', 14, 15, 'Route', 'PO', '0-45'],
#  [0, 'T47', 7, 8, 'Drug', 'Quetiapine', '0-49'],
#  [0, 'T48', 8, 10, 'Strength', '25 mg', '0-49'],
#  [0, 'T49', 10, 11, 'Route', 'PO', '0-49'],
#  [0, 'T50', 11, 12, 'Frequency', 'QHS', '0-49'],
#  [0, 'T51', 12, 13, 'Drug', 'Citalopram', '0-49'],
#  [0, 'T52', 13, 15, 'Strength', '20 mg', '0-49'],
#  [0, 'T53', 15, 16, 'Route', 'PO', '0-49'],
#  [0, 'T54', 16, 17, 'Frequency', 'Daily', '0-49'],
#  [0, 'T55', 17, 18, 'Drug', 'Colace', '0-49'],
#  [0, 'T56', 18, 20, 'Strength', '100 mg', '0-49'],
#  [0, 'T57', 20, 21, 'Route', 'PO', '0-49'],
#  [0, 'T58', 21, 23, 'Frequency', 'B ID', '0-49'],
#  [0, 'T59', 23, 24, 'Drug', 'Atenolol', '0-49'],
#  [0, 'T60', 24, 26, 'Strength', '25 mg', '0-49'],
#  [0, 'T61', 26, 27, 'Route', 'PO', '0-49'],
#  [0, 'T62', 27, 28, 'Frequency', 'Daily', '0-49'],
#  [0, 'T63', 28, 29, 'Drug', 'Omeprazole', '0-49'],
#  [0, 'T64', 29, 31, 'Strength', '20 mg', '0-49'],
#  [0, 'T65', 31, 32, 'Route', 'PO', '0-49'],
#  [0, 'T66', 32, 33, 'Frequency', 'Daily', '0-49'],
#  [0, 'T67', 33, 34, 'Drug', 'Phenytoin', '0-49'],
#  [0, 'T68', 34, 36, 'Strength', '500 mg', '0-49'],
#  [0, 'T69', 36, 37, 'Route', 'PO', '0-49'],
#  [0, 'T70', 37, 38, 'Frequency', 'QHS', '0-49'],
#  [0, 'T71', 38, 39, 'Drug', 'Lisinopril', '0-49'],
#  [0, 'T72', 39, 41, 'Strength', '20 mg', '0-49'],
#  [0, 'T73', 41, 42, 'Route', 'PO', '0-49'],
#  [0, 'T74', 42, 43, 'Frequency', 'Daily', '0-49'],
#  [0, 'T75', 43, 44, 'Drug', 'Multivitamin', '0-49'],
#  [0, 'T76', 44, 45, 'Route', 'PO', '0-49'],
#  [0, 'T77', 45, 46, 'Frequency', 'Daily', '0-49'],
#  [0, 'T78', 46, 47, 'Drug', 'Motelukast', '0-49'],
#  [0, 'T79', 47, 49, 'Strength', '10 mg', '0-49'],
#  [0, 'T80', 49, 50, 'Route', 'PO', '0-49'],
#  [0, 'T81', 50, 51, 'Frequency', 'Daily', '0-49'],
#  [0, 'T82', 51, 52, 'Drug', 'Simethicone', '0-49'],
#  [0, 'T83', 52, 54, 'Strength', '80 mg', '0-49'],
#  [0, 'T84', 54, 55, 'Route', 'PO', '0-49'],
#  [0, 'T85', 55, 57, 'Frequency', 'Daily PRN', '0-49'],
#  [0, 'T86', 57, 58, 'Reason', 'cramps', '0-49'],
#  [0, 'T87', 58, 59, 'Drug', 'Thiamine', '0-49'],
#  [0, 'T88', 59, 61, 'Strength', '100 mg', '0-49'],
#  [0, 'T89', 61, 62, 'Route', 'PO', '0-49'],
#  [0, 'T90', 62, 63, 'Frequency', 'Daily', '0-49'],
#  [0, 'T91', 63, 64, 'Drug', 'Bisacodyl', '0-49'],
#  [0, 'T92', 64, 66, 'Strength', '5 mg', '0-49'],
#  [0, 'T93', 66, 67, 'Route', 'PO', '0-49'],
#  [0, 'T94', 67, 68, 'Frequency', 'PRN', '0-49'],
#  [0, 'T95', 68, 69, 'Reason', 'Constipation', '0-49'],
#  [0, 'T96', 69, 70, 'Drug', 'Senna', '0-49'],
#  [0, 'T97', 70, 72, 'Strength', '8.6 mg', '0-49'],
#  [0, 'T98', 72, 73, 'Route', 'PO', '0-49'],
#  [0, 'T99', 73, 74, 'Frequency', 'BID', '0-49'],
#  [0, 'T100', 74, 75, 'Drug', 'Albuterol', '0-49'],
#  [0, 'T101', 75, 77, 'Strength', '90 mcg', '0-49'],
#  [0, 'T102', 77, 78, 'Dosage', 'PRN', '0-49'],
#  [0, 'T103', 78, 80, 'Frequency', 'q4-6 hrs', '0-49'],
#  [0, 'T272', 80, 81, 'Reason', 'SOB', '0-49'],
#  [0, 'T104', 82, 83, 'Reason', 'Wheezing', '0-49'],
#  [0, 'T105', 1, 3, 'Drug', 'Piperacillin Sodium/Tazobactam', '0-108'],
#  [0, 'T106', 5, 6, 'Drug', 'Quinolones', '0-108'],
#  [0, 'T107', 6, 7, 'Drug', 'Ceftriaxone', '0-108'],
#  [0, 'T108', 7, 8, 'Drug', 'Metronidazole', '0-108'],
#  [0, 'T109', 8, 9, 'Drug', 'Levetiracetam', '0-108'],
#  [0, 'T110', 11, 12, 'Drug', 'Quetiapine', '0-113'],
#  [0, 'T111', 12, 14, 'Strength', '25 mg', '0-113'],
#  [0, 'T112', 14, 15, 'Form', 'Tablet', '0-113'],
#  [0, 'T113', 16, 18, 'Dosage', 'One (1)', '0-113'],
#  [0, 'T114', 18, 19, 'Form', 'Tablet', '0-113'],
#  [0, 'T115', 19, 20, 'Route', 'PO', '0-113'],
#  [0, 'T116', 20, 21, 'Frequency', 'QHS', '0-113'],
#  [0, 'T117', 1, 2, 'Drug', 'Citalopram', '0-120'],
#  [0, 'T118', 2, 4, 'Strength', '20 mg', '0-120'],
#  [0, 'T119', 4, 5, 'Form', 'Tablet', '0-120'],
#  [0, 'T120', 6, 8, 'Dosage', 'One (1)', '0-120'],
#  [0, 'T121', 8, 9, 'Form', 'Tablet', '0-120'],
#  [0, 'T122', 9, 10, 'Route', 'PO', '0-120'],
#  [0, 'T123', 10, 11, 'Frequency', 'DAILY', '0-120'],
#  [0, 'T124', 1, 2, 'Drug', 'Colace', '0-127'],
#  [0, 'T125', 2, 4, 'Strength', '100 mg', '0-127'],
#  [0, 'T126', 4, 5, 'Form', 'Capsule', '0-127'],
#  [0, 'T127', 6, 8, 'Dosage', 'One (1)', '0-127'],
#  [0, 'T128', 8, 9, 'Form', 'Capsule', '0-127'],
#  [0, 'T129', 9, 10, 'Route', 'PO', '0-127'],
#  [0, 'T130', 10, 13, 'Frequency', 'twice a day', '0-127'],
#  [0, 'T131', 1, 2, 'Drug', 'Omeprazole', '0-134'],
#  [0, 'T132', 2, 4, 'Strength', '20 mg', '0-134'],
#  [0, 'T133', 4, 7, 'Form', 'Capsule, Delayed Release(E.C.)', '0-134'],
#  [0, 'T134', 8, 10, 'Dosage', 'One (1)', '0-134'],
#  [0, 'T135', 10, 13, 'Form', 'Capsule, Delayed Release(E.C.)', '0-134'],
#  [0, 'T136', 13, 14, 'Route', 'PO', '0-134'],
#  [0, 'T137', 14, 17, 'Frequency', 'once a day', '0-134'],
#  [0, 'T138', 1, 4, 'Drug', 'Phenytoin Sodium Extended', '0-141'],
#  [0, 'T139', 4, 6, 'Strength', '100 mg', '0-141'],
#  [0, 'T140', 6, 7, 'Form', 'Capsule', '0-141'],
#  [0, 'T141', 8, 10, 'Dosage', 'Five (5)', '0-141'],
#  [0, 'T142', 10, 11, 'Form', 'Capsule', '0-141'],
#  [0, 'T143', 11, 12, 'Route', 'PO', '0-141'],
#  [0, 'T144', 12, 13, 'Frequency', 'QHS', '0-141'],
#  [0, 'T145', 1, 2, 'Drug', 'Multivitamin', '0-148'],
#  [0, 'T146', 2, 3, 'Form', 'Capsule', '0-148'],
#  [0, 'T147', 4, 6, 'Dosage', 'One (1)', '0-148'],
#  [0, 'T148', 6, 7, 'Form', 'Capsule', '0-148'],
#  [0, 'T149', 7, 8, 'Route', 'PO', '0-148'],
#  [0, 'T150', 8, 11, 'Frequency', 'once a day', '0-148'],
#  [0, 'T151', 1, 2, 'Drug', 'Montelukast', '0-154'],
#  [0, 'T152', 2, 4, 'Strength', '10 mg', '0-154'],
#  [0, 'T153', 4, 5, 'Form', 'Tablet', '0-154'],
#  [0, 'T154', 6, 8, 'Dosage', 'One (1)', '0-154'],
#  [0, 'T155', 8, 9, 'Form', 'Tablet', '0-154'],
#  [0, 'T156', 9, 10, 'Route', 'PO', '0-154'],
#  [0, 'T157', 10, 11, 'Frequency', 'DAILY', '0-154'],
#  [0, 'T158', 1, 2, 'Drug', 'Simethicone', '0-161'],
#  [0, 'T159', 2, 4, 'Strength', '80 mg', '0-161'],
#  [0, 'T160', 4, 6, 'Form', 'Tablet, Chewable', '0-161'],
#  [0, 'T161', 7, 9, 'Dosage', 'One (1)', '0-161'],
#  [0, 'T162', 9, 11, 'Form', 'Tablet, Chewable', '0-161'],
#  [0, 'T163', 11, 12, 'Route', 'PO', '0-161'],
#  [0, 'T164', 12, 17, 'Frequency', 'once a day as needed', '0-161'],
#  [0, 'T165', 18, 20, 'Reason', 'abdominal cramps', '0-161'],
#  [0, 'T166', 1, 3, 'Drug', 'Thiamine HCl', '0-169'],
#  [0, 'T167', 3, 5, 'Strength', '100 mg', '0-169'],
#  [0, 'T168', 5, 6, 'Form', 'Tablet', '0-169'],
#  [0, 'T169', 7, 9, 'Dosage', 'One (1)', '0-169'],
#  [0, 'T170', 9, 10, 'Form', 'Tablet', '0-169'],
#  [0, 'T171', 10, 11, 'Route', 'PO', '0-169'],
#  [0, 'T172', 11, 14, 'Frequency', 'once a day', '0-169'],
#  [0, 'T173', 1, 2, 'Drug', 'Senna', '0-176'],
#  [0, 'T174', 2, 4, 'Strength', '8.6 mg', '0-176'],
#  [0, 'T175', 4, 5, 'Form', 'Capsule', '0-176'],
#  [0, 'T176', 6, 8, 'Dosage', 'One (1)', '0-176'],
#  [0, 'T177', 8, 9, 'Form', 'Capsule', '0-176'],
#  [0, 'T178', 9, 10, 'Route', 'PO', '0-176'],
#  [0, 'T179', 10, 15, 'Frequency', 'twice a day as needed', '0-176'],
#  [0, 'T180', 16, 17, 'Reason', 'constipation', '0-176'],
#  [0, 'T181', 1, 2, 'Drug', 'Bisacodyl', '0-184'],
#  [0, 'T182', 2, 4, 'Strength', '5 mg', '0-184'],
#  [0, 'T183', 4, 5, 'Form', 'Tablet', '0-184'],
#  [0, 'T184', 6, 8, 'Dosage', 'One (1)', '0-184'],
#  [0, 'T185', 8, 9, 'Form', 'Tablet', '0-184'],
#  [0, 'T186', 9, 10, 'Route', 'PO', '0-184'],
#  [0, 'T187', 10, 15, 'Frequency', 'once a day as needed', '0-184'],
#  [0, 'T188', 16, 17, 'Reason', 'constipation', '0-184'],
#  [0, 'T189', 1, 2, 'Drug', 'Oxycodone', '0-192'],
#  [0, 'T190', 2, 4, 'Strength', '5 mg', '0-192'],
#  [0, 'T191', 4, 5, 'Form', 'Tablet', '0-192'],
#  [0, 'T192', 6, 8, 'Dosage', 'One (1)', '0-192'],
#  [0, 'T193', 8, 9, 'Form', 'Tablet', '0-192'],
#  [0, 'T194', 9, 10, 'Route', 'PO', '0-192'],
#  [0, 'T195', 10, 16, 'Frequency', 'Q6H (every 6 hours) as needed', '0-192'],
#  [0, 'T196', 17, 18, 'Reason', 'pain', '0-192'],
#  [0, 'T197', 4, 5, 'Drug', 'Prednisone', '0-200'],
#  [0, 'T198', 5, 7, 'Strength', '20 mg', '0-200'],
#  [0, 'T199', 7, 8, 'Form', 'Tablet', '0-200'],
#  [0, 'T200', 9, 11, 'Dosage', 'Two (2)', '0-200'],
#  [0, 'T201', 11, 12, 'Form', 'Tablet', '0-200'],
#  [0, 'T202', 12, 13, 'Route', 'PO', '0-200'],
#  [0, 'T203', 13, 16, 'Frequency', 'once a day', '0-200'],
#  [0, 'T204', 16, 19, 'Duration', 'for 3 days', '0-200'],
#  [0, 'T205', 4, 5, 'Drug', 'Tylenol', '0-208'],
#  [0, 'T206', 5, 7, 'Strength', '325 mg', '0-208'],
#  [0, 'T207', 7, 8, 'Form', 'Tablet', '0-208'],
#  [0, 'T208', 9, 10, 'Dosage', '1-2', '0-208'],
#  [0, 'T209', 10, 11, 'Form', 'Tablets', '0-208'],
#  [0, 'T210', 11, 12, 'Route', 'PO', '0-208'],
#  [0, 'T211', 12, 17, 'Frequency', 'every 4-6 hours as needed', '0-208'],
#  [0, 'T212', 18, 19, 'Reason', 'pain', '0-208'],
#  [0, 'T215', 6, 7, 'ADE', 'angioedema', '0-216'],
#  [0, 'T216', 7, 8, 'Drug', 'Lisinopril', '0-217'],
#  [0, 'T217', 10, 11, 'Drug', 'Naprosyn', '0-217'],
#  [0, 'T218', 5, 6, 'Drug', 'NSAIDS', '0-219'],
#  [0, 'T219', 7, 8, 'Drug', 'Motrin', '0-219'],
#  [0, 'T220', 9, 10, 'Drug', 'Ibuprofen', '0-219'],
#  [0, 'T221', 11, 12, 'Drug', 'Advil', '0-219'],
#  [0, 'T222', 4, 5, 'Drug', 'Quetiapine', '0-223'],
#  [0, 'T223', 5, 7, 'Strength', '25 mg', '0-223'],
#  [0, 'T224', 7, 9, 'Frequency', 'at night', '0-223'],
#  [0, 'T225', 9, 10, 'Drug', 'Citalopram', '0-223'],
#  [0, 'T226', 10, 12, 'Strength', '20 mg', '0-223'],
#  [0, 'T227', 12, 13, 'Frequency', 'daily', '0-223'],
#  [0, 'T228', 13, 14, 'Drug', 'Colace', '0-223'],
#  [0, 'T229', 14, 16, 'Strength', '100 mg', '0-223'],
#  [0, 'T230', 16, 19, 'Frequency', 'twice a day', '0-223'],
#  [0, 'T231', 19, 20, 'Drug', 'Omeprazole', '0-223'],
#  [0, 'T232', 20, 22, 'Strength', '20 mg', '0-223'],
#  [0, 'T233', 22, 23, 'Frequency', 'Daily', '0-223'],
#  [0, 'T234', 23, 24, 'Drug', 'Phenytoin', '0-223'],
#  [0, 'T235', 24, 26, 'Strength', '500 mg', '0-223'],
#  [0, 'T236', 26, 28, 'Frequency', 'at night', '0-223'],
#  [0, 'T237', 28, 29, 'Drug', 'Multivitamin', '0-223'],
#  [0, 'T238', 29, 30, 'Frequency', 'daily', '0-223'],
#  [0, 'T239', 30, 31, 'Drug', 'Motelukast', '0-223'],
#  [0, 'T240', 31, 33, 'Strength', '10 mg', '0-223'],
#  [0, 'T241', 33, 34, 'Frequency', 'daily', '0-223'],
#  [0, 'T242', 34, 35, 'Drug', 'Simethicone', '0-223'],
#  [0, 'T243', 35, 37, 'Strength', '80 mg', '0-223'],
#  [0, 'T244', 37, 40, 'Frequency', 'daily as needed', '0-223'],
#  [0, 'T245', 41, 42, 'Reason', 'cramps', '0-223'],
#  [0, 'T246', 42, 43, 'Drug', 'Thiamine', '0-223'],
#  [0, 'T247', 43, 45, 'Strength', '100 mg', '0-223'],
#  [0, 'T248', 45, 46, 'Frequency', 'daily', '0-223'],
#  [0, 'T249', 46, 47, 'Drug', 'Bisacodyl', '0-223'],
#  [0, 'T250', 47, 49, 'Strength', '5 mg', '0-223'],
#  [0, 'T251', 52, 53, 'Reason', 'constipation', '0-223'],
#  [0, 'T252', 53, 54, 'Drug', 'Senna', '0-223'],
#  [0, 'T253', 54, 56, 'Strength', '8.6 mg', '0-223'],
#  [0, 'T254', 56, 59, 'Frequency', 'twice a day', '0-223'],
#  [0, 'T255', 59, 60, 'Drug', 'Albuterol', '0-223'],
#  [0, 'T256', 60, 62, 'Strength', '90 mcg', '0-223'],
#  [0, 'T257', 62, 67, 'Frequency', 'every 4-6 hours as needed', '0-223'],
#  [0, 'T258', 68, 69, 'Reason', 'wheezing', '0-223'],
#  [0, 'T259', 73, 74, 'Drug', 'Lisinopril', '0-223'],
#  [0, 'T260', 74, 75, 'Drug', 'Atenolol', '0-223'],
#  [0, 'T261', 79, 80, 'Drug', 'Prednisone', '0-223'],
#  [0, 'T262', 80, 81, 'Strength', '40mg', '0-223'],
#  [0, 'T263', 81, 82, 'Frequency', 'daily', '0-223'],
#  [0, 'T264', 82, 87, 'Duration', 'for the next 3 days', '0-223'],
#  [0, 'T265', 87, 88, 'Drug', 'Tylenol', '0-266'],
#  [0, 'T266', 92, 93, 'Reason', 'pain', '0-266'],
#  [0, 'T267', 6, 7, 'Drug', 'Oxycodone', '0-268'],
#  [0, 'T268', 7, 8, 'Strength', '5mg', '0-268'],
#  [0, 'T269', 8, 13, 'Frequency', 'every 6 hours as needed', '0-268'],
#  [0, 'T270', 14, 15, 'Reason', 'pain', '0-268'],
#  [1, 'T181', 15, 16, 'Drug', 'Aspirin', '1-0'],
#  [1, 'T182', 17, 18, 'Drug', 'NSAIDS', '1-0'],
#  [1, 'T289', 39, 40, 'Drug', 'Aspirin', '1-0'],
#  [1, 'T292', 87, 88, 'Drug', 'anticoagulation', '1-0'],
#  [1, 'T293', 11, 12, 'Drug', 'ASA', '1-4'],
#  [1, 'T13', 14, 15, 'Drug', 'O2', '1-5'],
#  [1, 'T14', 16, 17, 'Route', 'NC', '1-5'],
#  [1, 'T91', 3, 5, 'Dosage', '3 units', '1-7'],
#  [1, 'T102', 6, 7, 'Drug', 'pRBC', '1-7'],
#  [1, 'T279', 6, 7, 'Reason', 'pneumonia', '1-9'],
#  [1, 'T280', 19, 20, 'Drug', 'prednisone', '1-9'],
#  [1, 'T281', 4, 5, 'Drug', 'moxifloxacin', '1-11'],
#  [1, 'T282', 5, 7, 'Strength', '400 mg', '1-11'],
#  [1, 'T283', 7, 8, 'Route', 'PO', '1-11'],
#  [1, 'T284', 8, 9, 'Frequency', 'qD', '1-11'],
#  [1, 'T285', 11, 12, 'Duration', '10-day', '1-11'],
#  [1, 'T286', 3, 4, 'Drug', 'ASA', '1-16'],
#  [1, 'T287', 7, 11, 'ADE', 'redness on his face', '1-16'],
#  [1, 'T288', 13, 14, 'ADE', 'rash', '1-16'],
#  [1, 'T290', 24, 28, 'Reason', 'prior history of PE', '1-19'],
#  [1, 'T291', 34, 35, 'Drug', 'Coumadin', '1-19'],
#  [1, 'T294', 14, 15, 'Drug', 'aspirin', '1-21'],
#  [1, 'T295', 19, 20, 'Drug', 'aspirin', '1-21'],
#  [1, 'T296', 4, 5, 'Drug', 'aspirin', '1-23'],
#  [1, 'T297', 4, 5, 'Drug', 'Atorvastatin', '1-24'],
#  [1, 'T298', 5, 7, 'Strength', '80 mg', '1-24'],
#  [1, 'T299', 7, 8, 'Frequency', 'qhs', '1-24'],
#  [1, 'T300', 9, 10, 'Drug', 'Carvedilol', '1-24'],
#  [1, 'T301', 10, 12, 'Strength', '6.25 mg', '1-24'],
#  [1, 'T302', 12, 13, 'Route', 'PO', '1-24'],
#  [1, 'T303', 13, 14, 'Frequency', 'BID', '1-24'],
#  [1, 'T304', 15, 16, 'Drug', 'ASA', '1-24'],
#  [1, 'T305', 16, 18, 'Strength', '325 mg', '1-24'],
#  [1, 'T306', 18, 19, 'Route', 'PO', '1-24'],
#  [1, 'T307', 19, 20, 'Frequency', 'qday', '1-24'],
#  [1, 'T308', 21, 22, 'Drug', 'Captopril', '1-24'],
#  [1, 'T309', 22, 24, 'Strength', '12.5 mg', '1-24'],
#  [1, 'T310', 24, 25, 'Frequency', 'TID', '1-24'],
#  [1, 'T311', 9, 10, 'Drug', 'captopril', '1-38'],
#  [1, 'T312', 13, 14, 'Drug', 'lisinopril', '1-38'],
#  [1, 'T1', 5, 6, 'Drug', 'Captopril', '1-40'],
#  [1, 'T2', 6, 8, 'Strength', '12.5 mg', '1-40'],
#  [1, 'T3', 8, 9, 'Route', 'PO', '1-40'],
#  [1, 'T4', 9, 10, 'Frequency', 'TID', '1-40'],
#  [1, 'T5', 11, 12, 'Drug', 'Carvedilol', '1-40'],
#  [1, 'T6', 12, 14, 'Strength', '6.25 mg', '1-40'],
#  [1, 'T7', 14, 15, 'Route', 'PO', '1-40'],
#  [1, 'T8', 15, 16, 'Frequency', 'BID', '1-40'],
#  [1, 'T9', 8, 9, 'Drug', 'captopril', '1-48'],
#  [1, 'T10', 12, 13, 'Drug', 'lisinopril', '1-48'],
#  [1, 'T11', 4, 5, 'Drug', 'spironolactone', '1-50'],
#  [1, 'T12', 7, 8, 'ADE', 'hyperkalemia', '1-50'],
#  [1, 'T15', 1, 2, 'Drug', 'heparin', '1-52'],
#  [1, 'T16', 2, 3, 'Route', 'gtt', '1-52'],
#  [1, 'T17', 2, 4, 'Duration', '10 days', '1-54'],
#  [1, 'T18', 6, 7, 'Drug', 'enoxaparin', '1-54'],
#  [1, 'T19', 7, 8, 'Route', 'injections', '1-54'],
#  [1, 'T20', 12, 13, 'Drug', 'coumadin', '1-54'],
#  [1, 'T21', 15, 16, 'Reason', 'PE', '1-54'],
#  [1, 'T22', 12, 13, 'Drug', 'anticoagulation', '1-59'],
#  [1, 'T23', 16, 17, 'Reason', 'COPD', '1-60'],
#  [1, 'T24', 3, 4, 'Drug', 'albuterol', '1-61'],
#  [1, 'T25', 5, 6, 'Drug', 'tiotropium', '1-61'],
#  [1, 'T26', 7, 8, 'Duration', '10-day', '1-63'],
#  [1, 'T27', 10, 11, 'Drug', 'avelox', '1-63'],
#  [1, 'T28', 12, 15, 'ADE', 'low grade fever', '1-63'],
#  [1, 'T29', 15, 18, 'Reason', 'low grade fever', '1-63'],
#  [1, 'T2900', 21, 22, 'Drug', 'prednisone', '1-63'],
#  [1, 'T30', 32, 33, 'Drug', 'albuterol', '1-63'],
#  [1, 'T31', 34, 35, 'Drug', 'tiotropium', '1-63'],
#  [1, 'T32', 9, 11, 'Reason', 'Temporal arteritis', '1-70'],
#  [1, 'T33', 1, 2, 'Drug', 'prednisone', '1-71'],
#  [1, 'T34', 2, 3, 'Strength', '10mg', '1-71'],
#  [1, 'T35', 3, 4, 'Frequency', 'daily', '1-71'],
#  [1, 'T36', 6, 7, 'Drug', 'aspirin', '1-74'],
#  [1, 'T37', 2, 3, 'Drug', 'Plavix', '1-75'],
#  [1, 'T38', 3, 5, 'Strength', '75 mg', '1-75'],
#  [1, 'T39', 5, 6, 'Route', 'PO', '1-75'],
#  [1, 'T40', 6, 7, 'Frequency', 'qD', '1-75'],
#  [1, 'T41', 7, 8, 'Drug', 'Diltiazem', '1-75'],
#  [1, 'T42', 8, 10, 'Strength', '180 mg', '1-75'],
#  [1, 'T43', 10, 11, 'Route', 'PO', '1-75'],
#  [1, 'T44', 11, 12, 'Frequency', 'qD', '1-75'],
#  [1, 'T45', 12, 13, 'Drug', 'Zetia', '1-75'],
#  [1, 'T46', 13, 15, 'Strength', '10 mg', '1-75'],
#  [1, 'T47', 15, 16, 'Route', 'PO', '1-75'],
#  [1, 'T48', 16, 17, 'Frequency', 'qD', '1-75'],
#  [1, 'T49', 17, 18, 'Drug', 'Simvastatin', '1-75'],
#  [1, 'T50', 18, 20, 'Strength', '20 mg', '1-75'],
#  [1, 'T51', 20, 21, 'Route', 'PO', '1-75'],
#  [1, 'T52', 21, 22, 'Frequency', 'qD', '1-75'],
#  [1, 'T53', 22, 23, 'Drug', 'Prednisone', '1-75'],
#  [1, 'T54', 23, 25, 'Strength', '10 mg', '1-75'],
#  [1, 'T55', 25, 26, 'Route', 'PO', '1-75'],
#  [1, 'T56', 26, 27, 'Frequency', 'qD', '1-75'],
#  [1, 'T57', 27, 28, 'Drug', 'Iron', '1-75'],
#  [1, 'T58', 28, 29, 'Form', 'supplement', '1-75'],
#  [1, 'T59', 29, 30, 'Drug', 'nitro', '1-75'],
#  [1, 'T60', 30, 31, 'Route', 'SL', '1-75'],
#  [1, 'T61', 31, 32, 'Frequency', 'prn', '1-75'],
#  [1, 'T62', 6, 7, 'Drug', 'Plavix', '1-100'],
#  [1, 'T63', 7, 9, 'Strength', '75 mg', '1-100'],
#  [1, 'T64', 9, 10, 'Route', 'PO', '1-100'],
#  [1, 'T65', 10, 11, 'Frequency', 'daily', '1-100'],
#  [1, 'T66', 11, 12, 'Drug', 'Zetia', '1-100'],
#  [1, 'T67', 12, 14, 'Strength', '10 mg', '1-100'],
#  [1, 'T68', 14, 15, 'Route', 'PO', '1-100'],
#  [1, 'T69', 15, 16, 'Frequency', 'daily', '1-100'],
#  [1, 'T70', 16, 17, 'Drug', 'Simvastatin', '1-100'],
#  [1, 'T71', 17, 19, 'Strength', '20 mg', '1-100'],
#  [1, 'T72', 19, 20, 'Route', 'PO', '1-100'],
#  [1, 'T73', 20, 21, 'Frequency', 'daily', '1-100'],
#  [1, 'T74', 21, 22, 'Drug', 'Captopril', '1-100'],
#  [1, 'T75', 22, 24, 'Strength', '12.5 mg', '1-100'],
#  [1, 'T76', 24, 25, 'Route', 'PO', '1-100'],
#  [1, 'T77', 25, 26, 'Frequency', 'TID', '1-100'],
#  [1, 'T78', 26, 27, 'Drug', 'Carvedilol', '1-100'],
#  [1, 'T79', 27, 29, 'Strength', '6.25 mg', '1-100'],
#  [1, 'T80', 29, 30, 'Route', 'PO', '1-100'],
#  [1, 'T81', 30, 31, 'Frequency', 'BID', '1-100'],
#  [1, 'T82', 31, 32, 'Drug', 'Nitroglycerin', '1-100'],
#  [1, 'T83', 32, 34, 'Strength', '0.1 mg/hr', '1-100'],
#  [1, 'T84', 36, 37, 'Route', 'TD', '1-100'],
#  [1, 'T85', 37, 38, 'Frequency', 'qHS', '1-100'],
#  [1, 'T86', 38, 39, 'Drug', 'Prednisone', '1-100'],
#  [1, 'T87', 39, 41, 'Strength', '10 mg', '1-100'],
#  [1, 'T88', 41, 42, 'Route', 'PO', '1-100'],
#  [1, 'T89', 42, 43, 'Frequency', 'qD', '1-100'],
#  [1, 'T90', 4, 5, 'Drug', 'ASPIRIN', '1-128'],
#  [1, 'T92', 6, 7, 'ADE', 'rash', '1-128'],
#  [1, 'T93', 8, 11, 'ADE', 'redness on face', '1-128'],
#  [1, 'T95', 14, 15, 'Drug', 'acetaminophen', '1-128'],
#  [1, 'T96', 15, 17, 'Strength', '325 mg', '1-128'],
#  [1, 'T97', 17, 18, 'Form', 'Tablet', '1-128'],
#  [1, 'T98', 19, 21, 'Dosage', 'One (1)', '1-128'],
#  [1, 'T99', 21, 22, 'Form', 'Tablet', '1-128'],
#  [1, 'T100', 22, 23, 'Route', 'PO', '1-128'],
#  [1, 'T101', 23, 29, 'Frequency', 'Q6H (every 6 hours) as needed', '1-128'],
#  [1, 'T103', 30, 31, 'Reason', 'pain', '1-128'],
#  [1, 'T104', 1, 2, 'Drug', 'carvedilol', '1-139'],
#  [1, 'T105', 2, 4, 'Strength', '3.125 mg', '1-139'],
#  [1, 'T106', 4, 5, 'Form', 'Tablet', '1-139'],
#  [1, 'T107', 6, 8, 'Dosage', 'Two (2)', '1-139'],
#  [1, 'T108', 8, 9, 'Form', 'Tablet', '1-139'],
#  [1, 'T109', 9, 10, 'Route', 'PO', '1-139'],
#  [1, 'T110', 10, 11, 'Frequency', 'BID', '1-139'],
#  [1, 'T111', 4, 5, 'Drug', 'warfarin', '1-146'],
#  [1, 'T112', 5, 7, 'Strength', '1 mg', '1-146'],
#  [1, 'T113', 7, 8, 'Form', 'Tablet', '1-146'],
#  [1, 'T114', 9, 11, 'Dosage', 'Three (3)', '1-146'],
#  [1, 'T115', 11, 12, 'Form', 'Tablet', '1-146'],
#  [1, 'T116', 12, 13, 'Route', 'PO', '1-146'],
#  [1, 'T117', 13, 18, 'Frequency', 'Once Daily at 4 PM', '1-146'],
#  [1, 'T118', 4, 5, 'Drug', 'captopril', '1-153'],
#  [1, 'T119', 5, 7, 'Strength', '12.5 mg', '1-153'],
#  [1, 'T120', 7, 8, 'Form', 'Tablet', '1-153'],
#  [1, 'T121', 9, 11, 'Dosage', 'One (1)', '1-153'],
#  [1, 'T122', 11, 12, 'Form', 'Tablet', '1-153'],
#  [1, 'T123', 12, 13, 'Route', 'PO', '1-153'],
#  [1, 'T124', 13, 17, 'Frequency', 'three times a day', '1-153'],
#  [1, 'T125', 4, 5, 'Drug', 'atorvastatin', '1-160'],
#  [1, 'T126', 5, 7, 'Strength', '80 mg', '1-160'],
#  [1, 'T127', 7, 8, 'Form', 'Tablet', '1-160'],
#  [1, 'T128', 9, 11, 'Dosage', 'One (1)', '1-160'],
#  [1, 'T129', 11, 12, 'Form', 'Tablet', '1-160'],
#  [1, 'T130', 12, 13, 'Route', 'PO', '1-160'],
#  [1, 'T131', 13, 14, 'Frequency', 'DAILY', '1-160'],
#  [1, 'T132', 4, 5, 'Drug', 'prednisone', '1-167'],
#  [1, 'T133', 5, 7, 'Strength', '5 mg', '1-167'],
#  [1, 'T134', 7, 8, 'Form', 'Tablet', '1-167'],
#  [1, 'T135', 9, 11, 'Dosage', 'Two (2)', '1-167'],
#  [1, 'T136', 11, 12, 'Form', 'Tablet', '1-167'],
#  [1, 'T137', 12, 13, 'Route', 'PO', '1-167'],
#  [1, 'T138', 13, 14, 'Frequency', 'DAILY', '1-167'],
#  [1, 'T139', 1, 2, 'Drug', 'aspirin', '1-174'],
#  [1, 'T140', 2, 4, 'Strength', '325 mg', '1-174'],
#  [1, 'T141', 4, 5, 'Form', 'Tablet', '1-174'],
#  [1, 'T142', 6, 8, 'Dosage', 'One (1)', '1-174'],
#  [1, 'T143', 8, 9, 'Form', 'Tablet', '1-174'],
#  [1, 'T144', 9, 10, 'Route', 'PO', '1-174'],
#  [1, 'T145', 10, 11, 'Frequency', 'DAILY', '1-174'],
#  [1, 'T146', 1, 3, 'Drug', 'albuterol sulfate', '1-181'],
#  [1, 'T147', 3, 5, 'Strength', '90 mcg/Actuation', '1-181'],
#  [1, 'T148', 5, 8, 'Form', 'HFA Aerosol Inhaler', '1-181'],
#  [1, 'T149', 9, 11, 'Dosage', 'One (1)', '1-181'],
#  [1, 'T150', 11, 12, 'Form', 'Inhalation', '1-181'],
#  [1, 'T151', 16, 19, 'Reason', 'shortness of breath', '1-181'],
#  [1, 'T152', 20, 21, 'Reason', 'wheezing', '1-181'],
#  [1, 'T153', 4, 6, 'Drug', 'tiotropium bromide', '1-188'],
#  [1, 'T154', 6, 8, 'Strength', '18 mcg', '1-188'],
#  [1, 'T155', 8, 11, 'Form', 'Capsule, w/Inhalation Device', '1-188'],
#  [1, 'T156', 12, 14, 'Dosage', 'One (1)', '1-188'],
#  [1, 'T157', 14, 15, 'Form', 'Inhalation', '1-188'],
#  [1, 'T158', 16, 17, 'Frequency', 'bedtime', '1-188'],
#  [1, 'T159', 4, 5, 'Drug', 'omeprazole', '1-194'],
#  [1, 'T160', 5, 7, 'Strength', '20 mg', '1-194'],
#  [1, 'T161', 7, 10, 'Form', 'Capsule, Delayed Release(E.C.)', '1-194'],
#  [1, 'T162', 11, 13, 'Dosage', 'One (1)', '1-194'],
#  [1, 'T163', 13, 16, 'Form', 'Capsule, Delayed Release(E.C.)', '1-194'],
#  [1, 'T164', 16, 17, 'Route', 'PO', '1-194'],
#  [1, 'T165', 17, 18, 'Frequency', 'DAILY', '1-194'],
#  [1, 'T166', 3, 4, 'Drug', 'enoxaparin', '1-201'],
#  [1, 'T167', 4, 7, 'Strength', '60 mg/0.6 mL', '1-201'],
#  [1, 'T168', 7, 8, 'Form', 'Syringe', '1-201'],
#  [1, 'T169', 9, 11, 'Dosage', 'One (1)', '1-201'],
#  [1, 'T170', 11, 12, 'Route', 'Subcutaneous', '1-201'],
#  [1, 'T171', 12, 15, 'Frequency', 'twice a day', '1-201'],
#  [1, 'T172', 15, 18, 'Duration', 'for 10 days', '1-201'],
#  [1, 'T173', 4, 5, 'Drug', 'nitroglycerin', '1-208'],
#  [1, 'T174', 5, 7, 'Strength', '0.4 mg', '1-208'],
#  [1, 'T175', 7, 8, 'Form', 'Tablet', '1-208'],
#  [1, 'T176', 9, 10, 'Route', 'Sublingual', '1-208'],
#  [1, 'T177', 11, 13, 'Dosage', 'One (1)', '1-208'],
#  [1, 'T178', 13, 14, 'Route', 'Sublingual', '1-208'],
#  [1, 'T179', 14, 17, 'Frequency', 'PRN as needed', '1-208'],
#  [1, 'T180', 18, 20, 'Reason', 'chest pain', '1-208'],
#  [1, 'T183', 21, 22, 'Drug', 'Dye', '1-216'],
#  [1, 'T184', 23, 24, 'Route', 'injected', '1-216'],
#  [1, 'T185', 6, 7, 'Drug', 'Lovenox', '1-218'],
#  [1, 'T186', 10, 11, 'Drug', 'Enoxaparin', '1-218'],
#  [1, 'T187', 2, 3, 'Form', 'injection', '1-220'],
#  [1, 'T188', 6, 9, 'Frequency', 'twice a day', '1-220'],
#  [1, 'T189', 6, 7, 'Drug', 'Warfarin', '1-222'],
#  [1, 'T190', 10, 11, 'Drug', 'Coumadin', '1-222'],
#  [1, 'T191', 3, 4, 'Form', 'pill', '1-224'],
#  [1, 'T192', 1, 2, 'Drug', 'warfarin', '1-225'],
#  [1, 'T193', 12, 13, 'Drug', 'enoxaparin', '1-225'],
#  [1, 'T194', 25, 26, 'Drug', 'warfarin', '1-225'],
#  [1, 'T195', 3, 4, 'Drug', 'enoxaparin', '1-228'],
#  [1, 'T196', 4, 5, 'Form', 'injections', '1-228'],
#  [1, 'T197', 5, 8, 'Duration', 'for 10 days', '1-228'],
#  [1, 'T198', 4, 5, 'Drug', 'Aspirin', '1-231'],
#  [1, 'T199', 29, 30, 'Drug', 'Acetaminophen', '1-232'],
#  [1, 'T200', 30, 32, 'Strength', '325 mg', '1-232'],
#  [1, 'T201', 32, 33, 'Form', 'Tablet', '1-232'],
#  [1, 'T202', 33, 34, 'Dosage', '1', '1-232'],
#  [1, 'T203', 34, 35, 'Form', 'Tablet', '1-232'],
#  [1, 'T204', 35, 37, 'Route', 'by mouth', '1-232'],
#  [1, 'T205', 38, 42, 'Frequency', '6 hours as needed', '1-232'],
#  [1, 'T206', 43, 44, 'Reason', 'pain', '1-232'],
#  [1, 'T207', 15, 16, 'Drug', 'Carvedilol', '1-240'],
#  [1, 'T208', 16, 18, 'Strength', '3.125 mg', '1-240'],
#  [1, 'T209', 18, 19, 'Form', 'Tablet', '1-240'],
#  [1, 'T210', 19, 20, 'Dosage', '2', '1-240'],
#  [1, 'T211', 20, 21, 'Form', 'Tablets', '1-240'],
#  [1, 'T212', 21, 23, 'Route', 'by mouth', '1-240'],
#  [1, 'T213', 25, 29, 'Frequency', '2 times a day', '1-240'],
#  [1, 'T214', 29, 30, 'Drug', 'Warfarin', '1-240'],
#  [1, 'T215', 30, 32, 'Strength', '1 mg', '1-240'],
#  [1, 'T216', 32, 33, 'Form', 'Tablet', '1-240'],
#  [1, 'T217', 33, 34, 'Dosage', '3', '1-240'],
#  [1, 'T218', 34, 35, 'Form', 'Tablets', '1-240'],
#  [1, 'T219', 35, 37, 'Route', 'by mouth', '1-240'],
#  [1, 'T220', 37, 42, 'Frequency', 'once Daily at 4 PM', '1-240'],
#  [1, 'T221', 27, 28, 'Drug', 'Captopril', '1-254'],
#  [1, 'T222', 28, 30, 'Strength', '12.5 mg', '1-254'],
#  [1, 'T223', 30, 31, 'Form', 'Tablet', '1-254'],
#  [1, 'T224', 31, 32, 'Dosage', '1', '1-254'],
#  [1, 'T225', 32, 33, 'Form', 'Tablet', '1-254'],
#  [1, 'T226', 33, 35, 'Route', 'by mouth', '1-254'],
#  [1, 'T227', 35, 39, 'Frequency', 'three times a day', '1-254'],
#  [1, 'T228', 12, 13, 'Drug', 'Atorvastatin', '1-261'],
#  [1, 'T229', 13, 15, 'Strength', '80 mg', '1-261'],
#  [1, 'T230', 15, 16, 'Form', 'Tablet', '1-261'],
#  [1, 'T231', 16, 17, 'Dosage', '1', '1-261'],
#  [1, 'T232', 17, 18, 'Form', 'Tablet', '1-261'],
#  [1, 'T233', 18, 20, 'Route', 'by mouth', '1-261'],
#  [1, 'T234', 20, 22, 'Frequency', 'at night', '1-261'],
#  [1, 'T235', 22, 23, 'Drug', 'Prednisone', '1-261'],
#  [1, 'T236', 23, 25, 'Strength', '5 mg', '1-261'],
#  [1, 'T237', 25, 26, 'Form', 'Tablet', '1-261'],
#  [1, 'T238', 26, 27, 'Dosage', '2', '1-261'],
#  [1, 'T239', 27, 28, 'Form', 'Tablet', '1-261'],
#  [1, 'T240', 28, 30, 'Route', 'by mouth', '1-261'],
#  [1, 'T241', 30, 31, 'Frequency', 'DAILY', '1-261'],
#  [1, 'T242', 31, 32, 'Drug', 'Aspirin', '1-261'],
#  [1, 'T243', 32, 34, 'Strength', '325 mg', '1-261'],
#  [1, 'T244', 34, 35, 'Form', 'Tablet', '1-261'],
#  [1, 'T245', 35, 36, 'Dosage', '1', '1-261'],
#  [1, 'T246', 36, 37, 'Form', 'tablet', '1-261'],
#  [1, 'T247', 37, 39, 'Route', 'by mouth', '1-261'],
#  [1, 'T248', 39, 40, 'Frequency', 'daily', '1-261'],
#  [1, 'T249', 40, 41, 'Drug', 'Omeprazole', '1-261'],
#  [1, 'T250', 41, 43, 'Strength', '20 mg', '1-261'],
#  [1, 'T251', 43, 44, 'Form', 'tablet', '1-261'],
#  [1, 'T252', 44, 45, 'Dosage', '1', '1-261'],
#  [1, 'T253', 45, 46, 'Form', 'tablet', '1-261'],
#  [1, 'T254', 46, 48, 'Route', 'by mouth', '1-261'],
#  [1, 'T255', 48, 49, 'Frequency', 'daily', '1-261'],
#  [1, 'T256', 49, 51, 'Drug', 'Albuterol sulfate', '1-261'],
#  [1, 'T257', 51, 53, 'Strength', '90 mcg/Actuation', '1-261'],
#  [1, 'T258', 53, 56, 'Form', 'HFA Aerosol Inhaler', '1-261'],
#  [1, 'T259', 56, 57, 'Dosage', '1', '1-261'],
#  [1, 'T260', 57, 58, 'Form', 'Inhalation', '1-261'],
#  [1, 'T261', 61, 64, 'Reason', 'shortness of breath', '1-261'],
#  [1, 'T262', 65, 66, 'Reason', 'wheezing', '1-261'],
#  [1, 'T263', 54, 56, 'Drug', 'Tiotropium bromide', '1-296'],
#  [1, 'T264', 56, 58, 'Strength', '18 mcg', '1-296'],
#  [1, 'T265', 58, 61, 'Form', 'Capsule, w/Inhalation Device', '1-296'],
#  [1, 'T266', 61, 62, 'Dosage', '1', '1-296'],
#  [1, 'T267', 62, 63, 'Form', 'Inhalation', '1-296'],
#  [1, 'T268', 63, 65, 'Frequency', 'at bedtime', '1-296'],
#  [1, 'T269', 11, 12, 'Drug', 'Enoxaparin', '1-302'],
#  [1, 'T270', 12, 14, 'Strength', '60 mcg', '1-302'],
#  [1, 'T271', 14, 15, 'Dosage', '1', '1-302'],
#  [1, 'T272', 15, 16, 'Form', 'injection', '1-302'],
#  [1, 'T273', 16, 19, 'Frequency', '2x a day', '1-302'],
#  [1, 'T274', 20, 22, 'Frequency', '10 days', '1-302'],
#  [1, 'T275', 22, 23, 'Drug', 'Nitroprusside', '1-302'],
#  [1, 'T276', 23, 24, 'Strength', '0.4', '1-302'],
#  [1, 'T277', 24, 25, 'Route', 'sublingual', '1-302'],
#  [1, 'T278', 28, 30, 'Reason', 'chest pain', '1-302'],
#  [2, 'T163', 5, 6, 'Reason', 'Gout', '2-0'],
#  [2, 'T164', 7, 8, 'Reason', 'osteoarthritis', '2-0'],
#  [2, 'T31', 10, 11, 'Drug', 'Indomethacin', '2-0'],
#  [2, 'T204', 15, 19, 'Reason', 'chronic severe knee pain', '2-0'],
#  [2, 'T165', 36, 37, 'Drug', 'ASA', '2-4'],
#  [2, 'T166', 39, 40, 'Drug', 'ACETMNPHN', '2-4'],
#  [2, 'T167', 41, 42, 'Drug', 'bnzodzpn', '2-4'],
#  [2, 'T168', 43, 44, 'Drug', 'barbitrt', '2-4'],
#  [2, 'T169', 45, 46, 'Drug', 'tricyclic', '2-4'],
#  [2, 'T170', 54, 55, 'Drug', 'bnzodzpn', '2-4'],
#  [2, 'T171', 56, 57, 'Drug', 'barbitrt', '2-4'],
#  [2, 'T162', 58, 59, 'Drug', 'opiates', '2-4'],
#  [2, 'T172', 61, 62, 'Drug', 'amphetmn', '2-4'],
#  [2, 'T173', 63, 64, 'Drug', 'mthdone', '2-4'],
#  [2, 'T174', 146, 147, 'Drug', 'CONTRAST', '2-4'],
#  [2, 'T175', 167, 168, 'Drug', 'CONTRAST', '2-4'],
#  [2, 'T26', 2, 3, 'Route', 'IV', '2-16'],
#  [2, 'T176', 3, 4, 'Drug', 'CONTRAST', '2-16'],
#  [2, 'T179', 10, 11, 'Route', 'intravenous', '2-18'],
#  [2, 'T178', 11, 12, 'Drug', 'contrast', '2-18'],
#  [2, 'T180', 43, 44, 'Drug', 'CONTRAST', '2-20'],
#  [2, 'T181', 65, 66, 'Drug', 'CONTRAST', '2-20'],
#  [2, 'T28', 100, 101, 'Route', 'IV', '2-20'],
#  [2, 'T182', 101, 102, 'Drug', 'CONTRAST', '2-20'],
#  [2, 'T186', 6, 7, 'Route', 'intravenous', '2-24'],
#  [2, 'T185', 7, 8, 'Drug', 'contrast', '2-24'],
#  [2, 'T161', 1, 2, 'Route', 'intravenous', '2-26'],
#  [2, 'T184', 2, 3, 'Drug', 'contrast', '2-26'],
#  [2, 'T85', 38, 40, 'Reason', 'hypertensive crisis', '2-28'],
#  [2, 'T83', 15, 16, 'Drug', 'antihypertensives', '2-29'],
#  [2, 'T187', 17, 18, 'Duration', 'continuous', '2-29'],
#  [2, 'T84', 18, 19, 'Route', 'drip', '2-29'],
#  [2, 'T86', 8, 9, 'Drug', 'NSAIDs', '2-32'],
#  [2, 'T188', 12, 13, 'Reason', 'gout', '2-32'],
#  [2, 'T87', 3, 6, 'Reason', 'blood glucose control', '2-34'],
#  [2, 'T22', 8, 9, 'Drug', 'insulin', '2-34'],
#  [2, 'T88', 9, 10, 'Dosage', 'sliding-scale', '2-34'],
#  [2, 'T189', 12, 15, 'ADE', 'acute renal failure', '2-34'],
#  [2, 'T190', 15, 18, 'Reason', 'acute renal failure', '2-34'],
#  [2, 'T67', 33, 34, 'Drug', 'Cipro', '2-34'],
#  [2, 'T90', 43, 44, 'Drug', 'IVF', '2-34'],
#  [2, 'T15', 49, 50, 'Drug', 'indomethacin', '2-34'],
#  [2, 'T91', 15, 17, 'Reason', 'gram-negative UTI', '2-42'],
#  [2, 'T25', 6, 7, 'Drug', 'ciprofloxacin', '2-43'],
#  [2, 'T92', 10, 14, 'ADE', 'worsened his renal failure', '2-43'],
#  [2, 'T191', 19, 20, 'ADE', 'febrile', '2-43'],
#  [2, 'T192', 21, 22, 'ADE', 'somnolent', '2-43'],
#  [2, 'T193', 23, 24, 'ADE', 'lethargic', '2-43'],
#  [2, 'T48', 30, 31, 'Route', 'IV', '2-43'],
#  [2, 'T74', 31, 32, 'Drug', 'vancomycin', '2-43'],
#  [2, 'T41', 33, 34, 'Drug', 'Zosyn', '2-43'],
#  [2, 'T47', 35, 36, 'Drug', 'vancomycin', '2-43'],
#  [2, 'T94', 20, 21, 'Duration', '3.5d', '2-52'],
#  [2, 'T75', 24, 25, 'Route', 'IV', '2-52'],
#  [2, 'T49', 25, 26, 'Drug', 'Zosyn', '2-52'],
#  [2, 'T50', 31, 32, 'Route', 'PO', '2-52'],
#  [2, 'T27', 32, 33, 'Drug', 'Bactrim', '2-52'],
#  [2, 'T95', 38, 39, 'Duration', '7-8d', '2-52'],
#  [2, 'T76', 41, 44, 'Reason', 'complicated (male) UTI', '2-52'],
#  [2, 'T89', 11, 12, 'Route', 'IV', '2-59'],
#  [2, 'T93', 12, 13, 'Drug', 'antibiotics', '2-59'],
#  [2, 'T32', 12, 13, 'Drug', 'Cipro', '2-61'],
#  [2, 'T194', 11, 12, 'Drug', 'SSI', '2-62'],
#  [2, 'T96', 52, 54, 'Duration', '3.5 days', '2-63'],
#  [2, 'T68', 58, 60, 'Drug', 'Bactrim DS', '2-63'],
#  [2, 'T70', 60, 61, 'Dosage', '1', '2-63'],
#  [2, 'T69', 61, 62, 'Form', 'tab', '2-63'],
#  [2, 'T71', 62, 63, 'Route', 'PO', '2-63'],
#  [2, 'T195', 64, 66, 'Reason', 'complicated UTI', '2-63'],
#  [2, 'T97', 70, 71, 'Drug', 'NSAID', '2-63'],
#  [2, 'T72', 79, 80, 'Drug', 'Indomethacin', '2-63'],
#  [2, 'T73', 80, 81, 'Strength', '50mg', '2-63'],
#  [2, 'T12', 84, 87, 'Drug', 'Tylenol with Codeine', '2-63'],
#  [2, 'T98', 87, 88, 'Frequency', 'prn', '2-63'],
#  [2, 'T23', 89, 90, 'Drug', 'Lipitor', '2-63'],
#  [2, 'T24', 90, 91, 'Strength', '20mg', '2-63'],
#  [2, 'T99', 91, 92, 'Frequency', 'qDay', '2-63'],
#  [2, 'T100', 93, 94, 'Drug', 'HCTZ', '2-63'],
#  [2, 'T101', 94, 95, 'Strength', '25mg', '2-63'],
#  [2, 'T102', 95, 96, 'Frequency', 'qDay', '2-63'],
#  [2, 'T103', 97, 98, 'Drug', 'Naprocen', '2-63'],
#  [2, 'T104', 98, 99, 'Strength', '500mg', '2-63'],
#  [2, 'T1', 103, 104, 'Drug', 'Insulin', '2-63'],
#  [2, 'T2', 104, 106, 'Strength', '55 units', '2-63'],
#  [2, 'T105', 106, 107, 'Frequency', 'qAM', '2-63'],
#  [2, 'T106', 109, 111, 'Dosage', '55 units', '2-63'],
#  [2, 'T107', 111, 112, 'Frequency', 'qPM', '2-63'],
#  [2, 'T108', 114, 115, 'Drug', 'SSI', '2-87'],
#  [2, 'T3', 118, 119, 'Drug', 'atorvastatin', '2-87'],
#  [2, 'T4', 119, 121, 'Strength', '20 mg', '2-87'],
#  [2, 'T109', 121, 122, 'Form', 'Tablet', '2-87'],
#  [2, 'T110', 123, 125, 'Dosage', 'One (1)', '2-87'],
#  [2, 'T5', 125, 126, 'Form', 'Tablet', '2-87'],
#  [2, 'T6', 126, 127, 'Route', 'PO', '2-87'],
#  [2, 'T111', 127, 129, 'Frequency', 'DAILY (Daily)', '2-87'],
#  [2, 'T33', 1, 4, 'Drug', 'glucagon (human recombinant)', '2-95'],
#  [2, 'T34', 4, 6, 'Strength', '1 mg', '2-95'],
#  [2, 'T113', 6, 8, 'Form', 'Recon Soln', '2-95'],
#  [2, 'T114', 9, 11, 'Dosage', 'One (1)', '2-95'],
#  [2, 'T115', 11, 14, 'Form', 'Recon Soln Injection', '2-95'],
#  [2, 'T116', 14, 18, 'Frequency', 'Q15MIN () as needed', '2-95'],
#  [2, 'T117', 19, 21, 'Reason', 'hypoglycemia protocol', '2-95'],
#  [2, 'T112', 1, 2, 'Drug', 'senna', '2-102'],
#  [2, 'T118', 2, 4, 'Strength', '8.6 mg', '2-102'],
#  [2, 'T119', 4, 5, 'Form', 'Tablet', '2-102'],
#  [2, 'T120', 6, 8, 'Dosage', 'One (1)', '2-102'],
#  [2, 'T35', 8, 9, 'Form', 'Tablet', '2-102'],
#  [2, 'T36', 9, 10, 'Route', 'PO', '2-102'],
#  [2, 'T121', 10, 15, 'Frequency', 'BID (2 times a day)', '2-102'],
#  [2, 'T7', 1, 3, 'Drug', 'docusate sodium', '2-109'],
#  [2, 'T8', 3, 5, 'Strength', '100 mg', '2-109'],
#  [2, 'T122', 5, 6, 'Form', 'Capsule', '2-109'],
#  [2, 'T123', 7, 9, 'Dosage', 'One (1)', '2-109'],
#  [2, 'T9', 9, 10, 'Form', 'Capsule', '2-109'],
#  [2, 'T10', 10, 11, 'Route', 'PO', '2-109'],
#  [2, 'T124', 11, 16, 'Frequency', 'BID (2 times a day)', '2-109'],
#  [2, 'T58', 1, 3, 'Drug', 'bisacody l', '2-116'],
#  [2, 'T55', 3, 5, 'Strength', '5 mg', '2-116'],
#  [2, 'T125', 5, 9, 'Form', 'Tablet, Delayed Release (E.C.)', '2-116'],
#  [2, 'T126', 10, 12, 'Dosage', 'Two (2)', '2-116'],
#  [2, 'T56', 12, 17, 'Form', 'Tablet , Delayed Release (E.C.)', '2-116'],
#  [2, 'T57', 17, 18, 'Route', 'PO', '2-116'],
#  [2, 'T127', 18, 22, 'Frequency', 'DAILY (Daily) as needed', '2-116'],
#  [2, 'T77', 23, 24, 'Reason', 'constipation', '2-116'],
#  [2, 'T59', 1, 3, 'Drug', 'heparin (porcine)', '2-124'],
#  [2, 'T60', 3, 6, 'Strength', '5,000 unit /mL', '2-124'],
#  [2, 'T128', 6, 7, 'Form', 'Solution', '2-124'],
#  [2, 'T129', 8, 10, 'Dosage', 'One (1)', '2-124'],
#  [2, 'T61', 10, 11, 'Form', 'Injection', '2-124'],
#  [2, 'T62', 11, 16, 'Frequency', 'TID (3 times a day)', '2-124'],
#  [2, 'T78', 18, 20, 'Reason', 'DVT prophylaxis', '2-124'],
#  [2, 'T42', 1, 3, 'Drug', 'calcium carbonate', '2-131'],
#  [2, 'T43', 3, 5, 'Strength', '200 mg', '2-131'],
#  [2, 'T130', 6, 8, 'Strength', '500 mg', '2-131'],
#  [2, 'T131', 9, 11, 'Form', 'Tablet, Chewable', '2-131'],
#  [2, 'T132', 12, 14, 'Dosage', 'One (1)', '2-131'],
#  [2, 'T44', 14, 17, 'Form', 'Tablet , Chewable', '2-131'],
#  [2, 'T46', 17, 18, 'Route', 'PO', '2-131'],
#  [2, 'T45', 18, 25, 'Frequency', 'QID (4 times a day) as needed', '2-131'],
#  [2, 'T79', 26, 27, 'Reason', 'indigestion', '2-131'],
#  [2, 'T51', 1, 3, 'Drug', 'metoprolol tartrate', '2-140'],
#  [2, 'T52', 3, 5, 'Strength', '25 mg', '2-140'],
#  [2, 'T133', 5, 6, 'Form', 'Tablet', '2-140'],
#  [2, 'T134', 7, 9, 'Dosage', 'One (1)', '2-140'],
#  [2, 'T53', 9, 10, 'Form', 'Tablet', '2-140'],
#  [2, 'T54', 10, 11, 'Route', 'PO', '2-140'],
#  [2, 'T135', 11, 16, 'Frequency', 'TID (3 times a day)', '2-140'],
#  [2, 'T18', 1, 2, 'Drug', 'amlodipine', '2-147'],
#  [2, 'T19', 2, 4, 'Strength', '5 mg', '2-147'],
#  [2, 'T136', 4, 5, 'Form', 'Tablet', '2-147'],
#  [2, 'T137', 6, 8, 'Dosage', 'Two (2)', '2-147'],
#  [2, 'T20', 8, 9, 'Form', 'Tablet', '2-147'],
#  [2, 'T21', 9, 10, 'Route', 'PO', '2-147'],
#  [2, 'T138', 10, 13, 'Frequency', 'HS (at bedtime)', '2-147'],
#  [2, 'T66', 1, 3, 'Drug', 'acetaminophe n', '2-154'],
#  [2, 'T63', 3, 5, 'Strength', '325 mg', '2-154'],
#  [2, 'T139', 5, 6, 'Form', 'Tablet', '2-154'],
#  [2, 'T140', 7, 9, 'Dosage', 'One (1)', '2-154'],
#  [2, 'T64', 9, 10, 'Form', 'Tablet', '2-154'],
#  [2, 'T65', 10, 11, 'Route', 'PO', '2-154'],
#  [2, 'T141', 11, 17, 'Frequency', 'Q6H (every 6 hours) as needed', '2-154'],
#  [2, 'T80', 18, 19, 'Reason', 'Pain', '2-154'],
#  [2, 'T40', 1, 3, 'Drug', 'famotidin e', '2-162'],
#  [2, 'T37', 3, 5, 'Strength', '20 mg', '2-162'],
#  [2, 'T142', 5, 6, 'Form', 'Tablet', '2-162'],
#  [2, 'T143', 7, 9, 'Dosage', 'One (1)', '2-162'],
#  [2, 'T38', 9, 10, 'Form', 'Tablet', '2-162'],
#  [2, 'T39', 10, 11, 'Route', 'PO', '2-162'],
#  [2, 'T144', 11, 13, 'Frequency', 'DAILY (Daily)', '2-162'],
#  [2, 'T17', 1, 3, 'Drug', 'sulfamethoxazole -trimethoprim', '2-169'],
#  [2, 'T145', 3, 5, 'Strength', '800-160 mg', '2-169'],
#  [2, 'T146', 5, 6, 'Form', 'Tablet', '2-169'],
#  [2, 'T147', 7, 9, 'Dosage', 'One (1)', '2-169'],
#  [2, 'T148', 9, 10, 'Form', 'Tablet', '2-169'],
#  [2, 'T149', 10, 11, 'Route', 'PO', '2-169'],
#  [2, 'T150', 11, 18, 'Frequency', 'BID (2 times a day) as needed', '2-169'],
#  [2, 'T81', 19, 22, 'Reason', 'Urianary tract infection', '2-169'],
#  [2, 'T151', 1, 6, 'Drug', 'dextrose 50% in water (D50W)', '2-177'],
#  [2, 'T152', 6, 7, 'Form', 'Syringe', '2-177'],
#  [2, 'T153', 8, 10, 'Dosage', 'One (1)', '2-177'],
#  [2, 'T154', 10, 11, 'Route', 'Intravenous', '2-177'],
#  [2, 'T155', 11, 16, 'Frequency', 'PRN (as needed) as needed', '2-177'],
#  [2, 'T82', 17, 19, 'Reason', 'hypoglycemia protocol', '2-177'],
#  [2, 'T13', 1, 4, 'Drug', 'insulin regular human', '2-183'],
#  [2, 'T14', 4, 9, 'Strength', '100 unit /mL (3 mL)', '2-183'],
#  [2, 'T156', 9, 11, 'Form', 'Insulin Pen', '2-183'],
#  [2, 'T29', 11, 12, 'Drug', 'Insulin', '2-183'],
#  [2, 'T158', 16, 17, 'Route', 'Subcutaneous', '2-183'],
#  [2, 'T30', 17, 21, 'Frequency', 'four times a day', '2-183'],
#  [2, 'T159', 23, 24, 'Dosage', 'sliding-scale', '2-183'],
#  [2, 'T11', 24, 25, 'Drug', 'insulin', '2-183'],
#  [2, 'T16', 27, 28, 'Drug', 'insulin', '2-183'],
#  [2, 'T160', 29, 31, 'Reason', 'diabetes mellitus', '2-183'],
#  [2,
#   'T197',
#   17,
#   22,
#   'Drug',
#   'painkiller medicines (indomethacin and naprosyn)',
#   '2-193'],
#  [2, 'T198', 26, 28, 'Frequency', 'every day', '2-193'],
#  [2, 'T201', 6, 9, 'Reason', 'urinary tract infection', '2-195'],
#  [2, 'T199', 20, 21, 'Drug', 'antibiotic', '2-195'],
#  [2, 'T200', 26, 29, 'Duration', '3 more days', '2-195'],
#  [3, 'T84', 15, 16, 'Drug', 'aspirin', '3-0'],
#  [3, 'T97', 5, 7, 'Reason', 'h/o afib', '3-1'],
#  [3, 'T70', 8, 9, 'Drug', 'coumadin', '3-1'],
#  [3, 'T93', 4, 5, 'Reason', 'Afib', '3-3'],
#  [3, 'T24', 6, 7, 'Drug', 'coumadin', '3-3'],
#  [3, 'T190', 8, 9, 'Reason', 'Gout', '3-3'],
#  [3, 'T191', 13, 14, 'Reason', 'HTN', '3-3'],
#  [3, 'T192', 16, 17, 'Reason', 'dermatitis', '3-3'],
#  [3, 'T193', 19, 20, 'Reason', 'Esophagitis', '3-3'],
#  [3, 'T8', 2, 3, 'Drug', 'allopurinol', '3-9'],
#  [3, 'T98', 3, 4, 'Strength', '100', '3-9'],
#  [3, 'T85', 5, 6, 'Drug', 'atenolol', '3-9'],
#  [3, 'T99', 6, 7, 'Strength', '50', '3-9'],
#  [3, 'T23', 8, 9, 'Drug', 'clobetasol', '3-9'],
#  [3, 'T100', 9, 10, 'Frequency', 'PRN', '3-9'],
#  [3, 'T31', 11, 12, 'Drug', 'finasteride', '3-9'],
#  [3, 'T101', 12, 13, 'Strength', '5', '3-9'],
#  [3, 'T37', 14, 15, 'Drug', 'furosemide', '3-9'],
#  [3, 'T102', 15, 16, 'Strength', '40', '3-9'],
#  [3, 'T103', 17, 18, 'Drug', 'Klor-Con', '3-9'],
#  [3, 'T38', 18, 19, 'Strength', '20meq', '3-9'],
#  [3, 'T86', 20, 21, 'Drug', 'omeprazole', '3-9'],
#  [3, 'T104', 21, 22, 'Strength', '20', '3-9'],
#  [3, 'T54', 23, 24, 'Drug', 'simvastatin', '3-9'],
#  [3, 'T105', 24, 25, 'Strength', '80', '3-9'],
#  [3, 'T66', 26, 27, 'Drug', 'terazosin', '3-9'],
#  [3, 'T106', 27, 28, 'Strength', '5', '3-9'],
#  [3, 'T72', 29, 30, 'Drug', 'warfarin', '3-9'],
#  [3, 'T107', 30, 31, 'Strength', '5', '3-9'],
#  [3, 'T108', 32, 33, 'Frequency', 'T,Sat', '3-9'],
#  [3, 'T109', 34, 35, 'Strength', '2.5', '3-9'],
#  [3, 'T110', 36, 37, 'Frequency', 'MWRFSun', '3-9'],
#  [3, 'T32', 7, 8, 'Drug', 'Daptomycin', '3-32'],
#  [3, 'T90', 2, 3, 'Drug', 'Daptomycin', '3-33'],
#  [3, 'T91', 4, 7, 'Strength', '3.0 MCG /ML', '3-33'],
#  [3, 'T172', 7, 8, 'Drug', 'contrast', '3-35'],
#  [3, 'T194', 9, 10, 'ADE', 'confused', '3-36'],
#  [3, 'T173', 18, 20, 'Drug', 'pain medications', '3-37'],
#  [3, 'T46', 3, 4, 'Drug', 'fentanyl', '3-38'],
#  [3, 'T53', 5, 6, 'Drug', 'propofol', '3-38'],
#  [3, 'T94', 7, 9, 'Reason', 'pain control', '3-38'],
#  [3, 'T111', 10, 11, 'Reason', 'sedation', '3-38'],
#  [3, 'T112', 7, 8, 'Reason', 'pain', '3-42'],
#  [3, 'T2', 11, 12, 'Route', 'IV', '3-42'],
#  [3, 'T1', 12, 13, 'Drug', 'dilaudid', '3-42'],
#  [3, 'T174', 14, 16, 'Reason', 'dressing changes', '3-42'],
#  [3, 'T12', 17, 18, 'Drug', 'oxycodone', '3-42'],
#  [3, 'T113', 21, 24, 'Reason', 'pain in between', '3-42'],
#  [3, 'T175', 5, 6, 'Drug', 'vasopressors', '3-48'],
#  [3, 'T13', 1, 2, 'Drug', 'coumadin', '3-49'],
#  [3, 'T176', 10, 12, 'Reason', 'prophylactically anticoagulated', '3-49'],
#  [3, 'T195', 13, 15, 'Frequency', 'once daily', '3-49'],
#  [3, 'T55', 15, 16, 'Drug', 'lovenox', '3-49'],
#  [3, 'T56', 16, 17, 'Route', 'injections', '3-49'],
#  [3, 'T179', 3, 4, 'Dosage', 'multiple', '3-54'],
#  [3, 'T177', 4, 6, 'Drug', 'blood product', '3-54'],
#  [3, 'T178', 6, 7, 'Form', 'transfusions', '3-54'],
#  [3, 'T180', 13, 16, 'Reason', 'loss of blood', '3-54'],
#  [3, 'T92', 5, 6, 'Drug', 'thiamine', '3-58'],
#  [3, 'T3', 7, 8, 'Drug', 'folate', '3-58'],
#  [3, 'T114', 9, 10, 'Drug', 'MVI', '3-58'],
#  [3, 'T115', 11, 14, 'Reason', 'h/o heavy EtOH', '3-58'],
#  [3, 'T17', 4, 5, 'Drug', 'albuterol', '3-62'],
#  [3, 'T18', 5, 6, 'Form', 'nebulizer', '3-62'],
#  [3, 'T116', 7, 8, 'Frequency', 'PRN', '3-62'],
#  [3, 'T95', 9, 10, 'Reason', 'wheezes', '3-62'],
#  [3, 'T196', 2, 3, 'Drug', 'isosource', '3-66'],
#  [3, 'T197', 3, 4, 'Strength', '1.5', '3-66'],
#  [3, 'T198', 9, 11, 'Dosage', '60 cc', '3-66'],
#  [3, 'T199', 12, 13, 'Frequency', 'hr', '3-66'],
#  [3, 'T183', 1, 2, 'Drug', 'electrolytes', '3-70'],
#  [3, 'T184', 4, 5, 'Frequency', 'PRN', '3-70'],
#  [3, 'T117', 3, 4, 'Drug', 'lasix', '3-72'],
#  [3, 'T118', 5, 6, 'Drug', 'albumin', '3-72'],
#  [3, 'T119', 10, 11, 'Reason', 'edema', '3-72'],
#  [3, 'T185', 8, 9, 'Drug', 'antibiotics', '3-75'],
#  [3, 'T120', 10, 11, 'Drug', 'vanc', '3-75'],
#  [3, 'T25', 12, 13, 'Drug', 'zosyn', '3-75'],
#  [3, 'T121', 14, 15, 'Drug', 'clinda', '3-75'],
#  [3, 'T186', 9, 10, 'Drug', 'antibiotic', '3-79'],
#  [3, 'T187', 13, 15, 'Drug', 'rabies vaccinations', '3-79'],
#  [3, 'T122', 2, 5, 'Drug', 'Rabies Immune Globulin', '3-81'],
#  [3, 'T123', 5, 7, 'Dosage', '1650 UNIT', '3-81'],
#  [3, 'T124', 7, 8, 'Route', 'IM', '3-81'],
#  [3, 'T125', 8, 11, 'Frequency', 'ONCE within 24-hours', '3-81'],
#  [3, 'T188', 15, 17, 'Drug', 'Rabies vaccine', '3-81'],
#  [3, 'T126', 18, 24, 'Duration', 'days 1, 3, 7 and 14', '3-81'],
#  [3, 'T67', 1, 2, 'Drug', 'clindamycin', '3-87'],
#  [3, 'T127', 11, 12, 'Reason', 'VRE', '3-88'],
#  [3, 'T44', 13, 14, 'Drug', 'Vancomycin', '3-88'],
#  [3, 'T68', 21, 22, 'Drug', 'zosyn', '3-88'],
#  [3, 'T7', 22, 23, 'Route', 'IV', '3-88'],
#  [3, 'T189', 1, 2, 'Reason', 'Prophylaxis', '3-92'],
#  [3, 'T15', 7, 8, 'Drug', 'Lovenox', '3-92'],
#  [3, 'T16', 8, 10, 'Strength', '40 mg', '3-92'],
#  [3, 'T128', 10, 11, 'Frequency', 'QD', '3-92'],
#  [3, 'T96', 12, 14, 'Reason', 'DVT prophylaxis', '3-92'],
#  [3, 'T26', 3, 4, 'Drug', 'allopurinol', '3-97'],
#  [3, 'T129', 4, 5, 'Strength', '100', '3-97'],
#  [3, 'T36', 6, 7, 'Drug', 'atenolol', '3-97'],
#  [3, 'T130', 7, 8, 'Strength', '50', '3-97'],
#  [3, 'T43', 9, 10, 'Drug', 'clobetasol', '3-97'],
#  [3, 'T131', 10, 11, 'Frequency', 'PRN', '3-97'],
#  [3, 'T45', 12, 13, 'Drug', 'finasteride', '3-97'],
#  [3, 'T132', 13, 14, 'Strength', '5', '3-97'],
#  [3, 'T51', 15, 16, 'Drug', 'furosemide', '3-97'],
#  [3, 'T133', 16, 17, 'Strength', '40', '3-97'],
#  [3, 'T134', 18, 19, 'Drug', 'Klor-Con', '3-97'],
#  [3, 'T52', 19, 20, 'Strength', '20meq', '3-97'],
#  [3, 'T71', 21, 22, 'Drug', 'omeprazole', '3-97'],
#  [3, 'T135', 22, 23, 'Strength', '20', '3-97'],
#  [3, 'T22', 24, 25, 'Drug', 'simvastatin', '3-97'],
#  [3, 'T136', 25, 26, 'Strength', '80', '3-97'],
#  [3, 'T75', 27, 28, 'Drug', 'terazosin', '3-97'],
#  [3, 'T137', 28, 29, 'Strength', '5', '3-97'],
#  [3, 'T79', 30, 31, 'Drug', 'warfarin', '3-97'],
#  [3, 'T138', 31, 32, 'Strength', '5', '3-97'],
#  [3, 'T139', 33, 34, 'Frequency', 'T,Sat', '3-97'],
#  [3, 'T140', 35, 36, 'Strength', '2.5', '3-97'],
#  [3, 'T141', 37, 38, 'Frequency', 'MWRFSun', '3-97'],
#  [3, 'T27', 28, 29, 'Drug', 'Acetaminophen', '3-120'],
#  [3, 'T28', 29, 31, 'Strength', '650 mg', '3-120'],
#  [3, 'T30', 31, 32, 'Route', 'PO', '3-120'],
#  [3, 'T29', 32, 33, 'Frequency', 'Q6H', '3-120'],
#  [3, 'T142', 6, 7, 'Drug', 'Albuterol', '3-124'],
#  [3, 'T143', 7, 8, 'Strength', '0.083%', '3-124'],
#  [3, 'T144', 8, 10, 'Form', 'Neb Soln', '3-124'],
#  [3, 'T145', 10, 11, 'Dosage', '1', '3-124'],
#  [3, 'T146', 11, 12, 'Form', 'NEB', '3-124'],
#  [3, 'T147', 12, 13, 'Route', 'IH', '3-124'],
#  [3, 'T148', 13, 14, 'Frequency', 'Q6H:PRN', '3-124'],
#  [3, 'T149', 14, 15, 'Reason', 'wheezes', '3-124'],
#  [3, 'T39', 10, 11, 'Drug', 'Allopurinol', '3-132'],
#  [3, 'T40', 11, 13, 'Strength', '100 mg', '3-132'],
#  [3, 'T42', 13, 14, 'Route', 'PO', '3-132'],
#  [3, 'T41', 14, 15, 'Frequency', 'BID', '3-132'],
#  [3, 'T47', 6, 7, 'Drug', 'Atenolol', '3-136'],
#  [3, 'T48', 7, 9, 'Strength', '50 mg', '3-136'],
#  [3, 'T50', 9, 10, 'Route', 'PO', '3-136'],
#  [3, 'T49', 10, 11, 'Frequency', 'BID', '3-136'],
#  [3, 'T57', 6, 8, 'Drug', 'Docusate Sodium', '3-140'],
#  [3, 'T59', 9, 10, 'Form', 'Liquid', '3-140'],
#  [3, 'T58', 11, 13, 'Strength', '100 mg', '3-140'],
#  [3, 'T61', 13, 14, 'Route', 'PO', '3-140'],
#  [3, 'T60', 14, 15, 'Frequency', 'BID:PRN', '3-140'],
#  [3, 'T150', 15, 16, 'Reason', 'constipation', '3-140'],
#  [3, 'T87', 9, 11, 'Drug', 'Enoxaparin Sodium', '3-146'],
#  [3, 'T88', 11, 13, 'Strength', '40 mg', '3-146'],
#  [3, 'T151', 13, 14, 'Route', 'SC', '3-146'],
#  [3, 'T152', 14, 16, 'Frequency', 'Q 24H', '3-146'],
#  [3, 'T76', 8, 9, 'Drug', 'Finasteride', '3-150'],
#  [3, 'T77', 9, 11, 'Strength', '5 mg', '3-150'],
#  [3, 'T78', 11, 12, 'Route', 'PO', '3-150'],
#  [3, 'T153', 12, 13, 'Frequency', 'DAILY', '3-150'],
#  [3, 'T19', 1, 3, 'Drug', 'FoLIC Acid', '3-154'],
#  [3, 'T20', 3, 5, 'Strength', '1 mg', '3-154'],
#  [3, 'T21', 5, 6, 'Route', 'PO', '3-154'],
#  [3, 'T154', 6, 7, 'Frequency', 'DAILY', '3-154'],
#  [3, 'T33', 7, 8, 'Drug', 'Thiamine', '3-158'],
#  [3, 'T34', 8, 10, 'Strength', '100 mg', '3-158'],
#  [3, 'T35', 10, 11, 'Route', 'PO', '3-158'],
#  [3, 'T155', 11, 12, 'Frequency', 'DAILY', '3-158'],
#  [3, 'T156', 6, 7, 'Drug', 'Senna', '3-162'],
#  [3, 'T157', 7, 8, 'Dosage', '1', '3-162'],
#  [3, 'T158', 8, 9, 'Form', 'TAB', '3-162'],
#  [3, 'T159', 9, 10, 'Route', 'PO', '3-162'],
#  [3, 'T160', 10, 11, 'Frequency', 'BID:PRN', '3-162'],
#  [3, 'T161', 11, 12, 'Reason', 'constipation', '3-162'],
#  [3, 'T62', 7, 8, 'Drug', 'Lansoprazole', '3-168'],
#  [3, 'T64', 8, 11, 'Form', 'Oral Disintegrating Tab', '3-168'],
#  [3, 'T63', 11, 13, 'Strength', '15 mg', '3-168'],
#  [3, 'T65', 13, 14, 'Route', 'PO', '3-168'],
#  [3, 'T162', 14, 15, 'Frequency', 'DAILY', '3-168'],
#  [3, 'T80', 9, 12, 'Drug', 'OxycoDONE (Immediate Release)', '3-173'],
#  [3, 'T163', 12, 14, 'Dosage', '5-10 mg', '3-173'],
#  [3, 'T82', 14, 15, 'Route', 'PO', '3-173'],
#  [3, 'T81', 15, 17, 'Frequency', 'Q4H :PRN', '3-173'],
#  [3, 'T164', 17, 18, 'Reason', 'pain', '3-173'],
#  [3, 'T4', 9, 10, 'Drug', 'Terazosin', '3-178'],
#  [3, 'T5', 10, 12, 'Strength', '5 mg', '3-178'],
#  [3, 'T6', 12, 13, 'Route', 'PO', '3-178'],
#  [3, 'T165', 13, 14, 'Frequency', 'HS', '3-178'],
#  [3, 'T9', 6, 7, 'Drug', 'Simvastatin', '3-182'],
#  [3, 'T10', 7, 9, 'Strength', '40 mg', '3-182'],
#  [3, 'T11', 9, 10, 'Route', 'PO', '3-182'],
#  [3, 'T166', 10, 11, 'Frequency', 'DAILY', '3-182'],
#  [3, 'T167', 6, 7, 'Drug', 'Multivitamins', '3-186'],
#  [3, 'T168', 7, 8, 'Dosage', '1', '3-186'],
#  [3, 'T169', 8, 9, 'Form', 'TAB', '3-186'],
#  [3, 'T170', 9, 10, 'Route', 'PO', '3-186'],
#  [3, 'T171', 10, 11, 'Frequency', 'DAILY', '3-186'],
#  [4, 'T82', 15, 16, 'Drug', 'Macrodantin', '4-0'],
#  [4, 'T83', 17, 18, 'Drug', 'Heparin', '4-0'],
#  [4, 'T104', 3, 5, 'Drug', 'vitamin K', '4-2'],
#  [4, 'T105', 5, 6, 'Strength', '10mg', '4-2'],
#  [4, 'T106', 6, 7, 'Route', 'SC', '4-2'],
#  [4, 'T108', 13, 14, 'Drug', 'octreotide', '4-2'],
#  [4, 'T109', 2, 4, 'Dosage', '2 units', '4-6'],
#  [4, 'T110', 4, 5, 'Drug', 'PRBC', '4-6'],
#  [4, 'T111', 6, 8, 'Reason', 'hct 25.9', '4-6'],
#  [4, 'T112', 9, 11, 'Dosage', '6 bags', '4-6'],
#  [4, 'T114', 12, 13, 'Drug', 'platelets', '4-6'],
#  [4, 'T118', 14, 17, 'Reason', 'platelets of 37K', '4-6'],
#  [4, 'T81', 5, 6, 'Drug', 'PRBC', '4-12'],
#  [4, 'T85', 5, 6, 'Drug', 'octreotide', '4-13'],
#  [4, 'T86', 7, 9, 'Duration', '7 day', '4-13'],
#  [4, 'T87', 11, 12, 'Drug', 'levofloxacin', '4-13'],
#  [4, 'T88', 13, 15, 'Reason', 'SBP prophylaxis', '4-13'],
#  [4, 'T89', 4, 5, 'Drug', 'lactulose', '4-17'],
#  [4, 'T90', 6, 7, 'Drug', 'rifaximin', '4-17'],
#  [4, 'T91', 8, 9, 'Reason', 'encephalopathy', '4-17'],
#  [4, 'T92', 9, 10, 'Drug', 'pentoxyfilline', '4-20'],
#  [4, 'T93', 11, 12, 'Drug', 'ursodiol', '4-20'],
#  [4, 'T94', 14, 17, 'Reason', 'acute alcoholic hepatitis', '4-20'],
#  [4, 'T95', 17, 18, 'Drug', 'Corticosteroids', '4-23'],
#  [4, 'T96', 1, 2, 'Drug', 'pentoxyfilline', '4-24'],
#  [4, 'T97', 3, 4, 'Drug', 'ursodiol', '4-24'],
#  [4, 'T98', 5, 6, 'Drug', 'octreotide', '4-26'],
#  ...]

# %%
(sents_dict)
# Out:
# {'0-0': 'Admission Date: [**2177-5-27**] Discharge Date: [**2177-5-29**] Date of Birth: [**2129-10-5**] Sex: F Service: MEDICINE Allergies: Zosyn / Quinolones / Ceftriaxone / Flagyl / Keppra / Lisinopril / Naprosyn Attending:[**First Name3 (LF) 562**] Chief Complaint: swelling of lips Major Surgical or Invasive Procedure: none History of Present Illness: 47F with asthma/COPD, atopic dermatitis, HTN on ACEI',
#  '0-9': 'She denies any wheezing, stridor, shortness of breath and states that has been on Lisinopril 20 mg',
#  '0-11': 'ENT tried scoping her to assess for vocal cord swelling, but she did not tolerate procedure secondarely to anxiety and dyscomfort',
#  '0-13': 'ER tried giving 5 mg of midazolam',
#  '0-15': 'Pt received 125 mg of IV solumedrol , 20 mg of IV famotidine , 25 mg of IV diphenydramine and epipen x 2',
#  '0-26': 'She is has a tough access and ER could only get a small IV in R forearm (that is why they gave epineprhine IM',
#  '0-28': 'She had been on an ACEI',
#  '0-29': 'There was no change in diet or specific trigger however it seems that she started Naprosyn',
#  '0-30': 'She was been seen by allergy for likely naproxen induced angioedema',
#  '0-32': 'She was started on steroids / antihistamines',
#  '0-34': 'Her ACE-i was stopped as well as Naproxen and NSAIDs',
#  '0-37': '#. Asthma',
#  '0-38': 'She was continued on Albuterol and on day of discharge Montelukast',
#  '0-40': '#. HTN - Pt on ACEI and beta-blocker',
#  '0-43': 'Her ace-inhibitor was held and her beta-blocker',
#  '0-45': '# seizure d/o: Patient was transitioned to Phenytoin IV while NPO and changed to PO',
#  '0-49': 'Code - Full code Medications on Admission: Quetiapine 25 mg PO QHS Citalopram 20 mg PO Daily Colace 100 mg PO B ID Atenolol 25 mg PO Daily Omeprazole 20 mg PO Daily Phenytoin 500 mg PO QHS Lisinopril 20 mg PO Daily Multivitamin PO Daily Motelukast 10 mg PO Daily Simethicone 80 mg PO Daily PRN cramps Thiamine 100 mg PO Daily Bisacodyl 5 mg PO PRN Constipation Senna 8.6 mg PO BID Albuterol 90 mcg PRN q4-6 hrs SOB / Wheezing',
#  '0-108': 'ALLERGIES: Piperacillin Sodium/Tazobactam : unknown Quinolones Ceftriaxone Metronidazole Levetiracetam',
#  '0-113': 'ALLERGIES: Piperacillin Sodium/Tazobactam: unknown Quinolones Ceftriaxone Metronidazole Levetiracetam Discharge Medications: 1. Quetiapine 25 mg Tablet Sig: One (1) Tablet PO QHS',
#  '0-120': '2. Citalopram 20 mg Tablet Sig: One (1) Tablet PO DAILY',
#  '0-127': '3. Colace 100 mg Capsule Sig: One (1) Capsule PO twice a day',
#  '0-134': '4. Omeprazole 20 mg Capsule, Delayed Release(E.C.) Sig: One (1) Capsule, Delayed Release(E.C.) PO once a day',
#  '0-141': '5. Phenytoin Sodium Extended 100 mg Capsule Sig: Five (5) Capsule PO QHS',
#  '0-148': '6. Multivitamin Capsule Sig: One (1) Capsule PO once a day',
#  '0-154': '7. Montelukast 10 mg Tablet Sig: One (1) Tablet PO DAILY',
#  '0-161': '8. Simethicone 80 mg Tablet, Chewable Sig: One (1) Tablet, Chewable PO once a day as needed for abdominal cramps',
#  '0-169': '9. Thiamine HCl 100 mg Tablet Sig: One (1) Tablet PO once a day',
#  '0-176': '10. Senna 8.6 mg Capsule Sig: One (1) Capsule PO twice a day as needed for constipation',
#  '0-184': '11. Bisacodyl 5 mg Tablet Sig: One (1) Tablet PO once a day as needed for constipation',
#  '0-192': '12. Oxycodone 5 mg Tablet Sig: One (1) Tablet PO Q6H (every 6 hours) as needed for pain',
#  '0-200': 'Disp:*15 Tablet(s)* Refills:*0* 13. Prednisone 20 mg Tablet Sig: Two (2) Tablet PO once a day for 3 days',
#  '0-208': 'Disp:*6 Tablet(s)* Refills:*0* 14. Tylenol 325 mg Tablet Sig: 1-2 Tablets PO every 4-6 hours as needed for pain',
#  '0-216': 'It was determined that you have angioedema',
#  '0-217': 'It may have been due to your Lisinopril or the Naprosyn',
#  '0-219': 'You should also avoid all NSAIDS including Motrin , Ibuprofen and Advil',
#  '0-223': 'You should CONTINUE taking: Quetiapine 25 mg at night Citalopram 20 mg daily Colace 100 mg twice a day Omeprazole 20 mg Daily Phenytoin 500 mg at night Multivitamin daily Motelukast 10 mg daily Simethicone 80 mg daily as needed for cramps Thiamine 100 mg daily Bisacodyl 5 mg as needed for constipation Senna 8.6 mg twice a day Albuterol 90 mcg every 4-6 hours as needed for wheezing You should STOP taking: Lisinopril Atenolol You should START taking: Prednisone 40mg daily for the next 3 days',
#  '0-266': 'You should CONTINUE taking: Quetiapine 25 mg at night Citalopram 20 mg daily Colace 100 mg twice a day Omeprazole 20 mg Daily Phenytoin 500 mg at night Multivitamin daily Motelukast 10 mg daily Simethicone 80 mg daily as needed for cramps Thiamine 100 mg daily Bisacodyl 5 mg as needed for constipation Senna 8.6 mg twice a day Albuterol 90 mcg every 4-6 hours as needed for wheezing You should STOP taking: Lisinopril Atenolol You should START taking: Prednisone 40mg daily for the next 3 days. Tylenol (Acetaminophen) as needed for pain',
#  '0-268': 'Tylenol (Acetaminophen) as needed for pain. Oxycodone 5mg every 6 hours as needed for pain',
#  '1-0': 'Admission Date: [**2109-1-20**] Discharge Date: [**2109-1-23**] Date of Birth: [**2023-8-19**] Sex: M Service: MEDICINE Allergies: Aspirin / NSAIDS Attending:[**First Name3 (LF) 2071**] Chief Complaint: NSTEMI Major Surgical or Invasive Procedure: Cardiac catherization Inferior Vena Cava Filter Placement (outside hospital) Aspirin Densensitazation History of Present Illness: Mr. [**Known firstname 90223**] is a 85-year-old male with CAD s/p PTCA LCx ([**2092**]), HLD, AAA, PE, PAD, COPD that was transferred to [**Hospital1 18**] for c. cath with complicated OSH course consisting of anemia secondary to GIB, bilateral PE not on anticoagulation',
#  '1-4': 'Pt is transferred to the CCU prior to cardiac cath for ASA',
#  '1-5': '[**Name2 (NI) **] oximetry was in the low 80s at home responsive to home O2 via NC',
#  '1-7': 'He was transfused 3 units of pRBC',
#  '1-9': 'The patient was also treated for pneumonia although viral URI was favored with fever 100.2 in setting of chronic prednisone',
#  '1-11': 'He was treated with moxifloxacin 400 mg PO qD for a 10-day',
#  '1-16': 'Pt describes an ASA allergy consisting of redness on his face , and rash',
#  '1-19': 'Past Medical History: - CAD s/p MI in [**2092**] with PTCA to of Lcx - bilateral pulmonary embolism s/p IVC filter placement ([**2109-1-10**]) with prior history of PE 1 year ago (previously treated with Coumadin',
#  '1-21': 'He was transferred to [**Hospital1 18**] for consideration of cardiac catherization, but first required aspirin desensitization as has documented aspirin',
#  '1-23': 'Left cardiac ICU after aspirin',
#  '1-24': '* Medical management with Atorvastatin 80 mg qhs , Carvedilol 6.25 mg PO BID , ASA 325 mg PO qday , Captopril 12.5 mg TID',
#  '1-38': '* [**Month (only) 116**] want to switch short acting captopril to longer acting lisinopril',
#  '1-40': '* Continued medical management with Captopril 12.5 mg PO TID , Carvedilol 6.25 mg PO BID',
#  '1-48': '[**Month (only) 116**] want to change short acting captopril to longer acting lisinopril',
#  '1-50': '* Deferred use of spironolactone as borderline hyperkalemia',
#  '1-52': 'Had heparin gtt',
#  '1-54': 'Discharged with 10 days worth of enoxaparin injections with bridging therapy with coumadin to treat PE',
#  '1-59': '* Follow up CBC/ Coag panel * Discuss with patient duration of anticoagulation',
#  '1-60': '* Need to follow-up final pathology of polyp from OSH * Check CBC on follow up COPD',
#  '1-61': 'Discharged home on albuterol and tiotropium',
#  '1-63': 'Additionally, at OSH was treated with a 10-day course of avelox for low grade fever low grade fever in setting of prednisone usage with no infiltrate on CXR or CT. * continued albuterol / tiotropium',
#  '1-70': "* Follow up LFT's as an outpateint CHRONIC ISSUES Temporal arteritis",
#  '1-71': 'Continued prednisone 10mg daily',
#  '1-74': 'Patient counseled on necessity of continuing aspirin',
#  '1-75': 'Home medications Plavix 75 mg PO qD Diltiazem 180 mg PO qD Zetia 10 mg PO qD Simvastatin 20 mg PO qD Prednisone 10 mg PO qD Iron supplement nitro SL prn',
#  '1-100': 'Medications on transfer to [**Hospital1 **] Plavix 75 mg PO daily Zetia 10 mg PO daily Simvastatin 20 mg PO daily Captopril 12.5 mg PO TID Carvedilol 6.25 mg PO BID Nitroglycerin 0.1 mg/hr (2.5 mg) TD qHS Prednisone 10 mg PO qD',
#  '1-128': 'ALLERGIES: SEVERE ALLERGY TO ASPIRIN --> rash , redness on face Discharge Medications: 1. acetaminophen 325 mg Tablet Sig: One (1) Tablet PO Q6H (every 6 hours) as needed for pain',
#  '1-139': '2. carvedilol 3.125 mg Tablet Sig: Two (2) Tablet PO BID',
#  '1-146': 'Disp:*120 Tablet(s)* Refills:*0* 3. warfarin 1 mg Tablet Sig: Three (3) Tablet PO Once Daily at 4 PM',
#  '1-153': 'Disp:*30 Tablet(s)* Refills:*0* 4. captopril 12.5 mg Tablet Sig: One (1) Tablet PO three times a day',
#  '1-160': 'Disp:*90 Tablet(s)* Refills:*0* 5. atorvastatin 80 mg Tablet Sig: One (1) Tablet PO DAILY',
#  '1-167': 'Disp:*30 Tablet(s)* Refills:*0* 6. prednisone 5 mg Tablet Sig: Two (2) Tablet PO DAILY',
#  '1-174': '7. aspirin 325 mg Tablet Sig: One (1) Tablet PO DAILY',
#  '1-181': '8. albuterol sulfate 90 mcg/Actuation HFA Aerosol Inhaler Sig: One (1) Inhalation PRN as needed for shortness of breath or wheezing',
#  '1-188': 'Disp:*1 inhaler* Refills:*0* 9. tiotropium bromide 18 mcg Capsule, w/Inhalation Device Sig: One (1) Inhalation at bedtime',
#  '1-194': 'Disp:*1 inhaler* Refills:*0* 10. omeprazole 20 mg Capsule, Delayed Release(E.C.) Sig: One (1) Capsule, Delayed Release(E.C.) PO DAILY',
#  '1-201': ')(s)* Refills:*0* 11. enoxaparin 60 mg/0.6 mL Syringe Sig: One (1) Subcutaneous twice a day for 10 days',
#  '1-208': 'Disp:*20 syringes* Refills:*0* 12. nitroglycerin 0.4 mg Tablet , Sublingual Sig: One (1) Sublingual PRN as needed for chest pain',
#  '1-216': 'This is a procedure where a catheter is inserted in the large vessel in your groin, and wired to the heart. Dye was injected',
#  '1-218': 'The first medication is called " Lovenox " or " Enoxaparin',
#  '1-220': 'It is injection you give yourself twice a day',
#  '1-222': 'The second drug is called " Warfarin " or " Coumadin',
#  '1-224': 'It is a pill',
#  '1-225': 'As warfarin takes some time to work, it is important you take enoxaparin in the interim to help keep your [**Name5 (PTitle) **] thin while warfarin',
#  '1-228': 'Please use the enoxaparin injections for 10 days',
#  '1-231': 'Your were "desensitzed" to Aspirin',
#  '1-232': 'HOWEVER if you miss even a single dose please call your PCP to discuss whether or not he wants you to take the next dose BEFORE you take it. Acetaminophen 325 mg Tablet 1 Tablet by mouth every 6 hours as needed for pain',
#  '1-240': 'Acetaminophen 325 mg Tablet 1 Tablet by mouth every 6 hours as needed for pain. Carvedilol 3.125 mg Tablet 2 Tablets by mouth [**Hospital1 **] 2 times a day Warfarin 1 mg Tablet 3 Tablets by mouth once Daily at 4 PM',
#  '1-254': 'Carvedilol 3.125 mg Tablet 2 Tablets by mouth [**Hospital1 **] 2 times a day Warfarin 1 mg Tablet 3 Tablets by mouth once Daily at 4 PM. Captopril 12.5 mg Tablet 1 Tablet by mouth three times a day',
#  '1-261': 'Captopril 12.5 mg Tablet 1 Tablet by mouth three times a day. Atorvastatin 80 mg Tablet 1 Tablet by mouth at night Prednisone 5 mg Tablet 2 Tablet by mouth DAILY Aspirin 325 mg Tablet 1 tablet by mouth daily Omeprazole 20 mg tablet 1 tablet by mouth daily Albuterol sulfate 90 mcg/Actuation HFA Aerosol Inhaler 1 Inhalation as needed for shortness of breath or wheezing',
#  '1-296': 'Atorvastatin 80 mg Tablet 1 Tablet by mouth at night Prednisone 5 mg Tablet 2 Tablet by mouth DAILY Aspirin 325 mg Tablet 1 tablet by mouth daily Omeprazole 20 mg tablet 1 tablet by mouth daily Albuterol sulfate 90 mcg/Actuation HFA Aerosol Inhaler 1 Inhalation as needed for shortness of breath or wheezing. Tiotropium bromide 18 mcg Capsule, w/Inhalation Device 1 Inhalation at bedtime',
#  '1-302': 'Tiotropium bromide 18 mcg Capsule, w/Inhalation Device 1 Inhalation at bedtime. Enoxaparin 60 mcg 1 injection 2x a day for 10 days Nitroprusside 0.4 sublingual as needed for chest pain',
#  '2-0': '- Peripheral vascular disease - Gout vs. osteoarthritis , given Indomethacin treatment and complaint of chronic severe knee pain',
#  '2-4': 'Pertinent Results: [**2167-11-27**] 05:00PM CK(CPK)-257 [**2167-11-27**] 05:00PM CK-MB-3 cTropnT-0.03* [**2167-11-27**] 09:01AM GLUCOSE-362* UREA N-24* CREAT-1.8* SODIUM-135 POTASSIUM-4.4 CHLORIDE-101 TOTAL CO2-27 ANION GAP-11 [**2167-11-27**] 09:01AM estGFR-Using this [**2167-11-27**] 09:01AM cTropnT-0.03* [**2167-11-27**] 09:01AM CALCIUM-8.9 PHOSPHATE-3.9 MAGNESIUM-2.1 [**2167-11-27**] 09:01AM ASA -NEG ETHANOL-NEG ACETMNPHN -NEG bnzodzpn -NEG barbitrt -NEG tricyclic -NEG [**2167-11-27**] 09:01AM URINE HOURS-RANDOM [**2167-11-27**] 09:01AM URINE bnzodzpn -NEG barbitrt -NEG opiates -NEG cocaine-NEG amphetmn -NEG mthdone -NEG [**2167-11-27**] 09:01AM WBC-13.1* RBC-4.78 HGB-14.3 HCT-41.3 MCV-87 MCH-30.0 MCHC-34.7 RDW-13.5 [**2167-11-27**] 09:01AM NEUTS-87.7* LYMPHS-8.4* MONOS-2.5 EOS-0.8 BASOS-0.6 [**2167-11-27**] 09:01AM PLT COUNT-266 [**2167-11-27**] 09:01AM PT-11.4 PTT-21.7* INR(PT)-0.9 [**2167-11-27**] 09:01AM URINE COLOR-Yellow APPEAR-Clear SP [**Last Name (un) 155**]-1.027 [**2167-11-27**] 09:01AM URINE BLOOD-SM NITRITE-NEG PROTEIN-500 GLUCOSE-1000 KETONE-NEG BILIRUBIN-NEG UROBILNGN-NEG PH-6.5 LEUK-NEG [**2167-11-27**] 09:01AM URINE RBC-0-2 WBC-0-2 BACTERIA-OCC YEAST-NONE EPI-0 [**2167-11-27**] 09:01AM URINE AMORPH-FEW [**2167-11-27**] 09:01AM URINE MUCOUS-FEW [**Known lastname **],[**Known firstname 20**] [**Medical Record Number 88116**] M 52 [**2115-10-30**] Radiology Report CT HEAD W/O CONTRAST Study Date of [**2167-11-27**] 9:31 AM [**Last Name (LF) **],[**First Name3 (LF) 488**] EU [**2167-11-27**] 9:31 AM CT HEAD W/O CONTRAST',
#  '2-16': 'CONTRAINDICATIONS FOR IV CONTRAST',
#  '2-18': 'TECHNIQUE: Contiguous axial images were obtained through the brain without intravenous contrast',
#  '2-20': 'DR. [**First Name (STitle) 251**] [**Name (STitle) 8580**] DR. [**First Name11 (Name Pattern1) **] [**Initial (NamePattern1) **] [**Last Name (NamePattern4) 7411**] Approved: FRI [**2167-11-27**] 12:47 PM [**Known lastname **],[**Known firstname 20**] [**Medical Record Number 88116**] M 52 [**2115-10-30**] Radiology Report CT HEAD W/O CONTRAST Study Date of [**2167-12-5**] 6:23 PM [**Last Name (LF) 162**],[**First Name3 (LF) **] NMED FA11 [**2167-12-5**] 6:23 PM CT HEAD W/O CONTRAST Clip # [**Clip Number (Radiology) 88118**] Reason: interval change [**Hospital 93**] MEDICAL CONDITION: 52 year old man with known IV and IP hemorrhage with worsening MS REASON FOR THIS EXAMINATION: interval change CONTRAINDICATIONS FOR IV CONTRAST',
#  '2-24': 'EXAMINATION: CT of the head without intravenous contrast',
#  '2-26': 'No intravenous contrast',
#  '2-28': 'DR. [**First Name (STitle) **] LI DR. [**First Name (STitle) 10627**] PERI Approved: SUN [**2167-12-6**] 12:13 PM Brief Hospital Course: 52yo man with longstanding HTN and [**Hospital **] transferred from [**Hospital1 **] with intracranial hemorrhage, suspected secondary to hypertensive crisis',
#  '2-29': 'The size of his bleed, the need for frequent neuro checks, and his need for antihypertensives via continuous drip',
#  '2-32': 'the acute-on-chronic renal failure, and recommended discontinuing his NSAIDs (taken for ? gout',
#  '2-34': "Continued issues were blood glucose control (managed with insulin sliding-scale ) and acute renal failure acute renal failure (initially ~2.0 and steady, but then up to 2.7 in the setting of UTI and Cipro Tx, all above a reported baseline CKD/Cr 1.5), despite IVF and holding the patient's previous indomethacin",
#  '2-42': 'On the floor, he became more confused and febrile, and was found to have a gram-negative UTI',
#  '2-43': 'Initially, he was treated empirically with ciprofloxacin , but this worsened his renal failure , and the patient became febrile and somnolent / lethargic , so he was switched to IV vancomycin and Zosyn ( vancomycin',
#  '2-52': 'This UCx ultimately speciated a pan-sensitive [**Last Name (LF) 88119**], [**First Name3 (LF) **] on [**12-8**] (day of discharge) after 3.5d of treatment with IV Zosyn , he was switched to PO Bactrim , plan to finish a 7-8d course for complicated (male) UTI',
#  '2-59': 'Fever defervesced rapidly and mental status improved markedly 1-2d after starting IV antibiotics',
#  '2-61': 'Blood cultures and a repeat UCx on [**12-5**] (after first dose of Cipro',
#  '2-62': 'His FSBG were in good control (120-150) on increased dosing of SSI',
#  '2-63': "Plan: -follow up in Neurology/[**Hospital 4038**] clinic with Dr. [**First Name8 (NamePattern2) **] [**Name (STitle) **] (see discharge information) -arrange follow-up with patient's PCP and if PCP agrees, consider starting him with Nephrology outpatient follow-up in the near future (chronic kidney disease and now recovering from acute renal failure and UTI) -finish 3.5 days more of [**Hospital1 **] Bactrim DS 1 tab PO for complicated UTI -continue medication regimen (excluding NSAID ) as listed below Medications on Admission: - Indomethacin 50mg [**Hospital1 **] - Tylenol with Codeine prn - Lipitor 20mg qDay - HCTZ 25mg qDay - Naprocen 500mg [**Hospital1 **] (scheduled) - Insulin 55 units qAM , usually 55 units qPM",
#  '2-87': "Plan: -follow up in Neurology/[**Hospital 4038**] clinic with Dr. [**First Name8 (NamePattern2) **] [**Name (STitle) **] (see discharge information) -arrange follow-up with patient's PCP and if PCP agrees, consider starting him with Nephrology outpatient follow-up in the near future (chronic kidney disease and now recovering from acute renal failure and UTI) -finish 3.5 days more of [**Hospital1 **] Bactrim DS 1 tab PO for complicated UTI -continue medication regimen (excluding NSAID) as listed below Medications on Admission: -Indomethacin 50mg [**Hospital1 **] -Tylenol with Codeine prn -Lipitor 20mg qDay -HCTZ 25mg qDay -Naprocen 500mg [**Hospital1 **] (scheduled) -Insulin 55 units qAM, usually 55 units qPM (does not give evening dose if glucose is not elevated). SSI Discharge Medications: 1. atorvastatin 20 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)",
#  '2-95': '2. glucagon (human recombinant) 1 mg Recon Soln Sig: One (1) Recon Soln Injection Q15MIN () as needed for hypoglycemia protocol',
#  '2-102': '3. senna 8.6 mg Tablet Sig: One (1) Tablet PO BID (2 times a day)',
#  '2-109': '4. docusate sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)',
#  '2-116': '5. bisacody l 5 mg Tablet, Delayed Release (E.C.) Sig: Two (2) Tablet , Delayed Release (E.C.) PO DAILY (Daily) as needed for constipation',
#  '2-124': '6. heparin (porcine) 5,000 unit /mL Solution Sig: One (1) Injection TID (3 times a day) : for DVT prophylaxis',
#  '2-131': '7. calcium carbonate 200 mg ( 500 mg ) Tablet, Chewable Sig: One (1) Tablet , Chewable PO QID (4 times a day) as needed for indigestion',
#  '2-140': '8. metoprolol tartrate 25 mg Tablet Sig: One (1) Tablet PO TID (3 times a day)',
#  '2-147': '9. amlodipine 5 mg Tablet Sig: Two (2) Tablet PO HS (at bedtime)',
#  '2-154': '10. acetaminophe n 325 mg Tablet Sig: One (1) Tablet PO Q6H (every 6 hours) as needed for Pain',
#  '2-162': '11. famotidin e 20 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '2-169': '12. sulfamethoxazole -trimethoprim 800-160 mg Tablet Sig: One (1) Tablet PO BID (2 times a day) as needed for Urianary tract infection',
#  '2-177': '13. dextrose 50% in water (D50W) Syringe Sig: One (1) Intravenous PRN (as needed) as needed for hypoglycemia protocol',
#  '2-183': '14. insulin regular human 100 unit /mL (3 mL) Insulin Pen Insulin Pen Sig: One (1) Subcutaneous four times a day : Per sliding-scale insulin regimen for insulin -dependent diabetes mellitus',
#  '2-193': 'Your kidneys, which were already chronically damaged, were also injured, at least in part due to the painkiller medicines (indomethacin and naprosyn) that you were taking every day',
#  '2-195': 'This was also related to a urinary tract infection you developed here in the hospital, which is being treated by antibiotic medication that will continue for 3 more days',
#  '3-0': 'Admission Date: [**2191-6-24**] Discharge Date: [**2191-7-13**] Date of Birth: [**2107-6-14**] Sex: M Service: PLASTIC Allergies: aspirin',
#  '3-1': 'A&O on presentation, HD stable, h/o afib on coumadin',
#  '3-3': 'Past Medical History: PMH: Afib on coumadin , Gout , chronic kidney disease, HTN , Chronic dermatitis , BPH, Esophagitis',
#  '3-9': "Home medications: allopurinol 100 '', atenolol 50 '', clobetasol PRN , finasteride 5 , furosemide 40 , Klor-Con 20meq , omeprazole 20 , simvastatin 80 , terazosin 5 , warfarin 5 ( T,Sat )/ 2.5 ( MWRFSun",
#  '3-32': 'DR. [**Last Name (STitle) 4091**] [**3-/4952**] REQUESTED Daptomycin',
#  '3-33': 'SENSITIVE TO Daptomycin ( 3.0 MCG /ML',
#  '3-35': 'Fluoroscopic images of the left forearm demonstrate contrast',
#  '3-36': 'At times he was A+Ox3 but at other times confused',
#  '3-37': 'Geriatric team felt fluctuations in mental status were multifactorial and related to trauma, de-conditioning, ICU stay, sleep deprivation, pain medications',
#  '3-38': 'He was on fentanyl and propofol for pain control and sedation',
#  '3-42': 'When he was awake and extubated, his pain was controlled with IV dilaudid for dressing changes and oxycodone for complaints of pain in between',
#  '3-48': 'Cardiovascular: He did not require vasopressors',
#  '3-49': 'His coumadin was held during this admission and he was prophylactically anticoagulated with once daily lovenox injections',
#  '3-54': 'Heme: Patient required multiple blood product transfusions during his ICU stay due to loss of blood',
#  '3-58': 'Geriatrics recommended starting patient on thiamine , folate and MVI for h/o heavy EtOH',
#  '3-62': 'He was ordered for albuterol nebulizer treatments PRN for wheezes',
#  '3-66': 'Patient received isosource 1.5 with a goal rate of 60 cc / hr',
#  '3-70': 'His electrolytes were repleted PRN',
#  '3-72': 'He was given lasix / albumin to assist with his edema',
#  '3-75': 'ID: He was initially started on broad spectrum antibiotics , vanc / zosyn / clinda',
#  '3-79': 'Infectious Disease was consulted on [**2191-6-25**] to help with antibiotic guidance and postexposure rabies vaccinations',
#  '3-81': 'Patient received Rabies Immune Globulin 1650 UNIT IM ONCE within 24-hours of arrival and then Rabies vaccine on days 1, 3, 7 and 14',
#  '3-87': 'The clindamycin',
#  '3-88': 'A tissue sample obtained in the OR from left elbow grew VRE so Vancomycin was discontinued and patient was maintained on zosyn IV',
#  '3-92': '. Prophylaxis : Patient was maintained on Lovenox 40 mg QD for DVT prophylaxis',
#  '3-97': "Medications on Admission: allopurinol 100 '', atenolol 50 '', clobetasol PRN , finasteride 5 , furosemide 40 , Klor-Con 20meq , omeprazole 20 , simvastatin 80 , terazosin 5 , warfarin 5 ( T,Sat )/ 2.5 ( MWRFSun",
#  '3-120': "Medications on Admission: allopurinol 100'', atenolol 50'', clobetasol PRN, finasteride 5, furosemide 40, Klor-Con 20meq, omeprazole 20, simvastatin 80, terazosin 5, warfarin 5 (T,Sat)/2.5 (MWRFSun) Discharge Medications: 1. Acetaminophen 650 mg PO Q6H",
#  '3-124': 'Acetaminophen 650 mg PO Q6H 2. Albuterol 0.083% Neb Soln 1 NEB IH Q6H:PRN wheezes',
#  '3-132': 'Albuterol 0.083% Neb Soln 1 NEB IH Q6H:PRN wheezes 3. Allopurinol 100 mg PO BID',
#  '3-136': 'Allopurinol 100 mg PO BID 4. Atenolol 50 mg PO BID',
#  '3-140': 'Atenolol 50 mg PO BID 5. Docusate Sodium ( Liquid ) 100 mg PO BID:PRN constipation',
#  '3-146': 'Docusate Sodium (Liquid) 100 mg PO BID:PRN constipation 6. Enoxaparin Sodium 40 mg SC Q 24H',
#  '3-150': 'Enoxaparin Sodium 40 mg SC Q 24H 7. Finasteride 5 mg PO DAILY',
#  '3-154': '8. FoLIC Acid 1 mg PO DAILY',
#  '3-158': 'FoLIC Acid 1 mg PO DAILY 9. Thiamine 100 mg PO DAILY',
#  '3-162': 'Thiamine 100 mg PO DAILY 10. Senna 1 TAB PO BID:PRN constipation',
#  '3-168': 'Senna 1 TAB PO BID:PRN constipation 11. Lansoprazole Oral Disintegrating Tab 15 mg PO DAILY',
#  '3-173': 'Lansoprazole Oral Disintegrating Tab 15 mg PO DAILY 12. OxycoDONE (Immediate Release) 5-10 mg PO Q4H :PRN pain',
#  '3-178': 'OxycoDONE (Immediate Release) 5-10 mg PO Q4H:PRN pain 13. Terazosin 5 mg PO HS',
#  '3-182': 'Terazosin 5 mg PO HS 14. Simvastatin 40 mg PO DAILY',
#  '3-186': 'Simvastatin 40 mg PO DAILY 15. Multivitamins 1 TAB PO DAILY',
#  '4-0': 'Admission Date: [**2140-7-16**] Discharge Date: [**2140-8-5**] Date of Birth: [**2095-12-26**] Sex: F Service: MEDICINE Allergies: Macrodantin / Heparin',
#  '4-2': 'Pt was given vitamin K 10mg SC and was admitted and started on octreotide',
#  '4-6': 'Pt received 2 units PRBC for hct 25.9 and 6 bags of platelets for platelets of 37K',
#  '4-12': 'Pt was given 4 units PRBC',
#  '4-13': 'Completed 5 day course of octreotide and 7 day course of levofloxacin for SBP prophylaxis',
#  '4-17': 'She was treated with lactulose and rifaximin for encephalopathy',
#  '4-20': 'Given rising bili/INR, she was given a trial of pentoxyfilline and ursodiol for suspected acute alcoholic hepatitis',
#  '4-23': 'Given rising bili/INR, she was given a trial of pentoxyfilline and ursodiol for suspected acute alcoholic hepatitis. Corticosteroids',
#  '4-24': 'Her pentoxyfilline and ursodiol',
#  '4-26': 'She was started empirically on octreotide / midodrine for possible hepatorenal syndrome',
#  '4-29': 'Nephrotoxic medications were held and she was given volume repletion both with normal saline and albumin',
#  '4-32': 'MELD at time of discharge was 33, driven by a bilirubin of 19.8, creatinine of 1.4, and an INR of 2.9. . Diuretics',
#  '4-33': '# Acute renal insufficiency : As outlined above, developed rising creatinine, initially concerning for hepatorenal syndrome',
#  '4-35': 'Started empirically on midodrine / octreotide',
#  '4-37': 'She was repleted with IV fluids',
#  '4-39': 'Initially started on Zosyn and Vancomycin as well as Levaquin for concern for infectious etiology , however antibiotics',
#  '4-44': '# DM II : On Metformin',
#  '4-46': 'Covered as inpatient on sliding scale insulin and glargine',
#  '4-49': 'Discharged on glargine 24units /night , and the patient demonstrated how to use SSI',
#  '4-53': 'Discharged on glargine 24units/night, and the patient demonstrated how to use SSI at home. Metformin and alternative oral hypoglycemics',
#  '4-56': 'All heparin',
#  '4-57': 'Medications on Admission: MEDS at home: metformin 500',
#  '4-59': 'MEDS on Transfer: Protonix 40mg IV BID MVI po daily Thiamine 100mg qday Folate i mg po daily nicotine patch 14gm qday nadolol 20mg qday oxazepam q2 prn for agitation per CIWA [**6-18**] 10mg 13-20 20mg Octreotide gtt',
#  '4-85': 'MEDS on Transfer: Protonix 40mg IV BID MVI po daily Thiamine 100mg qday Folate i mg po daily nicotine patch 14gm qday nadolol 20mg qday oxazepam q2 prn for agitation per CIWA [**6-18**] 10mg 13-20 20mg Octreotide gtt Discharge Medications: 1. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)',
#  '4-92': 'Disp:*90 Capsule(s)',
#  '4-93': 'Disp:*90 Capsule(s)* Refills:*2* 2. Folic Acid 1 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '4-100': 'Disp:*90 Tablet(s)',
#  '4-101': 'Disp:*90 Tablet(s)* Refills:*2* 3. Thiamine HCl 100 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '4-108': 'Disp:*90 Tablet(s)',
#  '4-109': 'Disp:*90 Tablet(s)* Refills:*2* 4. Pantoprazole 40 mg Tablet, Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q12H (every 12 hours)',
#  '4-116': 'Disp:*90 Tablet, Delayed Release (E.C.)',
#  '4-117': ')(s)* Refills:*2* 5. Lactulose 10 g/15 mL Syrup Sig: Thirty (30) ML PO TID (3 times a day)',
#  '4-123': 'Disp:*2700 ML(s)* Refills:*2* 6. Miconazole Nitrate 2 % Powder Sig: One (1) Appl Topical TID (3 times a day) as needed',
#  '5-0': 'Admission Date: [**2109-6-2**] Discharge Date: [**2109-6-8**] Date of Birth: [**2089-4-1**] Sex: M Service: SURGERY Allergies: No Known Allergies / Adverse Drug Reactions Attending:[**First Name3 (LF) 598**] Chief Complaint: Trauma: stab wound Major Surgical or Invasive Procedure: [**2109-6-2**] Trauma ex-lap, repair gastric perforation History of Present Illness: History Present Illness: 22M s/p stab to LUQ w/ 6" knife w/ large hematemesis ~2-3L, brought into ED via [**Location (un) **], received 2 units RBC , hemodynamically stable, intubated w/ more hematemesis post-intubation, additional 3units RBCs',
#  '5-4': 'During his operative course, he had a 500cc blood loss and received 1 U PRBC',
#  '5-7': 'His incisional pain was managed with a morphine PCA and changed to a dilaudid PCA because of reports of nausea',
#  '5-13': 'He had been out of bed.His diet was slowly advanced which he tolerated well.His diet was advanced to regular and he was started on oral pain meds',
#  '5-15': 'Medications on Admission: none Discharge Medications: 1. docusate sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)',
#  '5-22': '2. nicotine 14 mg /24 hr Patch 24 hr Sig: One (1) Patch 24 hr Transdermal DAILY (Daily)',
#  '5-29': '3. oxycodone 5 mg Tablet Sig: 1-2 Tablets PO Q4H (every 4 hours) as needed for pain',
#  '5-37': 'Disp:*30 Tablet(s)* Refills:*0* 4. acetaminophe n 325 mg Tablet Sig: One (1) Tablet PO Q6H (every 6 hours) as needed for pain',
#  '5-45': '5. pantoprazol e 40 mg Tablet, Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q24H (every 24 hours)',
#  '6-0': 'Admission Date: [**2193-7-28**] Discharge Date: [**2193-8-4**] Date of Birth: [**2140-11-9**] Sex: M Service: MEDICINE Allergies: Patient recorded as having No Known Allergies to Drugs Attending:[**First Name3 (LF) 348**] Chief Complaint: Hemoptysis Major Surgical or Invasive Procedure: endotracheal intubation femoral line placement bronchoscopy right bronchial artery embolization History of Present Illness: 52M w/ hx of treated TB (3 years ago, in [**Country 651**], 3 meds , cannot recall names, treated for 9 mos',
#  '6-3': 'SENSITIVITIES: MIC expressed in MCG/ML _________________________________________________________ STAPH AUREUS COAG + | CLINDAMYCIN -----------<=0.25 S ERYTHROMYCIN ----------<=0.25 S GENTAMICIN ------------ <=0.5 S LEVOFLOXACIN ---------- 0.25 S OXACILLIN ------------- 0.5 S TRIMETHOPRIM /SULFA',
#  '6-9': 'Pulmonary was consulted, and he was started on Ceftriaxone / Azithromycin empirically for CAP',
#  '6-12': 'He remained stable and was extubated on [**8-2**]. Ceftriaxone was replaced with Cefpodoxime',
#  '6-14': '# Elevated creatinine Elevated creatinine - He also had mild renal insufficiency which was likely secondary to contrast nephropathy',
#  '6-18': 'The patient was transferred to the medical floor on [**2193-8-3**], and his creatinine normalized with IV fluids',
#  '6-20': 'He was discharged on [**2193-8-4**] and will complete a 7 day course of both azithromycin and cefpodoxime',
#  '6-23': 'Medications on Admission: Patient takes no medications regularly Discharge Medications: 1. Cefpodoxime 100 mg Tablet Sig: Two (2) Tablet PO Q12H (every 12 hours) for 3 days',
#  '6-31': 'Disp:*10 Tablet (s)',
#  '6-32': 'Disp:*10 Tablet(s)* Refills:*0* 2. Azithromycin 250 mg Tablet Sig: One (1) Tablet PO once a day for 2 days',
#  '6-40': 'Disp:*2 Tablet(s) * Refills:*0* Discharge Disposition: Home Discharge Diagnosis: Primary Diagnosis: hemoptysis pneumonia Secondary Diagnoses: history of tuberculosis , treated with three drug',
#  '6-43': 'You were treated for a pneumonia with antiobiotics',
#  '6-45': 'you will continue taking two antibiotics : cefpodoxim e 200 mg twice a day for two days , finish on Tuesday azithromyci n 250 mg once a day for two days',
#  '7-0': 'Admission Date: [**2185-9-30**] Discharge Date: [**2185-10-4**] Date of Birth: [**2132-4-26**] Sex: M Service: MEDICINE Allergies: Penicillins / Terazosin Attending:[**Last Name (NamePattern4) 290**] Chief Complaint: BRBPR Major Surgical or Invasive Procedure: angiography EGD colonoscopy intubation central line placement History of Present Illness: 54 y/o with with Afib on coumadin',
#  '7-4': 'Denies use of NSAIDs',
#  '7-5': 'At [**Hospital1 **] he received 3 units of RBC , 3 Unit FFP , and 10mg of Vit K',
#  '7-10': 'In the ED the patient got 4 RBC , 2 FFP , 1 plt , and 5000U of Factor IX',
#  '7-18': 'Of note the patient was recently admitted at [**Hospital3 3765**] from [**2185-8-8**] to [**2185-8-22**] for severe cellulits c /w septic shock , treated with Levo , clindamycin , and cephalexin',
#  '7-23': 'He has been of all abx for approximately 3 weeks',
#  '7-24': 'Past Medical History: Afib on coumadin',
#  '7-26': 'Family History: NC Physical Exam: Vitals: T: 98.5 BP: 102/49 P: 111 R: 25 18 O2: 100% on 2L NC',
#  '7-27': 'Pertinent Results: Last set of labs: [**2185-10-4**] 03:20PM BLOOD WBC-16.9* RBC-3.35* Hgb-10.1* Hct-30.9* MCV-93 MCH-30.3 MCHC-32.7 RDW-17.8* Plt Ct-161 [**2185-10-4**] 12:24PM BLOOD Neuts-30* Bands-63* Lymphs-4* Monos-0 Eos-0 Baso-0 Atyps-0 Metas-2* Myelos-1* NRBC-1* [**2185-10-4**] 12:24PM BLOOD PT-19.7* PTT-47.0* INR(PT)-1.8* [**2185-10-4**] 03:20PM BLOOD Glucose-43* UreaN-56* Creat-2.1* Na-133 K-4.1 Cl-99 HCO3-18* AnGap-20 [**2185-10-4**] 02:51AM BLOOD ALT-16 AST-25 AlkPhos-84 TotBili-9.6* DirBili-7.8* IndBili-1.8 [**2185-10-4**] 03:20PM BLOOD Calcium-8.1* Phos-3.4 Mg-2.0 [**2185-10-4**] 03:25PM BLOOD Type-ART pO2-143* pCO2-42 pH-7.27* calTCO2-20* Base XS--7 [**2185-10-4**] 03:25PM BLOOD Glucose-50* Lactate-6.6* Na-129* K-4.0 Cl-99* [**2185-10-4**] 12:15AM URINE Color-Amber Appear-Cloudy Sp [**Last Name (un) **]-1.024 [**2185-10-4**] 12:15AM URINE Blood-LG Nitrite-NEG Protein-150 Glucose-NEG Ketone-TR Bilirub-MOD Urobiln-NEG pH-6.5 Leuks-MOD [**2185-10-4**] 12:15AM URINE RBC->50 WBC-21-50* Bacteri-MANY Yeast-NONE Epi-0-2 MICRO: [**10-3**] BCx: GNR Brief Hospital Course: Mr. [**Known lastname **] is a 53 year old man with h/o CHF, afib on Coumadin , who was transferred from an OSH with BRBPR in the setting of supratherapeutic INR',
#  '7-31': 'He was transfused 23units pRBCs',
#  '7-33': 'The patient was made comfort measures on [**2185-10-4**]. Pain medications were increased, and he was weaned off the pressors',
#  '7-35': 'Medications on Admission: Metoprolol 12.5mg TID Midodrine 10mg TID spironolactone 25mg PO daily Multivitamin Mirtazapine 7.5mg PO qhs Trypsin-Dalsam- Castor oil , 90 units topical prn collagenase 250 unit/gram oint , prn warfarin 2mg PO daily torsemide 40mg PO daily zolpidem 10mg PO daily zofran 4mg PO hs prn',
#  '8-0': 'He continued to be hypoxic when attempting to wean him from CMV to CPAP, and CXR showed possible infiltrate, so he was bronched and started on empiric antibiotics for ventilator associated pneumonia',
#  '8-2': 'When his BAL results came back as streptococcus pneumoniae , his antibiotics were briefly narrowed to ceftriaxone monotherapy, then re-broadened to Vanc / Cipro / Flagyl',
#  '8-8': 'To further assist in weaning him from the ventilator, a lasix drip was begun HD 3 and run for 2 days with good diuresis',
#  '8-12': 'On HD 5 he was weaned from propofol and versed to Precedex',
#  '8-15': 'He had diarrhea while in the ICU, C.Dif was negative, resolved with fiber',
#  '8-17': 'He was maintained on prophylaxis while in the ICU: Heparin sub-cu , famotidine',
#  '8-21': 'He was weaned off the oxygen',
#  '8-22': 'All antibi otics',
#  '8-23': 'Medications on Admission: albuterol , sertraline 100 mg daily Discharge Medications: 1. acetaminophen 325 mg Tablet Sig: Two (2) Tablet PO Q6H (every 6 hours) as needed for fever',
#  '8-35': '2. clonazepam 0.5 mg Tablet Sig: One (1) Tablet PO BID (2 times a day)',
#  '8-42': '3. sertralin e 50 mg Tablet Sig: Two (2) Tablet PO DAILY (Daily)',
#  '8-49': '4. pantoprazole 40 mg Tablet , Delayed Release (E.C.) Sig: One (1) Tablet , Delayed Release (E.C.) PO Q24H (every 24 hours)',
#  '8-56': '5. calcium carbonate 200 mg calcium ( 500 mg ) Tablet , Chewable Sig: [**2-15**] Tablet, Chewables PO QID (4 times a day) as needed for heartburn',
#  '8-65': '6. albuterol sulfate 90 mcg /actuation HFA Aerosol Inhaler Sig: Four (4) Puff Inhalation Q4H (every 4 hours) as needed for wheezing',
#  '8-73': 'You were treated with antibiotics for your respiratory infection',
#  '9-0': 'Admission Date: [**2194-12-7**] Discharge Date: [**2194-12-23**] Date of Birth: [**2118-3-21**] Sex: M Service: CARDIOTHORACIC Allergies: Amiodarone',
#  '9-1': 'Past Medical History: idiopathic thrombocytopenic purpura hepatitis C x8-10years coronary artery disease aortic stenosis hypertension hyperlipidemia atrial fibrillation pulmonary fibrosis secondary to amiodarone',
#  '9-3': 'An abdominal ultrasound showed no signs of splenomegaly and his heparin',
#  '9-4': 'His chronic thrombocytopenia',
#  '9-5': 'He received platelet transfusions',
#  '9-7': 'His Coumadin was restarted on [**12-20**] for his atrial fibrillation',
#  '9-9': "Medications on Admission: Coumadin 2.5mg PO daily Atacand 32mg PO daily Lopressor 100mg PO BID Insulin NPH 22 [**Hospital1 **] Glucotrol 5 ' Digoxin 0.125 ' Lipitor 20 ' Celexa 20 ' Protonix 40",
#  '9-33': "Medications on Admission: Coumadin 2.5mg PO daily Atacand 32mg PO daily Lopressor 100mg PO BID Insulin NPH 22 [**Hospital1 **] Glucotrol 5' Digoxin 0.125' Lipitor 20' Celexa 20' Protonix 40' Discharge Medications: 1. Acetaminophen 325 mg Tablet Sig: Two (2) Tablet PO Q4H (every 4 hours) as needed",
#  '9-40': '2. Aspiri n 81 mg Tablet, Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO DAILY (Daily)',
#  '9-47': '3. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)',
#  '9-54': '4. Oxycodone- Acetaminophen 5-325 mg Tablet Sig: 1-2 Tablets PO Q4H (every 4 hours) as needed for pain',
#  '9-62': '5. Ranitidine HCl 150 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '9-69': '6. Warfarin 5 mg Tablet Sig: One (1) Tablet PO once a day',
#  '9-76': '7. Metoprolol Tartrate 25 mg Tablet Sig: Three (3) Tablet PO BID (2 times a day)',
#  '9-83': '8. Magnesium Hydroxide 400 mg /5 mL Suspension Sig: Thirty (30) ML PO Q6H (every 6 hours) as needed',
#  '9-89': '9. Bisacody l 10 mg Suppository Sig: One (1) Suppository Rectal HS (at bedtime) as needed',
#  '9-96': '10. Lasix 20 mg Tablet Sig: One (1) Tablet PO twice a day for 7 days',
#  '9-104': '11. Lasix 20 mg Tablet Sig: One (1) Tablet PO once a day for 7 days',
#  '9-112': '12. Citalopra m 20 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '9-119': '13. Atorvastati n 20 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '9-126': '14. Humulin N 100 unit/mL Suspension Sig: Eleven (11) units Subcutaneous twice a day',
#  '9-132': '15. Humalog 100 unit/mL Cartridge Sig: One (1) Units Subcutaneous four times a day as needed for hyperglycemia : insulin sliding scale',
#  '10-0': 'The patient is status post a bicycle accident in the summer of [**2166**] and has been taking ibuprofe n 400 mg q. 4-6 hours for approximately one month',
#  '10-4': 'MEDICATIONS ON ADMISSION: 1. Neurontin (patient self-discontinued secondary to sedative',
#  '10-6': '2. Ibuprofen 400 mg q. 4-6 hours p.r.n.',
#  '10-9': '3. Prozac 20 mg p.o. q.d. 4. Flonase',
#  '10-14': '5. Omega oils',
#  '10-15': 'ALLERGIES: Sulfa',
#  '10-16': "The patient's hematocrit reached a nadir of 13.9 on [**2168-4-18**] and required six units of packed red blood cells for resuscitation",
#  '10-19': 'Gastroenterology followed the patient during the course of admission and made several recommendations to decrease future risks of GI bleeding , including Protonix b.i.d. for at least two weeks and then continued q.d. thereafter, avoidance of non-steroidal anti-inflammatory drugs and Omega oils',
#  '10-26': 'He had a normal EKG. Pain resolved with treatment of upper GI bleed and with Ultram',
#  '10-28': '3. Back pain : The patient was initiated on a treatment plan with Ultram as an alternative to ibuprofen',
#  '10-31': 'He will be discharged with a prescription for Ultram',
#  '10-32': 'He will be discharged with a prescription for Ultram. Tylenol',
#  '10-33': 'Anemia secondary to blood loss status post six units of packed red blood cells',
#  '10-35': 'DISCHARGE MEDICATIONS: 1. Protonix 40 mg p.o. b.i.d.',
#  '10-39': '2. Tramadol 50 mg p.o. q. 4-6 hours p.r.n',
#  '10-43': '3. Prozac 20 mg p.o. q.d.',
#  '11-0': 'She received one unit PRBC',
#  '11-2': 'EGD showed a single non-bleeding ulcer at the GE junction, blood in the body and fundus of the stomach',
#  '11-4': 'She received an additional three units PRBC',
#  '11-6': 'Contact: daughters [**Name (NI) **] [**Telephone/Fax (1) 94693**] (HCP) [**Name (NI) **] [**Telephone/Fax (1) 94694**] Family History: non-contributory Physical Exam: On admission: 98.0 94 104/41 14 98%RA Gen: elderly woman, comfortable, NAD HEENT: PERRL, anicteric, conjunctiva pale, OP clear with modestly dry MM HEENT: supple, no LAD, no JVD CV: RRR, III/VI pansystolic murmur, no s3s4, 2+radial and DP pulses Resp: CTAB Chest: mastectomy scars, sternal wound 1.5cm diameter, dressed with cream and dry gauze Back: winged scapula, nontender Abd: +BS, soft, ttp mid-epigastric, no rebounding or guarding, no HSM Ext: no edema, mildly ttp right calf Skin: diffuse nevi on neck, chest, abdomen, B arms, large nevi on abdomen, echymoses on right knee, left arm Pertinent Results: [**2180-4-9**] 11:40AM PT-13.5* PTT-19.6* INR(PT)-1.2 [**2180-4-9**] 11:40AM PLT SMR-NORMAL PLT COUNT-250 [**2180-4-9**] 11:40AM NEUTS-88.3* BANDS-0 LYMPHS-9.5* MONOS-2.1 EOS-0.1 BASOS-0.1 [**2180-4-9**] 11:40AM WBC-9.4 RBC-3.05* HGB-8.8* HCT-26.5* MCV-87 MCH-28.7 MCHC-33.0 RDW-13.1 [**2180-4-9**] 11:40AM DIGOXIN -1.1 [**2180-4-9**] 11:40AM CK(CPK)-63 [**2180-4-9**] 11:40AM GLUCOSE-165* UREA N-92* CREAT-1.2* SODIUM-141 POTASSIUM-5.2* CHLORIDE-106 TOTAL CO2-24 ANION GAP-16 [**2180-4-9**] 12:44PM URINE BLOOD-SM NITRITE-NEG PROTEIN-NEG GLUCOSE-NEG KETONE-NEG BILIRUBIN-NEG UROBILNGN-NEG PH-5.0 LEUK-TR [**2180-4-9**] 12:44PM URINE COLOR-Straw APPEAR-Clear SP [**Last Name (un) 155**]-1.013 [**2180-4-9**] 08:10PM HCT-26.9* [**2180-4-9**] 08:10PM CK(CPK)-62 EGD Report: Impression: Angioectasia in the stomach body Ulcers in the distal esophagus',
#  '11-8': 'Please hold asa and plavix',
#  '11-10': 'Please hold asa and plavix for 1 week if ok with primary team. High dose (double dose) PPI',
#  '11-12': 'Biopsies of esophagus not performed due to recent bleeding and recent ASA and plavix',
#  '11-14': '#. GI bleed : Patient was initially admitted to the ICU and transfused three units PRBC',
#  '11-17': 'She underwent repeat EGD which showed two distal esophageal ulcers',
#  '11-18': 'It was later noted that the patient had been taking only a minimal amount of water with her weekly Fosamax',
#  '11-19': 'It was later noted that the patient had been taking only a minimal amount of water with her weekly Fosamax, and this was thought to be the cause. Fosamax',
#  '11-20': '[**First Name (STitle) **], can be had. Aspirin and Plavis were also held, and she was treated with big iv Protonix',
#  '11-24': 'She was discharged to home on Prevacid 30mg [**Hospital1 **], liquid',
#  '11-27': 'She will resume taking Plavix 75mg daily',
#  '11-30': 'She was instructed to resume Aspirin 81mg daily',
#  '11-33': '#. CAD',
#  '11-34': 'She was ruled out for acute MI and continued on her outpatient regimen of captopril , carvedilol , and statin for secondary prevention',
#  '11-38': 'She was ruled out for acute MI and continued on her outpatient regimen of captopril, carvedilol, and statin for secondary prevention. Plavix will be restarted [**2180-4-19**], aspirin',
#  '11-40': 'Plavix will be restarted [**2180-4-19**], aspirin 4weeks after discharge.. #. CRI',
#  '11-41': 'It was thought to be prerenal in etiology and treated with gentle iv fluids',
#  '11-43': '#. Hypothyroid : continued Synthroid',
#  '11-45': 'Psych: continued citalopram , trazadone',
#  '11-47': 'Psych: continued citalopram, trazadone per outpatient regimen #. Osteoporosis : We discontinued weekly Fosamax out of concern that this was related to the developed of GE ulcers',
#  '11-51': 'The patient was instructed to discuss resuming Fosamax',
#  '11-52': 'Medications on Admission: Captopril 25mg [**Hospital1 **] Citalopram 60mg daily Coreg 6.25mg [**Hospital1 **] Digoxin 0.125mg daily Folate 4mg daily Trazodone 50mg qHS Fosamax 70mg qweek Lasix 40mg daily Levothyroxine 75mg daily Plavis 75mg daily Zocor 20mg daily',
#  '11-83': 'Medications on Admission: Captopril 25mg [**Hospital1 **] Citalopram 60mg daily Coreg 6.25mg [**Hospital1 **] Digoxin 0.125mg daily Folate 4mg daily Trazodone 50mg qHS Fosamax 70mg qweek Lasix 40mg daily Levothyroxine 75mg daily Plavis 75mg daily Zocor 20mg daily Discharge Medications: 1. Captopri l 25 mg Tablet Sig: One (1) Tablet PO BID (2 times a day)',
#  '11-90': '2. Citalopram Hydrobromide 20 mg Tablet Sig: Three (3) Tablet PO DAILY (Daily)',
#  '11-97': '3. Carvedilol 3.125 mg Tablet Sig: Two (2) Tablet PO BID (2 times a day)',
#  '11-104': '4. Folic Acid 1 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '11-111': '5. Levothyroxine Sodium 50 mcg Tablet Sig: One (1) Tablet PO QOD',
#  '11-118': '6. Levothyroxine Sodium 50 mcg Tablet Sig: 0.5 Tablet PO QOD',
#  '11-125': '7. Silver Sulfadiazine 1 % Cream Sig: One (1) Appl Topical DAILY (Daily) as needed',
#  '11-132': '8. Digoxin 125 mcg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '11-139': '9. Lorazepa m 0.5 mg Tablet Sig: One (1) Tablet PO HS (at bedtime) as needed for anxiety , sleeplessness',
#  '11-148': '10. Trazodone HCl 50 mg Tablet Sig: One (1) Tablet PO HS (at bedtime) as needed for sleeplessness',
#  '11-156': '11. Furosemide 40 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '11-163': '12. Simvastatin 10 mg Tablet Sig: Two (2) Tablet PO DAILY (Daily)',
#  '11-170': '13. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)',
#  '11-177': '14. Plavix 75 mg Tablet Sig: One (1) Tablet PO once a day',
#  '11-184': '15. Prevacid 30 mg Susp,Delayed Release for Recon Sig: Thirty (30) mg PO twice a day',
#  '11-190': 'Please do not restart your Plavix',
#  '11-191': 'Please resume taking aspirin',
#  '11-192': 'Please do not take Fosamax',
#  '11-193': 'Taking Fosamax without sufficient water may have been related to development of the ulcers',
#  '12-0': 'Admission Date: [**2185-5-23**] Discharge Date: [**2185-6-8**] Service: MEDICINE Allergies: Flagyl',
#  '12-1': 'She was again admitted from [**Date range (1) 33900**] for a rash that was determined to be from metronidazole , which she was taking for Clostridium difficile colitis , upon which she was placed on PO vancomycin',
#  '12-6': 'She was also noted to have diffuse rash on torso, legs, and arms, documented to be from Flagyl',
#  '12-8': 'CXR was concerning for RLL pneumonia , so she was given a dose of Vancomycin and levofloxacin IV',
#  '12-12': 'She was given 1g of tylenol for fever',
#  '12-15': 'HRs improved briefly to 90s with brief conversion to NSR after IVF bolus',
#  '12-17': 'She received a total of 1.5L of IVFs',
#  '12-19': 'For ventricular rates intermittently in 150s , she was then given 5mg IV lopressor',
#  '12-23': 'Vitals in ED prior to transfer were as follows: HR 98 BP 115/61 RR 28 O2',
#  '12-24': 'Physical Exam: Vitals: T: 96.6 BP: 114/64 P: 69 R: 27 O2: 97%RA General: Alert, oriented x 3, no acute distress, cooperative HEENT: Sclera anicteric, MMM, oropharynx clear Neck: supple, JVP not elevated, no LAD Lungs: rhonchorous sounds present at the right base > left base, presence of upper airway sounds, no accessory muscle use, no wheezes CV: Regular rate and rhythm, normal S1 + S2, no murmurs, rubs, gallops Abdomen: soft, non-tender, non-distended, bowel sounds present, no rebound tenderness or guarding, no organomegaly GU: no foley Ext: warm, well perfused, 2+ pulses, no clubbing, cyanosis or edema Skin: exfoliative, erythematous rash on arms, legs and torso Pertinent Results: CT Chest w/o Contrast',
#  '12-25': '[**Month (only) 116**] discontinue oral vancomycin',
#  '12-27': 'Note that pt has allergy to flagyl',
# ...
#  '28-9': 'The patient has been managed with q8h hematocrit checks and Protonix 40 mg',
#  '28-11': 'The patient has been gently diuresed with Lasix',
#  '28-13': 'History of hypercalcemia secondary to hyperparathyroidism ADMISSION MEDICATIONS: 1. Ultram 50 mg po q day',
#  '28-17': 'Ultram 50 mg po q day 2. Tums 3 tablets po q day',
#  '28-22': 'Tums 3 tablets po q day 3. Tylenol prn',
#  '28-24': 'Tylenol prn 4. Epogen [**Numeric Identifier 961**] units',
#  '28-26': '5. Celebrex 100 mg',
#  '28-28': 'Celebrex 100 mg [**Hospital1 **] 6. Zaroxolyn 2.5 mg po q day',
#  '28-32': 'Zaroxolyn 2.5 mg po q day 7. Calcium chloride 10 mg q day',
#  '28-35': 'Calcium chloride 10 mg q day 8. Iron 325 mg q day',
#  '28-38': 'Iron 325 mg q day 9. Lasix 100 mg q day',
#  '28-41': 'Lasix 100 mg q day 10. Captopril 50 mg tid',
#  '28-44': 'Captopril 50 mg tid 11. Prilosec 20 mg q day',
#  '28-47': 'Prilosec 20 mg q day 12. Multivitamin',
#  '28-48': 'Multivitamin 13. Enteric coated aspirin 325 mg q day',
#  '28-52': 'Enteric coated aspirin 325 mg q day 14. Peri-Colace 1 tablet q day',
#  '28-56': 'Peri-Colace 1 tablet q day 15. Levoxyl 112 mcg q day',
#  '28-59': 'Levoxyl 112 mcg q day 16. Zoloft 25 mg q day ALLERGIES: PENICILLIN - THE PATIENT GETS A RASH',
#  '28-64': 'PHYSICAL EXAM: VITAL SIGNS: Heart rate 100, respiratory rate 20, blood pressure 132/64, oxygen saturation 99% on 40% face mask',
#  '28-67': 'HOSPITAL COURSE: In summary, this is a [**Age over 90 **]-year-old woman with a history of congestive heart failure, dementia, gastroesophageal reflux disease, degenerative joint disease and arthritis who presents with upper gastrointestinal bleed upper gastrointestinal bleed thought secondary to NSAID use who is now status post 4 units of packed red blood cell transfusions',
#  '28-73': 'During this hospitalization, the [**Hospital 228**] hospital course was complicated by c ongestive heart failure exacerbation due to the 4 units of packed red blood cells',
#  '28-76': 'The patient was diuresed with Lasix. The patient is currently on room air and will resume her outpatient Lasix dose of 100 mg po q day',
#  '28-82': 'The patient is not a good candidate for aspirin',
#  '28-83': 'Will continue Lopressor 12.5 mg [**Hospital1 **] and captopril 50 mg tid',
#  '28-88': "In terms of the patient's anemia, the patient has normal renal function and will not be discharged with Epogen injections",
#  '28-90': 'The patient will get iron and vitamin C',
#  '28-92': 'DISCHARGE DIAGNOSES: 1. Upper gastrointestinal bleed secondary to NSAID',
#  '28-94': 'DISCHARGE MEDICATIONS: 1. Protonix 40 mg po qd',
#  '28-98': 'Protonix 40 mg po qd 2. Lopressor 12.5 mg po bid',
#  '28-102': 'Lopressor 12.5 mg po bid 3. Levoxyl 112 mcg po q day',
#  '28-106': 'Levoxyl 112 mcg po q day 4. Captopril 50 mg po tid',
#  '28-110': 'Captopril 50 mg po tid 5. Tums 3 tablets po q day',
#  '28-115': 'Tums 3 tablets po q day 6. Ultram 50 mg po q day',
#  '28-119': 'Ultram 50 mg po q day 7. Multivitamin 1 tablet po q day',
#  '28-124': 'Multivitamin 1 tablet po q day 8. Zoloft 25 mg po q day',
#  '28-128': 'Zoloft 25 mg po q day 9. Zaroxolyn 2.5 mg po q day',
#  '28-132': 'Zaroxolyn 2.5 mg po q day 10. Lasix 100 mg po q day',
#  '28-136': 'Lasix 100 mg po q day 11. Iron sulfate 325 mg po tid',
#  '28-140': 'Iron sulfate 325 mg po tid on an empty stomach 12. Vitamin C 250 mg tid with iron',
#  '28-144': 'Vitamin C 250 mg tid with iron 13. Peri-Colace 1 tablet po q day',
#  '28-149': 'Peri-Colace 1 tablet po q day 14. Potassium chloride 10 milliequivalents po q day',
#  '29-0': 'Admission Date: [**2107-1-17**] Discharge Date: [**2107-2-12**] Date of Birth: [**2042-4-4**] Sex: F Service: MEDICINE Allergies: Keflex / Penicillins / Erythromycin Base / Demerol / Ceclor',
#  '29-5': 'History of Present Illness: 64 yo woman w/ h/o recurrent PEs s/[**Initials (NamePattern4) **] [**Last Name (NamePattern4) 260**] filter, GIB while anticoagulated',
#  '29-7': 'She was readmitted [**2107-1-17**] after she was found to have a multifocal pneumonia and was treated with Levo / Flagyl and Vanco',
#  '29-11': 'Cultures were positive for MRSA. Levo and Flagyl were continued for suspected aspiration PNA',
#  '29-14': 'The pt recovered quickly over since admission and she is now back on her home O2',
#  '29-15': 'She was getting bridged for her anticoagulation with Lovenox',
#  '29-17': 'She required a total of 5 units PRBC and 4 units FFP',
#  '29-21': 'PE [**7-13**], c/b GIB while on anticoagulation',
#  '29-23': '[**2107-2-9**] ECG: Sinus tachycardia, Normal ECG except for rate Brief Hospital Course: 64F w/ h/o recurrent PE s/[**Initials (NamePattern4) **] [**Last Name (NamePattern4) 260**] filter, GIB on anticoagulation , COPD, recently admitted for new PE, readmitted for multifocal PNA, who developed a large abdominal wall hematoma in the context of enoxaparin injections',
#  '29-28': '# Multifocal Pneumonia : She was admitted with multifocal pneumonia',
#  '29-30': 'She was started on levofloxacin and vancomycin',
#  '29-32': 'She completed a 7 day course of levofloxacin',
#  '29-34': 'She completed a 7 day course of levofloxacin. MRSA was found to grow in her sputum so she was continued on a 14 day course of vancomycin',
#  '29-37': 'Her productive cough improved as well and she remained on her baseline home O2 of 2L',
#  '29-39': 'Approximately 4 days after completion of her 14 day course of Vancomycin',
#  '29-41': 'The patient was started back on Levofloxacin / Flagyl',
#  '29-43': 'The patient was started back on Levofloxacin/Flagyl. Vancomycin',
#  '29-44': 'Additionally, her sputum culture grew out GNRs. Levofloxacin was discontinued and Meropenem was started for concern for Pseudomonas',
#  '29-47': 'Her O2 sat remained stable 93-100% on 2L nasal cannula',
#  '29-50': 'She was given mucomyst inhaled nebulizers to assist in breaking up thick sputum',
#  '29-54': "Because of the sensitivity profile of the E. coli and the patient's allergy to penicillin and cephalosporins , the patient was continued on Meropenem",
#  '29-57': 'Her Vancomycin',
#  '29-58': 'She will continue a 14 day course of Meropenem',
#  '29-60': '# Pulmonary embolism / DVTs',
#  '29-62': 'Admission labwork revealed an INR of 7.9. Coumadin was thus held and reversed with FFP and vitamin K given her history of GIB on anticoagulation',
#  '29-67': 'In the interim, therapeutic lovenox injections were initiated, but within days of starting, she developed a large abdominal wall hematoma near to lovenox',
#  '29-71': 'Once her hematocrit stabilized, she was started on a heparin gtt with coumadin',
#  '29-74': 'While [**Last Name (NamePattern4) 9533**] her Coumadin with an INR 1.2, she was found to have a large Hct drop and a CT scan of the abdomen showed a new rectus hematoma',
#  '29-76': 'It was decided after her second hematoma while on anticoagulation , the risks of anticoagulation',
#  '29-79': '# Abdominal wall hematoma : As mentioned above, she developed a large left-sided abdominal wall hematoma from a Lovenox',
#  '29-81': 'She received 3 units prbcs , 4 units FFP',
#  '29-85': 'Her hematocrit then stabilized and once stable, she was restarted on heparin gtt',
#  '29-87': 'Her hematocrit then stabilized and once stable, she was restarted on heparin gtt. Coumadin was re-initiated and heparin gtt',
#  '29-90': 'While [**Location (un) 9533**] her Coumadin with an INR 1.2, she was found to have another Hct drop (25.9-> 22.2) and a CT scan of the abdomen showed a new right-sided rectus hematoma',
#  '29-92': 'She was given 1 unit FFP and 9 units PRBCs',
#  '29-96': 'It was decided after her second hematoma while on anticoagulation , the risks of anticoagulation',
#  '29-99': 'Her Hct remained stable after her anticoagulation',
#  '29-100': '# ? Zoster',
#  '29-101': 'She was treated with acyclovir',
#  '29-102': '# Candidal vaginitis : Treated with fluconazole x 2',
#  '29-105': '# Hyperlipidemia : Continued on lipitor',
#  '29-107': '# Depression / SAD : Continued on Prozac , risperdone , wellbutrin , and klonopin',
#  '29-113': '# Ulcerative Colitis',
#  '29-114': 'She was continued on mesalamine',
#  '29-115': '# Orthostatic hypotension',
#  '29-116': 'She was continued on midodrine',
#  '29-117': 'Medications on Admission: 1. Fluoxetine 30 mg daily',
#  '29-120': 'Fluoxetine 30 mg daily 2. Risperidone 3 mg PO HS',
#  '29-124': 'Risperidone 3 mg PO HS 3. Bupropion SR 150 mg',
#  '29-126': 'Bupropion SR 150 mg [**Hospital1 **] 5. Nicotine 7 mg/24 hr Patch',
#  '29-129': 'Nicotine 7 mg/24 hr Patch 6. Hexavitamin daily 7. ascorbic acid 500 tab 1',
#  '29-135': 'Hexavitamin daily 7. ascorbic acid 500 tab 1 [**Hospital1 **] 8. Calcium Carbonate 500 tab',
#  '29-138': 'Calcium Carbonate 500 tab [**Hospital1 **] 9. Ferrous gluconate 325 PO daily',
#  '29-142': 'Ferrous gluconate 325 PO daily 10. Atorvastatin 20 mg daily',
#  '29-145': 'Atorvastatin 20 mg daily 11. Fluticasone Salmeterol 250/50',
#  '29-147': 'Fluticasone Salmeterol 250/50 [**Hospital1 **] 12. Midodrine 5 mg tab 1 TID',
#  '29-152': 'Midodrine 5 mg tab 1 TID 13. Tiotropium bromide capsule one cap / day',
#  '29-157': 'Tiotropium bromide capsule one cap /day 14. Mesalamine 1200 TID',
#  '29-160': 'Mesalamine 1200 TID 15. Pantoprazole 40 / day',
#  '29-163': 'Pantoprazole 40/ day 16. Albuterol nebs prn (tid generally) 17. docusate sodium',
#  '29-167': 'Albuterol nebs prn (tid generally) 17. docusate sodium 18. Warfarin 5 mg / day',
#  '29-170': 'Warfarin 5 mg/day 19. Ipratropium nebs prn (tid generally) 20. clonazepam 1mg po tid',
#  '29-177': 'Ipratropium nebs prn (tid generally) 20. clonazepam 1mg po tid Discharge Medications: 1. Fluoxetine 10 mg Capsule Sig: Three (3) Capsule PO DAILY (Daily)',
#  '29-184': '2. Risperidone 1 mg Tablet Sig: Three (3) Tablet PO HS (at bedtime)',
#  '29-191': '3. Bupropion 150 mg Tablet Sustained Release Sig: One (1) Tablet Sustained Release PO BID (2 times a day)',
#  '29-198': '4. Hexavitamin Tablet Sig: One (1) Cap PO DAILY (Daily)',
#  '29-204': '5. Calcium Carbonate 500 mg Tablet, Chewable Sig: One (1) Tablet, Chewable PO BID (2 times a day)',
#  '29-211': '6. Fluticasone-Salmeterol 250-50 mcg/Dose Disk with Device Sig: One (1) Disk with Device Inhalation [**Hospital1 **] ( 2 times a day',
#  '29-218': '7. Midodrine 5 mg Tablet Sig: One (1) Tablet PO TID (3 times a day)',
#  '29-225': '8. Mesalamine 400 mg Tablet, Delayed Release (E.C.) Sig: Three (3) Tablet, Delayed Release (E.C.) PO TID (3 times a day)',
#  '29-232': '9. Pantoprazole 40 mg Tablet, Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q24H (every 24 hours)',
#  '29-239': '10. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)',
#  '29-246': '11. Nicotine 7 mg/24 hr Patch 24HR Sig: One (1) Patch 24HR Transdermal DAILY (Daily)',
#  '29-253': '12. Ferrous Gluconate 300 mg Tablet Sig: One (1) Tablet PO DAILY (Daily) : please do not take this with levofloxacin',
#  '29-261': '13. Cepacol 2 mg Lozenge Sig: One (1) Lozenge Mucous membrane Q4H (every 4 hours) as needed',
#  '29-268': 'Disp:*100 Lozenge(s)* Refills:*0* 14. Tiotropium Bromide 18 mcg Capsule, w/Inhalation Device Sig: One (1) Cap Inhalation DAILY (Daily)',
#  '29-275': '15. Sodium Chloride 0.65 % Aerosol, Spray Sig: [**2-8**] Sprays Nasal QID (4 times a day)',
#  '29-281': 'Disp:*QS bottle* Refills:*2* 16. Senna 8.6 mg Tablet Sig: One (1) Tablet PO BID (2 times a day)',
#  '29-288': 'Disp:*60 Tablet(s)* Refills:*2* 17. Clonazepam 1 mg Tablet Sig: One (1) Tablet PO TID (3 times a day) as needed for anxiety',
#  '29-296': 'Disp:*20 Tablet(s)* Refills:*0* 18. Saline Flush 0.9 % Syringe Sig: Three (3) ml Injection twice a day for 20 doses : prior to each vanco',
#  '29-304': 'Disp:*20 syringe* Refills:*0* 19. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO twice a day',
#  '29-311': '20. Simethicone 80 mg Tablet, Chewable Sig: One (1) Tablet, Chewable PO QID (4 times a day) as needed',
#  '29-318': '21. Aluminum-Magnesium Hydroxide 225-200 mg/5 mL Suspension Sig: 15-30 MLs PO QID (4 times a day) as needed',
#  '29-324': '22. Bisacodyl 5 mg Tablet, Delayed Release (E.C.) Sig: Two (2) Tablet, Delayed Release (E.C.) PO DAILY (Daily) as needed for constipation',
#  '29-332': '23. Oxycodone 5 mg Tablet Sig: 1-2 Tablets PO Q4-6H (every 4 to 6 hours) as needed for pain',
#  '29-340': '24. Lidocaine 5 %(700 mg/patch) Adhesive Patch, Medicated Sig: One (1) Adhesive Patch, Medicated Topical QD',
#  '29-347': '25. Pantoprazole 40 mg Tablet, Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q24H (every 24 hours)',
#  '29-354': '26. Nystatin 100,000 unit/g Cream Sig: One (1) Appl Topical [**Hospital1 **] ( 2 times a day',
#  '29-361': '27. Albuterol Sulfate 0.083 % Solution Sig: One (1) Inhalation Q6H (every 6 hours) as needed for wheezing',
#  '29-368': '28. Ezetimibe 10 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '29-375': '29. Acetaminophen 325 mg Tablet Sig: Two (2) Tablet PO Q6H (every 6 hours) as needed for pain',
#  '29-383': '30. Heparin Lock Flush (Porcine) 100 unit/mL Syringe Sig: One (1) ML Intravenous DAILY (Daily) as needed',
#  '29-389': '31. Meropenem 500 mg Recon Soln Sig: One (1) Recon Soln Intravenous Q6H (every 6 hours) for 7 days',
#  '29-397': 'Discharge Disposition: Extended Care Facility: [**Hospital3 7**] & Rehab Center - [**Hospital1 8**] Discharge Diagnosis: Primary: 1) Pulmonary Embolism with history of DVT and IVC filter placement in [**2106-7-8**] 2) Community Acquired Pneumonia 3) History of GI Bleed (extensive) in [**2106-7-8**] when anticoagulated 4) Abdominal wall hematoma hematoma , with acute blood loss anemia requiring 10 units PRBCs when anticoagulated for current pulmonary embolism 5) Noscomial Pneumonia with GNR in sputum, 6) Coagulopathy 7) Noscomial UTI with E. coli - quinolone resistant 8) Vagnitis , attributed to broad spectrum antibiotic',
#  '30-0': 'Admission Date: [**2165-6-3**] Discharge Date: [**2165-6-24**] Date of Birth: [**2098-4-23**] Sex: M Service: MEDICINE Allergies: Ampicillin / peanuts Attending:[**First Name3 (LF) 2297**] Chief Complaint: MUD AlloHSCT Major Surgical or Invasive Procedure: - MUD AlloHSCT - VP shunt tap - Bronchoscopy History of Present Illness: Mr. [**Known lastname **] is a 67-year-old man with trasnufsion dependent myelodysplastic disorder, normal pressure hydrocephalus, DM, CAD, HTN who is electively admitted for Allo SCT',
#  '30-2': 'He was last seen in clinic [**5-30**] w Dr. [**Last Name (STitle) 410**] for preadmission testing prior to planned admission today for a non-myeloablative matched unrelated donor transplant for his MDS that is associated with pancytopenia and transfusion dependence of both red cells and platelets',
#  '30-5': 'Due to multiple transfusions, he has develoepd Fe overload, and has been on chelation therapy with deferasirox.',
#  '30-7': 'The conditioning is to inlcude clofarabine, total nodal radiation and ATG',
#  '30-9': '[**10/2164**] he was admitted to the ICU with CAP / neutropenic fevers',
#  '30-11': 'He was treated with vancomycin , cefepime and ciprofloxacin',
#  '30-14': 'He has had one episode of diarrhea in the last day which is typical following Exgade',
#  '30-15': '- [**4-/2165**] EF 55%; cardiology cleared for transplant - Angina - once weekly depending on anemia and stress levels normally lasting 10-15 mins and resolves with nitro',
#  '30-17': '-NPH: s/p VP shunt placement [**11/2164**] w resolution of sx -PVD -Diabetes Mellitus - BPH on flomax',
#  '30-19': 'Hematologic Hx Longstanding history of myelodysplastic disorder associated with severe pancytopenia , now red cell and platelet transfusion',
#  '30-23': 'He was treated briefly with azacitidine (Vidaza)',
#  '30-24': "He has been getting PRBC's and platelet tranfusions , as well as iron chelation with deferasirox (Exjade)",
#  '30-29': 'MRI head w/o contrast',
#  '30-30': 'Brief Hospital Course: 66 year old M with transfusion dependent MDS, D+7 s/p allo SCT , normal pressure hydrocephalus, CAD, HTN and diabetes, who was initially electively admitted for allo SCT with clofarabine',
#  ...}

# %%
import json
with open("sents_dict.txt", "w") as fp:
    json.dump(sents_dict, fp)  # encode dict into JSON

# %%
entity_df = pd.DataFrame(tags_list, columns=['text_id','entity_id','start','end','concept','entity','sent_num']).set_index('entity_id')

# %%
entity_df['concept'].unique()
# Out:
# array(['Drug', 'Reason', 'Strength', 'Route', 'Dosage', 'ADE',
#        'Frequency', 'Form', 'Duration'], dtype=object)

# %%
entity_df.to_csv('entity.csv', sep=',', encoding='utf-8')

# %%
'''
This is to generate relations to a specific format for one of my model, a relation triplet is formated as 
"start_position_1st_entity, end_position_1st_entity, start_position_2nd_entity, end_position_2nd_entity,
relation_type, 1st_entity_type, 2nd_entity_type" Each relation is concatenated by all the relation triplets
within the sentence, seperated by '|'
'''

relations = []
sents = []
for i, an in enumerate(tqdm(anno)):
    text = an.get_text()
    relation = ''
    entity_curr = entity_df[entity_df['text_id']==i]#['sent_num']
    curr_sent = 0
    relation_df = pd.DataFrame.from_dict(an.relations,orient='index')#.values()
    relation_df['head_entity'] = relation_df[1].apply(lambda x: int(x[1]))
    relation_df = relation_df.sort_values(['head_entity']).drop('head_entity',axis = 1)
    for k in relation_df.values:
        if k[0][0] not in entity_curr.index or k[1][0] not in entity_curr.index:
            continue
        e1, e2, rel = entity_curr.loc[k[0][0]], entity_curr.loc[k[1][0]], k[2]

 

        if e1['sent_num'] != e2['sent_num']:
            continue
        if curr_sent == 0:
            relation = ' '.join([str(e1['start']), str(e1['end']), str(e2['start']), str(e2['end']),
                                   '/'+rel+'/'+k[0][3]+'/'+k[1][3], '|'])
            curr_sent = e1['sent_num']
        elif e1['sent_num'] == curr_sent:           
            relation = ' '.join([relation, str(e1['start']), str(e1['end']), str(e2['start']), str(e2['end']),
                                   '/'+rel+'/'+k[0][3]+'/'+k[1][3], '|'])
        else:
            #print(curr_sent)
            relations.append((curr_sent,relation[:-2]))  
            sents.append((curr_sent,sents_dict[curr_sent]))
            curr_sent = e1['sent_num']
            relation = ' '.join([str(e1['start']), str(e1['end']), str(e2['start']), str(e2['end']),
                                   '/'+rel+'/'+k[0][3]+'/'+k[1][3],'|'])
    if curr_sent == 0:
        continue
    relations.append((curr_sent,relation[:-2]))  
    sents.append((curr_sent,sents_dict[curr_sent]))
    relation = ' '.join([str(e1['start']), str(e1['end']), str(e2['start']), str(e2['end']),
                           '/'+rel+'/'+k[0][3]+'/'+k[1][3],'|'])
# Out:
#   0%|          | 0/303 [00:00<?, ?it/s]

# %%
relations[0:7]
# Out:
# [('0-0', '52 53 54 55 /Reason-Drug/Reason/Drug'),
#  ('0-9', '15 17 14 15 /Strength-Drug/Strength/Drug'),
#  ('0-13', '3 5 6 7 /Strength-Drug/Strength/Drug'),
#  ('0-15',
#   '2 4 6 7 /Strength-Drug/Strength/Drug | 5 6 6 7 /Route-Drug/Route/Drug | 11 12 12 13 /Route-Drug/Route/Drug | 8 10 12 13 /Strength-Drug/Strength/Drug | 14 16 18 19 /Strength-Drug/Strength/Drug | 17 18 18 19 /Route-Drug/Route/Drug | 22 23 20 21 /Dosage-Drug/Dosage/Drug'),
#  ('0-26', '23 24 22 23 /Route-Drug/Route/Drug'),
#  ('0-30', '10 11 8 9 /ADE-Drug/ADE/Drug'),
#  ('0-40',
#   '1 2 5 6 /Reason-Drug/Reason/Drug | 1 2 7 8 /Reason-Drug/Reason/Drug')]

# %%
import re
print(re.findall('\d+', relations[6][1]))
# Out:
# ['1', '2', '5', '6', '1', '2', '7', '8']

# %%
sents[0:7]
# Out:
# [('0-0',
#   'Admission Date: [**2177-5-27**] Discharge Date: [**2177-5-29**] Date of Birth: [**2129-10-5**] Sex: F Service: MEDICINE Allergies: Zosyn / Quinolones / Ceftriaxone / Flagyl / Keppra / Lisinopril / Naprosyn Attending:[**First Name3 (LF) 562**] Chief Complaint: swelling of lips Major Surgical or Invasive Procedure: none History of Present Illness: 47F with asthma/COPD, atopic dermatitis, HTN on ACEI'),
#  ('0-9',
#   'She denies any wheezing, stridor, shortness of breath and states that has been on Lisinopril 20 mg'),
#  ('0-13', 'ER tried giving 5 mg of midazolam'),
#  ('0-15',
#   'Pt received 125 mg of IV solumedrol , 20 mg of IV famotidine , 25 mg of IV diphenydramine and epipen x 2'),
#  ('0-26',
#   'She is has a tough access and ER could only get a small IV in R forearm (that is why they gave epineprhine IM'),
#  ('0-30',
#   'She was been seen by allergy for likely naproxen induced angioedema'),
#  ('0-40', '#. HTN - Pt on ACEI and beta-blocker')]

# %%
sents[6][1].split()
# Out:
# ['#.', 'HTN', '-', 'Pt', 'on', 'ACEI', 'and', 'beta-blocker']

# %%
i_relation = relations[6][1].split("| ")
sample = []
for i in i_relation:
    relation_sample = []
    relation_sample.append((int(i.split(" ")[0]),int(i.split(" ")[1])))
    relation_sample.append((int(i.split(" ")[2]),int(i.split(" ")[3])))
    relation_sample.append(i.split(" ")[4].split("/")[1])
    sample.append(relation_sample)
print(sample)
# Out:
# [[(1, 2), (5, 6), 'Reason-Drug'], [(1, 2), (7, 8), 'Reason-Drug']]

# %%
relation_data = []
for i in range(len(sents)):
    sample = []
    sample.append(sents[i][0])
    sample.append(sents[i][1].split())
    i_relation = relations[i][1].split("| ")
    i_sample = []
    for i in i_relation:
        relation_sample = []
        relation_sample.append((int(i.split(" ")[0]),int(i.split(" ")[1])))
        relation_sample.append((int(i.split(" ")[2]),int(i.split(" ")[3])))
        relation_sample.append(i.split(" ")[4].split("/")[1])
        i_sample.append(relation_sample)
    sample.append(i_sample)
    relation_data.append(sample)

# %%
relation_data[0]
# Out:
# ['0-0',
#  ['Admission',
#   'Date:',
#   '[**2177-5-27**]',
#   'Discharge',
#   'Date:',
#   '[**2177-5-29**]',
#   'Date',
#   'of',
#   'Birth:',
#   '[**2129-10-5**]',
#   'Sex:',
#   'F',
#   'Service:',
#   'MEDICINE',
#   'Allergies:',
#   'Zosyn',
#   '/',
#   'Quinolones',
#   '/',
#   'Ceftriaxone',
#   '/',
#   'Flagyl',
#   '/',
#   'Keppra',
#   '/',
#   'Lisinopril',
#   '/',
#   'Naprosyn',
#   'Attending:[**First',
#   'Name3',
#   '(LF)',
#   '562**]',
#   'Chief',
#   'Complaint:',
#   'swelling',
#   'of',
#   'lips',
#   'Major',
#   'Surgical',
#   'or',
#   'Invasive',
#   'Procedure:',
#   'none',
#   'History',
#   'of',
#   'Present',
#   'Illness:',
#   '47F',
#   'with',
#   'asthma/COPD,',
#   'atopic',
#   'dermatitis,',
#   'HTN',
#   'on',
#   'ACEI'],
#  [[(52, 53), (54, 55), 'Reason-Drug']]]

# %%
import json
with open("relation.txt", "w") as fp:
    json.dump(relation_data, fp)
