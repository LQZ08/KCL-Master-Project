# %%
import os
from tqdm.notebook import tqdm
import glob
import numpy as np
import pandas as pd
import random
from collections import defaultdict
from nltk.tokenize import sent_tokenize, word_tokenize

# %% [markdown]
# # Read files and annotations

# %%
#This class is provided by i2b2 challenge. I use its functions to get annotations and text

class RecordTrack2(object):
    """Record for Track 2 class."""

    def __init__(self, file_path):
        """Initialize."""
        self.path = os.path.abspath(file_path)
        self.basename = os.path.basename(self.path)
        self.annotations = self._get_annotations()
        # self.text = self._get_text()

    @property
    def tags(self):
        return self.annotations['tags']

    @property
    def relations(self):
        return self.annotations['relations']

    def _get_annotations(self):
        """Return a dictionary with all the annotations in the .ann file."""
        annotations = defaultdict(dict)
        with open(self.path) as annotation_file:
            lines = annotation_file.readlines()
            for line_num, line in enumerate(lines):
                if line.strip().startswith('T'):
                    try:
                        tag_id, tag_m, tag_text = line.strip().split('\t')
                    except ValueError:
                        print(self.path, line)
                    if len(tag_m.split(' ')) == 3:
                        tag_type, tag_start, tag_end = tag_m.split(' ')
                    elif len(tag_m.split(' ')) == 4:
                        tag_type, tag_start, _, tag_end = tag_m.split(' ')
                    elif len(tag_m.split(' ')) == 5:
                        tag_type, tag_start, _, _, tag_end = tag_m.split(' ')
                    else:
                        print(self.path)
                        print(line)
                    tag_start, tag_end = int(tag_start), int(tag_end)
                    annotations['tags'][tag_id] = (tag_id, tag_start ,tag_end, tag_type, tag_text)
            for line_num, line in enumerate(lines):
                if line.strip().startswith('R'):
                    rel_id, rel_m = line.strip().split('\t')
                    rel_type, rel_arg1, rel_arg2 = rel_m.split(' ')
                    rel_arg1 = rel_arg1.split(':')[1]
                    rel_arg2 = rel_arg2.split(':')[1]
                    arg1 = annotations['tags'][rel_arg1]
                    arg2 = annotations['tags'][rel_arg2]
                    annotations['relations'][rel_id] = (arg1,arg2, rel_type)
        return annotations

    def get_text(self):
        """Return the text in the corresponding txt file."""
        path = self.path.replace('.ann', '.txt')
        with open(path) as text_file:
            text = text_file.read()
        return text

# %%
#reading data and create a list of RecordTrack2 class for each file
folder1 = 'training_20180910/'
anno = []
files1 = set([os.path.basename(f) for f in glob.glob(
    os.path.join(folder1, '*.ann'))])
for file in files1:
    anno.append(RecordTrack2(os.path.join(folder1, file)))

# %% [markdown]
# # Generate entities within sentence
#
# Find the offset of each entity within that sentence.
#
# The offset provided by i2b2 is aginst the whole file.
#
# In this section, we will locate the entity, tokenise sentense, and remove extra spaces
#
# The offset I generated in this section is word offset (created by len(text.split()), feel free to change to character offset if needed.

# %%
#function to generate the first entity in a sentence
def first_entity(text, start, end, entity):
        text_before = sent_tokenize(text[:start]) #all the text befere the start of the entity
        sent_num = len(text_before)
        word_before = text_before[-1].split() #words before entity in the current sentence 
        word_start = len(word_before) #start position
        word_end = word_start+len(entity.split()) #end position
        sent_after = sent_tokenize(text[end:])[0] #the left of current sentence
        sent_piece = ' '.join(word_before + entity.split()) #current sentence until the end of first entity, extra spaces removed by .split()
        return word_start, word_end, sent_after, sent_piece

# %%
#function to generate non-first entity in a sentence, same logic sa first_entity function
def entity_within_sent(text, word_end_before, end_before, start, end, entity):
    word_between = text[end_before:start].split()
    word_start = word_end_before + len(word_between)
    word_end = word_start+len(entity.split())
    sent_after = sent_tokenize(text[end:])[0]
    #print(sent_after)
    sent_piece = ' '.join(word_between + entity.split())
    return word_start, word_end, sent_after, sent_piece

# %%
tags_list = []
sents_dict = {}
for i, an in enumerate(tqdm(anno)):
    text = an.get_text()
    tags = pd.DataFrame(an.tags.values()).sort_values(1).values
    #skip used to mark how many entities we have processed within the previous sentence
    skip = 0
    for j, (en_id, start, end, concept, entity) in enumerate(tags):
        #we skip the entities we have processed from last sentence, it will bring us to the first entity in current sentence
        if skip>0:
            skip -= 1
            continue
        #remove entities that across sentences
        if len(sent_tokenize(text[start:end]))>1:
            continue
        word_start, word_end, sent_after, sent_piece = first_entity(text, start, end, entity)
        #'-'.join([str(i),str(j)]) is an unique idenfitier for each sentence in the dataset, 
        #i identify the document and j identify the sentence within the document
        tags_list.append([i, en_id, word_start, word_end, concept, entity, '-'.join([str(i),str(j)])])
        while j+skip+1<len(tags) and end+len(sent_after)>= tags[j+skip+1][1]:
            anno_curr = tags[j+skip+1]
            word_end_before = word_end
            end_before = end
            sent_piece_before = sent_piece
            en_id = anno_curr[0]
            start = anno_curr[1]
            end = anno_curr[2]
            concept = anno_curr[3]
            entity = anno_curr[4]
            word_start, word_end, sent_after, sent_piece = entity_within_sent(text, word_end_before, end_before, start, end, entity)
            sent_piece = ' '. join([sent_piece_before, sent_piece])
            tags_list.append([i, en_id, word_start, word_end, concept, entity, '-'.join([str(i),str(j)])])
            skip += 1
        sents_dict['-'.join([str(i),str(j)])] = sent_piece
# Out:
#   0%|          | 0/303 [00:00<?, ?it/s]

# %%
tags_list
# Out:
# [[0, 'T63', 4, 5, 'Drug', 'ampicillin', '0-0'],
#  [0, 'T64', 5, 6, 'Strength', '2gm', '0-0'],
#  [0, 'T65', 6, 7, 'Route', 'IV', '0-0'],
#  [0, 'T66', 9, 10, 'Drug', 'gentamicin', '0-0'],
#  [0, 'T67', 10, 11, 'Strength', '80mg', '0-0'],
#  [0, 'T68', 11, 12, 'Route', 'IV', '0-0'],
#  [0, 'T104', 6, 7, 'Drug', 'anti-biotic', '0-6'],
#  [0, 'T105', 4, 9, 'Reason', 'fevers at home of 103.8', '0-7'],
#  [0, 'T34', 11, 12, 'Drug', 'tylenol', '0-7'],
#  [0, 'T69', 9, 10, 'Drug', 'levo', '0-9'],
#  [0, 'T29', 11, 12, 'Drug', 'flagyl', '0-9'],
#  [0, 'T70', 5, 6, 'Route', 'iv', '0-11'],
#  [0, 'T101', 6, 7, 'Drug', 'rehydration', '0-11'],
#  [0, 'T102', 8, 9, 'Route', 'iv', '0-11'],
#  [0, 'T71', 9, 10, 'Drug', 'abx', '0-11'],
#  [0, 'T72', 3, 4, 'Drug', 'IVF', '0-15'],
#  [0, 'T73', 5, 6, 'Drug', 'levo', '0-15'],
#  [0, 'T74', 7, 8, 'Drug', 'flagyl', '0-15'],
#  [0, 'T121', 8, 10, 'Drug', 'O2 sat', '0-18'],
#  [0, 'T106', 13, 16, 'Drug', 'third generation cephalosporins', '0-19'],
#  [0, 'T20', 18, 20, 'Drug', 'Trimethoprim /Sulfa', '0-20'],
#  [0, 'T27', 9, 10, 'Drug', 'CEFEPIME', '0-21'],
#  [0, 'T6', 13, 14, 'Drug', 'CEFTAZIDIME', '0-21'],
#  [0, 'T33', 17, 18, 'Drug', 'CEFTRIAXONE', '0-21'],
#  [0, 'T1', 21, 22, 'Drug', 'CIPROFLOXACIN', '0-21'],
#  [0, 'T75', 24, 25, 'Drug', 'GENTAMICIN', '0-21'],
#  [0, 'T56', 28, 29, 'Drug', 'IMIPENEM', '0-21'],
#  [0, 'T30', 32, 33, 'Drug', 'MEROPENEM', '0-21'],
#  [0, 'T57', 35, 36, 'Drug', 'PIPERACILLIN', '0-21'],
#  [0, 'T28', 39, 40, 'Drug', 'TOBRAMYCIN', '0-21'],
#  [0, 'T108', 5, 6, 'Route', 'IV', '0-30'],
#  [0, 'T107', 6, 7, 'Drug', 'CONTRAST', '0-30'],
#  [0, 'T110', 5, 6, 'Route', 'IV', '0-32'],
#  [0, 'T109', 6, 7, 'Drug', 'CONTRAST', '0-32'],
#  [0,
#   'T112',
#   4,
#   10,
#   'Reason',
#   'Gram negative septicemia due to cholangitis',
#   '0-34'],
#  [0, 'T15', 2, 3, 'Drug', 'ampicillin', '0-35'],
#  [0, 'T111', 4, 5, 'Drug', 'gentamicin', '0-35'],
#  [0, 'T113', 12, 13, 'Route', 'po', '0-35'],
#  [0, 'T31', 13, 14, 'Drug', 'cipro', '0-35'],
#  [0, 'T32', 1, 6, 'Duration', 'for total of 14 days', '0-39'],
#  [0, 'T114', 1, 3, 'Reason', 'h/o CAD', '0-40'],
#  [0, 'T45', 8, 9, 'Drug', 'aspirin', '0-40'],
#  [0, 'T115', 11, 13, 'Drug', 'beta blocker', '0-40'],
#  [0, 'T103', 1, 2, 'Drug', 'statin', '0-43'],
#  [0, 'T120', 6, 9, 'ADE', 'bump in LFTs', '0-43'],
#  [0, 'T76', 1, 3, 'Reason', 'h/o colitis', '0-45'],
#  [0, 'T21', 10, 11, 'Drug', 'Asacol', '0-45'],
#  [0, 'T55', 12, 13, 'Drug', 'Anaspaz', '0-45'],
#  [0, 'T116', 1, 2, 'Reason', 'ARF', '0-48'],
#  [0, 'T77', 5, 6, 'Drug', 'IVF', '0-48'],
#  [0, 'T49', 2, 3, 'Drug', 'diovan', '0-50'],
#  [0, 'T117', 1, 2, 'Reason', 'Coagulopathy', '0-51'],
#  [0, 'T118', 5, 7, 'Drug', 'vitamin K', '0-51'],
#  [0, 'T22', 16, 17, 'Drug', 'ASACOL', '0-53'],
#  [0, 'T23', 17, 18, 'Strength', '400MG', '0-53'],
#  [0, 'T25', 19, 20, 'Dosage', '2', '0-53'],
#  [0, 'T24', 20, 21, 'Form', 'tabs', '0-53'],
#  [0, 'T26', 21, 25, 'Frequency', 'three times a day', '0-53'],
#  [0, 'T35', 31, 32, 'Drug', 'ASPIRIN', '0-53'],
#  [0, 'T36', 32, 33, 'Strength', '81MG', '0-53'],
#  [0, 'T38', 34, 35, 'Dosage', 'One', '0-53'],
#  [0, 'T37', 35, 36, 'Form', 'tablet', '0-53'],
#  [0, 'T39', 36, 39, 'Frequency', 'twice a day', '0-53'],
#  [0, 'T7', 39, 40, 'Drug', 'DIOVAN', '0-53'],
#  [0, 'T8', 40, 41, 'Strength', '80MG', '0-53'],
#  [0, 'T10', 42, 43, 'Dosage', 'One', '0-53'],
#  [0, 'T9', 43, 44, 'Form', 'tablet', '0-53'],
#  [0, 'T11', 44, 46, 'Route', 'by mouth', '0-53'],
#  [0, 'T78', 46, 48, 'Frequency', 'every day', '0-53'],
#  [0, 'T50', 48, 50, 'Drug', 'HYOSCYAMINE SULFATE', '0-53'],
#  [0, 'T51', 50, 51, 'Strength', '0.375MG', '0-53'],
#  [0, 'T53', 52, 53, 'Dosage', 'One', '0-53'],
#  [0, 'T52', 53, 54, 'Form', 'tablet', '0-53'],
#  [0, 'T54', 54, 57, 'Frequency', 'twice a day', '0-53'],
#  [0, 'T40', 57, 59, 'Drug', 'METOPROLOL TARTRATE', '0-53'],
#  [0, 'T41', 59, 60, 'Strength', '25MG', '0-53'],
#  [0, 'T43', 61, 62, 'Dosage', 'One', '0-53'],
#  [0, 'T42', 62, 63, 'Form', 'tablet', '0-53'],
#  [0, 'T44', 63, 66, 'Frequency', 'twice a day', '0-53'],
#  [0, 'T16', 66, 67, 'Drug', 'PRAVACHOL', '0-53'],
#  [0, 'T17', 67, 68, 'Strength', '20MG', '0-53'],
#  [0, 'T19', 69, 70, 'Dosage', 'One', '0-53'],
#  [0, 'T18', 70, 71, 'Form', 'tablet', '0-53'],
#  [0, 'T79', 71, 73, 'Frequency', 'at bedtime', '0-53'],
#  [0, 'T80', 73, 74, 'Drug', 'TIMOLOL', '0-53'],
#  [0, 'T81', 74, 75, 'Strength', '0.25%', '0-53'],
#  [0, 'T82', 76, 77, 'Dosage', 'One', '0-53'],
#  [0, 'T83', 77, 78, 'Route', 'gtt', '0-53'],
#  [0, 'T84', 78, 81, 'Frequency', 'twice a day', '0-53'],
#  [0, 'T58', 70, 72, 'Drug', 'Metoprolol Tartrate', '0-89'],
#  [0, 'T59', 72, 74, 'Strength', '25 mg', '0-89'],
#  [0, 'T85', 74, 75, 'Form', 'Tablet', '0-89'],
#  [0, 'T61', 76, 77, 'Dosage', '0.5', '0-89'],
#  [0, 'T60', 77, 78, 'Form', 'Tablet', '0-89'],
#  [0, 'T62', 78, 79, 'Route', 'PO', '0-89'],
#  [0, 'T86', 79, 84, 'Frequency', 'BID (2 times a day)', '0-89'],
#  [0, 'T48', 4, 6, 'Drug', 'Mesalamin e', '0-96'],
#  [0, 'T46', 6, 8, 'Strength', '400 mg', '0-96'],
#  [0, 'T47', 8, 13, 'Form', 'Tablet , Delayed Release (E.C.)', '0-96'],
#  [0, 'T87', 14, 16, 'Dosage', 'Two (2)', '0-96'],
#  [0, 'T88', 16, 20, 'Form', 'Tablet, Delayed Release (E.C.)', '0-96'],
#  [0, 'T89', 20, 21, 'Route', 'PO', '0-96'],
#  [0, 'T90', 21, 26, 'Frequency', 'TID (3 times a day)', '0-96'],
#  [0, 'T12', 1, 3, 'Drug', 'Hyoscyamine Sulfate', '0-103'],
#  [0, 'T13', 3, 5, 'Strength', '0.125 mg', '0-103'],
#  [0, 'T14', 5, 6, 'Form', 'Tablet', '0-103'],
#  [0, 'T91', 7, 8, 'Route', 'Sublingual', '0-103'],
#  [0, 'T92', 9, 11, 'Dosage', 'One (1)', '0-103'],
#  [0, 'T93', 11, 12, 'Form', 'Tablet', '0-103'],
#  [0, 'T94', 13, 14, 'Route', 'Sublingual', '0-103'],
#  [0, 'T119', 14, 15, 'Route', 'Sublingual', '0-103'],
#  [0, 'T95', 15, 20, 'Frequency', 'QID (4 times a day)', '0-103'],
#  [0, 'T5', 5, 7, 'Drug', 'Ciprofloxaci n', '0-112'],
#  [0, 'T2', 7, 9, 'Strength', '750 mg', '0-112'],
#  [0, 'T96', 9, 10, 'Form', 'Tablet', '0-112'],
#  [0, 'T97', 11, 13, 'Dosage', 'One (1)', '0-112'],
#  [0, 'T3', 13, 14, 'Form', 'Tablet', '0-112'],
#  [0, 'T4', 14, 15, 'Route', 'PO', '0-112'],
#  [0, 'T98', 15, 18, 'Frequency', 'twice a day', '0-112'],
#  [0, 'T99', 18, 21, 'Duration', 'for 11 days', '0-112'],
#  [0, 'T100', 3, 4, 'Drug', 'antibiotics', '0-120'],
#  [1, 'T11', 29, 30, 'Drug', 'Heparin', '1-0'],
#  [1, 'T12', 30, 32, 'Dosage', '5,000 units', '1-0'],
#  [1, 'T31', 32, 33, 'Route', 'subq', '1-0'],
#  [1, 'T32', 33, 34, 'Frequency', 'q.8.', '1-0'],
#  [1, 'T13', 1, 2, 'Drug', 'Acetaminophen', '1-4'],
#  [1, 'T14', 2, 4, 'Strength', '325 mg', '1-4'],
#  [1, 'T16', 4, 5, 'Dosage', '1-2', '1-4'],
#  [1, 'T15', 5, 6, 'Form', 'tablets', '1-4'],
#  [1, 'T17', 6, 7, 'Route', 'p.o.', '1-4'],
#  [1, 'T33', 7, 9, 'Frequency', 'q.4-6h. prn.', '1-4'],
#  [1, 'T30', 1, 3, 'Drug', 'Olanzapin e', '1-10'],
#  [1, 'T27', 3, 5, 'Strength', '2.5 mg', '1-10'],
#  [1, 'T29', 5, 6, 'Route', 'p.o.', '1-10'],
#  [1, 'T28', 6, 8, 'Frequency', 'q.i.d. prn.', '1-10'],
#  [1, 'T6', 1, 2, 'Drug', 'Docusate', '1-14'],
#  [1, 'T7', 2, 4, 'Strength', '100 mg', '1-14'],
#  [1, 'T9', 4, 5, 'Route', 'p.o.', '1-14'],
#  [1, 'T8', 5, 7, 'Frequency', 'b.i.d. prn.', '1-14'],
#  [1, 'T34', 1, 2, 'Drug', 'Senna', '1-18'],
#  [1, 'T18', 2, 4, 'Strength', '8.6 mg', '1-18'],
#  [1, 'T20', 4, 5, 'Route', 'p.o.', '1-18'],
#  [1, 'T19', 5, 7, 'Frequency', 'b.i.d. prn.', '1-18'],
#  [1, 'T1', 1, 3, 'Drug', 'Carbidopa/ levodopa', '1-22'],
#  [1, 'T35', 3, 5, 'Strength', '25/100 mg', '1-22'],
#  [1, 'T3', 5, 6, 'Dosage', 'one', '1-22'],
#  [1, 'T2', 6, 7, 'Form', 'tablet', '1-22'],
#  [1, 'T5', 7, 8, 'Route', 'p.o.', '1-22'],
#  [1, 'T4', 8, 9, 'Frequency', 't.i.d.', '1-22'],
#  [1, 'T36', 1, 2, 'Drug', 'Levothyroxine', '1-28'],
#  [1, 'T21', 2, 4, 'Strength', '100 mcg', '1-28'],
#  [1, 'T22', 4, 5, 'Route', 'p.o.', '1-28'],
#  [1, 'T37', 5, 6, 'Frequency', 'q.d.', '1-28'],
#  [1, 'T23', 1, 3, 'Drug', 'Valsartan/ hydrochlorothiazide', '1-32'],
#  [1, 'T38', 3, 5, 'Strength', '80/12.5 mg', '1-32'],
#  [1, 'T25', 5, 6, 'Dosage', 'one', '1-32'],
#  [1, 'T24', 6, 7, 'Form', 'tablet', '1-32'],
#  [1, 'T26', 7, 8, 'Route', 'p.o.', '1-32'],
#  [1, 'T39', 8, 9, 'Frequency', 'q.d.', '1-32'],
#  [1, 'T40', 10, 13, 'Drug', 'thyroid replacement medication', '1-38'],
#  [1, 'T10', 35, 36, 'Drug', 'Lithium', '1-38'],
#  [2, 'T1', 15, 16, 'Drug', 'Penicillins', '2-0'],
#  [2, 'T2', 2, 3, 'Reason', 'hypertensive', '2-1'],
#  [2, 'T3', 7, 8, 'Drug', 'Labetolol', '2-1'],
#  [2, 'T4', 8, 9, 'Route', 'drip', '2-1'],
#  [2, 'T5', 10, 14, 'Reason', 'adequate blood pressure control', '2-1'],
#  [2, 'T7', 5, 6, 'Drug', 'antibiotics', '2-5'],
#  [2, 'T8', 8, 11, 'Reason', 'ventilator associated pneumonia', '2-5'],
#  [2, 'T9', 13, 16, 'Reason', 'positive blood cultures', '2-5'],
#  [2, 'T10', 5, 6, 'Route', 'IV', '2-8'],
#  [2, 'T11', 6, 7, 'Drug', 'Esmolol', '2-8'],
#  [2, 'T12', 8, 9, 'Route', 'IV', '2-8'],
#  [2, 'T13', 9, 10, 'Drug', 'Nipride', '2-8'],
#  [2, 'T14', 12, 13, 'Drug', 'HCTZ', '2-8'],
#  [2, 'T15', 13, 14, 'Strength', '25', '2-8'],
#  [2, 'T16', 14, 15, 'Frequency', 'qd', '2-8'],
#  [2, 'T17', 16, 17, 'Drug', 'Zocor', '2-8'],
#  [2, 'T18', 18, 19, 'Drug', 'Lisinopril', '2-8'],
#  [2, 'T19', 19, 20, 'Strength', '10', '2-8'],
#  [2, 'T20', 22, 23, 'Drug', 'Viagra', '2-8'],
#  [2, 'T21', 23, 24, 'Frequency', 'prn', '2-8'],
#  [2, 'T22', 24, 25, 'Drug', 'Ciprofloxacin', '2-20'],
#  [2, 'T23', 25, 27, 'Strength', '500 mg', '2-20'],
#  [2, 'T24', 27, 28, 'Form', 'Tablet', '2-20'],
#  [2, 'T25', 29, 31, 'Dosage', 'One (1)', '2-20'],
#  [2, 'T26', 31, 32, 'Form', 'Tablet', '2-20'],
#  [2, 'T27', 32, 33, 'Route', 'PO', '2-20'],
#  [2, 'T28', 33, 34, 'Frequency', 'Q12H', '2-20'],
#  [2, 'T29', 1, 2, 'Drug', 'Vancomycin', '2-27'],
#  [2, 'T30', 2, 4, 'Form', 'in Dextrose', '2-27'],
#  [2, 'T31', 4, 7, 'Strength', '1 gram/200 mL', '2-27'],
#  [2, 'T32', 7, 8, 'Form', 'Piggyback', '2-27'],
#  [2, 'T33', 9, 11, 'Dosage', 'One (1)', '2-27'],
#  [2, 'T34', 11, 12, 'Route', 'Intravenous', '2-27'],
#  [2, 'T35', 12, 17, 'Frequency', 'Q 12H (Every 12 Hours)', '2-27'],
#  [2, 'T36', 1, 2, 'Drug', 'Atorvastatin', '2-34'],
#  [2, 'T37', 2, 4, 'Strength', '20 mg', '2-34'],
#  [2, 'T38', 4, 5, 'Form', 'Tablet', '2-34'],
#  [2, 'T39', 6, 8, 'Dosage', 'One (1)', '2-34'],
#  [2, 'T40', 8, 9, 'Form', 'Tablet', '2-34'],
#  [2, 'T41', 9, 10, 'Route', 'PO', '2-34'],
#  [2, 'T42', 10, 11, 'Frequency', 'DAILY', '2-34'],
#  [2, 'T6', 1, 2, 'Form', 'Tablet(s)', '2-41'],
#  [2, 'T43', 4, 5, 'Drug', 'Aspirin', '2-42'],
#  [2, 'T44', 5, 7, 'Strength', '81 mg', '2-42'],
#  [2, 'T45', 7, 9, 'Form', 'Tablet, Chewable', '2-42'],
#  [2, 'T46', 10, 12, 'Dosage', 'One (1)', '2-42'],
#  [2, 'T47', 12, 14, 'Form', 'Tablet, Chewable', '2-42'],
#  [2, 'T48', 14, 15, 'Route', 'PO', '2-42'],
#  [2, 'T49', 15, 17, 'Frequency', 'DAILY (Daily)', '2-42'],
#  [2, 'T80', 1, 3, 'Form', 'Tablet, Chewable(s)', '2-49'],
#  [2, 'T50', 5, 6, 'Drug', 'Furosemide', '2-50'],
#  [2, 'T51', 6, 8, 'Strength', '10 mg/mL', '2-50'],
#  [2, 'T52', 8, 9, 'Form', 'Solution', '2-50'],
#  [2, 'T53', 10, 13, 'Dosage', 'Twenty (20) mg', '2-50'],
#  [2, 'T54', 13, 14, 'Form', 'Injection', '2-50'],
#  [2, 'T55', 14, 17, 'Frequency', 'twice a day', '2-50'],
#  [2, 'T56', 17, 20, 'Duration', 'for 7 days', '2-50'],
#  [2, 'T57', 4, 6, 'Drug', 'Potassium Chloride', '2-57'],
#  [2, 'T58', 6, 8, 'Strength', '20 mEq', '2-57'],
#  [2, 'T59', 8, 11, 'Form', 'Tab Sust.Rel. Particle/Crystal', '2-57'],
#  [2, 'T60', 12, 14, 'Dosage', 'One (1)', '2-57'],
#  [2, 'T61', 14, 17, 'Form', 'Tab Sust.Rel. Particle/Crystal', '2-57'],
#  [2, 'T62', 17, 18, 'Route', 'PO', '2-57'],
#  [2, 'T63', 18, 21, 'Frequency', 'once a day', '2-57'],
#  [2, 'T64', 21, 24, 'Duration', 'for 7 days', '2-57'],
#  [2, 'T65', 3, 4, 'Drug', 'Pantoprazole', '2-66'],
#  [2, 'T66', 4, 6, 'Strength', '40 mg', '2-66'],
#  [2, 'T67', 6, 10, 'Form', 'Tablet, Delayed Release (E.C.)', '2-66'],
#  [2, 'T68', 11, 13, 'Dosage', 'One (1)', '2-66'],
#  [2, 'T69', 13, 17, 'Form', 'Tablet, Delayed Release (E.C.)', '2-66'],
#  [2, 'T70', 17, 18, 'Route', 'PO', '2-66'],
#  [2, 'T71', 18, 22, 'Frequency', 'Q24H (every 24 hours)', '2-66'],
#  [2, 'T82', 1, 5, 'Form', 'Tablet, Delayed Release (E.C.)', '2-73'],
#  [2, 'T72', 3, 4, 'Drug', 'Labetalol', '2-74'],
#  [2, 'T73', 4, 6, 'Strength', '200 mg', '2-74'],
#  [2, 'T74', 6, 7, 'Form', 'Tablet', '2-74'],
#  [2, 'T75', 8, 10, 'Dosage', 'Four (4)', '2-74'],
#  [2, 'T76', 10, 11, 'Form', 'Tablet', '2-74'],
#  [2, 'T77', 11, 12, 'Route', 'PO', '2-74'],
#  [2, 'T78', 12, 17, 'Frequency', 'TID (3 times a day)', '2-74'],
#  [2, 'T83', 1, 2, 'Form', 'Tablet(s)', '2-81'],
#  [2, 'T79', 38, 39, 'Drug', 'antibiotics', '2-82'],
#  [3, 'T65', 9, 11, 'Drug', 'Sulfa (Sulfonamides)', '3-0'],
#  [3, 'T13', 12, 13, 'Drug', 'Heparin', '3-0'],
#  [3, 'T117', 56, 57, 'Reason', 'LGIB', '3-0'],
#  [3, 'T109', 4, 5, 'Drug', 'fluids', '3-3'],
#  [3, 'T66', 8, 9, 'Dosage', '2U', '3-3'],
#  [3, 'T67', 10, 11, 'Drug', 'FFP', '3-3'],
#  [3, 'T68', 12, 13, 'Dosage', '2U', '3-3'],
#  [3, 'T69', 14, 15, 'Drug', 'PRBC', '3-3'],
#  [3, 'T22', 10, 11, 'Drug', 'Heparin', '3-8'],
#  [3, 'T70', 11, 12, 'Route', 'sc', '3-8'],
#  [3, 'T23', 12, 13, 'Frequency', 'TID', '3-8'],
#  [3, 'T61', 14, 16, 'Reason', 'DVT prophylaxis', '3-8'],
#  [3, 'T56', 52, 53, 'Drug', 'coumadin', '3-12'],
#  [3, 'T62', 54, 56, 'Reason', 'DVT prophylaxis', '3-12'],
#  [3, 'T110', 8, 9, 'Reason', 'DVT', '3-14'],
#  [3, 'T24', 1, 2, 'Drug', 'lovenox', '3-15'],
#  [3, 'T38', 3, 4, 'Drug', 'plavix', '3-15'],
#  [3, 'T45', 5, 6, 'Drug', 'aspirin', '3-15'],
#  [3, 'T119', 10, 12, 'ADE', 'thigh hematoma', '3-15'],
#  [3, 'T111', 2, 3, 'Drug', 'steroids', '3-19'],
#  [3, 'T54', 9, 10, 'Drug', 'heparin', '3-20'],
#  [3, 'T71', 10, 11, 'Route', 'SQ', '3-20'],
#  [3, 'T120', 16, 17, 'ADE', 'BRBPR', '3-20'],
#  [3, 'T121', 18, 19, 'ADE', 'hypotension', '3-20'],
#  [3, 'T112', 7, 8, 'Drug', 'barium', '3-24'],
#  [3, 'T122', 1, 2, 'Reason', 'LGIB', '3-25'],
#  [3, 'T72', 2, 4, 'Dosage', '2 units', '3-26'],
#  [3, 'T73', 5, 6, 'Drug', 'FFP', '3-26'],
#  [3, 'T74', 7, 9, 'Dosage', '2 units', '3-26'],
#  [3, 'T75', 10, 11, 'Drug', "PRBC's", '3-26'],
#  [3, 'T7', 10, 11, 'Drug', 'GoLytely', '3-30'],
#  [3, 'T123', 14, 18, 'Reason', 'preparation for a colonoscopy', '3-30'],
#  [3, 'T79', 22, 24, 'Dosage', '2 units', '3-32'],
#  [3, 'T78', 25, 26, 'Drug', "PRBC's", '3-32'],
#  [3, 'T77', 29, 30, 'Route', 'IV', '3-32'],
#  [3, 'T76', 30, 31, 'Drug', 'PPI', '3-32'],
#  [3, 'T80', 1, 3, 'Reason', 'Rheumatoid Arthritis', '3-36'],
#  [3, 'T6', 19, 20, 'Drug', 'prednisone', '3-36'],
#  [3, 'T124', 20, 21, 'Dosage', 'taper', '3-36'],
#  [3, 'T49', 3, 5, 'Strength', '20 mg', '3-39'],
#  [3, 'T116', 8, 11, 'Reason', 'prevent adrenal insufficiency', '3-39'],
#  [3, 'T125', 1, 2, 'ADE', 'Leukocytosis', '3-41'],
#  [3, 'T48', 8, 9, 'Drug', 'prednisone', '3-41'],
#  [3, 'T81', 1, 2, 'Reason', 'Afib', '3-43'],
#  [3, 'T21', 3, 4, 'Drug', 'Sotalol', '3-43'],
#  [3, 'T126', 1, 2, 'Reason', 'FEN', '3-45'],
#  [3, 'T127', 5, 6, 'Drug', 'IVFs', '3-45'],
#  [3, 'T82', 9, 10, 'Drug', 'PPI', '3-47'],
#  [3, 'T63', 11, 13, 'Reason', 'GI prophylaxis', '3-47'],
#  [3, 'T17', 13, 14, 'Drug', 'Lipitor', '3-49'],
#  [3, 'T18', 14, 15, 'Strength', '10mg', '3-49'],
#  [3, 'T83', 15, 16, 'Frequency', 'QD', '3-49'],
#  [3, 'T84', 16, 18, 'Form', 'Enteric coated', '3-49'],
#  [3, 'T33', 18, 19, 'Drug', 'Aspirin', '3-49'],
#  [3, 'T32', 19, 21, 'Strength', '81 mg', '3-49'],
#  [3, 'T46', 21, 22, 'Drug', 'Nexium', '3-49'],
#  [3, 'T47', 22, 23, 'Strength', '40mg', '3-49'],
#  [3, 'T85', 23, 24, 'Frequency', 'QD', '3-49'],
#  [3, 'T11', 24, 25, 'Drug', 'Sotalol', '3-49'],
#  [3, 'T12', 25, 26, 'Strength', '40mg', '3-49'],
#  [3, 'T86', 26, 27, 'Frequency', 'QD', '3-49'],
#  [3, 'T19', 27, 28, 'Drug', 'Prednisone', '3-49'],
#  [3, 'T20', 28, 29, 'Strength', '20mg', '3-49'],
#  [3, 'T87', 29, 30, 'Frequency', 'QD', '3-49'],
#  [3, 'T88', 3, 4, 'Route', 'sq', '3-64'],
#  [3, 'T55', 4, 5, 'Drug', 'heparin', '3-64'],
#  [3, 'T53', 6, 8, 'Drug', 'Pantoprazol e', '3-66'],
#  [3, 'T50', 8, 10, 'Strength', '40 mg', '3-66'],
#  [3, 'T52', 10, 11, 'Route', 'PO', '3-66'],
#  [3, 'T51', 11, 12, 'Frequency', 'Q12H', '3-66'],
#  [3, 'T16', 12, 14, 'Drug', 'Prednison e', '3-66'],
#  [3, 'T14', 14, 16, 'Strength', '20 mg', '3-66'],
#  [3, 'T15', 16, 17, 'Route', 'PO', '3-66'],
#  [3, 'T89', 17, 18, 'Frequency', 'DAILY', '3-66'],
#  [3, 'T39', 18, 19, 'Drug', 'Acetaminophen', '3-66'],
#  [3, 'T90', 19, 21, 'Strength', '325-650 mg', '3-66'],
#  [3, 'T41', 21, 22, 'Route', 'PO', '3-66'],
#  [3, 'T40', 22, 24, 'Frequency', 'Q4 -6H:PRN', '3-66'],
#  [3, 'T25', 24, 26, 'Drug', 'Sotalol HCl', '3-66'],
#  [3, 'T26', 26, 28, 'Strength', '40 mg', '3-66'],
#  [3, 'T27', 28, 29, 'Route', 'PO', '3-66'],
#  [3, 'T91', 29, 30, 'Frequency', 'DAILY', '3-66'],
#  [3, 'T44', 30, 32, 'Drug', 'Atorvastati n', '3-66'],
#  [3, 'T42', 32, 34, 'Strength', '10 mg', '3-66'],
#  [3, 'T43', 34, 35, 'Route', 'PO', '3-66'],
#  [3, 'T92', 35, 36, 'Frequency', 'DAILY', '3-66'],
#  [3, 'T31', 35, 37, 'Drug', 'Atorvastati n', '3-86'],
#  [3, 'T28', 37, 39, 'Strength', '10 mg', '3-86'],
#  [3, 'T93', 39, 40, 'Form', 'Tablet', '3-86'],
#  [3, 'T94', 41, 43, 'Dosage', 'One (1)', '3-86'],
#  [3, 'T29', 43, 44, 'Form', 'Tablet', '3-86'],
#  [3, 'T30', 44, 45, 'Route', 'PO', '3-86'],
#  [3, 'T95', 45, 47, 'Frequency', 'DAILY (Daily)', '3-86'],
#  [3, 'T34', 1, 2, 'Drug', 'Acetaminophen', '3-93'],
#  [3, 'T35', 2, 4, 'Strength', '325 mg', '3-93'],
#  [3, 'T96', 4, 5, 'Form', 'Tablet', '3-93'],
#  [3, 'T97', 6, 8, 'Dosage', 'Two (2)', '3-93'],
#  [3, 'T36', 8, 9, 'Form', 'Tablet', '3-93'],
#  [3, 'T37', 9, 10, 'Route', 'PO', '3-93'],
#  [3, 'T64', 16, 17, 'Reason', 'pain', '3-93'],
#  [3, 'T8', 1, 2, 'Drug', 'Pantoprazole', '3-100'],
#  [3, 'T9', 2, 4, 'Strength', '40 mg', '3-100'],
#  [3, 'T10', 4, 9, 'Form', 'Tablet , Delayed Release (E.C.)', '3-100'],
#  [3, 'T98', 10, 12, 'Dosage', 'One (1)', '3-100'],
#  [3, 'T99', 12, 16, 'Form', 'Tablet, Delayed Release (E.C.)', '3-100'],
#  [3, 'T100', 16, 17, 'Route', 'PO', '3-100'],
#  [3, 'T101', 17, 21, 'Frequency', 'Q12H (every 12 hours)', '3-100'],
#  [3, 'T57', 1, 2, 'Drug', 'Prednisone', '3-107'],
#  [3, 'T58', 2, 4, 'Strength', '20 mg', '3-107'],
#  [3, 'T102', 4, 5, 'Form', 'Tablet', '3-107'],
#  [3, 'T103', 6, 8, 'Dosage', 'One (1)', '3-107'],
#  [3, 'T59', 8, 9, 'Form', 'Tablet', '3-107'],
#  [3, 'T60', 9, 10, 'Route', 'PO', '3-107'],
#  [3, 'T104', 10, 12, 'Frequency', 'DAILY (Daily)', '3-107'],
#  [3, 'T1', 1, 2, 'Drug', 'Sotalol', '3-114'],
#  [3, 'T2', 2, 4, 'Strength', '80 mg', '3-114'],
#  [3, 'T105', 4, 5, 'Form', 'Tablet', '3-114'],
#  [3, 'T4', 6, 7, 'Dosage', '0.5', '3-114'],
#  [3, 'T3', 7, 8, 'Form', 'Tablet', '3-114'],
#  [3, 'T5', 8, 9, 'Route', 'PO', '3-114'],
#  [3, 'T106', 9, 11, 'Frequency', 'DAILY (Daily)', '3-114'],
#  [4, 'T1', 40, 41, 'Drug', 'Lisinopril', '4-0'],
#  [4, 'T2', 41, 42, 'Strength', '2.5mg', '4-0'],
#  [4, 'T3', 42, 43, 'Frequency', 'daily', '4-0'],
#  [5, 'T366', 15, 16, 'Drug', 'Reglan', '5-0'],
#  [5, 'T369', 17, 18, 'Drug', 'sorbitol', '5-0'],
#  [5, 'T370', 19, 20, 'Drug', 'aspirin', '5-0'],
#  [5, 'T371', 21, 22, 'Drug', 'hydrochlorothiazide', '5-0'],
#  [5, 'T37', 5, 6, 'Strength', '40meq', '5-4'],
#  [5, 'T48', 7, 8, 'Dosage', '1L', '5-4'],
#  [5, 'T54', 8, 9, 'Drug', 'NS', '5-4'],
#  [5, 'T62', 10, 11, 'Drug', 'duoneb', '5-4'],
#  [5, 'T80', 12, 13, 'Dosage', '1', '5-4'],
#  [5, 'T84', 14, 15, 'Drug', 'zosyn', '5-4'],
#  [5, 'T96', 15, 16, 'Strength', '3.25g', '5-4'],
#  [5, 'T106', 17, 18, 'Dosage', '1', '5-4'],
#  [5, 'T111', 19, 20, 'Drug', 'atarax', '5-4'],
#  [5, 'T372', 4, 5, 'Drug', 'vanc', '5-13'],
#  [5, 'T373', 6, 7, 'Drug', 'zosyn', '5-13'],
#  [5, 'T374', 1, 2, 'Drug', 'vancomycin', '5-15'],
#  [5, 'T375', 3, 4, 'Drug', 'zosyn', '5-16'],
#  [5, 'T376', 7, 8, 'Duration', '7-day', '5-16'],
#  [5, 'T377', 8, 9, 'ADE', 'oversedation', '5-18'],
#  [5, 'T3', 12, 13, 'Route', 'IV', '5-18'],
#  [5, 'T379', 13, 14, 'Drug', 'morphine', '5-18'],
#  [5, 'T380', 15, 16, 'Drug', 'klonopin', '5-18'],
#  [5, 'T381', 16, 17, 'Frequency', 'PRN', '5-18'],
#  [5, 'T382', 19, 20, 'Drug', 'amitryptiline', '5-18'],
#  [5, 'T383', 22, 23, 'Drug', 'antiemetics', '5-18'],
#  [5, 'T384', 4, 5, 'Drug', 'IVF', '5-25'],
#  [5, 'T385', 1, 2, 'Drug', 'vancomycin', '5-26'],
#  [5, 'T1', 13, 14, 'Drug', 'mirtazapine', '5-27'],
#  [5, 'T2', 14, 16, 'Strength', '7.5 mg', '5-27'],
#  [5, 'T4', 16, 21, 'Frequency', 'QPM (1 hour before meals)', '5-27'],
#  [5, 'T5', 1, 2, 'Reason', 'depression', '5-30'],
#  [5, 'T6', 3, 4, 'Reason', 'COPD', '5-31'],
#  [5, 'T7', 10, 11, 'Drug', 'steroid', '5-31'],
#  [5, 'T8', 11, 12, 'Dosage', 'taper', '5-31'],
#  [5, 'T9', 2, 3, 'Drug', 'furosemide', '5-34'],
#  [5, 'T10', 4, 5, 'Drug', 'digoxin', '5-34'],
#  [5, 'T11', 1, 2, 'Drug', 'digoxin', '5-36'],
#  [5, 'T12', 5, 6, 'Drug', 'lasix', '5-37'],
#  [5, 'T13', 2, 3, 'Drug', 'Lumigan', '5-38'],
#  [5, 'T14', 3, 4, 'Strength', '0.3', '5-38'],
#  [5, 'T15', 5, 6, 'Route', 'OU', '5-38'],
#  [5, 'T16', 6, 7, 'Frequency', 'QHS', '5-38'],
#  [5, 'T17', 8, 9, 'Reason', 'DEPRESSION', '5-38'],
#  [5, 'T18', 10, 11, 'Reason', 'ANXIETY', '5-38'],
#  [5, 'T20', 2, 3, 'Drug', 'klonopin', '5-44'],
#  [5, 'T21', 5, 6, 'Frequency', 'PRN', '5-44'],
#  [5, 'T22', 13, 14, 'Drug', 'amitryptiline', '5-44'],
#  [5, 'T23', 15, 16, 'Drug', 'citalopram', '5-44'],
#  [5, 'T24', 1, 3, 'Reason', 'POLYMYALGIA RHEUMATICA', '5-48'],
#  [5, 'T25', 6, 7, 'Drug', 'prednisone', '5-48'],
#  [5, 'T26', 3, 5, 'Reason', 'adrenal insufficiency', '5-50'],
#  [5, 'T27', 2, 3, 'Drug', 'prednisone', '5-51'],
#  [5, 'T28', 3, 4, 'Strength', '5mg', '5-51'],
#  [5, 'T29', 4, 5, 'Route', 'PO', '5-51'],
#  [5, 'T30', 5, 6, 'Frequency', 'daily', '5-51'],
#  [5, 'T31', 10, 11, 'Drug', 'calcium', '5-51'],
#  [5, 'T32', 12, 14, 'Drug', 'vitamin D', '5-51'],
#  [5, 'T33', 18, 19, 'Drug', 'metoprolol', '5-57'],
#  [5, 'T34', 11, 12, 'Drug', 'Miralax', '5-58'],
#  [5, 'T35', 12, 13, 'Frequency', 'PRN', '5-58'],
#  [5, 'T36', 14, 15, 'Drug', 'Calcium', '5-58'],
#  [5, 'T38', 16, 18, 'Drug', 'Vitamin D3', '5-58'],
#  [5, 'T39', 18, 20, 'Strength', '50,000 IU', '5-58'],
#  [5, 'T40', 20, 21, 'Route', 'PO', '5-58'],
#  [5, 'T41', 21, 22, 'Frequency', 'monthly', '5-58'],
#  [5, 'T42', 23, 24, 'Drug', 'Protonix', '5-58'],
#  [5, 'T43', 24, 25, 'Strength', '40mg', '5-58'],
#  [5, 'T44', 25, 26, 'Route', 'PO', '5-58'],
#  [5, 'T45', 26, 27, 'Frequency', 'daily', '5-58'],
#  [5, 'T46', 28, 29, 'Drug', 'Klor-Con', '5-58'],
#  [5, 'T47', 29, 30, 'Strength', '20meq', '5-58'],
#  [5, 'T49', 30, 31, 'Route', 'PO', '5-58'],
#  [5, 'T50', 31, 32, 'Frequency', 'BID', '5-58'],
#  [5, 'T52', 33, 35, 'Drug', 'Metoprolol tart', '5-58'],
#  [5, 'T53', 35, 36, 'Strength', '50mg', '5-58'],
#  [5, 'T55', 36, 37, 'Route', 'PO', '5-58'],
#  [5, 'T56', 37, 38, 'Frequency', 'BID', '5-58'],
#  [5, 'T57', 39, 40, 'Drug', 'Fluticasone', '5-58'],
#  [5, 'T58', 40, 41, 'Form', 'spray', '5-58'],
#  [5, 'T59', 41, 42, 'Strength', '50mcg', '5-58'],
#  [5, 'T61', 42, 44, 'Frequency', 'twice daily', '5-58'],
#  [5, 'T64', 45, 46, 'Drug', 'Tylenol', '5-58'],
#  [5, 'T65', 46, 47, 'Strength', '650mg', '5-58'],
#  [5, 'T66', 47, 48, 'Route', 'PO', '5-58'],
#  [5, 'T68', 48, 50, 'Frequency', 'QID PRN', '5-58'],
#  [5, 'T69', 51, 52, 'Drug', 'Klonopin', '5-58'],
#  [5, 'T70', 52, 53, 'Strength', '1mg', '5-58'],
#  [5, 'T71', 53, 54, 'Route', 'PO', '5-58'],
#  [5, 'T72', 54, 56, 'Frequency', 'daily QHS', '5-58'],
#  [5, 'T74', 57, 58, 'Drug', 'Klonopin', '5-58'],
#  [5, 'T75', 58, 59, 'Strength', '0.5mg', '5-58'],
#  [5, 'T76', 59, 60, 'Route', 'PO', '5-58'],
#  [5, 'T78', 60, 62, 'Frequency', 'TID PRN', '5-58'],
#  [5, 'T79', 63, 64, 'Drug', 'Albuterol', '5-58'],
#  [5, 'T81', 64, 65, 'Route', 'neb', '5-58'],
#  [5, 'T82', 65, 67, 'Frequency', 'Q4hrs PRN', '5-58'],
#  [5, 'T83', 68, 69, 'Drug', 'Tramadol', '5-58'],
#  [5, 'T85', 69, 70, 'Strength', '50mg', '5-58'],
#  [5, 'T86', 70, 71, 'Route', 'PO', '5-58'],
#  [5, 'T88', 71, 73, 'Frequency', 'BID PRN', '5-58'],
#  [5, 'T89', 74, 77, 'Drug', 'Milk of Magnesia', '5-58'],
#  [5, 'T90', 77, 78, 'Frequency', 'PRN', '5-58'],
#  [5, 'T92', 79, 81, 'Drug', 'Fleet enema', '5-58'],
#  [5, 'T94', 81, 82, 'Frequency', 'PRN', '5-58'],
#  [5, 'T95', 83, 84, 'Drug', 'Robitussin', '5-58'],
#  [5, 'T97', 84, 85, 'Frequency', 'PRN', '5-58'],
#  [5, 'T98', 86, 87, 'Drug', 'Bisacodyl', '5-58'],
#  [5, 'T99', 87, 88, 'Strength', '10mg', '5-58'],
#  [5, 'T100', 88, 89, 'Form', 'supp', '5-58'],
#  [5, 'T101', 89, 90, 'Frequency', 'PRN', '5-58'],
#  [5, 'T102', 91, 92, 'Drug', 'Prednisone', '5-58'],
#  [5, 'T103', 92, 93, 'Strength', '5mg', '5-58'],
#  [5, 'T104', 95, 96, 'Strength', '7.5mg', '5-58'],
#  [5, 'T105', 96, 97, 'Route', 'PO', '5-58'],
#  [5, 'T107', 97, 98, 'Frequency', 'daily', '5-58'],
#  [5, 'T108', 99, 100, 'Drug', 'Lumigan', '5-58'],
#  [5, 'T109', 100, 101, 'Strength', '0.03', '5-58'],
#  [5, 'T110', 102, 103, 'Form', 'solution', '5-58'],
#  [5, 'T112', 103, 104, 'Frequency', 'QHS', '5-58'],
#  [5, 'T113', 105, 106, 'Drug', 'Lactulose', '5-58'],
#  [5, 'T114', 106, 107, 'Dosage', '30', '5-58'],
#  [5, 'T116', 108, 109, 'Route', 'PO', '5-58'],
#  [5, 'T117', 109, 114, 'Frequency', 'every other night at bedtime', '5-58'],
#  [5, 'T118', 115, 116, 'Drug', 'Amitryptiline', '5-58'],
#  [5, 'T119', 116, 117, 'Strength', '100mg', '5-58'],
#  [5, 'T120', 117, 118, 'Route', 'PO', '5-58'],
#  [5, 'T121', 118, 119, 'Frequency', 'QHS', '5-58'],
#  [5, 'T122', 120, 121, 'Drug', 'Lactobacillus', '5-58'],
#  [5, 'T123', 121, 122, 'Form', 'tabs', '5-58'],
#  [5, 'T124', 122, 123, 'Route', 'PO', '5-58'],
#  [5, 'T125', 123, 124, 'Frequency', 'TID', '5-58'],
#  [5, 'T126', 125, 126, 'Drug', 'Furosemide', '5-58'],
#  [5, 'T127', 126, 127, 'Strength', '60mg', '5-58'],
#  [5, 'T128', 127, 128, 'Route', 'PO', '5-58'],
#  [5, 'T129', 128, 129, 'Frequency', 'daily', '5-58'],
#  [5, 'T130', 130, 131, 'Drug', 'Digoxin', '5-58'],
#  [5, 'T131', 131, 132, 'Strength', '0.125mg', '5-58'],
#  [5, 'T132', 132, 133, 'Route', 'PO', '5-58'],
#  [5, 'T133', 133, 134, 'Frequency', 'daily', '5-58'],
#  [5, 'T134', 135, 136, 'Drug', 'Citalopram', '5-58'],
#  [5, 'T135', 136, 137, 'Strength', '30mg', '5-58'],
#  [5, 'T136', 137, 138, 'Route', 'PO', '5-58'],
#  [5, 'T137', 138, 139, 'Frequency', 'daily', '5-58'],
#  [5, 'T138', 140, 144, 'Drug', 'Bio E with selenium', '5-58'],
#  [5, 'T140', 144, 146, 'Form', 'soft gel', '5-58'],
#  [5, 'T141', 146, 147, 'Dosage', '1', '5-58'],
#  [5, 'T142', 147, 148, 'Form', 'tab', '5-58'],
#  [5, 'T143', 148, 149, 'Route', 'PO', '5-58'],
#  [5, 'T144', 149, 150, 'Frequency', 'daily', '5-58'],
#  [5, 'T145', 151, 152, 'Drug', 'Multivitamin', '5-58'],
#  [5, 'T146', 152, 153, 'Route', 'PO', '5-58'],
#  [5, 'T147', 153, 154, 'Frequency', 'daily', '5-58'],
#  [5, 'T148', 155, 156, 'Drug', 'Levaquin', '5-58'],
#  [5, 'T149', 156, 158, 'Strength', '750 mg', '5-58'],
#  [5, 'T151', 158, 160, 'Frequency', 'once daily', '5-58'],
#  [5, 'T152', 161, 163, 'Duration', '3 days', '5-58'],
#  [5, 'T153', 168, 169, 'Drug', 'Prednisone', '5-58'],
#  [5, 'T154', 169, 171, 'Strength', '5 mg', '5-58'],
#  [5, 'T155', 171, 172, 'Route', 'PO', '5-58'],
#  [5, 'T156', 172, 173, 'Frequency', 'daily', '5-58'],
#  [5, 'T157', 174, 175, 'Drug', 'Albuterol', '5-58'],
#  [5, 'T159', 175, 176, 'Form', 'neb', '5-58'],
#  [5, 'T160', 176, 177, 'Strength', '0.083', '5-58'],
#  [5, 'T161', 178, 179, 'Route', 'inhaled', '5-58'],
#  [5, 'T162', 179, 180, 'Frequency', 'QID', '5-58'],
#  [5, 'T163', 181, 183, 'Duration', '7 days', '5-58'],
#  [5, 'T164', 159, 161, 'Drug', 'Calcium 500', '5-166'],
#  [5, 'T166', 161, 163, 'Strength', '500 mg', '5-166'],
#  [5, 'T167', 163, 164, 'Drug', 'calcium', '5-166'],
#  [5, 'T168', 165, 167, 'Strength', '1,250 mg', '5-166'],
#  [5, 'T169', 168, 169, 'Form', 'Tablet', '5-166'],
#  [5, 'T170', 170, 172, 'Dosage', 'One (1)', '5-166'],
#  [5, 'T171', 172, 173, 'Form', 'Tablet', '5-166'],
#  [5, 'T172', 173, 174, 'Route', 'PO', '5-166'],
#  [5, 'T173', 174, 177, 'Frequency', 'twice a day', '5-166'],
#  [5, 'T174', 1, 2, 'Drug', 'Miralax', '5-175'],
#  [5, 'T175', 2, 4, 'Strength', '17 gram', '5-175'],
#  [5, 'T176', 4, 7, 'Form', 'Powder in Packet', '5-175'],
#  [5, 'T178', 8, 10, 'Dosage', 'One (1)', '5-175'],
#  [5, 'T180', 10, 11, 'Route', 'PO', '5-175'],
#  [5, 'T182', 11, 16, 'Frequency', 'once a day as needed', '5-175'],
#  [5, 'T183', 17, 18, 'Reason', 'constipation', '5-175'],
#  [5, 'T184', 1, 2, 'Drug', 'Klor-Con', '5-182'],
#  [5, 'T185', 2, 4, 'Strength', '20 mEq', '5-182'],
#  [5, 'T186', 4, 5, 'Form', 'Packet', '5-182'],
#  [5, 'T187', 6, 8, 'Dosage', 'One (1)', '5-182'],
#  [5, 'T188', 8, 9, 'Route', 'PO', '5-182'],
#  [5, 'T189', 9, 12, 'Frequency', 'twice a day', '5-182'],
#  [5, 'T191', 1, 3, 'Drug', 'metoprolol tartrate', '5-188'],
#  [5, 'T192', 3, 5, 'Strength', '50 mg', '5-188'],
#  [5, 'T193', 5, 6, 'Form', 'Tablet', '5-188'],
#  [5, 'T194', 7, 9, 'Dosage', 'One (1)', '5-188'],
#  [5, 'T196', 9, 10, 'Form', 'Tablet', '5-188'],
#  [5, 'T197', 10, 11, 'Route', 'PO', '5-188'],
#  [5, 'T198', 11, 12, 'Frequency', 'BID', '5-188'],
#  [5, 'T199', 1, 2, 'Drug', 'Protonix', '5-195'],
#  [5, 'T200', 2, 4, 'Strength', '40 mg', '5-195'],
#  [5, 'T202', 4, 8, 'Form', 'Tablet, Delayed Release (E.C.)', '5-195'],
#  [5, 'T203', 9, 11, 'Dosage', 'One (1)', '5-195'],
#  [5, 'T204', 11, 14, 'Form', 'Tablet, Delayed Release', '5-195'],
#  [5, 'T205', 7, 8, 'Route', 'PO', '5-200'],
#  [5, 'T206', 8, 11, 'Frequency', 'once a day', '5-200'],
#  [5, 'T207', 1, 2, 'Drug', 'fluticasone', '5-202'],
#  [5, 'T209', 2, 4, 'Strength', '50 mcg/actuation', '5-202'],
#  [5, 'T210', 4, 5, 'Form', 'Spray', '5-202'],
#  [5, 'T211', 6, 7, 'Form', 'Suspension', '5-202'],
#  [5, 'T212', 8, 10, 'Dosage', 'One (1)', '5-202'],
#  [5, 'T213', 10, 11, 'Route', 'Nasal', '5-202'],
#  [5, 'T214', 11, 14, 'Frequency', 'twice a day', '5-202'],
#  [5, 'T215', 1, 2, 'Drug', 'Tylenol', '5-209'],
#  [5, 'T216', 2, 4, 'Strength', '325 mg', '5-209'],
#  [5, 'T217', 4, 5, 'Form', 'Tablet', '5-209'],
#  [5, 'T218', 6, 8, 'Dosage', 'Two (2)', '5-209'],
#  [5, 'T220', 8, 9, 'Form', 'Tablet', '5-209'],
#  [5, 'T221', 9, 10, 'Route', 'PO', '5-209'],
#  [5, 'T223', 10, 16, 'Frequency', 'four times a day as needed', '5-209'],
#  [5, 'T224', 17, 18, 'Reason', 'pain', '5-209'],
#  [5, 'T225', 2, 3, 'Drug', 'clonazepam', '5-217'],
#  [5, 'T226', 3, 5, 'Strength', '0.5 mg', '5-217'],
#  [5, 'T227', 5, 6, 'Form', 'Tablet', '5-217'],
#  [5, 'T229', 7, 9, 'Dosage', 'One (1)', '5-217'],
#  [5, 'T230', 9, 10, 'Form', 'Tablet', '5-217'],
#  [5, 'T231', 10, 11, 'Route', 'PO', '5-217'],
#  [5, 'T233', 11, 18, 'Frequency', 'TID (3 times a day) as needed', '5-217'],
#  [5, 'T234', 19, 20, 'Reason', 'anxiety', '5-217'],
#  [5, 'T235', 21, 22, 'Reason', 'nausea', '5-217'],
#  [5, 'T236', 1, 3, 'Drug', 'albuterol sulfate', '5-226'],
#  [5, 'T237', 3, 7, 'Strength', '2.5 mg /3 mL', '5-226'],
#  [5, 'T238', 8, 9, 'Strength', '0.083', '5-226'],
#  [5, 'T239', 10, 11, 'Form', 'Solution', '5-226'],
#  [5, 'T240', 12, 13, 'Form', 'Nebulization', '5-226'],
#  [5, 'T241', 14, 16, 'Dosage', 'One (1)', '5-226'],
#  [5, 'T242', 16, 17, 'Route', 'Inhalation', '5-226'],
#  [5, 'T243', 17, 23, 'Frequency', 'every four (4) hours as needed', '5-226'],
#  [5, 'T244', 24, 25, 'Reason', 'SOB', '5-226'],
#  [5, 'T245', 26, 27, 'Reason', 'wheeze', '5-226'],
#  [5, 'T246', 1, 2, 'Drug', 'prednisone', '5-236'],
#  [5, 'T247', 2, 4, 'Strength', '5 mg', '5-236'],
#  [5, 'T248', 4, 5, 'Form', 'Tablet', '5-236'],
#  [5, 'T250', 6, 8, 'Dosage', 'One (1)', '5-236'],
#  [5, 'T251', 8, 9, 'Form', 'Tablet', '5-236'],
#  [5, 'T252', 9, 10, 'Route', 'PO', '5-236'],
#  [5, 'T253', 10, 11, 'Frequency', 'DAILY', '5-236'],
#  [5, 'T254', 1, 2, 'Drug', 'bimatoprost', '5-243'],
#  [5, 'T255', 2, 3, 'Strength', '0.03', '5-243'],
#  [5, 'T256', 4, 5, 'Form', 'Drops', '5-243'],
#  [5, 'T258', 6, 8, 'Dosage', 'One (1)', '5-243'],
#  [5, 'T259', 8, 9, 'Route', 'Ophthalmic', '5-243'],
#  [5, 'T260', 9, 10, 'Frequency', 'QHS', '5-243'],
#  [5, 'T261', 1, 2, 'Drug', 'amitriptyline', '5-249'],
#  [5, 'T262', 2, 4, 'Strength', '50 mg', '5-249'],
#  [5, 'T263', 4, 5, 'Form', 'Tablet', '5-249'],
#  [5, 'T264', 6, 8, 'Dosage', 'Two (2)', '5-249'],
#  [5, 'T266', 8, 9, 'Form', 'Tablet', '5-249'],
#  [5, 'T267', 9, 10, 'Route', 'PO', '5-249'],
#  [5, 'T268', 10, 11, 'Frequency', 'QHS', '5-249'],
#  [5, 'T270', 1, 3, 'Drug', 'lactobacillus acidophilus', '5-256'],
#  [5, 'T273', 3, 5, 'Form', 'Tablet, Chewable', '5-256'],
#  [5, 'T274', 6, 8, 'Dosage', 'One (1)', '5-256'],
#  [5, 'T276', 8, 10, 'Form', 'Tablet, Chewable', '5-256'],
#  [5, 'T277', 10, 11, 'Route', 'PO', '5-256'],
#  [5, 'T278', 11, 15, 'Frequency', 'three times a day', '5-256'],
#  [5, 'T279', 1, 2, 'Drug', 'digoxin', '5-262'],
#  [5, 'T280', 2, 4, 'Strength', '125 mcg', '5-262'],
#  [5, 'T281', 4, 5, 'Form', 'Tablet', '5-262'],
#  [5, 'T282', 6, 8, 'Dosage', 'One (1)', '5-262'],
#  [5, 'T284', 8, 9, 'Form', 'Tablet', '5-262'],
#  [5, 'T285', 9, 10, 'Route', 'PO', '5-262'],
#  [5, 'T286', 10, 11, 'Frequency', 'DAILY', '5-262'],
#  [5, 'T287', 1, 2, 'Drug', 'citalopram', '5-269'],
#  [5, 'T288', 2, 4, 'Strength', '20 mg', '5-269'],
#  [5, 'T289', 4, 5, 'Form', 'Tablet', '5-269'],
#  [5, 'T290', 6, 7, 'Dosage', '1.5', '5-269'],
#  [5, 'T291', 7, 8, 'Form', 'Tablets', '5-269'],
#  [5, 'T292', 8, 9, 'Route', 'PO', '5-269'],
#  [5, 'T293', 9, 10, 'Frequency', 'DAILY', '5-269'],
#  [5, 'T294', 1, 2, 'Drug', 'multivitamin', '5-276'],
#  [5, 'T295', 2, 3, 'Form', 'Tablet', '5-276'],
#  [5, 'T296', 4, 6, 'Dosage', 'One (1)', '5-276'],
#  [5, 'T298', 6, 7, 'Form', 'Tablet', '5-276'],
#  [5, 'T299', 7, 8, 'Route', 'PO', '5-276'],
#  [5, 'T300', 8, 11, 'Frequency', 'once a day', '5-276'],
#  [5, 'T302', 1, 2, 'Drug', 'Bisacodyl', '5-282'],
#  [5, 'T303', 2, 4, 'Strength', '10 mg', '5-282'],
#  [5, 'T304', 4, 5, 'Form', 'suppository', '5-282'],
#  [5, 'T305', 5, 6, 'Frequency', 'PRN', '5-282'],
#  [5, 'T306', 6, 7, 'Reason', 'constipation', '5-282'],
#  [5, 'T307', 1, 2, 'Drug', 'Robitussin', '5-287'],
#  [5, 'T308', 2, 3, 'Frequency', 'PRN', '5-287'],
#  [5, 'T309', 3, 4, 'Reason', 'cough', '5-287'],
#  [5, 'T310', 1, 4, 'Drug', 'Milk of Magnesia', '5-290'],
#  [5, 'T311', 4, 5, 'Frequency', 'PRN', '5-290'],
#  [5, 'T312', 5, 6, 'Reason', 'constipation', '5-290'],
#  [5, 'T314', 1, 3, 'Drug', 'Fleet Enema', '5-293'],
#  [5, 'T316', 3, 4, 'Frequency', 'PRN', '5-293'],
#  [5, 'T317', 4, 5, 'Reason', 'constipation', '5-293'],
#  [5, 'T318', 6, 7, 'Drug', 'lactulose', '5-293'],
#  [5, 'T320', 7, 10, 'Strength', '20 gram/30 mL', '5-293'],
#  [5, 'T322', 10, 11, 'Form', 'Solution', '5-293'],
#  [5, 'T324', 12, 15, 'Dosage', 'Thirty (30) mL', '5-293'],
#  [5, 'T326', 15, 16, 'Route', 'PO', '5-293'],
#  [5, 'T327', 16, 19, 'Frequency', 'Every other night', '5-293'],
#  [5, 'T328', 1, 2, 'Drug', 'Lumigan', '5-302'],
#  [5, 'T329', 2, 3, 'Strength', '0.03', '5-302'],
#  [5, 'T330', 4, 5, 'Form', 'Drops', '5-302'],
#  [5, 'T331', 6, 8, 'Dosage', 'One (1)', '5-302'],
#  [5, 'T332', 8, 9, 'Form', 'drop', '5-302'],
#  [5, 'T333', 9, 10, 'Route', 'Ophthalmic', '5-302'],
#  [5, 'T334', 10, 12, 'Frequency', 'at bedtime', '5-302'],
#  [5, 'T335', 1, 5, 'Drug', 'Bio E with selenium', '5-309'],
#  [5, 'T336', 5, 7, 'Form', 'soft gel', '5-309'],
#  [5, 'T337', 7, 8, 'Dosage', '1', '5-309'],
#  [5, 'T338', 8, 9, 'Form', 'tab', '5-309'],
#  [5, 'T339', 9, 10, 'Route', 'PO', '5-309'],
#  [5, 'T340', 10, 11, 'Frequency', 'daily', '5-309'],
#  [5, 'T341', 12, 13, 'Drug', 'Lasix', '5-315'],
#  [5, 'T342', 13, 15, 'Strength', '20 mg', '5-315'],
#  [5, 'T343', 15, 16, 'Form', 'Tablet', '5-315'],
#  [5, 'T345', 17, 19, 'Dosage', 'Three (3)', '5-315'],
#  [5, 'T346', 19, 20, 'Form', 'Tablet', '5-315'],
#  [5, 'T347', 20, 21, 'Route', 'PO', '5-315'],
#  [5, 'T348', 21, 24, 'Frequency', 'once a day', '5-315'],
#  [5, 'T349', 1, 3, 'Drug', 'Vitamin D2', '5-322'],
#  [5, 'T350', 3, 5, 'Strength', '50,000 unit', '5-322'],
#  [5, 'T351', 5, 6, 'Form', 'Capsule', '5-322'],
#  [5, 'T352', 7, 9, 'Dosage', 'One (1)', '5-322'],
#  [5, 'T353', 9, 10, 'Form', 'Capsule', '5-322'],
#  [5, 'T354', 10, 11, 'Route', 'PO', '5-322'],
#  [5, 'T355', 11, 14, 'Frequency', 'once a month', '5-322'],
#  [5, 'T356', 17, 18, 'Drug', 'antibiotics', '5-329'],
#  [5, 'T357', 4, 5, 'Route', 'intra-venous', '5-330'],
#  [5, 'T358', 5, 6, 'Drug', 'antibiotics', '5-330'],
#  [5, 'T359', 8, 9, 'Reason', 'infection', '5-330'],
#  [5, 'T360', 8, 9, 'Drug', 'mirtazapine', '5-333'],
#  [5, 'T361', 9, 11, 'Strength', '7.5 mg', '5-333'],
#  [5, 'T362', 11, 15, 'Frequency', '1 hour before dinner', '5-333'],
#  [5, 'T363', 23, 24, 'Drug', 'Klonopin', '5-333'],
#  [5, 'T364', 30, 32, 'Frequency', 'as needed', '5-333'],
#  [5, 'T365', 33, 34, 'Reason', 'anxiety', '5-333'],
#  [5, 'T367', 39, 40, 'Drug', 'furosemide', '5-333'],
#  [5, 'T368', 5, 6, 'Drug', 'tramadol', '5-340'],
#  [6, 'T91', 15, 16, 'Drug', 'Penicillins', '6-0'],
#  [6, 'T92', 47, 48, 'Reason', 'a.fib', '6-0'],
#  [6, 'T30', 49, 50, 'Drug', 'Coumadin', '6-0'],
#  [6, 'T93', 3, 5, 'Strength', '10 mg', '6-3'],
#  [6, 'T79', 6, 8, 'Drug', 'Vitamin K', '6-3'],
#  [6, 'T160', 10, 13, 'Reason', 'INR of 2.6', '6-3'],
#  [6, 'T94', 14, 15, 'Drug', 'FFP', '6-3'],
#  [6, 'T34', 18, 19, 'Drug', 'Labetalol', '6-3'],
#  [6, 'T35', 19, 21, 'Strength', '20 mg', '6-3'],
#  [6, 'T16', 21, 22, 'Route', 'IV', '6-3'],
#  [6, 'T95', 24, 28, 'Reason', 'SBP in the 170s', '6-3'],
#  [6, 'T98', 7, 8, 'Drug', 'Profilinine', '6-11'],
#  [6, 'T96', 12, 14, 'Dosage', '2 units', '6-11'],
#  [6, 'T97', 14, 15, 'Drug', 'FFP', '6-11'],
#  [6, 'T47', 32, 33, 'Drug', 'Nicardipine', '6-11'],
#  [6, 'T99', 33, 34, 'Route', 'gtt', '6-11'],
#  [6, 'T100', 5, 7, 'Reason', 'a. fib', '6-16'],
#  [6, 'T81', 8, 9, 'Drug', 'Coumadin', '6-16'],
#  [6, 'T161', 19, 20, 'Drug', 'O2', '6-18'],
#  [6, 'T162', 23, 24, 'Dosage', '2L', '6-18'],
#  [6, 'T163', 24, 25, 'Route', 'NC', '6-18'],
#  [6, 'T101', 36, 37, 'Reason', 'AF', '6-21'],
#  [6, 'T13', 38, 39, 'Drug', 'warfarin', '6-21'],
#  [6, 'T10', 7, 8, 'Drug', 'warfarin', '6-23'],
#  [6, 'T165', 9, 10, 'Reason', 'hypertension', '6-24'],
#  [6, 'T36', 12, 13, 'Route', 'IV', '6-24'],
#  [6, 'T48', 13, 14, 'Drug', 'nicardipine', '6-24'],
#  [6, 'T103', 14, 15, 'Route', 'infusion', '6-24'],
#  [6, 'T31', 26, 27, 'Drug', 'Aspirin', '6-28'],
#  [6, 'T68', 40, 41, 'Drug', 'warfarin', '6-28'],
#  [6, 'T104', 3, 5, 'Strength', '10 mg', '6-30'],
#  [6, 'T72', 6, 8, 'Drug', 'Vitamin K', '6-30'],
#  [6, 'T105', 10, 13, 'Reason', 'INR of 2.6', '6-30'],
#  [6, 'T106', 14, 15, 'Drug', 'FFP', '6-30'],
#  [6, 'T14', 18, 19, 'Drug', 'Labetalol', '6-30'],
#  [6, 'T15', 19, 21, 'Strength', '20 mg', '6-30'],
#  [6, 'T102', 21, 22, 'Route', 'IV', '6-30'],
#  [6, 'T107', 24, 28, 'Reason', 'SBP in the 170s', '6-30'],
#  [6, 'T109', 6, 10, 'Drug', 'Profilinine (activated factor IX)', '6-38'],
#  [6, 'T108', 12, 14, 'Dosage', '2 units', '6-38'],
#  [6, 'T110', 14, 15, 'Drug', 'FFP', '6-38'],
#  [6, 'T111', 17, 19, 'Reason', 'INR 2.3', '6-38'],
#  [6, 'T17', 5, 6, 'Drug', 'Nicardipine', '6-42'],
#  [6, 'T113', 6, 7, 'Form', 'infusion', '6-42'],
#  [6, 'T112', 8, 12, 'Reason', 'SBP up to 200s', '6-42'],
#  [6, 'T166', 11, 13, 'Reason', 'Cholesterol 240', '6-45'],
#  [6, 'T164', 13, 15, 'Reason', 'TGCs 111', '6-45'],
#  [6, 'T171', 15, 17, 'Reason', 'HDL 41', '6-45'],
#  [6, 'T172', 17, 19, 'Reason', 'LDL 177', '6-45'],
#  [6, 'T82', 5, 6, 'Drug', 'atorvastatin', '6-49'],
#  [6, 'T83', 6, 7, 'Strength', '40mg', '6-49'],
#  [6, 'T114', 7, 8, 'Frequency', 'daily', '6-49'],
#  [6, 'T115', 4, 5, 'Frequency', 'daily', '6-52'],
#  [6, 'T71', 5, 7, 'Drug', 'vitamin K', '6-52'],
#  [6, 'T167', 3, 4, 'Drug', 'antiplatelets', '6-54'],
#  [6, 'T64', 5, 6, 'Drug', 'aspirin', '6-54'],
#  [6, 'T65', 6, 7, 'Strength', '325mg', '6-54'],
#  [6, 'T29', 2, 3, 'Drug', 'warfarin', '6-57'],
#  [6, 'T175', 6, 7, 'ADE', 'hemorrhage', '6-57'],
#  [6, 'T116', 3, 4, 'ADE', 'hypotensive', '6-59'],
#  [6, 'T117', 7, 8, 'Route', 'IV', '6-59'],
#  [6, 'T45', 8, 9, 'Drug', 'nicardipine', '6-59'],
#  [6, 'T168', 11, 12, 'Drug', 'anti-hypertensives', '6-59'],
#  [6, 'T37', 4, 5, 'Drug', 'lisinopril', '6-63'],
#  [6, 'T46', 6, 7, 'Drug', 'carvedilol', '6-63'],
#  [6, 'T80', 10, 11, 'Drug', 'Warfarin', '6-65'],
#  [6, 'T38', 19, 20, 'Drug', 'aspirin', '6-65'],
#  [6, 'T39', 20, 21, 'Strength', '325mg', '6-65'],
#  [6, 'T118', 21, 22, 'Frequency', 'daily', '6-65'],
#  [6, 'T66', 4, 5, 'Drug', 'atorvastatin', '6-69'],
#  [6, 'T67', 5, 6, 'Strength', '40mg', '6-69'],
#  [6, 'T119', 6, 7, 'Frequency', 'daily', '6-69'],
#  [6, 'T11', 1, 2, 'Drug', 'aspirin', '6-72'],
#  [6, 'T12', 3, 4, 'Strength', '325mg', '6-72'],
#  [6, 'T120', 4, 5, 'Frequency', 'daily', '6-72'],
#  [6, 'T53', 4, 5, 'Drug', 'Nitroglycerin', '6-75'],
#  [6, 'T54', 5, 7, 'Strength', '0.4 mg', '6-75'],
#  [6, 'T121', 7, 8, 'Route', 'SL', '6-75'],
#  [6, 'T122', 8, 9, 'Frequency', 'prn', '6-75'],
#  [6, 'T87', 9, 11, 'Reason', 'chest pain', '6-75'],
#  [6, 'T85', 12, 13, 'Drug', 'Lisinopril', '6-75'],
#  [6, 'T86', 13, 15, 'Strength', '20 mg', '6-75'],
#  [6, 'T123', 15, 16, 'Frequency', 'daily', '6-75'],
#  [6, 'T19', 17, 18, 'Drug', 'Sertraline', '6-75'],
#  [6, 'T20', 18, 20, 'Strength', '100 mg', '6-75'],
#  [6, 'T124', 20, 21, 'Frequency', 'daily', '6-75'],
#  [6, 'T126', 22, 23, 'Drug', 'Pantropazole', '6-75'],
#  [6, 'T127', 23, 25, 'Strength', '40 mg', '6-75'],
#  [6, 'T128', 25, 26, 'Frequency', 'daily', '6-75'],
#  [6, 'T50', 27, 28, 'Drug', 'Coumadin', '6-75'],
#  [6, 'T51', 28, 30, 'Strength', '5 mg', '6-75'],
#  [6, 'T125', 30, 31, 'Frequency', 'daily', '6-75'],
#  [6, 'T129', 32, 33, 'Drug', 'ASA', '6-75'],
#  [6, 'T130', 33, 35, 'Strength', '81 mg', '6-75'],
#  [6, 'T131', 35, 36, 'Frequency', 'daily', '6-75'],
#  [6, 'T73', 37, 38, 'Drug', 'Carvedilol', '6-75'],
#  [6, 'T74', 38, 40, 'Strength', '25 mg', '6-75'],
#  [6, 'T44', 45, 47, 'Drug', 'acetaminophe n', '6-75'],
#  [6, 'T40', 47, 49, 'Strength', '325 mg', '6-75'],
#  [6, 'T132', 49, 50, 'Form', 'Tablet', '6-75'],
#  [6, 'T42', 51, 52, 'Dosage', '1-2', '6-75'],
#  [6, 'T41', 52, 53, 'Form', 'Tablets', '6-75'],
#  [6, 'T43', 53, 54, 'Route', 'PO', '6-75'],
#  [6, 'T133', 54, 60, 'Frequency', 'Q6H (every 6 hours) as needed', '6-75'],
#  [6, 'T88', 61, 62, 'Reason', 'pain', '6-75'],
#  [6, 'T3', 1, 2, 'Drug', 'nitroglycerin', '6-105'],
#  [6, 'T4', 2, 4, 'Strength', '0.4 mg', '6-105'],
#  [6, 'T5', 4, 7, 'Form', 'Tablet , Sublingual', '6-105'],
#  [6, 'T134', 8, 10, 'Dosage', 'One (1)', '6-105'],
#  [6, 'T135', 10, 11, 'Route', 'Sublingual', '6-105'],
#  [6, 'T136', 11, 16, 'Frequency', 'once a day as needed', '6-105'],
#  [6, 'T89', 17, 19, 'Reason', 'chest pain', '6-105'],
#  [6, 'T75', 1, 3, 'Drug', 'docusate sodium', '6-112'],
#  [6, 'T76', 3, 5, 'Strength', '100 mg', '6-112'],
#  [6, 'T137', 5, 6, 'Form', 'Capsule', '6-112'],
#  [6, 'T138', 7, 9, 'Dosage', 'One (1)', '6-112'],
#  [6, 'T77', 9, 10, 'Form', 'Capsule', '6-112'],
#  [6, 'T78', 10, 11, 'Route', 'PO', '6-112'],
#  [6, 'T139', 11, 18, 'Frequency', 'BID (2 times a day) as needed', '6-112'],
#  [6, 'T90', 19, 20, 'Reason', 'constipation', '6-112'],
#  [6, 'T63', 1, 3, 'Drug', 'sertralin e', '6-120'],
#  [6, 'T59', 3, 5, 'Strength', '100 mg', '6-120'],
#  [6, 'T140', 5, 6, 'Form', 'Tablet', '6-120'],
#  [6, 'T141', 7, 9, 'Dosage', 'One (1)', '6-120'],
#  [6, 'T60', 9, 10, 'Form', 'Tablet', '6-120'],
#  [6, 'T62', 10, 11, 'Route', 'PO', '6-120'],
#  [6, 'T61', 11, 14, 'Frequency', 'once a day', '6-120'],
#  [6, 'T25', 1, 3, 'Drug', 'carvedilo l', '6-127'],
#  [6, 'T21', 3, 5, 'Strength', '25 mg', '6-127'],
#  [6, 'T142', 5, 6, 'Form', 'Tablet', '6-127'],
#  [6, 'T143', 7, 9, 'Dosage', 'One (1)', '6-127'],
#  [6, 'T22', 9, 10, 'Form', 'Tablet', '6-127'],
#  [6, 'T24', 10, 11, 'Route', 'PO', '6-127'],
#  [6, 'T23', 11, 14, 'Frequency', 'twice a day', '6-127'],
#  [6, 'T58', 1, 3, 'Drug', 'lisinopri l', '6-134'],
#  [6, 'T55', 3, 5, 'Strength', '20 mg', '6-134'],
#  [6, 'T144', 5, 6, 'Form', 'Tablet', '6-134'],
#  [6, 'T145', 7, 9, 'Dosage', 'One (1)', '6-134'],
#  [6, 'T56', 9, 10, 'Form', 'Tablet', '6-134'],
#  [6, 'T57', 10, 11, 'Route', 'PO', '6-134'],
#  [6, 'T146', 11, 13, 'Frequency', 'DAILY (Daily)', '6-134'],
#  [6, 'T26', 1, 2, 'Drug', 'pantoprazole', '6-141'],
#  [6, 'T27', 2, 4, 'Strength', '40 mg', '6-141'],
#  [6, 'T28', 4, 9, 'Form', 'Tablet , Delayed Release (E.C.)', '6-141'],
#  [6, 'T147', 10, 12, 'Dosage', 'One (1)', '6-141'],
#  [6, 'T148', 12, 16, 'Form', 'Tablet, Delayed Release (E.C.)', '6-141'],
#  [6, 'T149', 16, 17, 'Route', 'PO', '6-141'],
#  [6, 'T150', 17, 20, 'Frequency', 'once a day', '6-141'],
#  [6, 'T9', 1, 3, 'Drug', 'atorvastati n', '6-148'],
#  [6, 'T6', 3, 5, 'Strength', '40 mg', '6-148'],
#  [6, 'T151', 5, 6, 'Form', 'Tablet', '6-148'],
#  [6, 'T152', 7, 9, 'Dosage', 'One (1)', '6-148'],
#  [6, 'T7', 9, 10, 'Form', 'Tablet', '6-148'],
#  [6, 'T8', 10, 11, 'Route', 'PO', '6-148'],
#  [6, 'T153', 11, 13, 'Frequency', 'at bedtime', '6-148'],
#  [6, 'T177', 11, 15, 'ADE', 'bleed in your brain', '6-155'],
#  [6, 'T84', 4, 6, 'Drug', 'warfarin (Coumadin)', '6-156'],
#  [6, 'T169', 9, 11, 'Reason', 'blood thinner', '6-156'],
#  [6, 'T170', 12, 14, 'ADE', 'worsens bleeding', '6-156'],
#  [6, 'T70', 21, 22, 'Drug', 'Coumadin', '6-156'],
#  [6, 'T18', 1, 2, 'Drug', 'warfarin', '6-160'],
#  [6, 'T52', 3, 4, 'Drug', 'aspirin', '6-161'],
#  [6, 'T154', 8, 9, 'Strength', '325mg', '6-161'],
#  [6, 'T155', 9, 10, 'Frequency', 'daily', '6-161'],
#  [6, 'T49', 3, 4, 'Drug', 'atorvastatin', '6-164'],
#  [6, 'T156', 5, 7, 'Reason', 'high cholesterol', '6-164'],
#  [6, 'T32', 4, 5, 'Drug', 'aspirin', '6-166'],
#  [6, 'T33', 11, 12, 'Strength', '325mg', '6-166'],
#  [6, 'T157', 12, 13, 'Frequency', 'daily', '6-166'],
#  [6, 'T69', 18, 20, 'Drug', 'warfarin (Coumadin)', '6-166'],
#  [6, 'T1', 22, 23, 'Drug', 'atorvastatin', '6-166'],
#  [6, 'T2', 23, 24, 'Strength', '40mg', '6-166'],
#  [6, 'T158', 24, 25, 'Frequency', 'daily', '6-166'],
#  [6, 'T159', 26, 28, 'Reason', 'high cholesterol', '6-166'],
#  [7, 'T95', 25, 27, 'Reason', 'CBD stone', '7-0'],
#  [7, 'T9', 4, 5, 'Route', 'IV', '7-1'],
#  [7, 'T38', 5, 6, 'Drug', 'Ciprofloxacin', '7-1'],
#  [7, 'T96', 24, 25, 'Reason', 'hypotensive', '7-1'],
#  [7, 'T62', 2, 3, 'Dosage', '3L', '7-4'],
#  [7, 'T63', 3, 4, 'Drug', 'IVF', '7-4'],
#  [7, 'T64', 4, 5, 'Dosage', 'boluses', '7-4'],
#  [7, 'T97', 3, 5, 'Reason', 'breast CA', '7-7'],
#  [7, 'T66', 3, 4, 'Frequency', 'wkly', '7-8'],
#  [7, 'T20', 4, 5, 'Drug', 'taxol', '7-8'],
#  [7, 'T32', 9, 10, 'Drug', 'herceptin', '7-8'],
#  [7, 'T86', 3, 4, 'Frequency', 'q3w', '7-11'],
#  [7, 'T56', 4, 5, 'Drug', 'Herceptin', '7-11'],
#  [7, 'T58', 20, 21, 'Drug', 'Lapatinib', '7-11'],
#  [7, 'T59', 21, 22, 'Strength', '1000mg', '7-11'],
#  [7, 'T67', 22, 23, 'Frequency', 'QD', '7-11'],
#  [7, 'T31', 28, 29, 'Drug', 'Lapatinib', '7-11'],
#  [7, 'T68', 30, 31, 'Frequency', 'weekly', '7-11'],
#  [7, 'T55', 31, 32, 'Drug', 'Herceptin', '7-11'],
#  [7, 'T33', 6, 7, 'Drug', 'Xeloda', '7-19'],
#  [7, 'T65', 8, 9, 'Drug', 'Lapatanib', '7-19'],
#  [7, 'T34', 6, 7, 'Drug', 'Herceptin', '7-21'],
#  [7, 'T39', 8, 9, 'Drug', 'Navelbine', '7-21'],
#  [7, 'T87', 10, 12, 'Dosage', '4 doses', '7-21'],
#  [7, 'T47', 5, 6, 'Drug', 'Avastin', '7-24'],
#  [7, 'T57', 7, 8, 'Drug', 'Gemzar', '7-24'],
#  [7, 'T99', 12, 13, 'Reason', 'Hypotension', '7-26'],
#  [7, 'T69', 33, 34, 'Dosage', '3L', '7-26'],
#  [7, 'T70', 34, 35, 'Drug', 'IVF', '7-26'],
#  [7, 'T71', 35, 36, 'Dosage', 'bolus', '7-26'],
#  [7, 'T88', 39, 40, 'Drug', 'antibitoics', '7-26'],
#  [7, 'T44', 42, 43, 'Drug', 'vancomycin', '7-26'],
#  [7, 'T60', 44, 45, 'Drug', 'zosyn', '7-26'],
#  [7, 'T89', 2, 3, 'Drug', 'pressors', '7-33'],
#  [7, 'T30', 4, 5, 'Route', 'IV', '7-33'],
#  [7, 'T90', 5, 6, 'Drug', 'fluid', '7-33'],
#  [7, 'T92', 6, 7, 'Dosage', 'boluses', '7-33'],
#  [7,
#   'T93',
#   7,
#   14,
#   'Reason',
#   'to maintain adequate MAP and urine output',
#   '7-33'],
#  [7, 'T43', 4, 5, 'Route', 'IV', '7-38'],
#  [7, 'T37', 5, 6, 'Drug', 'morphine', '7-38'],
#  [7, 'T73', 6, 7, 'Route', 'drip', '7-38'],
#  [7, 'T94', 7, 8, 'Drug', 'Antibiotics', '7-41'],
#  [7, 'T10', 3, 4, 'Drug', 'Oxycontin', '7-42'],
#  [7, 'T11', 4, 5, 'Strength', '10mg', '7-42'],
#  [7, 'T15', 7, 8, 'Drug', 'Oxycodone', '7-42'],
#  [7, 'T16', 8, 9, 'Strength', '5mg', '7-42'],
#  [7, 'T74', 9, 10, 'Frequency', 'PRN', '7-42'],
#  [7, 'T6', 3, 4, 'Drug', 'Ciprofloxacin', '7-47'],
#  [7, 'T7', 4, 5, 'Strength', '400mg', '7-47'],
#  [7, 'T54', 5, 6, 'Route', 'IV', '7-47'],
#  [7, 'T8', 6, 7, 'Frequency', 'Q12H', '7-47'],
#  [7, 'T45', 7, 8, 'Drug', 'Albuterol', '7-47'],
#  [7, 'T75', 8, 9, 'Form', 'nebs', '7-47'],
#  [7, 'T46', 9, 11, 'Frequency', 'Q6H prn', '7-47'],
#  [7, 'T1', 11, 12, 'Drug', 'Chlorhexidine', '7-47'],
#  [7, 'T2', 12, 13, 'Route', 'oral', '7-47'],
#  [7, 'T76', 13, 14, 'Form', 'rinse', '7-47'],
#  [7, 'T25', 16, 17, 'Drug', 'Colace', '7-47'],
#  [7, 'T26', 17, 18, 'Strength', '100mg', '7-47'],
#  [7, 'T12', 20, 21, 'Drug', 'Heparin', '7-47'],
#  [7, 'T77', 21, 22, 'Route', 'SC', '7-47'],
#  [7, 'T13', 22, 23, 'Frequency', 'TID', '7-47'],
#  [7, 'T40', 23, 24, 'Drug', 'Hydrocortisone', '7-47'],
#  [7, 'T41', 24, 25, 'Strength', '100mg', '7-47'],
#  [7, 'T61', 25, 26, 'Route', 'IV', '7-47'],
#  [7, 'T42', 26, 27, 'Frequency', 'Q8H', '7-47'],
#  [7, 'T17', 27, 28, 'Drug', 'Ipratropium', '7-47'],
#  [7, 'T19', 28, 29, 'Route', 'Neb', '7-47'],
#  [7, 'T18', 29, 31, 'Frequency', 'Q6H prn', '7-47'],
#  [7, 'T14', 31, 32, 'Drug', 'Magnesium', '7-47'],
#  [7, 'T78', 32, 34, 'Dosage', 'sliding scale', '7-47'],
#  [7, 'T35', 34, 35, 'Drug', 'Oxycontin', '7-47'],
#  [7, 'T36', 35, 36, 'Strength', '10mg', '7-47'],
#  [7, 'T3', 38, 39, 'Drug', 'Oxycodone', '7-47'],
#  [7, 'T4', 39, 40, 'Strength', '5mg', '7-47'],
#  [7, 'T5', 40, 42, 'Frequency', 'Q4H prn', '7-47'],
#  [7, 'T22', 42, 43, 'Drug', 'Pantoprazole', '7-47'],
#  [7, 'T23', 43, 44, 'Strength', '40mg', '7-47'],
#  [7, 'T24', 44, 45, 'Route', 'po', '7-47'],
#  [7, 'T79', 45, 46, 'Frequency', 'Q24H', '7-47'],
#  [7, 'T27', 46, 47, 'Drug', 'Zosyn', '7-47'],
#  [7, 'T28', 47, 48, 'Strength', '4.5mg', '7-47'],
#  [7, 'T72', 48, 49, 'Route', 'IV', '7-47'],
#  [7, 'T29', 49, 50, 'Frequency', 'Q8H', '7-47'],
#  [7, 'T21', 52, 53, 'Drug', 'Potassium', '7-47'],
#  [7, 'T80', 53, 55, 'Dosage', 'sliding scale', '7-47'],
#  [7, 'T48', 55, 56, 'Drug', 'Prochlorperazine', '7-47'],
#  [7, 'T49', 56, 57, 'Strength', '10mg', '7-47'],
#  [7, 'T50', 57, 59, 'Frequency', 'Q6H prn', '7-47'],
#  [7, 'T81', 59, 60, 'Drug', 'Senna', '7-47'],
#  [7, 'T82', 60, 61, 'Dosage', '1', '7-47'],
#  [7, 'T83', 61, 62, 'Form', 'tab', '7-47'],
#  [7, 'T84', 62, 63, 'Route', 'po', '7-47'],
#  [7, 'T85', 63, 64, 'Frequency', 'BID', '7-47'],
#  [7, 'T51', 64, 65, 'Drug', 'Vancomycin', '7-47'],
#  [7, 'T52', 65, 67, 'Strength', '1000 mg', '7-47'],
#  [7, 'T91', 67, 68, 'Route', 'IV', '7-47'],
#  [7, 'T53', 68, 70, 'Frequency', 'Q 12H', '7-47'],
#  [8, 'T83', 9, 11, 'Drug', 'Ace Inhibitors', '8-0'],
#  [8, 'T103', 12, 15, 'Drug', 'Sulfa (Sulfonamide Antibiotics)', '8-0'],
#  [8, 'T119', 47, 50, 'Reason', 'chronic atrial fibrillation', '8-0'],
#  [8, 'T125', 51, 52, 'Drug', 'Coumadin', '8-0'],
#  [8, 'T91', 26, 28, 'Strength', '10 mg', '8-4'],
#  [8, 'T95', 29, 30, 'Route', 'PO', '8-4'],
#  [8, 'T96', 30, 32, 'Drug', 'Vitamin K', '8-4'],
#  [8, 'T104', 41, 42, 'Drug', 'antibiotics', '8-7'],
#  [8, 'T105', 45, 46, 'Drug', 'Coumadin', '8-7'],
#  [8, 'T107', 9, 10, 'Drug', 'Coumadin', '8-9'],
#  [8, 'T108', 12, 13, 'Strength', '2.5', '8-9'],
#  [8, 'T110', 5, 7, 'Dosage', '2 units', '8-11'],
#  [8, 'T112', 8, 9, 'Drug', 'FFP', '8-11'],
#  [8, 'T113', 18, 19, 'Reason', 'Angiogedema', '8-13'],
#  [8, 'T54', 22, 23, 'Route', 'IV', '8-13'],
#  [8, 'T115', 23, 24, 'Drug', 'solumedrol', '8-13'],
#  [8, 'T116', 25, 27, 'Drug', 'H1,H2 blockers', '8-13'],
#  [8, 'T117', 9, 10, 'ADE', 'Angioedema', '8-17'],
#  [8, 'T118', 28, 29, 'Drug', 'lisinospril', '8-17'],
#  [8, 'T102', 8, 9, 'Route', 'IV', '8-19'],
#  ...]

# %%
(sents_dict)
# Out:
# {'0-0': 'He was pretreated with ampicillin 2gm IV , and gentamicin 80mg IV',
#  '0-6': 'He was NOT discharged on any anti-biotic',
#  '0-7': 'c/o fatigue, with reported fevers at home of 103.8 --pt took tylenol',
#  '0-9': 'wcc is 20. pt was pancultured and started on levo and flagyl',
#  '0-11': 'pt was therefore admitted for iv rehydration , iv abx',
#  '0-15': 'Blood cx sent. IVF given, levo , flagyl',
#  '0-18': 'T 102.0(R); hr 57; BP 104/45; rr 21 O2 sat',
#  '0-19': 'For serious infections, repeat culture and sensitivity testing may therefore be warranted if third generation cephalosporins',
#  '0-20': 'For serious infections, repeat culture and sensitivity testing may therefore be warranted if third generation cephalosporins were used. Trimethoprim /Sulfa',
#  '0-21': 'SENSITIVITIES: MIC expressed in MCG/ML _________________________________________________________ ENTEROBACTER CLOACAE | CEFEPIME -------------- <=1 S CEFTAZIDIME ----------- <=1 S CEFTRIAXONE ----------- <=1 S CIPROFLOXACIN ---------<=0.25 S GENTAMICIN ------------ <=1 S IMIPENEM -------------- <=1 S MEROPENEM -------------<=0.25 S PIPERACILLIN ---------- <=4 S TOBRAMYCIN',
#  '0-30': 'CT OF THE ABDOMEN WITH IV CONTRAST',
#  '0-32': 'CT OF THE PELVIS WITH IV CONTRAST',
#  '0-34': 'Brief Hospital Course: 1) Gram negative septicemia due to cholangitis',
#  '0-35': 'Patient received ampicillin and gentamicin while in house and was discharged on po cipro',
#  '0-39': 'Plan for total of 14 days',
#  '0-40': '5) h/o CAD : Patient is on an aspirin and a beta blocker',
#  '0-43': 'His statin was held due to bump in LFTs',
#  '0-45': '6) h/o colitis : Patient was continued on his home Asacol , Anaspaz',
#  '0-48': '7) ARF : Resolved with IVF',
#  '0-50': 'Please resume diovan',
#  '0-51': '8) Coagulopathy : Resolved with vitamin K',
#  '0-53': '10) Code status: DNR/DNI Medications on Admission: Meds from records--need to confirm with wife in AM ASACOL 400MG -- 2 tabs three times a day per dr [**Last Name (STitle) 96328**] ASPIRIN 81MG -- One tablet twice a day DIOVAN 80MG -- One tablet by mouth every day HYOSCYAMINE SULFATE 0.375MG -- One tablet twice a day METOPROLOL TARTRATE 25MG -- One tablet twice a day PRAVACHOL 20MG -- One tablet at bedtime TIMOLOL 0.25% -- One gtt twice a day',
#  '0-89': '10) Code status: DNR/DNI Medications on Admission: Meds from records--need to confirm with wife in AM ASACOL 400MG--2 tabs three times a day per dr [**Last Name (STitle) 96328**] ASPIRIN 81MG--One tablet twice a day DIOVAN 80MG--One tablet by mouth every day HYOSCYAMINE SULFATE 0.375MG--One tablet twice a day METOPROLOL TARTRATE 25MG--One tablet twice a day PRAVACHOL 20MG--One tablet at bedtime TIMOLOL 0.25%--One gtt twice a day Discharge Medications: 1. Metoprolol Tartrate 25 mg Tablet Sig: 0.5 Tablet PO BID (2 times a day)',
#  '0-96': 'Disp:*30 Tablet(s)* Refills:*2* 2. Mesalamin e 400 mg Tablet , Delayed Release (E.C.) Sig: Two (2) Tablet, Delayed Release (E.C.) PO TID (3 times a day)',
#  '0-103': '3. Hyoscyamine Sulfate 0.125 mg Tablet , Sublingual Sig: One (1) Tablet , Sublingual Sublingual QID (4 times a day)',
#  '0-112': 'Disp:*120 Tablet, Sublingual(s)* Refills:*0* 4. Ciprofloxaci n 750 mg Tablet Sig: One (1) Tablet PO twice a day for 11 days',
#  '0-120': 'Please take the antibiotics',
#  '1-0': 'Name: [**Known lastname **], [**Known firstname 9188**] Unit No: [**Numeric Identifier 15402**] Admission Date: [**2107-3-4**] Discharge Date: [**2107-3-10**] Date of Birth: [**2029-12-14**] Sex: F Service: FINAL DISCHARGE MEDICATIONS: 1. Heparin 5,000 units subq q.8.',
#  '1-4': '2. Acetaminophen 325 mg 1-2 tablets p.o. q.4-6h. prn.',
#  '1-10': '3. Olanzapin e 2.5 mg p.o. q.i.d. prn.',
#  '1-14': '4. Docusate 100 mg p.o. b.i.d. prn.',
#  '1-18': '5. Senna 8.6 mg p.o. b.i.d. prn.',
#  '1-22': '6. Carbidopa/ levodopa 25/100 mg one tablet p.o. t.i.d.',
#  '1-28': '7. Levothyroxine 100 mcg p.o. q.d.',
#  '1-32': '8. Valsartan/ hydrochlorothiazide 80/12.5 mg one tablet p.o. q.d.',
#  '1-38': '[**Name10 (NameIs) 15403**] patient will likely need close followup of thyroid replacement medication as she will likely require a lower dose of exogenous thyroid in the future as she is unlikely to be reinstated on Lithium',
#  '2-0': 'Admission Date: [**2142-8-14**] Discharge Date: [**2142-8-29**] Date of Birth: [**2095-1-22**] Sex: M Service: CARDIOTHORACIC Allergies: Penicillins',
#  '2-1': 'He remained hypertensive and continued to require Labetolol drip for adequate blood pressure control',
#  '2-5': 'He was empirically started on antibiotics for possible ventilator associated pneumonia along with positive blood cultures',
#  '2-8': 'Medications on Admission: Transfer meds: IV Esmolol , IV Nipride Home meds: HCTZ 25 qd , Zocor , Lisinopril 10 [**Hospital1 **], Viagra prn',
#  '2-20': 'Medications on Admission: Transfer meds: IV Esmolol, IV Nipride Home meds: HCTZ 25 qd, Zocor, Lisinopril 10 [**Hospital1 **], Viagra prn Discharge Medications: 1. Ciprofloxacin 500 mg Tablet Sig: One (1) Tablet PO Q12H',
#  '2-27': '2. Vancomycin in Dextrose 1 gram/200 mL Piggyback Sig: One (1) Intravenous Q 12H (Every 12 Hours)',
#  '2-34': '3. Atorvastatin 20 mg Tablet Sig: One (1) Tablet PO DAILY',
#  '2-41': 'Disp:*30 Tablet(s)',
#  '2-42': 'Disp:*30 Tablet(s)* Refills:*0* 4. Aspirin 81 mg Tablet, Chewable Sig: One (1) Tablet, Chewable PO DAILY (Daily)',
#  '2-49': 'Disp:*30 Tablet, Chewable(s)',
#  '2-50': 'Disp:*30 Tablet, Chewable(s)* Refills:*0* 5. Furosemide 10 mg/mL Solution Sig: Twenty (20) mg Injection twice a day for 7 days',
#  '2-57': 'Disp:*qs * Refills:*0* 6. Potassium Chloride 20 mEq Tab Sust.Rel. Particle/Crystal Sig: One (1) Tab Sust.Rel. Particle/Crystal PO once a day for 7 days',
#  '2-66': 'Particle/Crystal(s)* Refills:*0* 7. Pantoprazole 40 mg Tablet, Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q24H (every 24 hours)',
#  '2-73': 'Disp:*30 Tablet, Delayed Release (E.C.)',
#  '2-74': ')(s)* Refills:*0* 8. Labetalol 200 mg Tablet Sig: Four (4) Tablet PO TID (3 times a day)',
#  '2-81': 'Disp:*360 Tablet(s)',
#  '2-82': 'Followup Instructions: Dr. [**Last Name (STitle) **] in 4 weeks, call for appt Dr. [**Last Name (STitle) **] in [**3-11**] weeks, call for appt CTA scan in 3 months to evaluate aneurysm Please follow weekly LFTs/BUN/Creatinine while on antibiotics',
#  '3-0': 'Admission Date: [**2198-11-11**] Discharge Date: [**2198-11-16**] Service: MEDICINE Allergies: Sulfa (Sulfonamides) / Heparin Agents Attending:[**First Name3 (LF) 3705**] Chief Complaint: GIB Major Surgical or Invasive Procedure: colonoscopy Central line placement by VIR History of Present Illness: Ms. [**Known lastname 70011**] is a [**Age over 90 **] yo female with severe RA who presented to OSH with LGIB',
#  '3-3': 'The patient was given fluids and was transfused 2U of FFP and 2U of PRBC',
#  '3-8': 'The pt had an IVC filter placed and was on Heparin sc TID for DVT prophylaxis',
#  '3-12': 'PSH: S/p b/l TKR in [**2193**] s/p R total hip replacement in [**9-/2198**] complicated by a DVT for which an IVC filter was placed Addendum/clarification based on discussion with the PCP ([**First Name5 (NamePattern1) 4468**] [**Last Name (NamePattern1) 70012**]): She underwent R THR at [**Hospital3 934**] in [**5-15**] without complications, discharged on coumadin for DVT prophylaxis',
#  '3-14': 'Readmitted in [**6-14**] with thigh pain and a DVT',
#  '3-15': 'On lovenox , plavix and aspirin , she developed a thigh hematoma',
#  '3-19': 'Placed on steroids',
#  '3-20': 'Readmitted [**11-11**] from rehab because she was placed on heparin SQ despite the IVCF and developed BRBPR and hypotension',
#  '3-24': 'Targeted colonoscopy of this area or single-contrast barium',
#  '3-25': '1) LGIB',
#  '3-26': "She received 2 units of FFP and 2 units of PRBC's",
#  '3-30': 'She was admitted to the MICU at [**Hospital1 18**] and GoLytely was administered in preparation for a colonoscopy',
#  '3-32': "On admission to this institution, she had a large drop in her hct from 33.8 to 26.6 and was transfused an additional 2 units of PRBC's and started on IV PPI",
#  '3-36': '3) Rheumatoid Arthritis - Patient has a long history of RA for 30 years and is on a slow prednisone taper',
#  '3-39': 'Current dose of 20 mg was continued to prevent adrenal insufficiency',
#  '3-41': '4) Leukocytosis : Most likely due to chronic prednisone',
#  '3-43': '5) Afib : Sotalol',
#  '3-45': '6) FEN : Received gentle IVFs',
#  '3-47': 'Patient has IVC filter in place given h/o DVT. PPI for GI prophylaxis',
#  '3-49': '9) Code status: DNR/DNI Medications on Admission: Medications on admission to outside hospital: Lipitor 10mg QD Enteric coated Aspirin 81 mg Nexium 40mg QD Sotalol 40mg QD Prednisone 20mg QD',
#  '3-64': 'Home Meds: included sq heparin',
#  '3-66': 'Medications on transfer to outside hospital: Pantoprazol e 40 mg PO Q12H Prednison e 20 mg PO DAILY Acetaminophen 325-650 mg PO Q4 -6H:PRN Sotalol HCl 40 mg PO DAILY Atorvastati n 10 mg PO DAILY',
#  '3-86': 'Medications on transfer to outside hospital: Pantoprazole 40 mg PO Q12H Prednisone 20 mg PO DAILY Acetaminophen 325-650 mg PO Q4-6H:PRN Sotalol HCl 40 mg PO DAILY Atorvastatin 10 mg PO DAILY Discharge Medications: 1. Atorvastati n 10 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '3-93': '2. Acetaminophen 325 mg Tablet Sig: Two (2) Tablet PO every [**3-15**] hours as needed for pain',
#  '3-100': '3. Pantoprazole 40 mg Tablet , Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q12H (every 12 hours)',
#  '3-107': '4. Prednisone 20 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '3-114': '5. Sotalol 80 mg Tablet Sig: 0.5 Tablet PO DAILY (Daily)',
#  '4-0': 'Name: [**Known lastname **],[**Known firstname **] Unit No: [**Numeric Identifier 12228**] Admission Date: [**2181-11-6**] Discharge Date: [**2181-11-17**] Date of Birth: [**2117-12-19**] Sex: M Service: CARDIOTHORACIC Allergies: Patient recorded as having No Known Allergies to Drugs Attending:[**First Name3 (LF) 135**] Addendum: Lisinopril 2.5mg daily',
#  '5-0': 'Admission Date: [**2123-4-6**] Discharge Date: [**2123-4-13**] Date of Birth: [**2038-1-27**] Sex: F Service: MEDICINE Allergies: Reglan / sorbitol / aspirin / hydrochlorothiazide',
#  '5-4': "She rec'd K repletion with 40meq , 1L NS , duoneb x 1 , zosyn 3.25g x 1 , atarax",
#  '5-13': 'Patient was started on vanc / zosyn',
#  '5-15': 'Her vancomycin',
#  '5-16': 'She remained on zosyn and completed a 7-day',
#  '5-18': 'This was thought to be the result of oversedation from meds ( IV morphine , klonopin PRN , PM amitryptiline , and antiemetics',
#  '5-25': 'She was maintained on IVF',
#  '5-26': 'Her vancomycin',
#  '5-27': 'The psychiatry team evaluated her while she was in the hospital and started mirtazapine 7.5 mg QPM (1 hour before meals)',
#  '5-30': 'Her depression',
#  '5-31': 'CHRONIC DIAGNOSES: # COPD : Treated for exacerbation with rapid steroid taper',
#  '5-34': 'On home furosemide and digoxin',
#  '5-36': "Pt's digoxin",
#  '5-37': 'Given poor PO intake, her lasix',
#  '5-38': 'Continued on Lumigan 0.3 % OU QHS # DEPRESSION / ANXIETY',
#  '5-44': 'Her home klonopin was dose-reduced PRN but she was continued on her home amitryptiline and citalopram',
#  '5-48': '# POLYMYALGIA RHEUMATICA : On chronic prednisone',
#  '5-50': 'No evidence of adrenal insufficiency',
#  '5-51': 'Continued on prednisone 5mg PO daily in-house as well as calcium and vitamin D',
#  '5-57': 'Continued on prednisone 5mg PO daily in-house as well as calcium and vitamin D. # HTN: Restarted on metoprolol',
#  '5-58': 'TRANSITIONAL ISSUES: Code Status: DNR/DNI, not CMO Medications on Admission: - Miralax PRN - Calcium - Vitamin D3 50,000 IU PO monthly - Protonix 40mg PO daily - Klor-Con 20meq PO BID - Metoprolol tart 50mg PO BID - Fluticasone spray 50mcg twice daily - Tylenol 650mg PO QID PRN - Klonopin 1mg PO daily QHS - Klonopin 0.5mg PO TID PRN - Albuterol neb Q4hrs PRN - Tramadol 50mg PO BID PRN - Milk of Magnesia PRN - Fleet enema PRN - Robitussin PRN - Bisacodyl 10mg supp PRN - Prednisone 5mg alternating with 7.5mg PO daily - Lumigan 0.03 % solution QHS - Lactulose 30 ml PO every other night at bedtime - Amitryptiline 100mg PO QHS - Lactobacillus tabs PO TID - Furosemide 60mg PO daily - Digoxin 0.125mg PO daily - Citalopram 30mg PO daily - Bio E with selenium soft gel 1 tab PO daily - Multivitamin PO daily - Levaquin 750 mg once daily x 3 days ([**Date range (1) 110282**]) - Prednisone 5 mg PO daily - Albuterol neb 0.083 % inhaled QID x 7 days',
#  '5-166': 'TRANSITIONAL ISSUES: Code Status: DNR/DNI, not CMO Medications on Admission: -Miralax PRN -Calcium -Vitamin D3 50,000 IU PO monthly -Protonix 40mg PO daily -Klor-Con 20meq PO BID -Metoprolol tart 50mg PO BID -Fluticasone spray 50mcg twice daily -Tylenol 650mg PO QID PRN -Klonopin 1mg PO daily QHS -Klonopin 0.5mg PO TID PRN -Albuterol neb Q4hrs PRN -Tramadol 50mg PO BID PRN -Milk of Magnesia PRN -Fleet enema PRN -Robitussin PRN -Bisacodyl 10mg supp PRN -Prednisone 5mg alternating with 7.5mg PO daily -Lumigan 0.03% solution QHS -Lactulose 30 ml PO every other night at bedtime -Amitryptiline 100mg PO QHS -Lactobacillus tabs PO TID -Furosemide 60mg PO daily -Digoxin 0.125mg PO daily -Citalopram 30mg PO daily -Bio E with selenium soft gel 1 tab PO daily -Multivitamin PO daily -Levaquin 750 mg once daily x 3 days ([**Date range (1) 110282**]) -Prednisone 5 mg PO daily -Albuterol neb 0.083% inhaled QID x 7 days ([**Date range (1) 45260**]) Discharge Medications: 1. Calcium 500 500 mg calcium ( 1,250 mg ) Tablet Sig: One (1) Tablet PO twice a day',
#  '5-175': '2. Miralax 17 gram Powder in Packet Sig: One (1) PO once a day as needed for constipation',
#  '5-182': '3. Klor-Con 20 mEq Packet Sig: One (1) PO twice a day',
#  '5-188': '4. metoprolol tartrate 50 mg Tablet Sig: One (1) Tablet PO BID',
#  '5-195': '5. Protonix 40 mg Tablet, Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release',
#  '5-200': 'Sig: One (1) Tablet, Delayed Release (E.C.) PO once a day',
#  '5-202': '6. fluticasone 50 mcg/actuation Spray , Suspension Sig: One (1) Nasal twice a day',
#  '5-209': '7. Tylenol 325 mg Tablet Sig: Two (2) Tablet PO four times a day as needed for pain',
#  '5-217': 'Tablet(s) 8. clonazepam 0.5 mg Tablet Sig: One (1) Tablet PO TID (3 times a day) as needed for anxiety / nausea',
#  '5-226': '9. albuterol sulfate 2.5 mg /3 mL ( 0.083 %) Solution for Nebulization Sig: One (1) Inhalation every four (4) hours as needed for SOB / wheeze',
#  '5-236': '10. prednisone 5 mg Tablet Sig: One (1) Tablet PO DAILY',
#  '5-243': '11. bimatoprost 0.03 % Drops Sig: One (1) Ophthalmic QHS',
#  '5-249': '12. amitriptyline 50 mg Tablet Sig: Two (2) Tablet PO QHS',
#  '5-256': '13. lactobacillus acidophilus Tablet, Chewable Sig: One (1) Tablet, Chewable PO three times a day',
#  '5-262': '14. digoxin 125 mcg Tablet Sig: One (1) Tablet PO DAILY',
#  '5-269': '15. citalopram 20 mg Tablet Sig: 1.5 Tablets PO DAILY',
#  '5-276': '16. multivitamin Tablet Sig: One (1) Tablet PO once a day',
#  '5-282': 'Medication Bisacodyl 10 mg suppository PRN constipation',
#  '5-287': 'Medication Robitussin PRN cough',
#  '5-290': 'Medication Milk of Magnesia PRN constipation',
#  '5-293': 'Medication Fleet Enema PRN constipation 21. lactulose 20 gram/30 mL Solution Sig: Thirty (30) mL PO Every other night',
#  '5-302': '22. Lumigan 0.03 % Drops Sig: One (1) drop Ophthalmic at bedtime',
#  '5-309': 'Medication Bio E with selenium soft gel 1 tab PO daily',
#  '5-315': 'Medication Bio E with selenium soft gel 1 tab PO daily 24. Lasix 20 mg Tablet Sig: Three (3) Tablet PO once a day',
#  '5-322': '25. Vitamin D2 50,000 unit Capsule Sig: One (1) Capsule PO once a month',
#  '5-329': 'In the hospital it was decided that the best course of management would be a course of antibiotics',
#  '5-330': 'You were started on intra-venous antibiotics and your infection',
#  '5-333': 'MEDICATION INSTRUCTIONS: - Medications ADDED: ---> Please take mirtazapine 7.5 mg 1 hour before dinner - Medications STOPPED: ---> Please stop taking standing Klonopin (you may take a small dose as needed for anxiety ) ---> Please stop taking furosemide',
#  '5-340': '---> Please do not take tramadol',
#  '6-0': 'Admission Date: [**2104-12-29**] Discharge Date: [**2104-12-31**] Date of Birth: [**2038-10-7**] Sex: M Service: NEUROLOGY Allergies: Penicillins Attending:[**First Name3 (LF) 2569**] Chief Complaint: R-sided weakness and R facial droop Major Surgical or Invasive Procedure: None History of Present Illness: 66 year-old right-handed man with PMH significant for HTN, a.fib (on Coumadin',
#  '6-3': 'He was given 10 mg of Vitamin K for an INR of 2.6 (no FFP was given) and Labetalol 20 mg IV for a SBP in the 170s',
#  '6-11': 'In the [**Hospital1 18**] ED, he received Profilinine , was ordered for 2 units FFP (did not receive while in ED, but was due to receive in ICU) and started on a Nicardipine gtt',
#  '6-16': 'Past Medical History: -HTN - a. fib (on Coumadin',
#  '6-18': 'Physical Exam: Admission Physical Exam: Vitals: T: 98.6 P: 50 R: 16 BP: 178/95 (up to 200s systolic) Sa O2 : 98% on 2L NC',
#  '6-21': 'Read by: [**Last Name (LF) **],[**First Name3 (LF) **] E. Intervals Axes Rate PR QRS QT/QTc P QRS T 50 238 96 540/522 31 -1 -87 Brief Hospital Course: 66 RHM with PMH significant for HTN, AF (on warfarin',
#  '6-23': 'Given the presence of the IPH, his warfarin',
#  '6-24': 'Patient was initially admitted to the ICU given significant hypertension requirinng an IV nicardipine infusion',
#  '6-28': 'Although the most likely cause for his IPH is hypertension, it was not possible to do an MRI to look for an underlying lesion given pacemaker. Aspirin should be started in 1 week and he will not be continued on warfarin',
#  '6-30': 'He was given 10 mg of Vitamin K for an INR of 2.6 (no FFP was given) and Labetalol 20 mg IV for a SBP in the 170s',
#  '6-38': 'At [**Hospital1 18**] ED, he received Profilinine (activated factor IX) and received 2 units FFP later for INR 2.3',
#  '6-42': 'He was started on a Nicardipine infusion for SBP up to 200s',
#  '6-45': 'Stroke risk factors were assessed with HbA1c 5.4% and FLP revealed Cholesterol 240 TGCs 111 HDL 41 LDL 177',
#  '6-49': 'He was therefore started on atorvastatin 40mg daily',
#  '6-52': 'He continued to receive daily vitamin K',
#  '6-54': 'We held all antiplatelets and aspirin 325mg',
#  '6-57': 'We stopped warfarin due to his hemorrhage',
#  '6-59': 'He was briefly hypotensive in the setting IV nicardipine and home anti-hypertensives',
#  '6-63': "We continued patient's home lisinopril and carvedilol",
#  '6-65': 'We monitored his INR daily and was 1.0 on discharge. Warfarin was stopped and he should be restarted on aspirin 325mg daily',
#  '6-69': 'Patient was started on atorvastatin 40mg daily',
#  '6-72': 'Restart aspirin at 325mg daily',
#  '6-75': 'Medications on Admission: - Nitroglycerin 0.4 mg SL prn chest pain - Lisinopril 20 mg daily - Sertraline 100 mg daily - Pantropazole 40 mg daily - Coumadin 5 mg daily - ASA 81 mg daily - Carvedilol 25 mg [**Hospital1 **] Discharge Medications: 1. acetaminophe n 325 mg Tablet Sig: 1-2 Tablets PO Q6H (every 6 hours) as needed for pain',
#  '6-105': '2. nitroglycerin 0.4 mg Tablet , Sublingual Sig: One (1) Sublingual once a day as needed for chest pain',
#  '6-112': '3. docusate sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day) as needed for constipation',
#  '6-120': '4. sertralin e 100 mg Tablet Sig: One (1) Tablet PO once a day',
#  '6-127': '5. carvedilo l 25 mg Tablet Sig: One (1) Tablet PO twice a day',
#  '6-134': '6. lisinopri l 20 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '6-141': '7. pantoprazole 40 mg Tablet , Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO once a day',
#  '6-148': '8. atorvastati n 40 mg Tablet Sig: One (1) Tablet PO at bedtime',
#  '6-155': 'You had a CT scan and were found to have a bleed in your brain',
#  '6-156': 'As you were on warfarin (Coumadin) which is a blood thinner and worsens bleeding , this was reversed with medications and Coumadin',
#  '6-160': 'Your warfarin',
#  '6-161': 'You should stop aspirin currently and restrat at 325mg daily',
#  '6-164': 'We also started atorvastatin for high cholesterol',
#  '6-166': 'Medication changes: We STOPPED aspirin and this should be restarted at 325mg daily in 1 week We STOPPED warfarin (Coumadin) We STARTED atorvastatin 40mg daily for high cholesterol',
#  '7-0': 'In the ED, a RUQ U/S was unable to identify the CBD but it did show dilatation of the pancreatic duct which was suspcious for CBD stone',
#  '7-1': 'Patient was treated with IV Ciprofloxacin and stable on the OMED service until the early am of [**2187-8-19**] when patient was found to be hypotensive',
#  '7-4': 'Patient received 3L IVF boluses',
#  '7-7': 'Onc History: Recurrent breast CA',
#  '7-8': "She then rec'd wkly taxol /[**Doctor Last Name **]/ herceptin",
#  '7-11': 'She was on q3w Herceptin from [**12/2184**] - [**4-/2186**], when she developed brain mets and consented to trial 06-356 combining Lapatinib 1000mg QD with whole brain radiation then Lapatinib with weekly Herceptin',
#  '7-19': 'She progressed and was changed to Xeloda - Lapatanib',
#  '7-21': "After cyberknife she was tx'd w/ Herceptin / Navelbine for 4 doses",
#  '7-24': 'In [**Month (only) 116**] she Avastin / Gemzar',
#  '7-26': 'Brief Hospital Course: On transfer to the [**Hospital Unit Name 153**] # Hypotension - Patient met SIRS criteria with T < 96 and SBP<70 on the floor prior to transfer which resolved with 3L IVF bolus and broadening of antibitoics to include vancomycin and zosyn',
#  '7-33': 'Initially on pressors and IV fluid boluses to maintain adequate MAP and urine output',
#  '7-38': 'Patient was started on IV morphine drip',
#  '7-41': 'Patient was started on IV morphine drip. Antibiotics',
#  '7-42': 'Medications on Admission: Oxycontin 10mg [**Hospital1 **] Oxycodone 5mg PRN',
#  '7-47': 'Meds on transfer: Ciprofloxacin 400mg IV Q12H Albuterol nebs Q6H prn Chlorhexidine oral rinse [**Hospital1 **] Colace 100mg [**Hospital1 **] Heparin SC TID Hydrocortisone 100mg IV Q8H Ipratropium Neb Q6H prn Magnesium sliding scale Oxycontin 10mg [**Hospital1 **] Oxycodone 5mg Q4H prn Pantoprazole 40mg po Q24H Zosyn 4.5mg IV Q8H day#1 [**8-19**] Potassium sliding scale Prochlorperazine 10mg Q6H prn Senna 1 tab po BID Vancomycin 1000 mg IV Q 12H',
#  '8-0': 'Admission Date: [**2121-5-7**] Discharge Date: [**2121-5-13**] Service: MEDICINE Allergies: Ace Inhibitors / Sulfa (Sulfonamide Antibiotics) / Fish Product Derivatives Attending:[**First Name3 (LF) 1928**] Chief Complaint: Fall with hematoma to right side of head Major Surgical or Invasive Procedure: None History of Present Illness: 87 year-old woman with chronic atrial fibrillation on Coumadin',
#  '8-4': "After falling, pt's next memory is of daughter taking her to her primary care doctor, where she was found ot have an elevated INR and administered 10 mg of PO Vitamin K",
#  '8-7': "After falling, pt's next memory is of daughter taking her to her primary care doctor, where she was found ot have an elevated INR and administered 10 mg of PO Vitamin K. Pt denies any changes to her medications including new antibiotics , changes in Coumadin",
#  '8-9': 'She takes her medications by herself and knows her Coumadin dose ( 2.5',
#  '8-11': 'Patient was T&C and received 2 units of FFP',
#  '8-13': "Pt's daughter reports she was confused and altered from her baseline mental status on day prior to admission. Angiogedema improved significantly with IV solumedrol and H1,H2 blockers",
#  '8-17': 'Past Medical History: - Left Caudate Head infarct - Angioedema : pruritis and periorbital and lip/tongue edema, previously intubated in MICU ([**12-16**]), etiology thought to be due to lisinospril',
#  '8-19': 'Recurrence in [**3-19**] requiring MICU admission, managed with IV steroids and H1/H2 blockers',
#  '8-22': '- Atrial fibrillation on Coumadin',
#  '8-24': 'Discharge labs: [**2121-5-13**] 07:12AM BLOOD WBC-10.8 RBC-3.88* Hgb-11.5* Hct-34.2* MCV-88 MCH-29.7 MCHC-33.6 RDW-12.8 Plt Ct-314 [**2121-5-13**] 07:12AM BLOOD PT-17.7* PTT-25.1 INR(PT)-1.6* Brief Hospital Course: 87 year-old woman presents after falling down and hitting head, admitted with GIB and supratherapeutic INR to ICU. INR was >20 INR was >20 and was reversed with Vitamin K and 2 units of FFP',
#  '8-29': 'INR was >20 and was reversed with Vitamin K and 2 units of FFP. Coumadin',
#  '8-30': 'HCT was stable so decision was made not to pursue colonoscopy. Acute renal failure resolved with IVF',
#  '8-32': 'Nutritional deficiency vs less efficient GI absorption of Vitamin K vs drug-drug interaction causing decreased metabolism of Coumadin',
#  '8-34': 'She was reversed with Vitamin K and FFP',
#  '8-36': 'After discussion with her primary care provider, [**Name10 (NameIs) **] decision was made to restart coumadin at a lower dose of 1.5mg daily',
#  '8-39': 'Lower GI Bleed: No active bleeding after reversing anticoagulation',
#  '8-40': 'After discussions with her PMD, she was restarted on coumadin at a lower dose at 1.5mg daily',
#  '8-43': 'After discussions with her PMD, she was restarted on coumadin at a lower dose at 1.5mg daily #. Atrial fibrillation : Metoprolol dose reduced because of bradycardia',
#  '8-46': 'As above, her anticoagulation',
#  '8-47': 'She will restart coumadin at a lower dose at 1.5mg daily',
#  '8-50': 'Falling down / Gait instability: PT consult to determine recommended level of home supervision #. Acute Kidney Injury',
#  '8-51': 'Resolved with IVF',
#  '8-52': '#. Hypertension : On Metoprolol',
#  '8-54': 'Held Amlodipine',
#  '8-55': 'Restart if needed for BP control',
#  '8-56': 'Restart if needed for BP control #. Hyperlipidemia : Continue statin',
#  '8-58': 'Hyperlipidemia: Continue statin #. Angioedema : Continue Fexofenadine , Famotidine , and Prednisone',
#  '8-62': 'Contact - [**Name (NI) 553**] (daughter) [**Telephone/Fax (1) 79254**] Medications on Admission: Amlodipine 10 mg PO Daily Fexofenadine 60 mg PO BID Famotidine 20 mg PO BID Metoprolol 12.5 mg PO BID Prednisone 5 mg PO Every other day Simvastatin 20 mg PO Daily Vitamin D 1000 IU PO Daily Warfarin 3 mg PO Daily Oyster calcium 500 mg PO BID Alendronate 70 mg PO Weekly',
#  '8-102': 'Contact - [**Name (NI) 553**] (daughter) [**Telephone/Fax (1) 79254**] Medications on Admission: Amlodipine 10 mg PO Daily Fexofenadine 60 mg PO BID Famotidine 20 mg PO BID Metoprolol 12.5 mg PO BID Prednisone 5 mg PO Every other day Simvastatin 20 mg PO Daily Vitamin D 1000 IU PO Daily Warfarin 3 mg PO Daily Oyster calcium 500 mg PO BID Alendronate 70 mg PO Weekly Discharge Medications: 1. Famotidine 20 mg Tablet Sig: One (1) Tablet PO Q24H',
#  '8-109': '2. Fexofenadine 60 mg Tablet Sig: One (1) Tablet PO BID',
#  '8-116': '3. Prednisone 5 mg Tablet Sig: One (1) Tablet PO EVERY OTHER DAY',
#  '8-123': '4. Simvastatin 10 mg Tablet Sig: Two (2) Tablet PO DAILY',
#  '8-130': '5. Vitamin D 1,000 unit Tablet Sig: One (1) Tablet PO once a day',
#  '8-137': '6. Calcium Carbonate 500 mg Tablet, Chewable Sig: One (1) Tablet, Chewable PO BID',
#  '8-144': '7. Alendronate 70 mg Tablet Sig: One (1) Tablet PO once a week',
#  '8-151': '8. Coumadin 1 mg Tablet Sig: 1.5 Tablets PO at bedtime',
#  '8-158': 'Disp:*30 Tablet(s)* Refills:*0* 9. Metoprolol Tartrate 25 mg Tablet Sig: 0.25 Tablet PO twice a day',
#  '8-165': 'Disp:*15 Tablet(s)* Refills:*0* 10. Famotidine 20mg',
#  '8-167': 'Famotidine 20mg [**Hospital1 **] 11. Fexofenadine 60mg',
#  '8-169': 'Your INR was corrected with Vitamin K and transfusion of plasma',
#  '8-173': 'We recommend that you stop taking Coumadin',
#  '8-174': 'You should restart Coumadin at a lower dose of 1.5mg daily',
#  '8-177': 'Restart coumadin 1.5mg daily',
#  '8-180': 'DECREASE DOSE of Metoprolol to 6.25mg twice a day (The dose was decreased because your heart rate was too slow',
#  '8-184': 'STOP Amlodipine',
#  '9-0': 'He developed throbbing frontal occipital headache eyes and dry mouth and the headache was alleviated only slightly with ibuprofen',
#  '9-2': 'PAST MEDICAL HISTORY: HIV',
#  '9-3': 'He was in no previous HAART',
#  '9-4': 'Two weeks ago, CD4 count was 171, his viral load 200,000 and was started on Bactrim for Pneumocystis carinii prophylaxis',
#  '9-6': 'MEDICATIONS PRIOR TO ADMISSION: Bactrim , acyclovir',
#  '9-8': 'MCV is 85, sodium 136, potassium 3.4, chloride 102, HCO3 25, BUN 9, creatinine 0.9, glucose',
#  '9-11': 'Induced sputums were performed and the patient was started on intravenous Bactrim and prednisone for a possible PCP infection and levofloxacin for any community-acquired pneumonia',
#  '9-17': 'The patient was also feeling increasingly anxious and was given morphine , pantoprazole , zolpidem , and heparin',
#  '9-21': 'The patient was sedated through Fentanyl , lorazepam and also received nicotine',
#  '9-25': 'As Bactrim has been described to be associated with adult respiratory distress syndrome , Bactrim',
#  '9-28': 'The skin signs markedly improved and his 02 saturation on hospital day nine was now 98% on four liters of oxygen / nasal cannula',
#  '9-31': 'On day ten of his hospital stay, the patient developed withdrawal symptoms consisting of agitation , hallucinations and tachypnea , which could be attributed to the high doses of Fentanyl',
#  '9-35': 'He also still had hallucinations and an oral thrush could be observed and treated with Nystatin',
#  '9-37': 'On day 12 of his hospital stay, the patient was started on Dapsone for PCP prophylaxis , but the patient developed a rash on both arms and the back',
#  '9-40': 'As Dapsone is known to show a cross reactivity to Bactrim in [**10-20**]%, Dapsone',
#  '9-43': 'On day 14 of his hospital stay, all medications except prednisone and the nicotine patch',
#  '9-46': 'Blood cultures will have to be followed up with Dr. [**Last Name (STitle) **], with whom he has an appointment within two weeks and a Infectious Disease Consult for starting of HAART',
#  '9-47': 'His medications on discharge are Nystatin and nicotine patches',
#  '10-0': '4 hours later, the pt had " indigestion ", took Tums',
#  '10-2': 'In the [**Name (NI) **], pt had temp up to 104.2, BP down to 85/47',
#  '10-3': 'She was given 7 L IVF , a R SC central line was placed, and she was started on levophed',
#  '10-6': 'She was given zosyn , flagyl , tylenol , and zofran',
#  '10-10': '50 yo generally healthy female, p/w N/V, fever, hypotension, erythroderma and sepsis on admission requiring pressor',
#  '10-12': '. Sepsis',
#  '10-13': 'recieved Vancomycin , clindamycin , and zosyn',
#  '10-16': 'She improved hemodynamically and abx were tapered to clindamycin po and she was transferred to the medical [**Hospital1 **], at which time wbc again rose with eosinophilia , this was changed to cefalexin for one day',
#  '10-22': 'As WBC continued to rise, all abx',
#  '10-23': 'At this time a morbilliform drug erruption',
#  '10-24': 'These began to resolve by d/c with discontinuation of all abx',
#  '10-25': 'Her ICU course was complicated by mild acute renal failure that improved with fluids , as well as mild pulmonary edema, attributed to massive IV fluid',
#  '10-29': 'Medications on Admission: Tums',
#  '10-30': 'Discharge Medications: Benadryl prn for itching',
#  '10-33': 'Discharge Disposition: Home Discharge Diagnosis: Toxic shock syndrome with septic shock requiring vasopressors and aggressive IV volume repletion resuting in pulmonary edema',
#  '10-36': 'Discharge Disposition: Home Discharge Diagnosis: Toxic shock syndrome with septic shock requiring vasopressors and aggressive IV volume repletion resuting in pulmonary edema . Beta lactam allergy (likely) with drug eruption ( rash',
#  '10-38': 'You can resume TUMS as you were prior to coming to the hospital, and you can use over the counter benadryl for itching as needed',
#  '11-0': 'Admission Date: [**2178-1-20**] Discharge Date: [**2178-2-7**] Date of Birth: [**2107-2-15**] Sex: M Service: OME HISTORY OF PRESENT ILLNESS: This patient is a 70-year-old male with extensive locally recurrent melanoma',
#  '11-1': 'He was due to be started on high-dose IL-2 but in clinic on [**2178-1-12**], he was noticed to have erythema in an area of recent lymph node dissection felt consistent with cellulitis , and was started on oral Keflex',
#  '11-6': 'The patient reports that in the week since he started antibiotics',
#  '11-7': 'Follow up head MRI and torso CT on [**2178-1-7**] revealed no metastatic brain lesions, but metastatic disease in his chest, left axilla, mediastinum and lung, as well as a T12 sclerotic focus felt consistent with melanoma',
#  '11-8': 'He has passed screening tests to begin high-dose IL-2',
#  '11-10': 'MEDICATIONS ON ADMISSION: Enalapril 20 mg p.o. daily , pravastatin 20 mg p.o. daily , Keflex 500 mg p.o. b.i.d.',
#  '11-22': 'HOSPITAL COURSE: The patient was admitted with cellulitis and was placed on IV vancomycin',
#  '11-25': 'HOSPITAL COURSE: The patient was admitted with cellulitis and was placed on IV vancomycin. Doxycycline',
#  '11-26': 'Doxycycline was added when he did not appear to be improving. Unasyn was added when the cellulitic area continued to worsen',
#  '11-28': 'He also became short of breath and was treated with Lasix',
#  '11-30': 'Transthoracic echo revealed diastolic heart failure and he was continued on enalapril and Lasix',
#  '11-33': 'He had an ID consult on [**1-28**] who suggested stopping the Unasyn , changing to cefepime and adding vancomycin',
#  '11-36': 'Derm consult on [**1-28**] was obtained due to persistent rash, and a biopsy was performed consistent with melanoma',
#  '11-37': 'He was subsequently transferred to the biologic service on [**2178-1-30**] to begin high-dose IL-2',
#  '11-39': 'During this week he received 7 of 14 doses with 7 doses held related to tachycardia and pulmonary edema',
#  '11-41': 'Chest x- ray was consistent with bilateral pleural effusions',
#  '11-42': 'Throughout the day he became increasingly more tachypneic and fatigued',
#  '11-44': 'He was treated with Lasix',
#  '11-45': 'He developed SVT to the 140s on [**2178-2-4**], which spontaneously improved with a fluid bolus',
#  '11-48': 'His respiratory status improved with continued diuresis',
#  '11-49': 'His respiratory status improved with continued diuresis, and he was transferred back to the floor on [**2178-2-5**]. Lasix and enalapril',
#  '11-51': 'Other side effects related to IL-2 included rigors improved with Demerol ; fatigue ; and hypotension on treatment day 3, requiring fluid boluses',
#  '11-58': 'He developed metabolic acidosis with a minimum bicarb of 18, improved with bicarbonate boluses',
#  '11-61': 'Strict I & Os and serum chemistries were maintained. IV fluids',
#  '11-63': 'DISCHARGE DIAGNOSES: 1. Metastatic melanoma status post cycle 1, week 1, high- dose IL-2 therapy complicated by pulmonary edema , and bilateral pleural effusions from IL-2 induced capillary leak , with respiratory distress',
#  '11-71': '2. Acute renal failure related to IL-2',
#  '11-73': 'DISCHARGE MEDICATIONS: Enalapril 20 mg p.o. daily , Lasix 20 mg p.o. daily , lorazepa m 0.5 mg q. 6 hours p.r.n. nausea , pravastatin 20 mg p.o. daily , Compazine 5 to 10 mg q.i.d. p.r.n. nausea',
#  '12-0': 'Past Medical History: A fib (on coumadin ) Coronary Artery Disease Cerebrovascular accident Osteoporosis Social History: lives at home alone, has VNA to check on coumadin',
#  '12-3': 'She has a history of chronic atrial fibrillation treated with Coumadin',
#  '12-5': 'Upon admission her INR was 6.0',
#  '12-6': 'CT scans from [**Hospital 1474**] hospital as well as our institution showed a large left retroperitoneal hematoma',
#  '12-7': 'The patient had been generally hemodynamically stable but has required pressors and several units of packed red blood cells',
#  '12-9': 'We diuresed her with several doses of IV furosemide',
#  '12-12': 'During her hospital stay she was not anticoagulated with coumadin , given her recent episode of bleeding',
#  '12-15': 'She is receiving 5000 units sq heparin twice daily and is instructed to get in touch with her PCP as soon as possible to resume her coumadin',
#  '12-20': 'We increased her beta-blocker dose to 50 mg QID',
#  '12-23': 'Medications on Admission: Acetaminophen , Insulin , Famotidine , Simvastatin , Dilaudid , Heparin , Hydralazine , Metoprolol , Nitro , Aspirin , Lisinopril',
#  '12-34': 'Medications on Admission: Acetaminophen, Insulin, Famotidine, Simvastatin, Dilaudid, Heparin, Hydralazine, Metoprolol, Nitro, Aspirin, Lisinopril Discharge Medications: 1. Furosemide 40 mg Tablet Sig: One (1) Tablet PO BID',
#  '12-41': '2. Hydralazine 25 mg Tablet Sig: Two (2) Tablet PO Q8H',
#  '12-48': '3. Multivitamin Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '12-54': '4. Aspirin 81 mg Tablet, Chewable Sig: One (1) Tablet, Chewable PO DAILY (Daily)',
#  '12-61': '5. Cholecalciferol (Vitamin D3 ) 400 unit Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '12-68': '6. Amlodipine 2.5 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '12-75': '7. Simvastatin 40 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '12-82': '8. Isosorbide Mononitrate 30 mg Tablet Sustained Release 24 hr Sig: Two (2) Tablet Sustained Release 24 hr PO DAILY (Daily)',
#  '12-89': '9. Lisinopril 10 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '12-96': '10. Spironolactone 25 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '12-103': '11. Famotidine 20 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '12-110': '12. Calcium Carbonate 500 mg Tablet, Chewable Sig: One (1) Tablet, Chewable PO BID (2 times a day)',
#  '12-117': '13. Trazodone 50 mg Tablet Sig: 0.5 Tablet PO HS (at bedtime)',
#  '12-124': '14. Oxycodone 5 mg/5 mL Solution Sig: One (1) ml PO Q4H (every 4 hours) as needed for pain for 2 weeks',
#  '12-132': 'Disp:*400 ml* Refills:*0* 15. Senna 8.6 mg Tablet Sig: One (1) Tablet PO HS (at bedtime) for 2 weeks',
#  '12-140': 'Disp:*30 Tablet(s)* Refills:*0* 16. Docusate Sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day) for 2 weeks',
#  '12-148': 'Disp:*30 Capsule(s)* Refills:*0* 17. Insulin Regular Human 100 unit/mL Solution Sig: One (1) units per sliding scale Injection ASDIR',
#  '12-155': '18. Metoprolol Tartrate 50 mg Tablet Sig: One (1) Tablet PO QID',
#  '12-162': '19. Heparin (Porcine) 5,000 unit/mL Solution Sig: One (1) 5000 Injection [**Hospital1 **] (2 times a day)',
#  '12-168': '[**Last Name (STitle) 17887**] as soon as possible for further guidance on your coumadin',
#  '12-169': '[**Last Name (STitle) 17887**] for resuming your coumadin',
#  '13-0': "He went to [**Doctor Last Name 1263**] ED, found to be febrile with abnormal LFT's, was started on antibiotics ( clinda / ceftaz ) and IVF , and was transferred to [**Hospital1 18**] for presumed biliary sepsis",
#  '13-6': 'On transfer, he was started on zosyn / levo / flagyl',
#  '13-9': 'SWAN on [**12-24**] showed PCWP 35, BP 95/43, FA=22, and the next warning, he went into rapid afib with decompensation',
#  '13-10': 'He was on 3 pressors at the time ( levophed , vasopressin , dopa ), converted into NSR temporarily, was started on amio',
#  '13-15': 'DCCV was repeated 2 times without success; he spontaneously reverted to NSR (?s/p DCCV on [**12-26**]) has remained in this rhythm, and is on an amio taper ( drip',
#  '13-18': 'With respect to his sepsis , he required 3 pressors as above, was on vanco / zosyn / lev / flagyl',
#  '13-24': 'Blood cultures from [**Doctor Last Name 1263**] grew out [**4-26**] E. coli (with E. coli also in urine) resistant to amp / pip / sulbactam',
#  '13-27': 'Blood cultures from [**Doctor Last Name 1263**] grew out [**4-26**] E. coli (with E. coli also in urine) resistant to amp/pip/sulbactam. Ciprofloxacin',
#  '13-28': 'He is currently just on cipro and is to complete a 14 day course for E. coli',
#  '13-31': 'Other MICU events include a drop in platelets following 48 hours of heparin',
#  '13-33': 'MI [**6-29**] yrs ago; few episodes of angina since that time Other PMH: 1. RA x 30 yrs, on remicaide and MTX',
#  '13-36': "Pilonidal cyst in 20's Meds on transfer: Ciprofloxacin 500 [**Hospital1 **] (d4/14; d1=[**12-26**]) Amiodarone taper Oxybutynin 5 mg TID SSI ASA 325 Lansoprazole Ativan PRN MsO4 PRN Nystatin suspension",
#  '13-53': 'He remained hypotensive despite IVF , and pressors were continued, with eventual triple pressor therapy ( Levo , Dopamine and Vasopressin ) required for hemodynamic support',
#  '13-61': 'Despite appropriate response, the low random cortisol prompted initiation of steroid therapy, initially Dexamethasone , then hydrocortisone and Fludrocortisone with plan to complete 7 days',
#  '13-67': 'He was successfully weaned off Levo and Vasopressin on [**2195-12-28**], then off Dopamine',
#  '13-70': 'He was initially on vanco / zosyn / flagyl --> cipro / vanco / flagyl',
#  '13-76': 'He was initially on vanco/zosyn/flagyl-->cipro/vanco/flagyl. Vanco / flagyl were discontinued on [**12-27**] (c. diff neg x 3), and he will continue a course of cipro for ? urosepsis',
#  '13-80': 'All cultures here have been NGTD, but he is being treated for [**4-26**] E. coli blood culture bottles at [**Doctor Last Name 1263**]. Ciprofloxacin was continued for the 14 day',
#  '13-82': 'He was hemodynamically stable throughout hospitalization. Blood pressure medications',
#  '13-83': 'Blood pressure medications were initially held [**2-23**] hypotension. Lisinopril',
#  '13-84': 'Lisinopril was restarted prior to discharge after renal function improved. Atenolol was held given patient was still on amiodarone taper',
#  '13-87': "He received 48 hours of intravenous heparin , D/C'd in the setting of thrombocytopenia",
#  '13-91': 'Cardiology followed in-house. Lisinopril , ASA',
#  '13-93': 'Lisinopril, ASA, were continued. Lipitor was added upon discharge at a lower dose, and atenolol',
#  '13-95': 'This should be restarted when amiodarone taper',
#  '13-97': '3. Afib',
#  '13-98': 'He was loaded with amiodarone IV and an amiodarone drip',
#  '13-102': 'Then, he reverted back into afib on [**12-26**] after an increase in dopamine dose to 3',
#  '13-105': 'Given low cardiac output and ongoing hypotension requiring 3 pressors',
#  '13-107': 'The patient was switched to PO amiodarone on [**12-26**], to be continued TID until [**1-2**], then [**Hospital1 **] for 1 week , then QD for 1 week , then 200 mg PO QD',
#  '13-116': 'His atenolol was held and should be restarted after he finishes his amiodarone taper',
#  '13-119': 'He was started on fondaparinux / coumadin for anticoagulation',
#  '13-122': 'Goal INR is [**2-24**], fondaparinux',
#  '13-123': 'He diuresed very well on IV lasix',
#  '13-126': 'He was discharge on PO bumex 1 mg daily',
#  '13-130': 'They should be checked within a week of discharge. Lipitor',
#  '13-131': '7. Thrombocytopenia',
#  '13-132': 'Concern for HIT was raised and Heparin was discontinued after 48 hours',
#  '13-135': 'Ultimately, thrombocytopenia was felt medication-induced, query direct effect of Heparin versus antibiotics ( vanco , Flagyl',
#  '13-140': 'This was likley multifactorial in the setting of sepsis, medications, pressors and not [**2-23**] heparin',
#  '13-142': '8. ? Glucose intolerance Glucose intolerance : continue on SSI , no history of DM, likely in setting of steroids for sepsis',
#  '13-147': '?Glucose intolerance: continue on SSI, no history of DM, likely in setting of steroids for sepsis. SSI',
#  '13-148': 'Medications on Admission: Aspirin 325 po daily Lipitor 80 daily Protonix 40 daily Folate 1 mg po daily Zestril 10 po daily atenolol 25 daily remicaid q weeks',
#  '13-171': 'Medications on Admission: Aspirin 325 po daily Lipitor 80 daily Protonix 40 daily Folate 1 mg po daily Zestril 10 po daily atenolol 25 daily remicaid q weeks Discharge Medications: 1. Aspirin 325 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '13-178': '2. Nystatin 100,000 unit/mL Suspension Sig: Five (5) ML PO QID (4 times a day) as needed',
#  '13-185': '3. Insulin Regular Human 100 unit/mL Solution Sig: sliding scale Injection ASDIR (AS DIRECTED)',
#  '13-191': '4. Oxybutynin Chloride 5 mg Tablet Sig: One (1) Tablet PO TID (3 times a day) as needed',
#  '13-198': '5. Ciprofloxacin 500 mg Tablet Sig: One (1) Tablet PO Q12H (every 12 hours) for 7 days',
#  '13-206': '6. Amiodarone HCl 200 mg Tablet Sig: Two (2) Tablet PO BID (2 times a day) for 7 days',
#  '13-214': '7. Amiodarone HCl 200 mg Tablet Sig: Two (2) Tablet PO DAILY (Daily)',
#  '13-221': '8. Pantoprazole Sodium 40 mg Tablet, Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q24H (every 24 hours)',
#  '13-228': '9. Senna 8.6 mg Tablet Sig: One (1) Tablet PO BID (2 times a day) as needed',
#  '13-235': '10. Zolpidem Tartrate 5 mg Tablet Sig: Two (2) Tablet PO HS (at bedtime) as needed',
#  '13-242': '11. Fondaparinux Sodium 2.5 mg/0.5 mL Syringe Sig: One (1) Subcutaneous DAILY (Daily) : Continue until therapeutic on coumadin',
#  '13-249': 'Overlap therapy for 2 days with therapeutic coumadin',
#  '13-250': '12. Morphine Sulfate 2-4 mg IV Q4H:PRN',
#  '13-254': 'Morphine Sulfate 2-4 mg IV Q4H:PRN 13. Lorazepam 0.5-2 mg IV Q4H:PRN',
#  '13-258': 'Lorazepam 0.5-2 mg IV Q4H:PRN 14. Warfarin Sodium 2 mg Tablet Sig: One (1) Tablet PO HS',
#  '13-265': 'Adjust coumadin',
#  '13-266': '15. Lisinopril 2.5 mg Tablet Sig: One (1) Tablet PO once a day',
#  '13-273': '16. Bumex 1 mg Tablet Sig: One (1) Tablet PO once a day',
#  '13-280': '17. Lipitor 40 mg Tablet Sig: One (1) Tablet PO once a day',
#  '13-287': '18. Cyanocobalamin 1,000 mcg Tablet Sustained Release Sig: One (1) Tablet Sustained Release PO once a day',
#  '13-294': '-We added Bumex 1 mg PO qam , for diuresis',
#  '13-299': '- You should finish a course of antibiotics ( ciprofloxacin ); continue until [**1-9**], for positive blood cultures - You can continue the oxybutynin for bladder spasms if you continue to requires this - We started you on Fondaparinux and coumadin ( anticoagulation for your atrial fibrillation and low ejection fraction',
#  '13-308': 'The Fondaparinux will only be continued until you are therapeutic on your coumadin',
#  '13-310': '- You should finish amiodarone taper',
#  '13-312': '- We are holding your beta blocker (you were on atenolol 25 mg daily ) for now until you complete the amiodarone taper',
#  '13-317': '- We are also holding your rheumatoid arthritis medications at this time ( MTX , Remicaide',
#  '13-320': '- We also decreased your lipitor to 40 qd',
#  '13-323': 'He can consider stopping your bumex at this time, restart your beta blocker and your rheumatoid arthritis medications',
#  '13-326': 'You will be on an amiodarone taper',
#  '13-328': 'She should consider restarting your atenolol at this time and monitor your coumadin',
#  '13-330': 'She should also consider titrating up your Lisinopril to your usual dose ( 10 mg daily',
#  '13-333': 'We are discharging you on 2.5 mg daily',
#  '13-335': 'She may decide when to restart your Methotrexate and Remicaide',
#  '14-0': 'Admission Date: [**2174-4-18**] Discharge Date: [**2174-5-17**] Date of Birth: [**2135-11-15**] Sex: F Service: MEDICINE Allergies: Prochlorperazine / Heparin Agents Attending:[**First Name3 (LF) 3918**] Chief Complaint: Abdominal Pain Major Surgical or Invasive Procedure: Upper GI series with small bowel follow through Right heart catheterization IR guided paracentesis History of Present Illness: 38 yo F w/ h/o ALL in remission s/p cord transplant in [**1-13**], anthracycline -induced cardiomyopathy',
#  '14-4': 'She received iv zofran and morphine 4mg iv and 1L IVF',
#  '14-11': 'WBC 149,000; received leukapheresis, started on hydroxyurea',
#  '14-12': "Dx'ed with precursor B-cell ALL",
#  '14-13': '- underwent phase I induction with daunorubicin , vincristine , dexamethasone , L-asparaginase , MTX ; phase II with cyclophosphamide , cytarabine , mercaptopurine , MTX - Bone Marrow Aspirate/Biopsy on [**2172-10-26**] showed no morphologic evidence of residual leukemia - underwent allo double cord blood SCT [**2173-1-11**], course complicated by neutropenic fever and acute skin GVHD OTHER MEDICAL HISTORY: - Embolic stroke in [**3-/2174**] on coumadin - Cardiomyopathy due to early anthracycline -related cardiotoxicity',
#  '14-27': 'Study is suboptimal for evaluation of solid organs due to lack of IV contrast',
#  '14-29': 'There is no evidence of colonic wall thickening, although evaluation is suboptimal given lack of IV or PO contrast',
# ...
#  '29-62': 'Medication changes: 1)We started you on a multivitamin , folic acid , and thiamine to take every day',
#  '30-0': 'Admission Date: [**2113-6-15**] Discharge Date: [**2113-6-20**] Date of Birth: [**2031-6-5**] Sex: M Service: MEDICINE Allergies: Vancomycin',
#  '30-1': 'Intra-operative TEE was unremarkable, but he did require Neosynephrine in the OR for hypotension that was thought to be due to the prolonged anesthesia',
#  '30-4': 'Given the significant infection , the wound was left open, to close by secondary intention, with plan to treat with IV antibiotics',
#  '30-7': 'With regards to the recent device infection in [**2113-1-12**], this was initially treated with IV vancomycin , but that was discontinued due to development of fever and rash',
#  '30-12': 'He was instead treated with a full course of IV linezolid',
#  '30-14': 'He received a 200cc NS IVF bolus',
#  '30-17': 'His external pacemaker rate was increased from 60 to 80 bpm. IV Linezolid was started for possible septicemia',
#  '30-20': 'He did not require any further IVF or vasopressor',
#  '30-22': '* Device infection in [**2113-1-12**], initially treated with IV vancomycin , which was discontinued due to development of fever and rash',
#  '30-27': 'Then treated with full course of IV linezolid',
#  '30-29': 'Brief Hospital Course: 82-yo man with complete heart block s/p dual chamber pacemaker with RV lead revision and recent device infection who presented with continued device infection for lead and device extraction, found to have significant infection of the pacer pocket and lead fibrosis, now s/p external temporary pacemaker placement and awaiting treatment with IV antibiotics',
#  '30-32': 'On arrival to the CCU, the patient was hypotensive',
#  '30-33': 'He received a 200cc NS IVF bolus',
#  '30-36': 'He was started on IV Linezolid',
#  '30-38': 'He did not require any further IVF or vasopressor',
#  '30-40': 'He was seen by ID who recommended 2 weeks of linezolid',
#  '30-42': 'His wound culture eventually grew coag-neg staph',
#  '30-43': 'He was continued on home ASA',
#  '30-44': "# hypertension - The patient's anti-hypertensives were intially held secondary to his hypotension",
#  '30-47': 'Once his pressures had stabilzed he was restarted on lisinopril 10mg and home metoprolol succinate 12.5mg',
#  '30-51': '# dyslipidemia - stable, continued home statin',
#  '30-53': '# diabetes - stable, continued home Actos and ISS',
#  '30-56': '# GERD - stable, continued home H2B # BPH - His flomax was initally held secondary to hypotension',
#  '30-61': 'Medications on Admission: Lisinopril 20mg daily Lovastatin 20mg daily Metoprolol succinate 12.5mg daily Actos 15mg daily Zantac 150mg daily PRN Flomax 0.4mg daily Aspirin 325 mg daily Vitamin C 500mg daily Vitamin B12 500mcg daily Glucosamine-Chondroitin 500mg-400mg daily Loratadine 10mg QHS Multivitamin daily Aleve 220mg daily PRN Vitamin E 400unit daily',
#  '30-102': 'Medications on Admission: Lisinopril 20mg daily Lovastatin 20mg daily Metoprolol succinate 12.5mg daily Actos 15mg daily Zantac 150mg daily PRN Flomax 0.4mg daily Aspirin 325 mg daily Vitamin C 500mg daily Vitamin B12 500mcg daily Glucosamine-Chondroitin 500mg-400mg daily Loratadine 10mg QHS Multivitamin daily Aleve 220mg daily PRN Vitamin E 400unit daily Discharge Medications: 1. Aspiri n 325 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '30-109': '2. Tylenol 325 mg Tablet Sig: 1-2 Tablets PO four times a day as needed for pain',
#  '30-117': '3. Lovastati n 20 mg Tablet Sig: One (1) Tablet PO daily',
#  '30-124': '4. Pioglitazon e 15 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '30-131': '5. Ranitidine HCl 150 mg Tablet Sig: One (1) Tablet PO DAILY (Daily) as needed for indigestion',
#  '30-139': '6. Metoprolol Succinate 25 mg Tablet Sustained Release 24 hr Sig: 0.5 Tablet Sustained Release 24 hr PO once a day',
#  '30-146': '7. Ascorbic Acid 500 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '30-153': '8. Vitamin E 400 unit Tablet Sig: One (1) Tablet PO once a day',
#  '30-160': '9. Cyanocobalamin 500 mcg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '30-167': '10. Loratadin e 10 mg Tablet Sig: One (1) Tablet PO at bedtime',
#  '30-174': '11. Multivitamin Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '30-180': '12. Tamsulosin 0.4 mg Capsule, Sust. Release 24 hr Sig: One (1) Capsule, Sust. Release 24 hr PO HS (at bedtime)',
#  '30-187': '13. Lisinopril 10 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '30-194': '16. Linezolid 600 mg Tablet Sig: One (1) Tablet PO Q12H (every 12 hours) for 9 days',
#  '30-202': 'Disp:*18 Tablet',
#  '30-203': 'Discharge Instructions: You had a pacemaker pocket infection',
#  '30-204': 'You are on Linezolid antibiotic to treat this infection',
#  '30-206': 'While you are on the antibiotics',
#  '30-207': 'New medicines: 1. Linezolid : an antibiotic to treat the pocket infection',
#  '30-209': 'Please decrease your Lisinopril to 10 mg at night',
#  '31-0': 'Admission Date: [**2132-1-30**] Discharge Date: [**2132-2-2**] Date of Birth: [**2077-2-8**] Sex: F Service: MEDICINE Allergies: Sulfa (Sulfonamides) / Procardia Attending:[**First Name3 (LF) 1257**] Chief Complaint: GI Bleed Major Surgical or Invasive Procedure: Colonoscopy Right femoral line History of Present Illness: 54 year old woman with past medical history significant for diverticulosis, hypertension, hyperlipidemia, rhythm controlled afib not on coumadin',
#  '31-3': 'Pt denies fever/chill, NSAIDs use, but she is on ASA 81mg daily',
#  '31-7': 'Patient was given 1 liter NS',
#  '31-9': 'NG lavage was negative for blood. Hct was 26 from baseline of 43, so she was given 2 unit of blood',
#  '31-12': 'She was alert during these encounter. Intravenous Protonix given and Cipro and flagyl',
#  '31-16': 'She received total of 6 U PRBC (last one at 8 AM today) 1 U FFP',
#  '31-20': 'Past Medical History: #. pAfib - maintained on Propafenone - CHADS1 , on aspirin',
#  '31-24': "Bladder cancer - dx'ed 3 yrs ago s/p resection, no chemo",
#  '31-25': 'Brief Hospital Course: 54 year old woman with past medical history of diverticulosis with past GI bleeds, atrial fibrillation (CHADS1, not on coumadin',
#  '31-26': '# Bright red blood per rectum',
#  '31-27': 'Hematocrit stabilized after 6 units pRBC , 1 unit FFP',
#  '31-31': 'Etiology likely diverticular bleed',
#  '31-32': 'Also on the differential but lower include ischemic colitis given atrial fibrillation (without coumadin',
#  '31-33': 'Her IV pantoprazole',
#  '31-35': '# PRURITIC RASH PRURITIC RASH',
#  '31-37': 'Responded to Sarna lotion',
#  '31-39': 'Patient felt the IV pantoprazole caused her rash',
#  '31-42': '# PAROXYSMAL ATRIAL FIBRILLATION',
#  '31-43': 'Given her GI bleed , aspirin',
#  '31-45': 'She was continued on Propafenon',
#  '31-46': '# CHRONIC DIASTOLIC HEART FAILURE',
#  '31-47': "After her colonoscopy, patient's home Diltiazem",
#  '31-48': 'Her enalapril',
#  '31-49': '# OSTEOARTHRITIS : Stable and pain well controlled with tylenol and oxycodone PRN',
#  '31-54': '# CODE: Full, discussed and confirmed in ICU Medications on Admission: DILTIAZEM HCL - 240 mg Capsule ENALAPRIL MALEATE - 20 mg Tablet [**Hospital1 **] FUROSEMIDE - 40 mg Tablet daily OXYCODONE- ACETAMINOPHEN - 5 mg -325 mg q6H :PRN Pain PROPAFENONE [RYTHMOL SR] - 225 mg Capsule [**Hospital1 **] DOCUSATE SODIUM - 100 mg Capsule ASPIRIN 81mg daily',
#  '31-77': '# CODE: Full, discussed and confirmed in ICU Medications on Admission: DILTIAZEM HCL - 240 mg Capsule ENALAPRIL MALEATE - 20 mg Tablet [**Hospital1 **] FUROSEMIDE - 40 mg Tablet daily OXYCODONE-ACETAMINOPHEN - 5 mg-325 mg q6H:PRN Pain PROPAFENONE [RYTHMOL SR] - 225 mg Capsule [**Hospital1 **] DOCUSATE SODIUM - 100 mg Capsule ASPIRIN 81mg daily Discharge Medications: 1. Oxycodone- Acetaminophen 5-325 mg Tablet Sig: One (1) Tablet PO Q6H (every 6 hours) as needed for back pain',
#  '31-85': '2. Propafenone 225 mg Capsule, Sust. Release 12 hr Sig: One (1) Capsule, Sust. Release 12 hr PO twice a day',
#  '31-92': '3. Cartia XT 240 mg Capsule, Sust. Release 24 hr Sig: One (1) Capsule, Sust. Release 24 hr PO once a day',
#  '31-99': '4. Docusate Sodium 250 mg Capsule Sig: One (1) Capsule PO twice a day',
#  '31-106': '5. Aspirin 81 mg Tablet Sig: One (1) Tablet PO once a day',
#  '31-113': '6. Enalapril Maleate 20 mg Tablet Sig: One (1) Tablet PO once a day',
#  '31-120': 'Discharge Disposition: Home Discharge Diagnosis: Primary: Diverticular bleed Secondary: Paroxysmal atrial fibrillation, chronic diastolic CHF, hypertension/hyperlipidemia, osteoarthritis Discharge Condition: Mental Status:Clear and coherent Level of Consciousness:Alert and interactive Activity Status:Ambulatory - Independent Discharge Instructions: -You were admitted with bright red blood in your bowel',
#  '31-121': 'You were briefly in the ICU but stabilized well with 6 units of red blood cells',
#  '31-123': 'We made the following changes to your medications during this admission: --> HOLD Furosemide 40mg daily until you discuss with your primary care doctor --> RESUME Aspirin 81mg daily --> RESUME Rhythmol SR 225mg twice daily --> RESUME Enalapril 20mg twice daily',
#  '31-135': 'Please discuss with her about re-starting Furosemide (aka Lasix)',
#  '32-0': 'Admission Date: [**2180-9-9**] Discharge Date: [**2180-10-13**] Date of Birth: [**2148-11-12**] Sex: F Service: SURGERY Allergies: Nafcillin / Peanut Attending:[**First Name3 (LF) 5569**] Chief Complaint: Abdominal pain and fever Major Surgical or Invasive Procedure: Colonoscopy ([**2180-9-11**]) History of Present Illness: 31yoF with h/o IVDA, cirrhosis [**1-19**] autoimmune hepatitis c/b portal HTN w/ ascites, variceal bleed s/p TIPS on [**2180-7-17**], and hepatic encephalopathy, as well as hyperglycemia [**1-19**] TIPs and steroids',
#  '32-2': 'During that admission, she had a CT scan which showed no cause for her pain. Gastroenteritis was presumed and she was discharged home after her symptoms improved with zofran and dilaudid',
#  '32-5': 'At OSH ED, she received zofran 4 mg , dilaudid 1 mg x 3 , and 1L NS',
#  '32-12': 'She was given 2L NS , 0.5 mg IV dilaudid x 2 , and 4 mg IV zofran',
#  '32-21': 'Course was complicated by high-grade MRSA bacteremia requiring 6 weeks of IV vancomycin',
#  '32-25': 'Past Medical History: # Autoimmune hepatitis: [**Doctor First Name **]+, AMA-, [**Last Name (un) 15412**]+ # Cirrhosis, complicated by varices, hepatic encephalopathy, and ascites s/p TIPS [**2180-7-17**] # Hep C: Genotype 3. most recent viral load undetectable # high grade S aureus bacteremia on vancomycin',
#  '32-27': 'F with h/o IDDM, IVDA, cirrhosis [**1-19**] autoimmune hepatitis c/b portal HTN w/ ascites, variceal bleed s/p TIPS on [**2180-7-17**], and hepatic encephalopathy, presented with abd pain and occult anemia',
#  '32-28': 'Hct drop from 24 to 21. PRBC transfusion',
#  '32-30': 'Postop course was complicated by high ascites drain output requiring IV fluid replacements and albumin',
#  '32-34': 'Diet was slowly advanced. Lactulose and Rifaximin were started to prevent encephalopathy',
#  '32-37': 'She had high pain med requirements for persistent abdominal pain',
#  '32-39': 'Culture of fluid isolated 2 species of Acinetobacter Baumanii pan-sensitive except Bactrim',
#  '32-41': 'She was started on Cetriaxone',
#  '32-42': 'On postop day 13, she was re-started on Lasix and Aldactone',
#  '32-44': 'Creatinine continued to rise to 3.2 then decrease. Lasix was given for generalized edema',
#  '32-46': 'Diet was advanced and tolerated. Insulin gtt was initially started then switched to sliding scale',
#  '32-49': '[**Last Name (un) **] was consulted and Lantus with sliding scale',
#  '32-51': 'She was assisted out of bed to ambulate. Pain medication was switched to po Dilaudid',
#  '32-54': 'Dose was increased for c/o abdominal pain',
#  '32-55': 'She was also hypertensive',
#  '32-56': 'This was treated with IV Lopressor and IV Morphine',
#  '32-60': 'Head CT was normal. Norvasc was stopped for potential etiology of headache',
#  '32-62': 'Headache and abdominal pain resolved. Immunosuppression consisted of Cellcept which was well tolerated, steroids were tapered',
#  '32-66': 'Immunosuppression consisted of Cellcept which was well tolerated, steroids were tapered per protocol. Prograf',
#  '32-67': 'The plan was for Prednisone to continue permanently after taper for Autoimmune hepatitis',
#  '32-70': 'The plan was for Prednisone to continue permanently after taper for Autoimmune hepatitis. Lasix was continued for 2+ leg edema',
#  '32-72': 'She demonstrated good knowledge of medications and insulin',
#  '32-73': 'Of note, she experienced developed diffuse itching and burning of the skin and sensation of shortness of breath after eating a peanut butter',
#  '32-75': 'She was given Benadryl',
#  '32-76': 'Serum specific IgE to peanuts and other common food allergens were sent, and she was given an EpiPen',
#  '32-78': 'Medications on Admission: MEDICATIONS: (from prior discharge summary) # lactulose 10 gram /15 mL Syrup Sig: Thirty (30) ML PO Q2H (every 2 hours) as needed',
#  '32-84': '# azathioprine 50 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '32-91': '# magnesium oxide 400 mg Tablet Sig: One (1) Tablet PO twice a day',
#  '32-98': '# sulfamethoxazole- trimethoprim 800-160 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '32-105': '# spironolacton e 25 mg Tablet Sig: Two (2) Tablet PO DAILY (Daily ): Please give with furosemide',
#  '32-113': '# furosemide 40 mg Tablet Sig: One (1) Tablet PO DAILY (Daily) : Please give with spironolactone',
#  '32-121': '# metoprolol tartrate 25 mg Tablet Sig: One (1) Tablet PO BID (2 times a day)',
#  '32-128': '# pantoprazole 40 mg Tablet , Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO Q12H (every 12 hours)',
#  '32-135': '# rifaximi n 550 mg Tablet Sig: One (1) Tablet PO BID (2 times a day)',
#  '32-142': '# prednisone 10 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '32-149': '# insulin glargine 100 unit/mL Cartridge Sig: Thirty (30) units Subcutaneous qam : Please take 30 units of glargine insulin in the morning',
#  '32-158': '# ondansetro n 4 mg Tablet, Rapid Dissolve Sig: One (1) Tablet, Rapid Dissolve PO every eight (8) hours as needed for nausea for 5 doses',
#  '32-167': '# clotrimazole 10 mg Troche Sig: One (1) Troche Mucous membrane 5X/DAY (5 Times a Day)',
#  '32-174': '# fluconazol e 150 mg Tablet Sig: One (1) Tablet PO EVERY 3 DAYS (Every 3 Days)',
#  '32-181': '# insulin lispro 100 unit /mL Solution Sig: sliding scale Subcutaneous per sliding scale : Please take insulin lispro as directed by your home sliding scale three times a day before meals and before bedtime',
#  '32-190': 'Discharge Medications: 1. fluconazole 200 mg Tablet Sig: Two (2) Tablet PO Q24H (every 24 hours)',
#  '32-197': '2. prednisone 20 mg Tablet Sig: One (1) Tablet PO DAILY (Daily) : follow sliding scale taper',
#  '32-205': '3. docusate sodium 100 mg Capsule Sig: One (1) Capsule PO BID (2 times a day)',
#  '32-212': '4. mycophenolate mofetil 500 mg Tablet Sig: Two (2) Tablet PO BID (2 times a day)',
#  '32-219': '5. sulfamethoxazole-trimethoprim 400-80 mg Tablet Sig: One (1) Tablet PO DAILY (Daily)',
#  '32-226': '6. pantoprazol e 40 mg Tablet , Delayed Release (E.C.) Sig: One (1) Tablet, Delayed Release (E.C.) PO twice a day',
#  '32-233': '7. valganciclovi r 450 mg Tablet Sig: Two (2) Tablet PO once a day',
#  '32-240': '8. tacrolimus 1 mg Capsule Sig: Five (5) Capsule PO Q12H (every 12 hours)',
#  '32-247': '9. insulin lispro 100 unit /mL Solution Sig: follow sliding scale Subcutaneous four times a day',
#  '32-253': 'Disp:*1 bottle* Refills:*2* 10. tacrolimu s 1 mg Capsule Sig: Three (3) Capsule PO Q12H (every 12 hours)',
#  '32-260': '11. metoprolol tartrate 25 mg Tablet Sig: One (1) Tablet PO BID (2 times a day)',
#  '32-267': 'Disp:*60 Tablet(s) * Refills:*2* 12. pregabali n 25 mg Capsule Sig: Two (2) Capsule PO QHS (once a day (at bedtime))',
#  '32-275': 'Disp:*60 Capsule(s) * Refills:*2* 13. morphine 15 mg Tablet Extended Release Sig: One (1) Tablet Extended Release PO Q12H (every 12 hours)',
#  ...}

# %%
import json
#with open("sents_dict.txt", "w") as fp:
    json.dump(sents_dict, fp)  # encode dict into JSON

# %%
entity_df = pd.DataFrame(tags_list, columns=['text_id','entity_id','start','end','concept','entity','sent_num']).set_index('entity_id')

# %%
entity_df['concept'].unique()
# Out:
# array(['Drug', 'Strength', 'Route', 'Reason', 'Duration', 'ADE', 'Dosage',
#        'Form', 'Frequency'], dtype=object)

# %%
#entity_df.to_csv('entity.csv', sep=',', encoding='utf-8')

# %%
'''
This is to generate relations to a specific format for one of my model, a relation triplet is formated as 
"start_position_1st_entity, end_position_1st_entity, start_position_2nd_entity, end_position_2nd_entity,
relation_type, 1st_entity_type, 2nd_entity_type" Each relation is concatenated by all the relation triplets
within the sentence, seperated by '|'
'''

relations = []
sents = []
for i, an in enumerate(tqdm(anno)):
    text = an.get_text()
    relation = ''
    entity_curr = entity_df[entity_df['text_id']==i]#['sent_num']
    curr_sent = 0
    relation_df = pd.DataFrame.from_dict(an.relations,orient='index')#.values()
    relation_df['head_entity'] = relation_df[1].apply(lambda x: int(x[1]))
    relation_df = relation_df.sort_values(['head_entity']).drop('head_entity',axis = 1)
    for k in relation_df.values:
        if k[0][0] not in entity_curr.index or k[1][0] not in entity_curr.index:
            continue
        e1, e2, rel = entity_curr.loc[k[0][0]], entity_curr.loc[k[1][0]], k[2]

 

        if e1['sent_num'] != e2['sent_num']:
            continue
        if curr_sent == 0:
            relation = ' '.join([str(e1['start']), str(e1['end']), str(e2['start']), str(e2['end']),
                                   '/'+rel+'/'+k[0][3]+'/'+k[1][3], '|'])
            curr_sent = e1['sent_num']
        elif e1['sent_num'] == curr_sent:           
            relation = ' '.join([relation, str(e1['start']), str(e1['end']), str(e2['start']), str(e2['end']),
                                   '/'+rel+'/'+k[0][3]+'/'+k[1][3], '|'])
        else:
            #print(curr_sent)
            relations.append(relation[:-2])  
            sents.append(sents_dict[curr_sent])
            curr_sent = e1['sent_num']
            relation = ' '.join([str(e1['start']), str(e1['end']), str(e2['start']), str(e2['end']),
                                   '/'+rel+'/'+k[0][3]+'/'+k[1][3],'|'])
    if curr_sent == 0:
        continue
    relations.append(relation[:-2])  
    sents.append(sents_dict[curr_sent])
    relation = ' '.join([str(e1['start']), str(e1['end']), str(e2['start']), str(e2['end']),
                           '/'+rel+'/'+k[0][3]+'/'+k[1][3],'|'])
# Out:
#   0%|          | 0/303 [00:00<?, ?it/s]

# %%
relations[6]
# Out:
# '1 3 8 9 /Reason-Drug/Reason/Drug | 1 3 11 13 /Reason-Drug/Reason/Drug'

# %%
import re
print(re.findall('\d+', relations[6]))
# Out:
# ['1', '3', '8', '9', '1', '3', '11', '13']

# %%
i_relation = relations[6].split("| ")
sample = []
for i in i_relation:
    relation_sample = []
    relation_sample.append((int(i.split(" ")[0]),int(i.split(" ")[1])))
    relation_sample.append((int(i.split(" ")[2]),int(i.split(" ")[3])))
    relation_sample.append(i.split(" ")[4].split("/")[1])
    sample.append(relation_sample)
print(sample)
# Out:
# [[(1, 3), (8, 9), 'Reason-Drug'], [(1, 3), (11, 13), 'Reason-Drug']]

# %%
sents[6].split()
# Out:
# ['5)',
#  'h/o',
#  'CAD',
#  ':',
#  'Patient',
#  'is',
#  'on',
#  'an',
#  'aspirin',
#  'and',
#  'a',
#  'beta',
#  'blocker']

# %%
relation_data = []
for i in range(len(sents)):
    sample = []
    sample.append(sents[i].split())
    i_relation = relations[i].split("| ")
    i_sample = []
    for i in i_relation:
        relation_sample = []
        relation_sample.append((int(i.split(" ")[0]),int(i.split(" ")[1])))
        relation_sample.append((int(i.split(" ")[2]),int(i.split(" ")[3])))
        relation_sample.append(i.split(" ")[4].split("/")[1])
        i_sample.append(relation_sample)
    sample.append(i_sample)
    relation_data.append(sample)

# %%
relation_data[6]
# Out:
# [['5)',
#   'h/o',
#   'CAD',
#   ':',
#   'Patient',
#   'is',
#   'on',
#   'an',
#   'aspirin',
#   'and',
#   'a',
#   'beta',
#   'blocker'],
#  [[(1, 3), (8, 9), 'Reason-Drug'], [(1, 3), (11, 13), 'Reason-Drug']]]

# %%
import json
with open("relation.txt", "w") as fp:
    json.dump(relation_data, fp)
